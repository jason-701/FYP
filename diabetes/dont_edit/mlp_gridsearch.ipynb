# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
from imblearn.over_sampling import SMOTE
import os

# %%
# Read the CSV file
df = pd.read_csv('diabetes_prediction_dataset.csv')
print(df.columns)
# Out:
# Index(['gender', 'age', 'hypertension', 'heart_disease', 'smoking_history',
#        'bmi', 'HbA1c_level', 'blood_glucose_level', 'diabetes'],
#       dtype='object')

# %% [markdown]
# ## <span style="color:red">Preprocessing</span>

# %%
null_counts = df.isnull().sum()
print(null_counts)
# Out:
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# smoking_history        0
# bmi                    0
# HbA1c_level            0
# blood_glucose_level    0
# diabetes               0
# dtype: int64

# %% [markdown]
# ### <span style="color:yellow">No columns have null values</span>

# %%
for i in df.columns:
    print("number of unique values in", i, ":", df[i].nunique())
# Out:
# number of unique values in gender : 3
# number of unique values in age : 102
# number of unique values in hypertension : 2
# number of unique values in heart_disease : 2
# number of unique values in smoking_history : 6
# number of unique values in bmi : 4247
# number of unique values in HbA1c_level : 18
# number of unique values in blood_glucose_level : 18
# number of unique values in diabetes : 2

# %% [markdown]
# ### <span style="color:yellow">One-hot encoding for gender and smoking_history</span>

# %%
df_encoded = pd.get_dummies(df, columns=['gender', 'smoking_history'], drop_first=True)
print(df_encoded.head())
# Out:
#     age  hypertension  heart_disease    bmi  HbA1c_level  blood_glucose_level  \
# 0  80.0             0              1  25.19          6.6                  140
# 1  54.0             0              0  27.32          6.6                   80
# 2  28.0             0              0  27.32          5.7                  158
# 3  36.0             0              0  23.45          5.0                  155
# 4  76.0             1              1  20.14          4.8                  155
#
#    diabetes  gender_Male  gender_Other  smoking_history_current  \
# 0         0        False         False                    False
# 1         0        False         False                    False
# 2         0         True         False                    False
# 3         0        False         False                     True
# 4         0         True         False                     True
#
#    smoking_history_ever  smoking_history_former  smoking_history_never  \
# 0                 False                   False                   True
# 1                 False                   False                  False
# 2                 False                   False                   True
# 3                 False                   False                  False
# 4                 False                   False                  False
#
#    smoking_history_not current
# 0                        False
# 1                        False
# 2                        False
# 3                        False
# 4                        False

# %% [markdown]
# ### <span style="color:yellow">Normalizing the data</span>

# %%
boolean_columns = df_encoded.select_dtypes(include=bool).columns
numerical_columns = df_encoded.select_dtypes(include=np.number).columns
print(boolean_columns)
print(numerical_columns)
# Out:
# Index(['gender_Male', 'gender_Other', 'smoking_history_current',
#        'smoking_history_ever', 'smoking_history_former',
#        'smoking_history_never', 'smoking_history_not current'],
#       dtype='object')
# Index(['age', 'hypertension', 'heart_disease', 'bmi', 'HbA1c_level',
#        'blood_glucose_level', 'diabetes'],
#       dtype='object')

# %%
# Separate features and target
X = df_encoded.drop(columns=['diabetes'])
y = df_encoded['diabetes']

# Identify numerical, boolean, and one-hot encoded columns
numerical_columns = X.select_dtypes(include=['float64', 'int64']).columns
boolean_columns = X.select_dtypes(include=['bool']).columns
one_hot_encoded_columns = X.columns.difference(numerical_columns.union(boolean_columns))

# Resample the data using SMOTE
# smote = SMOTE(random_state=42, sampling_strategy=0.10)

# Nevermind let's not do the resampling for now
X_resampled, y_resampled = X,y

# Normalize the numerical features
scaler = StandardScaler()
X_resampled_numerical = pd.DataFrame(scaler.fit_transform(X_resampled[numerical_columns]), columns=numerical_columns)

# Combine the normalized numerical features with the boolean and one-hot encoded features
X_resampled_scaled = pd.concat([X_resampled_numerical, X_resampled[boolean_columns].reset_index(drop=True), X_resampled[one_hot_encoded_columns].reset_index(drop=True)], axis=1)

# Add the target variable back to the DataFrame
df_resampled_scaled = pd.concat([X_resampled_scaled, y_resampled.reset_index(drop=True)], axis=1)

# Display the first few rows of the resampled and scaled DataFrame
print("Resampled and Scaled DataFrame:")
print(df_resampled_scaled.head())

# Check the class distribution after resampling
print("\nClass Distribution After Resampling:")
print(df_resampled_scaled['diabetes'].value_counts())

print("\nClass distribution before resampling:")
print(df['diabetes'].value_counts())
# Out:
# Resampled and Scaled DataFrame:
#         age  hypertension  heart_disease       bmi  HbA1c_level  \
# 0  1.692704     -0.284439       4.936379 -0.321056     1.001706
# 1  0.538006     -0.284439      -0.202578 -0.000116     1.001706
# 2 -0.616691     -0.284439      -0.202578 -0.000116     0.161108
# 3 -0.261399     -0.284439      -0.202578 -0.583232    -0.492690
# 4  1.515058      3.515687       4.936379 -1.081970    -0.679490
#
#    blood_glucose_level  gender_Male  gender_Other  smoking_history_current  \
# 0             0.047704        False         False                    False
# 1            -1.426210        False         False                    False
# 2             0.489878         True         False                    False
# 3             0.416183        False         False                     True
# 4             0.416183         True         False                     True
#
#    smoking_history_ever  smoking_history_former  smoking_history_never  \
# 0                 False                   False                   True
# 1                 False                   False                  False
# 2                 False                   False                   True
# 3                 False                   False                  False
# 4                 False                   False                  False
#
#    smoking_history_not current  diabetes
# 0                        False         0
# 1                        False         0
# 2                        False         0
# 3                        False         0
# 4                        False         0
#
# Class Distribution After Resampling:
# diabetes
# 0    91500
# 1     8500
# Name: count, dtype: int64
#
# Class distribution before resampling:
# diabetes
# 0    91500
# 1     8500
# Name: count, dtype: int64

# %% [markdown]
# ### <span style="color:yellow">Train test split</span>

# %%
x = df_resampled_scaled.drop('diabetes', axis=1)
y = df_resampled_scaled['diabetes']

x_train_val, x_test, y_train_val, y_test = train_test_split(x, y, test_size=0.15, random_state=42)
x_train, x_val, y_train, y_val = train_test_split(x_train_val, y_train_val, test_size=0.1765, random_state=42)

print(f"Train set size: {len(x_train)}")
print(f"Validation set size: {len(x_val)}")
print(f"Test set size: {len(x_test)}")
# Out:
# Train set size: 69997
# Validation set size: 15003
# Test set size: 15000

# %%
x_train
# Out:
#             age  hypertension  heart_disease       bmi  HbA1c_level  \
# 6237  -0.927571     -0.284439      -0.202578 -0.991565    -1.893686
# 55777  1.159766     -0.284439      -0.202578 -0.331603     1.842303
# 35621  0.626829     -0.284439      -0.202578  0.608616     0.534707
# 36264 -0.616691     -0.284439      -0.202578  0.189736     0.441307
# 72023 -0.572279     -0.284439      -0.202578 -0.000116    -1.893686
# ...         ...           ...            ...       ...          ...
# 4783  -1.726976     -0.284439      -0.202578 -1.339627     1.001706
# 62465  0.538006     -0.284439      -0.202578  0.289183     0.441307
# 61720  0.449184     -0.284439      -0.202578  0.161108     0.161108
# 31640  0.404772     -0.284439      -0.202578  0.554373     0.161108
# 66837 -1.783823     -0.284439      -0.202578 -1.341133    -0.492690
#
#        blood_glucose_level  gender_Male  gender_Other  \
# 6237              0.539009        False         False
# 55777             2.504228        False         False
# 35621             3.486837         True         False
# 36264             2.012923        False         False
# 72023             0.539009        False         False
# ...                    ...          ...           ...
# 4783             -1.303384         True         False
# 62465             0.416183        False         False
# 61720            -0.296209        False         False
# 31640             1.521618         True         False
# 66837             0.539009         True         False
#
#        smoking_history_current  smoking_history_ever  smoking_history_former  \
# 6237                     False                 False                   False
# 55777                    False                 False                    True
# 35621                     True                 False                   False
# 36264                    False                 False                   False
# 72023                    False                 False                   False
# ...                        ...                   ...                     ...
# 4783                     False                 False                   False
# 62465                    False                 False                   False
# 61720                    False                  True                   False
# 31640                    False                 False                   False
# 66837                    False                 False                   False
#
#        smoking_history_never  smoking_history_not current
# 6237                   False                        False
# 55777                  False                        False
# 35621                  False                        False
# 36264                   True                        False
# 72023                   True                        False
# ...                      ...                          ...
# 4783                   False                        False
# 62465                   True                        False
# 61720                  False                        False
# 31640                  False                        False
# 66837                  False                        False
#
# [69997 rows x 13 columns]

# %%
boolean_cols = x_train.select_dtypes(include=bool).columns

x_train[boolean_cols] = x_train[boolean_cols].astype(int)
x_val[boolean_cols] = x_val[boolean_cols].astype(int)
x_test[boolean_cols] = x_test[boolean_cols].astype(int)

# %% [markdown]
# ### <span style="color:yellow">Training an MLP model</span>

# %%
# import os
# import torch
# import torch.nn as nn
# import torch.optim as optim
# from torch.utils.data import DataLoader, TensorDataset

# # Check if CUDA is available and print the device being used
# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# print(f"Using device: {device}")

# # Convert data to PyTorch tensors
# X_train_tensor = torch.tensor(x_train.values, dtype=torch.float32)
# y_train_tensor = torch.tensor(y_train.values, dtype=torch.float32).unsqueeze(1)
# X_test_tensor = torch.tensor(x_test.values, dtype=torch.float32)
# y_test_tensor = torch.tensor(y_test.values, dtype=torch.float32).unsqueeze(1)

# # Create DataLoader
# train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
# test_dataset = TensorDataset(X_test_tensor, y_test_tensor)
# train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
# test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# class MLP(nn.Module):
#     def __init__(self, input_dim):
#         super(MLP, self).__init__()
#         self.model = nn.Sequential(
#             nn.Linear(input_dim, 64),
#             nn.ReLU(),
#             nn.Linear(64, 32),
#             nn.ReLU(),
#             nn.Linear(32, 1),
#             nn.Sigmoid()  # Sigmoid for binary classification
#         )

#     def forward(self, x):
#         return self.model(x)


# # Initialize the model, loss function, and optimizer
# input_dim = x_train.shape[1]
# model = MLP(input_dim).to(device)
# criterion = nn.BCELoss()
# optimizer = optim.Adam(model.parameters(), lr=0.001)

# # Define the path to the saved model file
# model_file = './models/mlp_model.pth'

# # Check if the model file exists
# if os.path.exists(model_file):
#     print("Model file exists. Loading the model...")
#     model.load_state_dict(torch.load(model_file))
# else:
#     print("Model file does not exist. Training a new model...")

#     # Train the model
#     num_epochs = 50
#     best_loss = float('inf')
#     patience = 3
#     patience_counter = 0

#     for epoch in range(num_epochs):
#         model.train()
#         running_loss = 0.0
#         for X_batch, y_batch in train_loader:
#             X_batch, y_batch = X_batch.to(device), y_batch.to(device)

#             optimizer.zero_grad()
#             outputs = model(X_batch)
#             loss = criterion(outputs, y_batch)
#             loss.backward()
#             optimizer.step()

#             running_loss += loss.item() * X_batch.size(0)

#         epoch_loss = running_loss / len(train_loader.dataset)
#         print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {epoch_loss:.4f}')

#         # Early stopping
#         model.eval()
#         val_loss = 0.0
#         with torch.no_grad():
#             for X_batch, y_batch in test_loader:
#                 X_batch, y_batch = X_batch.to(device), y_batch.to(device)
#                 outputs = model(X_batch)
#                 loss = criterion(outputs, y_batch)
#                 val_loss += loss.item() * X_batch.size(0)

#         val_loss /= len(test_loader.dataset)
#         print(f'Validation Loss: {val_loss:.4f}')

#         if val_loss < best_loss:
#             best_loss = val_loss
#             patience_counter = 0
#         else:
#             patience_counter += 1
#             if patience_counter >= patience:
#                 print("Early stopping triggered.")
#                 break

#     # Save the trained model after training is complete
#     torch.save(model.state_dict(), model_file)
#     print("Model trained and saved.")

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset

class MLP(nn.Module):
    def __init__(self, input_dim, hidden_size, dropout):
        super(MLP, self).__init__()
        self.model = nn.Sequential(
            nn.Linear(input_dim, hidden_size),
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Linear(hidden_size, 32),
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Linear(32, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.model(x)

def train_mlp(train_dataset, val_dataset, batch_size, hidden_size, learning_rate, dropout, num_epochs, patience, model_file='./models/mlp_model.pth'):
    print(f"Using device: {device}")

    # Create DataLoader
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

    # Initialize the model, loss function, and optimizer
    input_dim = train_dataset.tensors[0].shape[1]
    model = MLP(input_dim, hidden_size, dropout).to(device)
    criterion = nn.BCELoss()
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)

    # Check if the model file exists
    if os.path.exists(model_file):
        print("Model file exists. Loading the model...")
        model.load_state_dict(torch.load(model_file))
    else:
        print("Model file does not exist. Training a new model...")
        best_loss = float('inf')
        patience_counter = 0

        for epoch in range(num_epochs):
            model.train()
            running_loss = 0.0
            for X_batch, y_batch in train_loader:
                X_batch, y_batch = X_batch.to(device), y_batch.to(device)

                optimizer.zero_grad()
                outputs = model(X_batch)
                loss = criterion(outputs, y_batch)
                loss.backward()
                optimizer.step()

                running_loss += loss.item() * X_batch.size(0)

            epoch_loss = running_loss / len(train_loader.dataset)
            print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {epoch_loss:.4f}')

            # Early stopping
            model.eval()
            val_loss = 0.0
            with torch.no_grad():
                for X_batch, y_batch in val_loader:
                    X_batch, y_batch = X_batch.to(device), y_batch.to(device)
                    outputs = model(X_batch)
                    loss = criterion(outputs, y_batch)
                    val_loss += loss.item() * X_batch.size(0)

            val_loss /= len(val_loader.dataset)
            print(f'Validation Loss: {val_loss:.4f}')

            if val_loss < best_loss:
                best_loss = val_loss
                patience_counter = 0
            else:
                patience_counter += 1
                if patience_counter >= patience:
                    print("Early stopping triggered.")
                    break

        # Save the trained model after training is complete
        # torch.save(model.state_dict(), model_file)
        print("Model trained and saved.")

    return model

# %%
X_train_tensor = torch.tensor(x_train.values, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train.values, dtype=torch.float32).unsqueeze(1)
X_val_tensor = torch.tensor(x_val.values, dtype=torch.float32)
y_val_tensor = torch.tensor(y_val.values, dtype=torch.float32).unsqueeze(1)
X_test_tensor = torch.tensor(x_test.values, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test.values, dtype=torch.float32).unsqueeze(1)

train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
val_dataset = TensorDataset(X_val_tensor, y_val_tensor)
test_dataset = TensorDataset(X_test_tensor, y_test_tensor)

# %%
# Hyperparameters
batch_size = 32
hidden_size = 64
learning_rate = 0.001
dropout = 0.2
num_epochs = 250
patience = 10

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = train_mlp(train_dataset, val_dataset, batch_size, hidden_size, learning_rate, dropout, num_epochs, patience)
# Out:
# Using device: cpu
# Model file does not exist. Training a new model...
# Epoch [1/250], Loss: 0.1365
# Validation Loss: 0.1070
# Epoch [2/250], Loss: 0.1081
# Validation Loss: 0.0907
# Epoch [3/250], Loss: 0.0975
# Validation Loss: 0.0850
# Epoch [4/250], Loss: 0.0932
# Validation Loss: 0.0828
# Epoch [5/250], Loss: 0.0909
# Validation Loss: 0.0813
# Epoch [6/250], Loss: 0.0890
# Validation Loss: 0.0805
# Epoch [7/250], Loss: 0.0872
# Validation Loss: 0.0825
# Epoch [8/250], Loss: 0.0866
# Validation Loss: 0.0794
# Epoch [9/250], Loss: 0.0867
# Validation Loss: 0.0789
# Epoch [10/250], Loss: 0.0856
# Validation Loss: 0.0798
# Epoch [11/250], Loss: 0.0855
# Validation Loss: 0.0790
# Epoch [12/250], Loss: 0.0851
# Validation Loss: 0.0788
# Epoch [13/250], Loss: 0.0850
# Validation Loss: 0.0798
# Epoch [14/250], Loss: 0.0845
# Validation Loss: 0.0786
# Epoch [15/250], Loss: 0.0845
# Validation Loss: 0.0783
# Epoch [16/250], Loss: 0.0840
# Validation Loss: 0.0787
# Epoch [17/250], Loss: 0.0839
# Validation Loss: 0.0796
# Epoch [18/250], Loss: 0.0843
# Validation Loss: 0.0791
# Epoch [19/250], Loss: 0.0838
# Validation Loss: 0.0782
# Epoch [20/250], Loss: 0.0837
# Validation Loss: 0.0787
# Epoch [21/250], Loss: 0.0836
# Validation Loss: 0.0786
# Epoch [22/250], Loss: 0.0835
# Validation Loss: 0.0799
# Epoch [23/250], Loss: 0.0832
# Validation Loss: 0.0785
# Epoch [24/250], Loss: 0.0834
# Validation Loss: 0.0784
# Epoch [25/250], Loss: 0.0834
# Validation Loss: 0.0779
# Epoch [26/250], Loss: 0.0834
# Validation Loss: 0.0783
# Epoch [27/250], Loss: 0.0829
# Validation Loss: 0.0784
# Epoch [28/250], Loss: 0.0831
# Validation Loss: 0.0786
# Epoch [29/250], Loss: 0.0831
# Validation Loss: 0.0780
# Epoch [30/250], Loss: 0.0827
# Validation Loss: 0.0785
# Epoch [31/250], Loss: 0.0826
# Validation Loss: 0.0785
# Epoch [32/250], Loss: 0.0825
# Validation Loss: 0.0785
# Epoch [33/250], Loss: 0.0829
# Validation Loss: 0.0786
# Epoch [34/250], Loss: 0.0826
# Validation Loss: 0.0785
# Epoch [35/250], Loss: 0.0827
# Validation Loss: 0.0787
# Early stopping triggered.
# Model trained and saved.

# %%
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# Evaluate the model
model.eval()
test_loss = 0.0
with torch.no_grad():
    for X_batch, y_batch in test_loader:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)
        outputs = model(X_batch)

# Calculate Mean Absolute Error (MAE)
test_mae = 0.0
with torch.no_grad():
    for X_batch, y_batch in test_loader:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)
        outputs = model(X_batch)
        mae = torch.mean(torch.abs(outputs - y_batch))
        test_mae += mae.item() * X_batch.size(0)

test_mae /= len(test_loader.dataset)
print(f'Test MAE: {test_mae:.4f}')

# Calculate Prediction Accuracy
correct_predictions = 0
total_predictions = 0
with torch.no_grad():
    for X_batch, y_batch in test_loader:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)
        outputs = model(X_batch)  # Outputs are probabilities due to sigmoid
        predictions = (outputs > 0.5).float()  # Convert probabilities to binary predictions
        correct_predictions += torch.sum(predictions == y_batch).item()
        total_predictions += y_batch.size(0)

accuracy = correct_predictions / total_predictions
print("Total Predictions:", total_predictions)
print("Correct Predictions:", correct_predictions)
print("Incorrect Predictions:", total_predictions - correct_predictions)
print(f'Prediction Accuracy: {accuracy:.4f}')
# Out:
# Test MAE: 0.0443
# Total Predictions: 15000
# Correct Predictions: 14574
# Incorrect Predictions: 426
# Prediction Accuracy: 0.9716

# %%
import itertools

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Hyperparameter tuning
hidden_sizes = [32, 64, 128]
learning_rates = [0.01, 0.005, 0.001]
dropouts = [0.0, 0.1, 0.2, 0.3]
batch_sizes = [16, 32, 64]
num_epochs = 50
patience = 10

num_trials = 5

results = []

total_combinations = len(hidden_sizes) * len(learning_rates) * len(dropouts) * len(batch_sizes)
count = 0

for lr, batch_size, hidden_size, dropout in itertools.product(learning_rates, batch_sizes, hidden_sizes, dropouts):
    print(f"Learning Rate: {lr}, Batch Size: {batch_size}, Hidden Size: {hidden_size}, Dropout: {dropout}")
    print(f"Completed {count}/{total_combinations} combinations")
    count += 1

    maes, accuracies = [], []
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
    for i in range(num_trials):
        model = train_mlp(train_dataset, val_dataset, batch_size, hidden_size, lr, dropout, num_epochs, patience)

        model.eval()
        test_loss = 0.0
        with torch.no_grad():
            for X_batch, y_batch in test_loader:
                X_batch, y_batch = X_batch.to(device), y_batch.to(device)
                outputs = model(X_batch)

        # Calculate Mean Absolute Error (MAE)
        test_mae = 0.0
        with torch.no_grad():
            for X_batch, y_batch in test_loader:
                X_batch, y_batch = X_batch.to(device), y_batch.to(device)
                outputs = model(X_batch)
                mae = torch.mean(torch.abs(outputs - y_batch))
                test_mae += mae.item() * X_batch.size(0)

        test_mae /= len(test_loader.dataset)
        print(f'Test MAE: {test_mae:.4f}')

        # Calculate Prediction Accuracy
        correct_predictions = 0
        total_predictions = 0
        with torch.no_grad():
            for X_batch, y_batch in test_loader:
                X_batch, y_batch = X_batch.to(device), y_batch.to(device)
                outputs = model(X_batch)  # Outputs are probabilities due to sigmoid
                predictions = (outputs > 0.5).float()  # Convert probabilities to binary predictions
                correct_predictions += torch.sum(predictions == y_batch).item()
                total_predictions += y_batch.size(0)

        accuracy = correct_predictions / total_predictions
        print(f'Prediction Accuracy: {accuracy:.4f}%')

        maes.append(test_mae)
        accuracies.append(accuracy)

    mae_mean = np.mean(maes)
    accuracy_mean = np.mean(accuracies)
    results.append([lr, batch_size, hidden_size, dropout, mae_mean, accuracy_mean])

results_df = pd.DataFrame(results, columns=['Learning Rate', 'Batch Size', 'Hidden Size', 'Dropout', 'MAE', 'Accuracy'])
results_df.to_csv('results.csv', index=False)
# Out:
# Streaming output truncated to the last 5000 lines.
# Validation Loss: 0.0785
# Epoch [25/50], Loss: 0.0816
# Validation Loss: 0.0791
# Epoch [26/50], Loss: 0.0815
# Validation Loss: 0.0790
# Early stopping triggered.
# Model trained and saved.
# Test MAE: 0.0458
# Prediction Accuracy: 0.9719%
# Using device: cpu
# Model file does not exist. Training a new model...
# Epoch [1/50], Loss: 0.1241
# Validation Loss: 0.0939
# Epoch [2/50], Loss: 0.0950
# Validation Loss: 0.0839
# Epoch [3/50], Loss: 0.0893
# Validation Loss: 0.0830
# Epoch [4/50], Loss: 0.0869
# Validation Loss: 0.0801
# Epoch [5/50], Loss: 0.0856
# Validation Loss: 0.0801
# Epoch [6/50], Loss: 0.0852
# Validation Loss: 0.0795
# Epoch [7/50], Loss: 0.0845
# Validation Loss: 0.0815
# Epoch [8/50], Loss: 0.0842
# Validation Loss: 0.0794
# Epoch [9/50], Loss: 0.0839
# Validation Loss: 0.0794
# Epoch [10/50], Loss: 0.0832
# Validation Loss: 0.0789
# Epoch [11/50], Loss: 0.0828
# Validation Loss: 0.0792
# Epoch [12/50], Loss: 0.0831
# Validation Loss: 0.0794
# Epoch [13/50], Loss: 0.0827
# Validation Loss: 0.0794
# Epoch [14/50], Loss: 0.0827
# Validation Loss: 0.0789
# Epoch [15/50], Loss: 0.0825
# Validation Loss: 0.0791
# Epoch [16/50], Loss: 0.0822
# Validation Loss: 0.0786
# Epoch [17/50], Loss: 0.0824
# Validation Loss: 0.0782
# Epoch [18/50], Loss: 0.0826
# Validation Loss: 0.0798
# Epoch [19/50], Loss: 0.0824
# Validation Loss: 0.0790
# Epoch [20/50], Loss: 0.0822
# Validation Loss: 0.0797
# Epoch [21/50], Loss: 0.0819
# Validation Loss: 0.0791
# Epoch [22/50], Loss: 0.0819
# Validation Loss: 0.0793
# Epoch [23/50], Loss: 0.0816
# Validation Loss: 0.0799
# Epoch [24/50], Loss: 0.0820
# Validation Loss: 0.0791
# Epoch [25/50], Loss: 0.0815
# Validation Loss: 0.0787
# Epoch [26/50], Loss: 0.0816
# Validation Loss: 0.0796
# Epoch [27/50], Loss: 0.0815
# Validation Loss: 0.0787
# Early stopping triggered.
# Model trained and saved.
# Test MAE: 0.0450
# Prediction Accuracy: 0.9716%
# Using device: cpu
# Model file does not exist. Training a new model...
# Epoch [1/50], Loss: 0.1223
# Validation Loss: 0.0979
# Epoch [2/50], Loss: 0.0963
# Validation Loss: 0.0878
# Epoch [3/50], Loss: 0.0894
# Validation Loss: 0.0817
# Epoch [4/50], Loss: 0.0871
# Validation Loss: 0.0804
# Epoch [5/50], Loss: 0.0857
# Validation Loss: 0.0792
# Epoch [6/50], Loss: 0.0848
# Validation Loss: 0.0829
# Epoch [7/50], Loss: 0.0844
# Validation Loss: 0.0788
# Epoch [8/50], Loss: 0.0842
# Validation Loss: 0.0792
# Epoch [9/50], Loss: 0.0834
# Validation Loss: 0.0801
# Epoch [10/50], Loss: 0.0831
# Validation Loss: 0.0795
# Epoch [11/50], Loss: 0.0833
# Validation Loss: 0.0795
# Epoch [12/50], Loss: 0.0832
# Validation Loss: 0.0793
# Epoch [13/50], Loss: 0.0831
# Validation Loss: 0.0787
# Epoch [14/50], Loss: 0.0827
# Validation Loss: 0.0795
# Epoch [15/50], Loss: 0.0827
# Validation Loss: 0.0789
# Epoch [16/50], Loss: 0.0824
# Validation Loss: 0.0791
# Epoch [17/50], Loss: 0.0822
# Validation Loss: 0.0789
# Epoch [18/50], Loss: 0.0822
# Validation Loss: 0.0790
# Epoch [19/50], Loss: 0.0824
# Validation Loss: 0.0791
# Epoch [20/50], Loss: 0.0817
# Validation Loss: 0.0792
# Epoch [21/50], Loss: 0.0819
# Validation Loss: 0.0790
# Epoch [22/50], Loss: 0.0814
# Validation Loss: 0.0784
# Epoch [23/50], Loss: 0.0816
# Validation Loss: 0.0790
# Epoch [24/50], Loss: 0.0815
# Validation Loss: 0.0784
# Epoch [25/50], Loss: 0.0817
# Validation Loss: 0.0791
# Epoch [26/50], Loss: 0.0815
# Validation Loss: 0.0819
# Epoch [27/50], Loss: 0.0813
# Validation Loss: 0.0796
# Epoch [28/50], Loss: 0.0815
# Validation Loss: 0.0785
# Epoch [29/50], Loss: 0.0814
# Validation Loss: 0.0785
# Epoch [30/50], Loss: 0.0811
# Validation Loss: 0.0781
# Epoch [31/50], Loss: 0.0806
# Validation Loss: 0.0791
# Epoch [32/50], Loss: 0.0812
# Validation Loss: 0.0789
# Epoch [33/50], Loss: 0.0811
# Validation Loss: 0.0791
# Epoch [34/50], Loss: 0.0809
# Validation Loss: 0.0791
# Epoch [35/50], Loss: 0.0808
# Validation Loss: 0.0788
# Epoch [36/50], Loss: 0.0808
# Validation Loss: 0.0787
# Epoch [37/50], Loss: 0.0807
# Validation Loss: 0.0784
# Epoch [38/50], Loss: 0.0806
# Validation Loss: 0.0785
# Epoch [39/50], Loss: 0.0803
# Validation Loss: 0.0790
# Epoch [40/50], Loss: 0.0802
# Validation Loss: 0.0789
# Early stopping triggered.
# Model trained and saved.
# Test MAE: 0.0456
# Prediction Accuracy: 0.9711%
# Using device: cpu
# Model file does not exist. Training a new model...
# Epoch [1/50], Loss: 0.1245
# Validation Loss: 0.0971
# Epoch [2/50], Loss: 0.0970
# Validation Loss: 0.0859
# Epoch [3/50], Loss: 0.0902
# Validation Loss: 0.0859
# Epoch [4/50], Loss: 0.0875
# Validation Loss: 0.0821
# Epoch [5/50], Loss: 0.0864
# Validation Loss: 0.0800
# Epoch [6/50], Loss: 0.0855
# Validation Loss: 0.0803
# Epoch [7/50], Loss: 0.0849
# Validation Loss: 0.0812
# Epoch [8/50], Loss: 0.0841
# Validation Loss: 0.0795
# Epoch [9/50], Loss: 0.0843
# Validation Loss: 0.0797
# Epoch [10/50], Loss: 0.0837
# Validation Loss: 0.0784
# Epoch [11/50], Loss: 0.0836
# Validation Loss: 0.0819
# Epoch [12/50], Loss: 0.0832
# Validation Loss: 0.0807
# Epoch [13/50], Loss: 0.0832
# Validation Loss: 0.0789
# Epoch [14/50], Loss: 0.0829
# Validation Loss: 0.0795
# Epoch [15/50], Loss: 0.0830
# Validation Loss: 0.0804
# Epoch [16/50], Loss: 0.0826
# Validation Loss: 0.0795
# Epoch [17/50], Loss: 0.0824
# Validation Loss: 0.0788
# Epoch [18/50], Loss: 0.0823
# Validation Loss: 0.0794
# Epoch [19/50], Loss: 0.0822
# Validation Loss: 0.0789
# Epoch [20/50], Loss: 0.0816
# Validation Loss: 0.0793
# Early stopping triggered.
# Model trained and saved.
# Test MAE: 0.0424
# Prediction Accuracy: 0.9715%
# Learning Rate: 0.001, Batch Size: 32, Hidden Size: 128, Dropout: 0.2
# Completed 94/108 combinations
# Using device: cpu
# Model file does not exist. Training a new model...
# Epoch [1/50], Loss: 0.1291
# Validation Loss: 0.0945
# Epoch [2/50], Loss: 0.0968
# Validation Loss: 0.0862
# Epoch [3/50], Loss: 0.0908
# Validation Loss: 0.0825
# Epoch [4/50], Loss: 0.0880
# Validation Loss: 0.0799
# Epoch [5/50], Loss: 0.0871
# Validation Loss: 0.0802
# Epoch [6/50], Loss: 0.0856
# Validation Loss: 0.0792
# Epoch [7/50], Loss: 0.0855
# Validation Loss: 0.0802
# Epoch [8/50], Loss: 0.0850
# Validation Loss: 0.0793
# Epoch [9/50], Loss: 0.0849
# Validation Loss: 0.0784
# Epoch [10/50], Loss: 0.0842
# Validation Loss: 0.0795
# Epoch [11/50], Loss: 0.0846
# Validation Loss: 0.0794
# Epoch [12/50], Loss: 0.0839
# Validation Loss: 0.0791
# Epoch [13/50], Loss: 0.0836
# Validation Loss: 0.0787
# Epoch [14/50], Loss: 0.0838
# Validation Loss: 0.0789
# Epoch [15/50], Loss: 0.0837
# Validation Loss: 0.0787
# Epoch [16/50], Loss: 0.0833
# Validation Loss: 0.0792
# Epoch [17/50], Loss: 0.0834
# Validation Loss: 0.0785
# Epoch [18/50], Loss: 0.0833
# Validation Loss: 0.0789
# Epoch [19/50], Loss: 0.0830
# Validation Loss: 0.0778
# Epoch [20/50], Loss: 0.0831
# Validation Loss: 0.0785
# Epoch [21/50], Loss: 0.0831
# Validation Loss: 0.0791
# Epoch [22/50], Loss: 0.0825
# Validation Loss: 0.0809
# Epoch [23/50], Loss: 0.0829
# Validation Loss: 0.0784
# Epoch [24/50], Loss: 0.0825
# Validation Loss: 0.0783
# Epoch [25/50], Loss: 0.0827
# Validation Loss: 0.0791
# Epoch [26/50], Loss: 0.0825
# Validation Loss: 0.0791
# Epoch [27/50], Loss: 0.0824
# Validation Loss: 0.0791
# Epoch [28/50], Loss: 0.0823
# Validation Loss: 0.0793
# Epoch [29/50], Loss: 0.0829
# Validation Loss: 0.0785
# Early stopping triggered.
# Model trained and saved.
# Test MAE: 0.0459
# Prediction Accuracy: 0.9717%
# Using device: cpu
# Model file does not exist. Training a new model...
# Epoch [1/50], Loss: 0.1291
# Validation Loss: 0.0953
# Epoch [2/50], Loss: 0.0985
# Validation Loss: 0.0864
# Epoch [3/50], Loss: 0.0915
# Validation Loss: 0.0831
# Epoch [4/50], Loss: 0.0887
# Validation Loss: 0.0806
# Epoch [5/50], Loss: 0.0876
# Validation Loss: 0.0816
# Epoch [6/50], Loss: 0.0864
# Validation Loss: 0.0804
# Epoch [7/50], Loss: 0.0859
# Validation Loss: 0.0796
# Epoch [8/50], Loss: 0.0852
# Validation Loss: 0.0793
# Epoch [9/50], Loss: 0.0844
# Validation Loss: 0.0790
# Epoch [10/50], Loss: 0.0840
# Validation Loss: 0.0790
# Epoch [11/50], Loss: 0.0843
# Validation Loss: 0.0832
# Epoch [12/50], Loss: 0.0840
# Validation Loss: 0.0791
# Epoch [13/50], Loss: 0.0840
# Validation Loss: 0.0792
# Epoch [14/50], Loss: 0.0836
# Validation Loss: 0.0792
# Epoch [15/50], Loss: 0.0833
# Validation Loss: 0.0793
# Epoch [16/50], Loss: 0.0834
# Validation Loss: 0.0794
# Epoch [17/50], Loss: 0.0834
# Validation Loss: 0.0790
# Epoch [18/50], Loss: 0.0834
# Validation Loss: 0.0795
# Epoch [19/50], Loss: 0.0827
# Validation Loss: 0.0789
# Epoch [20/50], Loss: 0.0828
# Validation Loss: 0.0782
# Epoch [21/50], Loss: 0.0827
# Validation Loss: 0.0786
# Epoch [22/50], Loss: 0.0829
# Validation Loss: 0.0783
# Epoch [23/50], Loss: 0.0825
# Validation Loss: 0.0784
# Epoch [24/50], Loss: 0.0823
# Validation Loss: 0.0784
# Epoch [25/50], Loss: 0.0829
# Validation Loss: 0.0781
# Epoch [26/50], Loss: 0.0825
# Validation Loss: 0.0788
# Epoch [27/50], Loss: 0.0826
# Validation Loss: 0.0786
# Epoch [28/50], Loss: 0.0823
# Validation Loss: 0.0784
# Epoch [29/50], Loss: 0.0825
# Validation Loss: 0.0784
# Epoch [30/50], Loss: 0.0827
# Validation Loss: 0.0786
# Epoch [31/50], Loss: 0.0820
# Validation Loss: 0.0786
# Epoch [32/50], Loss: 0.0824
# Validation Loss: 0.0788
# Epoch [33/50], Loss: 0.0820
# Validation Loss: 0.0784
# Epoch [34/50], Loss: 0.0822
# Validation Loss: 0.0785
# Epoch [35/50], Loss: 0.0818
# Validation Loss: 0.0785
# Early stopping triggered.
# Model trained and saved.
# Test MAE: 0.0460
# Prediction Accuracy: 0.9719%
# Using device: cpu
# Model file does not exist. Training a new model...
# Epoch [1/50], Loss: 0.1281
# Validation Loss: 0.0977
# Epoch [2/50], Loss: 0.0978
# Validation Loss: 0.0878
# Epoch [3/50], Loss: 0.0923
# Validation Loss: 0.0818
# Epoch [4/50], Loss: 0.0891
# Validation Loss: 0.0800
# Epoch [5/50], Loss: 0.0873
# Validation Loss: 0.0818
# Epoch [6/50], Loss: 0.0862
# Validation Loss: 0.0795
# Epoch [7/50], Loss: 0.0861
# Validation Loss: 0.0795
# Epoch [8/50], Loss: 0.0852
# Validation Loss: 0.0792
# Epoch [9/50], Loss: 0.0846
# Validation Loss: 0.0795
# Epoch [10/50], Loss: 0.0843
# Validation Loss: 0.0788
# Epoch [11/50], Loss: 0.0842
# Validation Loss: 0.0797
# Epoch [12/50], Loss: 0.0842
# Validation Loss: 0.0782
# Epoch [13/50], Loss: 0.0837
# Validation Loss: 0.0782
# Epoch [14/50], Loss: 0.0837
# Validation Loss: 0.0797
# Epoch [15/50], Loss: 0.0832
# Validation Loss: 0.0784
# Epoch [16/50], Loss: 0.0836
# Validation Loss: 0.0799
# Epoch [17/50], Loss: 0.0829
# Validation Loss: 0.0783
# Epoch [18/50], Loss: 0.0833
# Validation Loss: 0.0787
# Epoch [19/50], Loss: 0.0830
# Validation Loss: 0.0794
# Epoch [20/50], Loss: 0.0831
# Validation Loss: 0.0787
# Epoch [21/50], Loss: 0.0826
# Validation Loss: 0.0787
# Epoch [22/50], Loss: 0.0832
# Validation Loss: 0.0790
# Early stopping triggered.
# Model trained and saved.
# Test MAE: 0.0479
# Prediction Accuracy: 0.9716%
# Using device: cpu
# Model file does not exist. Training a new model...
# Epoch [1/50], Loss: 0.1296
# Validation Loss: 0.0984
# Epoch [2/50], Loss: 0.0989
# Validation Loss: 0.0858
# Epoch [3/50], Loss: 0.0924
# Validation Loss: 0.0825
# Epoch [4/50], Loss: 0.0894
# Validation Loss: 0.0807
# Epoch [5/50], Loss: 0.0873
# Validation Loss: 0.0797
# Epoch [6/50], Loss: 0.0867
# Validation Loss: 0.0795
# Epoch [7/50], Loss: 0.0854
# Validation Loss: 0.0805
# Epoch [8/50], Loss: 0.0859
# Validation Loss: 0.0796
# Epoch [9/50], Loss: 0.0847
# Validation Loss: 0.0797
# Epoch [10/50], Loss: 0.0844
# Validation Loss: 0.0787
# Epoch [11/50], Loss: 0.0843
# Validation Loss: 0.0788
# Epoch [12/50], Loss: 0.0843
# Validation Loss: 0.0800
# Epoch [13/50], Loss: 0.0838
# Validation Loss: 0.0805
# Epoch [14/50], Loss: 0.0833
# Validation Loss: 0.0790
# Epoch [15/50], Loss: 0.0837
# Validation Loss: 0.0783
# Epoch [16/50], Loss: 0.0834
# Validation Loss: 0.0787
# Epoch [17/50], Loss: 0.0831
# Validation Loss: 0.0786
# Epoch [18/50], Loss: 0.0832
# Validation Loss: 0.0790
# Epoch [19/50], Loss: 0.0828
# Validation Loss: 0.0797
# Epoch [20/50], Loss: 0.0830
# Validation Loss: 0.0785
# Epoch [21/50], Loss: 0.0830
# Validation Loss: 0.0784
# Epoch [22/50], Loss: 0.0826
# Validation Loss: 0.0788
# Epoch [23/50], Loss: 0.0832
# Validation Loss: 0.0792
# Epoch [24/50], Loss: 0.0827
# Validation Loss: 0.0786
# Epoch [25/50], Loss: 0.0824
# Validation Loss: 0.0791
# Early stopping triggered.
# Model trained and saved.
# Test MAE: 0.0453
# Prediction Accuracy: 0.9717%
# Using device: cpu
# Model file does not exist. Training a new model...
# Epoch [1/50], Loss: 0.1277
# Validation Loss: 0.0943
# Epoch [2/50], Loss: 0.0967
# Validation Loss: 0.0855
# Epoch [3/50], Loss: 0.0914
# Validation Loss: 0.0815
# Epoch [4/50], Loss: 0.0893
# Validation Loss: 0.0808
# Epoch [5/50], Loss: 0.0877
# Validation Loss: 0.0810
# Epoch [6/50], Loss: 0.0863
# Validation Loss: 0.0803
# Epoch [7/50], Loss: 0.0855
# Validation Loss: 0.0794
# Epoch [8/50], Loss: 0.0853
# Validation Loss: 0.0788
# Epoch [9/50], Loss: 0.0848
# Validation Loss: 0.0790
# Epoch [10/50], Loss: 0.0845
# Validation Loss: 0.0786
# Epoch [11/50], Loss: 0.0840
# Validation Loss: 0.0797
# Epoch [12/50], Loss: 0.0840
# Validation Loss: 0.0786
# Epoch [13/50], Loss: 0.0834
# Validation Loss: 0.0783
# Epoch [14/50], Loss: 0.0835
# Validation Loss: 0.0795
# Epoch [15/50], Loss: 0.0831
# Validation Loss: 0.0793
# Epoch [16/50], Loss: 0.0834
# Validation Loss: 0.0789
# Epoch [17/50], Loss: 0.0833
# Validation Loss: 0.0785
# Epoch [18/50], Loss: 0.0849
# Validation Loss: 0.0784
# Epoch [19/50], Loss: 0.0831
# Validation Loss: 0.0788
# Epoch [20/50], Loss: 0.0831
# Validation Loss: 0.0792
# Epoch [21/50], Loss: 0.0828
# Validation Loss: 0.0786
# Epoch [22/50], Loss: 0.0831
# Validation Loss: 0.0783
# Epoch [23/50], Loss: 0.0830
# Validation Loss: 0.0787
# Epoch [24/50], Loss: 0.0828
# Validation Loss: 0.0789
# Epoch [25/50], Loss: 0.0828
# Validation Loss: 0.0792
# Epoch [26/50], Loss: 0.0825
# Validation Loss: 0.0789
# Epoch [27/50], Loss: 0.0826
# Validation Loss: 0.0779
# Epoch [28/50], Loss: 0.0824
# Validation Loss: 0.0791
# Epoch [29/50], Loss: 0.0829
# Validation Loss: 0.0783
# Epoch [30/50], Loss: 0.0825
# Validation Loss: 0.0783
# Epoch [31/50], Loss: 0.0822
# Validation Loss: 0.0784
# Epoch [32/50], Loss: 0.0826
# Validation Loss: 0.0785
# Epoch [33/50], Loss: 0.0817
# Validation Loss: 0.0790
# Epoch [34/50], Loss: 0.0823
# Validation Loss: 0.0787
# Epoch [35/50], Loss: 0.0822
# Validation Loss: 0.0788
# Epoch [36/50], Loss: 0.0818
# Validation Loss: 0.0793
# Epoch [37/50], Loss: 0.0823
# Validation Loss: 0.0790
# Early stopping triggered.
# Model trained and saved.
# Test MAE: 0.0431
# Prediction Accuracy: 0.9715%
# Learning Rate: 0.001, Batch Size: 32, Hidden Size: 128, Dropout: 0.3
# Completed 95/108 combinations
# Using device: cpu
# Model file does not exist. Training a new model...
# Epoch [1/50], Loss: 0.1312
# Validation Loss: 0.0991
# Epoch [2/50], Loss: 0.1036
# Validation Loss: 0.0881
# Epoch [3/50], Loss: 0.0947
# Validation Loss: 0.0832
# Epoch [4/50], Loss: 0.0913
# Validation Loss: 0.0827
# Epoch [5/50], Loss: 0.0885
# Validation Loss: 0.0808
# Epoch [6/50], Loss: 0.0874
# Validation Loss: 0.0799
# Epoch [7/50], Loss: 0.0862
# Validation Loss: 0.0798
# Epoch [8/50], Loss: 0.0858
# Validation Loss: 0.0791
# Epoch [9/50], Loss: 0.0853
# Validation Loss: 0.0788
# Epoch [10/50], Loss: 0.0856
# Validation Loss: 0.0803
# Epoch [11/50], Loss: 0.0848
# Validation Loss: 0.0790
# Epoch [12/50], Loss: 0.0850
# Validation Loss: 0.0796
# Epoch [13/50], Loss: 0.0848
# Validation Loss: 0.0789
# Epoch [14/50], Loss: 0.0848
# Validation Loss: 0.0790
# Epoch [15/50], Loss: 0.0848
# Validation Loss: 0.0787
# Epoch [16/50], Loss: 0.0840
# Validation Loss: 0.0785
# Epoch [17/50], Loss: 0.0843
# Validation Loss: 0.0784
# Epoch [18/50], Loss: 0.0844
# Validation Loss: 0.0789
# Epoch [19/50], Loss: 0.0843
# Validation Loss: 0.0787
# Epoch [20/50], Loss: 0.0839
# Validation Loss: 0.0785
# Epoch [21/50], Loss: 0.0840
# Validation Loss: 0.0785
# Epoch [22/50], Loss: 0.0839
# Validation Loss: 0.0790
# Epoch [23/50], Loss: 0.0835
# Validation Loss: 0.0791
# Epoch [24/50], Loss: 0.0836
# Validation Loss: 0.0782
# Epoch [25/50], Loss: 0.0837
# Validation Loss: 0.0782
# Epoch [26/50], Loss: 0.0851
# Validation Loss: 0.0783
# Epoch [27/50], Loss: 0.0838
# Validation Loss: 0.0780
# Epoch [28/50], Loss: 0.0839
# Validation Loss: 0.0791
# Epoch [29/50], Loss: 0.0834
# Validation Loss: 0.0781
# Epoch [30/50], Loss: 0.0833
# Validation Loss: 0.0789
# Epoch [31/50], Loss: 0.0841
# Validation Loss: 0.0784
# Epoch [32/50], Loss: 0.0834
# Validation Loss: 0.0790
# Epoch [33/50], Loss: 0.0833
# Validation Loss: 0.0794
# Epoch [34/50], Loss: 0.0829
# Validation Loss: 0.0789
# Epoch [35/50], Loss: 0.0830
# Validation Loss: 0.0785
# Epoch [36/50], Loss: 0.0835
# Validation Loss: 0.0787
# Epoch [37/50], Loss: 0.0834
# Validation Loss: 0.0793
# Early stopping triggered.
# Model trained and saved.
# Test MAE: 0.0477
# Prediction Accuracy: 0.9715%
# Using device: cpu
# Model file does not exist. Training a new model...
# Epoch [1/50], Loss: 0.1309
# Validation Loss: 0.0961
# Epoch [2/50], Loss: 0.1001
# Validation Loss: 0.0869
# Epoch [3/50], Loss: 0.0932
# Validation Loss: 0.0817
# Epoch [4/50], Loss: 0.0901
# Validation Loss: 0.0825
# Epoch [5/50], Loss: 0.0881
# Validation Loss: 0.0802
# Epoch [6/50], Loss: 0.0871
# Validation Loss: 0.0794
# Epoch [7/50], Loss: 0.0863
# Validation Loss: 0.0789
# Epoch [8/50], Loss: 0.0852
# Validation Loss: 0.0792
# Epoch [9/50], Loss: 0.0852
# Validation Loss: 0.0798
# Epoch [10/50], Loss: 0.0851
# Validation Loss: 0.0793
# Epoch [11/50], Loss: 0.0847
# Validation Loss: 0.0789
# Epoch [12/50], Loss: 0.0845
# Validation Loss: 0.0794
# Epoch [13/50], Loss: 0.0842
# Validation Loss: 0.0795
# Epoch [14/50], Loss: 0.0850
# Validation Loss: 0.0788
# Epoch [15/50], Loss: 0.0846
# Validation Loss: 0.0828
# Epoch [16/50], Loss: 0.0850
# Validation Loss: 0.0792
# Epoch [17/50], Loss: 0.0844
# Validation Loss: 0.0797
# Epoch [18/50], Loss: 0.0836
# Validation Loss: 0.0785
# Epoch [19/50], Loss: 0.0847
# Validation Loss: 0.0787
# Epoch [20/50], Loss: 0.0837
# Validation Loss: 0.0799
# Epoch [21/50], Loss: 0.0838
# Validation Loss: 0.0785
# Epoch [22/50], Loss: 0.0834
# Validation Loss: 0.0787
# Epoch [23/50], Loss: 0.0838
# Validation Loss: 0.0793
# Epoch [24/50], Loss: 0.0835
# Validation Loss: 0.0782
# Epoch [25/50], Loss: 0.0837
# Validation Loss: 0.0786
# Epoch [26/50], Loss: 0.0837
# Validation Loss: 0.0798
# Epoch [27/50], Loss: 0.0836
# Validation Loss: 0.0797
# Epoch [28/50], Loss: 0.0835
# Validation Loss: 0.0785
# Epoch [29/50], Loss: 0.0832
# Validation Loss: 0.0786
# Epoch [30/50], Loss: 0.0831
# Validation Loss: 0.0794
# Epoch [31/50], Loss: 0.0831
# Validation Loss: 0.0792
# Epoch [32/50], Loss: 0.0834
# Validation Loss: 0.0786
# Epoch [33/50], Loss: 0.0826
# Validation Loss: 0.0800
# Epoch [34/50], Loss: 0.0832
# Validation Loss: 0.0791
# Early stopping triggered.
# Model trained and saved.
# Test MAE: 0.0467
# Prediction Accuracy: 0.9715%
# Using device: cpu
# Model file does not exist. Training a new model...
# Epoch [1/50], Loss: 0.1309
# Validation Loss: 0.0941
# Epoch [2/50], Loss: 0.1005
# Validation Loss: 0.0867
# Epoch [3/50], Loss: 0.0929
# Validation Loss: 0.0833
# Epoch [4/50], Loss: 0.0901
# Validation Loss: 0.0801
# Epoch [5/50], Loss: 0.0884
# Validation Loss: 0.0818
# Epoch [6/50], Loss: 0.0871
# Validation Loss: 0.0789
# Epoch [7/50], Loss: 0.0871
# Validation Loss: 0.0797
# Epoch [8/50], Loss: 0.0860
# Validation Loss: 0.0791
# Epoch [9/50], Loss: 0.0862
# Validation Loss: 0.0790
# Epoch [10/50], Loss: 0.0854
# Validation Loss: 0.0791
# Epoch [11/50], Loss: 0.0852
# Validation Loss: 0.0786
# Epoch [12/50], Loss: 0.0850
# Validation Loss: 0.0789
# Epoch [13/50], Loss: 0.0849
# Validation Loss: 0.0797
# Epoch [14/50], Loss: 0.0847
# Validation Loss: 0.0785
# Epoch [15/50], Loss: 0.0849
# Validation Loss: 0.0795
# Epoch [16/50], Loss: 0.0846
# Validation Loss: 0.0791
# Epoch [17/50], Loss: 0.0845
# Validation Loss: 0.0796
# Epoch [18/50], Loss: 0.0852
# Validation Loss: 0.0792
# Epoch [19/50], Loss: 0.0842
# Validation Loss: 0.0798
# Epoch [20/50], Loss: 0.0841
# Validation Loss: 0.0784
# Epoch [21/50], Loss: 0.0838
# Validation Loss: 0.0787
# Epoch [22/50], Loss: 0.0843
# Validation Loss: 0.0788
# Epoch [23/50], Loss: 0.0839
# Validation Loss: 0.0789
# Epoch [24/50], Loss: 0.0842
# Validation Loss: 0.0787
# Epoch [25/50], Loss: 0.0840
# Validation Loss: 0.0786
# Epoch [26/50], Loss: 0.0839
# Validation Loss: 0.0784
# Epoch [27/50], Loss: 0.0840
# Validation Loss: 0.0797
# Epoch [28/50], Loss: 0.0833
# Validation Loss: 0.0792
# Epoch [29/50], Loss: 0.0836
# Validation Loss: 0.0801
# Epoch [30/50], Loss: 0.0832
# Validation Loss: 0.0788
# Early stopping triggered.
# Model trained and saved.
# Test MAE: 0.0470
# Prediction Accuracy: 0.9719%
# Using device: cpu
# Model file does not exist. Training a new model...
# Epoch [1/50], Loss: 0.1291
# Validation Loss: 0.0942
# Epoch [2/50], Loss: 0.0987
# Validation Loss: 0.0849
# Epoch [3/50], Loss: 0.0928
# Validation Loss: 0.0817
# Epoch [4/50], Loss: 0.0896
# Validation Loss: 0.0842
# Epoch [5/50], Loss: 0.0870
# Validation Loss: 0.0802
# Epoch [6/50], Loss: 0.0862
# Validation Loss: 0.0798
# Epoch [7/50], Loss: 0.0862
# Validation Loss: 0.0793
# Epoch [8/50], Loss: 0.0852
# Validation Loss: 0.0789
# Epoch [9/50], Loss: 0.0845
# Validation Loss: 0.0780
# Epoch [10/50], Loss: 0.0845
# Validation Loss: 0.0791
# Epoch [11/50], Loss: 0.0849
# Validation Loss: 0.0787
# Epoch [12/50], Loss: 0.0847
# Validation Loss: 0.0791
# Epoch [13/50], Loss: 0.0843
# Validation Loss: 0.0788
# Epoch [14/50], Loss: 0.0842
# Validation Loss: 0.0789
# Epoch [15/50], Loss: 0.0845
# Validation Loss: 0.0785
# Epoch [16/50], Loss: 0.0838
# Validation Loss: 0.0793
# Epoch [17/50], Loss: 0.0843
# Validation Loss: 0.0791
# Epoch [18/50], Loss: 0.0840
# Validation Loss: 0.0788
# Epoch [19/50], Loss: 0.0837
# Validation Loss: 0.0790
# Early stopping triggered.
# Model trained and saved.
# Test MAE: 0.0474
# Prediction Accuracy: 0.9715%
# Using device: cpu
# Model file does not exist. Training a new model...
# Epoch [1/50], Loss: 0.1278
# Validation Loss: 0.0948
# Epoch [2/50], Loss: 0.0980
# Validation Loss: 0.0849
# Epoch [3/50], Loss: 0.0926
# Validation Loss: 0.0809
# Epoch [4/50], Loss: 0.0893
# Validation Loss: 0.0822
# Epoch [5/50], Loss: 0.0879
# Validation Loss: 0.0808
# Epoch [6/50], Loss: 0.0868
# Validation Loss: 0.0806
# Epoch [7/50], Loss: 0.0870
# Validation Loss: 0.0788
# Epoch [8/50], Loss: 0.0857
# Validation Loss: 0.0796
# Epoch [9/50], Loss: 0.0855
# Validation Loss: 0.0792
# Epoch [10/50], Loss: 0.0850
# Validation Loss: 0.0786
# Epoch [11/50], Loss: 0.0846
# Validation Loss: 0.0797
# Epoch [12/50], Loss: 0.0846
# Validation Loss: 0.0783
# Epoch [13/50], Loss: 0.0845
# Validation Loss: 0.0807
# Epoch [14/50], Loss: 0.0843
# Validation Loss: 0.0782
# Epoch [15/50], Loss: 0.0847
# Validation Loss: 0.0788
# Epoch [16/50], Loss: 0.0840
# Validation Loss: 0.0784
# Epoch [17/50], Loss: 0.0841
# Validation Loss: 0.0783
# Epoch [18/50], Loss: 0.0843
# Validation Loss: 0.0786
# Epoch [19/50], Loss: 0.0843
# Validation Loss: 0.0782
# Epoch [20/50], Loss: 0.0836
# Validation Loss: 0.0788
# Epoch [21/50], Loss: 0.0840
# Validation Loss: 0.0788
# Epoch [22/50], Loss: 0.0834
# Validation Loss: 0.0780
# Epoch [23/50], Loss: 0.0839
# Validation Loss: 0.0786
# Epoch [24/50], Loss: 0.0835
# Validation Loss: 0.0796
# Epoch [25/50], Loss: 0.0834
# Validation Loss: 0.0788
# Epoch [26/50], Loss: 0.0840
# Validation Loss: 0.0784
# Epoch [27/50], Loss: 0.0836
# Validation Loss: 0.0785
# Epoch [28/50], Loss: 0.0829
# Validation Loss: 0.0786
# Epoch [29/50], Loss: 0.0838
# Validation Loss: 0.0786
# Epoch [30/50], Loss: 0.0831
# Validation Loss: 0.0784
# Epoch [31/50], Loss: 0.0832
# Validation Loss: 0.0792
# Epoch [32/50], Loss: 0.0836
# Validation Loss: 0.0802
# Early stopping triggered.
# Model trained and saved.
# Test MAE: 0.0508
# Prediction Accuracy: 0.9711%
# Learning Rate: 0.001, Batch Size: 64, Hidden Size: 32, Dropout: 0.0
# Completed 96/108 combinations
# Using device: cpu
# Model file does not exist. Training a new model...
# Epoch [1/50], Loss: 0.1595
# Validation Loss: 0.1107
# Epoch [2/50], Loss: 0.1126
# Validation Loss: 0.1065
# Epoch [3/50], Loss: 0.1077
# Validation Loss: 0.1037
# Epoch [4/50], Loss: 0.1001
# Validation Loss: 0.0928
# Epoch [5/50], Loss: 0.0945
# Validation Loss: 0.0885
# Epoch [6/50], Loss: 0.0908
# Validation Loss: 0.0856
# Epoch [7/50], Loss: 0.0883
# Validation Loss: 0.0843
# Epoch [8/50], Loss: 0.0866
# Validation Loss: 0.0828
# Epoch [9/50], Loss: 0.0856
# Validation Loss: 0.0812
# Epoch [10/50], Loss: 0.0846
# Validation Loss: 0.0818
# Epoch [11/50], Loss: 0.0844
# Validation Loss: 0.0808
# Epoch [12/50], Loss: 0.0836
# Validation Loss: 0.0807
# Epoch [13/50], Loss: 0.0832
# Validation Loss: 0.0801
# Epoch [14/50], Loss: 0.0832
# Validation Loss: 0.0803
# Epoch [15/50], Loss: 0.0827
# Validation Loss: 0.0795
# Epoch [16/50], Loss: 0.0828
# Validation Loss: 0.0794
# Epoch [17/50], Loss: 0.0825
# Validation Loss: 0.0819
# Epoch [18/50], Loss: 0.0823
# Validation Loss: 0.0791
# Epoch [19/50], Loss: 0.0823
# Validation Loss: 0.0788
# Epoch [20/50], Loss: 0.0823
# Validation Loss: 0.0789
# Epoch [21/50], Loss: 0.0823
# Validation Loss: 0.0789
# Epoch [22/50], Loss: 0.0820
# Validation Loss: 0.0790
# Epoch [23/50], Loss: 0.0818
# Validation Loss: 0.0811
# Epoch [24/50], Loss: 0.0817
# Validation Loss: 0.0793
# Epoch [25/50], Loss: 0.0818
# Validation Loss: 0.0795
# Epoch [26/50], Loss: 0.0816
# Validation Loss: 0.0797
# Epoch [27/50], Loss: 0.0818
# Validation Loss: 0.0788
# Epoch [28/50], Loss: 0.0816
# Validation Loss: 0.0796
# Epoch [29/50], Loss: 0.0816
# Validation Loss: 0.0790
# Epoch [30/50], Loss: 0.0815
# Validation Loss: 0.0797
# Epoch [31/50], Loss: 0.0811
# Validation Loss: 0.0792
# Epoch [32/50], Loss: 0.0817
# Validation Loss: 0.0796
# Epoch [33/50], Loss: 0.0816
# Validation Loss: 0.0787
# Epoch [34/50], Loss: 0.0814
# Validation Loss: 0.0784
# Epoch [35/50], Loss: 0.0814
# Validation Loss: 0.0786
# Epoch [36/50], Loss: 0.0810
# Validation Loss: 0.0808
# Epoch [37/50], Loss: 0.0812
# Validation Loss: 0.0786
# Epoch [38/50], Loss: 0.0812
# Validation Loss: 0.0788
# Epoch [39/50], Loss: 0.0811
# Validation Loss: 0.0787
# Epoch [40/50], Loss: 0.0810
# Validation Loss: 0.0808
# Epoch [41/50], Loss: 0.0809
# Validation Loss: 0.0792
# Epoch [42/50], Loss: 0.0809
# Validation Loss: 0.0790
# Epoch [43/50], Loss: 0.0810
# Validation Loss: 0.0800
# Epoch [44/50], Loss: 0.0810
# Validation Loss: 0.0792
# Early stopping triggered.
# Model trained and saved.
# Test MAE: 0.0463
# Prediction Accuracy: 0.9713%
# Using device: cpu
# Model file does not exist. Training a new model...
# Epoch [1/50], Loss: 0.1547
# Validation Loss: 0.1131
# Epoch [2/50], Loss: 0.1105
# Validation Loss: 0.1036
# Epoch [3/50], Loss: 0.1002
# Validation Loss: 0.0926
# Epoch [4/50], Loss: 0.0918
# Validation Loss: 0.0864
# Epoch [5/50], Loss: 0.0880
# Validation Loss: 0.0829
# Epoch [6/50], Loss: 0.0857
# Validation Loss: 0.0820
# Epoch [7/50], Loss: 0.0846
# Validation Loss: 0.0809
# Epoch [8/50], Loss: 0.0840
# Validation Loss: 0.0812
# Epoch [9/50], Loss: 0.0834
# Validation Loss: 0.0797
# Epoch [10/50], Loss: 0.0829
# Validation Loss: 0.0793
# Epoch [11/50], Loss: 0.0826
# Validation Loss: 0.0793
# Epoch [12/50], Loss: 0.0822
# Validation Loss: 0.0790
# Epoch [13/50], Loss: 0.0820
# Validation Loss: 0.0810
# Epoch [14/50], Loss: 0.0820
# Validation Loss: 0.0803
# Epoch [15/50], Loss: 0.0817
# Validation Loss: 0.0804
# Epoch [16/50], Loss: 0.0817
# Validation Loss: 0.0787
# Epoch [17/50], Loss: 0.0815
# Validation Loss: 0.0789
# Epoch [18/50], Loss: 0.0814
# Validation Loss: 0.0788
# Epoch [19/50], Loss: 0.0813
# Validation Loss: 0.0788
# Epoch [20/50], Loss: 0.0813
# Validation Loss: 0.0789
# Epoch [21/50], Loss: 0.0813
# Validation Loss: 0.0790
# Epoch [22/50], Loss: 0.0812
# Validation Loss: 0.0783
# Epoch [23/50], Loss: 0.0810
# Validation Loss: 0.0785
# Epoch [24/50], Loss: 0.0810
# Validation Loss: 0.0799
# Epoch [25/50], Loss: 0.0810
# Validation Loss: 0.0786
# Epoch [26/50], Loss: 0.0809
# Validation Loss: 0.0786
# Epoch [27/50], Loss: 0.0807
# Validation Loss: 0.0790
# Epoch [28/50], Loss: 0.0809
# Validation Loss: 0.0789
# Epoch [29/50], Loss: 0.0809
# Validation Loss: 0.0795
# Epoch [30/50], Loss: 0.0807
# Validation Loss: 0.0793
# Epoch [31/50], Loss: 0.0809
# Validation Loss: 0.0786
# Epoch [32/50], Loss: 0.0806
# Validation Loss: 0.0786
# Early stopping triggered.
# Model trained and saved.
# Test MAE: 0.0481
# Prediction Accuracy: 0.9716%
# Using device: cpu
# Model file does not exist. Training a new model...
# Epoch [1/50], Loss: 0.1467
# Validation Loss: 0.1085
# Epoch [2/50], Loss: 0.1082
# Validation Loss: 0.1011
# Epoch [3/50], Loss: 0.0979
# Validation Loss: 0.0895
# Epoch [4/50], Loss: 0.0905
# Validation Loss: 0.0859
# Epoch [5/50], Loss: 0.0871
# Validation Loss: 0.0851
# Epoch [6/50], Loss: 0.0858
# Validation Loss: 0.0833
# Epoch [7/50], Loss: 0.0849
# Validation Loss: 0.0818
# Epoch [8/50], Loss: 0.0843
# Validation Loss: 0.0802
# Epoch [9/50], Loss: 0.0837
# Validation Loss: 0.0795
# Epoch [10/50], Loss: 0.0832
# Validation Loss: 0.0800
# Epoch [11/50], Loss: 0.0828
# Validation Loss: 0.0797
# Epoch [12/50], Loss: 0.0826
# Validation Loss: 0.0803
# Epoch [13/50], Loss: 0.0824
# Validation Loss: 0.0794
# Epoch [14/50], Loss: 0.0823
# Validation Loss: 0.0790
# Epoch [15/50], Loss: 0.0822
# Validation Loss: 0.0793
# Epoch [16/50], Loss: 0.0823
# Validation Loss: 0.0790
# Epoch [17/50], Loss: 0.0820
# Validation Loss: 0.0798
# Epoch [18/50], Loss: 0.0819
# Validation Loss: 0.0796
# Epoch [19/50], Loss: 0.0818
# Validation Loss: 0.0797
# Epoch [20/50], Loss: 0.0820
# Validation Loss: 0.0789
# Epoch [21/50], Loss: 0.0816
# Validation Loss: 0.0795
# Epoch [22/50], Loss: 0.0816
# Validation Loss: 0.0789
# Epoch [23/50], Loss: 0.0817
# Validation Loss: 0.0790
# Epoch [24/50], Loss: 0.0816
# Validation Loss: 0.0812
# Epoch [25/50], Loss: 0.0814
# Validation Loss: 0.0784
# Epoch [26/50], Loss: 0.0815
# Validation Loss: 0.0791
# Epoch [27/50], Loss: 0.0814
# Validation Loss: 0.0787
# Epoch [28/50], Loss: 0.0815
# Validation Loss: 0.0786
# Epoch [29/50], Loss: 0.0813
# Validation Loss: 0.0801
# Epoch [30/50], Loss: 0.0812
# Validation Loss: 0.0792
# Epoch [31/50], Loss: 0.0812
# Validation Loss: 0.0787
# Epoch [32/50], Loss: 0.0810
# Validation Loss: 0.0789
# Epoch [33/50], Loss: 0.0813
# Validation Loss: 0.0793
# Epoch [34/50], Loss: 0.0810
# Validation Loss: 0.0811
# Epoch [35/50], Loss: 0.0811
# Validation Loss: 0.0795
# Early stopping triggered.
# Model trained and saved.
# Test MAE: 0.0458
# Prediction Accuracy: 0.9720%
# Using device: cpu
# Model file does not exist. Training a new model...
# Epoch [1/50], Loss: 0.1557
# Validation Loss: 0.1110
# Epoch [2/50], Loss: 0.1112
# Validation Loss: 0.1031
# Epoch [3/50], Loss: 0.1033
# Validation Loss: 0.0946
# Epoch [4/50], Loss: 0.0958
# Validation Loss: 0.0896
# Epoch [5/50], Loss: 0.0907
# Validation Loss: 0.0877
# Epoch [6/50], Loss: 0.0877
# Validation Loss: 0.0859
# Epoch [7/50], Loss: 0.0860
# Validation Loss: 0.0822
# Epoch [8/50], Loss: 0.0852
# Validation Loss: 0.0832
# Epoch [9/50], Loss: 0.0842
# Validation Loss: 0.0807
# Epoch [10/50], Loss: 0.0837
# Validation Loss: 0.0812
# Epoch [11/50], Loss: 0.0834
# Validation Loss: 0.0796
# Epoch [12/50], Loss: 0.0831
# Validation Loss: 0.0795
# Epoch [13/50], Loss: 0.0827
# Validation Loss: 0.0792
# Epoch [14/50], Loss: 0.0826
# Validation Loss: 0.0787
# Epoch [15/50], Loss: 0.0823
# Validation Loss: 0.0797
# Epoch [16/50], Loss: 0.0822
# Validation Loss: 0.0782
# Epoch [17/50], Loss: 0.0822
# Validation Loss: 0.0787
# Epoch [18/50], Loss: 0.0819
# Validation Loss: 0.0789
# Epoch [19/50], Loss: 0.0819
# Validation Loss: 0.0791
# Epoch [20/50], Loss: 0.0818
# Validation Loss: 0.0836
# Epoch [21/50], Loss: 0.0818
# Validation Loss: 0.0792
# Epoch [22/50], Loss: 0.0818
# Validation Loss: 0.0798
# Epoch [23/50], Loss: 0.0817
# Validation Loss: 0.0789
# Epoch [24/50], Loss: 0.0817
# Validation Loss: 0.0786
# Epoch [25/50], Loss: 0.0816
# Validation Loss: 0.0783
# Epoch [26/50], Loss: 0.0813
# Validation Loss: 0.0786
# Early stopping triggered.
# Model trained and saved.
# Test MAE: 0.0437
# Prediction Accuracy: 0.9716%
# Using device: cpu
# Model file does not exist. Training a new model...
# Epoch [1/50], Loss: 0.1496
# Validation Loss: 0.1124
# Epoch [2/50], Loss: 0.1139
# Validation Loss: 0.1088
# Epoch [3/50], Loss: 0.1105
# Validation Loss: 0.1056
# Epoch [4/50], Loss: 0.1038
# Validation Loss: 0.0953
# Epoch [5/50], Loss: 0.0964
# Validation Loss: 0.0896
# Epoch [6/50], Loss: 0.0918
# Validation Loss: 0.0862
# Epoch [7/50], Loss: 0.0892
# Validation Loss: 0.0837
# Epoch [8/50], Loss: 0.0871
# Validation Loss: 0.0823
# Epoch [9/50], Loss: 0.0859
# Validation Loss: 0.0812
# Epoch [10/50], Loss: 0.0850
# Validation Loss: 0.0831
# Epoch [11/50], Loss: 0.0841
# Validation Loss: 0.0793
# Epoch [12/50], Loss: 0.0835
# Validation Loss: 0.0794
# Epoch [13/50], Loss: 0.0831
# Validation Loss: 0.0792
# Epoch [14/50], Loss: 0.0828
# Validation Loss: 0.0790
# Epoch [15/50], Loss: 0.0826
# Validation Loss: 0.0784
# Epoch [16/50], Loss: 0.0824
# Validation Loss: 0.0786
# Epoch [17/50], Loss: 0.0823
# Validation Loss: 0.0786
# Epoch [18/50], Loss: 0.0821
# Validation Loss: 0.0787
# Epoch [19/50], Loss: 0.0822
# Validation Loss: 0.0784
# Epoch [20/50], Loss: 0.0818
# Validation Loss: 0.0800
# Epoch [21/50], Loss: 0.0818
# Validation Loss: 0.0788
# Epoch [22/50], Loss: 0.0818
# Validation Loss: 0.0782
# Epoch [23/50], Loss: 0.0815
# Validation Loss: 0.0795
# Epoch [24/50], Loss: 0.0816
# Validation Loss: 0.0788
# Epoch [25/50], Loss: 0.0816
# Validation Loss: 0.0790
# Epoch [26/50], Loss: 0.0815
# Validation Loss: 0.0786
# Epoch [27/50], Loss: 0.0814
# Validation Loss: 0.0788
# Epoch [28/50], Loss: 0.0814
# Validation Loss: 0.0784
# Epoch [29/50], Loss: 0.0814
# Validation Loss: 0.0788
# Epoch [30/50], Loss: 0.0815
# Validation Loss: 0.0786
# Epoch [31/50], Loss: 0.0813
# Validation Loss: 0.0788
# Epoch [32/50], Loss: 0.0813
# Validation Loss: 0.0788
# Early stopping triggered.
# Model trained and saved.
# Test MAE: 0.0460
# Prediction Accuracy: 0.9719%
# Learning Rate: 0.001, Batch Size: 64, Hidden Size: 32, Dropout: 0.1
# Completed 97/108 combinations
# Using device: cpu
# Model file does not exist. Training a new model...
# Epoch [1/50], Loss: 0.1652
# Validation Loss: 0.1074
# Epoch [2/50], Loss: 0.1088
# Validation Loss: 0.0955
# Epoch [3/50], Loss: 0.0999
# Validation Loss: 0.0887
# Epoch [4/50], Loss: 0.0946
# Validation Loss: 0.0847
# Epoch [5/50], Loss: 0.0911
# Validation Loss: 0.0841
# Epoch [6/50], Loss: 0.0891
# Validation Loss: 0.0811
# Epoch [7/50], Loss: 0.0882
# Validation Loss: 0.0827
# Epoch [8/50], Loss: 0.0877
# Validation Loss: 0.0797
# Epoch [9/50], Loss: 0.0866
# Validation Loss: 0.0797
# Epoch [10/50], Loss: 0.0857
# Validation Loss: 0.0801
# Epoch [11/50], Loss: 0.0855
# Validation Loss: 0.0805
# Epoch [12/50], Loss: 0.0856
# Validation Loss: 0.0796
# Epoch [13/50], Loss: 0.0851
# Validation Loss: 0.0790
# Epoch [14/50], Loss: 0.0851
# Validation Loss: 0.0785
# Epoch [15/50], Loss: 0.0845
# Validation Loss: 0.0784
# Epoch [16/50], Loss: 0.0849
# Validation Loss: 0.0786
# Epoch [17/50], Loss: 0.0842
# Validation Loss: 0.0780
# Epoch [18/50], Loss: 0.0840
# Validation Loss: 0.0783
# Epoch [19/50], Loss: 0.0837
# Validation Loss: 0.0791
# Epoch [20/50], Loss: 0.0835
# Validation Loss: 0.0791
# Epoch [21/50], Loss: 0.0838
# Validation Loss: 0.0785
# Epoch [22/50], Loss: 0.0836
# Validation Loss: 0.0786
# Epoch [23/50], Loss: 0.0830
# Validation Loss: 0.0792
# Epoch [24/50], Loss: 0.0835
# Validation Loss: 0.0789
# Epoch [25/50], Loss: 0.0829
# Validation Loss: 0.0784
# Epoch [26/50], Loss: 0.0829
# Validation Loss: 0.0780
# Epoch [27/50], Loss: 0.0830
# Validation Loss: 0.0783
# Epoch [28/50], Loss: 0.0831
# Validation Loss: 0.0778
# Epoch [29/50], Loss: 0.0832
# Validation Loss: 0.0788
# Epoch [30/50], Loss: 0.0829
# Validation Loss: 0.0782
# Epoch [31/50], Loss: 0.0828
# Validation Loss: 0.0786
# Epoch [32/50], Loss: 0.0823
# Validation Loss: 0.0782
# Epoch [33/50], Loss: 0.0827
# Validation Loss: 0.0793
# Epoch [34/50], Loss: 0.0828
# Validation Loss: 0.0779
# Epoch [35/50], Loss: 0.0823
# Validation Loss: 0.0783
# Epoch [36/50], Loss: 0.0825
# Validation Loss: 0.0791
# Epoch [37/50], Loss: 0.0827
# Validation Loss: 0.0785
# Epoch [38/50], Loss: 0.0826
# Validation Loss: 0.0779
# Early stopping triggered.
# Model trained and saved.
# Test MAE: 0.0444
# Prediction Accuracy: 0.9717%
# Using device: cpu
# Model file does not exist. Training a new model...
# Epoch [1/50], Loss: 0.1544
# Validation Loss: 0.1110
# Epoch [2/50], Loss: 0.1156
# Validation Loss: 0.1033
# Epoch [3/50], Loss: 0.1068
# Validation Loss: 0.0945
# Epoch [4/50], Loss: 0.0988
# Validation Loss: 0.0885
# Epoch [5/50], Loss: 0.0937
# Validation Loss: 0.0848
# Epoch [6/50], Loss: 0.0899
# Validation Loss: 0.0834
# Epoch [7/50], Loss: 0.0886
# Validation Loss: 0.0811
# Epoch [8/50], Loss: 0.0870
# Validation Loss: 0.0792
# Epoch [9/50], Loss: 0.0857
# Validation Loss: 0.0793
# Epoch [10/50], Loss: 0.0854
# Validation Loss: 0.0787
# Epoch [11/50], Loss: 0.0850
# Validation Loss: 0.0782
# Epoch [12/50], Loss: 0.0846
# Validation Loss: 0.0784
# Epoch [13/50], Loss: 0.0845
# Validation Loss: 0.0787
# Epoch [14/50], Loss: 0.0845
# Validation Loss: 0.0786
# Epoch [15/50], Loss: 0.0841
# Validation Loss: 0.0780
# Epoch [16/50], Loss: 0.0836
# Validation Loss: 0.0782
# Epoch [17/50], Loss: 0.0837
# Validation Loss: 0.0782
# Epoch [18/50], Loss: 0.0834
# Validation Loss: 0.0785
# Epoch [19/50], Loss: 0.0833
# Validation Loss: 0.0783
# Epoch [20/50], Loss: 0.0832
# Validation Loss: 0.0780
# Epoch [21/50], Loss: 0.0831
# Validation Loss: 0.0781
# Epoch [22/50], Loss: 0.0830
# Validation Loss: 0.0801
# Epoch [23/50], Loss: 0.0831
# Validation Loss: 0.0781
# Epoch [24/50], Loss: 0.0826
# Validation Loss: 0.0779
# Epoch [25/50], Loss: 0.0829
# Validation Loss: 0.0779
# Epoch [26/50], Loss: 0.0826
# Validation Loss: 0.0780
# Epoch [27/50], Loss: 0.0829
# Validation Loss: 0.0784
# Epoch [28/50], Loss: 0.0827
# Validation Loss: 0.0780
# Epoch [29/50], Loss: 0.0826
# Validation Loss: 0.0786
# Epoch [30/50], Loss: 0.0826
# Validation Loss: 0.0781
# Epoch [31/50], Loss: 0.0827
# Validation Loss: 0.0780
# Epoch [32/50], Loss: 0.0827
# Validation Loss: 0.0780
# Epoch [33/50], Loss: 0.0824
# Validation Loss: 0.0779
# Epoch [34/50], Loss: 0.0825
# Validation Loss: 0.0782
# Epoch [35/50], Loss: 0.0824
# Validation Loss: 0.0805
# Early stopping triggered.
# Model trained and saved.
# Test MAE: 0.0437
# Prediction Accuracy: 0.9709%
# Using device: cpu
# Model file does not exist. Training a new model...
# Epoch [1/50], Loss: 0.1582
# Validation Loss: 0.1126
# Epoch [2/50], Loss: 0.1186
# Validation Loss: 0.1087
# Epoch [3/50], Loss: 0.1116
# Validation Loss: 0.1015
# Epoch [4/50], Loss: 0.1057
# Validation Loss: 0.0960
# Epoch [5/50], Loss: 0.1000
# Validation Loss: 0.0911
# Epoch [6/50], Loss: 0.0969
# Validation Loss: 0.0879
# Epoch [7/50], Loss: 0.0934
# Validation Loss: 0.0840
# Epoch [8/50], Loss: 0.0916
# Validation Loss: 0.0829
# Epoch [9/50], Loss: 0.0897
# Validation Loss: 0.0817
# Epoch [10/50], Loss: 0.0893
# Validation Loss: 0.0807
# Epoch [11/50], Loss: 0.0878
# Validation Loss: 0.0806
# Epoch [12/50], Loss: 0.0870
# Validation Loss: 0.0803
# Epoch [13/50], Loss: 0.0865
# Validation Loss: 0.0802
# Epoch [14/50], Loss: 0.0856
# Validation Loss: 0.0824
# Epoch [15/50], Loss: 0.0859
# Validation Loss: 0.0787
# Epoch [16/50], Loss: 0.0853
# Validation Loss: 0.0788
# Epoch [17/50], Loss: 0.0847
# Validation Loss: 0.0792
# Epoch [18/50], Loss: 0.0848
# Validation Loss: 0.0796
# Epoch [19/50], Loss: 0.0844
# Validation Loss: 0.0788
# Epoch [20/50], Loss: 0.0840
# Validation Loss: 0.0785
# Epoch [21/50], Loss: 0.0847
# Validation Loss: 0.0782
# Epoch [22/50], Loss: 0.0841
# Validation Loss: 0.0783
# Epoch [23/50], Loss: 0.0837
# Validation Loss: 0.0784
# Epoch [24/50], Loss: 0.0842
# Validation Loss: 0.0784
# Epoch [25/50], Loss: 0.0836
# Validation Loss: 0.0782
# Epoch [26/50], Loss: 0.0837
# Validation Loss: 0.0784
# Epoch [27/50], Loss: 0.0836
# Validation Loss: 0.0784
# Epoch [28/50], Loss: 0.0837
# Validation Loss: 0.0783
# Epoch [29/50], Loss: 0.0834
# Validation Loss: 0.0788
# Epoch [30/50], Loss: 0.0835
# Validation Loss: 0.0788
# Epoch [31/50], Loss: 0.0833
# Validation Loss: 0.0785
# Early stopping triggered.
# Model trained and saved.
# Test MAE: 0.0454
# Prediction Accuracy: 0.9721%
# Using device: cpu
# Model file does not exist. Training a new model...
# Epoch [1/50], Loss: 0.1661
# Validation Loss: 0.1109
# Epoch [2/50], Loss: 0.1146
# Validation Loss: 0.1013
# Epoch [3/50], Loss: 0.1064
# Validation Loss: 0.0948
# Epoch [4/50], Loss: 0.0987
# Validation Loss: 0.0889
# Epoch [5/50], Loss: 0.0947
# Validation Loss: 0.0854
# Epoch [6/50], Loss: 0.0917
# Validation Loss: 0.0828
# Epoch [7/50], Loss: 0.0898
# Validation Loss: 0.0825
# Epoch [8/50], Loss: 0.0886
# Validation Loss: 0.0810
# Epoch [9/50], Loss: 0.0875
# Validation Loss: 0.0806
# Epoch [10/50], Loss: 0.0866
# Validation Loss: 0.0796
# Epoch [11/50], Loss: 0.0855
# Validation Loss: 0.0796
# Epoch [12/50], Loss: 0.0861
# Validation Loss: 0.0796
# Epoch [13/50], Loss: 0.0853
# Validation Loss: 0.0796
# Epoch [14/50], Loss: 0.0851
# Validation Loss: 0.0801
# Epoch [15/50], Loss: 0.0850
# Validation Loss: 0.0795
# Epoch [16/50], Loss: 0.0844
# Validation Loss: 0.0786
# Epoch [17/50], Loss: 0.0841
# Validation Loss: 0.0783
# Epoch [18/50], Loss: 0.0841
# Validation Loss: 0.0788
# Epoch [19/50], Loss: 0.0839
# Validation Loss: 0.0791
# Epoch [20/50], Loss: 0.0835
# Validation Loss: 0.0782
# Epoch [21/50], Loss: 0.0836
# Validation Loss: 0.0786
# Epoch [22/50], Loss: 0.0832
# Validation Loss: 0.0787
# Epoch [23/50], Loss: 0.0832
# Validation Loss: 0.0783
# Epoch [24/50], Loss: 0.0832
# Validation Loss: 0.0779
# Epoch [25/50], Loss: 0.0827
# Validation Loss: 0.0785
# Epoch [26/50], Loss: 0.0829
# Validation Loss: 0.0794
# Epoch [27/50], Loss: 0.0830
# Validation Loss: 0.0778
# Epoch [28/50], Loss: 0.0826
# Validation Loss: 0.0775
# Epoch [29/50], Loss: 0.0823
# Validation Loss: 0.0784
# Epoch [30/50], Loss: 0.0825
# Validation Loss: 0.0777
# Epoch [31/50], Loss: 0.0830
# Validation Loss: 0.0779
# Epoch [32/50], Loss: 0.0824
# Validation Loss: 0.0776
# Epoch [33/50], Loss: 0.0823
# Validation Loss: 0.0780
# Epoch [34/50], Loss: 0.0822
# Validation Loss: 0.0780
# Epoch [35/50], Loss: 0.0822
# Validation Loss: 0.0780
# Epoch [36/50], Loss: 0.0823
# Validation Loss: 0.0778
# Epoch [37/50], Loss: 0.0823
# Validation Loss: 0.0780
# Epoch [38/50], Loss: 0.0824
# Validation Loss: 0.0779
# Early stopping triggered.
# Model trained and saved.
# Test MAE: 0.0447
# Prediction Accuracy: 0.9717%
# Using device: cpu
# Model file does not exist. Training a new model...
# Epoch [1/50], Loss: 0.1549
# Validation Loss: 0.1092
# Epoch [2/50], Loss: 0.1131
# Validation Loss: 0.1013
# Epoch [3/50], Loss: 0.1041
# Validation Loss: 0.0915
# Epoch [4/50], Loss: 0.0960
# Validation Loss: 0.0856
# Epoch [5/50], Loss: 0.0905
# Validation Loss: 0.0824
# Epoch [6/50], Loss: 0.0884
# Validation Loss: 0.0803
# Epoch [7/50], Loss: 0.0868
# Validation Loss: 0.0803
# Epoch [8/50], Loss: 0.0853
# Validation Loss: 0.0796
# Epoch [9/50], Loss: 0.0842
# Validation Loss: 0.0789
# Epoch [10/50], Loss: 0.0845
# Validation Loss: 0.0790
# Epoch [11/50], Loss: 0.0840
# Validation Loss: 0.0780
# Epoch [12/50], Loss: 0.0839
# Validation Loss: 0.0785
# Epoch [13/50], Loss: 0.0834
# Validation Loss: 0.0783
# Epoch [14/50], Loss: 0.0830
# Validation Loss: 0.0792
# Epoch [15/50], Loss: 0.0834
# Validation Loss: 0.0783
# Epoch [16/50], Loss: 0.0833
# Validation Loss: 0.0781
# Epoch [17/50], Loss: 0.0830
# Validation Loss: 0.0781
# Epoch [18/50], Loss: 0.0828
# Validation Loss: 0.0783
# Epoch [19/50], Loss: 0.0830
# Validation Loss: 0.0781
# Epoch [20/50], Loss: 0.0832
# Validation Loss: 0.0785
# Epoch [21/50], Loss: 0.0828
# Validation Loss: 0.0783
# Early stopping triggered.
# Model trained and saved.
# Test MAE: 0.0454
# Prediction Accuracy: 0.9719%
# Learning Rate: 0.001, Batch Size: 64, Hidden Size: 32, Dropout: 0.2
# Completed 98/108 combinations
# Using device: cpu
# Model file does not exist. Training a new model...
# Epoch [1/50], Loss: 0.1596
# Validation Loss: 0.1083
# Epoch [2/50], Loss: 0.1148
# Validation Loss: 0.0993
# Epoch [3/50], Loss: 0.1072
# Validation Loss: 0.0950
# Epoch [4/50], Loss: 0.1024
# Validation Loss: 0.0890
# Epoch [5/50], Loss: 0.0990
# Validation Loss: 0.0876
# Epoch [6/50], Loss: 0.0963
# Validation Loss: 0.0841
# Epoch [7/50], Loss: 0.0934
# Validation Loss: 0.0814
# Epoch [8/50], Loss: 0.0913
# Validation Loss: 0.0806
# Epoch [9/50], Loss: 0.0903
# Validation Loss: 0.0794
# Epoch [10/50], Loss: 0.0890
# Validation Loss: 0.0790
# Epoch [11/50], Loss: 0.0882
# Validation Loss: 0.0798
# Epoch [12/50], Loss: 0.0874
# Validation Loss: 0.0786
# Epoch [13/50], Loss: 0.0876
# Validation Loss: 0.0788
# Epoch [14/50], Loss: 0.0870
# Validation Loss: 0.0787
# Epoch [15/50], Loss: 0.0868
# Validation Loss: 0.0792
# Epoch [16/50], Loss: 0.0863
# Validation Loss: 0.0786
# Epoch [17/50], Loss: 0.0867
# Validation Loss: 0.0785
# Epoch [18/50], Loss: 0.0864
# Validation Loss: 0.0782
# Epoch [19/50], Loss: 0.0859
# Validation Loss: 0.0785
# Epoch [20/50], Loss: 0.0856
# Validation Loss: 0.0779
# Epoch [21/50], Loss: 0.0861
# Validation Loss: 0.0789
# Epoch [22/50], Loss: 0.0855
# Validation Loss: 0.0786
# Epoch [23/50], Loss: 0.0860
# Validation Loss: 0.0784
# Epoch [24/50], Loss: 0.0857
# Validation Loss: 0.0786
# Epoch [25/50], Loss: 0.0854
# Validation Loss: 0.0793
# Epoch [26/50], Loss: 0.0861
# Validation Loss: 0.0782
# Epoch [27/50], Loss: 0.0850
# Validation Loss: 0.0783
# Epoch [28/50], Loss: 0.0847
# Validation Loss: 0.0781
# Epoch [29/50], Loss: 0.0851
# Validation Loss: 0.0784
# Epoch [30/50], Loss: 0.0849
# Validation Loss: 0.0780
# Early stopping triggered.
# Model trained and saved.
# Test MAE: 0.0453
# Prediction Accuracy: 0.9717%
# Using device: cpu
# Model file does not exist. Training a new model...
# Epoch [1/50], Loss: 0.1567
# Validation Loss: 0.1091
# Epoch [2/50], Loss: 0.1135
# Validation Loss: 0.0972
# Epoch [3/50], Loss: 0.1020
# Validation Loss: 0.0885
# Epoch [4/50], Loss: 0.0959
# Validation Loss: 0.0840
# Epoch [5/50], Loss: 0.0921
# Validation Loss: 0.0817
# Epoch [6/50], Loss: 0.0893
# Validation Loss: 0.0812
# Epoch [7/50], Loss: 0.0881
# Validation Loss: 0.0797
# Epoch [8/50], Loss: 0.0869
# Validation Loss: 0.0792
# Epoch [9/50], Loss: 0.0856
# Validation Loss: 0.0797
# Epoch [10/50], Loss: 0.0858
# Validation Loss: 0.0786
# Epoch [11/50], Loss: 0.0854
# Validation Loss: 0.0786
# Epoch [12/50], Loss: 0.0849
# Validation Loss: 0.0787
# Epoch [13/50], Loss: 0.0850
# Validation Loss: 0.0786
# Epoch [14/50], Loss: 0.0850
# Validation Loss: 0.0789
# Epoch [15/50], Loss: 0.0849
# Validation Loss: 0.0791
# Epoch [16/50], Loss: 0.0845
# Validation Loss: 0.0790
# Epoch [17/50], Loss: 0.0846
# Validation Loss: 0.0790
# Epoch [18/50], Loss: 0.0845
# Validation Loss: 0.0782
# Epoch [19/50], Loss: 0.0842
# Validation Loss: 0.0782
# Epoch [20/50], Loss: 0.0844
# Validation Loss: 0.0781
# Epoch [21/50], Loss: 0.0843
# Validation Loss: 0.0784
# Epoch [22/50], Loss: 0.0841
# Validation Loss: 0.0779
# Epoch [23/50], Loss: 0.0841
# Validation Loss: 0.0785
# Epoch [24/50], Loss: 0.0834
# Validation Loss: 0.0784
# Epoch [25/50], Loss: 0.0834
# Validation Loss: 0.0786
# Epoch [26/50], Loss: 0.0837
# Validation Loss: 0.0781
# Epoch [27/50], Loss: 0.0840
# Validation Loss: 0.0784
# Epoch [28/50], Loss: 0.0840
# Validation Loss: 0.0785
# Epoch [29/50], Loss: 0.0841
# Validation Loss: 0.0782
# Epoch [30/50], Loss: 0.0838
# Validation Loss: 0.0783
# Epoch [31/50], Loss: 0.0836
# Validation Loss: 0.0779
# Epoch [32/50], Loss: 0.0837
# Validation Loss: 0.0779
# Epoch [33/50], Loss: 0.0834
# Validation Loss: 0.0783
# Epoch [34/50], Loss: 0.0838
# Validation Loss: 0.0781
# Epoch [35/50], Loss: 0.0835
# Validation Loss: 0.0780
# Epoch [36/50], Loss: 0.0835
# Validation Loss: 0.0781
# Epoch [37/50], Loss: 0.0835
# Validation Loss: 0.0781
# Epoch [38/50], Loss: 0.0834
# Validation Loss: 0.0782
# Epoch [39/50], Loss: 0.0834
# Validation Loss: 0.0780
# Epoch [40/50], Loss: 0.0830
# Validation Loss: 0.0781
# Epoch [41/50], Loss: 0.0833
# Validation Loss: 0.0782
# Epoch [42/50], Loss: 0.0831
# Validation Loss: 0.0784
# Early stopping triggered.
# Model trained and saved.
# Test MAE: 0.0458
# Prediction Accuracy: 0.9717%
# Using device: cpu
# Model file does not exist. Training a new model...
# Epoch [1/50], Loss: 0.1706
# Validation Loss: 0.1102
# Epoch [2/50], Loss: 0.1151
# Validation Loss: 0.0991
# Epoch [3/50], Loss: 0.1050
# Validation Loss: 0.0909
# Epoch [4/50], Loss: 0.0975
# Validation Loss: 0.0874
# Epoch [5/50], Loss: 0.0926
# Validation Loss: 0.0823
# Epoch [6/50], Loss: 0.0900
# Validation Loss: 0.0806
# Epoch [7/50], Loss: 0.0884
# Validation Loss: 0.0795
# Epoch [8/50], Loss: 0.0878
# Validation Loss: 0.0796
# Epoch [9/50], Loss: 0.0875
# Validation Loss: 0.0788
# Epoch [10/50], Loss: 0.0864
# Validation Loss: 0.0790
# Epoch [11/50], Loss: 0.0860
# Validation Loss: 0.0782
# Epoch [12/50], Loss: 0.0858
# Validation Loss: 0.0784
# Epoch [13/50], Loss: 0.0850
# Validation Loss: 0.0784
# Epoch [14/50], Loss: 0.0854
# Validation Loss: 0.0784
# Epoch [15/50], Loss: 0.0849
# Validation Loss: 0.0785
# Epoch [16/50], Loss: 0.0856
# Validation Loss: 0.0784
# Epoch [17/50], Loss: 0.0846
# Validation Loss: 0.0787
# Epoch [18/50], Loss: 0.0846
# Validation Loss: 0.0784
# Epoch [19/50], Loss: 0.0841
# Validation Loss: 0.0783
# Epoch [20/50], Loss: 0.0845
# Validation Loss: 0.0792
# Epoch [21/50], Loss: 0.0844
# Validation Loss: 0.0790
# Early stopping triggered.
# Model trained and saved.
# Test MAE: 0.0498
# Prediction Accuracy: 0.9713%
# Using device: cpu
# Model file does not exist. Training a new model...
# Epoch [1/50], Loss: 0.1727
# Validation Loss: 0.1132
# Epoch [2/50], Loss: 0.1185
# Validation Loss: 0.1044
# Epoch [3/50], Loss: 0.1099
# Validation Loss: 0.0958
# Epoch [4/50], Loss: 0.1020
# Validation Loss: 0.0917
# Epoch [5/50], Loss: 0.0976
# Validation Loss: 0.0868
# Epoch [6/50], Loss: 0.0964
# Validation Loss: 0.0868
# Epoch [7/50], Loss: 0.0947
# Validation Loss: 0.0848
# Epoch [8/50], Loss: 0.0925
# Validation Loss: 0.0859
# Epoch [9/50], Loss: 0.0919
# Validation Loss: 0.0815
# Epoch [10/50], Loss: 0.0912
# Validation Loss: 0.0832
# Epoch [11/50], Loss: 0.0914
# Validation Loss: 0.0829
# Epoch [12/50], Loss: 0.0897
# Validation Loss: 0.0812
# Epoch [13/50], Loss: 0.0889
# Validation Loss: 0.0797
# Epoch [14/50], Loss: 0.0884
# Validation Loss: 0.0813
# Epoch [15/50], Loss: 0.0881
# Validation Loss: 0.0812
# Epoch [16/50], Loss: 0.0869
# Validation Loss: 0.0795
# Epoch [17/50], Loss: 0.0873
# ...
# Validation Loss: 0.0784
# Early stopping triggered.
# Model trained and saved.
# Test MAE: 0.0472
# Prediction Accuracy: 0.9715%
# Using device: cpu
# Model file does not exist. Training a new model...
# Epoch [1/50], Loss: 0.1427
# Validation Loss: 0.1018
# Epoch [2/50], Loss: 0.1044
# Validation Loss: 0.0902
# Epoch [3/50], Loss: 0.0958
# Validation Loss: 0.0859
# Epoch [4/50], Loss: 0.0916
# Validation Loss: 0.0842
# Epoch [5/50], Loss: 0.0894
# Validation Loss: 0.0813
# Epoch [6/50], Loss: 0.0876
# Validation Loss: 0.0809
# Epoch [7/50], Loss: 0.0871
# Validation Loss: 0.0812
# Epoch [8/50], Loss: 0.0853
# Validation Loss: 0.0795
# Epoch [9/50], Loss: 0.0851
# Validation Loss: 0.0806
# Epoch [10/50], Loss: 0.0847
# Validation Loss: 0.0801
# Epoch [11/50], Loss: 0.0844
# Validation Loss: 0.0784
# Epoch [12/50], Loss: 0.0836
# Validation Loss: 0.0787
# Epoch [13/50], Loss: 0.0837
# Validation Loss: 0.0781
# Epoch [14/50], Loss: 0.0831
# Validation Loss: 0.0788
# Epoch [15/50], Loss: 0.0832
# Validation Loss: 0.0791
# Epoch [16/50], Loss: 0.0830
# Validation Loss: 0.0793
# Epoch [17/50], Loss: 0.0833
# Validation Loss: 0.0782
# Epoch [18/50], Loss: 0.0830
# Validation Loss: 0.0786
# Epoch [19/50], Loss: 0.0823
# Validation Loss: 0.0786
# Epoch [20/50], Loss: 0.0829
# Validation Loss: 0.0786
# Epoch [21/50], Loss: 0.0823
# Validation Loss: 0.0778
# Epoch [22/50], Loss: 0.0827
# Validation Loss: 0.0782
# Epoch [23/50], Loss: 0.0823
# Validation Loss: 0.0782
# Epoch [24/50], Loss: 0.0823
# Validation Loss: 0.0787
# Epoch [25/50], Loss: 0.0823
# Validation Loss: 0.0786
# Epoch [26/50], Loss: 0.0822
# Validation Loss: 0.0782
# Epoch [27/50], Loss: 0.0823
# Validation Loss: 0.0780
# Epoch [28/50], Loss: 0.0821
# Validation Loss: 0.0784
# Epoch [29/50], Loss: 0.0817
# Validation Loss: 0.0787
# Epoch [30/50], Loss: 0.0820
# Validation Loss: 0.0784
# Epoch [31/50], Loss: 0.0818
# Validation Loss: 0.0788
# Early stopping triggered.
# Model trained and saved.
# Test MAE: 0.0472
# Prediction Accuracy: 0.9717%
# Using device: cpu
# Model file does not exist. Training a new model...
# Epoch [1/50], Loss: 0.1347
# Validation Loss: 0.0995
# Epoch [2/50], Loss: 0.1022
# Validation Loss: 0.0883
# Epoch [3/50], Loss: 0.0943
# Validation Loss: 0.0847
# Epoch [4/50], Loss: 0.0904
# Validation Loss: 0.0828
# Epoch [5/50], Loss: 0.0887
# Validation Loss: 0.0815
# Epoch [6/50], Loss: 0.0873
# Validation Loss: 0.0803
# Epoch [7/50], Loss: 0.0862
# Validation Loss: 0.0794
# Epoch [8/50], Loss: 0.0855
# Validation Loss: 0.0794
# Epoch [9/50], Loss: 0.0850
# Validation Loss: 0.0798
# Epoch [10/50], Loss: 0.0845
# Validation Loss: 0.0801
# Epoch [11/50], Loss: 0.0842
# Validation Loss: 0.0786
# Epoch [12/50], Loss: 0.0840
# Validation Loss: 0.0804
# Epoch [13/50], Loss: 0.0837
# Validation Loss: 0.0788
# Epoch [14/50], Loss: 0.0837
# Validation Loss: 0.0781
# Epoch [15/50], Loss: 0.0831
# Validation Loss: 0.0787
# Epoch [16/50], Loss: 0.0832
# Validation Loss: 0.0789
# Epoch [17/50], Loss: 0.0833
# Validation Loss: 0.0784
# Epoch [18/50], Loss: 0.0831
# Validation Loss: 0.0785
# Epoch [19/50], Loss: 0.0832
# Validation Loss: 0.0786
# Epoch [20/50], Loss: 0.0828
# Validation Loss: 0.0785
# Epoch [21/50], Loss: 0.0826
# Validation Loss: 0.0783
# Epoch [22/50], Loss: 0.0828
# Validation Loss: 0.0786
# Epoch [23/50], Loss: 0.0824
# Validation Loss: 0.0784
# Epoch [24/50], Loss: 0.0826
# Validation Loss: 0.0787
# Early stopping triggered.
# Model trained and saved.
# Test MAE: 0.0473
# Prediction Accuracy: 0.9714%
# Using device: cpu
# Model file does not exist. Training a new model...
# Epoch [1/50], Loss: 0.1392
# Validation Loss: 0.1015
# Epoch [2/50], Loss: 0.1028
# Validation Loss: 0.0884
# Epoch [3/50], Loss: 0.0935
# Validation Loss: 0.0843
# Epoch [4/50], Loss: 0.0908
# Validation Loss: 0.0819
# Epoch [5/50], Loss: 0.0885
# Validation Loss: 0.0802
# Epoch [6/50], Loss: 0.0874
# Validation Loss: 0.0804
# Epoch [7/50], Loss: 0.0869
# Validation Loss: 0.0809
# Epoch [8/50], Loss: 0.0862
# Validation Loss: 0.0797
# Epoch [9/50], Loss: 0.0850
# Validation Loss: 0.0795
# Epoch [10/50], Loss: 0.0847
# Validation Loss: 0.0792
# Epoch [11/50], Loss: 0.0844
# Validation Loss: 0.0789
# Epoch [12/50], Loss: 0.0843
# Validation Loss: 0.0786
# Epoch [13/50], Loss: 0.0840
# Validation Loss: 0.0788
# Epoch [14/50], Loss: 0.0834
# Validation Loss: 0.0781
# Epoch [15/50], Loss: 0.0831
# Validation Loss: 0.0783
# Epoch [16/50], Loss: 0.0832
# Validation Loss: 0.0790
# Epoch [17/50], Loss: 0.0832
# Validation Loss: 0.0784
# Epoch [18/50], Loss: 0.0834
# Validation Loss: 0.0785
# Epoch [19/50], Loss: 0.0828
# Validation Loss: 0.0785
# Epoch [20/50], Loss: 0.0829
# Validation Loss: 0.0784
# Epoch [21/50], Loss: 0.0823
# Validation Loss: 0.0782
# Epoch [22/50], Loss: 0.0826
# Validation Loss: 0.0782
# Epoch [23/50], Loss: 0.0824
# Validation Loss: 0.0792
# Epoch [24/50], Loss: 0.0823
# Validation Loss: 0.0787
# Early stopping triggered.
# Model trained and saved.
# Test MAE: 0.0474
# Prediction Accuracy: 0.9714%
# Using device: cpu
# Model file does not exist. Training a new model...
# Epoch [1/50], Loss: 0.1401
# Validation Loss: 0.1035
# Epoch [2/50], Loss: 0.1054
# Validation Loss: 0.0920
# Epoch [3/50], Loss: 0.0962
# Validation Loss: 0.0853
# Epoch [4/50], Loss: 0.0920
# Validation Loss: 0.0839
# Epoch [5/50], Loss: 0.0896
# Validation Loss: 0.0820
# Epoch [6/50], Loss: 0.0887
# Validation Loss: 0.0807
# Epoch [7/50], Loss: 0.0870
# Validation Loss: 0.0809
# Epoch [8/50], Loss: 0.0858
# Validation Loss: 0.0801
# Epoch [9/50], Loss: 0.0852
# Validation Loss: 0.0790
# Epoch [10/50], Loss: 0.0851
# Validation Loss: 0.0792
# Epoch [11/50], Loss: 0.0844
# Validation Loss: 0.0795
# Epoch [12/50], Loss: 0.0842
# Validation Loss: 0.0786
# Epoch [13/50], Loss: 0.0836
# Validation Loss: 0.0796
# Epoch [14/50], Loss: 0.0835
# Validation Loss: 0.0790
# Epoch [15/50], Loss: 0.0834
# Validation Loss: 0.0782
# Epoch [16/50], Loss: 0.0832
# Validation Loss: 0.0784
# Epoch [17/50], Loss: 0.0835
# Validation Loss: 0.0804
# Epoch [18/50], Loss: 0.0825
# Validation Loss: 0.0787
# Epoch [19/50], Loss: 0.0831
# Validation Loss: 0.0788
# Epoch [20/50], Loss: 0.0828
# Validation Loss: 0.0787
# Epoch [21/50], Loss: 0.0824
# Validation Loss: 0.0788
# Epoch [22/50], Loss: 0.0826
# Validation Loss: 0.0784
# Epoch [23/50], Loss: 0.0827
# Validation Loss: 0.0785
# Epoch [24/50], Loss: 0.0829
# Validation Loss: 0.0781
# Epoch [25/50], Loss: 0.0825
# Validation Loss: 0.0786
# Epoch [26/50], Loss: 0.0821
# Validation Loss: 0.0783
# Epoch [27/50], Loss: 0.0817
# Validation Loss: 0.0780
# Epoch [28/50], Loss: 0.0823
# Validation Loss: 0.0781
# Epoch [29/50], Loss: 0.0821
# Validation Loss: 0.0782
# Epoch [30/50], Loss: 0.0827
# Validation Loss: 0.0782
# Epoch [31/50], Loss: 0.0817
# Validation Loss: 0.0781
# Epoch [32/50], Loss: 0.0819
# Validation Loss: 0.0778
# Epoch [33/50], Loss: 0.0814
# Validation Loss: 0.0784
# Epoch [34/50], Loss: 0.0819
# Validation Loss: 0.0781
# Epoch [35/50], Loss: 0.0818
# Validation Loss: 0.0784
# Epoch [36/50], Loss: 0.0814
# Validation Loss: 0.0787
# Epoch [37/50], Loss: 0.0816
# Validation Loss: 0.0787
# Epoch [38/50], Loss: 0.0819
# Validation Loss: 0.0782
# Epoch [39/50], Loss: 0.0814
# Validation Loss: 0.0787
# Epoch [40/50], Loss: 0.0818
# Validation Loss: 0.0781
# Epoch [41/50], Loss: 0.0813
# Validation Loss: 0.0783
# Epoch [42/50], Loss: 0.0812
# Validation Loss: 0.0784
# Early stopping triggered.
# Model trained and saved.
# Test MAE: 0.0464
# Prediction Accuracy: 0.9721%
# Learning Rate: 0.001, Batch Size: 64, Hidden Size: 128, Dropout: 0.3
# Completed 107/108 combinations
# Using device: cpu
# Model file does not exist. Training a new model...
# Epoch [1/50], Loss: 0.1456
# Validation Loss: 0.1004
# Epoch [2/50], Loss: 0.1050
# Validation Loss: 0.0883
# Epoch [3/50], Loss: 0.0959
# Validation Loss: 0.0862
# Epoch [4/50], Loss: 0.0917
# Validation Loss: 0.0810
# Epoch [5/50], Loss: 0.0887
# Validation Loss: 0.0808
# Epoch [6/50], Loss: 0.0868
# Validation Loss: 0.0795
# Epoch [7/50], Loss: 0.0866
# Validation Loss: 0.0794
# Epoch [8/50], Loss: 0.0865
# Validation Loss: 0.0797
# Epoch [9/50], Loss: 0.0859
# Validation Loss: 0.0786
# Epoch [10/50], Loss: 0.0849
# Validation Loss: 0.0787
# Epoch [11/50], Loss: 0.0845
# Validation Loss: 0.0786
# Epoch [12/50], Loss: 0.0851
# Validation Loss: 0.0785
# Epoch [13/50], Loss: 0.0841
# Validation Loss: 0.0788
# Epoch [14/50], Loss: 0.0840
# Validation Loss: 0.0787
# Epoch [15/50], Loss: 0.0844
# Validation Loss: 0.0782
# Epoch [16/50], Loss: 0.0836
# Validation Loss: 0.0780
# Epoch [17/50], Loss: 0.0839
# Validation Loss: 0.0781
# Epoch [18/50], Loss: 0.0831
# Validation Loss: 0.0783
# Epoch [19/50], Loss: 0.0836
# Validation Loss: 0.0777
# Epoch [20/50], Loss: 0.0837
# Validation Loss: 0.0785
# Epoch [21/50], Loss: 0.0841
# Validation Loss: 0.0781
# Epoch [22/50], Loss: 0.0833
# Validation Loss: 0.0781
# Epoch [23/50], Loss: 0.0833
# Validation Loss: 0.0781
# Epoch [24/50], Loss: 0.0828
# Validation Loss: 0.0782
# Epoch [25/50], Loss: 0.0829
# Validation Loss: 0.0776
# Epoch [26/50], Loss: 0.0830
# Validation Loss: 0.0780
# Epoch [27/50], Loss: 0.0836
# Validation Loss: 0.0781
# Epoch [28/50], Loss: 0.0829
# Validation Loss: 0.0779
# Epoch [29/50], Loss: 0.0825
# Validation Loss: 0.0783
# Epoch [30/50], Loss: 0.0828
# Validation Loss: 0.0780
# Epoch [31/50], Loss: 0.0830
# Validation Loss: 0.0781
# Epoch [32/50], Loss: 0.0825
# Validation Loss: 0.0784
# Epoch [33/50], Loss: 0.0827
# Validation Loss: 0.0781
# Epoch [34/50], Loss: 0.0823
# Validation Loss: 0.0779
# Epoch [35/50], Loss: 0.0826
# Validation Loss: 0.0782
# Early stopping triggered.
# Model trained and saved.
# Test MAE: 0.0469
# Prediction Accuracy: 0.9717%
# Using device: cpu
# Model file does not exist. Training a new model...
# Epoch [1/50], Loss: 0.1437
# Validation Loss: 0.1011
# Epoch [2/50], Loss: 0.1063
# Validation Loss: 0.0899
# Epoch [3/50], Loss: 0.0968
# Validation Loss: 0.0857
# Epoch [4/50], Loss: 0.0935
# Validation Loss: 0.0832
# Epoch [5/50], Loss: 0.0911
# Validation Loss: 0.0825
# Epoch [6/50], Loss: 0.0887
# Validation Loss: 0.0801
# Epoch [7/50], Loss: 0.0877
# Validation Loss: 0.0791
# Epoch [8/50], Loss: 0.0861
# Validation Loss: 0.0794
# Epoch [9/50], Loss: 0.0855
# Validation Loss: 0.0786
# Epoch [10/50], Loss: 0.0855
# Validation Loss: 0.0796
# Epoch [11/50], Loss: 0.0847
# Validation Loss: 0.0798
# Epoch [12/50], Loss: 0.0843
# Validation Loss: 0.0781
# Epoch [13/50], Loss: 0.0844
# Validation Loss: 0.0782
# Epoch [14/50], Loss: 0.0844
# Validation Loss: 0.0781
# Epoch [15/50], Loss: 0.0845
# Validation Loss: 0.0786
# Epoch [16/50], Loss: 0.0844
# Validation Loss: 0.0785
# Epoch [17/50], Loss: 0.0839
# Validation Loss: 0.0786
# Epoch [18/50], Loss: 0.0840
# Validation Loss: 0.0783
# Epoch [19/50], Loss: 0.0834
# Validation Loss: 0.0779
# Epoch [20/50], Loss: 0.0838
# Validation Loss: 0.0783
# Epoch [21/50], Loss: 0.0833
# Validation Loss: 0.0789
# Epoch [22/50], Loss: 0.0835
# Validation Loss: 0.0783
# Epoch [23/50], Loss: 0.0834
# Validation Loss: 0.0783
# Epoch [24/50], Loss: 0.0830
# Validation Loss: 0.0781
# Epoch [25/50], Loss: 0.0831
# Validation Loss: 0.0783
# Epoch [26/50], Loss: 0.0830
# Validation Loss: 0.0783
# Epoch [27/50], Loss: 0.0830
# Validation Loss: 0.0782
# Epoch [28/50], Loss: 0.0826
# Validation Loss: 0.0796
# Epoch [29/50], Loss: 0.0829
# Validation Loss: 0.0782
# Early stopping triggered.
# Model trained and saved.
# Test MAE: 0.0453
# Prediction Accuracy: 0.9720%
# Using device: cpu
# Model file does not exist. Training a new model...
# Epoch [1/50], Loss: 0.1485
# Validation Loss: 0.1031
# Epoch [2/50], Loss: 0.1080
# Validation Loss: 0.0910
# Epoch [3/50], Loss: 0.0977
# Validation Loss: 0.0849
# Epoch [4/50], Loss: 0.0942
# Validation Loss: 0.0827
# Epoch [5/50], Loss: 0.0905
# Validation Loss: 0.0817
# Epoch [6/50], Loss: 0.0885
# Validation Loss: 0.0802
# Epoch [7/50], Loss: 0.0879
# Validation Loss: 0.0803
# Epoch [8/50], Loss: 0.0863
# Validation Loss: 0.0793
# Epoch [9/50], Loss: 0.0861
# Validation Loss: 0.0793
# Epoch [10/50], Loss: 0.0859
# Validation Loss: 0.0783
# Epoch [11/50], Loss: 0.0846
# Validation Loss: 0.0793
# Epoch [12/50], Loss: 0.0849
# Validation Loss: 0.0786
# Epoch [13/50], Loss: 0.0843
# Validation Loss: 0.0791
# Epoch [14/50], Loss: 0.0840
# Validation Loss: 0.0788
# Epoch [15/50], Loss: 0.0841
# Validation Loss: 0.0786
# Epoch [16/50], Loss: 0.0843
# Validation Loss: 0.0783
# Epoch [17/50], Loss: 0.0836
# Validation Loss: 0.0807
# Epoch [18/50], Loss: 0.0836
# Validation Loss: 0.0785
# Epoch [19/50], Loss: 0.0837
# Validation Loss: 0.0787
# Epoch [20/50], Loss: 0.0833
# Validation Loss: 0.0783
# Epoch [21/50], Loss: 0.0836
# Validation Loss: 0.0785
# Epoch [22/50], Loss: 0.0834
# Validation Loss: 0.0787
# Epoch [23/50], Loss: 0.0836
# Validation Loss: 0.0794
# Epoch [24/50], Loss: 0.0833
# Validation Loss: 0.0784
# Epoch [25/50], Loss: 0.0833
# Validation Loss: 0.0784
# Epoch [26/50], Loss: 0.0831
# Validation Loss: 0.0785
# Early stopping triggered.
# Model trained and saved.
# Test MAE: 0.0460
# Prediction Accuracy: 0.9717%
# Using device: cpu
# Model file does not exist. Training a new model...
# Epoch [1/50], Loss: 0.1417
# Validation Loss: 0.1016
# Epoch [2/50], Loss: 0.1054
# Validation Loss: 0.0887
# Epoch [3/50], Loss: 0.0963
# Validation Loss: 0.0856
# Epoch [4/50], Loss: 0.0925
# Validation Loss: 0.0832
# Epoch [5/50], Loss: 0.0899
# Validation Loss: 0.0812
# Epoch [6/50], Loss: 0.0885
# Validation Loss: 0.0798
# Epoch [7/50], Loss: 0.0872
# Validation Loss: 0.0807
# Epoch [8/50], Loss: 0.0866
# Validation Loss: 0.0791
# Epoch [9/50], Loss: 0.0856
# Validation Loss: 0.0783
# Epoch [10/50], Loss: 0.0853
# Validation Loss: 0.0786
# Epoch [11/50], Loss: 0.0847
# Validation Loss: 0.0787
# Epoch [12/50], Loss: 0.0845
# Validation Loss: 0.0787
# Epoch [13/50], Loss: 0.0844
# Validation Loss: 0.0783
# Epoch [14/50], Loss: 0.0841
# Validation Loss: 0.0784
# Epoch [15/50], Loss: 0.0835
# Validation Loss: 0.0781
# Epoch [16/50], Loss: 0.0842
# Validation Loss: 0.0780
# Epoch [17/50], Loss: 0.0830
# Validation Loss: 0.0784
# Epoch [18/50], Loss: 0.0836
# Validation Loss: 0.0786
# Epoch [19/50], Loss: 0.0834
# Validation Loss: 0.0782
# Epoch [20/50], Loss: 0.0834
# Validation Loss: 0.0784
# Epoch [21/50], Loss: 0.0835
# Validation Loss: 0.0790
# Epoch [22/50], Loss: 0.0832
# Validation Loss: 0.0781
# Epoch [23/50], Loss: 0.0833
# Validation Loss: 0.0787
# Epoch [24/50], Loss: 0.0835
# Validation Loss: 0.0778
# Epoch [25/50], Loss: 0.0828
# Validation Loss: 0.0785
# Epoch [26/50], Loss: 0.0831
# Validation Loss: 0.0777
# Epoch [27/50], Loss: 0.0832
# Validation Loss: 0.0779
# Epoch [28/50], Loss: 0.0832
# Validation Loss: 0.0780
# Epoch [29/50], Loss: 0.0830
# Validation Loss: 0.0783
# Epoch [30/50], Loss: 0.0831
# Validation Loss: 0.0782
# Epoch [31/50], Loss: 0.0829
# Validation Loss: 0.0783
# Epoch [32/50], Loss: 0.0827
# Validation Loss: 0.0781
# Epoch [33/50], Loss: 0.0832
# Validation Loss: 0.0780
# Epoch [34/50], Loss: 0.0831
# Validation Loss: 0.0783
# Epoch [35/50], Loss: 0.0824
# Validation Loss: 0.0786
# Epoch [36/50], Loss: 0.0827
# Validation Loss: 0.0782
# Early stopping triggered.
# Model trained and saved.
# Test MAE: 0.0461
# Prediction Accuracy: 0.9719%
# Using device: cpu
# Model file does not exist. Training a new model...
# Epoch [1/50], Loss: 0.1450
# Validation Loss: 0.1040
# Epoch [2/50], Loss: 0.1084
# Validation Loss: 0.0922
# Epoch [3/50], Loss: 0.1002
# Validation Loss: 0.0902
# Epoch [4/50], Loss: 0.0946
# Validation Loss: 0.0835
# Epoch [5/50], Loss: 0.0916
# Validation Loss: 0.0835
# Epoch [6/50], Loss: 0.0903
# Validation Loss: 0.0813
# Epoch [7/50], Loss: 0.0895
# Validation Loss: 0.0806
# Epoch [8/50], Loss: 0.0876
# Validation Loss: 0.0806
# Epoch [9/50], Loss: 0.0870
# Validation Loss: 0.0795
# Epoch [10/50], Loss: 0.0863
# Validation Loss: 0.0794
# Epoch [11/50], Loss: 0.0857
# Validation Loss: 0.0786
# Epoch [12/50], Loss: 0.0846
# Validation Loss: 0.0783
# Epoch [13/50], Loss: 0.0849
# Validation Loss: 0.0781
# Epoch [14/50], Loss: 0.0849
# Validation Loss: 0.0786
# Epoch [15/50], Loss: 0.0841
# Validation Loss: 0.0788
# Epoch [16/50], Loss: 0.0840
# Validation Loss: 0.0786
# Epoch [17/50], Loss: 0.0839
# Validation Loss: 0.0784
# Epoch [18/50], Loss: 0.0837
# Validation Loss: 0.0782
# Epoch [19/50], Loss: 0.0837
# Validation Loss: 0.0779
# Epoch [20/50], Loss: 0.0838
# Validation Loss: 0.0779
# Epoch [21/50], Loss: 0.0835
# Validation Loss: 0.0781
# Epoch [22/50], Loss: 0.0833
# Validation Loss: 0.0781
# Epoch [23/50], Loss: 0.0833
# Validation Loss: 0.0786
# Epoch [24/50], Loss: 0.0833
# Validation Loss: 0.0782
# Epoch [25/50], Loss: 0.0836
# Validation Loss: 0.0779
# Epoch [26/50], Loss: 0.0830
# Validation Loss: 0.0790
# Epoch [27/50], Loss: 0.0830
# Validation Loss: 0.0785
# Epoch [28/50], Loss: 0.0828
# Validation Loss: 0.0779
# Epoch [29/50], Loss: 0.0830
# Validation Loss: 0.0785
# Early stopping triggered.
# Model trained and saved.
# Test MAE: 0.0466
# Prediction Accuracy: 0.9717%

# %%
results_df.sort_values(by='Accuracy', ascending=False).head(5)
# Out:
#      Learning Rate  Batch Size  Hidden Size  Dropout       MAE  Accuracy
# 107          0.001          64          128      0.3  0.046189  0.971813
# 48           0.005          32           32      0.0  0.045561  0.971813
# 49           0.005          32           32      0.1  0.046554  0.971800
# 85           0.001          32           32      0.1  0.046237  0.971787
# 103          0.001          64           64      0.3  0.044846  0.971720

# %%
results_df.sort_values(by='MAE', ascending=False).head(5)
# Out:
#     Learning Rate  Batch Size  Hidden Size  Dropout       MAE  Accuracy
# 11           0.01          16          128      0.3  0.052501  0.969427
# 14           0.01          32           32      0.2  0.052433  0.971147
# 9            0.01          16          128      0.1  0.051909  0.970720
# 6            0.01          16           64      0.2  0.051487  0.970107
# 4            0.01          16           64      0.0  0.051299  0.970080
