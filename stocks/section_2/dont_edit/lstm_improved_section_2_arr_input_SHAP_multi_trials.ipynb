# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
from numpy.linalg import norm

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# Load the data
file_path = "../SPY_section_2.csv"
df = pd.read_csv(file_path)

# %%
# Define Autoencoder
class Autoencoder(nn.Module):
    def __init__(self, input_dim, encoding_dim, dropout_rate):
        super(Autoencoder, self).__init__()
        self.encoder = nn.Sequential(
            nn.Linear(input_dim, 128),
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.Linear(64, encoding_dim)
        )
        self.decoder = nn.Sequential(
            nn.Linear(encoding_dim, 64),
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.Linear(64, 128),
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.Linear(128, input_dim)
        )
    
    def forward(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return decoded

# %%
# Define LSTM model
class ComplexLSTMModel(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, dropout_rate):
        super(ComplexLSTMModel, self).__init__()
        # Unidirectional LSTM for sequential stock price prediction
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers,
                            batch_first=True, dropout=dropout_rate)  # Removed bidirectional=True

        # Fully connected layers for added complexity
        self.fc1 = nn.Linear(hidden_size, hidden_size // 2)
        self.dropout1 = nn.Dropout(dropout_rate)
        self.fc2 = nn.Linear(hidden_size // 2, hidden_size // 4)
        self.dropout2 = nn.Dropout(dropout_rate)
        self.fc3 = nn.Linear(hidden_size // 4, 1)

    def forward(self, x):
        # LSTM expects input of shape (batch_size, sequence_length, input_size)
        out, _ = self.lstm(x)
        # Use the output of the last time step
        out = out[:, -1, :]  # Shape: (batch_size, hidden_size)

        out = torch.relu(self.fc1(out))  # First fully connected layer
        out = self.dropout1(out)
        out = torch.relu(self.fc2(out))  # Second fully connected layer
        out = self.dropout2(out)
        out = self.fc3(out)  # Output layer (no activation for regression)
        return out
    
    
sequence_length = 10

# Reshape data into sequences
def create_sequences(data, target, seq_length):
    X_seq, y_seq = [], []
    for i in range(len(data) - seq_length):
        X_seq.append(data[i:i + seq_length])
        y_seq.append(target[i + seq_length])
    return np.array(X_seq), np.array(y_seq)

# %%
# Define the target variable
if "Target" not in df.columns:
    # df["Target"] = (df["Close"].shift(-1) > df["Close"]).astype(int)
    df["Target"] = df["Close"].shift(-1)
df = df.dropna()

# %%
# Adding SMA and EMA to the feature
short_term_period = 20
medium_term_period = 50
long_term_period = 200

# Compute the SMAs
df['SMA_20'] = df['Close'].rolling(window=short_term_period).mean() # Short-term SMA
df['SMA_50'] = df['Close'].rolling(window=medium_term_period).mean() # Medium-term SMA
df['SMA_200'] = df['Close'].rolling(window=long_term_period).mean() # Long-term SMA

df['EMA_10'] = df['Close'].ewm(span=10, adjust=False).mean()  # Short-term EMA
df['EMA_50'] = df['Close'].ewm(span=50, adjust=False).mean()  # Medium-term EMA
df['EMA_200'] = df['Close'].ewm(span=200, adjust=False).mean()  # Long-term EMA

df = df.dropna()

# %%
X = df.drop(columns=["Date", "Target"])
y = df["Target"]

feature_columns = ["Open", "High", "Low", "Close", "Volume", "SMA_20", "SMA_50", "SMA_200", "EMA_10", "EMA_50", "EMA_200"]

train_size = int(X.shape[0] * 0.7)
val_size = int(X.shape[0] * 0.15)

scaler = MinMaxScaler()

# Split data into train, validation, and test
temp_train = X[:train_size]
temp_val = X[train_size:train_size + val_size]
temp_test = X[train_size + val_size:]

temp_train = temp_train[feature_columns]
temp_val = temp_val[feature_columns]
temp_test = temp_test[feature_columns]

# Fit and transform for train, transform for validation and test
temp_train = scaler.fit_transform(temp_train)
temp_val = scaler.transform(temp_val)
temp_test = scaler.transform(temp_test)

# Convert NumPy arrays back to DataFrames
temp_train = pd.DataFrame(temp_train, columns=feature_columns)
temp_val = pd.DataFrame(temp_val, columns=feature_columns)
temp_test = pd.DataFrame(temp_test, columns=feature_columns)

# Concatenate the data
X_scaled = pd.concat([temp_train, temp_val, temp_test], axis=0)

X_seq, y_seq = create_sequences(X_scaled, y.values, sequence_length)

# Split sequentially
X_train, y_train = X_seq[:train_size], y_seq[:train_size]
X_val, y_val = X_seq[train_size:train_size + val_size], y_seq[train_size:train_size + val_size]
X_test, y_test = X_seq[train_size + val_size:], y_seq[train_size + val_size:]

# Print sizes to confirm
print(f"Train: {len(X_train)}, Val: {len(X_val)}, Test: {len(X_test)}")
print(X_scaled.shape)
# Out:
# Train: 1194, Val: 256, Test: 247
# (1707, 11)

# %%
# Convert to PyTorch tensors
X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train, dtype=torch.float32)
X_val_tensor = torch.tensor(X_val, dtype=torch.float32)
y_val_tensor = torch.tensor(y_val, dtype=torch.float32)
X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test, dtype=torch.float32)

# Create DataLoaders
train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
val_dataset = TensorDataset(X_val_tensor, y_val_tensor)
test_dataset = TensorDataset(X_test_tensor, y_test_tensor)

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=64, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

# %% [markdown]
# <span style="color: yellow; font-size: 40px;">Evaluating original LSTM</span>

# %%
# Hyperparameters
input_size = X_train.shape[2]  # Number of features
hidden_size = 128
num_layers = 2
dropout_rate = 0.1
learning_rate = 0.0005
num_epochs = 500
patience = 30

# %%
# Define paths
LSTM_model_path = "../lstm_codes/lstm_models/lstm_section_2.pth"  # Change this to your specific model file

# Load the trained model
LSTM_model = ComplexLSTMModel(input_size=input_size, hidden_size=hidden_size, num_layers=num_layers, dropout_rate=dropout_rate).to(device)
LSTM_model.load_state_dict(torch.load(LSTM_model_path))
LSTM_model.eval()

# Define loss function
criterion = torch.nn.MSELoss()

# Evaluate on test data
test_loss = 0.0
test_mae = 0.0
all_true = []
all_preds = []

with torch.no_grad():
    for X_batch, y_batch in test_loader:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)
        outputs = LSTM_model(X_batch)
        loss = criterion(outputs, y_batch)
        mae = torch.mean(torch.abs(outputs - y_batch))
        
        test_loss += loss.item() * X_batch.size(0)
        test_mae += mae.item() * X_batch.size(0)
        
        all_true.extend(y_batch.cpu().numpy())
        all_preds.extend(outputs.cpu().numpy())

# Compute final metrics
test_loss /= len(test_loader.dataset)
test_mae /= len(test_loader.dataset)

# Compute error percentages
all_true = np.array(all_true).flatten()
all_preds = np.array(all_preds).flatten()
error = np.abs(all_true - all_preds) / (np.abs(all_true) + 1e-8)
avg_error = np.mean(error) * 100
largest_error = np.max(error) * 100

# Print results
print("\n===== Evaluation Results =====")
print(f"Test Loss: {test_loss:.4f}")
print(f"Test MAE: {test_mae:.4f}")
print(f"Average Error Percentage: {avg_error:.2f}%")
print(f"Largest Error Percentage: {largest_error:.2f}%")

# Plot actual vs predicted values
plt.figure(figsize=(10, 5))
plt.plot(all_true, label='True Values', color='blue')
plt.plot(all_preds, label='Predicted Values', color='red')
plt.xlabel('Time')
plt.ylabel('Value')
plt.title('Actual vs. Predicted Values')
plt.legend()
plt.show()
# Out:
# C:\Users\ROG\AppData\Local\Temp/ipykernel_31148/2396509660.py:6: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   LSTM_model.load_state_dict(torch.load(LSTM_model_path))
# d:\Anaconda\lib\site-packages\torch\nn\modules\loss.py:538: UserWarning: Using a target size (torch.Size([64])) that is different to the input size (torch.Size([64, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# d:\Anaconda\lib\site-packages\torch\nn\modules\loss.py:538: UserWarning: Using a target size (torch.Size([55])) that is different to the input size (torch.Size([55, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# ===== Evaluation Results =====
# Test Loss: 28.6670
# Test MAE: 4.1148
# Average Error Percentage: 4.20%
# Largest Error Percentage: 22.92%

# %% [markdown]
# <span style="color: yellow; font-size: 40px;">Evaluating original autoencoder</span>

# %%
X_train = X_scaled[:train_size]
X_val = X_scaled[train_size:train_size + val_size]
X_test = X_scaled[train_size + val_size:]

# %%
X_train = X_train.values
X_val = X_val.values
X_test = X_test.values

# %%
# Convert data to PyTorch tensors
X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
X_val_tensor = torch.tensor(X_val, dtype=torch.float32)
X_test_tensor = torch.tensor(X_test, dtype=torch.float32)

# Create DataLoader
train_dataset = TensorDataset(X_train_tensor, X_train_tensor)
val_dataset = TensorDataset(X_val_tensor, X_val_tensor)
test_dataset = TensorDataset(X_test_tensor, X_test_tensor)
train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=16, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=16, shuffle=False)

# %%
input_dim = X_train.shape[1]

# Hyperparameters
encoding_dim = 5
learning_rate = 0.0005
dropout_rate = 0.3
epochs = 750
batch_size = 16
patience = 40

# %%
autoencoder_model_path = "../autoencoder_codes/autoencoder_models/autoencoder_section_2.pth"
autoencoder_model = Autoencoder(input_dim=input_dim, encoding_dim=encoding_dim, dropout_rate=dropout_rate).to(device)
autoencoder_model.load_state_dict(torch.load(autoencoder_model_path))
# Out:
# C:\Users\ROG\AppData\Local\Temp/ipykernel_31148/3578911162.py:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   autoencoder_model.load_state_dict(torch.load(autoencoder_model_path))
# <All keys matched successfully>

# %%
autoencoder_model.eval()
with torch.no_grad():
    reconstructed_test = autoencoder_model(torch.tensor(X_test, dtype=torch.float32).to(device)).cpu().numpy()
mse = np.mean((X_test - reconstructed_test) ** 2)
mae = np.mean(np.abs(X_test - reconstructed_test))
ree = np.mean(np.linalg.norm(X_test - reconstructed_test, axis=1) / np.linalg.norm(X_test, axis=1))
euclidean_dist = np.mean([norm(X_test[i] - reconstructed_test[i]) for i in range(len(X_test))])
reconstruction_error_percentage = (
    np.mean(np.abs(X_test - reconstructed_test) / (np.abs(X_test) + 1e-8), axis=1) * 100
)
average_error = np.mean(reconstruction_error_percentage)
print(f'MSE: {mse:.4f}, MAE: {mae:.4f}, REE: {ree:.4f}, Euclidean Distance: {euclidean_dist:.4f}, Average Error: {average_error:.4f}%')
# Out:
# MSE: 0.0228, MAE: 0.0984, REE: 0.2287, Euclidean Distance: 0.4141, Average Error: 81.7411%

# %%
# Scatter plot of reconstruction error percentage
plt.figure(figsize=(10, 5))
plt.scatter(range(len(reconstruction_error_percentage)), reconstruction_error_percentage, alpha=0.5)
plt.ylim(0, 50)
plt.xlabel('Sample')
plt.ylabel('Reconstruction Error Percentage')
plt.title('Reconstruction Error Percentage')
plt.show()

# %% [markdown]
# <span style="color: yellow; font-size: 40px;">Bias correction model - single input</span>

# %%
# import torch
# import torch.nn as nn
# import torch.nn.functional as F

# class BiasPredictor(nn.Module):
#     def __init__(self, input_size, hidden_size1, dropout_rate):
#         super(BiasPredictor, self).__init__()
        
#         hidden_size2 = hidden_size1 // 2
#         hidden_size3 = hidden_size2 // 2
#         hidden_size4 = hidden_size3 // 2  # New additional layer

#         self.fc1 = nn.Linear(input_size, hidden_size1)
#         self.dropout1 = nn.Dropout(dropout_rate)
        
#         self.fc2 = nn.Linear(hidden_size1, hidden_size2)
#         self.dropout2 = nn.Dropout(dropout_rate)
        
#         self.fc3 = nn.Linear(hidden_size2, hidden_size3)
#         self.dropout3 = nn.Dropout(dropout_rate)

#         self.fc4 = nn.Linear(hidden_size3, hidden_size4)  # New additional layer
#         self.dropout4 = nn.Dropout(dropout_rate)

#         self.fc5 = nn.Linear(hidden_size4, 1)  # Final output layer

#     def forward(self, x):
#         x = F.relu(self.fc1(x))
#         x = self.dropout1(x)
        
#         x = F.relu(self.fc2(x))
#         x = self.dropout2(x)
        
#         x = F.relu(self.fc3(x))
#         x = self.dropout3(x)

#         x = F.relu(self.fc4(x))  # New layer
#         x = self.dropout4(x)

#         return self.fc5(x)



import torch
import torch.nn as nn
import torch.nn.functional as F

class BiasPredictor(nn.Module):
    def __init__(self, input_size, hidden_size, dropout_rate):
        super(BiasPredictor, self).__init__()

        hidden_size2 = hidden_size // 2

        # Define layers
        self.fc1 = nn.Linear(input_size, hidden_size)
        self.dropout1 = nn.Dropout(dropout_rate)

        self.fc2 = nn.Linear(hidden_size, hidden_size2)
        self.dropout2 = nn.Dropout(dropout_rate)

        self.fc3 = nn.Linear(hidden_size2, 1) 

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = self.dropout1(x)

        x = F.relu(self.fc2(x))
        x = self.dropout2(x)

        return self.fc3(x)

# %%
# Get LSTM predictions of entire dataset
with torch.no_grad():
    X_tensor = torch.tensor(X_seq, dtype=torch.float32).to(device)
    LSTM_preds = LSTM_model(X_tensor).cpu().numpy()
    
# Put LSTM predictions into a new DataFrame
new_df = pd.DataFrame(LSTM_preds, columns=["LSTM_Pred"])

# %%
# Drop the first sequence_length rows
temp_y = y
temp_y = temp_y[sequence_length:]

# add the target variable to the new DataFrame
new_df["Target"] = temp_y.values

# %%
# Get reconstruction error percentage for the entire dataset
autoencoder_model.eval()
with torch.no_grad():
    reconstructed = autoencoder_model(torch.tensor(X_scaled.values, dtype=torch.float32).to(device)).cpu().numpy()
    
# Compute the MAE
reconstruction_error = np.mean(np.abs(X_scaled.values - reconstructed), axis=1)

# Compute the reconstruction error percentage
# reconstruction_error = np.mean(np.abs(X_scaled.values - reconstructed) / (np.abs(X_scaled.values) + 1e-8), axis=1) * 100
# reconstruction_error = np.mean((X_scaled.values - reconstructed) / ((X_scaled.values) + 1e-8), axis=1) * 100

# Drop the first sequence_length rows
reconstruction_error_new = reconstruction_error[sequence_length:]

# Add the reconstruction error to the new DataFrame
new_df["Reconstruction_error_single"] = reconstruction_error_new

# Get reconstruction error arr of past 10 days
reconstruction_error_arr = []
for i in range(sequence_length, len(reconstruction_error)):
    reconstruction_error_arr.append(reconstruction_error[i - sequence_length:i])
    

# Add the reconstruction error array to the new DataFrame
new_df["Reconstruction_error_arr"] = reconstruction_error_arr

# %%
# plot reconstruction error scatter plot
plt.figure(figsize=(10, 5))
plt.scatter(range(len(reconstruction_error)), reconstruction_error, alpha=0.5)
plt.ylim(0, 0.5)
plt.xlabel('Sample')
# plt.ylabel('Reconstruction Error Percentage')
# plt.title('Reconstruction Error Percentage')
plt.ylabel('Reconstruction Error MAE')
plt.title('Reconstruction Error MAE')
plt.show()

# %%
reconstruction_error_arr[0]
# Out:
# array([0.00346785, 0.00279189, 0.00238324, 0.00250549, 0.0036095 ,
#        0.00329989, 0.00362503, 0.0051211 , 0.003162  , 0.00687032])

# %%
# Calculate the difference between the target and LSTM prediction
new_df["Bias"] = new_df["Target"] - new_df["LSTM_Pred"]

# %%
y = new_df["Bias"]
X = new_df["Reconstruction_error_single"]
# X = new_df["Reconstruction_error_arr"]

# %%
# Sequential split
train_size = int(0.7 * len(X))
val_size = int(0.15 * len(X))

X_train_raw = X[:train_size]
y_train_raw = y[:train_size]
X_val_raw = X[train_size:train_size + val_size]
y_val_raw = y[train_size:train_size + val_size]
X_test_raw = X[train_size + val_size:]
y_test_raw = y[train_size + val_size:]

# Scale using StandardScaler (fit only on train data)
# X_scaler = StandardScaler()
X_scaler = RobustScaler()
X_train_scaled = X_scaler.fit_transform(X_train_raw.values.reshape(-1, 1))
X_val_scaled = X_scaler.transform(X_val_raw.values.reshape(-1, 1))
X_test_scaled = X_scaler.transform(X_test_raw.values.reshape(-1, 1))

# y_scaler = StandardScaler()
y_scaler = RobustScaler()
y_train_scaled = y_scaler.fit_transform(y_train_raw.values.reshape(-1, 1))
y_val_scaled = y_scaler.transform(y_val_raw.values.reshape(-1, 1))
y_test_scaled = y_scaler.transform(y_test_raw.values.reshape(-1, 1))

# Convert data to PyTorch tensors
X_train = torch.tensor(X_train_scaled, dtype=torch.float32).unsqueeze(1)
y_train = torch.tensor(y_train_scaled, dtype=torch.float32).unsqueeze(1)
X_val = torch.tensor(X_val_scaled, dtype=torch.float32).unsqueeze(1)
y_val = torch.tensor(y_val_scaled, dtype=torch.float32).unsqueeze(1)
X_test = torch.tensor(X_test_scaled, dtype=torch.float32).unsqueeze(1)
y_test = torch.tensor(y_test_scaled, dtype=torch.float32).unsqueeze(1)

# Print sizes
print(f"Train: {len(X_train)}, Val: {len(X_val)}, Test: {len(X_test)}")
# Out:
# Train: 1187, Val: 254, Test: 256

# %%
# Create DataLoader
train_dataset = TensorDataset(X_train, y_train)
val_dataset = TensorDataset(X_val, y_val)
test_dataset = TensorDataset(X_test, y_test)
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import os
from torch.utils.data import DataLoader, TensorDataset

# Directory to save the models
save_dir = "uni_input_trials"
os.makedirs(save_dir, exist_ok=True)

# Number of trials
num_trials = 10

# Training parameters
input_size = 1
hidden_size = 32
dropout_rate = 0.2
learning_rate = 0.0001
num_epochs = 500
patience = 20

bias_model = BiasPredictor(input_size=input_size, hidden_size=hidden_size, dropout_rate=dropout_rate).to(device)

#load model
bias_model.load_state_dict(torch.load("./models/bias_model_uni_input_section_2.pth"))

bias_model.eval()

with torch.no_grad():
    combined_X = torch.cat((X_train, X_val, X_test), dim=0).to(device)
    y_pred = bias_model(combined_X).cpu().numpy()
    
outputs_unscaled = y_scaler.inverse_transform(y_pred.reshape(y_pred.shape[0], -1))


# # To store predictions for each trial
# all_predictions = {}

# for trial in range(num_trials):
#     print(f"Starting trial {trial + 1}/{num_trials}")

#     # Initialize model, loss function, and optimizer
#     bias_model = BiasPredictor(input_size=input_size, hidden_size=hidden_size, dropout_rate=dropout_rate).to(device)
#     criterion = nn.MSELoss()
#     optimizer = optim.Adam(bias_model.parameters(), lr=learning_rate)

#     best_val_loss = np.inf
#     best_epoch = 0
#     best_model_state = None  # Store best model state

#     # Training loop
#     for epoch in range(num_epochs):
#         bias_model.train()
#         train_loss = 0.0
#         for X_batch, y_batch in train_loader:
#             X_batch, y_batch = X_batch.to(device), y_batch.to(device)
#             optimizer.zero_grad()
#             outputs = bias_model(X_batch)
#             loss = criterion(outputs, y_batch)
#             loss.backward()
#             optimizer.step()
#             train_loss += loss.item() * X_batch.size(0)

#         train_loss /= len(train_loader.dataset)

#         # Validation loop
#         bias_model.eval()
#         val_loss = 0.0
#         with torch.no_grad():
#             for X_batch, y_batch in val_loader:
#                 X_batch, y_batch = X_batch.to(device), y_batch.to(device)
#                 outputs = bias_model(X_batch)
#                 loss = criterion(outputs, y_batch)
#                 val_loss += loss.item() * X_batch.size(0)

#         val_loss /= len(val_loader.dataset)

#         if val_loss < best_val_loss:
#             best_val_loss = val_loss
#             best_epoch = epoch
#             best_model_state = bias_model.state_dict()  # Save the best model state

#         elif epoch - best_epoch >= patience:
#             print(f"Trial {trial + 1}: Stopping early at epoch {epoch}")
#             break

#         print(f"Trial {trial + 1}, Epoch {epoch}, Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}")

#     # Save the best model from this trial
#     if best_model_state is not None:
#         model_filename = os.path.join(save_dir, f"bias_model_trial_{trial + 1}.pth")
#         torch.save(best_model_state, model_filename)
#         print(f"Saved model for Trial {trial + 1} to {model_filename}")

#         # Load best model and generate predictions
#         bias_model.load_state_dict(best_model_state)
#         bias_model.eval()
        
#         with torch.no_grad():
#             combined_X = torch.cat((X_train, X_val, X_test), dim=0).to(device)
#             y_pred = bias_model(combined_X).cpu().numpy()

#         outputs_unscaled = y_scaler.inverse_transform(y_pred.reshape(y_pred.shape[0], -1))
        
#         # Store predictions for this trial
#         all_predictions[f"trial_{trial + 1}"] = outputs_unscaled

# print("Completed all trials and saved models & predictions!")
# Out:
# C:\Users\ROG\AppData\Local\Temp/ipykernel_31148/231497249.py:34: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   bias_model.load_state_dict(torch.load("./models/bias_model_uni_input_section_2.pth"))

# %%
# concat y values of train test and val 
combined_y = torch.cat((y_train, y_val, y_test), dim=0)
combined_y = combined_y.cpu().numpy()

# %%
# Create empty DataFrame
temp_df = pd.DataFrame()

temp_df["bias_model_uni_prediction"] = outputs_unscaled.flatten()

# %%
temp_df["LSTM_prediction_original"] = new_df["LSTM_Pred"]
temp_df["Target"] = new_df["Target"]
temp_df["New_predictions_uni"] = new_df["LSTM_Pred"] + temp_df["bias_model_uni_prediction"]

# %%
# plot graph of lstm prediction vs new predictions
plt.figure(figsize=(20, 10))
plt.plot(temp_df["New_predictions_uni"].iloc[train_size+val_size:], label='New predicted values', color='blue')
plt.plot(temp_df["LSTM_prediction_original"].iloc[train_size+val_size:], label='Original predicted values', color='red')
plt.plot(temp_df["Target"].iloc[train_size+val_size:], label='True Values', color='green')
plt.xlabel('Time')
plt.ylabel('Value')
plt.title('Actual vs. Predicted Values')
plt.legend()
plt.show()

# %%
original_LSTM_error_percent = np.mean(np.abs(temp_df["Target"].iloc[train_size+val_size:].values - temp_df["LSTM_prediction_original"].iloc[train_size+val_size:].values) / (np.abs(temp_df["Target"].iloc[train_size+val_size:].values) + 1e-8)) * 100
new_LSTM_error_percent = np.mean(np.abs(temp_df["Target"].iloc[train_size+val_size:].values - temp_df["New_predictions_uni"].iloc[train_size+val_size:].values) / (np.abs(temp_df["Target"].iloc[train_size+val_size:].values) + 1e-8)) * 100

print(f"Original LSTM Error Percentage: {original_LSTM_error_percent:.4f}%")
print(f"New LSTM Error Percentage: {new_LSTM_error_percent:.4f}%")
# Out:
# Original LSTM Error Percentage: 4.1651%
# New LSTM Error Percentage: 11.0015%

# %% [markdown]
# <span style="color: yellow; font-size: 40px;">Bias correction model - multi input</span>

# %%
temp_df
# Out:
#       bias_model_uni_prediction  LSTM_prediction_original     Target  \
# 0                      0.915156                 56.224648  54.456104
# 1                      0.832995                 55.993626  53.457096
# 2                      0.881154                 55.830807  52.352238
# 3                      0.814442                 55.628464  53.172611
# 4                      0.834067                 55.400654  51.670799
# ...                         ...                       ...        ...
# 1692                   2.863703                 68.171516  67.947273
# 1693                   3.472999                 67.981392  69.425034
# 1694                   5.743398                 67.806717  69.244072
# 1695                   2.290634                 67.598228  69.892502
# 1696                   2.281421                 67.549828  69.326996
#
#       New_predictions_uni
# 0               57.139805
# 1               56.826622
# 2               56.711960
# 3               56.442905
# 4               56.234722
# ...                   ...
# 1692            71.035217
# 1693            71.454391
# 1694            73.550117
# 1695            69.888863
# 1696            69.831245
#
# [1697 rows x 4 columns]

# %%
X_train_scaled_df = pd.DataFrame(X_train_scaled, columns=["Reconstruction_error"])
X_val_scaled_df = pd.DataFrame(X_val_scaled, columns=["Reconstruction_error"])
X_test_scaled_df = pd.DataFrame(X_test_scaled, columns=["Reconstruction_error"])

combined_X_df = pd.concat([X_train_scaled_df, X_val_scaled_df, X_test_scaled_df], axis=0)
combined_X_df
# Out:
#      Reconstruction_error
# 0                0.689265
# 1                0.290316
# 2                0.526882
# 3               -0.078268
# 4               -0.407371
# ..                    ...
# 251             17.672788
# 252             22.943957
# 253             42.585740
# 254             12.715030
# 255             12.635324
#
# [1697 rows x 1 columns]

# %%
combined_X_df['Reconstruction_error_array'] = np.nan

# Fill the new column with arrays of the past 10 reconstruction errors
# for i in range(len(combined_X_df)):
#     if i >= 9:
#         combined_X_df.at[i, 'reconstruction_error_array'] = combined_X_df['Reconstruction_error'][i-9:i+1].tolist()

reconstruction_error_arrays = []
for i in range(len(combined_X_df)):
    if i >= 9:
        reconstruction_error_arrays.append(combined_X_df['Reconstruction_error'][i-9:i+1].tolist())
    else:
        reconstruction_error_arrays.append(np.nan)  # Keep NaN for the first 9 rows

combined_X_df['Reconstruction_error_array'] = reconstruction_error_arrays

# %%
combined_X_df = combined_X_df.dropna()
combined_X_df = combined_X_df.reset_index(drop=True)
combined_X_df.head()
# Out:
#    Reconstruction_error                         Reconstruction_error_array
# 0              1.079714  [0.6892649190138563, 0.2903163869379717, 0.526...
# 1              0.139054  [0.2903163869379717, 0.526881584424156, -0.078...
# 2              1.626928  [0.526881584424156, -0.07826817559449811, -0.4...
# 3             -0.223699  [-0.07826817559449811, -0.407370580203193, 1.2...
# 4              1.308816  [-0.407370580203193, 1.2778838024890617, 1.087...

# %%
if temp_df.shape[0] != combined_X_df.shape[0]:
    temp_df = temp_df.iloc[sequence_length-1:]
    temp_df = temp_df.reset_index(drop=True)
    print("Shape mismatch, adjusted DataFrame")
    print("temp_df shape:", temp_df.shape)
    print("combined_X_df shape:", combined_X_df.shape)
# Out:
# Shape mismatch, adjusted DataFrame
# temp_df shape: (1688, 4)
# combined_X_df shape: (1688, 2)

# %%
y_train_scaled_df = pd.DataFrame(y_train_scaled, columns=["Bias"])
y_val_scaled_df = pd.DataFrame(y_val_scaled, columns=["Bias"])
y_test_scaled_df = pd.DataFrame(y_test_scaled, columns=["Bias"])

combined_y_df = pd.concat([y_train_scaled_df, y_val_scaled_df, y_test_scaled_df], axis=0)

# drop first 9 rows of y
if combined_y_df.shape[0] != combined_X_df.shape[0]:
    combined_y_df = combined_y_df.iloc[sequence_length-1:]
    combined_y_df = combined_y_df.reset_index(drop=True)
    print("Shape mismatch, adjusted DataFrame")
    print("combined_y_df shape:", combined_y_df.shape)
    print("combined_X_df shape:", combined_X_df.shape)
# Out:
# Shape mismatch, adjusted DataFrame
# combined_y_df shape: (1688, 1)
# combined_X_df shape: (1688, 2)

# %%
X = combined_X_df["Reconstruction_error_array"]
y = combined_y_df['Bias']

# Sequential split
train_size = int(0.7 * len(X))
val_size = int(0.15 * len(X))

X_train_raw = X[:train_size]
y_train_raw = y[:train_size]
X_val_raw = X[train_size:train_size + val_size]
y_val_raw = y[train_size:train_size + val_size]
X_test_raw = X[train_size + val_size:]
y_test_raw = y[train_size + val_size:]

# Convert data to PyTorch tensors
# X_train = torch.tensor(X_train_raw, dtype=torch.float32).unsqueeze(1)
# y_train = torch.tensor(y_train_raw, dtype=torch.float32).unsqueeze(1)
# X_val = torch.tensor(X_val_raw, dtype=torch.float32).unsqueeze(1)
# y_val = torch.tensor(y_val_raw, dtype=torch.float32).unsqueeze(1)
# X_test = torch.tensor(X_test_raw, dtype=torch.float32).unsqueeze(1)
# y_test = torch.tensor(y_test_raw, dtype=torch.float32).unsqueeze(1)
X_train = torch.tensor(np.stack(X_train_raw.values), dtype=torch.float32)
y_train = torch.tensor(y_train_raw.values, dtype=torch.float32).unsqueeze(1)
X_val = torch.tensor(np.stack(X_val_raw.values), dtype=torch.float32)
y_val = torch.tensor(y_val_raw.values, dtype=torch.float32).unsqueeze(1)
X_test = torch.tensor(np.stack(X_test_raw.values), dtype=torch.float32)
y_test = torch.tensor(y_test_raw.values, dtype=torch.float32).unsqueeze(1)

# Print sizes
print(f"Train: {len(X_train)}, Val: {len(X_val)}, Test: {len(X_test)}")
# Out:
# Train: 1181, Val: 253, Test: 254

# %%
# Define bias predictor model
class BiasPredictor(nn.Module):
    def __init__(self, input_size, hidden_size, dropout_rate, use_bn):
        super(BiasPredictor, self).__init__()

        hidden_size2 = hidden_size // 2
        hidden_size3 = hidden_size2 // 2

        self.use_bn = use_bn

        self.fc1 = nn.Linear(input_size, hidden_size)
        self.bn1 = nn.BatchNorm1d(hidden_size) if use_bn else nn.Identity()
        self.dropout1 = nn.Dropout(dropout_rate)

        self.fc2 = nn.Linear(hidden_size, hidden_size2)
        self.bn2 = nn.BatchNorm1d(hidden_size2) if use_bn else nn.Identity()
        self.dropout2 = nn.Dropout(dropout_rate)

        self.fc3 = nn.Linear(hidden_size2, hidden_size3)
        self.bn3 = nn.BatchNorm1d(hidden_size3) if use_bn else nn.Identity()
        self.dropout3 = nn.Dropout(dropout_rate)

        self.fc4 = nn.Linear(hidden_size3, 1)

    def forward(self, x):
        x = F.leaky_relu(self.bn1(self.fc1(x)))
        x = self.dropout1(x)

        x = F.leaky_relu(self.bn2(self.fc2(x)))
        x = self.dropout2(x)

        x = F.leaky_relu(self.bn3(self.fc3(x)))
        x = self.dropout3(x)

        return self.fc4(x)

# %%
# Training function
def train_bias_predictor(model, train_loader, val_loader, num_epochs, patience, learning_rate):
    model.to(device)
    criterion = nn.MSELoss()
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)

    best_val_loss = np.inf
    best_epoch = 0
    history = {"train_loss": [], "val_loss": []}

    for epoch in range(num_epochs):
        ###### Training Phase ######
        model.train()
        train_loss = 0.0

        for X_batch, y_batch in train_loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)

            optimizer.zero_grad()
            outputs = model(X_batch)
            loss = criterion(outputs, y_batch)
            loss.backward()
            optimizer.step()

            train_loss += loss.item() * X_batch.size(0)

        train_loss /= len(train_loader.dataset)
        history["train_loss"].append(train_loss)

        ###### Validation Phase ######
        model.eval()
        val_loss = 0.0

        with torch.no_grad():
            for X_batch, y_batch in val_loader:
                X_batch, y_batch = X_batch.to(device), y_batch.to(device)
                outputs = model(X_batch)
                loss = criterion(outputs, y_batch)
                val_loss += loss.item() * X_batch.size(0)

        val_loss /= len(val_loader.dataset)
        history["val_loss"].append(val_loss)

        # Print Progress
        print(f"📉 Epoch {epoch+1}/{num_epochs} - Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}")

        # Early Stopping Check
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            best_epoch = epoch
            best_model = model  # Store best model
        elif epoch - best_epoch >= patience:
            print(f"⏹️ Early stopping triggered at epoch {epoch+1}. Best epoch: {best_epoch+1}, Best Val Loss: {best_val_loss:.4f}")
            break

    return best_model, history

# %%
# # Create dataloader
# train_dataset = TensorDataset(X_train, y_train)
# val_dataset = TensorDataset(X_val, y_val)
# test_dataset = TensorDataset(X_test, y_test)
# train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
# val_loader = DataLoader(val_dataset, batch_size=16, shuffle=False)
# test_loader = DataLoader(test_dataset, batch_size=16, shuffle=False)

# Hyperparameters
input_size = 10
hidden_size = 16
dropout_rate = 0.0
use_bn = False
learning_rate = 0.0001
num_epochs = 500
patience = 20

arr_model = BiasPredictor(input_size=input_size, hidden_size=hidden_size, dropout_rate=dropout_rate, use_bn=use_bn).to(device)

arr_model.load_state_dict(torch.load("./models/bias_model_arr_input_section_2.pth"))
# Out:
# C:\Users\ROG\AppData\Local\Temp/ipykernel_31148/3195634940.py:20: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   arr_model.load_state_dict(torch.load("./models/bias_model_arr_input_section_2.pth"))
# <All keys matched successfully>

# %%
arr_model.eval()

with torch.no_grad():
    X_tensor = torch.tensor(X, dtype=torch.float32).to(device)
    y_pred_arr = arr_model(X_tensor).cpu().numpy()

outputs_arr_unscaled = y_scaler.inverse_transform(y_pred_arr.reshape(y_pred_arr.shape[0], -1))

# Add predictions into df
temp_df["bias_model_arr_prediction"] = outputs_arr_unscaled.flatten()
temp_df['New_predictions_arr'] = temp_df["LSTM_prediction_original"] + temp_df["bias_model_arr_prediction"]

# %%
temp_df
# Out:
#       bias_model_uni_prediction  LSTM_prediction_original     Target  \
# 0                      0.982708                 54.226692  57.261292
# 1                      0.812583                 54.316082  58.399250
# 2                      1.027725                 54.464626  58.644016
# 3                      0.821749                 54.754524  59.656273
# 4                      1.004774                 55.168800  59.226238
# ...                         ...                       ...        ...
# 1683                   2.863703                 68.171516  67.947273
# 1684                   3.472999                 67.981392  69.425034
# 1685                   5.743398                 67.806717  69.244072
# 1686                   2.290634                 67.598228  69.892502
# 1687                   2.281421                 67.549828  69.326996
#
#       New_predictions_uni  bias_model_arr_prediction  New_predictions_arr
# 0               55.209400                   0.868989            55.095680
# 1               55.128666                   0.876597            55.192680
# 2               55.492352                   0.866084            55.330711
# 3               55.576275                   0.883312            55.637836
# 4               56.173573                   0.882874            56.051674
# ...                   ...                        ...                  ...
# 1683            71.035217                   0.954866            69.126381
# 1684            71.454391                   0.954833            68.936226
# 1685            73.550117                   0.948759            68.755478
# 1686            69.888863                   1.360028            68.958260
# 1687            69.831245                   0.954477            68.504303
#
# [1688 rows x 6 columns]

# %%
# plot line graph of bias_model_arr_prediction vs original
plt.figure(figsize=(20, 10))
plt.plot(temp_df["New_predictions_arr"].iloc[train_size+val_size:], label='Array predictions', color='blue')
plt.plot(temp_df["New_predictions_uni"].iloc[train_size+val_size:], label='Single input predictions', color='red')
plt.plot(temp_df["Target"].iloc[train_size+val_size:], label='True Values', color='green')
plt.xlabel('Time')
plt.ylabel('Value')
plt.title('Actual vs. Predicted Values')
plt.legend()
plt.show()

# %%
# get prediction error percentages
original_error_percent = np.mean(np.abs(temp_df["Target"].iloc[train_size+val_size:].values - temp_df["LSTM_prediction_original"].iloc[train_size+val_size:].values) / (np.abs(temp_df["Target"].iloc[train_size+val_size:].values) + 1e-8)) * 100
uni_input_error_percent = np.mean(np.abs(temp_df["Target"].iloc[train_size+val_size:].values - temp_df["New_predictions_uni"].iloc[train_size+val_size:].values) / (np.abs(temp_df["Target"].iloc[train_size+val_size:].values) + 1e-8)) * 100
arr_input_error_percent = np.mean(np.abs(temp_df["Target"].iloc[train_size+val_size:].values - temp_df["New_predictions_arr"].iloc[train_size+val_size:].values) / (np.abs(temp_df["Target"].iloc[train_size+val_size:].values) + 1e-8)) * 100

print("Percentages over test set\n")
print(f"Original LSTM Error Percentage: {original_error_percent:.4f}%")
print(f"New LSTM Error Percentage (Single Input): {uni_input_error_percent:.4f}%")
print(f"New LSTM Error Percentage (Array Input): {arr_input_error_percent:.4f}%")
# Out:
# Percentages over test set
#
# Original LSTM Error Percentage: 4.1752%
# New LSTM Error Percentage (Single Input): 11.0498%
# New LSTM Error Percentage (Array Input): 4.3692%

# %%
# plot graph over entire dataset
plt.figure(figsize=(20, 10))
plt.plot(temp_df["New_predictions_arr"], label='Array predictions', color='blue')
plt.plot(temp_df["New_predictions_uni"], label='Single input predictions', color='red')
plt.plot(temp_df["Target"], label='True Values', color='green')
plt.xlabel('Time')
plt.ylabel('Value')
plt.title('Actual vs. Predicted Values')
plt.legend()
plt.show()

# %%
# get prediction error percentages
original_error_percent = np.mean(np.abs(temp_df["Target"].values - temp_df["LSTM_prediction_original"].values) / (np.abs(temp_df["Target"].values) + 1e-8)) * 100
uni_input_error_percent = np.mean(np.abs(temp_df["Target"].values - temp_df["New_predictions_uni"].values) / (np.abs(temp_df["Target"].values) + 1e-8)) * 100
arr_input_error_percent = np.mean(np.abs(temp_df["Target"].values - temp_df["New_predictions_arr"].values) / (np.abs(temp_df["Target"].values) + 1e-8)) * 100

print("Percentages over entire set\n")
print(f"Original LSTM Error Percentage: {original_error_percent:.4f}%")
print(f"New LSTM Error Percentage (Single Input): {uni_input_error_percent:.4f}%")
print(f"New LSTM Error Percentage (Array Input): {arr_input_error_percent:.4f}%")
# Out:
# Percentages over entire set
#
# Original LSTM Error Percentage: 2.0790%
# New LSTM Error Percentage (Single Input): 2.9527%
# New LSTM Error Percentage (Array Input): 1.8873%

# %% [markdown]
# <span style="color: yellow; font-size: 40px;">Bias correction model - multi input with SHAP</span>

# %%
import shap

# Define a custom wrapper for the PyTorch model
class ModelWrapper:
    def __init__(self, model):
        self.model = model

    def __call__(self, data):
        self.model.eval()
        with torch.no_grad():
            data = torch.tensor(data, dtype=torch.float32).to(device)
            return self.model(data).cpu().numpy()

arr_model.eval()

# Create SHAP explainer
wrapped_model = ModelWrapper(arr_model)
explainer = shap.Explainer(wrapped_model, X_test.cpu().numpy())



print("Running SHAP explainer...")
shap_values = explainer(X_test.cpu().numpy())
# Convert to numpy
shap_values_array = shap_values.values

# Average SHAP values across all test samples
feature_importance = np.mean(np.abs(shap_values_array), axis=0)

# Create labels for the features
num_features = len(feature_importance)
feature_labels = [f"Day {i+1}" for i in range(num_features)]
# Out:
# Running SHAP explainer...

# %%
# Plot feature importance
plt.figure(figsize=(10, 5))
plt.barh(feature_labels, feature_importance)
plt.xlabel('Average SHAP Value')
plt.title('Feature Importance')
plt.show()

# Display results
day = 1
for i in feature_importance:
    print(f"Day {day}: {i:.4f}")
    day += 1
# Out:
# Day 1: 0.0552
# Day 2: 0.1377
# Day 3: 0.1120
# Day 4: 0.1265
# Day 5: 0.0779
# Day 6: 0.1493
# Day 7: 0.1113
# Day 8: 0.1906
# Day 9: 0.2723
# Day 10: 0.1256

# %%
# Normalize feature importance such that sum = 1
normalized_importance = feature_importance / np.sum(feature_importance)

# Plot graph
plt.figure(figsize=(10, 5))
plt.barh(feature_labels, normalized_importance)
plt.xlabel('Normalized Importance')
plt.title('Feature Importance (Normalized)')
plt.show()

day = 1
for i in normalized_importance:
    print(f"Day {day}: {i:.4f}")
    day += 1
# Out:
# Day 1: 0.0407
# Day 2: 0.1013
# Day 3: 0.0825
# Day 4: 0.0931
# Day 5: 0.0573
# Day 6: 0.1099
# Day 7: 0.0819
# Day 8: 0.1403
# Day 9: 0.2005
# Day 10: 0.0925

# %%
sum = 0
for i in normalized_importance:
    sum += i
    
print(f"Total: {sum:.4f}")
# Out:
# Total: 1.0000

# %%
weighted = 0

if weighted == 0:
    # Multiply X by weights
    X_weighted = X.apply(lambda arr: arr * normalized_importance)
    weighted = 1
    # Print the first few elements to verify
    X_weighted.head()

# %%
X = X_weighted
y = combined_y_df['Bias']

# Sequential split
train_size = int(0.7 * len(X))
val_size = int(0.15 * len(X))

X_train_raw = X[:train_size]
y_train_raw = y[:train_size]
X_val_raw = X[train_size:train_size + val_size]
y_val_raw = y[train_size:train_size + val_size]
X_test_raw = X[train_size + val_size:]
y_test_raw = y[train_size + val_size:]

# Convert data to PyTorch tensors
# X_train = torch.tensor(X_train_raw, dtype=torch.float32).unsqueeze(1)
# y_train = torch.tensor(y_train_raw, dtype=torch.float32).unsqueeze(1)
# X_val = torch.tensor(X_val_raw, dtype=torch.float32).unsqueeze(1)
# y_val = torch.tensor(y_val_raw, dtype=torch.float32).unsqueeze(1)
# X_test = torch.tensor(X_test_raw, dtype=torch.float32).unsqueeze(1)
# y_test = torch.tensor(y_test_raw, dtype=torch.float32).unsqueeze(1)
X_train = torch.tensor(np.stack(X_train_raw.values), dtype=torch.float32)
y_train = torch.tensor(y_train_raw.values, dtype=torch.float32).unsqueeze(1)
X_val = torch.tensor(np.stack(X_val_raw.values), dtype=torch.float32)
y_val = torch.tensor(y_val_raw.values, dtype=torch.float32).unsqueeze(1)
X_test = torch.tensor(np.stack(X_test_raw.values), dtype=torch.float32)
y_test = torch.tensor(y_test_raw.values, dtype=torch.float32).unsqueeze(1)

# Print sizes
print(f"Train: {len(X_train)}, Val: {len(X_val)}, Test: {len(X_test)}")
# Out:
# Train: 1181, Val: 253, Test: 254

# %%
import itertools

# Create dataloader
train_dataset = TensorDataset(X_train, y_train)
val_dataset = TensorDataset(X_val, y_val)
test_dataset = TensorDataset(X_test, y_test)
train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=16, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=16, shuffle=False)

# # Hyperparameters
# input_size = 10
# hidden_size = 64
# dropout_rate = 0.2
# use_bn = True
# learning_rate = 0.0005
# num_epochs = 500
# patience = 20

# model = BiasPredictor(input_size=input_size, hidden_size=hidden_size, dropout_rate=dropout_rate, use_bn=use_bn).to(device)

# best_model, history = train_bias_predictor(model, train_loader, val_loader, num_epochs, patience, learning_rate)

# Define hyperparameter search space
# param_grid = {
#     "hidden_size": [32, 64, 128],
#     "dropout_rate": [0.0, 0.1, 0.2, 0.3],
#     "use_bn": [True, False],
#     "learning_rate": [0.001, 0.0005, 0.0001],
#     "batch_size" : [8,16,32]
# }

# # Number of runs per combination
# num_repeats = 5

# # Store results
# results = []

# # Define device
# device = "cuda" if torch.cuda.is_available() else "cpu"

# total_combinations = np.prod([len(v) for v in param_grid.values()])
# count = 0
# # Grid search loop
# for params in itertools.product(*param_grid.values()):
#     hidden_size, dropout_rate, use_bn, learning_rate, batch_size = params
#     param_key = f"HS={hidden_size}, DR={dropout_rate}, BN={use_bn}, LR={learning_rate}, BS={batch_size}"

#     print(f"\n🔍 Testing: {param_key}")
#     print(f"{count} / {total_combinations} combinations\n")
#     count += 1

#     # Store metrics across runs
#     avg_train_loss, avg_val_loss, avg_mae, avg_mse, avg_percent_error = 0, 0, 0, 0, 0

#     for run in range(num_repeats):
#         print(f"⚡ Run {run+1}/{num_repeats}")

#         train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
#         val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

#         # Initialize model
#         model = BiasPredictor(input_size=10, hidden_size=hidden_size, dropout_rate=dropout_rate, use_bn=use_bn).to(device)

#         # Train model
#         best_model, history = train_bias_predictor(model, train_loader, val_loader, num_epochs=500, patience=20, learning_rate=learning_rate)

#         # Evaluate performance
#         with torch.no_grad():
#             X_tensor = torch.tensor(X, dtype=torch.float32).to(device)
#             y_pred_arr = best_model(X_tensor).cpu().numpy()

#         # Unscale predictions
#         outputs_arr_unscaled = y_scaler.inverse_transform(y_pred_arr.reshape(y_pred_arr.shape[0], -1))

#         # Store predictions
#         temp_df["bias_model_arr_prediction"] = outputs_arr_unscaled.flatten()
#         temp_df["New_predictions_arr"] = temp_df["LSTM_prediction_original"] + temp_df["bias_model_arr_prediction"]

#         # Compute error metrics
#         target_vals = temp_df["Target"].iloc[train_size+val_size:].values
#         pred_vals = temp_df["New_predictions_arr"].iloc[train_size+val_size:].values

#         mae = np.mean(np.abs(target_vals - pred_vals))
#         mse = np.mean((target_vals - pred_vals) ** 2)
#         percent_error = np.mean(np.abs(target_vals - pred_vals) / (np.abs(target_vals) + 1e-8)) * 100

#         # Accumulate metrics
#         avg_train_loss += history["train_loss"][-1] / num_repeats
#         avg_val_loss += history["val_loss"][-1] / num_repeats
#         avg_mae += mae / num_repeats
#         avg_mse += mse / num_repeats
#         avg_percent_error += percent_error / num_repeats

#     # Store results
#     results.append({
#         "hidden_size": hidden_size,
#         "dropout_rate": dropout_rate,
#         "use_bn": use_bn,
#         "learning_rate": learning_rate,
#         "batch_size": batch_size,
#         "train_loss": avg_train_loss,
#         "val_loss": avg_val_loss,
#         "MAE": avg_mae,
#         "MSE": avg_mse,
#         "Percent Error": avg_percent_error
#     })

# # Convert results to DataFrame and sort by best validation loss
# results_df = pd.DataFrame(results)
# results_df = results_df.sort_values(by="Percent Error", ascending=True)

# # Print best hyperparameters
# best_params = results_df.iloc[0]
# print("\n🏆 Best Hyperparameters Found:")
# print(best_params)

# # Save results to CSV
# results_df.to_csv("grid_search_results.csv", index=False)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
import os

# Directory to save models
save_dir = "saved_models"
os.makedirs(save_dir, exist_ok=True)

# Number of runs
num_runs = 10

# Store results
all_predictions = []
error_percentages = []

# Run training 10 times
for run in range(num_runs):
    print(f"⚡ Run {run+1}/{num_runs}")

    train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)
    test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

    # Initialize model
    model = BiasPredictor(input_size=10, hidden_size=16, dropout_rate=0.3, use_bn=False).to(device)

    # Train model
    best_model, history = train_bias_predictor(model, train_loader, val_loader, num_epochs=500, patience=20, learning_rate=0.0001)

    # Save trained model
    model_path = os.path.join(save_dir, f"bias_predictor_run_{run+1}.pth")
    torch.save(best_model.state_dict(), model_path)
    print(f"✅ Model saved at: {model_path}")

    # Evaluate model
    best_model.eval()
    with torch.no_grad():
        X_tensor = torch.tensor(X, dtype=torch.float32).to(device)
        y_pred_arr = best_model(X_tensor).cpu().numpy()

    # Unscale predictions
    outputs_arr_unscaled = y_scaler.inverse_transform(y_pred_arr.reshape(y_pred_arr.shape[0], -1))

    # Store predictions
    temp_df[f"bias_model_arr_prediction_SHAP_run_{run+1}"] = outputs_arr_unscaled.flatten()
    temp_df[f"New_predictions_arr_SHAP_run_{run+1}"] = temp_df["LSTM_prediction_original"] + temp_df[f"bias_model_arr_prediction_SHAP_run_{run+1}"]

    # Compute error percentage for this run
    target_vals = temp_df["Target"].iloc[train_size+val_size:].values
    pred_vals = temp_df[f"New_predictions_arr_SHAP_run_{run+1}"].iloc[train_size+val_size:].values

    error_percent = np.mean(np.abs(target_vals - pred_vals) / (np.abs(target_vals) + 1e-8)) * 100
    error_percentages.append(error_percent)

    # Store predictions
    all_predictions.append(pred_vals)
# Out:
# ⚡ Run 1/10
# 📉 Epoch 1/500 - Train Loss: 0.6459, Val Loss: 2.5884
# 📉 Epoch 2/500 - Train Loss: 0.6389, Val Loss: 2.5728
# 📉 Epoch 3/500 - Train Loss: 0.6385, Val Loss: 2.5595
# 📉 Epoch 4/500 - Train Loss: 0.6326, Val Loss: 2.5450
# 📉 Epoch 5/500 - Train Loss: 0.6288, Val Loss: 2.5310
# 📉 Epoch 6/500 - Train Loss: 0.6260, Val Loss: 2.5190
# 📉 Epoch 7/500 - Train Loss: 0.6250, Val Loss: 2.5055
# 📉 Epoch 8/500 - Train Loss: 0.6224, Val Loss: 2.4949
# 📉 Epoch 9/500 - Train Loss: 0.6195, Val Loss: 2.4853
# 📉 Epoch 10/500 - Train Loss: 0.6168, Val Loss: 2.4769
# 📉 Epoch 11/500 - Train Loss: 0.6149, Val Loss: 2.4697
# 📉 Epoch 12/500 - Train Loss: 0.6132, Val Loss: 2.4633
# 📉 Epoch 13/500 - Train Loss: 0.6132, Val Loss: 2.4577
# 📉 Epoch 14/500 - Train Loss: 0.6106, Val Loss: 2.4530
# 📉 Epoch 15/500 - Train Loss: 0.6089, Val Loss: 2.4482
# 📉 Epoch 16/500 - Train Loss: 0.6076, Val Loss: 2.4440
# 📉 Epoch 17/500 - Train Loss: 0.6054, Val Loss: 2.4401
# 📉 Epoch 18/500 - Train Loss: 0.6050, Val Loss: 2.4361
# 📉 Epoch 19/500 - Train Loss: 0.6046, Val Loss: 2.4318
# 📉 Epoch 20/500 - Train Loss: 0.6024, Val Loss: 2.4282
# 📉 Epoch 21/500 - Train Loss: 0.6020, Val Loss: 2.4242
# 📉 Epoch 22/500 - Train Loss: 0.6010, Val Loss: 2.4205
# 📉 Epoch 23/500 - Train Loss: 0.5995, Val Loss: 2.4169
# 📉 Epoch 24/500 - Train Loss: 0.5996, Val Loss: 2.4135
# 📉 Epoch 25/500 - Train Loss: 0.5979, Val Loss: 2.4101
# 📉 Epoch 26/500 - Train Loss: 0.5974, Val Loss: 2.4070
# 📉 Epoch 27/500 - Train Loss: 0.5962, Val Loss: 2.4036
# 📉 Epoch 28/500 - Train Loss: 0.5953, Val Loss: 2.4002
# 📉 Epoch 29/500 - Train Loss: 0.5945, Val Loss: 2.3969
# 📉 Epoch 30/500 - Train Loss: 0.5938, Val Loss: 2.3933
# 📉 Epoch 31/500 - Train Loss: 0.5924, Val Loss: 2.3906
# 📉 Epoch 32/500 - Train Loss: 0.5928, Val Loss: 2.3871
# 📉 Epoch 33/500 - Train Loss: 0.5918, Val Loss: 2.3840
# 📉 Epoch 34/500 - Train Loss: 0.5908, Val Loss: 2.3813
# 📉 Epoch 35/500 - Train Loss: 0.5903, Val Loss: 2.3782
# 📉 Epoch 36/500 - Train Loss: 0.5894, Val Loss: 2.3751
# 📉 Epoch 37/500 - Train Loss: 0.5884, Val Loss: 2.3723
# 📉 Epoch 38/500 - Train Loss: 0.5880, Val Loss: 2.3693
# 📉 Epoch 39/500 - Train Loss: 0.5872, Val Loss: 2.3669
# 📉 Epoch 40/500 - Train Loss: 0.5876, Val Loss: 2.3636
# 📉 Epoch 41/500 - Train Loss: 0.5864, Val Loss: 2.3607
# 📉 Epoch 42/500 - Train Loss: 0.5851, Val Loss: 2.3581
# 📉 Epoch 43/500 - Train Loss: 0.5856, Val Loss: 2.3552
# 📉 Epoch 44/500 - Train Loss: 0.5846, Val Loss: 2.3527
# 📉 Epoch 45/500 - Train Loss: 0.5845, Val Loss: 2.3503
# 📉 Epoch 46/500 - Train Loss: 0.5835, Val Loss: 2.3477
# 📉 Epoch 47/500 - Train Loss: 0.5834, Val Loss: 2.3450
# 📉 Epoch 48/500 - Train Loss: 0.5829, Val Loss: 2.3427
# 📉 Epoch 49/500 - Train Loss: 0.5824, Val Loss: 2.3403
# 📉 Epoch 50/500 - Train Loss: 0.5819, Val Loss: 2.3375
# 📉 Epoch 51/500 - Train Loss: 0.5814, Val Loss: 2.3355
# 📉 Epoch 52/500 - Train Loss: 0.5813, Val Loss: 2.3333
# 📉 Epoch 53/500 - Train Loss: 0.5806, Val Loss: 2.3314
# 📉 Epoch 54/500 - Train Loss: 0.5799, Val Loss: 2.3290
# 📉 Epoch 55/500 - Train Loss: 0.5800, Val Loss: 2.3271
# 📉 Epoch 56/500 - Train Loss: 0.5792, Val Loss: 2.3254
# 📉 Epoch 57/500 - Train Loss: 0.5789, Val Loss: 2.3235
# 📉 Epoch 58/500 - Train Loss: 0.5789, Val Loss: 2.3214
# 📉 Epoch 59/500 - Train Loss: 0.5781, Val Loss: 2.3196
# 📉 Epoch 60/500 - Train Loss: 0.5777, Val Loss: 2.3181
# 📉 Epoch 61/500 - Train Loss: 0.5777, Val Loss: 2.3160
# 📉 Epoch 62/500 - Train Loss: 0.5776, Val Loss: 2.3137
# 📉 Epoch 63/500 - Train Loss: 0.5770, Val Loss: 2.3116
# 📉 Epoch 64/500 - Train Loss: 0.5768, Val Loss: 2.3097
# 📉 Epoch 65/500 - Train Loss: 0.5766, Val Loss: 2.3079
# 📉 Epoch 66/500 - Train Loss: 0.5764, Val Loss: 2.3064
# 📉 Epoch 67/500 - Train Loss: 0.5762, Val Loss: 2.3049
# 📉 Epoch 68/500 - Train Loss: 0.5756, Val Loss: 2.3032
# 📉 Epoch 69/500 - Train Loss: 0.5762, Val Loss: 2.3012
# 📉 Epoch 70/500 - Train Loss: 0.5756, Val Loss: 2.2993
# 📉 Epoch 71/500 - Train Loss: 0.5757, Val Loss: 2.2976
# 📉 Epoch 72/500 - Train Loss: 0.5750, Val Loss: 2.2958
# 📉 Epoch 73/500 - Train Loss: 0.5747, Val Loss: 2.2949
# 📉 Epoch 74/500 - Train Loss: 0.5749, Val Loss: 2.2934
# 📉 Epoch 75/500 - Train Loss: 0.5748, Val Loss: 2.2920
# 📉 Epoch 76/500 - Train Loss: 0.5744, Val Loss: 2.2907
# 📉 Epoch 77/500 - Train Loss: 0.5743, Val Loss: 2.2898
# 📉 Epoch 78/500 - Train Loss: 0.5740, Val Loss: 2.2886
# 📉 Epoch 79/500 - Train Loss: 0.5736, Val Loss: 2.2876
# 📉 Epoch 80/500 - Train Loss: 0.5738, Val Loss: 2.2864
# 📉 Epoch 81/500 - Train Loss: 0.5734, Val Loss: 2.2860
# 📉 Epoch 82/500 - Train Loss: 0.5732, Val Loss: 2.2842
# 📉 Epoch 83/500 - Train Loss: 0.5733, Val Loss: 2.2823
# 📉 Epoch 84/500 - Train Loss: 0.5730, Val Loss: 2.2823
# 📉 Epoch 85/500 - Train Loss: 0.5733, Val Loss: 2.2830
# 📉 Epoch 86/500 - Train Loss: 0.5732, Val Loss: 2.2829
# 📉 Epoch 87/500 - Train Loss: 0.5727, Val Loss: 2.2824
# 📉 Epoch 88/500 - Train Loss: 0.5727, Val Loss: 2.2828
# 📉 Epoch 89/500 - Train Loss: 0.5729, Val Loss: 2.2821
# 📉 Epoch 90/500 - Train Loss: 0.5726, Val Loss: 2.2808
# 📉 Epoch 91/500 - Train Loss: 0.5726, Val Loss: 2.2824
# 📉 Epoch 92/500 - Train Loss: 0.5722, Val Loss: 2.2817
# 📉 Epoch 93/500 - Train Loss: 0.5723, Val Loss: 2.2812
# 📉 Epoch 94/500 - Train Loss: 0.5723, Val Loss: 2.2802
# 📉 Epoch 95/500 - Train Loss: 0.5722, Val Loss: 2.2799
# 📉 Epoch 96/500 - Train Loss: 0.5720, Val Loss: 2.2800
# 📉 Epoch 97/500 - Train Loss: 0.5716, Val Loss: 2.2808
# 📉 Epoch 98/500 - Train Loss: 0.5713, Val Loss: 2.2820
# 📉 Epoch 99/500 - Train Loss: 0.5719, Val Loss: 2.2853
# 📉 Epoch 100/500 - Train Loss: 0.5714, Val Loss: 2.2894
# 📉 Epoch 101/500 - Train Loss: 0.5716, Val Loss: 2.2915
# 📉 Epoch 102/500 - Train Loss: 0.5717, Val Loss: 2.2918
# 📉 Epoch 103/500 - Train Loss: 0.5718, Val Loss: 2.2945
# 📉 Epoch 104/500 - Train Loss: 0.5722, Val Loss: 2.2979
# 📉 Epoch 105/500 - Train Loss: 0.5713, Val Loss: 2.3024
# 📉 Epoch 106/500 - Train Loss: 0.5716, Val Loss: 2.3033
# 📉 Epoch 107/500 - Train Loss: 0.5716, Val Loss: 2.3011
# 📉 Epoch 108/500 - Train Loss: 0.5712, Val Loss: 2.3022
# 📉 Epoch 109/500 - Train Loss: 0.5713, Val Loss: 2.3044
# 📉 Epoch 110/500 - Train Loss: 0.5710, Val Loss: 2.3109
# 📉 Epoch 111/500 - Train Loss: 0.5711, Val Loss: 2.3111
# 📉 Epoch 112/500 - Train Loss: 0.5712, Val Loss: 2.3144
# 📉 Epoch 113/500 - Train Loss: 0.5710, Val Loss: 2.3152
# 📉 Epoch 114/500 - Train Loss: 0.5712, Val Loss: 2.3127
# 📉 Epoch 115/500 - Train Loss: 0.5708, Val Loss: 2.3130
# ⏹️ Early stopping triggered at epoch 115. Best epoch: 95, Best Val Loss: 2.2799
# ✅ Model saved at: saved_models\bias_predictor_run_1.pth
# ⚡ Run 2/10
# 📉 Epoch 1/500 - Train Loss: 0.6177, Val Loss: 2.0844
# Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\torch\csrc\utils\tensor_new.cpp:281.)
# 📉 Epoch 2/500 - Train Loss: 0.6108, Val Loss: 2.0888
# 📉 Epoch 3/500 - Train Loss: 0.6050, Val Loss: 2.0929
# 📉 Epoch 4/500 - Train Loss: 0.6095, Val Loss: 2.0974
# 📉 Epoch 5/500 - Train Loss: 0.6058, Val Loss: 2.1018
# 📉 Epoch 6/500 - Train Loss: 0.6021, Val Loss: 2.1062
# 📉 Epoch 7/500 - Train Loss: 0.5979, Val Loss: 2.1102
# 📉 Epoch 8/500 - Train Loss: 0.5999, Val Loss: 2.1152
# 📉 Epoch 9/500 - Train Loss: 0.5946, Val Loss: 2.1197
# 📉 Epoch 10/500 - Train Loss: 0.5938, Val Loss: 2.1243
# 📉 Epoch 11/500 - Train Loss: 0.5905, Val Loss: 2.1289
# 📉 Epoch 12/500 - Train Loss: 0.5928, Val Loss: 2.1335
# 📉 Epoch 13/500 - Train Loss: 0.5865, Val Loss: 2.1379
# 📉 Epoch 14/500 - Train Loss: 0.5865, Val Loss: 2.1424
# 📉 Epoch 15/500 - Train Loss: 0.5873, Val Loss: 2.1471
# 📉 Epoch 16/500 - Train Loss: 0.5829, Val Loss: 2.1510
# 📉 Epoch 17/500 - Train Loss: 0.5865, Val Loss: 2.1556
# 📉 Epoch 18/500 - Train Loss: 0.5864, Val Loss: 2.1595
# 📉 Epoch 19/500 - Train Loss: 0.5824, Val Loss: 2.1641
# 📉 Epoch 20/500 - Train Loss: 0.5827, Val Loss: 2.1679
# 📉 Epoch 21/500 - Train Loss: 0.5805, Val Loss: 2.1712
# ⏹️ Early stopping triggered at epoch 21. Best epoch: 1, Best Val Loss: 2.0844
# ✅ Model saved at: saved_models\bias_predictor_run_2.pth
# ⚡ Run 3/10
# 📉 Epoch 1/500 - Train Loss: 0.5781, Val Loss: 2.3596
# 📉 Epoch 2/500 - Train Loss: 0.5739, Val Loss: 2.3558
# 📉 Epoch 3/500 - Train Loss: 0.5791, Val Loss: 2.3520
# 📉 Epoch 4/500 - Train Loss: 0.5749, Val Loss: 2.3496
# 📉 Epoch 5/500 - Train Loss: 0.5762, Val Loss: 2.3467
# 📉 Epoch 6/500 - Train Loss: 0.5775, Val Loss: 2.3435
# 📉 Epoch 7/500 - Train Loss: 0.5750, Val Loss: 2.3411
# 📉 Epoch 8/500 - Train Loss: 0.5766, Val Loss: 2.3398
# 📉 Epoch 9/500 - Train Loss: 0.5742, Val Loss: 2.3371
# 📉 Epoch 10/500 - Train Loss: 0.5754, Val Loss: 2.3352
# 📉 Epoch 11/500 - Train Loss: 0.5733, Val Loss: 2.3342
# 📉 Epoch 12/500 - Train Loss: 0.5758, Val Loss: 2.3320
# 📉 Epoch 13/500 - Train Loss: 0.5736, Val Loss: 2.3308
# 📉 Epoch 14/500 - Train Loss: 0.5724, Val Loss: 2.3288
# 📉 Epoch 15/500 - Train Loss: 0.5704, Val Loss: 2.3279
# 📉 Epoch 16/500 - Train Loss: 0.5734, Val Loss: 2.3263
# 📉 Epoch 17/500 - Train Loss: 0.5748, Val Loss: 2.3246
# 📉 Epoch 18/500 - Train Loss: 0.5720, Val Loss: 2.3242
# 📉 Epoch 19/500 - Train Loss: 0.5716, Val Loss: 2.3232
# 📉 Epoch 20/500 - Train Loss: 0.5766, Val Loss: 2.3228
# 📉 Epoch 21/500 - Train Loss: 0.5706, Val Loss: 2.3218
# 📉 Epoch 22/500 - Train Loss: 0.5746, Val Loss: 2.3211
# 📉 Epoch 23/500 - Train Loss: 0.5716, Val Loss: 2.3214
# 📉 Epoch 24/500 - Train Loss: 0.5753, Val Loss: 2.3206
# 📉 Epoch 25/500 - Train Loss: 0.5717, Val Loss: 2.3199
# 📉 Epoch 26/500 - Train Loss: 0.5699, Val Loss: 2.3197
# 📉 Epoch 27/500 - Train Loss: 0.5723, Val Loss: 2.3197
# 📉 Epoch 28/500 - Train Loss: 0.5705, Val Loss: 2.3191
# 📉 Epoch 29/500 - Train Loss: 0.5759, Val Loss: 2.3186
# 📉 Epoch 30/500 - Train Loss: 0.5738, Val Loss: 2.3186
# 📉 Epoch 31/500 - Train Loss: 0.5739, Val Loss: 2.3182
# 📉 Epoch 32/500 - Train Loss: 0.5725, Val Loss: 2.3171
# 📉 Epoch 33/500 - Train Loss: 0.5719, Val Loss: 2.3172
# 📉 Epoch 34/500 - Train Loss: 0.5715, Val Loss: 2.3161
# 📉 Epoch 35/500 - Train Loss: 0.5725, Val Loss: 2.3165
# 📉 Epoch 36/500 - Train Loss: 0.5745, Val Loss: 2.3169
# 📉 Epoch 37/500 - Train Loss: 0.5715, Val Loss: 2.3170
# 📉 Epoch 38/500 - Train Loss: 0.5678, Val Loss: 2.3164
# 📉 Epoch 39/500 - Train Loss: 0.5736, Val Loss: 2.3164
# 📉 Epoch 40/500 - Train Loss: 0.5667, Val Loss: 2.3166
# 📉 Epoch 41/500 - Train Loss: 0.5700, Val Loss: 2.3166
# 📉 Epoch 42/500 - Train Loss: 0.5711, Val Loss: 2.3164
# 📉 Epoch 43/500 - Train Loss: 0.5715, Val Loss: 2.3165
# 📉 Epoch 44/500 - Train Loss: 0.5718, Val Loss: 2.3163
# 📉 Epoch 45/500 - Train Loss: 0.5697, Val Loss: 2.3159
# 📉 Epoch 46/500 - Train Loss: 0.5693, Val Loss: 2.3156
# 📉 Epoch 47/500 - Train Loss: 0.5724, Val Loss: 2.3154
# 📉 Epoch 48/500 - Train Loss: 0.5703, Val Loss: 2.3153
# 📉 Epoch 49/500 - Train Loss: 0.5724, Val Loss: 2.3145
# 📉 Epoch 50/500 - Train Loss: 0.5739, Val Loss: 2.3151
# 📉 Epoch 51/500 - Train Loss: 0.5731, Val Loss: 2.3146
# 📉 Epoch 52/500 - Train Loss: 0.5705, Val Loss: 2.3140
# 📉 Epoch 53/500 - Train Loss: 0.5703, Val Loss: 2.3140
# 📉 Epoch 54/500 - Train Loss: 0.5701, Val Loss: 2.3133
# 📉 Epoch 55/500 - Train Loss: 0.5705, Val Loss: 2.3126
# 📉 Epoch 56/500 - Train Loss: 0.5706, Val Loss: 2.3125
# 📉 Epoch 57/500 - Train Loss: 0.5712, Val Loss: 2.3120
# 📉 Epoch 58/500 - Train Loss: 0.5689, Val Loss: 2.3117
# 📉 Epoch 59/500 - Train Loss: 0.5696, Val Loss: 2.3114
# 📉 Epoch 60/500 - Train Loss: 0.5692, Val Loss: 2.3114
# 📉 Epoch 61/500 - Train Loss: 0.5717, Val Loss: 2.3110
# 📉 Epoch 62/500 - Train Loss: 0.5697, Val Loss: 2.3107
# 📉 Epoch 63/500 - Train Loss: 0.5704, Val Loss: 2.3102
# 📉 Epoch 64/500 - Train Loss: 0.5706, Val Loss: 2.3099
# 📉 Epoch 65/500 - Train Loss: 0.5690, Val Loss: 2.3100
# 📉 Epoch 66/500 - Train Loss: 0.5705, Val Loss: 2.3096
# 📉 Epoch 67/500 - Train Loss: 0.5685, Val Loss: 2.3092
# 📉 Epoch 68/500 - Train Loss: 0.5722, Val Loss: 2.3098
# 📉 Epoch 69/500 - Train Loss: 0.5693, Val Loss: 2.3087
# 📉 Epoch 70/500 - Train Loss: 0.5717, Val Loss: 2.3085
# 📉 Epoch 71/500 - Train Loss: 0.5701, Val Loss: 2.3084
# 📉 Epoch 72/500 - Train Loss: 0.5704, Val Loss: 2.3086
# 📉 Epoch 73/500 - Train Loss: 0.5712, Val Loss: 2.3091
# 📉 Epoch 74/500 - Train Loss: 0.5728, Val Loss: 2.3087
# 📉 Epoch 75/500 - Train Loss: 0.5695, Val Loss: 2.3083
# 📉 Epoch 76/500 - Train Loss: 0.5738, Val Loss: 2.3079
# 📉 Epoch 77/500 - Train Loss: 0.5682, Val Loss: 2.3085
# 📉 Epoch 78/500 - Train Loss: 0.5731, Val Loss: 2.3085
# 📉 Epoch 79/500 - Train Loss: 0.5695, Val Loss: 2.3086
# 📉 Epoch 80/500 - Train Loss: 0.5688, Val Loss: 2.3087
# 📉 Epoch 81/500 - Train Loss: 0.5699, Val Loss: 2.3095
# 📉 Epoch 82/500 - Train Loss: 0.5727, Val Loss: 2.3089
# 📉 Epoch 83/500 - Train Loss: 0.5697, Val Loss: 2.3089
# 📉 Epoch 84/500 - Train Loss: 0.5691, Val Loss: 2.3091
# 📉 Epoch 85/500 - Train Loss: 0.5703, Val Loss: 2.3098
# 📉 Epoch 86/500 - Train Loss: 0.5719, Val Loss: 2.3097
# 📉 Epoch 87/500 - Train Loss: 0.5720, Val Loss: 2.3106
# 📉 Epoch 88/500 - Train Loss: 0.5727, Val Loss: 2.3114
# 📉 Epoch 89/500 - Train Loss: 0.5737, Val Loss: 2.3119
# 📉 Epoch 90/500 - Train Loss: 0.5689, Val Loss: 2.3119
# 📉 Epoch 91/500 - Train Loss: 0.5697, Val Loss: 2.3114
# 📉 Epoch 92/500 - Train Loss: 0.5669, Val Loss: 2.3116
# 📉 Epoch 93/500 - Train Loss: 0.5729, Val Loss: 2.3120
# 📉 Epoch 94/500 - Train Loss: 0.5692, Val Loss: 2.3142
# 📉 Epoch 95/500 - Train Loss: 0.5718, Val Loss: 2.3142
# 📉 Epoch 96/500 - Train Loss: 0.5686, Val Loss: 2.3143
# ⏹️ Early stopping triggered at epoch 96. Best epoch: 76, Best Val Loss: 2.3079
# ✅ Model saved at: saved_models\bias_predictor_run_3.pth
# ⚡ Run 4/10
# 📉 Epoch 1/500 - Train Loss: 0.6363, Val Loss: 2.0781
# 📉 Epoch 2/500 - Train Loss: 0.6338, Val Loss: 2.0844
# 📉 Epoch 3/500 - Train Loss: 0.6234, Val Loss: 2.0906
# 📉 Epoch 4/500 - Train Loss: 0.6216, Val Loss: 2.0957
# 📉 Epoch 5/500 - Train Loss: 0.6130, Val Loss: 2.1003
# 📉 Epoch 6/500 - Train Loss: 0.6065, Val Loss: 2.1043
# 📉 Epoch 7/500 - Train Loss: 0.6028, Val Loss: 2.1083
# 📉 Epoch 8/500 - Train Loss: 0.6002, Val Loss: 2.1113
# 📉 Epoch 9/500 - Train Loss: 0.5971, Val Loss: 2.1145
# 📉 Epoch 10/500 - Train Loss: 0.5969, Val Loss: 2.1183
# 📉 Epoch 11/500 - Train Loss: 0.5932, Val Loss: 2.1227
# 📉 Epoch 12/500 - Train Loss: 0.5923, Val Loss: 2.1271
# 📉 Epoch 13/500 - Train Loss: 0.5837, Val Loss: 2.1318
# 📉 Epoch 14/500 - Train Loss: 0.5847, Val Loss: 2.1370
# 📉 Epoch 15/500 - Train Loss: 0.5830, Val Loss: 2.1425
# 📉 Epoch 16/500 - Train Loss: 0.5789, Val Loss: 2.1474
# 📉 Epoch 17/500 - Train Loss: 0.5837, Val Loss: 2.1532
# 📉 Epoch 18/500 - Train Loss: 0.5844, Val Loss: 2.1568
# 📉 Epoch 19/500 - Train Loss: 0.5748, Val Loss: 2.1628
# 📉 Epoch 20/500 - Train Loss: 0.5810, Val Loss: 2.1677
# 📉 Epoch 21/500 - Train Loss: 0.5817, Val Loss: 2.1724
# ⏹️ Early stopping triggered at epoch 21. Best epoch: 1, Best Val Loss: 2.0781
# ✅ Model saved at: saved_models\bias_predictor_run_4.pth
# ⚡ Run 5/10
# 📉 Epoch 1/500 - Train Loss: 0.5877, Val Loss: 2.3473
# 📉 Epoch 2/500 - Train Loss: 0.5847, Val Loss: 2.3423
# 📉 Epoch 3/500 - Train Loss: 0.5876, Val Loss: 2.3390
# 📉 Epoch 4/500 - Train Loss: 0.5876, Val Loss: 2.3347
# 📉 Epoch 5/500 - Train Loss: 0.5869, Val Loss: 2.3309
# 📉 Epoch 6/500 - Train Loss: 0.5844, Val Loss: 2.3272
# 📉 Epoch 7/500 - Train Loss: 0.5820, Val Loss: 2.3241
# 📉 Epoch 8/500 - Train Loss: 0.5881, Val Loss: 2.3208
# 📉 Epoch 9/500 - Train Loss: 0.5839, Val Loss: 2.3178
# 📉 Epoch 10/500 - Train Loss: 0.5833, Val Loss: 2.3146
# 📉 Epoch 11/500 - Train Loss: 0.5811, Val Loss: 2.3132
# 📉 Epoch 12/500 - Train Loss: 0.5823, Val Loss: 2.3099
# 📉 Epoch 13/500 - Train Loss: 0.5859, Val Loss: 2.3081
# 📉 Epoch 14/500 - Train Loss: 0.5738, Val Loss: 2.3061
# 📉 Epoch 15/500 - Train Loss: 0.5784, Val Loss: 2.3035
# 📉 Epoch 16/500 - Train Loss: 0.5851, Val Loss: 2.3027
# 📉 Epoch 17/500 - Train Loss: 0.5807, Val Loss: 2.3014
# 📉 Epoch 18/500 - Train Loss: 0.5785, Val Loss: 2.2992
# 📉 Epoch 19/500 - Train Loss: 0.5831, Val Loss: 2.2976
# 📉 Epoch 20/500 - Train Loss: 0.5777, Val Loss: 2.2977
# 📉 Epoch 21/500 - Train Loss: 0.5777, Val Loss: 2.2971
# 📉 Epoch 22/500 - Train Loss: 0.5795, Val Loss: 2.2965
# 📉 Epoch 23/500 - Train Loss: 0.5750, Val Loss: 2.2944
# 📉 Epoch 24/500 - Train Loss: 0.5835, Val Loss: 2.2926
# 📉 Epoch 25/500 - Train Loss: 0.5798, Val Loss: 2.2930
# 📉 Epoch 26/500 - Train Loss: 0.5741, Val Loss: 2.2928
# 📉 Epoch 27/500 - Train Loss: 0.5768, Val Loss: 2.2923
# 📉 Epoch 28/500 - Train Loss: 0.5716, Val Loss: 2.2910
# 📉 Epoch 29/500 - Train Loss: 0.5701, Val Loss: 2.2893
# 📉 Epoch 30/500 - Train Loss: 0.5785, Val Loss: 2.2895
# 📉 Epoch 31/500 - Train Loss: 0.5733, Val Loss: 2.2887
# 📉 Epoch 32/500 - Train Loss: 0.5746, Val Loss: 2.2889
# 📉 Epoch 33/500 - Train Loss: 0.5762, Val Loss: 2.2886
# 📉 Epoch 34/500 - Train Loss: 0.5693, Val Loss: 2.2892
# 📉 Epoch 35/500 - Train Loss: 0.5801, Val Loss: 2.2878
# 📉 Epoch 36/500 - Train Loss: 0.5769, Val Loss: 2.2864
# 📉 Epoch 37/500 - Train Loss: 0.5800, Val Loss: 2.2874
# 📉 Epoch 38/500 - Train Loss: 0.5821, Val Loss: 2.2880
# 📉 Epoch 39/500 - Train Loss: 0.5802, Val Loss: 2.2895
# 📉 Epoch 40/500 - Train Loss: 0.5798, Val Loss: 2.2899
# 📉 Epoch 41/500 - Train Loss: 0.5813, Val Loss: 2.2912
# 📉 Epoch 42/500 - Train Loss: 0.5738, Val Loss: 2.2919
# 📉 Epoch 43/500 - Train Loss: 0.5835, Val Loss: 2.2922
# 📉 Epoch 44/500 - Train Loss: 0.5762, Val Loss: 2.2936
# 📉 Epoch 45/500 - Train Loss: 0.5691, Val Loss: 2.2942
# 📉 Epoch 46/500 - Train Loss: 0.5766, Val Loss: 2.2952
# 📉 Epoch 47/500 - Train Loss: 0.5769, Val Loss: 2.2965
# 📉 Epoch 48/500 - Train Loss: 0.5740, Val Loss: 2.2972
# 📉 Epoch 49/500 - Train Loss: 0.5761, Val Loss: 2.2979
# 📉 Epoch 50/500 - Train Loss: 0.5773, Val Loss: 2.3000
# 📉 Epoch 51/500 - Train Loss: 0.5781, Val Loss: 2.3017
# 📉 Epoch 52/500 - Train Loss: 0.5788, Val Loss: 2.3023
# 📉 Epoch 53/500 - Train Loss: 0.5718, Val Loss: 2.3038
# 📉 Epoch 54/500 - Train Loss: 0.5709, Val Loss: 2.3039
# 📉 Epoch 55/500 - Train Loss: 0.5773, Val Loss: 2.3053
# 📉 Epoch 56/500 - Train Loss: 0.5780, Val Loss: 2.3067
# ⏹️ Early stopping triggered at epoch 56. Best epoch: 36, Best Val Loss: 2.2864
# ✅ Model saved at: saved_models\bias_predictor_run_5.pth
# ⚡ Run 6/10
# 📉 Epoch 1/500 - Train Loss: 0.7177, Val Loss: 2.7473
# 📉 Epoch 2/500 - Train Loss: 0.7100, Val Loss: 2.7261
# 📉 Epoch 3/500 - Train Loss: 0.7050, Val Loss: 2.7055
# 📉 Epoch 4/500 - Train Loss: 0.6964, Val Loss: 2.6865
# 📉 Epoch 5/500 - Train Loss: 0.6858, Val Loss: 2.6676
# 📉 Epoch 6/500 - Train Loss: 0.6858, Val Loss: 2.6485
# 📉 Epoch 7/500 - Train Loss: 0.6791, Val Loss: 2.6309
# 📉 Epoch 8/500 - Train Loss: 0.6742, Val Loss: 2.6132
# 📉 Epoch 9/500 - Train Loss: 0.6638, Val Loss: 2.5955
# 📉 Epoch 10/500 - Train Loss: 0.6621, Val Loss: 2.5791
# 📉 Epoch 11/500 - Train Loss: 0.6576, Val Loss: 2.5639
# 📉 Epoch 12/500 - Train Loss: 0.6539, Val Loss: 2.5478
# 📉 Epoch 13/500 - Train Loss: 0.6502, Val Loss: 2.5347
# 📉 Epoch 14/500 - Train Loss: 0.6494, Val Loss: 2.5213
# 📉 Epoch 15/500 - Train Loss: 0.6400, Val Loss: 2.5096
# 📉 Epoch 16/500 - Train Loss: 0.6398, Val Loss: 2.4980
# 📉 Epoch 17/500 - Train Loss: 0.6388, Val Loss: 2.4862
# 📉 Epoch 18/500 - Train Loss: 0.6264, Val Loss: 2.4737
# 📉 Epoch 19/500 - Train Loss: 0.6295, Val Loss: 2.4615
# 📉 Epoch 20/500 - Train Loss: 0.6246, Val Loss: 2.4466
# 📉 Epoch 21/500 - Train Loss: 0.6224, Val Loss: 2.4290
# 📉 Epoch 22/500 - Train Loss: 0.6130, Val Loss: 2.4102
# 📉 Epoch 23/500 - Train Loss: 0.6116, Val Loss: 2.3940
# 📉 Epoch 24/500 - Train Loss: 0.6090, Val Loss: 2.3778
# 📉 Epoch 25/500 - Train Loss: 0.5991, Val Loss: 2.3621
# 📉 Epoch 26/500 - Train Loss: 0.6018, Val Loss: 2.3481
# 📉 Epoch 27/500 - Train Loss: 0.5997, Val Loss: 2.3351
# 📉 Epoch 28/500 - Train Loss: 0.5951, Val Loss: 2.3287
# 📉 Epoch 29/500 - Train Loss: 0.5945, Val Loss: 2.3249
# 📉 Epoch 30/500 - Train Loss: 0.5899, Val Loss: 2.3181
# 📉 Epoch 31/500 - Train Loss: 0.5963, Val Loss: 2.3149
# 📉 Epoch 32/500 - Train Loss: 0.5902, Val Loss: 2.3112
# 📉 Epoch 33/500 - Train Loss: 0.5891, Val Loss: 2.3092
# 📉 Epoch 34/500 - Train Loss: 0.5897, Val Loss: 2.3095
# 📉 Epoch 35/500 - Train Loss: 0.5885, Val Loss: 2.3151
# 📉 Epoch 36/500 - Train Loss: 0.5851, Val Loss: 2.3131
# 📉 Epoch 37/500 - Train Loss: 0.5814, Val Loss: 2.3133
# 📉 Epoch 38/500 - Train Loss: 0.5871, Val Loss: 2.3155
# 📉 Epoch 39/500 - Train Loss: 0.5873, Val Loss: 2.3184
# 📉 Epoch 40/500 - Train Loss: 0.5914, Val Loss: 2.3195
# 📉 Epoch 41/500 - Train Loss: 0.5822, Val Loss: 2.3243
# 📉 Epoch 42/500 - Train Loss: 0.5829, Val Loss: 2.3267
# 📉 Epoch 43/500 - Train Loss: 0.5863, Val Loss: 2.3336
# 📉 Epoch 44/500 - Train Loss: 0.5765, Val Loss: 2.3353
# 📉 Epoch 45/500 - Train Loss: 0.5926, Val Loss: 2.3387
# 📉 Epoch 46/500 - Train Loss: 0.5877, Val Loss: 2.3464
# 📉 Epoch 47/500 - Train Loss: 0.5852, Val Loss: 2.3524
# 📉 Epoch 48/500 - Train Loss: 0.5917, Val Loss: 2.3595
# 📉 Epoch 49/500 - Train Loss: 0.5872, Val Loss: 2.3688
# 📉 Epoch 50/500 - Train Loss: 0.5756, Val Loss: 2.3724
# 📉 Epoch 51/500 - Train Loss: 0.5767, Val Loss: 2.3766
# 📉 Epoch 52/500 - Train Loss: 0.5871, Val Loss: 2.3817
# 📉 Epoch 53/500 - Train Loss: 0.5843, Val Loss: 2.3881
# ⏹️ Early stopping triggered at epoch 53. Best epoch: 33, Best Val Loss: 2.3092
# ✅ Model saved at: saved_models\bias_predictor_run_6.pth
# ⚡ Run 7/10
# 📉 Epoch 1/500 - Train Loss: 0.6947, Val Loss: 2.0205
# 📉 Epoch 2/500 - Train Loss: 0.6866, Val Loss: 2.0245
# 📉 Epoch 3/500 - Train Loss: 0.6716, Val Loss: 2.0285
# 📉 Epoch 4/500 - Train Loss: 0.6766, Val Loss: 2.0324
# 📉 Epoch 5/500 - Train Loss: 0.6813, Val Loss: 2.0367
# 📉 Epoch 6/500 - Train Loss: 0.6646, Val Loss: 2.0412
# 📉 Epoch 7/500 - Train Loss: 0.6585, Val Loss: 2.0460
# 📉 Epoch 8/500 - Train Loss: 0.6515, Val Loss: 2.0506
# 📉 Epoch 9/500 - Train Loss: 0.6515, Val Loss: 2.0556
# 📉 Epoch 10/500 - Train Loss: 0.6501, Val Loss: 2.0608
# 📉 Epoch 11/500 - Train Loss: 0.6416, Val Loss: 2.0659
# 📉 Epoch 12/500 - Train Loss: 0.6408, Val Loss: 2.0720
# 📉 Epoch 13/500 - Train Loss: 0.6363, Val Loss: 2.0780
# 📉 Epoch 14/500 - Train Loss: 0.6341, Val Loss: 2.0834
# 📉 Epoch 15/500 - Train Loss: 0.6268, Val Loss: 2.0884
# 📉 Epoch 16/500 - Train Loss: 0.6214, Val Loss: 2.0924
# 📉 Epoch 17/500 - Train Loss: 0.6234, Val Loss: 2.0951
# 📉 Epoch 18/500 - Train Loss: 0.6175, Val Loss: 2.0962
# 📉 Epoch 19/500 - Train Loss: 0.6174, Val Loss: 2.0969
# 📉 Epoch 20/500 - Train Loss: 0.6088, Val Loss: 2.0973
# 📉 Epoch 21/500 - Train Loss: 0.6056, Val Loss: 2.0986
# ⏹️ Early stopping triggered at epoch 21. Best epoch: 1, Best Val Loss: 2.0205
# ✅ Model saved at: saved_models\bias_predictor_run_7.pth
# ⚡ Run 8/10
# 📉 Epoch 1/500 - Train Loss: 0.5715, Val Loss: 2.2042
# 📉 Epoch 2/500 - Train Loss: 0.5739, Val Loss: 2.2062
# 📉 Epoch 3/500 - Train Loss: 0.5752, Val Loss: 2.2073
# 📉 Epoch 4/500 - Train Loss: 0.5670, Val Loss: 2.2074
# 📉 Epoch 5/500 - Train Loss: 0.5735, Val Loss: 2.2093
# 📉 Epoch 6/500 - Train Loss: 0.5715, Val Loss: 2.2113
# 📉 Epoch 7/500 - Train Loss: 0.5737, Val Loss: 2.2126
# 📉 Epoch 8/500 - Train Loss: 0.5752, Val Loss: 2.2136
# 📉 Epoch 9/500 - Train Loss: 0.5749, Val Loss: 2.2177
# 📉 Epoch 10/500 - Train Loss: 0.5668, Val Loss: 2.2191
# 📉 Epoch 11/500 - Train Loss: 0.5714, Val Loss: 2.2213
# 📉 Epoch 12/500 - Train Loss: 0.5688, Val Loss: 2.2232
# 📉 Epoch 13/500 - Train Loss: 0.5730, Val Loss: 2.2252
# 📉 Epoch 14/500 - Train Loss: 0.5771, Val Loss: 2.2274
# 📉 Epoch 15/500 - Train Loss: 0.5731, Val Loss: 2.2303
# 📉 Epoch 16/500 - Train Loss: 0.5765, Val Loss: 2.2336
# 📉 Epoch 17/500 - Train Loss: 0.5745, Val Loss: 2.2374
# 📉 Epoch 18/500 - Train Loss: 0.5738, Val Loss: 2.2374
# 📉 Epoch 19/500 - Train Loss: 0.5718, Val Loss: 2.2396
# 📉 Epoch 20/500 - Train Loss: 0.5715, Val Loss: 2.2409
# 📉 Epoch 21/500 - Train Loss: 0.5727, Val Loss: 2.2448
# ⏹️ Early stopping triggered at epoch 21. Best epoch: 1, Best Val Loss: 2.2042
# ✅ Model saved at: saved_models\bias_predictor_run_8.pth
# ⚡ Run 9/10
# 📉 Epoch 1/500 - Train Loss: 0.5719, Val Loss: 2.2652
# 📉 Epoch 2/500 - Train Loss: 0.5720, Val Loss: 2.2642
# 📉 Epoch 3/500 - Train Loss: 0.5718, Val Loss: 2.2635
# 📉 Epoch 4/500 - Train Loss: 0.5719, Val Loss: 2.2625
# 📉 Epoch 5/500 - Train Loss: 0.5716, Val Loss: 2.2624
# 📉 Epoch 6/500 - Train Loss: 0.5716, Val Loss: 2.2617
# 📉 Epoch 7/500 - Train Loss: 0.5715, Val Loss: 2.2609
# 📉 Epoch 8/500 - Train Loss: 0.5715, Val Loss: 2.2606
# 📉 Epoch 9/500 - Train Loss: 0.5715, Val Loss: 2.2595
# 📉 Epoch 10/500 - Train Loss: 0.5714, Val Loss: 2.2584
# 📉 Epoch 11/500 - Train Loss: 0.5713, Val Loss: 2.2580
# 📉 Epoch 12/500 - Train Loss: 0.5713, Val Loss: 2.2570
# 📉 Epoch 13/500 - Train Loss: 0.5712, Val Loss: 2.2560
# 📉 Epoch 14/500 - Train Loss: 0.5711, Val Loss: 2.2556
# 📉 Epoch 15/500 - Train Loss: 0.5711, Val Loss: 2.2548
# 📉 Epoch 16/500 - Train Loss: 0.5711, Val Loss: 2.2547
# 📉 Epoch 17/500 - Train Loss: 0.5711, Val Loss: 2.2539
# 📉 Epoch 18/500 - Train Loss: 0.5710, Val Loss: 2.2533
# 📉 Epoch 19/500 - Train Loss: 0.5710, Val Loss: 2.2528
# 📉 Epoch 20/500 - Train Loss: 0.5709, Val Loss: 2.2524
# 📉 Epoch 21/500 - Train Loss: 0.5709, Val Loss: 2.2527
# 📉 Epoch 22/500 - Train Loss: 0.5708, Val Loss: 2.2522
# 📉 Epoch 23/500 - Train Loss: 0.5708, Val Loss: 2.2514
# 📉 Epoch 24/500 - Train Loss: 0.5708, Val Loss: 2.2509
# 📉 Epoch 25/500 - Train Loss: 0.5708, Val Loss: 2.2508
# 📉 Epoch 26/500 - Train Loss: 0.5707, Val Loss: 2.2499
# 📉 Epoch 27/500 - Train Loss: 0.5708, Val Loss: 2.2498
# 📉 Epoch 28/500 - Train Loss: 0.5708, Val Loss: 2.2492
# 📉 Epoch 29/500 - Train Loss: 0.5707, Val Loss: 2.2488
# 📉 Epoch 30/500 - Train Loss: 0.5707, Val Loss: 2.2483
# 📉 Epoch 31/500 - Train Loss: 0.5707, Val Loss: 2.2484
# 📉 Epoch 32/500 - Train Loss: 0.5706, Val Loss: 2.2491
# 📉 Epoch 33/500 - Train Loss: 0.5706, Val Loss: 2.2485
# 📉 Epoch 34/500 - Train Loss: 0.5707, Val Loss: 2.2485
# 📉 Epoch 35/500 - Train Loss: 0.5706, Val Loss: 2.2494
# 📉 Epoch 36/500 - Train Loss: 0.5706, Val Loss: 2.2509
# 📉 Epoch 37/500 - Train Loss: 0.5707, Val Loss: 2.2505
# 📉 Epoch 38/500 - Train Loss: 0.5706, Val Loss: 2.2507
# 📉 Epoch 39/500 - Train Loss: 0.5705, Val Loss: 2.2518
# 📉 Epoch 40/500 - Train Loss: 0.5705, Val Loss: 2.2531
# 📉 Epoch 41/500 - Train Loss: 0.5705, Val Loss: 2.2543
# 📉 Epoch 42/500 - Train Loss: 0.5705, Val Loss: 2.2554
# 📉 Epoch 43/500 - Train Loss: 0.5704, Val Loss: 2.2558
# 📉 Epoch 44/500 - Train Loss: 0.5706, Val Loss: 2.2555
# 📉 Epoch 45/500 - Train Loss: 0.5705, Val Loss: 2.2559
# 📉 Epoch 46/500 - Train Loss: 0.5704, Val Loss: 2.2576
# 📉 Epoch 47/500 - Train Loss: 0.5707, Val Loss: 2.2568
# 📉 Epoch 48/500 - Train Loss: 0.5706, Val Loss: 2.2570
# 📉 Epoch 49/500 - Train Loss: 0.5705, Val Loss: 2.2584
# 📉 Epoch 50/500 - Train Loss: 0.5704, Val Loss: 2.2580
# ⏹️ Early stopping triggered at epoch 50. Best epoch: 30, Best Val Loss: 2.2483
# ✅ Model saved at: saved_models\bias_predictor_run_9.pth
# ⚡ Run 10/10
# 📉 Epoch 1/500 - Train Loss: 0.6145, Val Loss: 2.0825
# 📉 Epoch 2/500 - Train Loss: 0.6120, Val Loss: 2.0859
# 📉 Epoch 3/500 - Train Loss: 0.6103, Val Loss: 2.0896
# 📉 Epoch 4/500 - Train Loss: 0.6075, Val Loss: 2.0932
# 📉 Epoch 5/500 - Train Loss: 0.6063, Val Loss: 2.0966
# 📉 Epoch 6/500 - Train Loss: 0.6047, Val Loss: 2.1004
# 📉 Epoch 7/500 - Train Loss: 0.6044, Val Loss: 2.1042
# 📉 Epoch 8/500 - Train Loss: 0.6017, Val Loss: 2.1080
# 📉 Epoch 9/500 - Train Loss: 0.5999, Val Loss: 2.1120
# 📉 Epoch 10/500 - Train Loss: 0.5997, Val Loss: 2.1165
# 📉 Epoch 11/500 - Train Loss: 0.5984, Val Loss: 2.1200
# 📉 Epoch 12/500 - Train Loss: 0.5968, Val Loss: 2.1237
# 📉 Epoch 13/500 - Train Loss: 0.5946, Val Loss: 2.1277
# 📉 Epoch 14/500 - Train Loss: 0.5943, Val Loss: 2.1322
# 📉 Epoch 15/500 - Train Loss: 0.5924, Val Loss: 2.1362
# 📉 Epoch 16/500 - Train Loss: 0.5898, Val Loss: 2.1405
# 📉 Epoch 17/500 - Train Loss: 0.5894, Val Loss: 2.1455
# 📉 Epoch 18/500 - Train Loss: 0.5905, Val Loss: 2.1494
# 📉 Epoch 19/500 - Train Loss: 0.5887, Val Loss: 2.1541
# 📉 Epoch 20/500 - Train Loss: 0.5866, Val Loss: 2.1591
# 📉 Epoch 21/500 - Train Loss: 0.5852, Val Loss: 2.1640
# ⏹️ Early stopping triggered at epoch 21. Best epoch: 1, Best Val Loss: 2.0825
# ✅ Model saved at: saved_models\bias_predictor_run_10.pth

# %%
# Plot all 10 runs in subplots (2 rows, 5 columns)
fig, axes = plt.subplots(2, 5, figsize=(25, 10))
fig.suptitle("Actual vs Predicted Values (10 Runs)")

for i, ax in enumerate(axes.flatten()):
    ax.plot(temp_df[f"New_predictions_arr_SHAP_run_{i+1}"].iloc[train_size+val_size:], label='Array input predictions (SHAP)', color='blue')
    ax.plot(temp_df["New_predictions_arr"].iloc[train_size+val_size:], label='Array input predictions', color='purple')
    ax.plot(temp_df["New_predictions_uni"].iloc[train_size+val_size:], label='Single input predictions', color='red')
    ax.plot(temp_df["Target"].iloc[train_size+val_size:], label='True Values', color='green')
    ax.set_title(f"Run {i+1}")
    ax.set_xlabel('Time')
    ax.set_ylabel('Value')
    ax.legend()

plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# Compute statistics for error percentages
error_stats = {
    "Mean Error %": np.mean(error_percentages),
    "Std Dev Error %": np.std(error_percentages),
    "Min Error %": np.min(error_percentages),
    "Max Error %": np.max(error_percentages),
}

# Print statistics
print("📊 Error Percentage Statistics For Each Run:\n")
count = 1
for error in error_percentages:
    print(f"Run {count} Error Percentage: {error:.4f}%")
    count += 1
print("\n📊 Error Percentage Statistics Across 10 Runs:\n")
for key, value in error_stats.items():
    print(f"{key}: {value:.4f}%")
  
print("------------------------------------------------------------------------------------------")  
original_LSTM_error_percent = np.mean(np.abs(temp_df["Target"].iloc[train_size+val_size:].values - temp_df["LSTM_prediction_original"].iloc[train_size+val_size:].values) / (np.abs(temp_df["Target"].iloc[train_size+val_size:].values) + 1e-8)) * 100
uni_input_error_percent = np.mean(np.abs(temp_df["Target"].iloc[train_size+val_size:].values - temp_df["New_predictions_uni"].iloc[train_size+val_size:].values) / (np.abs(temp_df["Target"].iloc[train_size+val_size:].values) + 1e-8)) * 100
arr_input_error_percent = np.mean(np.abs(temp_df["Target"].iloc[train_size+val_size:].values - temp_df["New_predictions_arr"].iloc[train_size+val_size:].values) / (np.abs(temp_df["Target"].iloc[train_size+val_size:].values) + 1e-8)) * 100
print(f"Original LSTM Error Percentage: {original_LSTM_error_percent:.4f}%")
print(f"Uni input bias prediction Error Percentage: {uni_input_error_percent:.4f}%")
print(f"Arr input bias prediction Error Percentage: {arr_input_error_percent:.4f}%")
# Out:
# 📊 Error Percentage Statistics For Each Run:
#
# Run 1 Error Percentage: 4.0114%
# Run 2 Error Percentage: 3.9834%
# Run 3 Error Percentage: 4.1126%
# Run 4 Error Percentage: 3.9684%
# Run 5 Error Percentage: 3.9502%
# Run 6 Error Percentage: 4.0273%
# Run 7 Error Percentage: 4.1176%
# Run 8 Error Percentage: 4.0390%
# Run 9 Error Percentage: 4.0363%
# Run 10 Error Percentage: 4.0442%
#
# 📊 Error Percentage Statistics Across 10 Runs:
#
# Mean Error %: 4.0291%
# Std Dev Error %: 0.0525%
# Min Error %: 3.9502%
# Max Error %: 4.1176%
# ------------------------------------------------------------------------------------------
# Original LSTM Error Percentage: 4.1752%
# Uni input bias prediction Error Percentage: 11.0498%
# Arr input bias prediction Error Percentage: 4.3692%
