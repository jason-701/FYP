# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
from numpy.linalg import norm

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# Load the data
# file_path = "../SPY_section_1.csv"
file_path = "SPY_section_2.csv"
df = pd.read_csv(file_path)

# %%
# Define Autoencoder
class Autoencoder(nn.Module):
    def __init__(self, input_dim, encoding_dim, dropout_rate):
        super(Autoencoder, self).__init__()
        self.encoder = nn.Sequential(
            nn.Linear(input_dim, 128),
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.Linear(64, encoding_dim)
        )
        self.decoder = nn.Sequential(
            nn.Linear(encoding_dim, 64),
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.Linear(64, 128),
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.Linear(128, input_dim)
        )

    def forward(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return decoded

# %%
# Define LSTM model
class ComplexLSTMModel(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, dropout_rate):
        super(ComplexLSTMModel, self).__init__()
        # Unidirectional LSTM for sequential stock price prediction
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers,
                            batch_first=True, dropout=dropout_rate)  # Removed bidirectional=True

        # Fully connected layers for added complexity
        self.fc1 = nn.Linear(hidden_size, hidden_size // 2)
        self.dropout1 = nn.Dropout(dropout_rate)
        self.fc2 = nn.Linear(hidden_size // 2, hidden_size // 4)
        self.dropout2 = nn.Dropout(dropout_rate)
        self.fc3 = nn.Linear(hidden_size // 4, 1)

    def forward(self, x):
        # LSTM expects input of shape (batch_size, sequence_length, input_size)
        out, _ = self.lstm(x)
        # Use the output of the last time step
        out = out[:, -1, :]  # Shape: (batch_size, hidden_size)

        out = torch.relu(self.fc1(out))  # First fully connected layer
        out = self.dropout1(out)
        out = torch.relu(self.fc2(out))  # Second fully connected layer
        out = self.dropout2(out)
        out = self.fc3(out)  # Output layer (no activation for regression)
        return out


sequence_length = 10

# Reshape data into sequences
def create_sequences(data, target, seq_length):
    X_seq, y_seq = [], []
    for i in range(len(data) - seq_length):
        X_seq.append(data[i:i + seq_length])
        y_seq.append(target[i + seq_length])
    return np.array(X_seq), np.array(y_seq)

# %%
# Define the target variable
if "Target" not in df.columns:
    # df["Target"] = (df["Close"].shift(-1) > df["Close"]).astype(int)
    df["Target"] = df["Close"].shift(-1)
df = df.dropna()

# %%
# Adding SMA and EMA to the feature
short_term_period = 20
medium_term_period = 50
long_term_period = 200

# Compute the SMAs
df['SMA_20'] = df['Close'].rolling(window=short_term_period).mean() # Short-term SMA
df['SMA_50'] = df['Close'].rolling(window=medium_term_period).mean() # Medium-term SMA
df['SMA_200'] = df['Close'].rolling(window=long_term_period).mean() # Long-term SMA

df['EMA_10'] = df['Close'].ewm(span=10, adjust=False).mean()  # Short-term EMA
df['EMA_50'] = df['Close'].ewm(span=50, adjust=False).mean()  # Medium-term EMA
df['EMA_200'] = df['Close'].ewm(span=200, adjust=False).mean()  # Long-term EMA

df = df.dropna()

# %%
X = df.drop(columns=["Date", "Target"])
y = df["Target"]

feature_columns = ["Open", "High", "Low", "Close", "Volume", "SMA_20", "SMA_50", "SMA_200", "EMA_10", "EMA_50", "EMA_200"]

train_size = int(X.shape[0] * 0.7)
val_size = int(X.shape[0] * 0.15)

scaler = MinMaxScaler()

# Split data into train, validation, and test
temp_train = X[:train_size]
temp_val = X[train_size:train_size + val_size]
temp_test = X[train_size + val_size:]

temp_train = temp_train[feature_columns]
temp_val = temp_val[feature_columns]
temp_test = temp_test[feature_columns]

# Fit and transform for train, transform for validation and test
temp_train = scaler.fit_transform(temp_train)
temp_val = scaler.transform(temp_val)
temp_test = scaler.transform(temp_test)

# Convert NumPy arrays back to DataFrames
temp_train = pd.DataFrame(temp_train, columns=feature_columns)
temp_val = pd.DataFrame(temp_val, columns=feature_columns)
temp_test = pd.DataFrame(temp_test, columns=feature_columns)

# Concatenate the data
X_scaled = pd.concat([temp_train, temp_val, temp_test], axis=0)

X_seq, y_seq = create_sequences(X_scaled, y.values, sequence_length)

# Split sequentially
X_train, y_train = X_seq[:train_size], y_seq[:train_size]
X_val, y_val = X_seq[train_size:train_size + val_size], y_seq[train_size:train_size + val_size]
X_test, y_test = X_seq[train_size + val_size:], y_seq[train_size + val_size:]

# Print sizes to confirm
print(f"Train: {len(X_train)}, Val: {len(X_val)}, Test: {len(X_test)}")
print(X_scaled.shape)
# Out:
# Train: 1194, Val: 256, Test: 247
# (1707, 11)

# %%
# Convert to PyTorch tensors
X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train, dtype=torch.float32)
X_val_tensor = torch.tensor(X_val, dtype=torch.float32)
y_val_tensor = torch.tensor(y_val, dtype=torch.float32)
X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test, dtype=torch.float32)

# Create DataLoaders
train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
val_dataset = TensorDataset(X_val_tensor, y_val_tensor)
test_dataset = TensorDataset(X_test_tensor, y_test_tensor)

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=64, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

# %% [markdown]
# <span style="color: yellow; font-size: 40px;">Evaluating original LSTM</span>

# %%
# Hyperparameters
input_size = X_train.shape[2]  # Number of features
hidden_size = 128
num_layers = 2
dropout_rate = 0.1
learning_rate = 0.0005
num_epochs = 500
patience = 30

# %%
# Define paths
# LSTM_model_path = "../lstm_codes/lstm_models/lstm_section_1.pth"
LSTM_model_path = "lstm_section_2.pth"

# Load the trained model
LSTM_model = ComplexLSTMModel(input_size=input_size, hidden_size=hidden_size, num_layers=num_layers, dropout_rate=dropout_rate).to(device)
LSTM_model.load_state_dict(torch.load(LSTM_model_path, map_location=torch.device('cpu')))
LSTM_model.eval()

# Define loss function
criterion = torch.nn.MSELoss()

# Evaluate on test data
test_loss = 0.0
test_mae = 0.0
all_true = []
all_preds = []

with torch.no_grad():
    for X_batch, y_batch in test_loader:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)
        outputs = LSTM_model(X_batch)
        loss = criterion(outputs, y_batch)
        mae = torch.mean(torch.abs(outputs - y_batch))

        test_loss += loss.item() * X_batch.size(0)
        test_mae += mae.item() * X_batch.size(0)

        all_true.extend(y_batch.cpu().numpy())
        all_preds.extend(outputs.cpu().numpy())

# Compute final metrics
test_loss /= len(test_loader.dataset)
test_mae /= len(test_loader.dataset)

# Compute error percentages
all_true = np.array(all_true).flatten()
all_preds = np.array(all_preds).flatten()
error = np.abs(all_true - all_preds) / (np.abs(all_true) + 1e-8)
avg_error = np.mean(error) * 100
largest_error = np.max(error) * 100

# Print results
print("\n===== Evaluation Results =====")
print(f"Test Loss: {test_loss:.4f}")
print(f"Test MAE: {test_mae:.4f}")
print(f"Average Error Percentage: {avg_error:.2f}%")
print(f"Largest Error Percentage: {largest_error:.2f}%")

# Plot actual vs predicted values
plt.figure(figsize=(10, 5))
plt.plot(all_true, label='True Values', color='blue')
plt.plot(all_preds, label='Predicted Values', color='red')
plt.xlabel('Time')
plt.ylabel('Value')
plt.title('Actual vs. Predicted Values')
plt.legend()
plt.show()
# Out:
# ===== Evaluation Results =====
# Test Loss: 28.6670
# Test MAE: 4.1148
# Average Error Percentage: 4.20%
# Largest Error Percentage: 22.92%
# <ipython-input-54-993d7e0f0063>:7: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   LSTM_model.load_state_dict(torch.load(LSTM_model_path, map_location=torch.device('cpu')))
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/loss.py:608: UserWarning: Using a target size (torch.Size([64])) that is different to the input size (torch.Size([64, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/loss.py:608: UserWarning: Using a target size (torch.Size([55])) that is different to the input size (torch.Size([55, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)

# %% [markdown]
# <span style="color: yellow; font-size: 40px;">Evaluating original autoencoder</span>

# %%
X_train = X_scaled[:train_size]
X_val = X_scaled[train_size:train_size + val_size]
X_test = X_scaled[train_size + val_size:]

# %%
X_train = X_train.values
X_val = X_val.values
X_test = X_test.values

# %%
# Convert data to PyTorch tensors
X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
X_val_tensor = torch.tensor(X_val, dtype=torch.float32)
X_test_tensor = torch.tensor(X_test, dtype=torch.float32)

# Create DataLoader
train_dataset = TensorDataset(X_train_tensor, X_train_tensor)
val_dataset = TensorDataset(X_val_tensor, X_val_tensor)
test_dataset = TensorDataset(X_test_tensor, X_test_tensor)
train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=16, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=16, shuffle=False)

# %%
input_dim = X_train.shape[1]

# Hyperparameters
encoding_dim = 5
learning_rate = 0.0005
dropout_rate = 0.3
epochs = 750
batch_size = 16
patience = 40

# %%
# autoencoder_model_path = "../autoencoder_codes/autoencoder_models/autoencoder_section_1.pth"
autoencoder_model_path = "autoencoder_section_2.pth"
autoencoder_model = Autoencoder(input_dim=input_dim, encoding_dim=encoding_dim, dropout_rate=dropout_rate).to(device)
autoencoder_model.load_state_dict(torch.load(autoencoder_model_path, map_location=torch.device('cpu')))
# Out:
# <ipython-input-59-3c47e69a6547>:4: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   autoencoder_model.load_state_dict(torch.load(autoencoder_model_path, map_location=torch.device('cpu')))
# <All keys matched successfully>

# %%
autoencoder_model.eval()
with torch.no_grad():
    reconstructed_test = autoencoder_model(torch.tensor(X_test, dtype=torch.float32).to(device)).cpu().numpy()
mse = np.mean((X_test - reconstructed_test) ** 2)
mae = np.mean(np.abs(X_test - reconstructed_test))
ree = np.mean(np.linalg.norm(X_test - reconstructed_test, axis=1) / np.linalg.norm(X_test, axis=1))
euclidean_dist = np.mean([norm(X_test[i] - reconstructed_test[i]) for i in range(len(X_test))])
reconstruction_error_percentage = (
    np.mean(np.abs(X_test - reconstructed_test) / (np.abs(X_test) + 1e-8), axis=1) * 100
)
average_error = np.mean(reconstruction_error_percentage)
print(f'MSE: {mse:.4f}, MAE: {mae:.4f}, REE: {ree:.4f}, Euclidean Distance: {euclidean_dist:.4f}, Average Error: {average_error:.4f}%')
# Out:
# MSE: 0.0228, MAE: 0.0984, REE: 0.2287, Euclidean Distance: 0.4141, Average Error: 81.7411%

# %%
# Scatter plot of reconstruction error percentage
plt.figure(figsize=(10, 5))
plt.scatter(range(len(reconstruction_error_percentage)), reconstruction_error_percentage, alpha=0.5)
plt.ylim(0, 50)
plt.xlabel('Sample')
plt.ylabel('Reconstruction Error Percentage')
plt.title('Reconstruction Error Percentage')
plt.show()

# %% [markdown]
# <span style="color: yellow; font-size: 40px;">Bias correction model - single input</span>

# %%
# import torch
# import torch.nn as nn
# import torch.nn.functional as F

# class BiasPredictor(nn.Module):
#     def __init__(self, input_size, hidden_size1, dropout_rate):
#         super(BiasPredictor, self).__init__()

#         hidden_size2 = hidden_size1 // 2
#         hidden_size3 = hidden_size2 // 2
#         hidden_size4 = hidden_size3 // 2  # New additional layer

#         self.fc1 = nn.Linear(input_size, hidden_size1)
#         self.dropout1 = nn.Dropout(dropout_rate)

#         self.fc2 = nn.Linear(hidden_size1, hidden_size2)
#         self.dropout2 = nn.Dropout(dropout_rate)

#         self.fc3 = nn.Linear(hidden_size2, hidden_size3)
#         self.dropout3 = nn.Dropout(dropout_rate)

#         self.fc4 = nn.Linear(hidden_size3, hidden_size4)  # New additional layer
#         self.dropout4 = nn.Dropout(dropout_rate)

#         self.fc5 = nn.Linear(hidden_size4, 1)  # Final output layer

#     def forward(self, x):
#         x = F.relu(self.fc1(x))
#         x = self.dropout1(x)

#         x = F.relu(self.fc2(x))
#         x = self.dropout2(x)

#         x = F.relu(self.fc3(x))
#         x = self.dropout3(x)

#         x = F.relu(self.fc4(x))  # New layer
#         x = self.dropout4(x)

#         return self.fc5(x)



import torch
import torch.nn as nn
import torch.nn.functional as F

class BiasPredictor(nn.Module):
    def __init__(self, input_size, hidden_size, dropout_rate):
        super(BiasPredictor, self).__init__()

        hidden_size2 = hidden_size // 2

        # Define layers
        self.fc1 = nn.Linear(input_size, hidden_size)
        self.dropout1 = nn.Dropout(dropout_rate)

        self.fc2 = nn.Linear(hidden_size, hidden_size2)
        self.dropout2 = nn.Dropout(dropout_rate)

        self.fc3 = nn.Linear(hidden_size2, 1)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = self.dropout1(x)

        x = F.relu(self.fc2(x))
        x = self.dropout2(x)

        return self.fc3(x)

# %%
# Get LSTM predictions of entire dataset
with torch.no_grad():
    X_tensor = torch.tensor(X_seq, dtype=torch.float32).to(device)
    LSTM_preds = LSTM_model(X_tensor).cpu().numpy()

# Put LSTM predictions into a new DataFrame
new_df = pd.DataFrame(LSTM_preds, columns=["LSTM_Pred"])

# %%
# Drop the first sequence_length rows
temp_y = y
temp_y = temp_y[sequence_length:]

# add the target variable to the new DataFrame
new_df["Target"] = temp_y.values

# %%
# Get reconstruction error percentage for the entire dataset
autoencoder_model.eval()
with torch.no_grad():
    reconstructed = autoencoder_model(torch.tensor(X_scaled.values, dtype=torch.float32).to(device)).cpu().numpy()

# Compute the MAE
reconstruction_error = np.mean(np.abs(X_scaled.values - reconstructed), axis=1)

# Compute the reconstruction error percentage
# reconstruction_error = np.mean(np.abs(X_scaled.values - reconstructed) / (np.abs(X_scaled.values) + 1e-8), axis=1) * 100
# reconstruction_error = np.mean((X_scaled.values - reconstructed) / ((X_scaled.values) + 1e-8), axis=1) * 100

# Drop the first sequence_length rows
reconstruction_error_new = reconstruction_error[sequence_length:]

# Add the reconstruction error to the new DataFrame
new_df["Reconstruction_error_single"] = reconstruction_error_new

# Get reconstruction error arr of past 10 days
reconstruction_error_arr = []
for i in range(sequence_length, len(reconstruction_error)):
    reconstruction_error_arr.append(reconstruction_error[i - sequence_length:i])


# Add the reconstruction error array to the new DataFrame
new_df["Reconstruction_error_arr"] = reconstruction_error_arr

# %%
# plot reconstruction error scatter plot
plt.figure(figsize=(10, 5))
plt.scatter(range(len(reconstruction_error)), reconstruction_error, alpha=0.5)
plt.ylim(0, 0.5)
plt.xlabel('Sample')
# plt.ylabel('Reconstruction Error Percentage')
# plt.title('Reconstruction Error Percentage')
plt.ylabel('Reconstruction Error MAE')
plt.title('Reconstruction Error MAE')
plt.show()

# %%
reconstruction_error_arr[0]
# Out:
# array([0.00346786, 0.00279189, 0.00238325, 0.0025055 , 0.00360949,
#        0.00329989, 0.00362503, 0.00512107, 0.00316199, 0.00687034])

# %%
# Calculate the difference between the target and LSTM prediction
new_df["Bias"] = new_df["Target"] - new_df["LSTM_Pred"]

# %%
y = new_df["Bias"]
X = new_df["Reconstruction_error_single"]
# X = new_df["Reconstruction_error_arr"]

# %%
# Sequential split
train_size = int(0.7 * len(X))
val_size = int(0.15 * len(X))

X_train_raw = X[:train_size]
y_train_raw = y[:train_size]
X_val_raw = X[train_size:train_size + val_size]
y_val_raw = y[train_size:train_size + val_size]
X_test_raw = X[train_size + val_size:]
y_test_raw = y[train_size + val_size:]

# Scale using StandardScaler (fit only on train data)
# X_scaler = StandardScaler()
X_scaler = RobustScaler()
X_train_scaled = X_scaler.fit_transform(X_train_raw.values.reshape(-1, 1))
X_val_scaled = X_scaler.transform(X_val_raw.values.reshape(-1, 1))
X_test_scaled = X_scaler.transform(X_test_raw.values.reshape(-1, 1))

# y_scaler = StandardScaler()
y_scaler = RobustScaler()
y_train_scaled = y_scaler.fit_transform(y_train_raw.values.reshape(-1, 1))
y_val_scaled = y_scaler.transform(y_val_raw.values.reshape(-1, 1))
y_test_scaled = y_scaler.transform(y_test_raw.values.reshape(-1, 1))

# Convert data to PyTorch tensors
X_train = torch.tensor(X_train_scaled, dtype=torch.float32).unsqueeze(1)
y_train = torch.tensor(y_train_scaled, dtype=torch.float32).unsqueeze(1)
X_val = torch.tensor(X_val_scaled, dtype=torch.float32).unsqueeze(1)
y_val = torch.tensor(y_val_scaled, dtype=torch.float32).unsqueeze(1)
X_test = torch.tensor(X_test_scaled, dtype=torch.float32).unsqueeze(1)
y_test = torch.tensor(y_test_scaled, dtype=torch.float32).unsqueeze(1)

# Print sizes
print(f"Train: {len(X_train)}, Val: {len(X_val)}, Test: {len(X_test)}")
# Out:
# Train: 1187, Val: 254, Test: 256

# %%
# Create DataLoader
train_dataset = TensorDataset(X_train, y_train)
val_dataset = TensorDataset(X_val, y_val)
test_dataset = TensorDataset(X_test, y_test)
train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=16, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=16, shuffle=False)

import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import os
from torch.utils.data import DataLoader, TensorDataset

# Directory to save the models
save_dir = "uni_input_trials"
os.makedirs(save_dir, exist_ok=True)

# Number of trials
num_trials = 10

# Training parameters
input_size = 1
hidden_size = 32
dropout_rate = 0.0
learning_rate = 0.0001
num_epochs = 500
patience = 20

bias_model = BiasPredictor(input_size=input_size, hidden_size=hidden_size, dropout_rate=dropout_rate).to(device)

#load model
# bias_model.load_state_dict(torch.load("./models/bias_model_uni_input_section_1.pth"))
bias_model.load_state_dict(torch.load("bias_model_uni_input_section_2.pth", map_location=torch.device('cpu')))

bias_model.eval()

with torch.no_grad():
    combined_X = torch.cat((X_train, X_val, X_test), dim=0).to(device)
    y_pred = bias_model(combined_X).cpu().numpy()

outputs_unscaled = y_scaler.inverse_transform(y_pred.reshape(y_pred.shape[0], -1))


# # To store predictions for each trial
# all_predictions = {}

# for trial in range(num_trials):
#     print(f"Starting trial {trial + 1}/{num_trials}")

#     # Initialize model, loss function, and optimizer
#     bias_model = BiasPredictor(input_size=input_size, hidden_size=hidden_size, dropout_rate=dropout_rate).to(device)
#     criterion = nn.MSELoss()
#     optimizer = optim.Adam(bias_model.parameters(), lr=learning_rate)

#     best_val_loss = np.inf
#     best_epoch = 0
#     best_model_state = None  # Store best model state

#     # Training loop
#     for epoch in range(num_epochs):
#         bias_model.train()
#         train_loss = 0.0
#         for X_batch, y_batch in train_loader:
#             X_batch, y_batch = X_batch.to(device), y_batch.to(device)
#             optimizer.zero_grad()
#             outputs = bias_model(X_batch)
#             loss = criterion(outputs, y_batch)
#             loss.backward()
#             optimizer.step()
#             train_loss += loss.item() * X_batch.size(0)

#         train_loss /= len(train_loader.dataset)

#         # Validation loop
#         bias_model.eval()
#         val_loss = 0.0
#         with torch.no_grad():
#             for X_batch, y_batch in val_loader:
#                 X_batch, y_batch = X_batch.to(device), y_batch.to(device)
#                 outputs = bias_model(X_batch)
#                 loss = criterion(outputs, y_batch)
#                 val_loss += loss.item() * X_batch.size(0)

#         val_loss /= len(val_loader.dataset)

#         if val_loss < best_val_loss:
#             best_val_loss = val_loss
#             best_epoch = epoch
#             best_model_state = bias_model.state_dict()  # Save the best model state

#         elif epoch - best_epoch >= patience:
#             print(f"Trial {trial + 1}: Stopping early at epoch {epoch}")
#             break

#         print(f"Trial {trial + 1}, Epoch {epoch}, Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}")

#     # Save the best model from this trial
#     if best_model_state is not None:
#         model_filename = os.path.join(save_dir, f"bias_model_trial_{trial + 1}.pth")
#         torch.save(best_model_state, model_filename)
#         print(f"Saved model for Trial {trial + 1} to {model_filename}")

#         # Load best model and generate predictions
#         bias_model.load_state_dict(best_model_state)
#         bias_model.eval()

#         with torch.no_grad():
#             combined_X = torch.cat((X_train, X_val, X_test), dim=0).to(device)
#             y_pred = bias_model(combined_X).cpu().numpy()

#         outputs_unscaled = y_scaler.inverse_transform(y_pred.reshape(y_pred.shape[0], -1))

#         # Store predictions for this trial
#         all_predictions[f"trial_{trial + 1}"] = outputs_unscaled

# print("Completed all trials and saved models & predictions!")
# Out:
# <ipython-input-71-048f4743c33b>:35: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   bias_model.load_state_dict(torch.load("bias_model_uni_input_section_2.pth", map_location=torch.device('cpu')))

# %%
# concat y values of train test and val
combined_y = torch.cat((y_train, y_val, y_test), dim=0)
combined_y = combined_y.cpu().numpy()

# %%
# Create empty DataFrame
temp_df = pd.DataFrame()

temp_df["bias_model_uni_prediction"] = outputs_unscaled.flatten()

# %%
temp_df["LSTM_prediction_original"] = new_df["LSTM_Pred"]
temp_df["Target"] = new_df["Target"]
temp_df["New_predictions_uni"] = new_df["LSTM_Pred"] + temp_df["bias_model_uni_prediction"]

# %%
# plot graph of lstm prediction vs new predictions
plt.figure(figsize=(20, 10))
plt.plot(temp_df["New_predictions_uni"].iloc[train_size+val_size:], label='New predicted values', color='blue')
plt.plot(temp_df["LSTM_prediction_original"].iloc[train_size+val_size:], label='Original predicted values', color='red')
plt.plot(temp_df["Target"].iloc[train_size+val_size:], label='True Values', color='green')
plt.xlabel('Time')
plt.ylabel('Value')
plt.title('Actual vs. Predicted Values')
plt.legend()
plt.show()

# %%
original_LSTM_error_percent = np.mean(np.abs(temp_df["Target"].iloc[train_size+val_size:].values - temp_df["LSTM_prediction_original"].iloc[train_size+val_size:].values) / (np.abs(temp_df["Target"].iloc[train_size+val_size:].values) + 1e-8)) * 100
new_LSTM_error_percent = np.mean(np.abs(temp_df["Target"].iloc[train_size+val_size:].values - temp_df["New_predictions_uni"].iloc[train_size+val_size:].values) / (np.abs(temp_df["Target"].iloc[train_size+val_size:].values) + 1e-8)) * 100

print(f"Original LSTM Error Percentage: {original_LSTM_error_percent:.4f}%")
print(f"New LSTM Error Percentage: {new_LSTM_error_percent:.4f}%")
# Out:
# Original LSTM Error Percentage: 4.1651%
# New LSTM Error Percentage: 11.0015%

# %% [markdown]
# <span style="color: yellow; font-size: 40px;">Bias correction model - multi input</span>

# %%
temp_df
# Out:
#       bias_model_uni_prediction  LSTM_prediction_original     Target  \
# 0                      0.915157                 56.224648  54.456104
# 1                      0.832992                 55.993618  53.457096
# 2                      0.881153                 55.830799  52.352238
# 3                      0.814443                 55.628464  53.172611
# 4                      0.834069                 55.400650  51.670799
# ...                         ...                       ...        ...
# 1692                   2.863692                 68.171516  67.947273
# 1693                   3.472985                 67.981384  69.425034
# 1694                   5.743372                 67.806709  69.244072
# 1695                   2.290626                 67.598221  69.892502
# 1696                   2.281411                 67.549820  69.326996
#
#       New_predictions_uni
# 0               57.139805
# 1               56.826611
# 2               56.711952
# 3               56.442905
# 4               56.234718
# ...                   ...
# 1692            71.035210
# 1693            71.454369
# 1694            73.550079
# 1695            69.888847
# 1696            69.831230
#
# [1697 rows x 4 columns]

# %%
X_train_scaled_df = pd.DataFrame(X_train_scaled, columns=["Reconstruction_error"])
X_val_scaled_df = pd.DataFrame(X_val_scaled, columns=["Reconstruction_error"])
X_test_scaled_df = pd.DataFrame(X_test_scaled, columns=["Reconstruction_error"])

combined_X_df = pd.concat([X_train_scaled_df, X_val_scaled_df, X_test_scaled_df], axis=0)
combined_X_df
# Out:
#      Reconstruction_error
# 0                0.689263
# 1                0.290295
# 2                0.526869
# 3               -0.078275
# 4               -0.407383
# ..                    ...
# 251             17.672802
# 252             22.943972
# 253             42.585776
# 254             12.715027
# 255             12.635315
#
# [1697 rows x 1 columns]

# %%
combined_X_df['Reconstruction_error_array'] = np.nan

# Fill the new column with arrays of the past 10 reconstruction errors
# for i in range(len(combined_X_df)):
#     if i >= 9:
#         combined_X_df.at[i, 'reconstruction_error_array'] = combined_X_df['Reconstruction_error'][i-9:i+1].tolist()

reconstruction_error_arrays = []
for i in range(len(combined_X_df)):
    if i >= 9:
        reconstruction_error_arrays.append(combined_X_df['Reconstruction_error'][i-9:i+1].tolist())
    else:
        reconstruction_error_arrays.append(np.nan)  # Keep NaN for the first 9 rows

combined_X_df['Reconstruction_error_array'] = reconstruction_error_arrays

# %%
combined_X_df = combined_X_df.dropna()
combined_X_df = combined_X_df.reset_index(drop=True)
combined_X_df.head()
# Out:
#    Reconstruction_error                         Reconstruction_error_array
# 0              1.079710  [0.689263057009242, 0.2902953273256955, 0.5268...
# 1              0.139052  [0.2902953273256955, 0.5268693301464156, -0.07...
# 2              1.626927  [0.5268693301464156, -0.07827531104573687, -0....
# 3             -0.223714  [-0.07827531104573687, -0.4073827516173701, 1....
# 4              1.308804  [-0.4073827516173701, 1.277875435472884, 1.087...

# %%
if temp_df.shape[0] != combined_X_df.shape[0]:
    temp_df = temp_df.iloc[sequence_length-1:]
    temp_df = temp_df.reset_index(drop=True)
    print("Shape mismatch, adjusted DataFrame")
    print("temp_df shape:", temp_df.shape)
    print("combined_X_df shape:", combined_X_df.shape)
# Out:
# Shape mismatch, adjusted DataFrame
# temp_df shape: (1688, 4)
# combined_X_df shape: (1688, 2)

# %%
y_train_scaled_df = pd.DataFrame(y_train_scaled, columns=["Bias"])
y_val_scaled_df = pd.DataFrame(y_val_scaled, columns=["Bias"])
y_test_scaled_df = pd.DataFrame(y_test_scaled, columns=["Bias"])

combined_y_df = pd.concat([y_train_scaled_df, y_val_scaled_df, y_test_scaled_df], axis=0)

# drop first 9 rows of y
if combined_y_df.shape[0] != combined_X_df.shape[0]:
    combined_y_df = combined_y_df.iloc[sequence_length-1:]
    combined_y_df = combined_y_df.reset_index(drop=True)
    print("Shape mismatch, adjusted DataFrame")
    print("combined_y_df shape:", combined_y_df.shape)
    print("combined_X_df shape:", combined_X_df.shape)
# Out:
# Shape mismatch, adjusted DataFrame
# combined_y_df shape: (1688, 1)
# combined_X_df shape: (1688, 2)

# %%
X = combined_X_df["Reconstruction_error_array"]
y = combined_y_df['Bias']

# Sequential split
train_size = int(0.7 * len(X))
val_size = int(0.15 * len(X))

X_train_raw = X[:train_size]
y_train_raw = y[:train_size]
X_val_raw = X[train_size:train_size + val_size]
y_val_raw = y[train_size:train_size + val_size]
X_test_raw = X[train_size + val_size:]
y_test_raw = y[train_size + val_size:]

# Convert data to PyTorch tensors
# X_train = torch.tensor(X_train_raw, dtype=torch.float32).unsqueeze(1)
# y_train = torch.tensor(y_train_raw, dtype=torch.float32).unsqueeze(1)
# X_val = torch.tensor(X_val_raw, dtype=torch.float32).unsqueeze(1)
# y_val = torch.tensor(y_val_raw, dtype=torch.float32).unsqueeze(1)
# X_test = torch.tensor(X_test_raw, dtype=torch.float32).unsqueeze(1)
# y_test = torch.tensor(y_test_raw, dtype=torch.float32).unsqueeze(1)
X_train = torch.tensor(np.stack(X_train_raw.values), dtype=torch.float32)
y_train = torch.tensor(y_train_raw.values, dtype=torch.float32).unsqueeze(1)
X_val = torch.tensor(np.stack(X_val_raw.values), dtype=torch.float32)
y_val = torch.tensor(y_val_raw.values, dtype=torch.float32).unsqueeze(1)
X_test = torch.tensor(np.stack(X_test_raw.values), dtype=torch.float32)
y_test = torch.tensor(y_test_raw.values, dtype=torch.float32).unsqueeze(1)

# Print sizes
print(f"Train: {len(X_train)}, Val: {len(X_val)}, Test: {len(X_test)}")
# Out:
# Train: 1181, Val: 253, Test: 254

# %%
# Define bias predictor model
class BiasPredictor(nn.Module):
    def __init__(self, input_size, hidden_size, dropout_rate, use_bn):
        super(BiasPredictor, self).__init__()

        hidden_size2 = hidden_size // 2
        hidden_size3 = hidden_size2 // 2

        self.use_bn = use_bn

        self.fc1 = nn.Linear(input_size, hidden_size)
        self.bn1 = nn.BatchNorm1d(hidden_size) if use_bn else nn.Identity()
        self.dropout1 = nn.Dropout(dropout_rate)

        self.fc2 = nn.Linear(hidden_size, hidden_size2)
        self.bn2 = nn.BatchNorm1d(hidden_size2) if use_bn else nn.Identity()
        self.dropout2 = nn.Dropout(dropout_rate)

        self.fc3 = nn.Linear(hidden_size2, hidden_size3)
        self.bn3 = nn.BatchNorm1d(hidden_size3) if use_bn else nn.Identity()
        self.dropout3 = nn.Dropout(dropout_rate)

        self.fc4 = nn.Linear(hidden_size3, 1)

    def forward(self, x):
        x = F.leaky_relu(self.bn1(self.fc1(x)))
        x = self.dropout1(x)

        x = F.leaky_relu(self.bn2(self.fc2(x)))
        x = self.dropout2(x)

        x = F.leaky_relu(self.bn3(self.fc3(x)))
        x = self.dropout3(x)

        return self.fc4(x)

# %%
# Training function
def train_bias_predictor(model, train_loader, val_loader, num_epochs, patience, learning_rate):
    model.to(device)
    criterion = nn.MSELoss()
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)

    best_val_loss = np.inf
    best_epoch = 0
    history = {"train_loss": [], "val_loss": []}

    for epoch in range(num_epochs):
        ###### Training Phase ######
        model.train()
        train_loss = 0.0

        for X_batch, y_batch in train_loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)

            optimizer.zero_grad()
            outputs = model(X_batch)
            loss = criterion(outputs, y_batch)
            loss.backward()
            optimizer.step()

            train_loss += loss.item() * X_batch.size(0)

        train_loss /= len(train_loader.dataset)
        history["train_loss"].append(train_loss)

        ###### Validation Phase ######
        model.eval()
        val_loss = 0.0

        with torch.no_grad():
            for X_batch, y_batch in val_loader:
                X_batch, y_batch = X_batch.to(device), y_batch.to(device)
                outputs = model(X_batch)
                loss = criterion(outputs, y_batch)
                val_loss += loss.item() * X_batch.size(0)

        val_loss /= len(val_loader.dataset)
        history["val_loss"].append(val_loss)

        # Print Progress
        print(f"📉 Epoch {epoch+1}/{num_epochs} - Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}")

        # Early Stopping Check
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            best_epoch = epoch
            best_model = model  # Store best model
        elif epoch - best_epoch >= patience:
            print(f"⏹️ Early stopping triggered at epoch {epoch+1}. Best epoch: {best_epoch+1}, Best Val Loss: {best_val_loss:.4f}")
            break

    return best_model, history

# %%
# # Create dataloader
# train_dataset = TensorDataset(X_train, y_train)
# val_dataset = TensorDataset(X_val, y_val)
# test_dataset = TensorDataset(X_test, y_test)
# train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
# val_loader = DataLoader(val_dataset, batch_size=16, shuffle=False)
# test_loader = DataLoader(test_dataset, batch_size=16, shuffle=False)

# Hyperparameters
input_size = 10
hidden_size = 16
dropout_rate = 0.0
use_bn = False
learning_rate = 0.0001
num_epochs = 500
patience = 20

arr_model = BiasPredictor(input_size=input_size, hidden_size=hidden_size, dropout_rate=dropout_rate, use_bn=use_bn).to(device)

# arr_model.load_state_dict(torch.load("./models/bias_model_arr_input_section_1.pth"))
arr_model.load_state_dict(torch.load("bias_model_arr_input_section_2.pth", map_location=torch.device('cpu')))
# Out:
# <ipython-input-86-253e392d4b86>:21: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   arr_model.load_state_dict(torch.load("bias_model_arr_input_section_2.pth", map_location=torch.device('cpu')))
# <All keys matched successfully>

# %%
arr_model.eval()

with torch.no_grad():
    X_tensor = torch.tensor(X, dtype=torch.float32).to(device)
    y_pred_arr = arr_model(X_tensor).cpu().numpy()

outputs_arr_unscaled = y_scaler.inverse_transform(y_pred_arr.reshape(y_pred_arr.shape[0], -1))

# Add predictions into df
temp_df["bias_model_arr_prediction"] = outputs_arr_unscaled.flatten()
temp_df['New_predictions_arr'] = temp_df["LSTM_prediction_original"] + temp_df["bias_model_arr_prediction"]

# %%
temp_df
# Out:
#       bias_model_uni_prediction  LSTM_prediction_original     Target  \
# 0                      0.982707                 54.226685  57.261292
# 1                      0.812585                 54.316078  58.399250
# 2                      1.027725                 54.464622  58.644016
# 3                      0.821752                 54.754524  59.656273
# 4                      1.004773                 55.168800  59.226238
# ...                         ...                       ...        ...
# 1683                   2.863692                 68.171516  67.947273
# 1684                   3.472985                 67.981384  69.425034
# 1685                   5.743372                 67.806709  69.244072
# 1686                   2.290626                 67.598221  69.892502
# 1687                   2.281411                 67.549820  69.326996
#
#       New_predictions_uni  bias_model_arr_prediction  New_predictions_arr
# 0               55.209393                   0.868991            55.095676
# 1               55.128662                   0.876599            55.192677
# 2               55.492348                   0.866086            55.330708
# 3               55.576275                   0.883313            55.637836
# 4               56.173573                   0.882875            56.051674
# ...                   ...                        ...                  ...
# 1683            71.035210                   0.954867            69.126381
# 1684            71.454369                   0.954834            68.936218
# 1685            73.550079                   0.948759            68.755470
# 1686            69.888847                   1.360027            68.958244
# 1687            69.831230                   0.954478            68.504295
#
# [1688 rows x 6 columns]

# %%
# plot line graph of bias_model_arr_prediction vs original
plt.figure(figsize=(20, 10))
plt.plot(temp_df["New_predictions_arr"].iloc[train_size+val_size:], label='Array predictions', color='blue')
plt.plot(temp_df["New_predictions_uni"].iloc[train_size+val_size:], label='Single input predictions', color='red')
plt.plot(temp_df["Target"].iloc[train_size+val_size:], label='True Values', color='green')
plt.xlabel('Time')
plt.ylabel('Value')
plt.title('Actual vs. Predicted Values')
plt.legend()
plt.show()

# %%
# get prediction error percentages
original_error_percent = np.mean(np.abs(temp_df["Target"].iloc[train_size+val_size:].values - temp_df["LSTM_prediction_original"].iloc[train_size+val_size:].values) / (np.abs(temp_df["Target"].iloc[train_size+val_size:].values) + 1e-8)) * 100
uni_input_error_percent = np.mean(np.abs(temp_df["Target"].iloc[train_size+val_size:].values - temp_df["New_predictions_uni"].iloc[train_size+val_size:].values) / (np.abs(temp_df["Target"].iloc[train_size+val_size:].values) + 1e-8)) * 100
arr_input_error_percent = np.mean(np.abs(temp_df["Target"].iloc[train_size+val_size:].values - temp_df["New_predictions_arr"].iloc[train_size+val_size:].values) / (np.abs(temp_df["Target"].iloc[train_size+val_size:].values) + 1e-8)) * 100

print("Percentages over test set\n")
print(f"Original LSTM Error Percentage: {original_error_percent:.4f}%")
print(f"New LSTM Error Percentage (Single Input): {uni_input_error_percent:.4f}%")
print(f"New LSTM Error Percentage (Array Input): {arr_input_error_percent:.4f}%")
# Out:
# Percentages over test set
#
# Original LSTM Error Percentage: 4.1752%
# New LSTM Error Percentage (Single Input): 11.0497%
# New LSTM Error Percentage (Array Input): 4.3692%

# %%
# plot graph over entire dataset
plt.figure(figsize=(20, 10))
plt.plot(temp_df["New_predictions_arr"], label='Array predictions', color='blue')
plt.plot(temp_df["New_predictions_uni"], label='Single input predictions', color='red')
plt.plot(temp_df["Target"], label='True Values', color='green')
plt.xlabel('Time')
plt.ylabel('Value')
plt.title('Actual vs. Predicted Values')
plt.legend()
plt.show()

# %%
# get prediction error percentages
original_error_percent = np.mean(np.abs(temp_df["Target"].values - temp_df["LSTM_prediction_original"].values) / (np.abs(temp_df["Target"].values) + 1e-8)) * 100
uni_input_error_percent = np.mean(np.abs(temp_df["Target"].values - temp_df["New_predictions_uni"].values) / (np.abs(temp_df["Target"].values) + 1e-8)) * 100
arr_input_error_percent = np.mean(np.abs(temp_df["Target"].values - temp_df["New_predictions_arr"].values) / (np.abs(temp_df["Target"].values) + 1e-8)) * 100

print("Percentages over entire set\n")
print(f"Original LSTM Error Percentage: {original_error_percent:.4f}%")
print(f"New LSTM Error Percentage (Single Input): {uni_input_error_percent:.4f}%")
print(f"New LSTM Error Percentage (Array Input): {arr_input_error_percent:.4f}%")
# Out:
# Percentages over entire set
#
# Original LSTM Error Percentage: 2.0790%
# New LSTM Error Percentage (Single Input): 2.9527%
# New LSTM Error Percentage (Array Input): 1.8873%

# %% [markdown]
# <span style="color: yellow; font-size: 40px;">Bias correction model - multi input with SHAP</span>

# %%
import shap

# Define a custom wrapper for the PyTorch model
class ModelWrapper:
    def __init__(self, model):
        self.model = model

    def __call__(self, data):
        self.model.eval()
        with torch.no_grad():
            data = torch.tensor(data, dtype=torch.float32).to(device)
            return self.model(data).cpu().numpy()

arr_model.eval()

# Create SHAP explainer
wrapped_model = ModelWrapper(arr_model)
explainer = shap.Explainer(wrapped_model, X_test.cpu().numpy())



print("Running SHAP explainer...")
shap_values = explainer(X_test.cpu().numpy())
# Convert to numpy
shap_values_array = shap_values.values

# Average SHAP values across all test samples
feature_importance = np.mean(np.abs(shap_values_array), axis=0)

# Create labels for the features
num_features = len(feature_importance)
feature_labels = [f"Day {i+1}" for i in range(num_features)]
# Out:
# Running SHAP explainer...
# ExactExplainer explainer: 255it [00:14, 15.17it/s]

# %%
# Plot feature importance
plt.figure(figsize=(10, 5))
plt.barh(feature_labels, feature_importance)
plt.xlabel('Average SHAP Value')
plt.title('Feature Importance')
plt.show()

# Display results
day = 1
for i in feature_importance:
    print(f"Day {day}: {i:.4f}")
    day += 1
# Out:
# Day 1: 0.0482
# Day 2: 0.1228
# Day 3: 0.1120
# Day 4: 0.1223
# Day 5: 0.0735
# Day 6: 0.1484
# Day 7: 0.1036
# Day 8: 0.1805
# Day 9: 0.2608
# Day 10: 0.1127

# %%
# Normalize feature importance such that sum = 1
normalized_importance = feature_importance / np.sum(feature_importance)

# Plot graph
plt.figure(figsize=(10, 5))
plt.barh(feature_labels, normalized_importance)
plt.xlabel('Normalized Importance')
plt.title('Feature Importance (Normalized)')
plt.show()

day = 1
for i in normalized_importance:
    print(f"Day {day}: {i:.4f}")
    day += 1
# Out:
# Day 1: 0.0375
# Day 2: 0.0956
# Day 3: 0.0872
# Day 4: 0.0952
# Day 5: 0.0572
# Day 6: 0.1155
# Day 7: 0.0806
# Day 8: 0.1405
# Day 9: 0.2030
# Day 10: 0.0877

# %%
sum = 0
for i in normalized_importance:
    sum += i

print(f"Total: {sum:.4f}")
# Out:
# Total: 1.0000

# %%
weighted = 0

if weighted == 0:
    # Multiply X by weights
    X_weighted = X.apply(lambda arr: arr * normalized_importance)
    weighted = 1
    # Print the first few elements to verify
    X_weighted.head()

# %%
X = X_weighted
y = combined_y_df['Bias']

# Sequential split
train_size = int(0.7 * len(X))
val_size = int(0.15 * len(X))

X_train_raw = X[:train_size]
y_train_raw = y[:train_size]
X_val_raw = X[train_size:train_size + val_size]
y_val_raw = y[train_size:train_size + val_size]
X_test_raw = X[train_size + val_size:]
y_test_raw = y[train_size + val_size:]

# Convert data to PyTorch tensors
# X_train = torch.tensor(X_train_raw, dtype=torch.float32).unsqueeze(1)
# y_train = torch.tensor(y_train_raw, dtype=torch.float32).unsqueeze(1)
# X_val = torch.tensor(X_val_raw, dtype=torch.float32).unsqueeze(1)
# y_val = torch.tensor(y_val_raw, dtype=torch.float32).unsqueeze(1)
# X_test = torch.tensor(X_test_raw, dtype=torch.float32).unsqueeze(1)
# y_test = torch.tensor(y_test_raw, dtype=torch.float32).unsqueeze(1)
X_train = torch.tensor(np.stack(X_train_raw.values), dtype=torch.float32)
y_train = torch.tensor(y_train_raw.values, dtype=torch.float32).unsqueeze(1)
X_val = torch.tensor(np.stack(X_val_raw.values), dtype=torch.float32)
y_val = torch.tensor(y_val_raw.values, dtype=torch.float32).unsqueeze(1)
X_test = torch.tensor(np.stack(X_test_raw.values), dtype=torch.float32)
y_test = torch.tensor(y_test_raw.values, dtype=torch.float32).unsqueeze(1)

# Print sizes
print(f"Train: {len(X_train)}, Val: {len(X_val)}, Test: {len(X_test)}")
# Out:
# Train: 1181, Val: 253, Test: 254

# %%
import itertools

# Create dataloader
train_dataset = TensorDataset(X_train, y_train)
val_dataset = TensorDataset(X_val, y_val)
test_dataset = TensorDataset(X_test, y_test)
train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=16, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=16, shuffle=False)

# # Hyperparameters
# input_size = 10
# hidden_size = 64
# dropout_rate = 0.2
# use_bn = True
# learning_rate = 0.0005
# num_epochs = 500
# patience = 20

# model = BiasPredictor(input_size=input_size, hidden_size=hidden_size, dropout_rate=dropout_rate, use_bn=use_bn).to(device)

# best_model, history = train_bias_predictor(model, train_loader, val_loader, num_epochs, patience, learning_rate)

# Define hyperparameter search space
param_grid = {
    "hidden_size": [16,32, 64, 128],
    "dropout_rate": [0.0, 0.1, 0.2, 0.3],
    "use_bn": [True, False],
    "learning_rate": [0.001, 0.0005, 0.0001],
    "batch_size" : [8,16,32]
}

# Number of runs per combination
num_repeats = 5

# Store results
results = []

# Define device
device = "cuda" if torch.cuda.is_available() else "cpu"

total_combinations = np.prod([len(v) for v in param_grid.values()])
count = 0
# Grid search loop
for params in itertools.product(*param_grid.values()):
    hidden_size, dropout_rate, use_bn, learning_rate, batch_size = params
    param_key = f"HS={hidden_size}, DR={dropout_rate}, BN={use_bn}, LR={learning_rate}, BS={batch_size}"

    print(f"\n🔍 Testing: {param_key}")
    print(f"{count} / {total_combinations} combinations\n")
    count += 1

    # Store metrics across runs
    avg_train_loss, avg_val_loss, avg_mae, avg_mse, avg_percent_error = 0, 0, 0, 0, 0

    for run in range(num_repeats):
        print(f"⚡ Run {run+1}/{num_repeats}")

        train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
        val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

        # Initialize model
        model = BiasPredictor(input_size=10, hidden_size=hidden_size, dropout_rate=dropout_rate, use_bn=use_bn).to(device)

        # Train model
        best_model, history = train_bias_predictor(model, train_loader, val_loader, num_epochs=500, patience=20, learning_rate=learning_rate)

        # Evaluate performance
        with torch.no_grad():
            X_tensor = torch.tensor(X, dtype=torch.float32).to(device)
            y_pred_arr = best_model(X_tensor).cpu().numpy()

        # Unscale predictions
        outputs_arr_unscaled = y_scaler.inverse_transform(y_pred_arr.reshape(y_pred_arr.shape[0], -1))

        # Store predictions
        temp_df["bias_model_arr_prediction"] = outputs_arr_unscaled.flatten()
        temp_df["New_predictions_arr"] = temp_df["LSTM_prediction_original"] + temp_df["bias_model_arr_prediction"]

        # Compute error metrics
        target_vals = temp_df["Target"].iloc[train_size+val_size:].values
        pred_vals = temp_df["New_predictions_arr"].iloc[train_size+val_size:].values

        mae = np.mean(np.abs(target_vals - pred_vals))
        mse = np.mean((target_vals - pred_vals) ** 2)
        percent_error = np.mean(np.abs(target_vals - pred_vals) / (np.abs(target_vals) + 1e-8)) * 100

        # Accumulate metrics
        avg_train_loss += history["train_loss"][-1] / num_repeats
        avg_val_loss += history["val_loss"][-1] / num_repeats
        avg_mae += mae / num_repeats
        avg_mse += mse / num_repeats
        avg_percent_error += percent_error / num_repeats

    # Store results
    results.append({
        "hidden_size": hidden_size,
        "dropout_rate": dropout_rate,
        "use_bn": use_bn,
        "learning_rate": learning_rate,
        "batch_size": batch_size,
        "train_loss": avg_train_loss,
        "val_loss": avg_val_loss,
        "MAE": avg_mae,
        "MSE": avg_mse,
        "Percent Error": avg_percent_error
    })

# Convert results to DataFrame and sort by best validation loss
results_df = pd.DataFrame(results)
results_df = results_df.sort_values(by="Percent Error", ascending=True)

# Print best hyperparameters
best_params = results_df.iloc[0]
print("\n🏆 Best Hyperparameters Found:")
print(best_params)

# Save results to CSV
results_df.to_csv("grid_search_results.csv", index=False)
# Out:
# 🔍 Testing: HS=16, DR=0.0, BN=True, LR=0.001, BS=8
# 0 / 288 combinations
#
# ⚡ Run 1/5
# 📉 Epoch 1/500 - Train Loss: 0.
# 📉 Epoch 34/500 - Train Loss: 0.5527, Val Loss: 9.0425
# 📉 Epoch 35/500 - Train Loss: 0.5508, Val Loss: 12.4468
# 📉 Epoch 36/500 - Train Loss: 0.5610, Val Loss: 7.8858
# 📉 Epoch 37/500 - Train Loss: 0.5584, Val Loss: 9.9866
# 📉 Epoch 38/500 - Train Loss: 0.5566, Val Loss: 18.0732
# 📉 Epoch 39/500 - Train Loss: 0.5499, Val Loss: 10.8956
# 📉 Epoch 40/500 - Train Loss: 0.5560, Val Loss: 9.2980
# 📉 Epoch 41/500 - Train Loss: 0.5582, Val Loss: 9.7743
# 📉 Epoch 42/500 - Train Loss: 0.5576, Val Loss: 9.9657
# 📉 Epoch 43/500 - Train Loss: 0.5545, Val Loss: 20.4875
# ⏹️ Early stopping triggered at epoch 43. Best epoch: 23, Best Val Loss: 4.7283
#
# 🔍 Testing: HS=128, DR=0.2, BN=True, LR=0.001, BS=16
# 253 / 288 combinations
#
# ⚡ Run 1/5
# 📉 Epoch 1/500 - Train Loss: 0.6471, Val Loss: 6.1073
# 📉 Epoch 2/500 - Train Loss: 0.6058, Val Loss: 6.8876
# 📉 Epoch 3/500 - Train Loss: 0.5873, Val Loss: 6.5533
# 📉 Epoch 4/500 - Train Loss: 0.5727, Val Loss: 8.6311
# 📉 Epoch 5/500 - Train Loss: 0.5798, Val Loss: 10.2709
# 📉 Epoch 6/500 - Train Loss: 0.5764, Val Loss: 9.7157
# 📉 Epoch 7/500 - Train Loss: 0.5687, Val Loss: 8.8620
# 📉 Epoch 8/500 - Train Loss: 0.5491, Val Loss: 6.8327
# 📉 Epoch 9/500 - Train Loss: 0.5672, Val Loss: 7.4021
# 📉 Epoch 10/500 - Train Loss: 0.5646, Val Loss: 7.1783
# 📉 Epoch 11/500 - Train Loss: 0.5566, Val Loss: 9.4163
# 📉 Epoch 12/500 - Train Loss: 0.5555, Val Loss: 7.4027
# 📉 Epoch 13/500 - Train Loss: 0.5490, Val Loss: 5.9726
# 📉 Epoch 14/500 - Train Loss: 0.5543, Val Loss: 4.5206
# 📉 Epoch 15/500 - Train Loss: 0.5470, Val Loss: 7.6402
# 📉 Epoch 16/500 - Train Loss: 0.5444, Val Loss: 6.6433
# 📉 Epoch 17/500 - Train Loss: 0.5588, Val Loss: 7.6153
# 📉 Epoch 18/500 - Train Loss: 0.5616, Val Loss: 6.4332
# 📉 Epoch 19/500 - Train Loss: 0.5522, Val Loss: 8.4237
# 📉 Epoch 20/500 - Train Loss: 0.5552, Val Loss: 9.0449
# 📉 Epoch 21/500 - Train Loss: 0.5493, Val Loss: 9.3709
# 📉 Epoch 22/500 - Train Loss: 0.5549, Val Loss: 8.6961
# 📉 Epoch 23/500 - Train Loss: 0.5348, Val Loss: 17.1170
# 📉 Epoch 24/500 - Train Loss: 0.5368, Val Loss: 15.5540
# 📉 Epoch 25/500 - Train Loss: 0.5395, Val Loss: 9.7058
# 📉 Epoch 26/500 - Train Loss: 0.5600, Val Loss: 10.4210
# 📉 Epoch 27/500 - Train Loss: 0.5322, Val Loss: 14.5071
# 📉 Epoch 28/500 - Train Loss: 0.5421, Val Loss: 11.2680
# 📉 Epoch 39/500 - Train Loss: 0.5401, Val Loss: 12.3239
# 📉 Epoch 40/500 - Train Loss: 0.5369, Val Loss: 12.2299
# 📉 Epoch 41/500 - Train Loss: 0.5413, Val Loss: 11.7185
# 📉 Epoch 42/500 - Train Loss: 0.5517, Val Loss: 15.1406
# 📉 Epoch 43/500 - Train Loss: 0.5496, Val Loss: 10.9763
# ⏹️ Early stopping triggered at epoch 43. Best epoch: 23, Best Val Loss: 6.8867
# ⚡ Run 5/5
# 📉 Epoch 1/500 - Train Loss: 0.7243, Val Loss: 9.3100
# 📉 Epoch 2/500 - Train Loss: 0.6579, Val Loss: 9.0957
# 📉 Epoch 3/500 - Train Loss: 0.6213, Val Loss: 12.3443
# 📉 Epoch 4/500 - Train Loss: 0.6137, Val Loss: 13.9530
# 📉 Epoch 5/500 - Train Loss: 0.6022, Val Loss: 16.4596
# 📉 Epoch 6/500 - Train Loss: 0.5735, Val Loss: 16.5764
# 📉 Epoch 7/500 - Train Loss: 0.6003, Val Loss: 7.2888
# 📉 Epoch 8/500 - Train Loss: 0.5796, Val Loss: 10.3223
# 📉 Epoch 9/500 - Train Loss: 0.5822, Val Loss: 7.4825
# 📉 Epoch 10/500 - Train Loss: 0.5764, Val Loss: 8.9775
# 📉 Epoch 11/500 - Train Loss: 0.5587, Val Loss: 10.0972
# 📉 Epoch 12/500 - Train Loss: 0.5799, Val Loss: 14.4241
# 📉 Epoch 13/500 - Train Loss: 0.5682, Val Loss: 13.3332
# 📉 Epoch 14/500 - Train Loss: 0.5637, Val Loss: 8.9415
# 📉 Epoch 15/500 - Train Loss: 0.5727, Val Loss: 15.1542
# 📉 Epoch 16/500 - Train Loss: 0.5639, Val Loss: 11.6417
# 📉 Epoch 17/500 - Train Loss: 0.5637, Val Loss: 10.0988
# 📉 Epoch 18/500 - Train Loss: 0.5603, Val Loss: 10.2365
# 📉 Epoch 19/500 - Train Loss: 0.5507, Val Loss: 10.8525
# 📉 Epoch 20/500 - Train Loss: 0.5637, Val Loss: 9.7133
# 📉 Epoch 21/500 - Train Loss: 0.5589, Val Loss: 12.7326
# 📉 Epoch 22/500 - Train Loss: 0.5584, Val Loss: 10.8516
# 📉 Epoch 23/500 - Train Loss: 0.5401, Val Loss: 13.0785
# 📉 Epoch 24/500 - Train Loss: 0.5555, Val Loss: 11.0532
# 📉 Epoch 25/500 - Train Loss: 0.5521, Val Loss: 8.7888
# 📉 Epoch 26/500 - Train Loss: 0.5539, Val Loss: 8.7132
# 📉 Epoch 27/500 - Train Loss: 0.5396, Val Loss: 8.1862
# ⏹️ Early stopping triggered at epoch 27. Best epoch: 7, Best Val Loss: 7.2888
#
# 🔍 Testing: HS=128, DR=0.2, BN=True, LR=0.0005, BS=32
# 257 / 288 combinations
#
# ⚡ Run 1/5
# 📉 Epoch 1/500 - Train Loss: 0
# ⏹️ Early stopping triggered at epoch 21. Best epoch: 1, Best Val Loss: 3.9408
# ⚡ Run 5/5
# 📉 Epoch 1/500 - Train Loss: 0.7220, Val Loss: 3.9814
# 📉 Epoch 2/500 - Train Loss: 0.6652, Val Loss: 17.4282
# 📉 Epoch 3/500 - Train Loss: 0.6240, Val Loss: 16.0406
# 📉 Epoch 4/500 - Train Loss: 0.6211, Val Loss: 12.3594
# 📉 Epoch 5/500 - Train Loss: 0.5895, Val Loss: 16.8025
# 📉 Epoch 6/500 - Train Loss: 0.5679, Val Loss: 11.6555
# 📉 Epoch 7/500 - Train Loss: 0.5972, Val Loss: 15.5305
# 📉 Epoch 8/500 - Train Loss: 0.5886, Val Loss: 11.1765
# 📉 Epoch 9/500 - Train Loss: 0.5762, Val Loss: 9.3479
# 📉 Epoch 10/500 - Train Loss: 0.5789, Val Loss: 8.6100
# 📉 Epoch 11/500 - Train Loss: 0.5716, Val Loss: 11.6025
# 📉 Epoch 12/500 - Train Loss: 0.5636, Val Loss: 10.3417
# 📉 Epoch 13/500 - Train Loss: 0.5601, Val Loss: 9.3356
# 📉 Epoch 14/500 - Train Loss: 0.5696, Val Loss: 8.2704
# 📉 Epoch 15/500 - Train Loss: 0.5652, Val Loss: 9.1654
# 📉 Epoch 16/500 - Train Loss: 0.5515, Val Loss: 9.1631
# 📉 Epoch 17/500 - Train Loss: 0.5632, Val Loss: 9.4321
# 📉 Epoch 18/500 - Train Loss: 0.5650, Val Loss: 8.4456
# 📉 Epoch 19/500 - Train Loss: 0.5637, Val Loss: 9.1563
# 📉 Epoch 20/500 - Train Loss: 0.5453, Val Loss: 12.6859
# 📉 Epoch 21/500 - Train Loss: 0.5603, Val Loss: 10.7437
# ⏹️ Early stopping triggered at epoch 21. Best epoch: 1, Best Val Loss: 3.9814
#
# 🔍 Testing: HS=128, DR=0.2, BN=True, LR=0.0001, BS=8
# 258 / 288 combinations
#
# ⚡ Run 1/5
# 📉 Epoch 1/500 - Train Loss: 0.6670, Val Loss: 19.8939
# 📉 Epoch 2/500 - Train Loss: 0.6557, Val Loss: 12.2433
# 📉 Epoch 3/500 - Train Loss: 0.6734, Val Loss: 11.4570
# 📉 Epoch 4/500 - Train Loss: 0.6403, Val Loss: 15.5021
# 📉 Epoch 5/500 - Train Loss: 0.6434, Val Loss: 12.5707
# 📉 Epoch 6/500 - Train Loss: 0.6265, Val Loss: 10.0049
# 📉 Epoch 7/500 - Train Loss: 0.6368, Val Loss: 13.4233
# 📉 Epoch 8/500 - Train Loss: 0.6163, Val Loss: 16.3458
# 📉 Epoch 9/500 - Train Loss: 0.5925, Val Loss: 8.0704
# 📉 Epoch 10/500 - Train Loss: 0.5989, Val Loss: 18.1112
# 📉 Epoch 11/500 - Train Loss: 0.6008, Val Loss: 9.9007
# 📉 Epoch 12/500 - Train Loss: 0.6272, Val Loss: 10.2621
# 📉 Epoch 13/500 - Train Loss: 0.6043, Val Loss: 10.3568
# 📉 Epoch 14/500 - Train Loss: 0.5989, Val Loss: 9.9232
# 📉 Epoch 15/500 - Train Loss: 0.5754, Val Loss: 8.9185
# ⚡ Run 2/5
# 📉 Epoch 1/500 - Train Loss: 1.0088, Val Loss: 32.2737
# 📉 Epoch 2/500 - Train Loss: 0.8391, Val Loss: 19.9884
# 📉 Epoch 3/500 - Train Loss: 0.7279, Val Loss: 14.8451
# 📉 Epoch 4/500 - Train Loss: 0.6853, Val Loss: 10.2807
# 📉 Epoch 5/500 - Train Loss: 0.6538, Val Loss: 9.7051
# 📉 Epoch 6/500 - Train Loss: 0.6510, Val Loss: 9.1312
# 📉 Epoch 7/500 - Train Loss: 0.6612, Val Loss: 9.5575
# 📉 Epoch 8/500 - Train Loss: 0.6316, Val Loss: 6.7988
# 📉 Epoch 9/500 - Train Loss: 0.6303, Val Loss: 6.3070
# 📉 Epoch 10/500 - Train Loss: 0.6267, Val Loss: 8.5591
# 📉 Epoch 11/500 - Train Loss: 0.6401, Val Loss: 7.0331
# 📉 Epoch 12/500 - Train Loss: 0.5997, Val Loss: 8.0782
# 📉 Epoch 13/500 - Train Loss: 0.6327, Val Loss: 8.1871
# 📉 Epoch 14/500 - Train Loss: 0.6055, Val Loss: 7.8368
# 📉 Epoch 15/500 - Train Loss: 0.6256, Val Loss: 9.8117
# 📉 Epoch 16/500 - Train Loss: 0.6168, Val Loss: 9.5087
# 📉 Epoch 17/500 - Train Loss: 0.5947, Val Loss: 10.9302
# 📉 Epoch 18/500 - Train Loss: 0.5903, Val Loss: 11.6425
# 📉 Epoch 19/500 - Train Loss: 0.6135, Val Loss: 10.2704
# 📉 Epoch 20/500 - Train Loss: 0.6094, Val Loss: 9.9107
# 📉 Epoch 21/500 - Train Loss: 0.5845, Val Loss: 9.0705
# 📉 Epoch 22/500 - Train Loss: 0.6017, Val Loss: 9.9552
# 📉 Epoch 23/500 - Train Loss: 0.6115, Val Loss: 11.1780
# 📉 Epoch 24/500 - Train Loss: 0.6150, Val Loss: 14.2273
# 📉 Epoch 25/500 - Train Loss: 0.5924, Val Loss: 18.6233
# 📉 Epoch 26/500 - Train Loss: 0.5769, Val Loss: 10.1816
# 📉 Epoch 27/500 - Train Loss: 0.5859, Val Loss: 10.8580
# 📉 Epoch 28/500 - Train Loss: 0.5902, Val Loss: 10.7162
# 📉 Epoch 29/500 - Train Loss: 0.5853, Val Loss: 9.0174
# ⏹️ Early stopping triggered at epoch 29. Best epoch: 9, Best Val Loss: 6.3070
# ⚡ Run 3/5
# 📉 Epoch 1/500 - Train Loss: 0.8794, Val Loss: 15.5550
# 📉 Epoch 2/500 - Train Loss: 0.7797, Val Loss: 16.0378
# 📉 Epoch 3/500 - Train Loss: 0.7226, Val Loss: 20.0300
# 📉 Epoch 4/500 - Train Loss: 0.6714, Val Loss: 9.9549
# 📉 Epoch 5/500 - Train Loss: 0.6243, Val Loss: 10.4715
# 📉 Epoch 6/500 - Train Loss: 0.6399, Val Loss: 12.0273
# ...
# 📉 Epoch 8/500 - Train Loss: 0.5750, Val Loss: 2.4188
# 📉 Epoch 9/500 - Train Loss: 0.5744, Val Loss: 2.4645
# 📉 Epoch 10/500 - Train Loss: 0.5732, Val Loss: 2.5293
# 📉 Epoch 11/500 - Train Loss: 0.5746, Val Loss: 2.5600
# 📉 Epoch 12/500 - Train Loss: 0.5709, Val Loss: 2.6093
# 📉 Epoch 13/500 - Train Loss: 0.5696, Val Loss: 2.6446
# 📉 Epoch 14/500 - Train Loss: 0.5730, Val Loss: 2.6662
# 📉 Epoch 15/500 - Train Loss: 0.5725, Val Loss: 2.7080
# 📉 Epoch 16/500 - Train Loss: 0.5698, Val Loss: 2.7300
# 📉 Epoch 17/500 - Train Loss: 0.5737, Val Loss: 2.7678
# 📉 Epoch 18/500 - Train Loss: 0.5667, Val Loss: 2.8101
# 📉 Epoch 19/500 - Train Loss: 0.5709, Val Loss: 2.8323
# 📉 Epoch 20/500 - Train Loss: 0.5743, Val Loss: 2.8642
# 📉 Epoch 21/500 - Train Loss: 0.5703, Val Loss: 2.8858
# 📉 Epoch 22/500 - Train Loss: 0.5722, Val Loss: 2.9195
# 📉 Epoch 23/500 - Train Loss: 0.5722, Val Loss: 2.9605
# ⏹️ Early stopping triggered at epoch 23. Best epoch: 3, Best Val Loss: 2.2022
# ⚡ Run 5/5
# 📉 Epoch 1/500 - Train Loss: 0.5732, Val Loss: 2.1937
# 📉 Epoch 2/500 - Train Loss: 0.5720, Val Loss: 2.2332
# 📉 Epoch 3/500 - Train Loss: 0.5731, Val Loss: 2.2760
# 📉 Epoch 4/500 - Train Loss: 0.5707, Val Loss: 2.2859
# 📉 Epoch 5/500 - Train Loss: 0.5718, Val Loss: 2.3167
# 📉 Epoch 6/500 - Train Loss: 0.5700, Val Loss: 2.3375
# 📉 Epoch 7/500 - Train Loss: 0.5702, Val Loss: 2.3771
# 📉 Epoch 8/500 - Train Loss: 0.5699, Val Loss: 2.3992
# 📉 Epoch 9/500 - Train Loss: 0.5698, Val Loss: 2.4474
# 📉 Epoch 10/500 - Train Loss: 0.5706, Val Loss: 2.4920
# 📉 Epoch 11/500 - Train Loss: 0.5676, Val Loss: 2.5457
# 📉 Epoch 12/500 - Train Loss: 0.5701, Val Loss: 2.6334
# 📉 Epoch 13/500 - Train Loss: 0.5658, Val Loss: 2.6992
# 📉 Epoch 14/500 - Train Loss: 0.5690, Val Loss: 2.7769
# 📉 Epoch 15/500 - Train Loss: 0.5694, Val Loss: 2.8576
# 📉 Epoch 16/500 - Train Loss: 0.5654, Val Loss: 2.9950
# 📉 Epoch 17/500 - Train Loss: 0.5667, Val Loss: 3.0831
# 📉 Epoch 18/500 - Train Loss: 0.5661, Val Loss: 3.2573
# 📉 Epoch 19/500 - Train Loss: 0.5668, Val Loss: 3.4189
# 📉 Epoch 20/500 - Train Loss: 0.5687, Val Loss: 3.5097
# 📉 Epoch 21/500 - Train Loss: 0.5682, Val Loss: 3.5688
# ⏹️ Early stopping triggered at epoch 21. Best epoch: 1, Best Val Loss: 2.1937
#
# 🔍 Testing: HS=128, DR=0.3, BN=False, LR=0.0001, BS=16
# 286 / 288 combinations
#
# ⚡ Run 1/5
# 📉 Epoch 1/500 - Train Loss: 0.6046, Val Loss: 2.2837
# 📉 Epoch 2/500 - Train Loss: 0.5866, Val Loss: 2.2335
# 📉 Epoch 3/500 - Train Loss: 0.5834, Val Loss: 2.2114
# 📉 Epoch 4/500 - Train Loss: 0.5766, Val Loss: 2.2118
# 📉 Epoch 5/500 - Train Loss: 0.5730, Val Loss: 2.2265
# 📉 Epoch 6/500 - Train Loss: 0.5707, Val Loss: 2.2425
# 📉 Epoch 7/500 - Train Loss: 0.5775, Val Loss: 2.2708
# 📉 Epoch 8/500 - Train Loss: 0.5775, Val Loss: 2.2992
# 📉 Epoch 9/500 - Train Loss: 0.5715, Val Loss: 2.3341
# 📉 Epoch 10/500 - Train Loss: 0.5730, Val Loss: 2.3518
# 📉 Epoch 11/500 - Train Loss: 0.5733, Val Loss: 2.3679
# 📉 Epoch 12/500 - Train Loss: 0.5736, Val Loss: 2.3910
# 📉 Epoch 13/500 - Train Loss: 0.5731, Val Loss: 2.4129
# 📉 Epoch 14/500 - Train Loss: 0.5758, Val Loss: 2.4274
# 📉 Epoch 15/500 - Train Loss: 0.5699, Val Loss: 2.4380
# 📉 Epoch 16/500 - Train Loss: 0.5677, Val Loss: 2.4508
# 📉 Epoch 17/500 - Train Loss: 0.5782, Val Loss: 2.4685
# 📉 Epoch 18/500 - Train Loss: 0.5729, Val Loss: 2.4810
# 📉 Epoch 19/500 - Train Loss: 0.5712, Val Loss: 2.4850
# 📉 Epoch 20/500 - Train Loss: 0.5695, Val Loss: 2.4929
# 📉 Epoch 21/500 - Train Loss: 0.5703, Val Loss: 2.5042
# 📉 Epoch 22/500 - Train Loss: 0.5700, Val Loss: 2.5540
# 📉 Epoch 23/500 - Train Loss: 0.5704, Val Loss: 2.5595
# ⏹️ Early stopping triggered at epoch 23. Best epoch: 3, Best Val Loss: 2.2114
# ⚡ Run 2/5
# 📉 Epoch 1/500 - Train Loss: 0.5755, Val Loss: 2.2560
# 📉 Epoch 2/500 - Train Loss: 0.5736, Val Loss: 2.2516
# 📉 Epoch 3/500 - Train Loss: 0.5720, Val Loss: 2.2541
# 📉 Epoch 4/500 - Train Loss: 0.5703, Val Loss: 2.2558
# 📉 Epoch 5/500 - Train Loss: 0.5720, Val Loss: 2.2692
# 📉 Epoch 6/500 - Train Loss: 0.5732, Val Loss: 2.2823
# 📉 Epoch 7/500 - Train Loss: 0.5711, Val Loss: 2.2926
# 📉 Epoch 8/500 - Train Loss: 0.5717, Val Loss: 2.3121
# 📉 Epoch 9/500 - Train Loss: 0.5686, Val Loss: 2.3347
# 📉 Epoch 10/500 - Train Loss: 0.5722, Val Loss: 2.3616
# 📉 Epoch 11/500 - Train Loss: 0.5696, Val Loss: 2.3875
# 📉 Epoch 12/500 - Train Loss: 0.5715, Val Loss: 2.4267
# 📉 Epoch 13/500 - Train Loss: 0.5676, Val Loss: 2.4667
# 📉 Epoch 14/500 - Train Loss: 0.5702, Val Loss: 2.5145
# 📉 Epoch 15/500 - Train Loss: 0.5706, Val Loss: 2.5801
# 📉 Epoch 16/500 - Train Loss: 0.5707, Val Loss: 2.6323
# 📉 Epoch 17/500 - Train Loss: 0.5695, Val Loss: 2.6836
# 📉 Epoch 18/500 - Train Loss: 0.5691, Val Loss: 2.7712
# 📉 Epoch 19/500 - Train Loss: 0.5692, Val Loss: 2.8104
# 📉 Epoch 20/500 - Train Loss: 0.5664, Val Loss: 2.9378
# 📉 Epoch 21/500 - Train Loss: 0.5682, Val Loss: 3.0507
# 📉 Epoch 22/500 - Train Loss: 0.5666, Val Loss: 3.1386
# ⏹️ Early stopping triggered at epoch 22. Best epoch: 2, Best Val Loss: 2.2516
# ⚡ Run 3/5
# 📉 Epoch 1/500 - Train Loss: 0.5729, Val Loss: 2.2511
# 📉 Epoch 2/500 - Train Loss: 0.5707, Val Loss: 2.2435
# 📉 Epoch 3/500 - Train Loss: 0.5697, Val Loss: 2.2551
# 📉 Epoch 4/500 - Train Loss: 0.5732, Val Loss: 2.2689
# 📉 Epoch 5/500 - Train Loss: 0.5710, Val Loss: 2.2827
# 📉 Epoch 6/500 - Train Loss: 0.5715, Val Loss: 2.2854
# 📉 Epoch 7/500 - Train Loss: 0.5715, Val Loss: 2.2903
# 📉 Epoch 8/500 - Train Loss: 0.5704, Val Loss: 2.3026
# 📉 Epoch 9/500 - Train Loss: 0.5704, Val Loss: 2.3208
# 📉 Epoch 10/500 - Train Loss: 0.5706, Val Loss: 2.3259
# 📉 Epoch 11/500 - Train Loss: 0.5699, Val Loss: 2.3571
# 📉 Epoch 12/500 - Train Loss: 0.5696, Val Loss: 2.3764
# 📉 Epoch 13/500 - Train Loss: 0.5701, Val Loss: 2.4079
# 📉 Epoch 14/500 - Train Loss: 0.5686, Val Loss: 2.4328
# 📉 Epoch 15/500 - Train Loss: 0.5684, Val Loss: 2.4915
# 📉 Epoch 16/500 - Train Loss: 0.5698, Val Loss: 2.5519
# 📉 Epoch 17/500 - Train Loss: 0.5681, Val Loss: 2.6168
# 📉 Epoch 18/500 - Train Loss: 0.5684, Val Loss: 2.6688
# 📉 Epoch 19/500 - Train Loss: 0.5690, Val Loss: 2.7261
# 📉 Epoch 20/500 - Train Loss: 0.5672, Val Loss: 2.8336
# 📉 Epoch 21/500 - Train Loss: 0.5675, Val Loss: 2.9121
# 📉 Epoch 22/500 - Train Loss: 0.5671, Val Loss: 3.0389
# ⏹️ Early stopping triggered at epoch 22. Best epoch: 2, Best Val Loss: 2.2435
# ⚡ Run 4/5
# 📉 Epoch 1/500 - Train Loss: 0.6115, Val Loss: 2.4062
# 📉 Epoch 2/500 - Train Loss: 0.5946, Val Loss: 2.3354
# 📉 Epoch 3/500 - Train Loss: 0.5813, Val Loss: 2.2894
# 📉 Epoch 4/500 - Train Loss: 0.5786, Val Loss: 2.2721
# 📉 Epoch 5/500 - Train Loss: 0.5755, Val Loss: 2.2737
# 📉 Epoch 6/500 - Train Loss: 0.5733, Val Loss: 2.2810
# 📉 Epoch 7/500 - Train Loss: 0.5751, Val Loss: 2.2978
# 📉 Epoch 8/500 - Train Loss: 0.5749, Val Loss: 2.3112
# 📉 Epoch 9/500 - Train Loss: 0.5711, Val Loss: 2.3290
# 📉 Epoch 10/500 - Train Loss: 0.5707, Val Loss: 2.3386
# 📉 Epoch 11/500 - Train Loss: 0.5707, Val Loss: 2.3733
# 📉 Epoch 12/500 - Train Loss: 0.5709, Val Loss: 2.3873
# 📉 Epoch 13/500 - Train Loss: 0.5687, Val Loss: 2.4030
# 📉 Epoch 14/500 - Train Loss: 0.5724, Val Loss: 2.4253
# 📉 Epoch 15/500 - Train Loss: 0.5728, Val Loss: 2.4366
# 📉 Epoch 16/500 - Train Loss: 0.5699, Val Loss: 2.4614
# 📉 Epoch 17/500 - Train Loss: 0.5691, Val Loss: 2.4861
# 📉 Epoch 18/500 - Train Loss: 0.5683, Val Loss: 2.4977
# 📉 Epoch 19/500 - Train Loss: 0.5708, Val Loss: 2.5116
# 📉 Epoch 20/500 - Train Loss: 0.5690, Val Loss: 2.5289
# 📉 Epoch 21/500 - Train Loss: 0.5713, Val Loss: 2.5475
# 📉 Epoch 22/500 - Train Loss: 0.5728, Val Loss: 2.5672
# 📉 Epoch 23/500 - Train Loss: 0.5689, Val Loss: 2.5838
# 📉 Epoch 24/500 - Train Loss: 0.5725, Val Loss: 2.6070
# ⏹️ Early stopping triggered at epoch 24. Best epoch: 4, Best Val Loss: 2.2721
# ⚡ Run 5/5
# 📉 Epoch 1/500 - Train Loss: 0.5711, Val Loss: 2.2787
# 📉 Epoch 2/500 - Train Loss: 0.5704, Val Loss: 2.3023
# 📉 Epoch 3/500 - Train Loss: 0.5714, Val Loss: 2.3205
# 📉 Epoch 4/500 - Train Loss: 0.5725, Val Loss: 2.3386
# 📉 Epoch 5/500 - Train Loss: 0.5712, Val Loss: 2.3466
# 📉 Epoch 6/500 - Train Loss: 0.5704, Val Loss: 2.3658
# 📉 Epoch 7/500 - Train Loss: 0.5697, Val Loss: 2.3886
# 📉 Epoch 8/500 - Train Loss: 0.5696, Val Loss: 2.4182
# 📉 Epoch 9/500 - Train Loss: 0.5701, Val Loss: 2.4477
# 📉 Epoch 10/500 - Train Loss: 0.5690, Val Loss: 2.4786
# 📉 Epoch 11/500 - Train Loss: 0.5693, Val Loss: 2.5157
# 📉 Epoch 12/500 - Train Loss: 0.5712, Val Loss: 2.5491
# 📉 Epoch 13/500 - Train Loss: 0.5687, Val Loss: 2.6024
# 📉 Epoch 14/500 - Train Loss: 0.5695, Val Loss: 2.7219
# 📉 Epoch 15/500 - Train Loss: 0.5675, Val Loss: 2.7924
# 📉 Epoch 16/500 - Train Loss: 0.5694, Val Loss: 2.8343
# 📉 Epoch 17/500 - Train Loss: 0.5680, Val Loss: 2.9855
# 📉 Epoch 18/500 - Train Loss: 0.5666, Val Loss: 3.1578
# 📉 Epoch 19/500 - Train Loss: 0.5669, Val Loss: 3.2118
# 📉 Epoch 20/500 - Train Loss: 0.5669, Val Loss: 3.3547
# 📉 Epoch 21/500 - Train Loss: 0.5674, Val Loss: 3.4978
# ⏹️ Early stopping triggered at epoch 21. Best epoch: 1, Best Val Loss: 2.2787
#
# 🔍 Testing: HS=128, DR=0.3, BN=False, LR=0.0001, BS=32
# 287 / 288 combinations
#
# ⚡ Run 1/5
# 📉 Epoch 1/500 - Train Loss: 0.5740, Val Loss: 2.3207
# 📉 Epoch 2/500 - Train Loss: 0.5707, Val Loss: 2.3215
# 📉 Epoch 3/500 - Train Loss: 0.5711, Val Loss: 2.3204
# 📉 Epoch 4/500 - Train Loss: 0.5730, Val Loss: 2.3226
# 📉 Epoch 5/500 - Train Loss: 0.5710, Val Loss: 2.3252
# 📉 Epoch 6/500 - Train Loss: 0.5706, Val Loss: 2.3317
# 📉 Epoch 7/500 - Train Loss: 0.5707, Val Loss: 2.3376
# 📉 Epoch 8/500 - Train Loss: 0.5709, Val Loss: 2.3445
# 📉 Epoch 9/500 - Train Loss: 0.5706, Val Loss: 2.3542
# 📉 Epoch 10/500 - Train Loss: 0.5698, Val Loss: 2.3668
# 📉 Epoch 11/500 - Train Loss: 0.5719, Val Loss: 2.3882
# 📉 Epoch 12/500 - Train Loss: 0.5710, Val Loss: 2.3961
# 📉 Epoch 13/500 - Train Loss: 0.5688, Val Loss: 2.4086
# 📉 Epoch 14/500 - Train Loss: 0.5711, Val Loss: 2.4277
# 📉 Epoch 15/500 - Train Loss: 0.5706, Val Loss: 2.4428
# 📉 Epoch 16/500 - Train Loss: 0.5702, Val Loss: 2.4614
# 📉 Epoch 17/500 - Train Loss: 0.5690, Val Loss: 2.4809
# 📉 Epoch 18/500 - Train Loss: 0.5681, Val Loss: 2.5045
# 📉 Epoch 19/500 - Train Loss: 0.5705, Val Loss: 2.5172
# 📉 Epoch 20/500 - Train Loss: 0.5680, Val Loss: 2.5545
# 📉 Epoch 21/500 - Train Loss: 0.5677, Val Loss: 2.5879
# 📉 Epoch 22/500 - Train Loss: 0.5679, Val Loss: 2.6096
# 📉 Epoch 23/500 - Train Loss: 0.5709, Val Loss: 2.6519
# ⏹️ Early stopping triggered at epoch 23. Best epoch: 3, Best Val Loss: 2.3204
# ⚡ Run 2/5
# 📉 Epoch 1/500 - Train Loss: 0.5995, Val Loss: 2.4299
# 📉 Epoch 2/500 - Train Loss: 0.5856, Val Loss: 2.3933
# 📉 Epoch 3/500 - Train Loss: 0.5814, Val Loss: 2.3598
# 📉 Epoch 4/500 - Train Loss: 0.5792, Val Loss: 2.3547
# 📉 Epoch 5/500 - Train Loss: 0.5693, Val Loss: 2.3584
# 📉 Epoch 6/500 - Train Loss: 0.5721, Val Loss: 2.3669
# 📉 Epoch 7/500 - Train Loss: 0.5700, Val Loss: 2.3695
# 📉 Epoch 8/500 - Train Loss: 0.5747, Val Loss: 2.3832
# 📉 Epoch 9/500 - Train Loss: 0.5773, Val Loss: 2.4037
# 📉 Epoch 10/500 - Train Loss: 0.5743, Val Loss: 2.4216
# 📉 Epoch 11/500 - Train Loss: 0.5708, Val Loss: 2.4300
# 📉 Epoch 12/500 - Train Loss: 0.5701, Val Loss: 2.4498
# 📉 Epoch 13/500 - Train Loss: 0.5749, Val Loss: 2.4596
# 📉 Epoch 14/500 - Train Loss: 0.5714, Val Loss: 2.4763
# 📉 Epoch 15/500 - Train Loss: 0.5713, Val Loss: 2.4866
# 📉 Epoch 16/500 - Train Loss: 0.5714, Val Loss: 2.4924
# 📉 Epoch 17/500 - Train Loss: 0.5699, Val Loss: 2.5041
# 📉 Epoch 18/500 - Train Loss: 0.5716, Val Loss: 2.5081
# 📉 Epoch 19/500 - Train Loss: 0.5706, Val Loss: 2.5059
# 📉 Epoch 20/500 - Train Loss: 0.5703, Val Loss: 2.5179
# 📉 Epoch 21/500 - Train Loss: 0.5725, Val Loss: 2.5267
# 📉 Epoch 22/500 - Train Loss: 0.5704, Val Loss: 2.5353
# 📉 Epoch 23/500 - Train Loss: 0.5663, Val Loss: 2.5463
# 📉 Epoch 24/500 - Train Loss: 0.5709, Val Loss: 2.5570
# ⏹️ Early stopping triggered at epoch 24. Best epoch: 4, Best Val Loss: 2.3547
# ⚡ Run 3/5
# 📉 Epoch 1/500 - Train Loss: 0.5726, Val Loss: 2.2982
# 📉 Epoch 2/500 - Train Loss: 0.5735, Val Loss: 2.2941
# 📉 Epoch 3/500 - Train Loss: 0.5708, Val Loss: 2.3020
# 📉 Epoch 4/500 - Train Loss: 0.5724, Val Loss: 2.3012
# 📉 Epoch 5/500 - Train Loss: 0.5678, Val Loss: 2.3117
# 📉 Epoch 6/500 - Train Loss: 0.5690, Val Loss: 2.3241
# 📉 Epoch 7/500 - Train Loss: 0.5706, Val Loss: 2.3376
# 📉 Epoch 8/500 - Train Loss: 0.5728, Val Loss: 2.3412
# 📉 Epoch 9/500 - Train Loss: 0.5700, Val Loss: 2.3530
# 📉 Epoch 10/500 - Train Loss: 0.5715, Val Loss: 2.3662
# 📉 Epoch 11/500 - Train Loss: 0.5701, Val Loss: 2.3895
# 📉 Epoch 12/500 - Train Loss: 0.5714, Val Loss: 2.4100
# 📉 Epoch 13/500 - Train Loss: 0.5729, Val Loss: 2.4270
# 📉 Epoch 14/500 - Train Loss: 0.5707, Val Loss: 2.4525
# 📉 Epoch 15/500 - Train Loss: 0.5707, Val Loss: 2.4723
# 📉 Epoch 16/500 - Train Loss: 0.5697, Val Loss: 2.4927
# 📉 Epoch 17/500 - Train Loss: 0.5698, Val Loss: 2.5296
# 📉 Epoch 18/500 - Train Loss: 0.5707, Val Loss: 2.5631
# 📉 Epoch 19/500 - Train Loss: 0.5695, Val Loss: 2.5803
# 📉 Epoch 20/500 - Train Loss: 0.5712, Val Loss: 2.6002
# 📉 Epoch 21/500 - Train Loss: 0.5705, Val Loss: 2.6433
# 📉 Epoch 22/500 - Train Loss: 0.5686, Val Loss: 2.6793
# ⏹️ Early stopping triggered at epoch 22. Best epoch: 2, Best Val Loss: 2.2941
# ⚡ Run 4/5
# 📉 Epoch 1/500 - Train Loss: 0.6183, Val Loss: 2.4246
# 📉 Epoch 2/500 - Train Loss: 0.6023, Val Loss: 2.3734
# 📉 Epoch 3/500 - Train Loss: 0.5951, Val Loss: 2.3332
# 📉 Epoch 4/500 - Train Loss: 0.5896, Val Loss: 2.3157
# 📉 Epoch 5/500 - Train Loss: 0.5789, Val Loss: 2.2905
# 📉 Epoch 6/500 - Train Loss: 0.5722, Val Loss: 2.2889
# 📉 Epoch 7/500 - Train Loss: 0.5743, Val Loss: 2.3024
# 📉 Epoch 8/500 - Train Loss: 0.5704, Val Loss: 2.3184
# 📉 Epoch 9/500 - Train Loss: 0.5752, Val Loss: 2.3360
# 📉 Epoch 10/500 - Train Loss: 0.5747, Val Loss: 2.3626
# 📉 Epoch 11/500 - Train Loss: 0.5755, Val Loss: 2.3839
# 📉 Epoch 12/500 - Train Loss: 0.5720, Val Loss: 2.4002
# 📉 Epoch 13/500 - Train Loss: 0.5697, Val Loss: 2.4204
# 📉 Epoch 14/500 - Train Loss: 0.5758, Val Loss: 2.4447
# 📉 Epoch 15/500 - Train Loss: 0.5762, Val Loss: 2.4601
# 📉 Epoch 16/500 - Train Loss: 0.5713, Val Loss: 2.4813
# 📉 Epoch 17/500 - Train Loss: 0.5752, Val Loss: 2.4892
# 📉 Epoch 18/500 - Train Loss: 0.5703, Val Loss: 2.4986
# 📉 Epoch 19/500 - Train Loss: 0.5696, Val Loss: 2.5115
# 📉 Epoch 20/500 - Train Loss: 0.5739, Val Loss: 2.5275
# 📉 Epoch 21/500 - Train Loss: 0.5722, Val Loss: 2.5379
# 📉 Epoch 22/500 - Train Loss: 0.5670, Val Loss: 2.5442
# 📉 Epoch 23/500 - Train Loss: 0.5725, Val Loss: 2.5551
# 📉 Epoch 24/500 - Train Loss: 0.5692, Val Loss: 2.5608
# 📉 Epoch 25/500 - Train Loss: 0.5664, Val Loss: 2.5704
# 📉 Epoch 26/500 - Train Loss: 0.5756, Val Loss: 2.5770
# ⏹️ Early stopping triggered at epoch 26. Best epoch: 6, Best Val Loss: 2.2889
# ⚡ Run 5/5
# 📉 Epoch 1/500 - Train Loss: 0.5938, Val Loss: 2.4150
# 📉 Epoch 2/500 - Train Loss: 0.5856, Val Loss: 2.3863
# 📉 Epoch 3/500 - Train Loss: 0.5806, Val Loss: 2.3676
# 📉 Epoch 4/500 - Train Loss: 0.5760, Val Loss: 2.3611
# 📉 Epoch 5/500 - Train Loss: 0.5746, Val Loss: 2.3551
# 📉 Epoch 6/500 - Train Loss: 0.5733, Val Loss: 2.3560
# 📉 Epoch 7/500 - Train Loss: 0.5736, Val Loss: 2.3677
# 📉 Epoch 8/500 - Train Loss: 0.5687, Val Loss: 2.3827
# 📉 Epoch 9/500 - Train Loss: 0.5685, Val Loss: 2.3963
# 📉 Epoch 10/500 - Train Loss: 0.5701, Val Loss: 2.4084
# 📉 Epoch 11/500 - Train Loss: 0.5729, Val Loss: 2.4306
# 📉 Epoch 12/500 - Train Loss: 0.5738, Val Loss: 2.4499
# 📉 Epoch 13/500 - Train Loss: 0.5680, Val Loss: 2.4666
# 📉 Epoch 14/500 - Train Loss: 0.5702, Val Loss: 2.4815
# 📉 Epoch 15/500 - Train Loss: 0.5726, Val Loss: 2.5029
# 📉 Epoch 16/500 - Train Loss: 0.5700, Val Loss: 2.5240
# 📉 Epoch 17/500 - Train Loss: 0.5741, Val Loss: 2.5428
# 📉 Epoch 18/500 - Train Loss: 0.5741, Val Loss: 2.5598
# 📉 Epoch 19/500 - Train Loss: 0.5724, Val Loss: 2.5850
# 📉 Epoch 20/500 - Train Loss: 0.5725, Val Loss: 2.6121
# 📉 Epoch 21/500 - Train Loss: 0.5670, Val Loss: 2.6387
# 📉 Epoch 22/500 - Train Loss: 0.5707, Val Loss: 2.6701
# 📉 Epoch 23/500 - Train Loss: 0.5683, Val Loss: 2.7030
# 📉 Epoch 24/500 - Train Loss: 0.5720, Val Loss: 2.7467
# 📉 Epoch 25/500 - Train Loss: 0.5711, Val Loss: 2.7789
# ⏹️ Early stopping triggered at epoch 25. Best epoch: 5, Best Val Loss: 2.3551
#
# 🏆 Best Hyperparameters Found:
# hidden_size             16
# dropout_rate           0.3
# use_bn               False
# learning_rate       0.0001
# batch_size              32
# train_loss        0.582239
# val_loss          2.315135
# MAE               2.684595
# MSE              12.832352
# Percent Error      3.94234
# Name: 71, dtype: object

# %%
print("Top 5 results")
results_df.head(5)
# Out:
# Top 5 results
#      hidden_size  dropout_rate  use_bn  learning_rate  batch_size  train_loss  \
# 71            16           0.3   False         0.0001          32    0.582239
# 52            16           0.2   False         0.0001          16    0.579219
# 125           32           0.2   False         0.0001          32    0.574706
# 124           32           0.2   False         0.0001          16    0.573219
# 34            16           0.1   False         0.0001          16    0.574838
#
#      val_loss       MAE        MSE  Percent Error
# 71   2.315135  2.684595  12.832352       3.942340
# 52   2.309751  2.694195  13.194680       3.964695
# 125  2.360015  2.720060  13.369953       4.001225
# 124  2.354935  2.713992  13.742700       4.001605
# 34   2.367447  2.723775  13.597390       4.013641

# %%
# # Create dataloader
# train_dataset = TensorDataset(X_train, y_train)
# val_dataset = TensorDataset(X_val, y_val)
# test_dataset = TensorDataset(X_test, y_test)
# train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
# val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)
# test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# # Hyperparameters
# input_size = 10
# hidden_size = 64
# dropout_rate = 0.3
# use_bn = False
# learning_rate = 0.0005
# num_epochs = 500
# patience = 20

# arr_model_shap = BiasPredictor(input_size=input_size, hidden_size=hidden_size, dropout_rate=dropout_rate, use_bn=use_bn).to(device)

# best_model, history = train_bias_predictor(arr_model_shap, train_loader, val_loader, num_epochs, patience, learning_rate)

# %%
# best_model.eval()

# with torch.no_grad():
#     X_tensor = torch.tensor(X, dtype=torch.float32).to(device)
#     y_pred_arr = best_model(X_tensor).cpu().numpy()

# outputs_arr_unscaled = y_scaler.inverse_transform(y_pred_arr.reshape(y_pred_arr.shape[0], -1))

# # Add predictions into df
# temp_df["bias_model_arr_prediction_SHAP"] = outputs_arr_unscaled.flatten()
# temp_df['New_predictions_arr_SHAP'] = temp_df["LSTM_prediction_original"] + temp_df["bias_model_arr_prediction_SHAP"]

# %%
temp_df.head()
# Out:
#    bias_model_uni_prediction  LSTM_prediction_original     Target  \
# 0                   0.982707                 54.226685  57.261292
# 1                   0.812585                 54.316078  58.399250
# 2                   1.027725                 54.464622  58.644016
# 3                   0.821752                 54.754524  59.656273
# 4                   1.004773                 55.168800  59.226238
#
#    New_predictions_uni  bias_model_arr_prediction  New_predictions_arr
# 0            55.209393                   0.913276            55.139961
# 1            55.128662                   0.931603            55.247681
# 2            55.492348                   0.900901            55.365524
# 3            55.576275                   0.946411            55.700935
# 4            56.173573                   0.901577            56.070377

# %%
# # plot line graph of bias_model_arr_prediction vs original
# plt.figure(figsize=(20, 10))
# plt.plot(temp_df["New_predictions_arr_SHAP"].iloc[train_size+val_size:], label='Array predictions', color='purple')
# plt.plot(temp_df["New_predictions_arr"].iloc[train_size+val_size:], label='Array predictions', color='blue')
# plt.plot(temp_df["New_predictions_uni"].iloc[train_size+val_size:], label='Single input predictions', color='red')
# plt.plot(temp_df["Target"].iloc[train_size+val_size:], label='True Values', color='green')
# plt.xlabel('Time')
# plt.ylabel('Value')
# plt.title('Actual vs. Predicted Values')
# plt.legend()
# plt.show()

# %%
# # get prediction error percentages
# original_error_percent = np.mean(np.abs(temp_df["Target"].iloc[train_size+val_size:].values - temp_df["LSTM_prediction_original"].iloc[train_size+val_size:].values) / (np.abs(temp_df["Target"].iloc[train_size+val_size:].values) + 1e-8)) * 100
# uni_input_error_percent = np.mean(np.abs(temp_df["Target"].iloc[train_size+val_size:].values - temp_df["New_predictions_uni"].iloc[train_size+val_size:].values) / (np.abs(temp_df["Target"].iloc[train_size+val_size:].values) + 1e-8)) * 100
# arr_input_error_percent = np.mean(np.abs(temp_df["Target"].iloc[train_size+val_size:].values - temp_df["New_predictions_arr"].iloc[train_size+val_size:].values) / (np.abs(temp_df["Target"].iloc[train_size+val_size:].values) + 1e-8)) * 100
# arr_input_error_percent_SHAP = np.mean(np.abs(temp_df["Target"].iloc[train_size+val_size:].values - temp_df["New_predictions_arr_SHAP"].iloc[train_size+val_size:].values) / (np.abs(temp_df["Target"].iloc[train_size+val_size:].values) + 1e-8)) * 100

# print("Percentages over test set\n")
# print(f"Original LSTM Error Percentage: {original_error_percent:.4f}%")
# print(f"New LSTM Error Percentage (Single Input): {uni_input_error_percent:.4f}%")
# print(f"New LSTM Error Percentage (Array Input): {arr_input_error_percent:.4f}%")
# print(f"New LSTM Error Percentage (Array Input SHAP): {arr_input_error_percent_SHAP:.4f}%")

# %%
# # plot graph over entire dataset
# plt.figure(figsize=(20, 10))
# plt.plot(temp_df["New_predictions_arr_SHAP"], label='Array predictions', color='purple')
# plt.plot(temp_df["New_predictions_arr"], label='Array predictions', color='blue')
# plt.plot(temp_df["New_predictions_uni"], label='Single input predictions', color='red')
# plt.plot(temp_df["Target"], label='True Values', color='green')
# plt.xlabel('Time')
# plt.ylabel('Value')
# plt.title('Actual vs. Predicted Values')
# plt.legend()
# plt.show()

# %%
# # get prediction error percentages
# original_error_percent = np.mean(np.abs(temp_df["Target"].values - temp_df["LSTM_prediction_original"].values) / (np.abs(temp_df["Target"].values) + 1e-8)) * 100
# uni_input_error_percent = np.mean(np.abs(temp_df["Target"].values - temp_df["New_predictions_uni"].values) / (np.abs(temp_df["Target"].values) + 1e-8)) * 100
# arr_input_error_percent = np.mean(np.abs(temp_df["Target"].values - temp_df["New_predictions_arr"].values) / (np.abs(temp_df["Target"].values) + 1e-8)) * 100
# arr_input_error_percent_SHAP = np.mean(np.abs(temp_df["Target"].values - temp_df["New_predictions_arr_SHAP"].values) / (np.abs(temp_df["Target"].values) + 1e-8)) * 100

# print("Percentages over entire set\n")
# print(f"Original LSTM Error Percentage: {original_error_percent:.4f}%")
# print(f"New LSTM Error Percentage (Single Input): {uni_input_error_percent:.4f}%")
# print(f"New LSTM Error Percentage (Array Input): {arr_input_error_percent:.4f}%")
# print(f"New LSTM Error Percentage (Array Input SHAP): {arr_input_error_percent_SHAP:.4f}%")
