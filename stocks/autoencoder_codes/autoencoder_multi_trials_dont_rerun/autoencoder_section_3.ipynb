# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from sklearn.base import BaseEstimator, RegressorMixin

# %%
# Load the data
file_path = "SPY_section_3.csv"
df = pd.read_csv(file_path)

# start to nov 2001 (dot com crash)
# not bad
# df = df.iloc[:2228]

# nov 01 to june 2009
# not bad
# df = df.iloc[2228:4135]

# june 2009 to april 2020
# ass
# df = df.iloc[4135:6862]

# april 2020 to most recent
# ass
# df = df.iloc[6862:]


# Convert the "Date" column to datetime
# df["Date"] = pd.to_datetime(df["Date"], format='%Y/%m/%d')

# # Sort the data by date in ascending order
# df = df.sort_values(by="Date")

# # Get the earliest and latest dates
# earliest_date = df["Date"].min()
# latest_date = df["Date"].max()

# print("Earliest Date:", earliest_date)
# print("Latest Date:", latest_date)

# %%
# Adding SMA as part of the feature test
short_term_period = 20
medium_term_period = 50
long_term_period = 200

# Compute the SMAs
df['SMA_20'] = df['Close'].rolling(window=short_term_period).mean()
df['SMA_50'] = df['Close'].rolling(window=medium_term_period).mean()
df['SMA_200'] = df['Close'].rolling(window=long_term_period).mean()

df['EMA_10'] = df['Close'].ewm(span=10, adjust=False).mean()  # Short-term EMA
df['EMA_50'] = df['Close'].ewm(span=50, adjust=False).mean()  # Medium-term EMA
df['EMA_200'] = df['Close'].ewm(span=200, adjust=False).mean()  # Long-term EMA

df = df.dropna()

# %%
feature_columns = ["Open", "High", "Low", "Close", "Volume"]  
dates = df["Date"]
# if "Open" and "High" and "Low" and "Close" and "Volume" in df.columns:
#     df = df[feature_columns]

# %%
# scaler = StandardScaler()
# scaler = MinMaxScaler()
# feature_columns = ["Open", "High", "Low", "Close", "Volume", "Day", "Weekday", "Week", "Month", "Year"]
# feature_columns = ["Open", "High", "Low", "Close", "Volume", "SMA_20", "SMA_50", "SMA_200", "EMA_10", "EMA_50", "EMA_200", "Non_Linear_Trend"]
feature_columns = ["Open", "High", "Low", "Close", "Volume", "SMA_20", "SMA_50", "SMA_200", "EMA_10", "EMA_50", "EMA_200"]
# feature_columns = ["Open", "High", "Low", "Close", "Volume", "Non_Linear_Trend", "SMA_20", "SMA_50", "EMA_10", "EMA_50"]
# feature_columns = ["Open", "High", "Low", "Close", "Volume", "Non_Linear_Trend"]
# feature_columns = ["Open", "High", "Low", "Close", "Volume", "SMA_200", "EMA_10"]
X = df[feature_columns]

# Split data
train_size = int(X.shape[0] * 0.7)
val_size = int(X.shape[0] * 0.15)

# Initialize scaler
scaler = MinMaxScaler()
# scaler = RobustScaler()

# Split data into train, validation, and test
temp_train = X[:train_size]
temp_val = X[train_size:train_size + val_size]
temp_test = X[train_size + val_size:]

temp_train = temp_train[feature_columns]
temp_val = temp_val[feature_columns]
temp_test = temp_test[feature_columns]

# Fit and transform for train, transform for validation and test
temp_train = scaler.fit_transform(temp_train)
temp_val = scaler.transform(temp_val)
temp_test = scaler.transform(temp_test)

# Convert NumPy arrays back to DataFrames
temp_train = pd.DataFrame(temp_train, columns=feature_columns)
temp_val = pd.DataFrame(temp_val, columns=feature_columns)
temp_test = pd.DataFrame(temp_test, columns=feature_columns)

# Concatenate the data
X_scaled = pd.concat([temp_train, temp_val, temp_test], axis=0)

# Split sequentially
X_train = X_scaled[:train_size]
X_val = X_scaled[train_size:train_size + val_size]
X_test = X_scaled[train_size + val_size:]

# Print sizes to confirm
print(f"Train: {len(X_train)}, Val: {len(X_val)}, Test: {len(X_test)}")
# Out:
# Train: 1769, Val: 379, Test: 380

# %%
X_train = X_train.values
X_val = X_val.values
X_test = X_test.values

# %%
# Convert data to PyTorch tensors
X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
X_val_tensor = torch.tensor(X_val, dtype=torch.float32)
X_test_tensor = torch.tensor(X_test, dtype=torch.float32)

# Create DataLoader
train_dataset = TensorDataset(X_train_tensor, X_train_tensor)
val_dataset = TensorDataset(X_val_tensor, X_val_tensor)
test_dataset = TensorDataset(X_test_tensor, X_test_tensor)
train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=16, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=16, shuffle=False)

# %%
# # Check if CUDA is available and print the device being used
# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# print(f"Using device: {device}")

# class Encoder(nn.Module):
#     def __init__(self, input_dim, encoding_dim):
#         super(Encoder, self).__init__()
#         self.encoder = nn.Sequential(
#             nn.Linear(input_dim, 128),
#             nn.ReLU(),
#             nn.Dropout(0.2),
#             nn.Linear(128, 64),
#             nn.ReLU(),
#             nn.Dropout(0.2),
#             nn.Linear(64, encoding_dim)
#         )

#     def forward(self, x):
#         return self.encoder(x)

# class Decoder(nn.Module):
#     def __init__(self, encoding_dim, input_dim):
#         super(Decoder, self).__init__()
#         self.decoder = nn.Sequential(
#             nn.Linear(encoding_dim, 64),
#             nn.ReLU(),
#             nn.Dropout(0.2),
#             nn.Linear(64, 128),
#             nn.ReLU(),
#             nn.Dropout(0.2),
#             nn.Linear(128, input_dim)
#         )

#     def forward(self, x):
#         return self.decoder(x)

    
# # Define input dimensions
# input_dim = X_train.shape[1]

# # Model file paths
# encoder_model_file = './autoencoder_trials/encoder.pth'
# decoder_model_file = './autoencoder_trials/decoder.pth'

# # Hyperparameters
# encoding_dim = 8
# learning_rate = 0.001
# epochs = 50
# batch_size = 8
# patience = 5

# # Check if the model files exist
# if os.path.exists(encoder_model_file) and os.path.exists(decoder_model_file):
#     print("Model files exist. Loading the models...")
#     encoder = Encoder(input_dim, encoding_dim).to(device)
#     decoder = Decoder(encoding_dim, input_dim).to(device)
#     encoder.load_state_dict(torch.load(encoder_model_file))
#     decoder.load_state_dict(torch.load(decoder_model_file))
# else:
#     print("Model files do not exist. Training new models...")

#     # Initialize the encoder and decoder models
#     encoder = Encoder(input_dim, encoding_dim).to(device)
#     decoder = Decoder(encoding_dim, input_dim).to(device)
#     optimizer_encoder = optim.Adam(encoder.parameters(), lr=learning_rate)
#     optimizer_decoder = optim.Adam(decoder.parameters(), lr=learning_rate)
#     criterion = nn.MSELoss()

#     # Track training loss
#     encoder_losses = []
#     decoder_losses = []

#     # Train the Encoder separately
#     encoder.train()
#     best_val_loss = float('inf')
#     patience_counter = 0
#     for epoch in range(epochs):
#         epoch_loss = 0
#         dataloader = DataLoader(TensorDataset(torch.tensor(X_train, dtype=torch.float32).to(device), torch.tensor(X_train, dtype=torch.float32).to(device)), batch_size=batch_size, shuffle=True, num_workers=0)
#         for i, (batch_X, _) in enumerate(dataloader):
#             batch_X = batch_X.to(device)
#             optimizer_encoder.zero_grad()
#             encoded = encoder(batch_X)
#             # Pass the encoded output through the decoder
#             decoded = decoder(encoded)
#             # Calculate loss between decoder output and original input
#             loss = criterion(decoded, batch_X)
#             loss.backward()
            
#             optimizer_encoder.step()
#             optimizer_encoder.zero_grad()
            
#             epoch_loss += loss.item()
#         avg_loss = epoch_loss / len(dataloader)
#         encoder_losses.append(avg_loss)
#         print(f"Epoch [{epoch+1}/{epochs}], Encoder Loss: {avg_loss:.4f}")

#         # Validation loss
#         encoder.eval()
#         decoder.eval()
#         with torch.no_grad():
#             val_encoded = encoder(torch.tensor(X_val, dtype=torch.float32).to(device))
#             val_decoded = decoder(val_encoded)
#             val_loss = criterion(val_decoded, torch.tensor(X_val, dtype=torch.float32).to(device)).item()
#         print(f"Validation Loss: {val_loss:.4f}")

#         # Early stopping
#         if val_loss < best_val_loss:
#             best_val_loss = val_loss
#             patience_counter = 0
#         else:
#             patience_counter += 1
#             if patience_counter >= patience:
#                 print("Early stopping triggered.")
#                 break

#     # Train the Decoder separately
#     encoded_train = encoder(torch.tensor(X_train, dtype=torch.float32).to(device)).detach()
#     decoder.train()
#     best_val_loss = float('inf')
#     patience_counter = 0
#     for epoch in range(epochs):
#         epoch_loss = 0
#         dataloader = DataLoader(TensorDataset(encoded_train, torch.tensor(X_train, dtype=torch.float32).to(device)), batch_size=batch_size, shuffle=True, num_workers=0)
#         for i, (batch_X, batch_y) in enumerate(dataloader):
#             batch_X, batch_y = batch_X.to(device), batch_y.to(device)
#             optimizer_decoder.zero_grad()
#             outputs = decoder(batch_X)
#             # Calculate loss between decoder output and original input
#             loss = criterion(outputs, batch_y)
#             loss.backward()
            
#             optimizer_decoder.step()
#             optimizer_decoder.zero_grad()
            
#             epoch_loss += loss.item()
#         avg_loss = epoch_loss / len(dataloader)
#         decoder_losses.append(avg_loss)
#         print(f"Epoch [{epoch+1}/{epochs}], Decoder Loss: {avg_loss:.4f}")

#         # Validation loss
#         decoder.eval()
#         with torch.no_grad():
#             val_outputs = decoder(encoded_train)
#             val_loss = criterion(val_outputs, torch.tensor(X_train, dtype=torch.float32).to(device)).item()
#         print(f"Validation Loss: {val_loss:.4f}")

#         # Early stopping
#         if val_loss < best_val_loss:
#             best_val_loss = val_loss
#             patience_counter = 0
#         else:
#             patience_counter += 1
#             print("Early stopping counter:", patience_counter)
#             if patience_counter >= patience:
#                 print("Early stopping triggered.")
#                 break

#     # Save the trained models
#     os.makedirs('./autoencoder_trials', exist_ok=True)
#     # torch.save(encoder.state_dict(), encoder_model_file)
#     # torch.save(decoder.state_dict(), decoder_model_file)
#     print("Models trained and saved.")

# # Combine Encoder and Decoder to form the Autoencoder
# class Autoencoder(nn.Module):
#     def __init__(self, encoder, decoder):
#         super(Autoencoder, self).__init__()
#         self.encoder = encoder
#         self.decoder = decoder

#     def forward(self, x):
#         encoded = self.encoder(x)
#         decoded = self.decoder(encoded)
#         return decoded

# autoencoder = Autoencoder(encoder, decoder).to(device)
# autoencoder.eval()

# # Calculate reconstruction error on the test set
# with torch.no_grad():
#     reconstructed_test = autoencoder(torch.tensor(X_test, dtype=torch.float32).to(device)).cpu().numpy()

# # Calculate Mean Squared Error (MSE)
# mse = np.mean((X_test - reconstructed_test) ** 2)
# print(f'Mean Squared Error (MSE): {mse}')

# # Calculate Mean Absolute Error (MAE)
# mae = np.mean(np.abs(X_test - reconstructed_test))
# print(f'Mean Absolute Error (MAE): {mae}')

# # Calculate Reconstruction Error Percentage
# # reconstruction_error = np.mean(np.square(X_test - reconstructed_test), axis=1)
# # reconstruction_error_percentage = np.mean(reconstruction_error) * 100
# # print(f'Reconstruction Error Percentage: {reconstruction_error_percentage}')

# reconstruction_error_percentage = (
#     np.mean(np.abs(X_test - reconstructed_test) / (np.abs(X_test) + 1e-8), axis=1) * 100
# )
# reconstruction_error_percentage_mean = np.mean(reconstruction_error_percentage)
# print(f'Reconstruction Error Percentage: {reconstruction_error_percentage_mean}')

# def calculate_index_error_percentage(index, X, reconstructed_X):
#     print(np.mean(np.abs(X[index] - reconstructed_X[index]) / (np.abs(X[index]) + 1e-8)) * 100)

# %%
# # import os
# # import torch
# # import torch.nn as nn
# # import torch.optim as optim
# # import numpy as np
# # from torch.utils.data import DataLoader, TensorDataset

# # # Check if CUDA is available
# # device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# # print(f"Using device: {device}")

# # # Define Encoder
# # class Encoder(nn.Module):
# #     def __init__(self, input_dim, encoding_dim, dropout_rate):
# #         super(Encoder, self).__init__()
# #         self.encoder = nn.Sequential(
# #             nn.Linear(input_dim, 128),
# #             nn.ReLU(),
# #             nn.Dropout(dropout_rate),
# #             nn.Linear(128, 64),
# #             nn.ReLU(),
# #             nn.Dropout(dropout_rate),
# #             nn.Linear(64, encoding_dim)
# #         )

# #     def forward(self, x):
# #         return self.encoder(x)

# # # Define Decoder
# # class Decoder(nn.Module):
# #     def __init__(self, encoding_dim, input_dim, dropout_rate):
# #         super(Decoder, self).__init__()
# #         self.decoder = nn.Sequential(
# #             nn.Linear(encoding_dim, 64),
# #             nn.ReLU(),
# #             nn.Dropout(dropout_rate),
# #             nn.Linear(64, 128),
# #             nn.ReLU(),
# #             nn.Dropout(dropout_rate),
# #             nn.Linear(128, input_dim)
# #         )

# #     def forward(self, x):
# #         return self.decoder(x)

# # def relative_euclidean_error(X, X_reconstructed):
# #     return np.linalg.norm(X - X_reconstructed, axis=1) / np.linalg.norm(X, axis=1)

# # class RelativeEuclideanError(nn.Module):
# #     def forward(self, y_true, y_pred):
# #         return torch.mean(torch.norm(y_true - y_pred, dim=1) / torch.norm(y_true, dim=1))

# # # Define input dimensions
# # input_dim = X_train.shape[1]

# # # Model file paths
# # encoder_model_file = './autoencoder_trials/encoder.pth'
# # decoder_model_file = './autoencoder_trials/decoder.pth'

# # # Hyperparameters
# # encoding_dim = 5
# # learning_rate = 0.0001
# # dropout_rate = 0.0
# # epochs = 750
# # batch_size = 16
# # patience = 30

# # # Initialize models
# # encoder = Encoder(input_dim, encoding_dim, dropout_rate).to(device)
# # decoder = Decoder(encoding_dim, input_dim, dropout_rate).to(device)

# # # Define optimizers and loss function
# # optimizer_encoder = optim.Adam(encoder.parameters(), lr=learning_rate)
# # optimizer_decoder = optim.Adam(decoder.parameters(), lr=learning_rate)
# # # criterion = nn.MSELoss()
# # criterion = RelativeEuclideanError()
# # #use MAE
# # # criterion = nn.L1Loss()

# # # Add Gaussian noise to encoded representations to avoid overfitting
# # def add_noise(encoded, noise_factor=0.01):
# #     return encoded + noise_factor * torch.randn_like(encoded)

# # # Train Encoder
# # def train_encoder():
# #     print("Training Encoder...")
# #     encoder.train()
# #     best_val_loss = float('inf')
# #     patience_counter = 0
# #     # clip_value = 1

# #     for epoch in range(epochs):
# #         epoch_loss = 0
# #         dataloader = DataLoader(TensorDataset(torch.tensor(X_train, dtype=torch.float32).to(device), 
# #                                               torch.tensor(X_train, dtype=torch.float32).to(device)), 
# #                                 batch_size=batch_size, shuffle=True, num_workers=0)

# #         for batch_X, _ in dataloader:
# #             batch_X = batch_X.to(device)
# #             optimizer_encoder.zero_grad()
# #             encoded = encoder(batch_X)
# #             decoded = decoder(encoded)
# #             loss = criterion(decoded, batch_X)
# #             loss.backward()
            
# #             # torch.nn.utils.clip_grad_norm_(encoder.parameters(), max_norm=clip_value)  # Option 1
# #             # torch.nn.utils.clip_grad_value_(encoder.parameters(), clip_value=clip_value)  # Option 2

# #             optimizer_encoder.step()
# #             epoch_loss += loss.item()

# #         avg_loss = epoch_loss / len(dataloader)
# #         print(f"Epoch [{epoch+1}/{epochs}], Encoder Loss: {avg_loss:.4f}")

# #         # Validation loss
# #         encoder.eval()
# #         decoder.eval()
# #         with torch.no_grad():
# #             val_encoded = encoder(torch.tensor(X_val, dtype=torch.float32).to(device))
# #             val_decoded = decoder(val_encoded)
# #             val_loss = criterion(val_decoded, torch.tensor(X_val, dtype=torch.float32).to(device)).item()
# #         print(f"Validation Loss: {val_loss:.4f}")

# #         # Early stopping
# #         if val_loss < best_val_loss:
# #             best_val_loss = val_loss
# #             patience_counter = 0
# #             torch.save(encoder.state_dict(), encoder_model_file)  # Save best model
# #         else:
# #             patience_counter += 1
# #             print("Early stopping counter:", patience_counter)
# #             if patience_counter >= patience:
# #                 print("Early stopping triggered for encoder.")
# #                 break

# # # Train Decoder
# # def train_decoder():
# #     print("Training Decoder...")
# #     encoder.eval()
# #     encoded_train = encoder(torch.tensor(X_train, dtype=torch.float32).to(device)).detach()

# #     decoder.train()
# #     best_val_loss = float('inf')
# #     patience_counter = 0
# #     # clip_value = 1

# #     for epoch in range(epochs):
# #         epoch_loss = 0
# #         dataloader = DataLoader(TensorDataset(encoded_train, torch.tensor(X_train, dtype=torch.float32).to(device)), 
# #                                 batch_size=batch_size, shuffle=True, num_workers=0)

# #         for batch_X, batch_y in dataloader:
# #             batch_X, batch_y = batch_X.to(device), batch_y.to(device)
            
# #             # Add Gaussian noise
# #             noisy_batch_X = add_noise(batch_X)

# #             optimizer_decoder.zero_grad()
# #             outputs = decoder(noisy_batch_X)
# #             loss = criterion(outputs, batch_y)
# #             loss.backward()
            
# #             # torch.nn.utils.clip_grad_norm_(decoder.parameters(), max_norm=clip_value)  # Option 1
# #             # torch.nn.utils.clip_grad_value_(decoder.parameters(), clip_value=clip_value)  # Option 2
            
# #             optimizer_decoder.step()
            
# #             epoch_loss += loss.item()

# #         avg_loss = epoch_loss / len(dataloader)
# #         print(f"Epoch [{epoch+1}/{epochs}], Decoder Loss: {avg_loss:.4f}")

# #         # Validation loss
# #         decoder.eval()
# #         with torch.no_grad():
# #             val_encoded = encoder(torch.tensor(X_val, dtype=torch.float32).to(device))
# #             val_decoded = decoder(val_encoded)
# #             val_loss = criterion(val_decoded, torch.tensor(X_val, dtype=torch.float32).to(device)).item()
# #         print(f"Validation Loss: {val_loss:.4f}")

# #         # Early stopping
# #         if val_loss < best_val_loss:
# #             best_val_loss = val_loss
# #             patience_counter = 0
# #             torch.save(decoder.state_dict(), decoder_model_file)  # Save best model
# #         else:
# #             patience_counter += 1
# #             print("Early stopping counter:", patience_counter)
# #             if patience_counter >= patience:
# #                 print("Early stopping triggered for decoder.")
# #                 break

# # # Train models if files do not exist
# # if os.path.exists(encoder_model_file) and os.path.exists(decoder_model_file):
# #     print("Model files exist. Loading the models...")
# #     encoder.load_state_dict(torch.load(encoder_model_file))
# #     decoder.load_state_dict(torch.load(decoder_model_file))
# # else:
# #     os.makedirs('./autoencoder_trials', exist_ok=True)
# #     train_encoder()
# #     train_decoder()

# # # Combine Encoder and Decoder to form the Autoencoder
# # class Autoencoder(nn.Module):
# #     def __init__(self, encoder, decoder):
# #         super(Autoencoder, self).__init__()
# #         self.encoder = encoder
# #         self.decoder = decoder

# #     def forward(self, x):
# #         encoded = self.encoder(x)
# #         decoded = self.decoder(encoded)
# #         return decoded

# # # Load trained models
# # encoder.load_state_dict(torch.load(encoder_model_file))
# # decoder.load_state_dict(torch.load(decoder_model_file))
# # autoencoder = Autoencoder(encoder, decoder).to(device)
# # autoencoder.eval()

# # # Calculate reconstruction error on the test set
# # with torch.no_grad():
# #     reconstructed_test = autoencoder(torch.tensor(X_test, dtype=torch.float32).to(device)).cpu().numpy()

# # # Calculate Mean Squared Error (MSE)
# # mse = np.mean((X_test - reconstructed_test) ** 2)
# # print(f'Mean Squared Error (MSE): {mse}')

# # # Calculate Mean Absolute Error (MAE)
# # mae = np.mean(np.abs(X_test - reconstructed_test))
# # print(f'Mean Absolute Error (MAE): {mae}')

# # # Calculate Reconstruction Error Percentage
# # reconstruction_error_percentage = (
# #     np.mean(np.abs(X_test - reconstructed_test) / (np.abs(X_test) + 1e-8), axis=1) * 100
# # )
# # reconstruction_error_percentage_mean = np.mean(reconstruction_error_percentage)
# # print(f'Reconstruction Error Percentage: {reconstruction_error_percentage_mean:.4f}%')

# # def calculate_index_error_percentage(index, X, reconstructed_X):
# #     print(np.mean(np.abs(X[index] - reconstructed_X[index]) / (np.abs(X[index]) + 1e-8)) * 100)  


# import os
# import torch
# import torch.nn as nn
# import torch.optim as optim
# import numpy as np
# from torch.utils.data import DataLoader, TensorDataset

# # Check if CUDA is available
# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# print(f"Using device: {device}")

# # Define Autoencoder
# class Autoencoder(nn.Module):
#     def __init__(self, input_dim, encoding_dim, dropout_rate):
#         super(Autoencoder, self).__init__()
#         self.encoder = nn.Sequential(
#             nn.Linear(input_dim, 128),
#             nn.ReLU(),
#             nn.Dropout(dropout_rate),
#             nn.Linear(128, 64),
#             nn.ReLU(),
#             nn.Dropout(dropout_rate),
#             nn.Linear(64, encoding_dim)
#         )
#         self.decoder = nn.Sequential(
#             nn.Linear(encoding_dim, 64),
#             nn.ReLU(),
#             nn.Dropout(dropout_rate),
#             nn.Linear(64, 128),
#             nn.ReLU(),
#             nn.Dropout(dropout_rate),
#             nn.Linear(128, input_dim)
#         )
    
#     def forward(self, x):
#         encoded = self.encoder(x)
#         decoded = self.decoder(encoded)
#         return decoded

# # Define Relative Euclidean Error Loss
# class RelativeEuclideanError(nn.Module):
#     def __init__(self, epsilon=1e-8):
#         super(RelativeEuclideanError, self).__init__()
#         self.epsilon = epsilon

#     def forward(self, y_true, y_pred):
#         numerator = torch.norm(y_true - y_pred, dim=1)
#         denominator = torch.norm(y_true, dim=1) + self.epsilon
#         return torch.mean(numerator / denominator)

# # Define input dimensions
# input_dim = X_train.shape[1]

# # Model file path
# autoencoder_model_file = './autoencoder_trials/autoencoder.pth'

# # Hyperparameters
# encoding_dim = 5
# learning_rate = 0.0005
# dropout_rate = 0.3
# epochs = 750
# batch_size = 16
# patience = 40

# # Initialize model
# autoencoder = Autoencoder(input_dim, encoding_dim, dropout_rate).to(device)
# optimizer = optim.Adam(autoencoder.parameters(), lr=learning_rate)
# # criterion = RelativeEuclideanError()
# criterion = nn.MSELoss()

# # Train Autoencoder
# def train_autoencoder():
#     print("Training Autoencoder...")
#     autoencoder.train()
#     best_val_loss = float('inf')
#     patience_counter = 0

#     for epoch in range(epochs):
#         epoch_loss = 0
#         dataloader = DataLoader(TensorDataset(torch.tensor(X_train, dtype=torch.float32).to(device), 
#                                               torch.tensor(X_train, dtype=torch.float32).to(device)), 
#                                 batch_size=batch_size, shuffle=True, num_workers=0)

#         for batch_X, _ in dataloader:
#             batch_X = batch_X.to(device)
#             optimizer.zero_grad()
#             outputs = autoencoder(batch_X)
#             loss = criterion(outputs, batch_X)
#             loss.backward()
#             optimizer.step()
#             epoch_loss += loss.item()

#         avg_loss = epoch_loss / len(dataloader)
#         print(f"Epoch [{epoch+1}/{epochs}], Loss: {avg_loss:.4f}")

#         # Validation loss
#         autoencoder.eval()
#         with torch.no_grad():
#             val_outputs = autoencoder(torch.tensor(X_val, dtype=torch.float32).to(device))
#             val_loss = criterion(val_outputs, torch.tensor(X_val, dtype=torch.float32).to(device)).item()
            
#             # calculate Relative Euclidean Error
#             relative_error = np.mean(np.abs(X_val - val_outputs.cpu().numpy()) / (np.abs(X_val) + 1e-8), axis=1) * 100
#             relative_error_mean = np.mean(relative_error)
            
#             combined_metric = 0.8 * val_loss + 0.2 * relative_error_mean
            
#         print(f"Validation Loss: {combined_metric:.4f}")

#         # Early stopping
#         if combined_metric < best_val_loss:
#             best_val_loss = combined_metric
#             patience_counter = 0
#             torch.save(autoencoder.state_dict(), autoencoder_model_file)
#         else:
#             patience_counter += 1
#             print("Early stopping counter:", patience_counter)
#             if patience_counter >= patience:
#                 print("Early stopping triggered.")
#                 break

# # Train model if file does not exist
# if os.path.exists(autoencoder_model_file):
#     print("Model file exists. Loading the model...")
#     autoencoder.load_state_dict(torch.load(autoencoder_model_file))
# else:
#     os.makedirs('./autoencoder_trials', exist_ok=True)
#     train_autoencoder()

# # Evaluate Autoencoder
# autoencoder.eval()
# with torch.no_grad():
#     reconstructed_test = autoencoder(torch.tensor(X_test, dtype=torch.float32).to(device)).cpu().numpy()

# # Calculate evaluation metrics
# mse = np.mean((X_test - reconstructed_test) ** 2)
# print(f'Mean Squared Error (MSE): {mse}')

# mae = np.mean(np.abs(X_test - reconstructed_test))
# print(f'Mean Absolute Error (MAE): {mae}')

# reconstruction_error_percentage = (
#     np.mean(np.abs(X_test - reconstructed_test) / (np.abs(X_test) + 1e-8), axis=1) * 100
# )
# reconstruction_error_percentage_mean = np.mean(reconstruction_error_percentage)
# print(f'Reconstruction Error Percentage: {reconstruction_error_percentage_mean:.4f}%')

# def calculate_index_error_percentage(index, X, reconstructed_X):
#     print(np.mean(np.abs(X[index] - reconstructed_X[index]) / (np.abs(X[index]) + 1e-8)) * 100)

# %%
# # number of points with error greater than average
# np.sum(reconstruction_error_percentage > reconstruction_error_percentage_mean)

# %%
# # plot line graph of price for entire df, price column is df['Close']
# last_15_percent_index = int(len(df) * 0.85)
# last_30_percent_index = int(len(df) * 0.70)

# plt.figure(figsize=(14, 7))
# plt.plot(df['Close'], label='Train', color='blue')
# plt.plot(df['Close'].iloc[last_30_percent_index:last_15_percent_index], label='Val', color='green')
# plt.plot(df['Close'].iloc[last_15_percent_index:], label='Test', color='red')
# plt.title('Close Price History')
# plt.xlabel('Date')
# plt.ylabel('Price')
# plt.legend()
# plt.show()

# %%
# #   scatter graph to plot all errors, dont need to rearragne points
# plt.figure(figsize=(14, 7))
# plt.scatter(range(len(reconstruction_error_percentage)), reconstruction_error_percentage, color='blue')
# plt.ylim(0, 200)
# plt.title('Reconstruction Error Percentage')
# plt.xlabel('Data Point')
# plt.ylabel('Error Percentage')
# plt.legend()
# plt.show()

# %%
# # error count frequency per range
# error_ranges = [0, 1, 2, 5, 10, 20, 50, 100, 200]
# error_counts = np.zeros(len(error_ranges) - 1)
# for i in range(len(error_ranges) - 1):
#     error_counts[i] = np.sum((reconstruction_error_percentage > error_ranges[i]) & (reconstruction_error_percentage <= error_ranges[i + 1]))

# # print with descriptino
# for i in range(len(error_ranges) - 1):
#     print(f'Error percentage between {error_ranges[i]} and {error_ranges[i + 1]}: {error_counts[i]}')

# %%
# # get cosine similarity
# from sklearn.metrics.pairwise import cosine_similarity
# cosine_similarities  = np.diag(cosine_similarity(X_test, reconstructed_test))

# # get some statistics on the cosine similarities
# cosine_similarities_mean = np.mean(cosine_similarities)
# cosine_similarities_std = np.std(cosine_similarities)
# cosine_similarities_min = np.min(cosine_similarities)
# cosine_similarities_max = np.max(cosine_similarities)

# print(f'Cosine Similarity Mean: {cosine_similarities_mean}')
# print(f'Cosine Similarity Std: {cosine_similarities_std}')
# print(f'Cosine Similarity Min: {cosine_similarities_min}')
# print(f'Cosine Similarity Max: {cosine_similarities_max}')

# %%
# from sklearn.manifold import TSNE
# import matplotlib.pyplot as plt

# # Combine original and reconstructed vectors
# X_combined = np.vstack([X_test, reconstructed_test])
# labels = ["Original"] * len(X_test) + ["Reconstructed"] * len(reconstructed_test)

# # Apply t-SNE
# tsne = TSNE(n_components=2, perplexity=30, random_state=42)
# X_tsne = tsne.fit_transform(X_combined)

# # Plot
# plt.figure(figsize=(12, 6))
# plt.scatter(X_tsne[:len(X_test), 0], X_tsne[:len(X_test), 1], label="Original", alpha=0.5)
# plt.scatter(X_tsne[len(X_test):, 0], X_tsne[len(X_test):, 1], label="Reconstructed", alpha=0.5)
# plt.legend()
# plt.title("t-SNE Visualization of Original vs. Reconstructed Data")
# plt.show()

# %%
# from sklearn.decomposition import PCA

# X_combined = np.vstack([X_test, reconstructed_test])

# # Apply PCA
# pca = PCA(n_components=2)
# X_pca = pca.fit_transform(X_combined)

# # Plot
# plt.figure(figsize=(12, 6))
# plt.scatter(X_pca[:len(X_test), 0], X_pca[:len(X_test), 1], label="Original", alpha=0.5)
# plt.scatter(X_pca[len(X_test):, 0], X_pca[len(X_test):, 1], label="Reconstructed", alpha=0.5)
# plt.legend()
# plt.title("PCA Projection of Original vs. Reconstructed Data")
# plt.show()

# %%
# from numpy.linalg import norm

# euclidean_dist = np.mean([norm(X_test[i] - reconstructed_test[i]) for i in range(len(X_test))])
# print(f"Average Euclidean Distance: {euclidean_dist:.4f}")

# relative_error = euclidean_dist / np.mean(np.linalg.norm(X_test, axis=1))
# print(f"Relative Euclidean Error: {relative_error:.4f}")

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader, TensorDataset
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
from numpy.linalg import norm

# Check device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Define Autoencoder
class Autoencoder(nn.Module):
    def __init__(self, input_dim, encoding_dim, dropout_rate):
        super(Autoencoder, self).__init__()
        self.encoder = nn.Sequential(
            nn.Linear(input_dim, 128),
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.Linear(64, encoding_dim)
        )
        self.decoder = nn.Sequential(
            nn.Linear(encoding_dim, 64),
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.Linear(64, 128),
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.Linear(128, input_dim)
        )
    
    def forward(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return decoded

# Define input dimensions
input_dim = X_train.shape[1]

# Hyperparameters
encoding_dim = 5
learning_rate = 0.01
dropout_rate = 0.0
epochs = 750
batch_size = 32
patience = 40

# Training function
def train_autoencoder():
    autoencoder = Autoencoder(input_dim, encoding_dim, dropout_rate).to(device)
    optimizer = optim.Adam(autoencoder.parameters(), lr=learning_rate)
    criterion = nn.MSELoss()
    
    best_val_loss = float('inf')
    patience_counter = 0
    
    for epoch in range(epochs):
        epoch_loss = 0
        dataloader = DataLoader(TensorDataset(torch.tensor(X_train, dtype=torch.float32).to(device)), batch_size=batch_size, shuffle=True)

        for batch_X in dataloader:
            batch_X = batch_X[0]
            optimizer.zero_grad()
            outputs = autoencoder(batch_X)
            loss = criterion(outputs, batch_X)
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item()
        
        avg_loss = epoch_loss / len(dataloader)
        
        # Validation
        autoencoder.eval()
        with torch.no_grad():
            val_outputs = autoencoder(torch.tensor(X_val, dtype=torch.float32).to(device))
            mse_loss = criterion(val_outputs, torch.tensor(X_val, dtype=torch.float32).to(device)).item()
            ree = np.mean(np.linalg.norm(X_val - val_outputs.cpu().numpy(), axis=1) / np.linalg.norm(X_val, axis=1))
            combined_metric = 0.8 * mse_loss + 0.2 * ree
        
        print(f"Epoch [{epoch+1}/{epochs}], Combined Loss: {combined_metric:.4f}")
        
        # Early stopping
        if combined_metric < best_val_loss:
            best_val_loss = combined_metric
            patience_counter = 0
            best_model = autoencoder.state_dict()
        else:
            patience_counter += 1
            if patience_counter >= patience:
                print("Early stopping triggered.")
                break
    
    return best_model

# Run 10 trials
num_trials = 10
metrics = []
error_percentages = []

t_sne_results = []
pca_results = []

for trial in range(num_trials):
    print(f"Starting trial {trial+1}...")
    best_model = train_autoencoder()
    autoencoder = Autoencoder(input_dim, encoding_dim, dropout_rate).to(device)
    autoencoder.load_state_dict(best_model)
    autoencoder.eval()
    
    with torch.no_grad():
        reconstructed_test = autoencoder(torch.tensor(X_test, dtype=torch.float32).to(device)).cpu().numpy()
    
    mse = np.mean((X_test - reconstructed_test) ** 2)
    mae = np.mean(np.abs(X_test - reconstructed_test))
    ree = np.mean(np.linalg.norm(X_test - reconstructed_test, axis=1) / np.linalg.norm(X_test, axis=1))
    euclidean_dist = np.mean([norm(X_test[i] - reconstructed_test[i]) for i in range(len(X_test))])
    
    print(f'Trial {trial+1} - MSE: {mse:.4f}, MAE: {mae:.4f}, REE: {ree:.4f}, Euclidean Distance: {euclidean_dist:.4f}')
    metrics.append([mse, mae, ree, euclidean_dist])
    
    # Reconstruction Error Percentage
    reconstruction_error_percentage = (
        np.mean(np.abs(X_test - reconstructed_test) / (np.abs(X_test) + 1e-8), axis=1) * 100
    )
    error_percentages.append(reconstruction_error_percentage)
    
    # t-SNE
    X_combined = np.vstack([X_test, reconstructed_test])
    labels = ["Original"] * len(X_test) + ["Reconstructed"] * len(reconstructed_test)
    tsne = TSNE(n_components=2, perplexity=30, random_state=42)
    t_sne_results.append(tsne.fit_transform(X_combined))
    
    # PCA
    pca = PCA(n_components=2)
    pca_results.append(pca.fit_transform(X_combined))
# Out:
# Using device: cuda
# Starting trial 1...
# Epoch [1/750], Combined Loss: 0.0178
# Epoch [2/750], Combined Loss: 0.0103
# Epoch [3/750], Combined Loss: 0.0097
# Epoch [4/750], Combined Loss: 0.0095
# Epoch [5/750], Combined Loss: 0.0110
# Epoch [6/750], Combined Loss: 0.0132
# Epoch [7/750], Combined Loss: 0.0097
# Epoch [8/750], Combined Loss: 0.0093
# Epoch [9/750], Combined Loss: 0.0231
# Epoch [10/750], Combined Loss: 0.0097
# Epoch [11/750], Combined Loss: 0.0079
# Epoch [12/750], Combined Loss: 0.0082
# Epoch [13/750], Combined Loss: 0.0066
# Epoch [14/750], Combined Loss: 0.0107
# Epoch [15/750], Combined Loss: 0.0080
# Epoch [16/750], Combined Loss: 0.0093
# Epoch [17/750], Combined Loss: 0.0080
# Epoch [18/750], Combined Loss: 0.0145
# Epoch [19/750], Combined Loss: 0.0126
# Epoch [20/750], Combined Loss: 0.0095
# Epoch [21/750], Combined Loss: 0.0082
# Epoch [22/750], Combined Loss: 0.0099
# Epoch [23/750], Combined Loss: 0.0119
# Epoch [24/750], Combined Loss: 0.0096
# Epoch [25/750], Combined Loss: 0.0119
# Epoch [26/750], Combined Loss: 0.0188
# Epoch [27/750], Combined Loss: 0.0103
# Epoch [28/750], Combined Loss: 0.0073
# Epoch [29/750], Combined Loss: 0.0079
# Epoch [30/750], Combined Loss: 0.0067
# Epoch [31/750], Combined Loss: 0.0075
# Epoch [32/750], Combined Loss: 0.0088
# Epoch [33/750], Combined Loss: 0.0074
# Epoch [34/750], Combined Loss: 0.0083
# Epoch [35/750], Combined Loss: 0.0078
# Epoch [36/750], Combined Loss: 0.0159
# Epoch [37/750], Combined Loss: 0.0083
# Epoch [38/750], Combined Loss: 0.0056
# Epoch [39/750], Combined Loss: 0.0078
# Epoch [40/750], Combined Loss: 0.0074
# Epoch [41/750], Combined Loss: 0.0078
# Epoch [42/750], Combined Loss: 0.0082
# Epoch [43/750], Combined Loss: 0.0083
# Epoch [44/750], Combined Loss: 0.0065
# Epoch [45/750], Combined Loss: 0.0063
# Epoch [46/750], Combined Loss: 0.0043
# Epoch [47/750], Combined Loss: 0.0056
# Epoch [48/750], Combined Loss: 0.0046
# Epoch [49/750], Combined Loss: 0.0031
# Epoch [50/750], Combined Loss: 0.0049
# Epoch [51/750], Combined Loss: 0.0061
# Epoch [52/750], Combined Loss: 0.0054
# Epoch [53/750], Combined Loss: 0.0056
# Epoch [54/750], Combined Loss: 0.0058
# Epoch [55/750], Combined Loss: 0.0052
# Epoch [56/750], Combined Loss: 0.0045
# Epoch [57/750], Combined Loss: 0.0052
# Epoch [58/750], Combined Loss: 0.0050
# Epoch [59/750], Combined Loss: 0.0089
# Epoch [60/750], Combined Loss: 0.0047
# Epoch [61/750], Combined Loss: 0.0052
# Epoch [62/750], Combined Loss: 0.0071
# Epoch [63/750], Combined Loss: 0.0055
# Epoch [64/750], Combined Loss: 0.0097
# Epoch [65/750], Combined Loss: 0.0055
# Epoch [66/750], Combined Loss: 0.0103
# Epoch [67/750], Combined Loss: 0.0047
# Epoch [68/750], Combined Loss: 0.0053
# Epoch [69/750], Combined Loss: 0.0038
# Epoch [70/750], Combined Loss: 0.0041
# Epoch [71/750], Combined Loss: 0.0034
# Epoch [72/750], Combined Loss: 0.0063
# Epoch [73/750], Combined Loss: 0.0047
# Epoch [74/750], Combined Loss: 0.0046
# Epoch [75/750], Combined Loss: 0.0038
# Epoch [76/750], Combined Loss: 0.0050
# Epoch [77/750], Combined Loss: 0.0038
# Epoch [78/750], Combined Loss: 0.0043
# Epoch [79/750], Combined Loss: 0.0073
# Epoch [80/750], Combined Loss: 0.0060
# Epoch [81/750], Combined Loss: 0.0052
# Epoch [82/750], Combined Loss: 0.0035
# Epoch [83/750], Combined Loss: 0.0061
# Epoch [84/750], Combined Loss: 0.0119
# Epoch [85/750], Combined Loss: 0.0052
# Epoch [86/750], Combined Loss: 0.0037
# Epoch [87/750], Combined Loss: 0.0071
# Epoch [88/750], Combined Loss: 0.0061
# Epoch [89/750], Combined Loss: 0.0045
# Early stopping triggered.
# Trial 1 - MSE: 0.0039, MAE: 0.0474, REE: 0.0421, Euclidean Distance: 0.1941
# Starting trial 2...
# Epoch [1/750], Combined Loss: 0.0077
# Epoch [2/750], Combined Loss: 0.0070
# Epoch [3/750], Combined Loss: 0.0090
# Epoch [4/750], Combined Loss: 0.0061
# Epoch [5/750], Combined Loss: 0.0062
# Epoch [6/750], Combined Loss: 0.0064
# Epoch [7/750], Combined Loss: 0.0079
# Epoch [8/750], Combined Loss: 0.0074
# Epoch [9/750], Combined Loss: 0.0063
# Epoch [10/750], Combined Loss: 0.0051
# Epoch [11/750], Combined Loss: 0.0068
# Epoch [12/750], Combined Loss: 0.0069
# Epoch [13/750], Combined Loss: 0.0060
# Epoch [14/750], Combined Loss: 0.0096
# Epoch [15/750], Combined Loss: 0.0043
# Epoch [16/750], Combined Loss: 0.0074
# Epoch [17/750], Combined Loss: 0.0047
# Epoch [18/750], Combined Loss: 0.0063
# Epoch [19/750], Combined Loss: 0.0057
# Epoch [20/750], Combined Loss: 0.0149
# Epoch [21/750], Combined Loss: 0.0069
# Epoch [22/750], Combined Loss: 0.0098
# Epoch [23/750], Combined Loss: 0.0078
# Epoch [24/750], Combined Loss: 0.0076
# Epoch [25/750], Combined Loss: 0.0070
# Epoch [26/750], Combined Loss: 0.0085
# Epoch [27/750], Combined Loss: 0.0070
# Epoch [28/750], Combined Loss: 0.0125
# Epoch [29/750], Combined Loss: 0.0073
# Epoch [30/750], Combined Loss: 0.0053
# Epoch [31/750], Combined Loss: 0.0059
# Epoch [32/750], Combined Loss: 0.0050
# Epoch [33/750], Combined Loss: 0.0076
# Epoch [34/750], Combined Loss: 0.0066
# Epoch [35/750], Combined Loss: 0.0103
# Epoch [36/750], Combined Loss: 0.0115
# Epoch [37/750], Combined Loss: 0.0087
# Epoch [38/750], Combined Loss: 0.0121
# Epoch [39/750], Combined Loss: 0.0077
# Epoch [40/750], Combined Loss: 0.0135
# Epoch [41/750], Combined Loss: 0.0082
# Epoch [42/750], Combined Loss: 0.0120
# Epoch [43/750], Combined Loss: 0.0079
# Epoch [44/750], Combined Loss: 0.0104
# Epoch [45/750], Combined Loss: 0.0057
# Epoch [46/750], Combined Loss: 0.0084
# Epoch [47/750], Combined Loss: 0.0107
# Epoch [48/750], Combined Loss: 0.0065
# Epoch [49/750], Combined Loss: 0.0053
# Epoch [50/750], Combined Loss: 0.0046
# Epoch [51/750], Combined Loss: 0.0042
# Epoch [52/750], Combined Loss: 0.0072
# Epoch [53/750], Combined Loss: 0.0057
# Epoch [54/750], Combined Loss: 0.0077
# Epoch [55/750], Combined Loss: 0.0176
# Epoch [56/750], Combined Loss: 0.0054
# Epoch [57/750], Combined Loss: 0.0158
# Epoch [58/750], Combined Loss: 0.0050
# Epoch [59/750], Combined Loss: 0.0039
# Epoch [60/750], Combined Loss: 0.0046
# Epoch [61/750], Combined Loss: 0.0096
# Epoch [62/750], Combined Loss: 0.0065
# Epoch [63/750], Combined Loss: 0.0071
# Epoch [64/750], Combined Loss: 0.0040
# Epoch [65/750], Combined Loss: 0.0185
# Epoch [66/750], Combined Loss: 0.0037
# Epoch [67/750], Combined Loss: 0.0059
# Epoch [68/750], Combined Loss: 0.0054
# Epoch [69/750], Combined Loss: 0.0048
# Epoch [70/750], Combined Loss: 0.0077
# Epoch [71/750], Combined Loss: 0.0087
# Epoch [72/750], Combined Loss: 0.0052
# Epoch [73/750], Combined Loss: 0.0074
# Epoch [74/750], Combined Loss: 0.0067
# Epoch [75/750], Combined Loss: 0.0056
# Epoch [76/750], Combined Loss: 0.0069
# Epoch [77/750], Combined Loss: 0.0057
# Epoch [78/750], Combined Loss: 0.0284
# Epoch [79/750], Combined Loss: 0.0068
# Epoch [80/750], Combined Loss: 0.0079
# Epoch [81/750], Combined Loss: 0.0054
# Epoch [82/750], Combined Loss: 0.0048
# Epoch [83/750], Combined Loss: 0.0030
# Epoch [84/750], Combined Loss: 0.0065
# Epoch [85/750], Combined Loss: 0.0038
# Epoch [86/750], Combined Loss: 0.0042
# Epoch [87/750], Combined Loss: 0.0072
# Epoch [88/750], Combined Loss: 0.0063
# Epoch [89/750], Combined Loss: 0.0068
# Epoch [90/750], Combined Loss: 0.0060
# Epoch [91/750], Combined Loss: 0.0082
# Epoch [92/750], Combined Loss: 0.0063
# Epoch [93/750], Combined Loss: 0.0096
# Epoch [94/750], Combined Loss: 0.0052
# Epoch [95/750], Combined Loss: 0.0191
# Epoch [96/750], Combined Loss: 0.0060
# Epoch [97/750], Combined Loss: 0.0078
# Epoch [98/750], Combined Loss: 0.0083
# Epoch [99/750], Combined Loss: 0.0073
# Epoch [100/750], Combined Loss: 0.0052
# Epoch [101/750], Combined Loss: 0.0059
# Epoch [102/750], Combined Loss: 0.0078
# Epoch [103/750], Combined Loss: 0.0102
# Epoch [104/750], Combined Loss: 0.0064
# Epoch [105/750], Combined Loss: 0.0070
# Epoch [106/750], Combined Loss: 0.0141
# Epoch [107/750], Combined Loss: 0.0052
# Epoch [108/750], Combined Loss: 0.0092
# Epoch [109/750], Combined Loss: 0.0085
# Epoch [110/750], Combined Loss: 0.0047
# Epoch [111/750], Combined Loss: 0.0112
# Epoch [112/750], Combined Loss: 0.0103
# Epoch [113/750], Combined Loss: 0.0052
# Epoch [114/750], Combined Loss: 0.0052
# Epoch [115/750], Combined Loss: 0.0102
# Epoch [116/750], Combined Loss: 0.0147
# Epoch [117/750], Combined Loss: 0.0042
# Epoch [118/750], Combined Loss: 0.0047
# Epoch [119/750], Combined Loss: 0.0050
# Epoch [120/750], Combined Loss: 0.0049
# Epoch [121/750], Combined Loss: 0.0066
# Epoch [122/750], Combined Loss: 0.0053
# Epoch [123/750], Combined Loss: 0.0063
# Early stopping triggered.
# Trial 2 - MSE: 0.0075, MAE: 0.0650, REE: 0.0587, Euclidean Distance: 0.2673
# Starting trial 3...
# Epoch [1/750], Combined Loss: 0.0127
# Epoch [2/750], Combined Loss: 0.0120
# Epoch [3/750], Combined Loss: 0.0124
# Epoch [4/750], Combined Loss: 0.0105
# Epoch [5/750], Combined Loss: 0.0078
# Epoch [6/750], Combined Loss: 0.0074
# Epoch [7/750], Combined Loss: 0.0070
# Epoch [8/750], Combined Loss: 0.0087
# Epoch [9/750], Combined Loss: 0.0079
# Epoch [10/750], Combined Loss: 0.0135
# Epoch [11/750], Combined Loss: 0.0120
# Epoch [12/750], Combined Loss: 0.0083
# Epoch [13/750], Combined Loss: 0.0110
# Epoch [14/750], Combined Loss: 0.0082
# Epoch [15/750], Combined Loss: 0.0210
# Epoch [16/750], Combined Loss: 0.0101
# Epoch [17/750], Combined Loss: 0.0115
# Epoch [18/750], Combined Loss: 0.0094
# Epoch [19/750], Combined Loss: 0.0103
# Epoch [20/750], Combined Loss: 0.0085
# Epoch [21/750], Combined Loss: 0.0097
# Epoch [22/750], Combined Loss: 0.0095
# Epoch [23/750], Combined Loss: 0.0124
# Epoch [24/750], Combined Loss: 0.0083
# Epoch [25/750], Combined Loss: 0.0122
# Epoch [26/750], Combined Loss: 0.0083
# Epoch [27/750], Combined Loss: 0.0587
# Epoch [28/750], Combined Loss: 0.0097
# Epoch [29/750], Combined Loss: 0.0151
# Epoch [30/750], Combined Loss: 0.0138
# Epoch [31/750], Combined Loss: 0.0121
# Epoch [32/750], Combined Loss: 0.0142
# Epoch [33/750], Combined Loss: 0.0111
# Epoch [34/750], Combined Loss: 0.0076
# Epoch [35/750], Combined Loss: 0.0111
# Epoch [36/750], Combined Loss: 0.0119
# Epoch [37/750], Combined Loss: 0.0117
# Epoch [38/750], Combined Loss: 0.0159
# Epoch [39/750], Combined Loss: 0.0109
# Epoch [40/750], Combined Loss: 0.0140
# Epoch [41/750], Combined Loss: 0.0080
# Epoch [42/750], Combined Loss: 0.0114
# Epoch [43/750], Combined Loss: 0.0183
# Epoch [44/750], Combined Loss: 0.0471
# Epoch [45/750], Combined Loss: 0.0090
# Epoch [46/750], Combined Loss: 0.0099
# Epoch [47/750], Combined Loss: 0.0074
# Early stopping triggered.
# Trial 3 - MSE: 0.0107, MAE: 0.0732, REE: 0.0698, Euclidean Distance: 0.3225
# Starting trial 4...
# Epoch [1/750], Combined Loss: 0.0184
# Epoch [2/750], Combined Loss: 0.0086
# Epoch [3/750], Combined Loss: 0.0060
# Epoch [4/750], Combined Loss: 0.0046
# Epoch [5/750], Combined Loss: 0.0065
# Epoch [6/750], Combined Loss: 0.0050
# Epoch [7/750], Combined Loss: 0.0045
# Epoch [8/750], Combined Loss: 0.0065
# Epoch [9/750], Combined Loss: 0.0058
# Epoch [10/750], Combined Loss: 0.0072
# Epoch [11/750], Combined Loss: 0.0343
# Epoch [12/750], Combined Loss: 0.0077
# Epoch [13/750], Combined Loss: 0.0069
# Epoch [14/750], Combined Loss: 0.0077
# Epoch [15/750], Combined Loss: 0.0077
# Epoch [16/750], Combined Loss: 0.0087
# Epoch [17/750], Combined Loss: 0.0089
# Epoch [18/750], Combined Loss: 0.0122
# Epoch [19/750], Combined Loss: 0.0193
# Epoch [20/750], Combined Loss: 0.0142
# Epoch [21/750], Combined Loss: 0.0142
# Epoch [22/750], Combined Loss: 0.0104
# Epoch [23/750], Combined Loss: 0.0287
# Epoch [24/750], Combined Loss: 0.0101
# Epoch [25/750], Combined Loss: 0.0083
# Epoch [26/750], Combined Loss: 0.0120
# Epoch [27/750], Combined Loss: 0.0090
# Epoch [28/750], Combined Loss: 0.0099
# Epoch [29/750], Combined Loss: 0.0160
# Epoch [30/750], Combined Loss: 0.0263
# Epoch [31/750], Combined Loss: 0.0123
# Epoch [32/750], Combined Loss: 0.0111
# Epoch [33/750], Combined Loss: 0.0084
# Epoch [34/750], Combined Loss: 0.0123
# Epoch [35/750], Combined Loss: 0.0095
# Epoch [36/750], Combined Loss: 0.0088
# Epoch [37/750], Combined Loss: 0.0323
# Epoch [38/750], Combined Loss: 0.0351
# Epoch [39/750], Combined Loss: 0.0111
# Epoch [40/750], Combined Loss: 0.0084
# Epoch [41/750], Combined Loss: 0.0087
# Epoch [42/750], Combined Loss: 0.0094
# Epoch [43/750], Combined Loss: 0.0087
# Epoch [44/750], Combined Loss: 0.0126
# Epoch [45/750], Combined Loss: 0.0171
# Epoch [46/750], Combined Loss: 0.0172
# Epoch [47/750], Combined Loss: 0.0079
# Early stopping triggered.
# Trial 4 - MSE: 0.0106, MAE: 0.0904, REE: 0.0688, Euclidean Distance: 0.3256
# Starting trial 5...
# Epoch [1/750], Combined Loss: 0.0075
# Epoch [2/750], Combined Loss: 0.0114
# Epoch [3/750], Combined Loss: 0.0075
# Epoch [4/750], Combined Loss: 0.0059
# Epoch [5/750], Combined Loss: 0.0152
# Epoch [6/750], Combined Loss: 0.0049
# Epoch [7/750], Combined Loss: 0.0063
# Epoch [8/750], Combined Loss: 0.0053
# Epoch [9/750], Combined Loss: 0.0049
# Epoch [10/750], Combined Loss: 0.0075
# Epoch [11/750], Combined Loss: 0.0343
# Epoch [12/750], Combined Loss: 0.0072
# Epoch [13/750], Combined Loss: 0.0057
# Epoch [14/750], Combined Loss: 0.0054
# Epoch [15/750], Combined Loss: 0.0057
# Epoch [16/750], Combined Loss: 0.0054
# Epoch [17/750], Combined Loss: 0.0064
# Epoch [18/750], Combined Loss: 0.0056
# Epoch [19/750], Combined Loss: 0.0050
# Epoch [20/750], Combined Loss: 0.0044
# Epoch [21/750], Combined Loss: 0.0052
# Epoch [22/750], Combined Loss: 0.0072
# Epoch [23/750], Combined Loss: 0.0052
# Epoch [24/750], Combined Loss: 0.0055
# Epoch [25/750], Combined Loss: 0.0060
# Epoch [26/750], Combined Loss: 0.0062
# Epoch [27/750], Combined Loss: 0.0065
# Epoch [28/750], Combined Loss: 0.0078
# Epoch [29/750], Combined Loss: 0.0073
# Epoch [30/750], Combined Loss: 0.0094
# Epoch [31/750], Combined Loss: 0.0072
# Epoch [32/750], Combined Loss: 0.0105
# Epoch [33/750], Combined Loss: 0.0061
# Epoch [34/750], Combined Loss: 0.0302
# Epoch [35/750], Combined Loss: 0.0056
# Epoch [36/750], Combined Loss: 0.0064
# Epoch [37/750], Combined Loss: 0.0045
# Epoch [38/750], Combined Loss: 0.0083
# Epoch [39/750], Combined Loss: 0.0052
# Epoch [40/750], Combined Loss: 0.0077
# Epoch [41/750], Combined Loss: 0.0049
# Epoch [42/750], Combined Loss: 0.0040
# Epoch [43/750], Combined Loss: 0.0060
# Epoch [44/750], Combined Loss: 0.0066
# Epoch [45/750], Combined Loss: 0.0074
# Epoch [46/750], Combined Loss: 0.0085
# Epoch [47/750], Combined Loss: 0.0104
# Epoch [48/750], Combined Loss: 0.0068
# Epoch [49/750], Combined Loss: 0.0062
# Epoch [50/750], Combined Loss: 0.0075
# Epoch [51/750], Combined Loss: 0.0065
# Epoch [52/750], Combined Loss: 0.0085
# Epoch [53/750], Combined Loss: 0.0078
# Epoch [54/750], Combined Loss: 0.0063
# Epoch [55/750], Combined Loss: 0.0093
# Epoch [56/750], Combined Loss: 0.0074
# Epoch [57/750], Combined Loss: 0.0075
# Epoch [58/750], Combined Loss: 0.0064
# Epoch [59/750], Combined Loss: 0.0066
# Epoch [60/750], Combined Loss: 0.0183
# Epoch [61/750], Combined Loss: 0.0064
# Epoch [62/750], Combined Loss: 0.0160
# Epoch [63/750], Combined Loss: 0.0078
# Epoch [64/750], Combined Loss: 0.0055
# Epoch [65/750], Combined Loss: 0.0050
# Epoch [66/750], Combined Loss: 0.0047
# Epoch [67/750], Combined Loss: 0.0140
# Epoch [68/750], Combined Loss: 0.0082
# Epoch [69/750], Combined Loss: 0.0061
# Epoch [70/750], Combined Loss: 0.0063
# Epoch [71/750], Combined Loss: 0.0046
# Epoch [72/750], Combined Loss: 0.0068
# Epoch [73/750], Combined Loss: 0.0065
# Epoch [74/750], Combined Loss: 0.0094
# Epoch [75/750], Combined Loss: 0.0135
# Epoch [76/750], Combined Loss: 0.0065
# Epoch [77/750], Combined Loss: 0.0062
# Epoch [78/750], Combined Loss: 0.0112
# Epoch [79/750], Combined Loss: 0.0045
# Epoch [80/750], Combined Loss: 0.0068
# Epoch [81/750], Combined Loss: 0.0050
# Epoch [82/750], Combined Loss: 0.0046
# Early stopping triggered.
# Trial 5 - MSE: 0.0049, MAE: 0.0460, REE: 0.0479, Euclidean Distance: 0.2195
# Starting trial 6...
# Epoch [1/750], Combined Loss: 0.0168
# Epoch [2/750], Combined Loss: 0.0107
# Epoch [3/750], Combined Loss: 0.0105
# Epoch [4/750], Combined Loss: 0.0117
# Epoch [5/750], Combined Loss: 0.0072
# Epoch [6/750], Combined Loss: 0.0096
# Epoch [7/750], Combined Loss: 0.0100
# Epoch [8/750], Combined Loss: 0.0102
# Epoch [9/750], Combined Loss: 0.0080
# Epoch [10/750], Combined Loss: 0.0074
# Epoch [11/750], Combined Loss: 0.0142
# Epoch [12/750], Combined Loss: 0.0162
# Epoch [13/750], Combined Loss: 0.0094
# Epoch [14/750], Combined Loss: 0.0087
# Epoch [15/750], Combined Loss: 0.0113
# Epoch [16/750], Combined Loss: 0.0063
# Epoch [17/750], Combined Loss: 0.0102
# Epoch [18/750], Combined Loss: 0.0087
# Epoch [19/750], Combined Loss: 0.0075
# Epoch [20/750], Combined Loss: 0.0133
# Epoch [21/750], Combined Loss: 0.0108
# Epoch [22/750], Combined Loss: 0.0136
# Epoch [23/750], Combined Loss: 0.0074
# Epoch [24/750], Combined Loss: 0.0152
# Epoch [25/750], Combined Loss: 0.0105
# Epoch [26/750], Combined Loss: 0.0087
# Epoch [27/750], Combined Loss: 0.0093
# Epoch [28/750], Combined Loss: 0.0073
# Epoch [29/750], Combined Loss: 0.0139
# Epoch [30/750], Combined Loss: 0.0259
# Epoch [31/750], Combined Loss: 0.0079
# Epoch [32/750], Combined Loss: 0.0086
# Epoch [33/750], Combined Loss: 0.0132
# Epoch [34/750], Combined Loss: 0.0105
# Epoch [35/750], Combined Loss: 0.0111
# Epoch [36/750], Combined Loss: 0.0095
# Epoch [37/750], Combined Loss: 0.0058
# Epoch [38/750], Combined Loss: 0.0077
# Epoch [39/750], Combined Loss: 0.0082
# Epoch [40/750], Combined Loss: 0.0087
# Epoch [41/750], Combined Loss: 0.0070
# Epoch [42/750], Combined Loss: 0.0078
# Epoch [43/750], Combined Loss: 0.0091
# Epoch [44/750], Combined Loss: 0.0058
# Epoch [45/750], Combined Loss: 0.0053
# Epoch [46/750], Combined Loss: 0.0072
# Epoch [47/750], Combined Loss: 0.0058
# Epoch [48/750], Combined Loss: 0.0045
# Epoch [49/750], Combined Loss: 0.0062
# Epoch [50/750], Combined Loss: 0.0060
# Epoch [51/750], Combined Loss: 0.0071
# Epoch [52/750], Combined Loss: 0.0047
# Epoch [53/750], Combined Loss: 0.0216
# Epoch [54/750], Combined Loss: 0.0077
# Epoch [55/750], Combined Loss: 0.0079
# Epoch [56/750], Combined Loss: 0.0057
# Epoch [57/750], Combined Loss: 0.0063
# Epoch [58/750], Combined Loss: 0.0058
# Epoch [59/750], Combined Loss: 0.0070
# Epoch [60/750], Combined Loss: 0.0062
# Epoch [61/750], Combined Loss: 0.0051
# Epoch [62/750], Combined Loss: 0.0061
# Epoch [63/750], Combined Loss: 0.0072
# Epoch [64/750], Combined Loss: 0.0057
# Epoch [65/750], Combined Loss: 0.0062
# Epoch [66/750], Combined Loss: 0.0156
# Epoch [67/750], Combined Loss: 0.0050
# Epoch [68/750], Combined Loss: 0.0117
# Epoch [69/750], Combined Loss: 0.0058
# Epoch [70/750], Combined Loss: 0.0071
# Epoch [71/750], Combined Loss: 0.0060
# Epoch [72/750], Combined Loss: 0.0051
# Epoch [73/750], Combined Loss: 0.0063
# Epoch [74/750], Combined Loss: 0.0040
# Epoch [75/750], Combined Loss: 0.0052
# Epoch [76/750], Combined Loss: 0.0372
# Epoch [77/750], Combined Loss: 0.0055
# Epoch [78/750], Combined Loss: 0.0058
# Epoch [79/750], Combined Loss: 0.0058
# Epoch [80/750], Combined Loss: 0.0042
# Epoch [81/750], Combined Loss: 0.0082
# Epoch [82/750], Combined Loss: 0.0063
# Epoch [83/750], Combined Loss: 0.0052
# Epoch [84/750], Combined Loss: 0.0071
# Epoch [85/750], Combined Loss: 0.0066
# Epoch [86/750], Combined Loss: 0.0057
# Epoch [87/750], Combined Loss: 0.0065
# Epoch [88/750], Combined Loss: 0.0120
# Epoch [89/750], Combined Loss: 0.0089
# Epoch [90/750], Combined Loss: 0.0054
# Epoch [91/750], Combined Loss: 0.0240
# Epoch [92/750], Combined Loss: 0.0052
# Epoch [93/750], Combined Loss: 0.0054
# Epoch [94/750], Combined Loss: 0.0050
# Epoch [95/750], Combined Loss: 0.0078
# Epoch [96/750], Combined Loss: 0.0055
# Epoch [97/750], Combined Loss: 0.0061
# Epoch [98/750], Combined Loss: 0.0049
# Epoch [99/750], Combined Loss: 0.0068
# Epoch [100/750], Combined Loss: 0.0044
# Epoch [101/750], Combined Loss: 0.0080
# Epoch [102/750], Combined Loss: 0.0092
# Epoch [103/750], Combined Loss: 0.0044
# Epoch [104/750], Combined Loss: 0.0060
# Epoch [105/750], Combined Loss: 0.0053
# Epoch [106/750], Combined Loss: 0.0090
# Epoch [107/750], Combined Loss: 0.0060
# Epoch [108/750], Combined Loss: 0.0052
# Epoch [109/750], Combined Loss: 0.0050
# Epoch [110/750], Combined Loss: 0.0054
# Epoch [111/750], Combined Loss: 0.0067
# Epoch [112/750], Combined Loss: 0.0058
# Epoch [113/750], Combined Loss: 0.0045
# Epoch [114/750], Combined Loss: 0.0057
# Early stopping triggered.
# Trial 6 - MSE: 0.0060, MAE: 0.0626, REE: 0.0527, Euclidean Distance: 0.2410
# Starting trial 7...
# Epoch [1/750], Combined Loss: 0.0238
# Epoch [2/750], Combined Loss: 0.0068
# Epoch [3/750], Combined Loss: 0.0084
# Epoch [4/750], Combined Loss: 0.0126
# Epoch [5/750], Combined Loss: 0.0068
# Epoch [6/750], Combined Loss: 0.0068
# Epoch [7/750], Combined Loss: 0.0065
# Epoch [8/750], Combined Loss: 0.0060
# Epoch [9/750], Combined Loss: 0.0152
# Epoch [10/750], Combined Loss: 0.0074
# Epoch [11/750], Combined Loss: 0.0052
# Epoch [12/750], Combined Loss: 0.0077
# Epoch [13/750], Combined Loss: 0.0080
# Epoch [14/750], Combined Loss: 0.0061
# Epoch [15/750], Combined Loss: 0.0101
# Epoch [16/750], Combined Loss: 0.0082
# Epoch [17/750], Combined Loss: 0.0173
# Epoch [18/750], Combined Loss: 0.0062
# Epoch [19/750], Combined Loss: 0.0102
# Epoch [20/750], Combined Loss: 0.0061
# Epoch [21/750], Combined Loss: 0.0092
# Epoch [22/750], Combined Loss: 0.0101
# Epoch [23/750], Combined Loss: 0.0058
# Epoch [24/750], Combined Loss: 0.0086
# Epoch [25/750], Combined Loss: 0.0089
# Epoch [26/750], Combined Loss: 0.0072
# Epoch [27/750], Combined Loss: 0.0118
# Epoch [28/750], Combined Loss: 0.0113
# Epoch [29/750], Combined Loss: 0.0046
# Epoch [30/750], Combined Loss: 0.0048
# Epoch [31/750], Combined Loss: 0.0044
# Epoch [32/750], Combined Loss: 0.0045
# Epoch [33/750], Combined Loss: 0.0045
# Epoch [34/750], Combined Loss: 0.0045
# Epoch [35/750], Combined Loss: 0.0040
# Epoch [36/750], Combined Loss: 0.0038
# Epoch [37/750], Combined Loss: 0.0056
# Epoch [38/750], Combined Loss: 0.0047
# Epoch [39/750], Combined Loss: 0.0046
# Epoch [40/750], Combined Loss: 0.0039
# Epoch [41/750], Combined Loss: 0.0045
# Epoch [42/750], Combined Loss: 0.0055
# Epoch [43/750], Combined Loss: 0.0112
# Epoch [44/750], Combined Loss: 0.0069
# Epoch [45/750], Combined Loss: 0.0051
# Epoch [46/750], Combined Loss: 0.0037
# Epoch [47/750], Combined Loss: 0.0048
# Epoch [48/750], Combined Loss: 0.0039
# Epoch [49/750], Combined Loss: 0.0048
# Epoch [50/750], Combined Loss: 0.0038
# Epoch [51/750], Combined Loss: 0.0039
# Epoch [52/750], Combined Loss: 0.0033
# Epoch [53/750], Combined Loss: 0.0035
# Epoch [54/750], Combined Loss: 0.0036
# Epoch [55/750], Combined Loss: 0.0034
# Epoch [56/750], Combined Loss: 0.0054
# Epoch [57/750], Combined Loss: 0.0054
# Epoch [58/750], Combined Loss: 0.0030
# Epoch [59/750], Combined Loss: 0.0034
# Epoch [60/750], Combined Loss: 0.0031
# Epoch [61/750], Combined Loss: 0.0096
# Epoch [62/750], Combined Loss: 0.0055
# Epoch [63/750], Combined Loss: 0.0227
# Epoch [64/750], Combined Loss: 0.0136
# Epoch [65/750], Combined Loss: 0.0080
# Epoch [66/750], Combined Loss: 0.0049
# Epoch [67/750], Combined Loss: 0.0066
# Epoch [68/750], Combined Loss: 0.0057
# Epoch [69/750], Combined Loss: 0.0043
# Epoch [70/750], Combined Loss: 0.0039
# Epoch [71/750], Combined Loss: 0.0050
# Epoch [72/750], Combined Loss: 0.0034
# Epoch [73/750], Combined Loss: 0.0050
# Epoch [74/750], Combined Loss: 0.0043
# Epoch [75/750], Combined Loss: 0.0065
# Epoch [76/750], Combined Loss: 0.0049
# Epoch [77/750], Combined Loss: 0.0053
# Epoch [78/750], Combined Loss: 0.0049
# Epoch [79/750], Combined Loss: 0.0063
# Epoch [80/750], Combined Loss: 0.0113
# Epoch [81/750], Combined Loss: 0.0093
# Epoch [82/750], Combined Loss: 0.0094
# Epoch [83/750], Combined Loss: 0.0070
# Epoch [84/750], Combined Loss: 0.0059
# Epoch [85/750], Combined Loss: 0.0055
# Epoch [86/750], Combined Loss: 0.0054
# Epoch [87/750], Combined Loss: 0.0046
# Epoch [88/750], Combined Loss: 0.0067
# Epoch [89/750], Combined Loss: 0.0068
# Epoch [90/750], Combined Loss: 0.0074
# Epoch [91/750], Combined Loss: 0.0060
# Epoch [92/750], Combined Loss: 0.0049
# Epoch [93/750], Combined Loss: 0.0052
# Epoch [94/750], Combined Loss: 0.0040
# Epoch [95/750], Combined Loss: 0.0054
# Epoch [96/750], Combined Loss: 0.0068
# Epoch [97/750], Combined Loss: 0.0050
# Epoch [98/750], Combined Loss: 0.0063
# Early stopping triggered.
# Trial 7 - MSE: 0.0058, MAE: 0.0623, REE: 0.0527, Euclidean Distance: 0.2418
# Starting trial 8...
# Epoch [1/750], Combined Loss: 0.0104
# Epoch [2/750], Combined Loss: 0.0067
# Epoch [3/750], Combined Loss: 0.0086
# Epoch [4/750], Combined Loss: 0.0068
# Epoch [5/750], Combined Loss: 0.0073
# Epoch [6/750], Combined Loss: 0.0043
# Epoch [7/750], Combined Loss: 0.0042
# Epoch [8/750], Combined Loss: 0.0068
# Epoch [9/750], Combined Loss: 0.0056
# Epoch [10/750], Combined Loss: 0.0059
# Epoch [11/750], Combined Loss: 0.0096
# Epoch [12/750], Combined Loss: 0.0056
# Epoch [13/750], Combined Loss: 0.0123
# Epoch [14/750], Combined Loss: 0.0059
# Epoch [15/750], Combined Loss: 0.0039
# Epoch [16/750], Combined Loss: 0.0042
# Epoch [17/750], Combined Loss: 0.0108
# Epoch [18/750], Combined Loss: 0.0066
# Epoch [19/750], Combined Loss: 0.0073
# Epoch [20/750], Combined Loss: 0.0050
# Epoch [21/750], Combined Loss: 0.0054
# Epoch [22/750], Combined Loss: 0.0058
# Epoch [23/750], Combined Loss: 0.0067
# Epoch [24/750], Combined Loss: 0.0148
# Epoch [25/750], Combined Loss: 0.0044
# Epoch [26/750], Combined Loss: 0.0061
# Epoch [27/750], Combined Loss: 0.0044
# Epoch [28/750], Combined Loss: 0.0041
# Epoch [29/750], Combined Loss: 0.0043
# Epoch [30/750], Combined Loss: 0.0049
# Epoch [31/750], Combined Loss: 0.0199
# Epoch [32/750], Combined Loss: 0.0074
# Epoch [33/750], Combined Loss: 0.0046
# Epoch [34/750], Combined Loss: 0.0038
# Epoch [35/750], Combined Loss: 0.0042
# Epoch [36/750], Combined Loss: 0.0035
# Epoch [37/750], Combined Loss: 0.0033
# Epoch [38/750], Combined Loss: 0.0033
# Epoch [39/750], Combined Loss: 0.0032
# Epoch [40/750], Combined Loss: 0.0035
# Epoch [41/750], Combined Loss: 0.0033
# Epoch [42/750], Combined Loss: 0.0042
# Epoch [43/750], Combined Loss: 0.0050
# Epoch [44/750], Combined Loss: 0.0073
# Epoch [45/750], Combined Loss: 0.0085
# Epoch [46/750], Combined Loss: 0.0050
# Epoch [47/750], Combined Loss: 0.0040
# Epoch [48/750], Combined Loss: 0.0082
# Epoch [49/750], Combined Loss: 0.0037
# Epoch [50/750], Combined Loss: 0.0038
# Epoch [51/750], Combined Loss: 0.0060
# Epoch [52/750], Combined Loss: 0.0044
# Epoch [53/750], Combined Loss: 0.0060
# Epoch [54/750], Combined Loss: 0.0045
# Epoch [55/750], Combined Loss: 0.0044
# Epoch [56/750], Combined Loss: 0.0086
# Epoch [57/750], Combined Loss: 0.0174
# Epoch [58/750], Combined Loss: 0.0109
# Epoch [59/750], Combined Loss: 0.0108
# Epoch [60/750], Combined Loss: 0.0073
# Epoch [61/750], Combined Loss: 0.0080
# Epoch [62/750], Combined Loss: 0.0104
# Epoch [63/750], Combined Loss: 0.0158
# Epoch [64/750], Combined Loss: 0.0081
# Epoch [65/750], Combined Loss: 0.0062
# Epoch [66/750], Combined Loss: 0.0092
# Epoch [67/750], Combined Loss: 0.0074
# Epoch [68/750], Combined Loss: 0.0063
# Epoch [69/750], Combined Loss: 0.0057
# Epoch [70/750], Combined Loss: 0.0071
# Epoch [71/750], Combined Loss: 0.0074
# Epoch [72/750], Combined Loss: 0.0062
# Epoch [73/750], Combined Loss: 0.0079
# Epoch [74/750], Combined Loss: 0.0080
# Epoch [75/750], Combined Loss: 0.0074
# Epoch [76/750], Combined Loss: 0.0072
# Epoch [77/750], Combined Loss: 0.0248
# Epoch [78/750], Combined Loss: 0.0232
# Epoch [79/750], Combined Loss: 0.0096
# Early stopping triggered.
# Trial 8 - MSE: 0.0067, MAE: 0.0571, REE: 0.0545, Euclidean Distance: 0.2540
# Starting trial 9...
# Epoch [1/750], Combined Loss: 0.0085
# Epoch [2/750], Combined Loss: 0.0078
# Epoch [3/750], Combined Loss: 0.0084
# Epoch [4/750], Combined Loss: 0.0080
# Epoch [5/750], Combined Loss: 0.0088
# Epoch [6/750], Combined Loss: 0.0130
# Epoch [7/750], Combined Loss: 0.0071
# Epoch [8/750], Combined Loss: 0.0072
# Epoch [9/750], Combined Loss: 0.0049
# Epoch [10/750], Combined Loss: 0.0056
# Epoch [11/750], Combined Loss: 0.0046
# Epoch [12/750], Combined Loss: 0.0087
# Epoch [13/750], Combined Loss: 0.0148
# Epoch [14/750], Combined Loss: 0.0167
# Epoch [15/750], Combined Loss: 0.0159
# Epoch [16/750], Combined Loss: 0.0142
# Epoch [17/750], Combined Loss: 0.0196
# Epoch [18/750], Combined Loss: 0.0148
# Epoch [19/750], Combined Loss: 0.0162
# Epoch [20/750], Combined Loss: 0.0194
# Epoch [21/750], Combined Loss: 0.0098
# Epoch [22/750], Combined Loss: 0.0095
# Epoch [23/750], Combined Loss: 0.0126
# Epoch [24/750], Combined Loss: 0.0136
# Epoch [25/750], Combined Loss: 0.0132
# Epoch [26/750], Combined Loss: 0.0113
# Epoch [27/750], Combined Loss: 0.0132
# Epoch [28/750], Combined Loss: 0.0155
# Epoch [29/750], Combined Loss: 0.0137
# Epoch [30/750], Combined Loss: 0.0160
# Epoch [31/750], Combined Loss: 0.0134
# Epoch [32/750], Combined Loss: 0.0150
# Epoch [33/750], Combined Loss: 0.0115
# Epoch [34/750], Combined Loss: 0.0146
# Epoch [35/750], Combined Loss: 0.0121
# Epoch [36/750], Combined Loss: 0.0166
# Epoch [37/750], Combined Loss: 0.0351
# Epoch [38/750], Combined Loss: 0.0087
# Epoch [39/750], Combined Loss: 0.0130
# Epoch [40/750], Combined Loss: 0.0088
# Epoch [41/750], Combined Loss: 0.0143
# Epoch [42/750], Combined Loss: 0.0084
# Epoch [43/750], Combined Loss: 0.0097
# Epoch [44/750], Combined Loss: 0.0073
# Epoch [45/750], Combined Loss: 0.0106
# Epoch [46/750], Combined Loss: 0.0087
# Epoch [47/750], Combined Loss: 0.0087
# Epoch [48/750], Combined Loss: 0.0117
# Epoch [49/750], Combined Loss: 0.0107
# Epoch [50/750], Combined Loss: 0.0187
# Epoch [51/750], Combined Loss: 0.0140
# Early stopping triggered.
# Trial 9 - MSE: 0.0255, MAE: 0.1391, REE: 0.1091, Euclidean Distance: 0.5125
# Starting trial 10...
# Epoch [1/750], Combined Loss: 0.0074
# Epoch [2/750], Combined Loss: 0.0068
# Epoch [3/750], Combined Loss: 0.0067
# Epoch [4/750], Combined Loss: 0.0058
# Epoch [5/750], Combined Loss: 0.0088
# Epoch [6/750], Combined Loss: 0.0107
# Epoch [7/750], Combined Loss: 0.0057
# Epoch [8/750], Combined Loss: 0.0048
# Epoch [9/750], Combined Loss: 0.0083
# Epoch [10/750], Combined Loss: 0.0140
# Epoch [11/750], Combined Loss: 0.0110
# Epoch [12/750], Combined Loss: 0.0075
# Epoch [13/750], Combined Loss: 0.0072
# Epoch [14/750], Combined Loss: 0.0085
# Epoch [15/750], Combined Loss: 0.0117
# Epoch [16/750], Combined Loss: 0.0089
# Epoch [17/750], Combined Loss: 0.0395
# Epoch [18/750], Combined Loss: 0.0086
# Epoch [19/750], Combined Loss: 0.0048
# Epoch [20/750], Combined Loss: 0.0056
# Epoch [21/750], Combined Loss: 0.0081
# Epoch [22/750], Combined Loss: 0.0086
# Epoch [23/750], Combined Loss: 0.0056
# Epoch [24/750], Combined Loss: 0.0066
# Epoch [25/750], Combined Loss: 0.0062
# Epoch [26/750], Combined Loss: 0.0043
# Epoch [27/750], Combined Loss: 0.0074
# Epoch [28/750], Combined Loss: 0.0072
# Epoch [29/750], Combined Loss: 0.0084
# Epoch [30/750], Combined Loss: 0.0068
# Epoch [31/750], Combined Loss: 0.0084
# Epoch [32/750], Combined Loss: 0.0108
# Epoch [33/750], Combined Loss: 0.0103
# Epoch [34/750], Combined Loss: 0.0100
# Epoch [35/750], Combined Loss: 0.0055
# Epoch [36/750], Combined Loss: 0.0050
# Epoch [37/750], Combined Loss: 0.0048
# Epoch [38/750], Combined Loss: 0.0046
# Epoch [39/750], Combined Loss: 0.0037
# Epoch [40/750], Combined Loss: 0.0103
# Epoch [41/750], Combined Loss: 0.0034
# Epoch [42/750], Combined Loss: 0.0107
# Epoch [43/750], Combined Loss: 0.0061
# Epoch [44/750], Combined Loss: 0.0038
# Epoch [45/750], Combined Loss: 0.0034
# Epoch [46/750], Combined Loss: 0.0034
# Epoch [47/750], Combined Loss: 0.0044
# Epoch [48/750], Combined Loss: 0.0032
# Epoch [49/750], Combined Loss: 0.0050
# Epoch [50/750], Combined Loss: 0.0121
# Epoch [51/750], Combined Loss: 0.0041
# Epoch [52/750], Combined Loss: 0.0030
# Epoch [53/750], Combined Loss: 0.0055
# Epoch [54/750], Combined Loss: 0.0052
# Epoch [55/750], Combined Loss: 0.0057
# Epoch [56/750], Combined Loss: 0.0042
# Epoch [57/750], Combined Loss: 0.0042
# Epoch [58/750], Combined Loss: 0.0040
# Epoch [59/750], Combined Loss: 0.0048
# Epoch [60/750], Combined Loss: 0.0049
# Epoch [61/750], Combined Loss: 0.0083
# Epoch [62/750], Combined Loss: 0.0157
# Epoch [63/750], Combined Loss: 0.0060
# Epoch [64/750], Combined Loss: 0.0052
# Epoch [65/750], Combined Loss: 0.0043
# Epoch [66/750], Combined Loss: 0.0056
# Epoch [67/750], Combined Loss: 0.0055
# Epoch [68/750], Combined Loss: 0.0058
# Epoch [69/750], Combined Loss: 0.0044
# Epoch [70/750], Combined Loss: 0.0051
# Epoch [71/750], Combined Loss: 0.0054
# Epoch [72/750], Combined Loss: 0.0051
# Epoch [73/750], Combined Loss: 0.0065
# Epoch [74/750], Combined Loss: 0.0204
# Epoch [75/750], Combined Loss: 0.0042
# Epoch [76/750], Combined Loss: 0.0036
# Epoch [77/750], Combined Loss: 0.0039
# Epoch [78/750], Combined Loss: 0.0066
# Epoch [79/750], Combined Loss: 0.0432
# Epoch [80/750], Combined Loss: 0.0261
# Epoch [81/750], Combined Loss: 0.0096
# Epoch [82/750], Combined Loss: 0.0061
# Epoch [83/750], Combined Loss: 0.0055
# Epoch [84/750], Combined Loss: 0.0052
# Epoch [85/750], Combined Loss: 0.0054
# Epoch [86/750], Combined Loss: 0.0043
# Epoch [87/750], Combined Loss: 0.0053
# Epoch [88/750], Combined Loss: 0.0031
# Epoch [89/750], Combined Loss: 0.0043
# Epoch [90/750], Combined Loss: 0.0033
# Epoch [91/750], Combined Loss: 0.0058
# Epoch [92/750], Combined Loss: 0.0034
# Early stopping triggered.
# Trial 10 - MSE: 0.0054, MAE: 0.0556, REE: 0.0474, Euclidean Distance: 0.2190

# %%
num_trials = 10

# Create a 2x5 grid of subplots
fig, axes = plt.subplots(2, 5, figsize=(25, 10))
axes = axes.flatten()  # Flatten the 2D array of axes to 1D for easy indexing

# Plot Reconstruction Error Percentage
for trial in range(num_trials):
    ax = axes[trial]
    ax.scatter(range(len(error_percentages[trial])), error_percentages[trial], color='blue')
    ax.set_ylim(0, 200)
    ax.set_title(f'Reconstruction Error Percentage - Trial {trial+1}')
    ax.set_xlabel('Data Point')
    ax.set_ylabel('Error Percentage')

# Adjust layout
plt.tight_layout()
plt.show()

# %%
num_trials = 10

# Create a 2x5 grid of subplots
fig, axes = plt.subplots(2, 5, figsize=(25, 10))
axes = axes.flatten()  # Flatten the 2D array of axes to 1D for easy indexing

# Plot t-SNE Visualization
for trial in range(num_trials):
    ax = axes[trial]
    ax.scatter(t_sne_results[trial][:len(X_test), 0], t_sne_results[trial][:len(X_test), 1], label="Original", alpha=0.5)
    ax.scatter(t_sne_results[trial][len(X_test):, 0], t_sne_results[trial][len(X_test):, 1], label="Reconstructed", alpha=0.5)
    ax.legend()
    ax.set_title(f't-SNE Visualization - Trial {trial+1}')

# Adjust layout
plt.tight_layout()
plt.show()

# %%
num_trials = 10

# Create a 2x5 grid of subplots
fig, axes = plt.subplots(2, 5, figsize=(25, 10))
axes = axes.flatten()  # Flatten the 2D array of axes to 1D for easy indexing

# Plot PCA Projection
for trial in range(num_trials):
    ax = axes[trial]
    ax.scatter(pca_results[trial][:len(X_test), 0], pca_results[trial][:len(X_test), 1], label="Original", alpha=0.5)
    ax.scatter(pca_results[trial][len(X_test):, 0], pca_results[trial][len(X_test):, 1], label="Reconstructed", alpha=0.5)
    ax.legend()
    ax.set_title(f'PCA Projection - Trial {trial+1}')

# Adjust layout
plt.tight_layout()
plt.show()

# %%
count = 1

for result in metrics:
    print(f"Trial {count}")
    count += 1
    print("MSE:", result[0])
    print("MAE:", result[1])
    print("REE:", result[2])
    print("Euclidean Distance:", result[3])
    print()
# Out:
# Trial 1
# MSE: 0.003890691224433621
# MAE: 0.04738823101211396
# REE: 0.04211963336767748
# Euclidean Distance: 0.194131458737547
#
# Trial 2
# MSE: 0.0074726769903032415
# MAE: 0.06498999093986055
# REE: 0.058681710696469574
# Euclidean Distance: 0.2673123977435105
#
# Trial 3
# MSE: 0.01068179869101169
# MAE: 0.07318742450293182
# REE: 0.06975063384962674
# Euclidean Distance: 0.322461312170133
#
# Trial 4
# MSE: 0.010565194076679047
# MAE: 0.0903755695867161
# REE: 0.06883326138926384
# Euclidean Distance: 0.3256099156863606
#
# Trial 5
# MSE: 0.004877891979547252
# MAE: 0.045973789875730094
# REE: 0.04789346871979808
# Euclidean Distance: 0.2194927599508495
#
# Trial 6
# MSE: 0.006000348565463402
# MAE: 0.06263798004700777
# REE: 0.05274337664986138
# Euclidean Distance: 0.24103551017383032
#
# Trial 7
# MSE: 0.005805260547416744
# MAE: 0.06230511371144737
# REE: 0.052719782236946934
# Euclidean Distance: 0.24175965092384463
#
# Trial 8
# MSE: 0.006739049595547581
# MAE: 0.057064263487027526
# REE: 0.054528812797858865
# Euclidean Distance: 0.2539552240130481
#
# Trial 9
# MSE: 0.025500084277106604
# MAE: 0.13905140379349723
# REE: 0.10913882200916263
# Euclidean Distance: 0.5124993452180734
#
# Trial 10
# MSE: 0.0053655184133736674
# MAE: 0.05562553078860615
# REE: 0.04736530723506518
# Euclidean Distance: 0.21899038460423315

# %%
# Calculate statistics for MSE, MAE, REE, and Euclidean error
metrics = np.array(metrics)
mse_mean = np.mean(metrics[:, 0])
mse_std = np.std(metrics[:, 0])
mae_mean = np.mean(metrics[:, 1])
mae_std = np.std(metrics[:, 1])
ree_mean = np.mean(metrics[:, 2])
ree_std = np.std(metrics[:, 2])
euclidean_mean = np.mean(metrics[:, 3])
euclidean_std = np.std(metrics[:, 3])
error_percentages_mean = np.mean([np.mean(error_percentage) for error_percentage in error_percentages])
error_percentages_std = np.std([np.mean(error_percentage) for error_percentage in error_percentages])


# Print statistics for MSE, MAE, REE, and Euclidean error
print("\n===== Additional Metrics Across 10 Trials =====")
print(f"Error Percentage Mean: {error_percentages_mean:.4f}% ± {error_percentages_std:.4f}%")
print(f"MSE Mean: {mse_mean:.4f} ± {mse_std:.4f}")
print(f"MAE Mean: {mae_mean:.4f} ± {mae_std:.4f}")
print(f"REE Mean: {ree_mean:.4f} ± {ree_std:.4f}")
print(f"Euclidean Mean: {euclidean_mean:.4f} ± {euclidean_std:.4f}")
# Out:
# ===== Additional Metrics Across 10 Trials =====
# Error Percentage Mean: 62.6931% ± 54.2197%
# MSE Mean: 0.0087 ± 0.0060
# MAE Mean: 0.0699 ± 0.0261
# REE Mean: 0.0604 ± 0.0183
# Euclidean Mean: 0.2797 ± 0.0875
