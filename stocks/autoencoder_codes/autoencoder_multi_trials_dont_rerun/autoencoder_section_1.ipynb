# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from sklearn.base import BaseEstimator, RegressorMixin

# %%
# Load the data
file_path = "SPY_section_1.csv"
df = pd.read_csv(file_path)

# start to nov 2001 (dot com crash)
# not bad
# df = df.iloc[:2228]

# nov 01 to june 2009
# not bad
# df = df.iloc[2228:4135]

# june 2009 to april 2020
# ass
# df = df.iloc[4135:6862]

# april 2020 to most recent
# ass
# df = df.iloc[6862:]


# Convert the "Date" column to datetime
# df["Date"] = pd.to_datetime(df["Date"], format='%Y/%m/%d')

# # Sort the data by date in ascending order
# df = df.sort_values(by="Date")

# # Get the earliest and latest dates
# earliest_date = df["Date"].min()
# latest_date = df["Date"].max()

# print("Earliest Date:", earliest_date)
# print("Latest Date:", latest_date)

# %%
# Adding SMA as part of the feature test
short_term_period = 20
medium_term_period = 50
long_term_period = 200

# Compute the SMAs
df['SMA_20'] = df['Close'].rolling(window=short_term_period).mean()
df['SMA_50'] = df['Close'].rolling(window=medium_term_period).mean()
df['SMA_200'] = df['Close'].rolling(window=long_term_period).mean()

df['EMA_10'] = df['Close'].ewm(span=10, adjust=False).mean()  # Short-term EMA
df['EMA_50'] = df['Close'].ewm(span=50, adjust=False).mean()  # Medium-term EMA
df['EMA_200'] = df['Close'].ewm(span=200, adjust=False).mean()  # Long-term EMA

df = df.dropna()

# %%
feature_columns = ["Open", "High", "Low", "Close", "Volume"]  
dates = df["Date"]
# if "Open" and "High" and "Low" and "Close" and "Volume" in df.columns:
#     df = df[feature_columns]

# %%
# scaler = StandardScaler()
# scaler = MinMaxScaler()
# feature_columns = ["Open", "High", "Low", "Close", "Volume", "Day", "Weekday", "Week", "Month", "Year"]
# feature_columns = ["Open", "High", "Low", "Close", "Volume", "SMA_20", "SMA_50", "SMA_200", "EMA_10", "EMA_50", "EMA_200", "Non_Linear_Trend"]
feature_columns = ["Open", "High", "Low", "Close", "Volume", "SMA_20", "SMA_50", "SMA_200", "EMA_10", "EMA_50", "EMA_200"]
# feature_columns = ["Open", "High", "Low", "Close", "Volume", "Non_Linear_Trend", "SMA_20", "SMA_50", "EMA_10", "EMA_50"]
# feature_columns = ["Open", "High", "Low", "Close", "Volume", "Non_Linear_Trend"]
# feature_columns = ["Open", "High", "Low", "Close", "Volume", "SMA_200", "EMA_10"]
X = df[feature_columns]

# Split data
train_size = int(X.shape[0] * 0.7)
val_size = int(X.shape[0] * 0.15)

# Initialize scaler
scaler = MinMaxScaler()
# scaler = RobustScaler()

# Split data into train, validation, and test
temp_train = X[:train_size]
temp_val = X[train_size:train_size + val_size]
temp_test = X[train_size + val_size:]

temp_train = temp_train[feature_columns]
temp_val = temp_val[feature_columns]
temp_test = temp_test[feature_columns]

# Fit and transform for train, transform for validation and test
temp_train = scaler.fit_transform(temp_train)
temp_val = scaler.transform(temp_val)
temp_test = scaler.transform(temp_test)

# Convert NumPy arrays back to DataFrames
temp_train = pd.DataFrame(temp_train, columns=feature_columns)
temp_val = pd.DataFrame(temp_val, columns=feature_columns)
temp_test = pd.DataFrame(temp_test, columns=feature_columns)

# Concatenate the data
X_scaled = pd.concat([temp_train, temp_val, temp_test], axis=0)

# Split sequentially
X_train = X_scaled[:train_size]
X_val = X_scaled[train_size:train_size + val_size]
X_test = X_scaled[train_size + val_size:]

# Print sizes to confirm
print(f"Train: {len(X_train)}, Val: {len(X_val)}, Test: {len(X_test)}")
# Out:
# Train: 1421, Val: 304, Test: 305

# %%
X_train = X_train.values
X_val = X_val.values
X_test = X_test.values

# %%
# Convert data to PyTorch tensors
X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
X_val_tensor = torch.tensor(X_val, dtype=torch.float32)
X_test_tensor = torch.tensor(X_test, dtype=torch.float32)

# Create DataLoader
train_dataset = TensorDataset(X_train_tensor, X_train_tensor)
val_dataset = TensorDataset(X_val_tensor, X_val_tensor)
test_dataset = TensorDataset(X_test_tensor, X_test_tensor)
train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=16, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=16, shuffle=False)

# %%
# # Check if CUDA is available and print the device being used
# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# print(f"Using device: {device}")

# class Encoder(nn.Module):
#     def __init__(self, input_dim, encoding_dim):
#         super(Encoder, self).__init__()
#         self.encoder = nn.Sequential(
#             nn.Linear(input_dim, 128),
#             nn.ReLU(),
#             nn.Dropout(0.2),
#             nn.Linear(128, 64),
#             nn.ReLU(),
#             nn.Dropout(0.2),
#             nn.Linear(64, encoding_dim)
#         )

#     def forward(self, x):
#         return self.encoder(x)

# class Decoder(nn.Module):
#     def __init__(self, encoding_dim, input_dim):
#         super(Decoder, self).__init__()
#         self.decoder = nn.Sequential(
#             nn.Linear(encoding_dim, 64),
#             nn.ReLU(),
#             nn.Dropout(0.2),
#             nn.Linear(64, 128),
#             nn.ReLU(),
#             nn.Dropout(0.2),
#             nn.Linear(128, input_dim)
#         )

#     def forward(self, x):
#         return self.decoder(x)

    
# # Define input dimensions
# input_dim = X_train.shape[1]

# # Model file paths
# encoder_model_file = './autoencoder_trials/encoder.pth'
# decoder_model_file = './autoencoder_trials/decoder.pth'

# # Hyperparameters
# encoding_dim = 8
# learning_rate = 0.001
# epochs = 50
# batch_size = 8
# patience = 5

# # Check if the model files exist
# if os.path.exists(encoder_model_file) and os.path.exists(decoder_model_file):
#     print("Model files exist. Loading the models...")
#     encoder = Encoder(input_dim, encoding_dim).to(device)
#     decoder = Decoder(encoding_dim, input_dim).to(device)
#     encoder.load_state_dict(torch.load(encoder_model_file))
#     decoder.load_state_dict(torch.load(decoder_model_file))
# else:
#     print("Model files do not exist. Training new models...")

#     # Initialize the encoder and decoder models
#     encoder = Encoder(input_dim, encoding_dim).to(device)
#     decoder = Decoder(encoding_dim, input_dim).to(device)
#     optimizer_encoder = optim.Adam(encoder.parameters(), lr=learning_rate)
#     optimizer_decoder = optim.Adam(decoder.parameters(), lr=learning_rate)
#     criterion = nn.MSELoss()

#     # Track training loss
#     encoder_losses = []
#     decoder_losses = []

#     # Train the Encoder separately
#     encoder.train()
#     best_val_loss = float('inf')
#     patience_counter = 0
#     for epoch in range(epochs):
#         epoch_loss = 0
#         dataloader = DataLoader(TensorDataset(torch.tensor(X_train, dtype=torch.float32).to(device), torch.tensor(X_train, dtype=torch.float32).to(device)), batch_size=batch_size, shuffle=True, num_workers=0)
#         for i, (batch_X, _) in enumerate(dataloader):
#             batch_X = batch_X.to(device)
#             optimizer_encoder.zero_grad()
#             encoded = encoder(batch_X)
#             # Pass the encoded output through the decoder
#             decoded = decoder(encoded)
#             # Calculate loss between decoder output and original input
#             loss = criterion(decoded, batch_X)
#             loss.backward()
            
#             optimizer_encoder.step()
#             optimizer_encoder.zero_grad()
            
#             epoch_loss += loss.item()
#         avg_loss = epoch_loss / len(dataloader)
#         encoder_losses.append(avg_loss)
#         print(f"Epoch [{epoch+1}/{epochs}], Encoder Loss: {avg_loss:.4f}")

#         # Validation loss
#         encoder.eval()
#         decoder.eval()
#         with torch.no_grad():
#             val_encoded = encoder(torch.tensor(X_val, dtype=torch.float32).to(device))
#             val_decoded = decoder(val_encoded)
#             val_loss = criterion(val_decoded, torch.tensor(X_val, dtype=torch.float32).to(device)).item()
#         print(f"Validation Loss: {val_loss:.4f}")

#         # Early stopping
#         if val_loss < best_val_loss:
#             best_val_loss = val_loss
#             patience_counter = 0
#         else:
#             patience_counter += 1
#             if patience_counter >= patience:
#                 print("Early stopping triggered.")
#                 break

#     # Train the Decoder separately
#     encoded_train = encoder(torch.tensor(X_train, dtype=torch.float32).to(device)).detach()
#     decoder.train()
#     best_val_loss = float('inf')
#     patience_counter = 0
#     for epoch in range(epochs):
#         epoch_loss = 0
#         dataloader = DataLoader(TensorDataset(encoded_train, torch.tensor(X_train, dtype=torch.float32).to(device)), batch_size=batch_size, shuffle=True, num_workers=0)
#         for i, (batch_X, batch_y) in enumerate(dataloader):
#             batch_X, batch_y = batch_X.to(device), batch_y.to(device)
#             optimizer_decoder.zero_grad()
#             outputs = decoder(batch_X)
#             # Calculate loss between decoder output and original input
#             loss = criterion(outputs, batch_y)
#             loss.backward()
            
#             optimizer_decoder.step()
#             optimizer_decoder.zero_grad()
            
#             epoch_loss += loss.item()
#         avg_loss = epoch_loss / len(dataloader)
#         decoder_losses.append(avg_loss)
#         print(f"Epoch [{epoch+1}/{epochs}], Decoder Loss: {avg_loss:.4f}")

#         # Validation loss
#         decoder.eval()
#         with torch.no_grad():
#             val_outputs = decoder(encoded_train)
#             val_loss = criterion(val_outputs, torch.tensor(X_train, dtype=torch.float32).to(device)).item()
#         print(f"Validation Loss: {val_loss:.4f}")

#         # Early stopping
#         if val_loss < best_val_loss:
#             best_val_loss = val_loss
#             patience_counter = 0
#         else:
#             patience_counter += 1
#             print("Early stopping counter:", patience_counter)
#             if patience_counter >= patience:
#                 print("Early stopping triggered.")
#                 break

#     # Save the trained models
#     os.makedirs('./autoencoder_trials', exist_ok=True)
#     # torch.save(encoder.state_dict(), encoder_model_file)
#     # torch.save(decoder.state_dict(), decoder_model_file)
#     print("Models trained and saved.")

# # Combine Encoder and Decoder to form the Autoencoder
# class Autoencoder(nn.Module):
#     def __init__(self, encoder, decoder):
#         super(Autoencoder, self).__init__()
#         self.encoder = encoder
#         self.decoder = decoder

#     def forward(self, x):
#         encoded = self.encoder(x)
#         decoded = self.decoder(encoded)
#         return decoded

# autoencoder = Autoencoder(encoder, decoder).to(device)
# autoencoder.eval()

# # Calculate reconstruction error on the test set
# with torch.no_grad():
#     reconstructed_test = autoencoder(torch.tensor(X_test, dtype=torch.float32).to(device)).cpu().numpy()

# # Calculate Mean Squared Error (MSE)
# mse = np.mean((X_test - reconstructed_test) ** 2)
# print(f'Mean Squared Error (MSE): {mse}')

# # Calculate Mean Absolute Error (MAE)
# mae = np.mean(np.abs(X_test - reconstructed_test))
# print(f'Mean Absolute Error (MAE): {mae}')

# # Calculate Reconstruction Error Percentage
# # reconstruction_error = np.mean(np.square(X_test - reconstructed_test), axis=1)
# # reconstruction_error_percentage = np.mean(reconstruction_error) * 100
# # print(f'Reconstruction Error Percentage: {reconstruction_error_percentage}')

# reconstruction_error_percentage = (
#     np.mean(np.abs(X_test - reconstructed_test) / (np.abs(X_test) + 1e-8), axis=1) * 100
# )
# reconstruction_error_percentage_mean = np.mean(reconstruction_error_percentage)
# print(f'Reconstruction Error Percentage: {reconstruction_error_percentage_mean}')

# def calculate_index_error_percentage(index, X, reconstructed_X):
#     print(np.mean(np.abs(X[index] - reconstructed_X[index]) / (np.abs(X[index]) + 1e-8)) * 100)

# %%
# # import os
# # import torch
# # import torch.nn as nn
# # import torch.optim as optim
# # import numpy as np
# # from torch.utils.data import DataLoader, TensorDataset

# # # Check if CUDA is available
# # device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# # print(f"Using device: {device}")

# # # Define Encoder
# # class Encoder(nn.Module):
# #     def __init__(self, input_dim, encoding_dim, dropout_rate):
# #         super(Encoder, self).__init__()
# #         self.encoder = nn.Sequential(
# #             nn.Linear(input_dim, 128),
# #             nn.ReLU(),
# #             nn.Dropout(dropout_rate),
# #             nn.Linear(128, 64),
# #             nn.ReLU(),
# #             nn.Dropout(dropout_rate),
# #             nn.Linear(64, encoding_dim)
# #         )

# #     def forward(self, x):
# #         return self.encoder(x)

# # # Define Decoder
# # class Decoder(nn.Module):
# #     def __init__(self, encoding_dim, input_dim, dropout_rate):
# #         super(Decoder, self).__init__()
# #         self.decoder = nn.Sequential(
# #             nn.Linear(encoding_dim, 64),
# #             nn.ReLU(),
# #             nn.Dropout(dropout_rate),
# #             nn.Linear(64, 128),
# #             nn.ReLU(),
# #             nn.Dropout(dropout_rate),
# #             nn.Linear(128, input_dim)
# #         )

# #     def forward(self, x):
# #         return self.decoder(x)

# # def relative_euclidean_error(X, X_reconstructed):
# #     return np.linalg.norm(X - X_reconstructed, axis=1) / np.linalg.norm(X, axis=1)

# # class RelativeEuclideanError(nn.Module):
# #     def forward(self, y_true, y_pred):
# #         return torch.mean(torch.norm(y_true - y_pred, dim=1) / torch.norm(y_true, dim=1))

# # # Define input dimensions
# # input_dim = X_train.shape[1]

# # # Model file paths
# # encoder_model_file = './autoencoder_trials/encoder.pth'
# # decoder_model_file = './autoencoder_trials/decoder.pth'

# # # Hyperparameters
# # encoding_dim = 5
# # learning_rate = 0.0001
# # dropout_rate = 0.0
# # epochs = 750
# # batch_size = 16
# # patience = 30

# # # Initialize models
# # encoder = Encoder(input_dim, encoding_dim, dropout_rate).to(device)
# # decoder = Decoder(encoding_dim, input_dim, dropout_rate).to(device)

# # # Define optimizers and loss function
# # optimizer_encoder = optim.Adam(encoder.parameters(), lr=learning_rate)
# # optimizer_decoder = optim.Adam(decoder.parameters(), lr=learning_rate)
# # # criterion = nn.MSELoss()
# # criterion = RelativeEuclideanError()
# # #use MAE
# # # criterion = nn.L1Loss()

# # # Add Gaussian noise to encoded representations to avoid overfitting
# # def add_noise(encoded, noise_factor=0.01):
# #     return encoded + noise_factor * torch.randn_like(encoded)

# # # Train Encoder
# # def train_encoder():
# #     print("Training Encoder...")
# #     encoder.train()
# #     best_val_loss = float('inf')
# #     patience_counter = 0
# #     # clip_value = 1

# #     for epoch in range(epochs):
# #         epoch_loss = 0
# #         dataloader = DataLoader(TensorDataset(torch.tensor(X_train, dtype=torch.float32).to(device), 
# #                                               torch.tensor(X_train, dtype=torch.float32).to(device)), 
# #                                 batch_size=batch_size, shuffle=True, num_workers=0)

# #         for batch_X, _ in dataloader:
# #             batch_X = batch_X.to(device)
# #             optimizer_encoder.zero_grad()
# #             encoded = encoder(batch_X)
# #             decoded = decoder(encoded)
# #             loss = criterion(decoded, batch_X)
# #             loss.backward()
            
# #             # torch.nn.utils.clip_grad_norm_(encoder.parameters(), max_norm=clip_value)  # Option 1
# #             # torch.nn.utils.clip_grad_value_(encoder.parameters(), clip_value=clip_value)  # Option 2

# #             optimizer_encoder.step()
# #             epoch_loss += loss.item()

# #         avg_loss = epoch_loss / len(dataloader)
# #         print(f"Epoch [{epoch+1}/{epochs}], Encoder Loss: {avg_loss:.4f}")

# #         # Validation loss
# #         encoder.eval()
# #         decoder.eval()
# #         with torch.no_grad():
# #             val_encoded = encoder(torch.tensor(X_val, dtype=torch.float32).to(device))
# #             val_decoded = decoder(val_encoded)
# #             val_loss = criterion(val_decoded, torch.tensor(X_val, dtype=torch.float32).to(device)).item()
# #         print(f"Validation Loss: {val_loss:.4f}")

# #         # Early stopping
# #         if val_loss < best_val_loss:
# #             best_val_loss = val_loss
# #             patience_counter = 0
# #             torch.save(encoder.state_dict(), encoder_model_file)  # Save best model
# #         else:
# #             patience_counter += 1
# #             print("Early stopping counter:", patience_counter)
# #             if patience_counter >= patience:
# #                 print("Early stopping triggered for encoder.")
# #                 break

# # # Train Decoder
# # def train_decoder():
# #     print("Training Decoder...")
# #     encoder.eval()
# #     encoded_train = encoder(torch.tensor(X_train, dtype=torch.float32).to(device)).detach()

# #     decoder.train()
# #     best_val_loss = float('inf')
# #     patience_counter = 0
# #     # clip_value = 1

# #     for epoch in range(epochs):
# #         epoch_loss = 0
# #         dataloader = DataLoader(TensorDataset(encoded_train, torch.tensor(X_train, dtype=torch.float32).to(device)), 
# #                                 batch_size=batch_size, shuffle=True, num_workers=0)

# #         for batch_X, batch_y in dataloader:
# #             batch_X, batch_y = batch_X.to(device), batch_y.to(device)
            
# #             # Add Gaussian noise
# #             noisy_batch_X = add_noise(batch_X)

# #             optimizer_decoder.zero_grad()
# #             outputs = decoder(noisy_batch_X)
# #             loss = criterion(outputs, batch_y)
# #             loss.backward()
            
# #             # torch.nn.utils.clip_grad_norm_(decoder.parameters(), max_norm=clip_value)  # Option 1
# #             # torch.nn.utils.clip_grad_value_(decoder.parameters(), clip_value=clip_value)  # Option 2
            
# #             optimizer_decoder.step()
            
# #             epoch_loss += loss.item()

# #         avg_loss = epoch_loss / len(dataloader)
# #         print(f"Epoch [{epoch+1}/{epochs}], Decoder Loss: {avg_loss:.4f}")

# #         # Validation loss
# #         decoder.eval()
# #         with torch.no_grad():
# #             val_encoded = encoder(torch.tensor(X_val, dtype=torch.float32).to(device))
# #             val_decoded = decoder(val_encoded)
# #             val_loss = criterion(val_decoded, torch.tensor(X_val, dtype=torch.float32).to(device)).item()
# #         print(f"Validation Loss: {val_loss:.4f}")

# #         # Early stopping
# #         if val_loss < best_val_loss:
# #             best_val_loss = val_loss
# #             patience_counter = 0
# #             torch.save(decoder.state_dict(), decoder_model_file)  # Save best model
# #         else:
# #             patience_counter += 1
# #             print("Early stopping counter:", patience_counter)
# #             if patience_counter >= patience:
# #                 print("Early stopping triggered for decoder.")
# #                 break

# # # Train models if files do not exist
# # if os.path.exists(encoder_model_file) and os.path.exists(decoder_model_file):
# #     print("Model files exist. Loading the models...")
# #     encoder.load_state_dict(torch.load(encoder_model_file))
# #     decoder.load_state_dict(torch.load(decoder_model_file))
# # else:
# #     os.makedirs('./autoencoder_trials', exist_ok=True)
# #     train_encoder()
# #     train_decoder()

# # # Combine Encoder and Decoder to form the Autoencoder
# # class Autoencoder(nn.Module):
# #     def __init__(self, encoder, decoder):
# #         super(Autoencoder, self).__init__()
# #         self.encoder = encoder
# #         self.decoder = decoder

# #     def forward(self, x):
# #         encoded = self.encoder(x)
# #         decoded = self.decoder(encoded)
# #         return decoded

# # # Load trained models
# # encoder.load_state_dict(torch.load(encoder_model_file))
# # decoder.load_state_dict(torch.load(decoder_model_file))
# # autoencoder = Autoencoder(encoder, decoder).to(device)
# # autoencoder.eval()

# # # Calculate reconstruction error on the test set
# # with torch.no_grad():
# #     reconstructed_test = autoencoder(torch.tensor(X_test, dtype=torch.float32).to(device)).cpu().numpy()

# # # Calculate Mean Squared Error (MSE)
# # mse = np.mean((X_test - reconstructed_test) ** 2)
# # print(f'Mean Squared Error (MSE): {mse}')

# # # Calculate Mean Absolute Error (MAE)
# # mae = np.mean(np.abs(X_test - reconstructed_test))
# # print(f'Mean Absolute Error (MAE): {mae}')

# # # Calculate Reconstruction Error Percentage
# # reconstruction_error_percentage = (
# #     np.mean(np.abs(X_test - reconstructed_test) / (np.abs(X_test) + 1e-8), axis=1) * 100
# # )
# # reconstruction_error_percentage_mean = np.mean(reconstruction_error_percentage)
# # print(f'Reconstruction Error Percentage: {reconstruction_error_percentage_mean:.4f}%')

# # def calculate_index_error_percentage(index, X, reconstructed_X):
# #     print(np.mean(np.abs(X[index] - reconstructed_X[index]) / (np.abs(X[index]) + 1e-8)) * 100)  


# import os
# import torch
# import torch.nn as nn
# import torch.optim as optim
# import numpy as np
# from torch.utils.data import DataLoader, TensorDataset

# # Check if CUDA is available
# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# print(f"Using device: {device}")

# # Define Autoencoder
# class Autoencoder(nn.Module):
#     def __init__(self, input_dim, encoding_dim, dropout_rate):
#         super(Autoencoder, self).__init__()
#         self.encoder = nn.Sequential(
#             nn.Linear(input_dim, 128),
#             nn.ReLU(),
#             nn.Dropout(dropout_rate),
#             nn.Linear(128, 64),
#             nn.ReLU(),
#             nn.Dropout(dropout_rate),
#             nn.Linear(64, encoding_dim)
#         )
#         self.decoder = nn.Sequential(
#             nn.Linear(encoding_dim, 64),
#             nn.ReLU(),
#             nn.Dropout(dropout_rate),
#             nn.Linear(64, 128),
#             nn.ReLU(),
#             nn.Dropout(dropout_rate),
#             nn.Linear(128, input_dim)
#         )
    
#     def forward(self, x):
#         encoded = self.encoder(x)
#         decoded = self.decoder(encoded)
#         return decoded

# # Define Relative Euclidean Error Loss
# class RelativeEuclideanError(nn.Module):
#     def __init__(self, epsilon=1e-8):
#         super(RelativeEuclideanError, self).__init__()
#         self.epsilon = epsilon

#     def forward(self, y_true, y_pred):
#         numerator = torch.norm(y_true - y_pred, dim=1)
#         denominator = torch.norm(y_true, dim=1) + self.epsilon
#         return torch.mean(numerator / denominator)

# # Define input dimensions
# input_dim = X_train.shape[1]

# # Model file path
# autoencoder_model_file = './autoencoder_trials/autoencoder.pth'

# # Hyperparameters
# encoding_dim = 5
# learning_rate = 0.0005
# dropout_rate = 0.3
# epochs = 750
# batch_size = 16
# patience = 40

# # Initialize model
# autoencoder = Autoencoder(input_dim, encoding_dim, dropout_rate).to(device)
# optimizer = optim.Adam(autoencoder.parameters(), lr=learning_rate)
# # criterion = RelativeEuclideanError()
# criterion = nn.MSELoss()

# # Train Autoencoder
# def train_autoencoder():
#     print("Training Autoencoder...")
#     autoencoder.train()
#     best_val_loss = float('inf')
#     patience_counter = 0

#     for epoch in range(epochs):
#         epoch_loss = 0
#         dataloader = DataLoader(TensorDataset(torch.tensor(X_train, dtype=torch.float32).to(device), 
#                                               torch.tensor(X_train, dtype=torch.float32).to(device)), 
#                                 batch_size=batch_size, shuffle=True, num_workers=0)

#         for batch_X, _ in dataloader:
#             batch_X = batch_X.to(device)
#             optimizer.zero_grad()
#             outputs = autoencoder(batch_X)
#             loss = criterion(outputs, batch_X)
#             loss.backward()
#             optimizer.step()
#             epoch_loss += loss.item()

#         avg_loss = epoch_loss / len(dataloader)
#         print(f"Epoch [{epoch+1}/{epochs}], Loss: {avg_loss:.4f}")

#         # Validation loss
#         autoencoder.eval()
#         with torch.no_grad():
#             val_outputs = autoencoder(torch.tensor(X_val, dtype=torch.float32).to(device))
#             val_loss = criterion(val_outputs, torch.tensor(X_val, dtype=torch.float32).to(device)).item()
            
#             # calculate Relative Euclidean Error
#             relative_error = np.mean(np.abs(X_val - val_outputs.cpu().numpy()) / (np.abs(X_val) + 1e-8), axis=1) * 100
#             relative_error_mean = np.mean(relative_error)
            
#             combined_metric = 0.8 * val_loss + 0.2 * relative_error_mean
            
#         print(f"Validation Loss: {combined_metric:.4f}")

#         # Early stopping
#         if combined_metric < best_val_loss:
#             best_val_loss = combined_metric
#             patience_counter = 0
#             torch.save(autoencoder.state_dict(), autoencoder_model_file)
#         else:
#             patience_counter += 1
#             print("Early stopping counter:", patience_counter)
#             if patience_counter >= patience:
#                 print("Early stopping triggered.")
#                 break

# # Train model if file does not exist
# if os.path.exists(autoencoder_model_file):
#     print("Model file exists. Loading the model...")
#     autoencoder.load_state_dict(torch.load(autoencoder_model_file))
# else:
#     os.makedirs('./autoencoder_trials', exist_ok=True)
#     train_autoencoder()

# # Evaluate Autoencoder
# autoencoder.eval()
# with torch.no_grad():
#     reconstructed_test = autoencoder(torch.tensor(X_test, dtype=torch.float32).to(device)).cpu().numpy()

# # Calculate evaluation metrics
# mse = np.mean((X_test - reconstructed_test) ** 2)
# print(f'Mean Squared Error (MSE): {mse}')

# mae = np.mean(np.abs(X_test - reconstructed_test))
# print(f'Mean Absolute Error (MAE): {mae}')

# reconstruction_error_percentage = (
#     np.mean(np.abs(X_test - reconstructed_test) / (np.abs(X_test) + 1e-8), axis=1) * 100
# )
# reconstruction_error_percentage_mean = np.mean(reconstruction_error_percentage)
# print(f'Reconstruction Error Percentage: {reconstruction_error_percentage_mean:.4f}%')

# def calculate_index_error_percentage(index, X, reconstructed_X):
#     print(np.mean(np.abs(X[index] - reconstructed_X[index]) / (np.abs(X[index]) + 1e-8)) * 100)

# %%
# # number of points with error greater than average
# np.sum(reconstruction_error_percentage > reconstruction_error_percentage_mean)

# %%
# # plot line graph of price for entire df, price column is df['Close']
# last_15_percent_index = int(len(df) * 0.85)
# last_30_percent_index = int(len(df) * 0.70)

# plt.figure(figsize=(14, 7))
# plt.plot(df['Close'], label='Train', color='blue')
# plt.plot(df['Close'].iloc[last_30_percent_index:last_15_percent_index], label='Val', color='green')
# plt.plot(df['Close'].iloc[last_15_percent_index:], label='Test', color='red')
# plt.title('Close Price History')
# plt.xlabel('Date')
# plt.ylabel('Price')
# plt.legend()
# plt.show()

# %%
# #   scatter graph to plot all errors, dont need to rearragne points
# plt.figure(figsize=(14, 7))
# plt.scatter(range(len(reconstruction_error_percentage)), reconstruction_error_percentage, color='blue')
# plt.ylim(0, 200)
# plt.title('Reconstruction Error Percentage')
# plt.xlabel('Data Point')
# plt.ylabel('Error Percentage')
# plt.legend()
# plt.show()

# %%
# # error count frequency per range
# error_ranges = [0, 1, 2, 5, 10, 20, 50, 100, 200]
# error_counts = np.zeros(len(error_ranges) - 1)
# for i in range(len(error_ranges) - 1):
#     error_counts[i] = np.sum((reconstruction_error_percentage > error_ranges[i]) & (reconstruction_error_percentage <= error_ranges[i + 1]))

# # print with descriptino
# for i in range(len(error_ranges) - 1):
#     print(f'Error percentage between {error_ranges[i]} and {error_ranges[i + 1]}: {error_counts[i]}')

# %%
# # get cosine similarity
# from sklearn.metrics.pairwise import cosine_similarity
# cosine_similarities  = np.diag(cosine_similarity(X_test, reconstructed_test))

# # get some statistics on the cosine similarities
# cosine_similarities_mean = np.mean(cosine_similarities)
# cosine_similarities_std = np.std(cosine_similarities)
# cosine_similarities_min = np.min(cosine_similarities)
# cosine_similarities_max = np.max(cosine_similarities)

# print(f'Cosine Similarity Mean: {cosine_similarities_mean}')
# print(f'Cosine Similarity Std: {cosine_similarities_std}')
# print(f'Cosine Similarity Min: {cosine_similarities_min}')
# print(f'Cosine Similarity Max: {cosine_similarities_max}')

# %%
# from sklearn.manifold import TSNE
# import matplotlib.pyplot as plt

# # Combine original and reconstructed vectors
# X_combined = np.vstack([X_test, reconstructed_test])
# labels = ["Original"] * len(X_test) + ["Reconstructed"] * len(reconstructed_test)

# # Apply t-SNE
# tsne = TSNE(n_components=2, perplexity=30, random_state=42)
# X_tsne = tsne.fit_transform(X_combined)

# # Plot
# plt.figure(figsize=(12, 6))
# plt.scatter(X_tsne[:len(X_test), 0], X_tsne[:len(X_test), 1], label="Original", alpha=0.5)
# plt.scatter(X_tsne[len(X_test):, 0], X_tsne[len(X_test):, 1], label="Reconstructed", alpha=0.5)
# plt.legend()
# plt.title("t-SNE Visualization of Original vs. Reconstructed Data")
# plt.show()

# %%
# from sklearn.decomposition import PCA

# X_combined = np.vstack([X_test, reconstructed_test])

# # Apply PCA
# pca = PCA(n_components=2)
# X_pca = pca.fit_transform(X_combined)

# # Plot
# plt.figure(figsize=(12, 6))
# plt.scatter(X_pca[:len(X_test), 0], X_pca[:len(X_test), 1], label="Original", alpha=0.5)
# plt.scatter(X_pca[len(X_test):, 0], X_pca[len(X_test):, 1], label="Reconstructed", alpha=0.5)
# plt.legend()
# plt.title("PCA Projection of Original vs. Reconstructed Data")
# plt.show()

# %%
# from numpy.linalg import norm

# euclidean_dist = np.mean([norm(X_test[i] - reconstructed_test[i]) for i in range(len(X_test))])
# print(f"Average Euclidean Distance: {euclidean_dist:.4f}")

# relative_error = euclidean_dist / np.mean(np.linalg.norm(X_test, axis=1))
# print(f"Relative Euclidean Error: {relative_error:.4f}")

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader, TensorDataset
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
from numpy.linalg import norm

# Check device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Define Autoencoder
class Autoencoder(nn.Module):
    def __init__(self, input_dim, encoding_dim, dropout_rate):
        super(Autoencoder, self).__init__()
        self.encoder = nn.Sequential(
            nn.Linear(input_dim, 128),
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.Linear(64, encoding_dim)
        )
        self.decoder = nn.Sequential(
            nn.Linear(encoding_dim, 64),
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.Linear(64, 128),
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.Linear(128, input_dim)
        )
    
    def forward(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return decoded

# Define input dimensions
input_dim = X_train.shape[1]

# Hyperparameters
encoding_dim = 5
learning_rate = 0.0005
dropout_rate = 0.3
epochs = 750
batch_size = 16
patience = 40

# Training function
def train_autoencoder():
    autoencoder = Autoencoder(input_dim, encoding_dim, dropout_rate).to(device)
    optimizer = optim.Adam(autoencoder.parameters(), lr=learning_rate)
    criterion = nn.MSELoss()
    
    best_val_loss = float('inf')
    patience_counter = 0
    
    for epoch in range(epochs):
        epoch_loss = 0
        dataloader = DataLoader(TensorDataset(torch.tensor(X_train, dtype=torch.float32).to(device)), batch_size=batch_size, shuffle=True)

        for batch_X in dataloader:
            batch_X = batch_X[0]
            optimizer.zero_grad()
            outputs = autoencoder(batch_X)
            loss = criterion(outputs, batch_X)
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item()
        
        avg_loss = epoch_loss / len(dataloader)
        
        # Validation
        autoencoder.eval()
        with torch.no_grad():
            val_outputs = autoencoder(torch.tensor(X_val, dtype=torch.float32).to(device))
            mse_loss = criterion(val_outputs, torch.tensor(X_val, dtype=torch.float32).to(device)).item()
            ree = np.mean(np.linalg.norm(X_val - val_outputs.cpu().numpy(), axis=1) / np.linalg.norm(X_val, axis=1))
            combined_metric = 0.8 * mse_loss + 0.2 * ree
        
        print(f"Epoch [{epoch+1}/{epochs}], Combined Loss: {combined_metric:.4f}")
        
        # Early stopping
        if combined_metric < best_val_loss:
            best_val_loss = combined_metric
            patience_counter = 0
            best_model = autoencoder.state_dict()
        else:
            patience_counter += 1
            if patience_counter >= patience:
                print("Early stopping triggered.")
                break
    
    return best_model

# Run 10 trials
num_trials = 10
metrics = []
error_percentages = []

t_sne_results = []
pca_results = []

for trial in range(num_trials):
    print(f"Starting trial {trial+1}...")
    best_model = train_autoencoder()
    autoencoder = Autoencoder(input_dim, encoding_dim, dropout_rate).to(device)
    autoencoder.load_state_dict(best_model)
    autoencoder.eval()
    
    with torch.no_grad():
        reconstructed_test = autoencoder(torch.tensor(X_test, dtype=torch.float32).to(device)).cpu().numpy()
    
    mse = np.mean((X_test - reconstructed_test) ** 2)
    mae = np.mean(np.abs(X_test - reconstructed_test))
    ree = np.mean(np.linalg.norm(X_test - reconstructed_test, axis=1) / np.linalg.norm(X_test, axis=1))
    euclidean_dist = np.mean([norm(X_test[i] - reconstructed_test[i]) for i in range(len(X_test))])
    
    print(f'Trial {trial+1} - MSE: {mse:.4f}, MAE: {mae:.4f}, REE: {ree:.4f}, Euclidean Distance: {euclidean_dist:.4f}')
    metrics.append([mse, mae, ree, euclidean_dist])
    
    # Reconstruction Error Percentage
    reconstruction_error_percentage = (
        np.mean(np.abs(X_test - reconstructed_test) / (np.abs(X_test) + 1e-8), axis=1) * 100
    )
    error_percentages.append(reconstruction_error_percentage)
    
    # t-SNE
    X_combined = np.vstack([X_test, reconstructed_test])
    labels = ["Original"] * len(X_test) + ["Reconstructed"] * len(reconstructed_test)
    tsne = TSNE(n_components=2, perplexity=30, random_state=42)
    t_sne_results.append(tsne.fit_transform(X_combined))
    
    # PCA
    pca = PCA(n_components=2)
    pca_results.append(pca.fit_transform(X_combined))
# Out:
# Using device: cuda
# Starting trial 1...
# Epoch [1/750], Combined Loss: 0.0663
# Epoch [2/750], Combined Loss: 0.0206
# Epoch [3/750], Combined Loss: 0.0191
# Epoch [4/750], Combined Loss: 0.0179
# Epoch [5/750], Combined Loss: 0.0156
# Epoch [6/750], Combined Loss: 0.0155
# Epoch [7/750], Combined Loss: 0.0144
# Epoch [8/750], Combined Loss: 0.0132
# Epoch [9/750], Combined Loss: 0.0109
# Epoch [10/750], Combined Loss: 0.0114
# Epoch [11/750], Combined Loss: 0.0106
# Epoch [12/750], Combined Loss: 0.0126
# Epoch [13/750], Combined Loss: 0.0113
# Epoch [14/750], Combined Loss: 0.0129
# Epoch [15/750], Combined Loss: 0.0099
# Epoch [16/750], Combined Loss: 0.0109
# Epoch [17/750], Combined Loss: 0.0112
# Epoch [18/750], Combined Loss: 0.0108
# Epoch [19/750], Combined Loss: 0.0126
# Epoch [20/750], Combined Loss: 0.0121
# Epoch [21/750], Combined Loss: 0.0129
# Epoch [22/750], Combined Loss: 0.0121
# Epoch [23/750], Combined Loss: 0.0106
# Epoch [24/750], Combined Loss: 0.0087
# Epoch [25/750], Combined Loss: 0.0143
# Epoch [26/750], Combined Loss: 0.0144
# Epoch [27/750], Combined Loss: 0.0121
# Epoch [28/750], Combined Loss: 0.0128
# Epoch [29/750], Combined Loss: 0.0133
# Epoch [30/750], Combined Loss: 0.0109
# Epoch [31/750], Combined Loss: 0.0116
# Epoch [32/750], Combined Loss: 0.0131
# Epoch [33/750], Combined Loss: 0.0107
# Epoch [34/750], Combined Loss: 0.0104
# Epoch [35/750], Combined Loss: 0.0111
# Epoch [36/750], Combined Loss: 0.0101
# Epoch [37/750], Combined Loss: 0.0125
# Epoch [38/750], Combined Loss: 0.0110
# Epoch [39/750], Combined Loss: 0.0115
# Epoch [40/750], Combined Loss: 0.0141
# Epoch [41/750], Combined Loss: 0.0124
# Epoch [42/750], Combined Loss: 0.0144
# Epoch [43/750], Combined Loss: 0.0097
# Epoch [44/750], Combined Loss: 0.0140
# Epoch [45/750], Combined Loss: 0.0125
# Epoch [46/750], Combined Loss: 0.0142
# Epoch [47/750], Combined Loss: 0.0108
# Epoch [48/750], Combined Loss: 0.0112
# Epoch [49/750], Combined Loss: 0.0091
# Epoch [50/750], Combined Loss: 0.0062
# Epoch [51/750], Combined Loss: 0.0083
# Epoch [52/750], Combined Loss: 0.0065
# Epoch [53/750], Combined Loss: 0.0052
# Epoch [54/750], Combined Loss: 0.0081
# Epoch [55/750], Combined Loss: 0.0042
# Epoch [56/750], Combined Loss: 0.0053
# Epoch [57/750], Combined Loss: 0.0055
# Epoch [58/750], Combined Loss: 0.0067
# Epoch [59/750], Combined Loss: 0.0067
# Epoch [60/750], Combined Loss: 0.0049
# Epoch [61/750], Combined Loss: 0.0065
# Epoch [62/750], Combined Loss: 0.0063
# Epoch [63/750], Combined Loss: 0.0057
# Epoch [64/750], Combined Loss: 0.0066
# Epoch [65/750], Combined Loss: 0.0042
# Epoch [66/750], Combined Loss: 0.0070
# Epoch [67/750], Combined Loss: 0.0062
# Epoch [68/750], Combined Loss: 0.0059
# Epoch [69/750], Combined Loss: 0.0067
# Epoch [70/750], Combined Loss: 0.0072
# Epoch [71/750], Combined Loss: 0.0068
# Epoch [72/750], Combined Loss: 0.0060
# Epoch [73/750], Combined Loss: 0.0070
# Epoch [74/750], Combined Loss: 0.0078
# Epoch [75/750], Combined Loss: 0.0074
# Epoch [76/750], Combined Loss: 0.0079
# Epoch [77/750], Combined Loss: 0.0068
# Epoch [78/750], Combined Loss: 0.0063
# Epoch [79/750], Combined Loss: 0.0071
# Epoch [80/750], Combined Loss: 0.0069
# Epoch [81/750], Combined Loss: 0.0085
# Epoch [82/750], Combined Loss: 0.0066
# Epoch [83/750], Combined Loss: 0.0088
# Epoch [84/750], Combined Loss: 0.0077
# Epoch [85/750], Combined Loss: 0.0094
# Epoch [86/750], Combined Loss: 0.0073
# Epoch [87/750], Combined Loss: 0.0072
# Epoch [88/750], Combined Loss: 0.0068
# Epoch [89/750], Combined Loss: 0.0083
# Epoch [90/750], Combined Loss: 0.0074
# Epoch [91/750], Combined Loss: 0.0058
# Epoch [92/750], Combined Loss: 0.0060
# Epoch [93/750], Combined Loss: 0.0058
# Epoch [94/750], Combined Loss: 0.0040
# Epoch [95/750], Combined Loss: 0.0061
# Epoch [96/750], Combined Loss: 0.0050
# Epoch [97/750], Combined Loss: 0.0053
# Epoch [98/750], Combined Loss: 0.0044
# Epoch [99/750], Combined Loss: 0.0040
# Epoch [100/750], Combined Loss: 0.0040
# Epoch [101/750], Combined Loss: 0.0055
# Epoch [102/750], Combined Loss: 0.0044
# Epoch [103/750], Combined Loss: 0.0049
# Epoch [104/750], Combined Loss: 0.0045
# Epoch [105/750], Combined Loss: 0.0043
# Epoch [106/750], Combined Loss: 0.0047
# Epoch [107/750], Combined Loss: 0.0033
# Epoch [108/750], Combined Loss: 0.0044
# Epoch [109/750], Combined Loss: 0.0047
# Epoch [110/750], Combined Loss: 0.0038
# Epoch [111/750], Combined Loss: 0.0043
# Epoch [112/750], Combined Loss: 0.0046
# Epoch [113/750], Combined Loss: 0.0044
# Epoch [114/750], Combined Loss: 0.0034
# Epoch [115/750], Combined Loss: 0.0041
# Epoch [116/750], Combined Loss: 0.0045
# Epoch [117/750], Combined Loss: 0.0041
# Epoch [118/750], Combined Loss: 0.0045
# Epoch [119/750], Combined Loss: 0.0044
# Epoch [120/750], Combined Loss: 0.0046
# Epoch [121/750], Combined Loss: 0.0043
# Epoch [122/750], Combined Loss: 0.0039
# Epoch [123/750], Combined Loss: 0.0047
# Epoch [124/750], Combined Loss: 0.0044
# Epoch [125/750], Combined Loss: 0.0046
# Epoch [126/750], Combined Loss: 0.0052
# Epoch [127/750], Combined Loss: 0.0052
# Epoch [128/750], Combined Loss: 0.0043
# Epoch [129/750], Combined Loss: 0.0042
# Epoch [130/750], Combined Loss: 0.0043
# Epoch [131/750], Combined Loss: 0.0040
# Epoch [132/750], Combined Loss: 0.0038
# Epoch [133/750], Combined Loss: 0.0037
# Epoch [134/750], Combined Loss: 0.0041
# Epoch [135/750], Combined Loss: 0.0043
# Epoch [136/750], Combined Loss: 0.0032
# Epoch [137/750], Combined Loss: 0.0037
# Epoch [138/750], Combined Loss: 0.0075
# Epoch [139/750], Combined Loss: 0.0041
# Epoch [140/750], Combined Loss: 0.0040
# Epoch [141/750], Combined Loss: 0.0040
# Epoch [142/750], Combined Loss: 0.0042
# Epoch [143/750], Combined Loss: 0.0040
# Epoch [144/750], Combined Loss: 0.0041
# Epoch [145/750], Combined Loss: 0.0041
# Epoch [146/750], Combined Loss: 0.0043
# Epoch [147/750], Combined Loss: 0.0045
# Epoch [148/750], Combined Loss: 0.0047
# Epoch [149/750], Combined Loss: 0.0040
# Epoch [150/750], Combined Loss: 0.0036
# Epoch [151/750], Combined Loss: 0.0034
# Epoch [152/750], Combined Loss: 0.0036
# Epoch [153/750], Combined Loss: 0.0034
# Epoch [154/750], Combined Loss: 0.0045
# Epoch [155/750], Combined Loss: 0.0040
# Epoch [156/750], Combined Loss: 0.0037
# Epoch [157/750], Combined Loss: 0.0038
# Epoch [158/750], Combined Loss: 0.0049
# Epoch [159/750], Combined Loss: 0.0039
# Epoch [160/750], Combined Loss: 0.0045
# Epoch [161/750], Combined Loss: 0.0042
# Epoch [162/750], Combined Loss: 0.0052
# Epoch [163/750], Combined Loss: 0.0035
# Epoch [164/750], Combined Loss: 0.0042
# Epoch [165/750], Combined Loss: 0.0040
# Epoch [166/750], Combined Loss: 0.0039
# Epoch [167/750], Combined Loss: 0.0049
# Epoch [168/750], Combined Loss: 0.0043
# Epoch [169/750], Combined Loss: 0.0055
# Epoch [170/750], Combined Loss: 0.0036
# Epoch [171/750], Combined Loss: 0.0046
# Epoch [172/750], Combined Loss: 0.0039
# Epoch [173/750], Combined Loss: 0.0036
# Epoch [174/750], Combined Loss: 0.0041
# Epoch [175/750], Combined Loss: 0.0036
# Epoch [176/750], Combined Loss: 0.0041
# Early stopping triggered.
# Trial 1 - MSE: 0.0007, MAE: 0.0187, REE: 0.0256, Euclidean Distance: 0.0813
# Starting trial 2...
# Epoch [1/750], Combined Loss: 0.0658
# Epoch [2/750], Combined Loss: 0.0198
# Epoch [3/750], Combined Loss: 0.0164
# Epoch [4/750], Combined Loss: 0.0151
# Epoch [5/750], Combined Loss: 0.0163
# Epoch [6/750], Combined Loss: 0.0159
# Epoch [7/750], Combined Loss: 0.0145
# Epoch [8/750], Combined Loss: 0.0137
# Epoch [9/750], Combined Loss: 0.0119
# Epoch [10/750], Combined Loss: 0.0103
# Epoch [11/750], Combined Loss: 0.0108
# Epoch [12/750], Combined Loss: 0.0088
# Epoch [13/750], Combined Loss: 0.0093
# Epoch [14/750], Combined Loss: 0.0116
# Epoch [15/750], Combined Loss: 0.0129
# Epoch [16/750], Combined Loss: 0.0125
# Epoch [17/750], Combined Loss: 0.0078
# Epoch [18/750], Combined Loss: 0.0126
# Epoch [19/750], Combined Loss: 0.0135
# Epoch [20/750], Combined Loss: 0.0103
# Epoch [21/750], Combined Loss: 0.0139
# Epoch [22/750], Combined Loss: 0.0143
# Epoch [23/750], Combined Loss: 0.0100
# Epoch [24/750], Combined Loss: 0.0130
# Epoch [25/750], Combined Loss: 0.0125
# Epoch [26/750], Combined Loss: 0.0114
# Epoch [27/750], Combined Loss: 0.0117
# Epoch [28/750], Combined Loss: 0.0093
# Epoch [29/750], Combined Loss: 0.0121
# Epoch [30/750], Combined Loss: 0.0088
# Epoch [31/750], Combined Loss: 0.0118
# Epoch [32/750], Combined Loss: 0.0093
# Epoch [33/750], Combined Loss: 0.0079
# Epoch [34/750], Combined Loss: 0.0089
# Epoch [35/750], Combined Loss: 0.0109
# Epoch [36/750], Combined Loss: 0.0125
# Epoch [37/750], Combined Loss: 0.0091
# Epoch [38/750], Combined Loss: 0.0105
# Epoch [39/750], Combined Loss: 0.0072
# Epoch [40/750], Combined Loss: 0.0077
# Epoch [41/750], Combined Loss: 0.0084
# Epoch [42/750], Combined Loss: 0.0078
# Epoch [43/750], Combined Loss: 0.0064
# Epoch [44/750], Combined Loss: 0.0065
# Epoch [45/750], Combined Loss: 0.0066
# Epoch [46/750], Combined Loss: 0.0066
# Epoch [47/750], Combined Loss: 0.0071
# Epoch [48/750], Combined Loss: 0.0056
# Epoch [49/750], Combined Loss: 0.0063
# Epoch [50/750], Combined Loss: 0.0085
# Epoch [51/750], Combined Loss: 0.0064
# Epoch [52/750], Combined Loss: 0.0063
# Epoch [53/750], Combined Loss: 0.0066
# Epoch [54/750], Combined Loss: 0.0063
# Epoch [55/750], Combined Loss: 0.0067
# Epoch [56/750], Combined Loss: 0.0062
# Epoch [57/750], Combined Loss: 0.0053
# Epoch [58/750], Combined Loss: 0.0054
# Epoch [59/750], Combined Loss: 0.0079
# Epoch [60/750], Combined Loss: 0.0053
# Epoch [61/750], Combined Loss: 0.0064
# Epoch [62/750], Combined Loss: 0.0066
# Epoch [63/750], Combined Loss: 0.0052
# Epoch [64/750], Combined Loss: 0.0052
# Epoch [65/750], Combined Loss: 0.0056
# Epoch [66/750], Combined Loss: 0.0051
# Epoch [67/750], Combined Loss: 0.0056
# Epoch [68/750], Combined Loss: 0.0062
# Epoch [69/750], Combined Loss: 0.0055
# Epoch [70/750], Combined Loss: 0.0055
# Epoch [71/750], Combined Loss: 0.0048
# Epoch [72/750], Combined Loss: 0.0066
# Epoch [73/750], Combined Loss: 0.0052
# Epoch [74/750], Combined Loss: 0.0052
# Epoch [75/750], Combined Loss: 0.0058
# Epoch [76/750], Combined Loss: 0.0048
# Epoch [77/750], Combined Loss: 0.0055
# Epoch [78/750], Combined Loss: 0.0046
# Epoch [79/750], Combined Loss: 0.0049
# Epoch [80/750], Combined Loss: 0.0050
# Epoch [81/750], Combined Loss: 0.0051
# Epoch [82/750], Combined Loss: 0.0053
# Epoch [83/750], Combined Loss: 0.0051
# Epoch [84/750], Combined Loss: 0.0049
# Epoch [85/750], Combined Loss: 0.0040
# Epoch [86/750], Combined Loss: 0.0044
# Epoch [87/750], Combined Loss: 0.0049
# Epoch [88/750], Combined Loss: 0.0046
# Epoch [89/750], Combined Loss: 0.0039
# Epoch [90/750], Combined Loss: 0.0047
# Epoch [91/750], Combined Loss: 0.0055
# Epoch [92/750], Combined Loss: 0.0046
# Epoch [93/750], Combined Loss: 0.0046
# Epoch [94/750], Combined Loss: 0.0054
# Epoch [95/750], Combined Loss: 0.0075
# Epoch [96/750], Combined Loss: 0.0059
# Epoch [97/750], Combined Loss: 0.0045
# Epoch [98/750], Combined Loss: 0.0045
# Epoch [99/750], Combined Loss: 0.0043
# Epoch [100/750], Combined Loss: 0.0038
# Epoch [101/750], Combined Loss: 0.0037
# Epoch [102/750], Combined Loss: 0.0039
# Epoch [103/750], Combined Loss: 0.0040
# Epoch [104/750], Combined Loss: 0.0042
# Epoch [105/750], Combined Loss: 0.0036
# Epoch [106/750], Combined Loss: 0.0038
# Epoch [107/750], Combined Loss: 0.0036
# Epoch [108/750], Combined Loss: 0.0045
# Epoch [109/750], Combined Loss: 0.0042
# Epoch [110/750], Combined Loss: 0.0043
# Epoch [111/750], Combined Loss: 0.0031
# Epoch [112/750], Combined Loss: 0.0041
# Epoch [113/750], Combined Loss: 0.0047
# Epoch [114/750], Combined Loss: 0.0039
# Epoch [115/750], Combined Loss: 0.0039
# Epoch [116/750], Combined Loss: 0.0051
# Epoch [117/750], Combined Loss: 0.0042
# Epoch [118/750], Combined Loss: 0.0045
# Epoch [119/750], Combined Loss: 0.0039
# Epoch [120/750], Combined Loss: 0.0040
# Epoch [121/750], Combined Loss: 0.0037
# Epoch [122/750], Combined Loss: 0.0038
# Epoch [123/750], Combined Loss: 0.0040
# Epoch [124/750], Combined Loss: 0.0034
# Epoch [125/750], Combined Loss: 0.0040
# Epoch [126/750], Combined Loss: 0.0032
# Epoch [127/750], Combined Loss: 0.0032
# Epoch [128/750], Combined Loss: 0.0044
# Epoch [129/750], Combined Loss: 0.0041
# Epoch [130/750], Combined Loss: 0.0038
# Epoch [131/750], Combined Loss: 0.0038
# Epoch [132/750], Combined Loss: 0.0057
# Epoch [133/750], Combined Loss: 0.0074
# Epoch [134/750], Combined Loss: 0.0038
# Epoch [135/750], Combined Loss: 0.0041
# Epoch [136/750], Combined Loss: 0.0035
# Epoch [137/750], Combined Loss: 0.0038
# Epoch [138/750], Combined Loss: 0.0041
# Epoch [139/750], Combined Loss: 0.0038
# Epoch [140/750], Combined Loss: 0.0038
# Epoch [141/750], Combined Loss: 0.0046
# Epoch [142/750], Combined Loss: 0.0036
# Epoch [143/750], Combined Loss: 0.0041
# Epoch [144/750], Combined Loss: 0.0035
# Epoch [145/750], Combined Loss: 0.0036
# Epoch [146/750], Combined Loss: 0.0035
# Epoch [147/750], Combined Loss: 0.0042
# Epoch [148/750], Combined Loss: 0.0040
# Epoch [149/750], Combined Loss: 0.0032
# Epoch [150/750], Combined Loss: 0.0036
# Epoch [151/750], Combined Loss: 0.0043
# Early stopping triggered.
# Trial 2 - MSE: 0.0009, MAE: 0.0202, REE: 0.0282, Euclidean Distance: 0.0892
# Starting trial 3...
# Epoch [1/750], Combined Loss: 0.0787
# Epoch [2/750], Combined Loss: 0.0192
# Epoch [3/750], Combined Loss: 0.0187
# Epoch [4/750], Combined Loss: 0.0169
# Epoch [5/750], Combined Loss: 0.0149
# Epoch [6/750], Combined Loss: 0.0157
# Epoch [7/750], Combined Loss: 0.0130
# Epoch [8/750], Combined Loss: 0.0117
# Epoch [9/750], Combined Loss: 0.0098
# Epoch [10/750], Combined Loss: 0.0106
# Epoch [11/750], Combined Loss: 0.0105
# Epoch [12/750], Combined Loss: 0.0099
# Epoch [13/750], Combined Loss: 0.0118
# Epoch [14/750], Combined Loss: 0.0095
# Epoch [15/750], Combined Loss: 0.0080
# Epoch [16/750], Combined Loss: 0.0105
# Epoch [17/750], Combined Loss: 0.0106
# Epoch [18/750], Combined Loss: 0.0103
# Epoch [19/750], Combined Loss: 0.0109
# Epoch [20/750], Combined Loss: 0.0089
# Epoch [21/750], Combined Loss: 0.0108
# Epoch [22/750], Combined Loss: 0.0094
# Epoch [23/750], Combined Loss: 0.0102
# Epoch [24/750], Combined Loss: 0.0114
# Epoch [25/750], Combined Loss: 0.0122
# Epoch [26/750], Combined Loss: 0.0103
# Epoch [27/750], Combined Loss: 0.0125
# Epoch [28/750], Combined Loss: 0.0102
# Epoch [29/750], Combined Loss: 0.0102
# Epoch [30/750], Combined Loss: 0.0134
# Epoch [31/750], Combined Loss: 0.0132
# Epoch [32/750], Combined Loss: 0.0129
# Epoch [33/750], Combined Loss: 0.0128
# Epoch [34/750], Combined Loss: 0.0100
# Epoch [35/750], Combined Loss: 0.0139
# Epoch [36/750], Combined Loss: 0.0114
# Epoch [37/750], Combined Loss: 0.0123
# Epoch [38/750], Combined Loss: 0.0135
# Epoch [39/750], Combined Loss: 0.0100
# Epoch [40/750], Combined Loss: 0.0120
# Epoch [41/750], Combined Loss: 0.0105
# Epoch [42/750], Combined Loss: 0.0105
# Epoch [43/750], Combined Loss: 0.0120
# Epoch [44/750], Combined Loss: 0.0130
# Epoch [45/750], Combined Loss: 0.0138
# Epoch [46/750], Combined Loss: 0.0112
# Epoch [47/750], Combined Loss: 0.0101
# Epoch [48/750], Combined Loss: 0.0104
# Epoch [49/750], Combined Loss: 0.0106
# Epoch [50/750], Combined Loss: 0.0095
# Epoch [51/750], Combined Loss: 0.0092
# Epoch [52/750], Combined Loss: 0.0083
# Epoch [53/750], Combined Loss: 0.0063
# Epoch [54/750], Combined Loss: 0.0079
# Epoch [55/750], Combined Loss: 0.0083
# Epoch [56/750], Combined Loss: 0.0083
# Epoch [57/750], Combined Loss: 0.0070
# Epoch [58/750], Combined Loss: 0.0072
# Epoch [59/750], Combined Loss: 0.0086
# Epoch [60/750], Combined Loss: 0.0074
# Epoch [61/750], Combined Loss: 0.0085
# Epoch [62/750], Combined Loss: 0.0096
# Epoch [63/750], Combined Loss: 0.0088
# Epoch [64/750], Combined Loss: 0.0103
# Epoch [65/750], Combined Loss: 0.0084
# Epoch [66/750], Combined Loss: 0.0086
# Epoch [67/750], Combined Loss: 0.0078
# Epoch [68/750], Combined Loss: 0.0095
# Epoch [69/750], Combined Loss: 0.0086
# Epoch [70/750], Combined Loss: 0.0070
# Epoch [71/750], Combined Loss: 0.0081
# Epoch [72/750], Combined Loss: 0.0092
# Epoch [73/750], Combined Loss: 0.0096
# Epoch [74/750], Combined Loss: 0.0075
# Epoch [75/750], Combined Loss: 0.0090
# Epoch [76/750], Combined Loss: 0.0066
# Epoch [77/750], Combined Loss: 0.0095
# Epoch [78/750], Combined Loss: 0.0081
# Epoch [79/750], Combined Loss: 0.0087
# Epoch [80/750], Combined Loss: 0.0088
# Epoch [81/750], Combined Loss: 0.0074
# Epoch [82/750], Combined Loss: 0.0099
# Epoch [83/750], Combined Loss: 0.0076
# Epoch [84/750], Combined Loss: 0.0064
# Epoch [85/750], Combined Loss: 0.0087
# Epoch [86/750], Combined Loss: 0.0088
# Epoch [87/750], Combined Loss: 0.0087
# Epoch [88/750], Combined Loss: 0.0110
# Epoch [89/750], Combined Loss: 0.0109
# Epoch [90/750], Combined Loss: 0.0067
# Epoch [91/750], Combined Loss: 0.0095
# Epoch [92/750], Combined Loss: 0.0096
# Epoch [93/750], Combined Loss: 0.0084
# Early stopping triggered.
# Trial 3 - MSE: 0.0037, MAE: 0.0439, REE: 0.0635, Euclidean Distance: 0.1980
# Starting trial 4...
# Epoch [1/750], Combined Loss: 0.0472
# Epoch [2/750], Combined Loss: 0.0224
# Epoch [3/750], Combined Loss: 0.0175
# Epoch [4/750], Combined Loss: 0.0164
# Epoch [5/750], Combined Loss: 0.0171
# Epoch [6/750], Combined Loss: 0.0160
# Epoch [7/750], Combined Loss: 0.0157
# Epoch [8/750], Combined Loss: 0.0172
# Epoch [9/750], Combined Loss: 0.0143
# Epoch [10/750], Combined Loss: 0.0091
# Epoch [11/750], Combined Loss: 0.0099
# Epoch [12/750], Combined Loss: 0.0090
# Epoch [13/750], Combined Loss: 0.0103
# Epoch [14/750], Combined Loss: 0.0094
# Epoch [15/750], Combined Loss: 0.0104
# Epoch [16/750], Combined Loss: 0.0089
# Epoch [17/750], Combined Loss: 0.0103
# Epoch [18/750], Combined Loss: 0.0093
# Epoch [19/750], Combined Loss: 0.0100
# Epoch [20/750], Combined Loss: 0.0130
# Epoch [21/750], Combined Loss: 0.0118
# Epoch [22/750], Combined Loss: 0.0114
# Epoch [23/750], Combined Loss: 0.0110
# Epoch [24/750], Combined Loss: 0.0132
# Epoch [25/750], Combined Loss: 0.0121
# Epoch [26/750], Combined Loss: 0.0121
# Epoch [27/750], Combined Loss: 0.0108
# Epoch [28/750], Combined Loss: 0.0127
# Epoch [29/750], Combined Loss: 0.0123
# Epoch [30/750], Combined Loss: 0.0097
# Epoch [31/750], Combined Loss: 0.0102
# Epoch [32/750], Combined Loss: 0.0111
# Epoch [33/750], Combined Loss: 0.0100
# Epoch [34/750], Combined Loss: 0.0087
# Epoch [35/750], Combined Loss: 0.0099
# Epoch [36/750], Combined Loss: 0.0091
# Epoch [37/750], Combined Loss: 0.0086
# Epoch [38/750], Combined Loss: 0.0065
# Epoch [39/750], Combined Loss: 0.0068
# Epoch [40/750], Combined Loss: 0.0084
# Epoch [41/750], Combined Loss: 0.0069
# Epoch [42/750], Combined Loss: 0.0096
# Epoch [43/750], Combined Loss: 0.0096
# Epoch [44/750], Combined Loss: 0.0100
# Epoch [45/750], Combined Loss: 0.0073
# Epoch [46/750], Combined Loss: 0.0061
# Epoch [47/750], Combined Loss: 0.0075
# Epoch [48/750], Combined Loss: 0.0060
# Epoch [49/750], Combined Loss: 0.0067
# Epoch [50/750], Combined Loss: 0.0084
# Epoch [51/750], Combined Loss: 0.0075
# Epoch [52/750], Combined Loss: 0.0081
# Epoch [53/750], Combined Loss: 0.0072
# Epoch [54/750], Combined Loss: 0.0089
# Epoch [55/750], Combined Loss: 0.0103
# Epoch [56/750], Combined Loss: 0.0073
# Epoch [57/750], Combined Loss: 0.0059
# Epoch [58/750], Combined Loss: 0.0088
# Epoch [59/750], Combined Loss: 0.0081
# Epoch [60/750], Combined Loss: 0.0088
# Epoch [61/750], Combined Loss: 0.0096
# Epoch [62/750], Combined Loss: 0.0102
# Epoch [63/750], Combined Loss: 0.0086
# Epoch [64/750], Combined Loss: 0.0091
# Epoch [65/750], Combined Loss: 0.0087
# Epoch [66/750], Combined Loss: 0.0067
# Epoch [67/750], Combined Loss: 0.0105
# Epoch [68/750], Combined Loss: 0.0072
# Epoch [69/750], Combined Loss: 0.0088
# Epoch [70/750], Combined Loss: 0.0092
# Epoch [71/750], Combined Loss: 0.0089
# Epoch [72/750], Combined Loss: 0.0084
# Epoch [73/750], Combined Loss: 0.0082
# Epoch [74/750], Combined Loss: 0.0071
# Epoch [75/750], Combined Loss: 0.0087
# Epoch [76/750], Combined Loss: 0.0076
# Epoch [77/750], Combined Loss: 0.0074
# Epoch [78/750], Combined Loss: 0.0081
# Epoch [79/750], Combined Loss: 0.0058
# Epoch [80/750], Combined Loss: 0.0082
# Epoch [81/750], Combined Loss: 0.0082
# Epoch [82/750], Combined Loss: 0.0081
# Epoch [83/750], Combined Loss: 0.0070
# Epoch [84/750], Combined Loss: 0.0063
# Epoch [85/750], Combined Loss: 0.0071
# Epoch [86/750], Combined Loss: 0.0064
# Epoch [87/750], Combined Loss: 0.0060
# Epoch [88/750], Combined Loss: 0.0065
# Epoch [89/750], Combined Loss: 0.0049
# Epoch [90/750], Combined Loss: 0.0050
# Epoch [91/750], Combined Loss: 0.0053
# Epoch [92/750], Combined Loss: 0.0043
# Epoch [93/750], Combined Loss: 0.0055
# Epoch [94/750], Combined Loss: 0.0054
# Epoch [95/750], Combined Loss: 0.0049
# Epoch [96/750], Combined Loss: 0.0038
# Epoch [97/750], Combined Loss: 0.0052
# Epoch [98/750], Combined Loss: 0.0047
# Epoch [99/750], Combined Loss: 0.0048
# Epoch [100/750], Combined Loss: 0.0049
# Epoch [101/750], Combined Loss: 0.0042
# Epoch [102/750], Combined Loss: 0.0040
# Epoch [103/750], Combined Loss: 0.0041
# Epoch [104/750], Combined Loss: 0.0044
# Epoch [105/750], Combined Loss: 0.0044
# Epoch [106/750], Combined Loss: 0.0043
# Epoch [107/750], Combined Loss: 0.0054
# Epoch [108/750], Combined Loss: 0.0046
# Epoch [109/750], Combined Loss: 0.0045
# Epoch [110/750], Combined Loss: 0.0042
# Epoch [111/750], Combined Loss: 0.0043
# Epoch [112/750], Combined Loss: 0.0037
# Epoch [113/750], Combined Loss: 0.0064
# Epoch [114/750], Combined Loss: 0.0051
# Epoch [115/750], Combined Loss: 0.0046
# Epoch [116/750], Combined Loss: 0.0044
# Epoch [117/750], Combined Loss: 0.0053
# Epoch [118/750], Combined Loss: 0.0046
# Epoch [119/750], Combined Loss: 0.0046
# Epoch [120/750], Combined Loss: 0.0049
# Epoch [121/750], Combined Loss: 0.0045
# Epoch [122/750], Combined Loss: 0.0044
# Epoch [123/750], Combined Loss: 0.0052
# Epoch [124/750], Combined Loss: 0.0055
# Epoch [125/750], Combined Loss: 0.0050
# Epoch [126/750], Combined Loss: 0.0053
# Epoch [127/750], Combined Loss: 0.0051
# Epoch [128/750], Combined Loss: 0.0050
# Epoch [129/750], Combined Loss: 0.0049
# Epoch [130/750], Combined Loss: 0.0044
# Epoch [131/750], Combined Loss: 0.0046
# Epoch [132/750], Combined Loss: 0.0049
# Epoch [133/750], Combined Loss: 0.0047
# Epoch [134/750], Combined Loss: 0.0047
# Epoch [135/750], Combined Loss: 0.0040
# Epoch [136/750], Combined Loss: 0.0049
# Epoch [137/750], Combined Loss: 0.0054
# Epoch [138/750], Combined Loss: 0.0052
# Epoch [139/750], Combined Loss: 0.0044
# Epoch [140/750], Combined Loss: 0.0044
# Epoch [141/750], Combined Loss: 0.0057
# Epoch [142/750], Combined Loss: 0.0048
# Epoch [143/750], Combined Loss: 0.0047
# Epoch [144/750], Combined Loss: 0.0053
# Epoch [145/750], Combined Loss: 0.0048
# Epoch [146/750], Combined Loss: 0.0045
# Epoch [147/750], Combined Loss: 0.0055
# Epoch [148/750], Combined Loss: 0.0054
# Epoch [149/750], Combined Loss: 0.0052
# Epoch [150/750], Combined Loss: 0.0044
# Epoch [151/750], Combined Loss: 0.0061
# Epoch [152/750], Combined Loss: 0.0055
# Early stopping triggered.
# Trial 4 - MSE: 0.0016, MAE: 0.0307, REE: 0.0393, Euclidean Distance: 0.1235
# Starting trial 5...
# Epoch [1/750], Combined Loss: 0.0430
# Epoch [2/750], Combined Loss: 0.0206
# Epoch [3/750], Combined Loss: 0.0166
# Epoch [4/750], Combined Loss: 0.0170
# Epoch [5/750], Combined Loss: 0.0167
# Epoch [6/750], Combined Loss: 0.0165
# Epoch [7/750], Combined Loss: 0.0184
# Epoch [8/750], Combined Loss: 0.0167
# Epoch [9/750], Combined Loss: 0.0143
# Epoch [10/750], Combined Loss: 0.0116
# Epoch [11/750], Combined Loss: 0.0114
# Epoch [12/750], Combined Loss: 0.0099
# Epoch [13/750], Combined Loss: 0.0104
# Epoch [14/750], Combined Loss: 0.0097
# Epoch [15/750], Combined Loss: 0.0094
# Epoch [16/750], Combined Loss: 0.0110
# Epoch [17/750], Combined Loss: 0.0105
# Epoch [18/750], Combined Loss: 0.0093
# Epoch [19/750], Combined Loss: 0.0110
# Epoch [20/750], Combined Loss: 0.0112
# Epoch [21/750], Combined Loss: 0.0098
# Epoch [22/750], Combined Loss: 0.0115
# Epoch [23/750], Combined Loss: 0.0100
# Epoch [24/750], Combined Loss: 0.0112
# Epoch [25/750], Combined Loss: 0.0108
# Epoch [26/750], Combined Loss: 0.0106
# Epoch [27/750], Combined Loss: 0.0104
# Epoch [28/750], Combined Loss: 0.0112
# Epoch [29/750], Combined Loss: 0.0100
# Epoch [30/750], Combined Loss: 0.0105
# Epoch [31/750], Combined Loss: 0.0099
# Epoch [32/750], Combined Loss: 0.0086
# Epoch [33/750], Combined Loss: 0.0106
# Epoch [34/750], Combined Loss: 0.0113
# Epoch [35/750], Combined Loss: 0.0097
# Epoch [36/750], Combined Loss: 0.0108
# Epoch [37/750], Combined Loss: 0.0110
# Epoch [38/750], Combined Loss: 0.0122
# Epoch [39/750], Combined Loss: 0.0100
# Epoch [40/750], Combined Loss: 0.0105
# Epoch [41/750], Combined Loss: 0.0101
# Epoch [42/750], Combined Loss: 0.0126
# Epoch [43/750], Combined Loss: 0.0094
# Epoch [44/750], Combined Loss: 0.0106
# Epoch [45/750], Combined Loss: 0.0108
# Epoch [46/750], Combined Loss: 0.0087
# Epoch [47/750], Combined Loss: 0.0110
# Epoch [48/750], Combined Loss: 0.0103
# Epoch [49/750], Combined Loss: 0.0121
# Epoch [50/750], Combined Loss: 0.0128
# Epoch [51/750], Combined Loss: 0.0097
# Epoch [52/750], Combined Loss: 0.0098
# Epoch [53/750], Combined Loss: 0.0103
# Epoch [54/750], Combined Loss: 0.0140
# Epoch [55/750], Combined Loss: 0.0100
# Epoch [56/750], Combined Loss: 0.0119
# Epoch [57/750], Combined Loss: 0.0102
# Epoch [58/750], Combined Loss: 0.0104
# Epoch [59/750], Combined Loss: 0.0102
# Epoch [60/750], Combined Loss: 0.0101
# Epoch [61/750], Combined Loss: 0.0065
# Epoch [62/750], Combined Loss: 0.0075
# Epoch [63/750], Combined Loss: 0.0051
# Epoch [64/750], Combined Loss: 0.0057
# Epoch [65/750], Combined Loss: 0.0060
# Epoch [66/750], Combined Loss: 0.0056
# Epoch [67/750], Combined Loss: 0.0083
# Epoch [68/750], Combined Loss: 0.0057
# Epoch [69/750], Combined Loss: 0.0063
# Epoch [70/750], Combined Loss: 0.0055
# Epoch [71/750], Combined Loss: 0.0055
# Epoch [72/750], Combined Loss: 0.0058
# Epoch [73/750], Combined Loss: 0.0064
# Epoch [74/750], Combined Loss: 0.0062
# Epoch [75/750], Combined Loss: 0.0057
# Epoch [76/750], Combined Loss: 0.0074
# Epoch [77/750], Combined Loss: 0.0066
# Epoch [78/750], Combined Loss: 0.0059
# Epoch [79/750], Combined Loss: 0.0065
# Epoch [80/750], Combined Loss: 0.0075
# Epoch [81/750], Combined Loss: 0.0068
# Epoch [82/750], Combined Loss: 0.0062
# Epoch [83/750], Combined Loss: 0.0057
# Epoch [84/750], Combined Loss: 0.0080
# Epoch [85/750], Combined Loss: 0.0051
# Epoch [86/750], Combined Loss: 0.0061
# Epoch [87/750], Combined Loss: 0.0069
# Epoch [88/750], Combined Loss: 0.0068
# Epoch [89/750], Combined Loss: 0.0077
# Epoch [90/750], Combined Loss: 0.0066
# Epoch [91/750], Combined Loss: 0.0079
# Epoch [92/750], Combined Loss: 0.0070
# Epoch [93/750], Combined Loss: 0.0078
# Epoch [94/750], Combined Loss: 0.0068
# Epoch [95/750], Combined Loss: 0.0060
# Epoch [96/750], Combined Loss: 0.0066
# Epoch [97/750], Combined Loss: 0.0061
# Epoch [98/750], Combined Loss: 0.0064
# Epoch [99/750], Combined Loss: 0.0060
# Epoch [100/750], Combined Loss: 0.0059
# Epoch [101/750], Combined Loss: 0.0061
# Epoch [102/750], Combined Loss: 0.0058
# Epoch [103/750], Combined Loss: 0.0068
# Early stopping triggered.
# Trial 5 - MSE: 0.0022, MAE: 0.0344, REE: 0.0451, Euclidean Distance: 0.1430
# Starting trial 6...
# Epoch [1/750], Combined Loss: 0.0274
# Epoch [2/750], Combined Loss: 0.0194
# Epoch [3/750], Combined Loss: 0.0177
# Epoch [4/750], Combined Loss: 0.0165
# Epoch [5/750], Combined Loss: 0.0182
# Epoch [6/750], Combined Loss: 0.0191
# Epoch [7/750], Combined Loss: 0.0165
# Epoch [8/750], Combined Loss: 0.0156
# Epoch [9/750], Combined Loss: 0.0167
# Epoch [10/750], Combined Loss: 0.0134
# Epoch [11/750], Combined Loss: 0.0122
# Epoch [12/750], Combined Loss: 0.0122
# Epoch [13/750], Combined Loss: 0.0099
# Epoch [14/750], Combined Loss: 0.0105
# Epoch [15/750], Combined Loss: 0.0094
# Epoch [16/750], Combined Loss: 0.0111
# Epoch [17/750], Combined Loss: 0.0105
# Epoch [18/750], Combined Loss: 0.0115
# Epoch [19/750], Combined Loss: 0.0096
# Epoch [20/750], Combined Loss: 0.0095
# Epoch [21/750], Combined Loss: 0.0112
# Epoch [22/750], Combined Loss: 0.0110
# Epoch [23/750], Combined Loss: 0.0095
# Epoch [24/750], Combined Loss: 0.0098
# Epoch [25/750], Combined Loss: 0.0118
# Epoch [26/750], Combined Loss: 0.0117
# Epoch [27/750], Combined Loss: 0.0106
# Epoch [28/750], Combined Loss: 0.0134
# Epoch [29/750], Combined Loss: 0.0111
# Epoch [30/750], Combined Loss: 0.0107
# Epoch [31/750], Combined Loss: 0.0118
# Epoch [32/750], Combined Loss: 0.0120
# Epoch [33/750], Combined Loss: 0.0109
# Epoch [34/750], Combined Loss: 0.0115
# Epoch [35/750], Combined Loss: 0.0125
# Epoch [36/750], Combined Loss: 0.0091
# Epoch [37/750], Combined Loss: 0.0092
# Epoch [38/750], Combined Loss: 0.0127
# Epoch [39/750], Combined Loss: 0.0098
# Epoch [40/750], Combined Loss: 0.0114
# Epoch [41/750], Combined Loss: 0.0115
# Epoch [42/750], Combined Loss: 0.0113
# Epoch [43/750], Combined Loss: 0.0124
# Epoch [44/750], Combined Loss: 0.0140
# Epoch [45/750], Combined Loss: 0.0132
# Epoch [46/750], Combined Loss: 0.0105
# Epoch [47/750], Combined Loss: 0.0084
# Epoch [48/750], Combined Loss: 0.0099
# Epoch [49/750], Combined Loss: 0.0095
# Epoch [50/750], Combined Loss: 0.0070
# Epoch [51/750], Combined Loss: 0.0098
# Epoch [52/750], Combined Loss: 0.0077
# Epoch [53/750], Combined Loss: 0.0073
# Epoch [54/750], Combined Loss: 0.0053
# Epoch [55/750], Combined Loss: 0.0062
# Epoch [56/750], Combined Loss: 0.0058
# Epoch [57/750], Combined Loss: 0.0062
# Epoch [58/750], Combined Loss: 0.0048
# Epoch [59/750], Combined Loss: 0.0057
# Epoch [60/750], Combined Loss: 0.0050
# Epoch [61/750], Combined Loss: 0.0051
# Epoch [62/750], Combined Loss: 0.0057
# Epoch [63/750], Combined Loss: 0.0046
# Epoch [64/750], Combined Loss: 0.0053
# Epoch [65/750], Combined Loss: 0.0052
# Epoch [66/750], Combined Loss: 0.0056
# Epoch [67/750], Combined Loss: 0.0058
# Epoch [68/750], Combined Loss: 0.0061
# Epoch [69/750], Combined Loss: 0.0068
# Epoch [70/750], Combined Loss: 0.0088
# Epoch [71/750], Combined Loss: 0.0057
# Epoch [72/750], Combined Loss: 0.0071
# Epoch [73/750], Combined Loss: 0.0047
# Epoch [74/750], Combined Loss: 0.0050
# Epoch [75/750], Combined Loss: 0.0054
# Epoch [76/750], Combined Loss: 0.0054
# Epoch [77/750], Combined Loss: 0.0051
# Epoch [78/750], Combined Loss: 0.0040
# Epoch [79/750], Combined Loss: 0.0061
# Epoch [80/750], Combined Loss: 0.0065
# Epoch [81/750], Combined Loss: 0.0048
# Epoch [82/750], Combined Loss: 0.0055
# Epoch [83/750], Combined Loss: 0.0044
# Epoch [84/750], Combined Loss: 0.0053
# Epoch [85/750], Combined Loss: 0.0049
# Epoch [86/750], Combined Loss: 0.0049
# Epoch [87/750], Combined Loss: 0.0041
# Epoch [88/750], Combined Loss: 0.0046
# Epoch [89/750], Combined Loss: 0.0047
# Epoch [90/750], Combined Loss: 0.0049
# Epoch [91/750], Combined Loss: 0.0041
# Epoch [92/750], Combined Loss: 0.0045
# Epoch [93/750], Combined Loss: 0.0054
# Epoch [94/750], Combined Loss: 0.0045
# Epoch [95/750], Combined Loss: 0.0044
# Epoch [96/750], Combined Loss: 0.0050
# Epoch [97/750], Combined Loss: 0.0040
# Epoch [98/750], Combined Loss: 0.0081
# Epoch [99/750], Combined Loss: 0.0051
# Epoch [100/750], Combined Loss: 0.0047
# Epoch [101/750], Combined Loss: 0.0045
# Epoch [102/750], Combined Loss: 0.0050
# Epoch [103/750], Combined Loss: 0.0047
# Epoch [104/750], Combined Loss: 0.0045
# Epoch [105/750], Combined Loss: 0.0045
# Epoch [106/750], Combined Loss: 0.0046
# Epoch [107/750], Combined Loss: 0.0045
# Epoch [108/750], Combined Loss: 0.0052
# Epoch [109/750], Combined Loss: 0.0046
# Epoch [110/750], Combined Loss: 0.0045
# Epoch [111/750], Combined Loss: 0.0040
# Epoch [112/750], Combined Loss: 0.0041
# Epoch [113/750], Combined Loss: 0.0043
# Epoch [114/750], Combined Loss: 0.0040
# Epoch [115/750], Combined Loss: 0.0059
# Epoch [116/750], Combined Loss: 0.0052
# Epoch [117/750], Combined Loss: 0.0047
# Epoch [118/750], Combined Loss: 0.0055
# Epoch [119/750], Combined Loss: 0.0050
# Epoch [120/750], Combined Loss: 0.0039
# Epoch [121/750], Combined Loss: 0.0049
# Epoch [122/750], Combined Loss: 0.0042
# Epoch [123/750], Combined Loss: 0.0040
# Epoch [124/750], Combined Loss: 0.0044
# Epoch [125/750], Combined Loss: 0.0048
# Epoch [126/750], Combined Loss: 0.0092
# Epoch [127/750], Combined Loss: 0.0065
# Epoch [128/750], Combined Loss: 0.0054
# Epoch [129/750], Combined Loss: 0.0046
# Epoch [130/750], Combined Loss: 0.0047
# Epoch [131/750], Combined Loss: 0.0049
# Epoch [132/750], Combined Loss: 0.0047
# Epoch [133/750], Combined Loss: 0.0046
# Epoch [134/750], Combined Loss: 0.0047
# Epoch [135/750], Combined Loss: 0.0041
# Epoch [136/750], Combined Loss: 0.0048
# Epoch [137/750], Combined Loss: 0.0051
# Epoch [138/750], Combined Loss: 0.0051
# Epoch [139/750], Combined Loss: 0.0048
# Epoch [140/750], Combined Loss: 0.0046
# Epoch [141/750], Combined Loss: 0.0050
# Epoch [142/750], Combined Loss: 0.0055
# Epoch [143/750], Combined Loss: 0.0056
# Epoch [144/750], Combined Loss: 0.0076
# Epoch [145/750], Combined Loss: 0.0052
# Epoch [146/750], Combined Loss: 0.0041
# Epoch [147/750], Combined Loss: 0.0049
# Epoch [148/750], Combined Loss: 0.0044
# Epoch [149/750], Combined Loss: 0.0050
# Epoch [150/750], Combined Loss: 0.0047
# Epoch [151/750], Combined Loss: 0.0051
# Epoch [152/750], Combined Loss: 0.0044
# Epoch [153/750], Combined Loss: 0.0043
# Epoch [154/750], Combined Loss: 0.0045
# Epoch [155/750], Combined Loss: 0.0049
# Epoch [156/750], Combined Loss: 0.0048
# Epoch [157/750], Combined Loss: 0.0041
# Epoch [158/750], Combined Loss: 0.0045
# Epoch [159/750], Combined Loss: 0.0040
# Epoch [160/750], Combined Loss: 0.0047
# Early stopping triggered.
# Trial 6 - MSE: 0.0011, MAE: 0.0205, REE: 0.0299, Euclidean Distance: 0.0946
# Starting trial 7...
# Epoch [1/750], Combined Loss: 0.0572
# Epoch [2/750], Combined Loss: 0.0190
# Epoch [3/750], Combined Loss: 0.0170
# Epoch [4/750], Combined Loss: 0.0164
# Epoch [5/750], Combined Loss: 0.0159
# Epoch [6/750], Combined Loss: 0.0167
# Epoch [7/750], Combined Loss: 0.0171
# Epoch [8/750], Combined Loss: 0.0154
# Epoch [9/750], Combined Loss: 0.0208
# Epoch [10/750], Combined Loss: 0.0139
# Epoch [11/750], Combined Loss: 0.0128
# Epoch [12/750], Combined Loss: 0.0122
# Epoch [13/750], Combined Loss: 0.0092
# Epoch [14/750], Combined Loss: 0.0096
# Epoch [15/750], Combined Loss: 0.0113
# Epoch [16/750], Combined Loss: 0.0092
# Epoch [17/750], Combined Loss: 0.0097
# Epoch [18/750], Combined Loss: 0.0100
# Epoch [19/750], Combined Loss: 0.0099
# Epoch [20/750], Combined Loss: 0.0107
# Epoch [21/750], Combined Loss: 0.0105
# Epoch [22/750], Combined Loss: 0.0112
# Epoch [23/750], Combined Loss: 0.0104
# Epoch [24/750], Combined Loss: 0.0105
# Epoch [25/750], Combined Loss: 0.0082
# Epoch [26/750], Combined Loss: 0.0111
# Epoch [27/750], Combined Loss: 0.0108
# Epoch [28/750], Combined Loss: 0.0137
# Epoch [29/750], Combined Loss: 0.0126
# Epoch [30/750], Combined Loss: 0.0093
# Epoch [31/750], Combined Loss: 0.0098
# Epoch [32/750], Combined Loss: 0.0112
# Epoch [33/750], Combined Loss: 0.0119
# Epoch [34/750], Combined Loss: 0.0118
# Epoch [35/750], Combined Loss: 0.0110
# Epoch [36/750], Combined Loss: 0.0110
# Epoch [37/750], Combined Loss: 0.0121
# Epoch [38/750], Combined Loss: 0.0096
# Epoch [39/750], Combined Loss: 0.0088
# Epoch [40/750], Combined Loss: 0.0104
# Epoch [41/750], Combined Loss: 0.0089
# Epoch [42/750], Combined Loss: 0.0094
# Epoch [43/750], Combined Loss: 0.0103
# Epoch [44/750], Combined Loss: 0.0100
# Epoch [45/750], Combined Loss: 0.0085
# Epoch [46/750], Combined Loss: 0.0086
# Epoch [47/750], Combined Loss: 0.0101
# Epoch [48/750], Combined Loss: 0.0075
# Epoch [49/750], Combined Loss: 0.0063
# Epoch [50/750], Combined Loss: 0.0058
# Epoch [51/750], Combined Loss: 0.0054
# Epoch [52/750], Combined Loss: 0.0049
# Epoch [53/750], Combined Loss: 0.0047
# Epoch [54/750], Combined Loss: 0.0051
# Epoch [55/750], Combined Loss: 0.0047
# Epoch [56/750], Combined Loss: 0.0050
# Epoch [57/750], Combined Loss: 0.0042
# Epoch [58/750], Combined Loss: 0.0051
# Epoch [59/750], Combined Loss: 0.0060
# Epoch [60/750], Combined Loss: 0.0051
# Epoch [61/750], Combined Loss: 0.0044
# Epoch [62/750], Combined Loss: 0.0044
# Epoch [63/750], Combined Loss: 0.0052
# Epoch [64/750], Combined Loss: 0.0056
# Epoch [65/750], Combined Loss: 0.0057
# Epoch [66/750], Combined Loss: 0.0048
# Epoch [67/750], Combined Loss: 0.0052
# Epoch [68/750], Combined Loss: 0.0064
# Epoch [69/750], Combined Loss: 0.0055
# Epoch [70/750], Combined Loss: 0.0068
# Epoch [71/750], Combined Loss: 0.0060
# Epoch [72/750], Combined Loss: 0.0063
# Epoch [73/750], Combined Loss: 0.0056
# Epoch [74/750], Combined Loss: 0.0069
# Epoch [75/750], Combined Loss: 0.0071
# Epoch [76/750], Combined Loss: 0.0061
# Epoch [77/750], Combined Loss: 0.0072
# Epoch [78/750], Combined Loss: 0.0067
# Epoch [79/750], Combined Loss: 0.0081
# Epoch [80/750], Combined Loss: 0.0064
# Epoch [81/750], Combined Loss: 0.0076
# Epoch [82/750], Combined Loss: 0.0069
# Epoch [83/750], Combined Loss: 0.0071
# Epoch [84/750], Combined Loss: 0.0086
# Epoch [85/750], Combined Loss: 0.0092
# Epoch [86/750], Combined Loss: 0.0067
# Epoch [87/750], Combined Loss: 0.0085
# Epoch [88/750], Combined Loss: 0.0086
# Epoch [89/750], Combined Loss: 0.0078
# Epoch [90/750], Combined Loss: 0.0080
# Epoch [91/750], Combined Loss: 0.0085
# Epoch [92/750], Combined Loss: 0.0111
# Epoch [93/750], Combined Loss: 0.0082
# Epoch [94/750], Combined Loss: 0.0090
# Epoch [95/750], Combined Loss: 0.0068
# Epoch [96/750], Combined Loss: 0.0080
# Epoch [97/750], Combined Loss: 0.0094
# Early stopping triggered.
# Trial 7 - MSE: 0.0043, MAE: 0.0469, REE: 0.0677, Euclidean Distance: 0.2111
# Starting trial 8...
# Epoch [1/750], Combined Loss: 0.0495
# Epoch [2/750], Combined Loss: 0.0191
# Epoch [3/750], Combined Loss: 0.0168
# Epoch [4/750], Combined Loss: 0.0152
# Epoch [5/750], Combined Loss: 0.0153
# Epoch [6/750], Combined Loss: 0.0144
# Epoch [7/750], Combined Loss: 0.0144
# Epoch [8/750], Combined Loss: 0.0120
# Epoch [9/750], Combined Loss: 0.0102
# Epoch [10/750], Combined Loss: 0.0116
# Epoch [11/750], Combined Loss: 0.0113
# Epoch [12/750], Combined Loss: 0.0104
# Epoch [13/750], Combined Loss: 0.0105
# Epoch [14/750], Combined Loss: 0.0113
# Epoch [15/750], Combined Loss: 0.0116
# Epoch [16/750], Combined Loss: 0.0119
# Epoch [17/750], Combined Loss: 0.0109
# Epoch [18/750], Combined Loss: 0.0098
# Epoch [19/750], Combined Loss: 0.0097
# Epoch [20/750], Combined Loss: 0.0092
# Epoch [21/750], Combined Loss: 0.0107
# Epoch [22/750], Combined Loss: 0.0129
# Epoch [23/750], Combined Loss: 0.0117
# Epoch [24/750], Combined Loss: 0.0087
# Epoch [25/750], Combined Loss: 0.0133
# Epoch [26/750], Combined Loss: 0.0117
# Epoch [27/750], Combined Loss: 0.0103
# Epoch [28/750], Combined Loss: 0.0115
# Epoch [29/750], Combined Loss: 0.0125
# Epoch [30/750], Combined Loss: 0.0105
# Epoch [31/750], Combined Loss: 0.0104
# Epoch [32/750], Combined Loss: 0.0124
# Epoch [33/750], Combined Loss: 0.0112
# Epoch [34/750], Combined Loss: 0.0132
# Epoch [35/750], Combined Loss: 0.0111
# Epoch [36/750], Combined Loss: 0.0119
# Epoch [37/750], Combined Loss: 0.0111
# Epoch [38/750], Combined Loss: 0.0125
# Epoch [39/750], Combined Loss: 0.0170
# Epoch [40/750], Combined Loss: 0.0102
# Epoch [41/750], Combined Loss: 0.0116
# Epoch [42/750], Combined Loss: 0.0182
# Epoch [43/750], Combined Loss: 0.0125
# Epoch [44/750], Combined Loss: 0.0133
# Epoch [45/750], Combined Loss: 0.0145
# Epoch [46/750], Combined Loss: 0.0125
# Epoch [47/750], Combined Loss: 0.0172
# Epoch [48/750], Combined Loss: 0.0138
# Epoch [49/750], Combined Loss: 0.0141
# Epoch [50/750], Combined Loss: 0.0127
# Epoch [51/750], Combined Loss: 0.0148
# Epoch [52/750], Combined Loss: 0.0178
# Epoch [53/750], Combined Loss: 0.0136
# Epoch [54/750], Combined Loss: 0.0143
# Epoch [55/750], Combined Loss: 0.0139
# Epoch [56/750], Combined Loss: 0.0134
# Epoch [57/750], Combined Loss: 0.0139
# Epoch [58/750], Combined Loss: 0.0122
# Epoch [59/750], Combined Loss: 0.0128
# Epoch [60/750], Combined Loss: 0.0131
# Epoch [61/750], Combined Loss: 0.0124
# Epoch [62/750], Combined Loss: 0.0141
# Epoch [63/750], Combined Loss: 0.0127
# Epoch [64/750], Combined Loss: 0.0166
# Early stopping triggered.
# Trial 8 - MSE: 0.0107, MAE: 0.0858, REE: 0.1055, Euclidean Distance: 0.3331
# Starting trial 9...
# Epoch [1/750], Combined Loss: 0.0550
# Epoch [2/750], Combined Loss: 0.0198
# Epoch [3/750], Combined Loss: 0.0181
# Epoch [4/750], Combined Loss: 0.0179
# Epoch [5/750], Combined Loss: 0.0174
# Epoch [6/750], Combined Loss: 0.0154
# Epoch [7/750], Combined Loss: 0.0151
# Epoch [8/750], Combined Loss: 0.0165
# Epoch [9/750], Combined Loss: 0.0120
# Epoch [10/750], Combined Loss: 0.0097
# Epoch [11/750], Combined Loss: 0.0107
# Epoch [12/750], Combined Loss: 0.0113
# Epoch [13/750], Combined Loss: 0.0112
# Epoch [14/750], Combined Loss: 0.0106
# Epoch [15/750], Combined Loss: 0.0102
# Epoch [16/750], Combined Loss: 0.0107
# Epoch [17/750], Combined Loss: 0.0107
# Epoch [18/750], Combined Loss: 0.0099
# Epoch [19/750], Combined Loss: 0.0116
# Epoch [20/750], Combined Loss: 0.0099
# Epoch [21/750], Combined Loss: 0.0100
# Epoch [22/750], Combined Loss: 0.0106
# Epoch [23/750], Combined Loss: 0.0086
# Epoch [24/750], Combined Loss: 0.0092
# Epoch [25/750], Combined Loss: 0.0110
# Epoch [26/750], Combined Loss: 0.0107
# Epoch [27/750], Combined Loss: 0.0105
# Epoch [28/750], Combined Loss: 0.0115
# Epoch [29/750], Combined Loss: 0.0091
# Epoch [30/750], Combined Loss: 0.0100
# Epoch [31/750], Combined Loss: 0.0103
# Epoch [32/750], Combined Loss: 0.0116
# Epoch [33/750], Combined Loss: 0.0113
# Epoch [34/750], Combined Loss: 0.0078
# Epoch [35/750], Combined Loss: 0.0086
# Epoch [36/750], Combined Loss: 0.0090
# Epoch [37/750], Combined Loss: 0.0091
# Epoch [38/750], Combined Loss: 0.0081
# Epoch [39/750], Combined Loss: 0.0086
# Epoch [40/750], Combined Loss: 0.0053
# Epoch [41/750], Combined Loss: 0.0079
# Epoch [42/750], Combined Loss: 0.0064
# Epoch [43/750], Combined Loss: 0.0066
# Epoch [44/750], Combined Loss: 0.0059
# Epoch [45/750], Combined Loss: 0.0049
# Epoch [46/750], Combined Loss: 0.0045
# Epoch [47/750], Combined Loss: 0.0050
# Epoch [48/750], Combined Loss: 0.0044
# Epoch [49/750], Combined Loss: 0.0046
# Epoch [50/750], Combined Loss: 0.0043
# Epoch [51/750], Combined Loss: 0.0051
# Epoch [52/750], Combined Loss: 0.0054
# Epoch [53/750], Combined Loss: 0.0044
# Epoch [54/750], Combined Loss: 0.0044
# Epoch [55/750], Combined Loss: 0.0048
# Epoch [56/750], Combined Loss: 0.0043
# Epoch [57/750], Combined Loss: 0.0044
# Epoch [58/750], Combined Loss: 0.0045
# Epoch [59/750], Combined Loss: 0.0050
# Epoch [60/750], Combined Loss: 0.0047
# Epoch [61/750], Combined Loss: 0.0055
# Epoch [62/750], Combined Loss: 0.0039
# Epoch [63/750], Combined Loss: 0.0060
# Epoch [64/750], Combined Loss: 0.0049
# Epoch [65/750], Combined Loss: 0.0065
# Epoch [66/750], Combined Loss: 0.0058
# Epoch [67/750], Combined Loss: 0.0066
# Epoch [68/750], Combined Loss: 0.0052
# Epoch [69/750], Combined Loss: 0.0064
# Epoch [70/750], Combined Loss: 0.0058
# Epoch [71/750], Combined Loss: 0.0077
# Epoch [72/750], Combined Loss: 0.0070
# Epoch [73/750], Combined Loss: 0.0058
# Epoch [74/750], Combined Loss: 0.0058
# Epoch [75/750], Combined Loss: 0.0055
# Epoch [76/750], Combined Loss: 0.0050
# Epoch [77/750], Combined Loss: 0.0055
# Epoch [78/750], Combined Loss: 0.0053
# Epoch [79/750], Combined Loss: 0.0049
# Epoch [80/750], Combined Loss: 0.0057
# Epoch [81/750], Combined Loss: 0.0046
# Epoch [82/750], Combined Loss: 0.0046
# Epoch [83/750], Combined Loss: 0.0048
# Epoch [84/750], Combined Loss: 0.0044
# Epoch [85/750], Combined Loss: 0.0046
# Epoch [86/750], Combined Loss: 0.0059
# Epoch [87/750], Combined Loss: 0.0054
# Epoch [88/750], Combined Loss: 0.0049
# Epoch [89/750], Combined Loss: 0.0046
# Epoch [90/750], Combined Loss: 0.0046
# Epoch [91/750], Combined Loss: 0.0061
# Epoch [92/750], Combined Loss: 0.0049
# Epoch [93/750], Combined Loss: 0.0050
# Epoch [94/750], Combined Loss: 0.0047
# Epoch [95/750], Combined Loss: 0.0051
# Epoch [96/750], Combined Loss: 0.0050
# Epoch [97/750], Combined Loss: 0.0045
# Epoch [98/750], Combined Loss: 0.0042
# Epoch [99/750], Combined Loss: 0.0046
# Epoch [100/750], Combined Loss: 0.0051
# Epoch [101/750], Combined Loss: 0.0039
# Epoch [102/750], Combined Loss: 0.0047
# Epoch [103/750], Combined Loss: 0.0044
# Epoch [104/750], Combined Loss: 0.0046
# Epoch [105/750], Combined Loss: 0.0044
# Epoch [106/750], Combined Loss: 0.0048
# Epoch [107/750], Combined Loss: 0.0047
# Epoch [108/750], Combined Loss: 0.0082
# Epoch [109/750], Combined Loss: 0.0050
# Epoch [110/750], Combined Loss: 0.0047
# Epoch [111/750], Combined Loss: 0.0051
# Epoch [112/750], Combined Loss: 0.0055
# Epoch [113/750], Combined Loss: 0.0061
# Epoch [114/750], Combined Loss: 0.0045
# Epoch [115/750], Combined Loss: 0.0049
# Epoch [116/750], Combined Loss: 0.0044
# Epoch [117/750], Combined Loss: 0.0046
# Epoch [118/750], Combined Loss: 0.0049
# Epoch [119/750], Combined Loss: 0.0048
# Epoch [120/750], Combined Loss: 0.0049
# Epoch [121/750], Combined Loss: 0.0043
# Epoch [122/750], Combined Loss: 0.0052
# Epoch [123/750], Combined Loss: 0.0052
# Epoch [124/750], Combined Loss: 0.0054
# Epoch [125/750], Combined Loss: 0.0046
# Epoch [126/750], Combined Loss: 0.0048
# Epoch [127/750], Combined Loss: 0.0050
# Epoch [128/750], Combined Loss: 0.0050
# Epoch [129/750], Combined Loss: 0.0055
# Epoch [130/750], Combined Loss: 0.0067
# Epoch [131/750], Combined Loss: 0.0057
# Epoch [132/750], Combined Loss: 0.0043
# Epoch [133/750], Combined Loss: 0.0054
# Epoch [134/750], Combined Loss: 0.0047
# Epoch [135/750], Combined Loss: 0.0043
# Epoch [136/750], Combined Loss: 0.0047
# Epoch [137/750], Combined Loss: 0.0046
# Epoch [138/750], Combined Loss: 0.0045
# Epoch [139/750], Combined Loss: 0.0049
# Epoch [140/750], Combined Loss: 0.0050
# Epoch [141/750], Combined Loss: 0.0054
# Early stopping triggered.
# Trial 9 - MSE: 0.0011, MAE: 0.0230, REE: 0.0322, Euclidean Distance: 0.1022
# Starting trial 10...
# Epoch [1/750], Combined Loss: 0.0505
# Epoch [2/750], Combined Loss: 0.0178
# Epoch [3/750], Combined Loss: 0.0185
# Epoch [4/750], Combined Loss: 0.0160
# Epoch [5/750], Combined Loss: 0.0182
# Epoch [6/750], Combined Loss: 0.0179
# Epoch [7/750], Combined Loss: 0.0176
# Epoch [8/750], Combined Loss: 0.0149
# Epoch [9/750], Combined Loss: 0.0149
# Epoch [10/750], Combined Loss: 0.0130
# Epoch [11/750], Combined Loss: 0.0111
# Epoch [12/750], Combined Loss: 0.0124
# Epoch [13/750], Combined Loss: 0.0111
# Epoch [14/750], Combined Loss: 0.0109
# Epoch [15/750], Combined Loss: 0.0112
# Epoch [16/750], Combined Loss: 0.0107
# Epoch [17/750], Combined Loss: 0.0093
# Epoch [18/750], Combined Loss: 0.0104
# Epoch [19/750], Combined Loss: 0.0118
# Epoch [20/750], Combined Loss: 0.0114
# Epoch [21/750], Combined Loss: 0.0100
# Epoch [22/750], Combined Loss: 0.0115
# Epoch [23/750], Combined Loss: 0.0130
# Epoch [24/750], Combined Loss: 0.0088
# Epoch [25/750], Combined Loss: 0.0110
# Epoch [26/750], Combined Loss: 0.0139
# Epoch [27/750], Combined Loss: 0.0148
# Epoch [28/750], Combined Loss: 0.0150
# Epoch [29/750], Combined Loss: 0.0140
# Epoch [30/750], Combined Loss: 0.0105
# Epoch [31/750], Combined Loss: 0.0095
# Epoch [32/750], Combined Loss: 0.0103
# Epoch [33/750], Combined Loss: 0.0112
# Epoch [34/750], Combined Loss: 0.0137
# Epoch [35/750], Combined Loss: 0.0113
# Epoch [36/750], Combined Loss: 0.0132
# Epoch [37/750], Combined Loss: 0.0142
# Epoch [38/750], Combined Loss: 0.0147
# Epoch [39/750], Combined Loss: 0.0165
# Epoch [40/750], Combined Loss: 0.0163
# Epoch [41/750], Combined Loss: 0.0116
# Epoch [42/750], Combined Loss: 0.0105
# Epoch [43/750], Combined Loss: 0.0143
# Epoch [44/750], Combined Loss: 0.0125
# Epoch [45/750], Combined Loss: 0.0143
# Epoch [46/750], Combined Loss: 0.0133
# Epoch [47/750], Combined Loss: 0.0131
# Epoch [48/750], Combined Loss: 0.0097
# Epoch [49/750], Combined Loss: 0.0112
# Epoch [50/750], Combined Loss: 0.0089
# Epoch [51/750], Combined Loss: 0.0107
# Epoch [52/750], Combined Loss: 0.0088
# Epoch [53/750], Combined Loss: 0.0062
# Epoch [54/750], Combined Loss: 0.0068
# Epoch [55/750], Combined Loss: 0.0065
# Epoch [56/750], Combined Loss: 0.0057
# Epoch [57/750], Combined Loss: 0.0064
# Epoch [58/750], Combined Loss: 0.0064
# Epoch [59/750], Combined Loss: 0.0055
# Epoch [60/750], Combined Loss: 0.0053
# Epoch [61/750], Combined Loss: 0.0052
# Epoch [62/750], Combined Loss: 0.0063
# Epoch [63/750], Combined Loss: 0.0060
# Epoch [64/750], Combined Loss: 0.0050
# Epoch [65/750], Combined Loss: 0.0057
# Epoch [66/750], Combined Loss: 0.0054
# Epoch [67/750], Combined Loss: 0.0055
# Epoch [68/750], Combined Loss: 0.0062
# Epoch [69/750], Combined Loss: 0.0059
# Epoch [70/750], Combined Loss: 0.0063
# Epoch [71/750], Combined Loss: 0.0075
# Epoch [72/750], Combined Loss: 0.0055
# Epoch [73/750], Combined Loss: 0.0057
# Epoch [74/750], Combined Loss: 0.0068
# Epoch [75/750], Combined Loss: 0.0066
# Epoch [76/750], Combined Loss: 0.0063
# Epoch [77/750], Combined Loss: 0.0055
# Epoch [78/750], Combined Loss: 0.0062
# Epoch [79/750], Combined Loss: 0.0060
# Epoch [80/750], Combined Loss: 0.0077
# Epoch [81/750], Combined Loss: 0.0056
# Epoch [82/750], Combined Loss: 0.0069
# Epoch [83/750], Combined Loss: 0.0068
# Epoch [84/750], Combined Loss: 0.0076
# Epoch [85/750], Combined Loss: 0.0074
# Epoch [86/750], Combined Loss: 0.0084
# Epoch [87/750], Combined Loss: 0.0079
# Epoch [88/750], Combined Loss: 0.0061
# Epoch [89/750], Combined Loss: 0.0064
# Epoch [90/750], Combined Loss: 0.0068
# Epoch [91/750], Combined Loss: 0.0069
# Epoch [92/750], Combined Loss: 0.0051
# Epoch [93/750], Combined Loss: 0.0062
# Epoch [94/750], Combined Loss: 0.0051
# Epoch [95/750], Combined Loss: 0.0061
# Epoch [96/750], Combined Loss: 0.0061
# Epoch [97/750], Combined Loss: 0.0061
# Epoch [98/750], Combined Loss: 0.0053
# Epoch [99/750], Combined Loss: 0.0060
# Epoch [100/750], Combined Loss: 0.0049
# Epoch [101/750], Combined Loss: 0.0054
# Epoch [102/750], Combined Loss: 0.0063
# Epoch [103/750], Combined Loss: 0.0056
# Epoch [104/750], Combined Loss: 0.0065
# Epoch [105/750], Combined Loss: 0.0052
# Epoch [106/750], Combined Loss: 0.0056
# Epoch [107/750], Combined Loss: 0.0059
# Epoch [108/750], Combined Loss: 0.0053
# Epoch [109/750], Combined Loss: 0.0052
# Epoch [110/750], Combined Loss: 0.0058
# Epoch [111/750], Combined Loss: 0.0051
# Epoch [112/750], Combined Loss: 0.0053
# Epoch [113/750], Combined Loss: 0.0054
# Epoch [114/750], Combined Loss: 0.0051
# Epoch [115/750], Combined Loss: 0.0051
# Epoch [116/750], Combined Loss: 0.0092
# Epoch [117/750], Combined Loss: 0.0060
# Epoch [118/750], Combined Loss: 0.0055
# Epoch [119/750], Combined Loss: 0.0059
# Epoch [120/750], Combined Loss: 0.0053
# Epoch [121/750], Combined Loss: 0.0054
# Epoch [122/750], Combined Loss: 0.0054
# Epoch [123/750], Combined Loss: 0.0052
# Epoch [124/750], Combined Loss: 0.0051
# Epoch [125/750], Combined Loss: 0.0056
# Epoch [126/750], Combined Loss: 0.0056
# Epoch [127/750], Combined Loss: 0.0052
# Epoch [128/750], Combined Loss: 0.0053
# Epoch [129/750], Combined Loss: 0.0048
# Epoch [130/750], Combined Loss: 0.0057
# Epoch [131/750], Combined Loss: 0.0051
# Epoch [132/750], Combined Loss: 0.0051
# Epoch [133/750], Combined Loss: 0.0051
# Epoch [134/750], Combined Loss: 0.0050
# Epoch [135/750], Combined Loss: 0.0050
# Epoch [136/750], Combined Loss: 0.0047
# Epoch [137/750], Combined Loss: 0.0049
# Epoch [138/750], Combined Loss: 0.0052
# Epoch [139/750], Combined Loss: 0.0051
# Epoch [140/750], Combined Loss: 0.0048
# Epoch [141/750], Combined Loss: 0.0047
# Epoch [142/750], Combined Loss: 0.0051
# Epoch [143/750], Combined Loss: 0.0053
# Epoch [144/750], Combined Loss: 0.0049
# Epoch [145/750], Combined Loss: 0.0047
# Epoch [146/750], Combined Loss: 0.0051
# Epoch [147/750], Combined Loss: 0.0047
# Epoch [148/750], Combined Loss: 0.0052
# Epoch [149/750], Combined Loss: 0.0049
# Epoch [150/750], Combined Loss: 0.0047
# Epoch [151/750], Combined Loss: 0.0048
# Epoch [152/750], Combined Loss: 0.0050
# Epoch [153/750], Combined Loss: 0.0061
# Epoch [154/750], Combined Loss: 0.0051
# Epoch [155/750], Combined Loss: 0.0047
# Epoch [156/750], Combined Loss: 0.0055
# Epoch [157/750], Combined Loss: 0.0048
# Epoch [158/750], Combined Loss: 0.0050
# Epoch [159/750], Combined Loss: 0.0050
# Epoch [160/750], Combined Loss: 0.0049
# Epoch [161/750], Combined Loss: 0.0051
# Epoch [162/750], Combined Loss: 0.0050
# Epoch [163/750], Combined Loss: 0.0051
# Epoch [164/750], Combined Loss: 0.0050
# Epoch [165/750], Combined Loss: 0.0052
# Epoch [166/750], Combined Loss: 0.0045
# Epoch [167/750], Combined Loss: 0.0047
# Epoch [168/750], Combined Loss: 0.0054
# Epoch [169/750], Combined Loss: 0.0046
# Epoch [170/750], Combined Loss: 0.0057
# Epoch [171/750], Combined Loss: 0.0049
# Epoch [172/750], Combined Loss: 0.0049
# Epoch [173/750], Combined Loss: 0.0046
# Epoch [174/750], Combined Loss: 0.0041
# Epoch [175/750], Combined Loss: 0.0048
# Epoch [176/750], Combined Loss: 0.0049
# Epoch [177/750], Combined Loss: 0.0045
# Epoch [178/750], Combined Loss: 0.0047
# Epoch [179/750], Combined Loss: 0.0053
# Epoch [180/750], Combined Loss: 0.0046
# Epoch [181/750], Combined Loss: 0.0048
# Epoch [182/750], Combined Loss: 0.0041
# Epoch [183/750], Combined Loss: 0.0050
# Epoch [184/750], Combined Loss: 0.0052
# Epoch [185/750], Combined Loss: 0.0050
# Epoch [186/750], Combined Loss: 0.0052
# Epoch [187/750], Combined Loss: 0.0048
# Epoch [188/750], Combined Loss: 0.0051
# Epoch [189/750], Combined Loss: 0.0048
# Epoch [190/750], Combined Loss: 0.0046
# Epoch [191/750], Combined Loss: 0.0056
# Epoch [192/750], Combined Loss: 0.0048
# Epoch [193/750], Combined Loss: 0.0046
# Epoch [194/750], Combined Loss: 0.0045
# Epoch [195/750], Combined Loss: 0.0047
# Epoch [196/750], Combined Loss: 0.0047
# Epoch [197/750], Combined Loss: 0.0047
# Epoch [198/750], Combined Loss: 0.0044
# Epoch [199/750], Combined Loss: 0.0051
# Epoch [200/750], Combined Loss: 0.0049
# Epoch [201/750], Combined Loss: 0.0042
# Epoch [202/750], Combined Loss: 0.0057
# Epoch [203/750], Combined Loss: 0.0053
# Epoch [204/750], Combined Loss: 0.0054
# Epoch [205/750], Combined Loss: 0.0050
# Epoch [206/750], Combined Loss: 0.0050
# Epoch [207/750], Combined Loss: 0.0045
# Epoch [208/750], Combined Loss: 0.0048
# Epoch [209/750], Combined Loss: 0.0045
# Epoch [210/750], Combined Loss: 0.0064
# Epoch [211/750], Combined Loss: 0.0054
# Epoch [212/750], Combined Loss: 0.0050
# Epoch [213/750], Combined Loss: 0.0053
# Epoch [214/750], Combined Loss: 0.0052
# Epoch [215/750], Combined Loss: 0.0053
# Epoch [216/750], Combined Loss: 0.0048
# Epoch [217/750], Combined Loss: 0.0050
# Epoch [218/750], Combined Loss: 0.0046
# Epoch [219/750], Combined Loss: 0.0052
# Epoch [220/750], Combined Loss: 0.0050
# Epoch [221/750], Combined Loss: 0.0052
# Epoch [222/750], Combined Loss: 0.0049
# Early stopping triggered.
# Trial 10 - MSE: 0.0015, MAE: 0.0238, REE: 0.0387, Euclidean Distance: 0.1219

# %%
num_trials = 10

# Create a 2x5 grid of subplots
fig, axes = plt.subplots(2, 5, figsize=(25, 10))
axes = axes.flatten()  # Flatten the 2D array of axes to 1D for easy indexing

# Plot Reconstruction Error Percentage
for trial in range(num_trials):
    ax = axes[trial]
    ax.scatter(range(len(error_percentages[trial])), error_percentages[trial], color='blue')
    ax.set_ylim(0, 200)
    ax.set_title(f'Reconstruction Error Percentage - Trial {trial+1}')
    ax.set_xlabel('Data Point')
    ax.set_ylabel('Error Percentage')

# Adjust layout
plt.tight_layout()
plt.show()

# %%
num_trials = 10

# Create a 2x5 grid of subplots
fig, axes = plt.subplots(2, 5, figsize=(25, 10))
axes = axes.flatten()  # Flatten the 2D array of axes to 1D for easy indexing

# Plot t-SNE Visualization
for trial in range(num_trials):
    ax = axes[trial]
    ax.scatter(t_sne_results[trial][:len(X_test), 0], t_sne_results[trial][:len(X_test), 1], label="Original", alpha=0.5)
    ax.scatter(t_sne_results[trial][len(X_test):, 0], t_sne_results[trial][len(X_test):, 1], label="Reconstructed", alpha=0.5)
    ax.legend()
    ax.set_title(f't-SNE Visualization - Trial {trial+1}')

# Adjust layout
plt.tight_layout()
plt.show()

# %%
num_trials = 10

# Create a 2x5 grid of subplots
fig, axes = plt.subplots(2, 5, figsize=(25, 10))
axes = axes.flatten()  # Flatten the 2D array of axes to 1D for easy indexing

# Plot PCA Projection
for trial in range(num_trials):
    ax = axes[trial]
    ax.scatter(pca_results[trial][:len(X_test), 0], pca_results[trial][:len(X_test), 1], label="Original", alpha=0.5)
    ax.scatter(pca_results[trial][len(X_test):, 0], pca_results[trial][len(X_test):, 1], label="Reconstructed", alpha=0.5)
    ax.legend()
    ax.set_title(f'PCA Projection - Trial {trial+1}')

# Adjust layout
plt.tight_layout()
plt.show()

# %%
count = 1

for result in metrics:
    print(f"Trial {count}")
    count += 1
    print("MSE:", result[0])
    print("MAE:", result[1])
    print("REE:", result[2])
    print("Euclidean Distance:", result[3])
    print()
# Out:
# Trial 1
# MSE: 0.0006842743660560177
# MAE: 0.01868967116541947
# REE: 0.025628505081196733
# Euclidean Distance: 0.08126969125187186
#
# Trial 2
# MSE: 0.0009054257346800033
# MAE: 0.02020705551153943
# REE: 0.02816249700700357
# Euclidean Distance: 0.08921111963682327
#
# Trial 3
# MSE: 0.0036974595873359743
# MAE: 0.04393339538476247
# REE: 0.06354847979415856
# Euclidean Distance: 0.19802922792035504
#
# Trial 4
# MSE: 0.001567259821587056
# MAE: 0.030726063101609833
# REE: 0.039261803320975265
# Euclidean Distance: 0.12354569897146725
#
# Trial 5
# MSE: 0.0021511393679667446
# MAE: 0.034352199069167616
# REE: 0.045142632525030736
# Euclidean Distance: 0.1429667747369127
#
# Trial 6
# MSE: 0.0010581385338681243
# MAE: 0.02046361530252578
# REE: 0.029887757195192502
# Euclidean Distance: 0.09463770109447033
#
# Trial 7
# MSE: 0.004265519970216209
# MAE: 0.04693637447964847
# REE: 0.0677056760721332
# Euclidean Distance: 0.21109576687593254
#
# Trial 8
# MSE: 0.010735183866904868
# MAE: 0.08584423038798526
# REE: 0.10554931729245126
# Euclidean Distance: 0.33306043960362514
#
# Trial 9
# MSE: 0.0011378816063169744
# MAE: 0.023007674539413246
# REE: 0.032216059576117874
# Euclidean Distance: 0.10215412814309074
#
# Trial 10
# MSE: 0.0014976363959652726
# MAE: 0.023784308590070843
# REE: 0.03867439435252626
# Euclidean Distance: 0.12189335389979976

# %%
# Calculate statistics for MSE, MAE, REE, and Euclidean error
metrics = np.array(metrics)
mse_mean = np.mean(metrics[:, 0])
mse_std = np.std(metrics[:, 0])
mae_mean = np.mean(metrics[:, 1])
mae_std = np.std(metrics[:, 1])
ree_mean = np.mean(metrics[:, 2])
ree_std = np.std(metrics[:, 2])
euclidean_mean = np.mean(metrics[:, 3])
euclidean_std = np.std(metrics[:, 3])
error_percentages_mean = np.mean([np.mean(error_percentage) for error_percentage in error_percentages])
error_percentages_std = np.std([np.mean(error_percentage) for error_percentage in error_percentages])


# Print statistics for MSE, MAE, REE, and Euclidean error
print("\n===== Additional Metrics Across 10 Trials =====")
print(f"Error Percentage Mean: {error_percentages_mean:.4f}% ± {error_percentages_std:.4f}%")
print(f"MSE Mean: {mse_mean:.4f} ± {mse_std:.4f}")
print(f"MAE Mean: {mae_mean:.4f} ± {mae_std:.4f}")
print(f"REE Mean: {ree_mean:.4f} ± {ree_std:.4f}")
print(f"Euclidean Mean: {euclidean_mean:.4f} ± {euclidean_std:.4f}")
# Out:
# ===== Additional Metrics Across 10 Trials =====
# Error Percentage Mean: 3.9090% ± 2.4684%
# MSE Mean: 0.0028 ± 0.0029
# MAE Mean: 0.0348 ± 0.0195
# REE Mean: 0.0476 ± 0.0236
# Euclidean Mean: 0.1498 ± 0.0741
