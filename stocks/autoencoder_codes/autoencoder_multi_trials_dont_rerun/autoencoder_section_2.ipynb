# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from sklearn.base import BaseEstimator, RegressorMixin

# %%
# Load the data
file_path = "SPY_section_2.csv"
df = pd.read_csv(file_path)

# start to nov 2001 (dot com crash)
# not bad
# df = df.iloc[:2228]

# nov 01 to june 2009
# not bad
# df = df.iloc[2228:4135]

# june 2009 to april 2020
# ass
# df = df.iloc[4135:6862]

# april 2020 to most recent
# ass
# df = df.iloc[6862:]


# Convert the "Date" column to datetime
# df["Date"] = pd.to_datetime(df["Date"], format='%Y/%m/%d')

# # Sort the data by date in ascending order
# df = df.sort_values(by="Date")

# # Get the earliest and latest dates
# earliest_date = df["Date"].min()
# latest_date = df["Date"].max()

# print("Earliest Date:", earliest_date)
# print("Latest Date:", latest_date)

# %%
# Adding SMA as part of the feature test
short_term_period = 20
medium_term_period = 50
long_term_period = 200

# Compute the SMAs
df['SMA_20'] = df['Close'].rolling(window=short_term_period).mean()
df['SMA_50'] = df['Close'].rolling(window=medium_term_period).mean()
df['SMA_200'] = df['Close'].rolling(window=long_term_period).mean()

df['EMA_10'] = df['Close'].ewm(span=10, adjust=False).mean()  # Short-term EMA
df['EMA_50'] = df['Close'].ewm(span=50, adjust=False).mean()  # Medium-term EMA
df['EMA_200'] = df['Close'].ewm(span=200, adjust=False).mean()  # Long-term EMA

df = df.dropna()

# %%
feature_columns = ["Open", "High", "Low", "Close", "Volume"]  
dates = df["Date"]
# if "Open" and "High" and "Low" and "Close" and "Volume" in df.columns:
#     df = df[feature_columns]

# %%
# scaler = StandardScaler()
# scaler = MinMaxScaler()
# feature_columns = ["Open", "High", "Low", "Close", "Volume", "Day", "Weekday", "Week", "Month", "Year"]
# feature_columns = ["Open", "High", "Low", "Close", "Volume", "SMA_20", "SMA_50", "SMA_200", "EMA_10", "EMA_50", "EMA_200", "Non_Linear_Trend"]
feature_columns = ["Open", "High", "Low", "Close", "Volume", "SMA_20", "SMA_50", "SMA_200", "EMA_10", "EMA_50", "EMA_200"]
# feature_columns = ["Open", "High", "Low", "Close", "Volume", "Non_Linear_Trend", "SMA_20", "SMA_50", "EMA_10", "EMA_50"]
# feature_columns = ["Open", "High", "Low", "Close", "Volume", "Non_Linear_Trend"]
# feature_columns = ["Open", "High", "Low", "Close", "Volume", "SMA_200", "EMA_10"]
X = df[feature_columns]

# Split data
train_size = int(X.shape[0] * 0.7)
val_size = int(X.shape[0] * 0.15)

# Initialize scaler
scaler = MinMaxScaler()
# scaler = RobustScaler()

# Split data into train, validation, and test
temp_train = X[:train_size]
temp_val = X[train_size:train_size + val_size]
temp_test = X[train_size + val_size:]

temp_train = temp_train[feature_columns]
temp_val = temp_val[feature_columns]
temp_test = temp_test[feature_columns]

# Fit and transform for train, transform for validation and test
temp_train = scaler.fit_transform(temp_train)
temp_val = scaler.transform(temp_val)
temp_test = scaler.transform(temp_test)

# Convert NumPy arrays back to DataFrames
temp_train = pd.DataFrame(temp_train, columns=feature_columns)
temp_val = pd.DataFrame(temp_val, columns=feature_columns)
temp_test = pd.DataFrame(temp_test, columns=feature_columns)

# Concatenate the data
X_scaled = pd.concat([temp_train, temp_val, temp_test], axis=0)

# Split sequentially
X_train = X_scaled[:train_size]
X_val = X_scaled[train_size:train_size + val_size]
X_test = X_scaled[train_size + val_size:]

# Print sizes to confirm
print(f"Train: {len(X_train)}, Val: {len(X_val)}, Test: {len(X_test)}")
# Out:
# Train: 1195, Val: 256, Test: 257

# %%
X_train = X_train.values
X_val = X_val.values
X_test = X_test.values

# %%
# Convert data to PyTorch tensors
X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
X_val_tensor = torch.tensor(X_val, dtype=torch.float32)
X_test_tensor = torch.tensor(X_test, dtype=torch.float32)

# Create DataLoader
train_dataset = TensorDataset(X_train_tensor, X_train_tensor)
val_dataset = TensorDataset(X_val_tensor, X_val_tensor)
test_dataset = TensorDataset(X_test_tensor, X_test_tensor)
train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=16, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=16, shuffle=False)

# %%
# # Check if CUDA is available and print the device being used
# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# print(f"Using device: {device}")

# class Encoder(nn.Module):
#     def __init__(self, input_dim, encoding_dim):
#         super(Encoder, self).__init__()
#         self.encoder = nn.Sequential(
#             nn.Linear(input_dim, 128),
#             nn.ReLU(),
#             nn.Dropout(0.2),
#             nn.Linear(128, 64),
#             nn.ReLU(),
#             nn.Dropout(0.2),
#             nn.Linear(64, encoding_dim)
#         )

#     def forward(self, x):
#         return self.encoder(x)

# class Decoder(nn.Module):
#     def __init__(self, encoding_dim, input_dim):
#         super(Decoder, self).__init__()
#         self.decoder = nn.Sequential(
#             nn.Linear(encoding_dim, 64),
#             nn.ReLU(),
#             nn.Dropout(0.2),
#             nn.Linear(64, 128),
#             nn.ReLU(),
#             nn.Dropout(0.2),
#             nn.Linear(128, input_dim)
#         )

#     def forward(self, x):
#         return self.decoder(x)

    
# # Define input dimensions
# input_dim = X_train.shape[1]

# # Model file paths
# encoder_model_file = './autoencoder_trials/encoder.pth'
# decoder_model_file = './autoencoder_trials/decoder.pth'

# # Hyperparameters
# encoding_dim = 8
# learning_rate = 0.001
# epochs = 50
# batch_size = 8
# patience = 5

# # Check if the model files exist
# if os.path.exists(encoder_model_file) and os.path.exists(decoder_model_file):
#     print("Model files exist. Loading the models...")
#     encoder = Encoder(input_dim, encoding_dim).to(device)
#     decoder = Decoder(encoding_dim, input_dim).to(device)
#     encoder.load_state_dict(torch.load(encoder_model_file))
#     decoder.load_state_dict(torch.load(decoder_model_file))
# else:
#     print("Model files do not exist. Training new models...")

#     # Initialize the encoder and decoder models
#     encoder = Encoder(input_dim, encoding_dim).to(device)
#     decoder = Decoder(encoding_dim, input_dim).to(device)
#     optimizer_encoder = optim.Adam(encoder.parameters(), lr=learning_rate)
#     optimizer_decoder = optim.Adam(decoder.parameters(), lr=learning_rate)
#     criterion = nn.MSELoss()

#     # Track training loss
#     encoder_losses = []
#     decoder_losses = []

#     # Train the Encoder separately
#     encoder.train()
#     best_val_loss = float('inf')
#     patience_counter = 0
#     for epoch in range(epochs):
#         epoch_loss = 0
#         dataloader = DataLoader(TensorDataset(torch.tensor(X_train, dtype=torch.float32).to(device), torch.tensor(X_train, dtype=torch.float32).to(device)), batch_size=batch_size, shuffle=True, num_workers=0)
#         for i, (batch_X, _) in enumerate(dataloader):
#             batch_X = batch_X.to(device)
#             optimizer_encoder.zero_grad()
#             encoded = encoder(batch_X)
#             # Pass the encoded output through the decoder
#             decoded = decoder(encoded)
#             # Calculate loss between decoder output and original input
#             loss = criterion(decoded, batch_X)
#             loss.backward()
            
#             optimizer_encoder.step()
#             optimizer_encoder.zero_grad()
            
#             epoch_loss += loss.item()
#         avg_loss = epoch_loss / len(dataloader)
#         encoder_losses.append(avg_loss)
#         print(f"Epoch [{epoch+1}/{epochs}], Encoder Loss: {avg_loss:.4f}")

#         # Validation loss
#         encoder.eval()
#         decoder.eval()
#         with torch.no_grad():
#             val_encoded = encoder(torch.tensor(X_val, dtype=torch.float32).to(device))
#             val_decoded = decoder(val_encoded)
#             val_loss = criterion(val_decoded, torch.tensor(X_val, dtype=torch.float32).to(device)).item()
#         print(f"Validation Loss: {val_loss:.4f}")

#         # Early stopping
#         if val_loss < best_val_loss:
#             best_val_loss = val_loss
#             patience_counter = 0
#         else:
#             patience_counter += 1
#             if patience_counter >= patience:
#                 print("Early stopping triggered.")
#                 break

#     # Train the Decoder separately
#     encoded_train = encoder(torch.tensor(X_train, dtype=torch.float32).to(device)).detach()
#     decoder.train()
#     best_val_loss = float('inf')
#     patience_counter = 0
#     for epoch in range(epochs):
#         epoch_loss = 0
#         dataloader = DataLoader(TensorDataset(encoded_train, torch.tensor(X_train, dtype=torch.float32).to(device)), batch_size=batch_size, shuffle=True, num_workers=0)
#         for i, (batch_X, batch_y) in enumerate(dataloader):
#             batch_X, batch_y = batch_X.to(device), batch_y.to(device)
#             optimizer_decoder.zero_grad()
#             outputs = decoder(batch_X)
#             # Calculate loss between decoder output and original input
#             loss = criterion(outputs, batch_y)
#             loss.backward()
            
#             optimizer_decoder.step()
#             optimizer_decoder.zero_grad()
            
#             epoch_loss += loss.item()
#         avg_loss = epoch_loss / len(dataloader)
#         decoder_losses.append(avg_loss)
#         print(f"Epoch [{epoch+1}/{epochs}], Decoder Loss: {avg_loss:.4f}")

#         # Validation loss
#         decoder.eval()
#         with torch.no_grad():
#             val_outputs = decoder(encoded_train)
#             val_loss = criterion(val_outputs, torch.tensor(X_train, dtype=torch.float32).to(device)).item()
#         print(f"Validation Loss: {val_loss:.4f}")

#         # Early stopping
#         if val_loss < best_val_loss:
#             best_val_loss = val_loss
#             patience_counter = 0
#         else:
#             patience_counter += 1
#             print("Early stopping counter:", patience_counter)
#             if patience_counter >= patience:
#                 print("Early stopping triggered.")
#                 break

#     # Save the trained models
#     os.makedirs('./autoencoder_trials', exist_ok=True)
#     # torch.save(encoder.state_dict(), encoder_model_file)
#     # torch.save(decoder.state_dict(), decoder_model_file)
#     print("Models trained and saved.")

# # Combine Encoder and Decoder to form the Autoencoder
# class Autoencoder(nn.Module):
#     def __init__(self, encoder, decoder):
#         super(Autoencoder, self).__init__()
#         self.encoder = encoder
#         self.decoder = decoder

#     def forward(self, x):
#         encoded = self.encoder(x)
#         decoded = self.decoder(encoded)
#         return decoded

# autoencoder = Autoencoder(encoder, decoder).to(device)
# autoencoder.eval()

# # Calculate reconstruction error on the test set
# with torch.no_grad():
#     reconstructed_test = autoencoder(torch.tensor(X_test, dtype=torch.float32).to(device)).cpu().numpy()

# # Calculate Mean Squared Error (MSE)
# mse = np.mean((X_test - reconstructed_test) ** 2)
# print(f'Mean Squared Error (MSE): {mse}')

# # Calculate Mean Absolute Error (MAE)
# mae = np.mean(np.abs(X_test - reconstructed_test))
# print(f'Mean Absolute Error (MAE): {mae}')

# # Calculate Reconstruction Error Percentage
# # reconstruction_error = np.mean(np.square(X_test - reconstructed_test), axis=1)
# # reconstruction_error_percentage = np.mean(reconstruction_error) * 100
# # print(f'Reconstruction Error Percentage: {reconstruction_error_percentage}')

# reconstruction_error_percentage = (
#     np.mean(np.abs(X_test - reconstructed_test) / (np.abs(X_test) + 1e-8), axis=1) * 100
# )
# reconstruction_error_percentage_mean = np.mean(reconstruction_error_percentage)
# print(f'Reconstruction Error Percentage: {reconstruction_error_percentage_mean}')

# def calculate_index_error_percentage(index, X, reconstructed_X):
#     print(np.mean(np.abs(X[index] - reconstructed_X[index]) / (np.abs(X[index]) + 1e-8)) * 100)

# %%
# # import os
# # import torch
# # import torch.nn as nn
# # import torch.optim as optim
# # import numpy as np
# # from torch.utils.data import DataLoader, TensorDataset

# # # Check if CUDA is available
# # device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# # print(f"Using device: {device}")

# # # Define Encoder
# # class Encoder(nn.Module):
# #     def __init__(self, input_dim, encoding_dim, dropout_rate):
# #         super(Encoder, self).__init__()
# #         self.encoder = nn.Sequential(
# #             nn.Linear(input_dim, 128),
# #             nn.ReLU(),
# #             nn.Dropout(dropout_rate),
# #             nn.Linear(128, 64),
# #             nn.ReLU(),
# #             nn.Dropout(dropout_rate),
# #             nn.Linear(64, encoding_dim)
# #         )

# #     def forward(self, x):
# #         return self.encoder(x)

# # # Define Decoder
# # class Decoder(nn.Module):
# #     def __init__(self, encoding_dim, input_dim, dropout_rate):
# #         super(Decoder, self).__init__()
# #         self.decoder = nn.Sequential(
# #             nn.Linear(encoding_dim, 64),
# #             nn.ReLU(),
# #             nn.Dropout(dropout_rate),
# #             nn.Linear(64, 128),
# #             nn.ReLU(),
# #             nn.Dropout(dropout_rate),
# #             nn.Linear(128, input_dim)
# #         )

# #     def forward(self, x):
# #         return self.decoder(x)

# # def relative_euclidean_error(X, X_reconstructed):
# #     return np.linalg.norm(X - X_reconstructed, axis=1) / np.linalg.norm(X, axis=1)

# # class RelativeEuclideanError(nn.Module):
# #     def forward(self, y_true, y_pred):
# #         return torch.mean(torch.norm(y_true - y_pred, dim=1) / torch.norm(y_true, dim=1))

# # # Define input dimensions
# # input_dim = X_train.shape[1]

# # # Model file paths
# # encoder_model_file = './autoencoder_trials/encoder.pth'
# # decoder_model_file = './autoencoder_trials/decoder.pth'

# # # Hyperparameters
# # encoding_dim = 5
# # learning_rate = 0.0001
# # dropout_rate = 0.0
# # epochs = 750
# # batch_size = 16
# # patience = 30

# # # Initialize models
# # encoder = Encoder(input_dim, encoding_dim, dropout_rate).to(device)
# # decoder = Decoder(encoding_dim, input_dim, dropout_rate).to(device)

# # # Define optimizers and loss function
# # optimizer_encoder = optim.Adam(encoder.parameters(), lr=learning_rate)
# # optimizer_decoder = optim.Adam(decoder.parameters(), lr=learning_rate)
# # # criterion = nn.MSELoss()
# # criterion = RelativeEuclideanError()
# # #use MAE
# # # criterion = nn.L1Loss()

# # # Add Gaussian noise to encoded representations to avoid overfitting
# # def add_noise(encoded, noise_factor=0.01):
# #     return encoded + noise_factor * torch.randn_like(encoded)

# # # Train Encoder
# # def train_encoder():
# #     print("Training Encoder...")
# #     encoder.train()
# #     best_val_loss = float('inf')
# #     patience_counter = 0
# #     # clip_value = 1

# #     for epoch in range(epochs):
# #         epoch_loss = 0
# #         dataloader = DataLoader(TensorDataset(torch.tensor(X_train, dtype=torch.float32).to(device), 
# #                                               torch.tensor(X_train, dtype=torch.float32).to(device)), 
# #                                 batch_size=batch_size, shuffle=True, num_workers=0)

# #         for batch_X, _ in dataloader:
# #             batch_X = batch_X.to(device)
# #             optimizer_encoder.zero_grad()
# #             encoded = encoder(batch_X)
# #             decoded = decoder(encoded)
# #             loss = criterion(decoded, batch_X)
# #             loss.backward()
            
# #             # torch.nn.utils.clip_grad_norm_(encoder.parameters(), max_norm=clip_value)  # Option 1
# #             # torch.nn.utils.clip_grad_value_(encoder.parameters(), clip_value=clip_value)  # Option 2

# #             optimizer_encoder.step()
# #             epoch_loss += loss.item()

# #         avg_loss = epoch_loss / len(dataloader)
# #         print(f"Epoch [{epoch+1}/{epochs}], Encoder Loss: {avg_loss:.4f}")

# #         # Validation loss
# #         encoder.eval()
# #         decoder.eval()
# #         with torch.no_grad():
# #             val_encoded = encoder(torch.tensor(X_val, dtype=torch.float32).to(device))
# #             val_decoded = decoder(val_encoded)
# #             val_loss = criterion(val_decoded, torch.tensor(X_val, dtype=torch.float32).to(device)).item()
# #         print(f"Validation Loss: {val_loss:.4f}")

# #         # Early stopping
# #         if val_loss < best_val_loss:
# #             best_val_loss = val_loss
# #             patience_counter = 0
# #             torch.save(encoder.state_dict(), encoder_model_file)  # Save best model
# #         else:
# #             patience_counter += 1
# #             print("Early stopping counter:", patience_counter)
# #             if patience_counter >= patience:
# #                 print("Early stopping triggered for encoder.")
# #                 break

# # # Train Decoder
# # def train_decoder():
# #     print("Training Decoder...")
# #     encoder.eval()
# #     encoded_train = encoder(torch.tensor(X_train, dtype=torch.float32).to(device)).detach()

# #     decoder.train()
# #     best_val_loss = float('inf')
# #     patience_counter = 0
# #     # clip_value = 1

# #     for epoch in range(epochs):
# #         epoch_loss = 0
# #         dataloader = DataLoader(TensorDataset(encoded_train, torch.tensor(X_train, dtype=torch.float32).to(device)), 
# #                                 batch_size=batch_size, shuffle=True, num_workers=0)

# #         for batch_X, batch_y in dataloader:
# #             batch_X, batch_y = batch_X.to(device), batch_y.to(device)
            
# #             # Add Gaussian noise
# #             noisy_batch_X = add_noise(batch_X)

# #             optimizer_decoder.zero_grad()
# #             outputs = decoder(noisy_batch_X)
# #             loss = criterion(outputs, batch_y)
# #             loss.backward()
            
# #             # torch.nn.utils.clip_grad_norm_(decoder.parameters(), max_norm=clip_value)  # Option 1
# #             # torch.nn.utils.clip_grad_value_(decoder.parameters(), clip_value=clip_value)  # Option 2
            
# #             optimizer_decoder.step()
            
# #             epoch_loss += loss.item()

# #         avg_loss = epoch_loss / len(dataloader)
# #         print(f"Epoch [{epoch+1}/{epochs}], Decoder Loss: {avg_loss:.4f}")

# #         # Validation loss
# #         decoder.eval()
# #         with torch.no_grad():
# #             val_encoded = encoder(torch.tensor(X_val, dtype=torch.float32).to(device))
# #             val_decoded = decoder(val_encoded)
# #             val_loss = criterion(val_decoded, torch.tensor(X_val, dtype=torch.float32).to(device)).item()
# #         print(f"Validation Loss: {val_loss:.4f}")

# #         # Early stopping
# #         if val_loss < best_val_loss:
# #             best_val_loss = val_loss
# #             patience_counter = 0
# #             torch.save(decoder.state_dict(), decoder_model_file)  # Save best model
# #         else:
# #             patience_counter += 1
# #             print("Early stopping counter:", patience_counter)
# #             if patience_counter >= patience:
# #                 print("Early stopping triggered for decoder.")
# #                 break

# # # Train models if files do not exist
# # if os.path.exists(encoder_model_file) and os.path.exists(decoder_model_file):
# #     print("Model files exist. Loading the models...")
# #     encoder.load_state_dict(torch.load(encoder_model_file))
# #     decoder.load_state_dict(torch.load(decoder_model_file))
# # else:
# #     os.makedirs('./autoencoder_trials', exist_ok=True)
# #     train_encoder()
# #     train_decoder()

# # # Combine Encoder and Decoder to form the Autoencoder
# # class Autoencoder(nn.Module):
# #     def __init__(self, encoder, decoder):
# #         super(Autoencoder, self).__init__()
# #         self.encoder = encoder
# #         self.decoder = decoder

# #     def forward(self, x):
# #         encoded = self.encoder(x)
# #         decoded = self.decoder(encoded)
# #         return decoded

# # # Load trained models
# # encoder.load_state_dict(torch.load(encoder_model_file))
# # decoder.load_state_dict(torch.load(decoder_model_file))
# # autoencoder = Autoencoder(encoder, decoder).to(device)
# # autoencoder.eval()

# # # Calculate reconstruction error on the test set
# # with torch.no_grad():
# #     reconstructed_test = autoencoder(torch.tensor(X_test, dtype=torch.float32).to(device)).cpu().numpy()

# # # Calculate Mean Squared Error (MSE)
# # mse = np.mean((X_test - reconstructed_test) ** 2)
# # print(f'Mean Squared Error (MSE): {mse}')

# # # Calculate Mean Absolute Error (MAE)
# # mae = np.mean(np.abs(X_test - reconstructed_test))
# # print(f'Mean Absolute Error (MAE): {mae}')

# # # Calculate Reconstruction Error Percentage
# # reconstruction_error_percentage = (
# #     np.mean(np.abs(X_test - reconstructed_test) / (np.abs(X_test) + 1e-8), axis=1) * 100
# # )
# # reconstruction_error_percentage_mean = np.mean(reconstruction_error_percentage)
# # print(f'Reconstruction Error Percentage: {reconstruction_error_percentage_mean:.4f}%')

# # def calculate_index_error_percentage(index, X, reconstructed_X):
# #     print(np.mean(np.abs(X[index] - reconstructed_X[index]) / (np.abs(X[index]) + 1e-8)) * 100)  


# import os
# import torch
# import torch.nn as nn
# import torch.optim as optim
# import numpy as np
# from torch.utils.data import DataLoader, TensorDataset

# # Check if CUDA is available
# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# print(f"Using device: {device}")

# # Define Autoencoder
# class Autoencoder(nn.Module):
#     def __init__(self, input_dim, encoding_dim, dropout_rate):
#         super(Autoencoder, self).__init__()
#         self.encoder = nn.Sequential(
#             nn.Linear(input_dim, 128),
#             nn.ReLU(),
#             nn.Dropout(dropout_rate),
#             nn.Linear(128, 64),
#             nn.ReLU(),
#             nn.Dropout(dropout_rate),
#             nn.Linear(64, encoding_dim)
#         )
#         self.decoder = nn.Sequential(
#             nn.Linear(encoding_dim, 64),
#             nn.ReLU(),
#             nn.Dropout(dropout_rate),
#             nn.Linear(64, 128),
#             nn.ReLU(),
#             nn.Dropout(dropout_rate),
#             nn.Linear(128, input_dim)
#         )
    
#     def forward(self, x):
#         encoded = self.encoder(x)
#         decoded = self.decoder(encoded)
#         return decoded

# # Define Relative Euclidean Error Loss
# class RelativeEuclideanError(nn.Module):
#     def __init__(self, epsilon=1e-8):
#         super(RelativeEuclideanError, self).__init__()
#         self.epsilon = epsilon

#     def forward(self, y_true, y_pred):
#         numerator = torch.norm(y_true - y_pred, dim=1)
#         denominator = torch.norm(y_true, dim=1) + self.epsilon
#         return torch.mean(numerator / denominator)

# # Define input dimensions
# input_dim = X_train.shape[1]

# # Model file path
# autoencoder_model_file = './autoencoder_trials/autoencoder.pth'

# # Hyperparameters
# encoding_dim = 5
# learning_rate = 0.0005
# dropout_rate = 0.3
# epochs = 750
# batch_size = 16
# patience = 40

# # Initialize model
# autoencoder = Autoencoder(input_dim, encoding_dim, dropout_rate).to(device)
# optimizer = optim.Adam(autoencoder.parameters(), lr=learning_rate)
# # criterion = RelativeEuclideanError()
# criterion = nn.MSELoss()

# # Train Autoencoder
# def train_autoencoder():
#     print("Training Autoencoder...")
#     autoencoder.train()
#     best_val_loss = float('inf')
#     patience_counter = 0

#     for epoch in range(epochs):
#         epoch_loss = 0
#         dataloader = DataLoader(TensorDataset(torch.tensor(X_train, dtype=torch.float32).to(device), 
#                                               torch.tensor(X_train, dtype=torch.float32).to(device)), 
#                                 batch_size=batch_size, shuffle=True, num_workers=0)

#         for batch_X, _ in dataloader:
#             batch_X = batch_X.to(device)
#             optimizer.zero_grad()
#             outputs = autoencoder(batch_X)
#             loss = criterion(outputs, batch_X)
#             loss.backward()
#             optimizer.step()
#             epoch_loss += loss.item()

#         avg_loss = epoch_loss / len(dataloader)
#         print(f"Epoch [{epoch+1}/{epochs}], Loss: {avg_loss:.4f}")

#         # Validation loss
#         autoencoder.eval()
#         with torch.no_grad():
#             val_outputs = autoencoder(torch.tensor(X_val, dtype=torch.float32).to(device))
#             val_loss = criterion(val_outputs, torch.tensor(X_val, dtype=torch.float32).to(device)).item()
            
#             # calculate Relative Euclidean Error
#             relative_error = np.mean(np.abs(X_val - val_outputs.cpu().numpy()) / (np.abs(X_val) + 1e-8), axis=1) * 100
#             relative_error_mean = np.mean(relative_error)
            
#             combined_metric = 0.8 * val_loss + 0.2 * relative_error_mean
            
#         print(f"Validation Loss: {combined_metric:.4f}")

#         # Early stopping
#         if combined_metric < best_val_loss:
#             best_val_loss = combined_metric
#             patience_counter = 0
#             torch.save(autoencoder.state_dict(), autoencoder_model_file)
#         else:
#             patience_counter += 1
#             print("Early stopping counter:", patience_counter)
#             if patience_counter >= patience:
#                 print("Early stopping triggered.")
#                 break

# # Train model if file does not exist
# if os.path.exists(autoencoder_model_file):
#     print("Model file exists. Loading the model...")
#     autoencoder.load_state_dict(torch.load(autoencoder_model_file))
# else:
#     os.makedirs('./autoencoder_trials', exist_ok=True)
#     train_autoencoder()

# # Evaluate Autoencoder
# autoencoder.eval()
# with torch.no_grad():
#     reconstructed_test = autoencoder(torch.tensor(X_test, dtype=torch.float32).to(device)).cpu().numpy()

# # Calculate evaluation metrics
# mse = np.mean((X_test - reconstructed_test) ** 2)
# print(f'Mean Squared Error (MSE): {mse}')

# mae = np.mean(np.abs(X_test - reconstructed_test))
# print(f'Mean Absolute Error (MAE): {mae}')

# reconstruction_error_percentage = (
#     np.mean(np.abs(X_test - reconstructed_test) / (np.abs(X_test) + 1e-8), axis=1) * 100
# )
# reconstruction_error_percentage_mean = np.mean(reconstruction_error_percentage)
# print(f'Reconstruction Error Percentage: {reconstruction_error_percentage_mean:.4f}%')

# def calculate_index_error_percentage(index, X, reconstructed_X):
#     print(np.mean(np.abs(X[index] - reconstructed_X[index]) / (np.abs(X[index]) + 1e-8)) * 100)

# %%
# # number of points with error greater than average
# np.sum(reconstruction_error_percentage > reconstruction_error_percentage_mean)

# %%
# # plot line graph of price for entire df, price column is df['Close']
# last_15_percent_index = int(len(df) * 0.85)
# last_30_percent_index = int(len(df) * 0.70)

# plt.figure(figsize=(14, 7))
# plt.plot(df['Close'], label='Train', color='blue')
# plt.plot(df['Close'].iloc[last_30_percent_index:last_15_percent_index], label='Val', color='green')
# plt.plot(df['Close'].iloc[last_15_percent_index:], label='Test', color='red')
# plt.title('Close Price History')
# plt.xlabel('Date')
# plt.ylabel('Price')
# plt.legend()
# plt.show()

# %%
# #   scatter graph to plot all errors, dont need to rearragne points
# plt.figure(figsize=(14, 7))
# plt.scatter(range(len(reconstruction_error_percentage)), reconstruction_error_percentage, color='blue')
# plt.ylim(0, 200)
# plt.title('Reconstruction Error Percentage')
# plt.xlabel('Data Point')
# plt.ylabel('Error Percentage')
# plt.legend()
# plt.show()

# %%
# # error count frequency per range
# error_ranges = [0, 1, 2, 5, 10, 20, 50, 100, 200]
# error_counts = np.zeros(len(error_ranges) - 1)
# for i in range(len(error_ranges) - 1):
#     error_counts[i] = np.sum((reconstruction_error_percentage > error_ranges[i]) & (reconstruction_error_percentage <= error_ranges[i + 1]))

# # print with descriptino
# for i in range(len(error_ranges) - 1):
#     print(f'Error percentage between {error_ranges[i]} and {error_ranges[i + 1]}: {error_counts[i]}')

# %%
# # get cosine similarity
# from sklearn.metrics.pairwise import cosine_similarity
# cosine_similarities  = np.diag(cosine_similarity(X_test, reconstructed_test))

# # get some statistics on the cosine similarities
# cosine_similarities_mean = np.mean(cosine_similarities)
# cosine_similarities_std = np.std(cosine_similarities)
# cosine_similarities_min = np.min(cosine_similarities)
# cosine_similarities_max = np.max(cosine_similarities)

# print(f'Cosine Similarity Mean: {cosine_similarities_mean}')
# print(f'Cosine Similarity Std: {cosine_similarities_std}')
# print(f'Cosine Similarity Min: {cosine_similarities_min}')
# print(f'Cosine Similarity Max: {cosine_similarities_max}')

# %%
# from sklearn.manifold import TSNE
# import matplotlib.pyplot as plt

# # Combine original and reconstructed vectors
# X_combined = np.vstack([X_test, reconstructed_test])
# labels = ["Original"] * len(X_test) + ["Reconstructed"] * len(reconstructed_test)

# # Apply t-SNE
# tsne = TSNE(n_components=2, perplexity=30, random_state=42)
# X_tsne = tsne.fit_transform(X_combined)

# # Plot
# plt.figure(figsize=(12, 6))
# plt.scatter(X_tsne[:len(X_test), 0], X_tsne[:len(X_test), 1], label="Original", alpha=0.5)
# plt.scatter(X_tsne[len(X_test):, 0], X_tsne[len(X_test):, 1], label="Reconstructed", alpha=0.5)
# plt.legend()
# plt.title("t-SNE Visualization of Original vs. Reconstructed Data")
# plt.show()

# %%
# from sklearn.decomposition import PCA

# X_combined = np.vstack([X_test, reconstructed_test])

# # Apply PCA
# pca = PCA(n_components=2)
# X_pca = pca.fit_transform(X_combined)

# # Plot
# plt.figure(figsize=(12, 6))
# plt.scatter(X_pca[:len(X_test), 0], X_pca[:len(X_test), 1], label="Original", alpha=0.5)
# plt.scatter(X_pca[len(X_test):, 0], X_pca[len(X_test):, 1], label="Reconstructed", alpha=0.5)
# plt.legend()
# plt.title("PCA Projection of Original vs. Reconstructed Data")
# plt.show()

# %%
# from numpy.linalg import norm

# euclidean_dist = np.mean([norm(X_test[i] - reconstructed_test[i]) for i in range(len(X_test))])
# print(f"Average Euclidean Distance: {euclidean_dist:.4f}")

# relative_error = euclidean_dist / np.mean(np.linalg.norm(X_test, axis=1))
# print(f"Relative Euclidean Error: {relative_error:.4f}")

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader, TensorDataset
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
from numpy.linalg import norm

# Check device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Define Autoencoder
class Autoencoder(nn.Module):
    def __init__(self, input_dim, encoding_dim, dropout_rate):
        super(Autoencoder, self).__init__()
        self.encoder = nn.Sequential(
            nn.Linear(input_dim, 128),
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.Linear(64, encoding_dim)
        )
        self.decoder = nn.Sequential(
            nn.Linear(encoding_dim, 64),
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.Linear(64, 128),
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.Linear(128, input_dim)
        )
    
    def forward(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return decoded

# Define input dimensions
input_dim = X_train.shape[1]

# Hyperparameters
encoding_dim = 5
learning_rate = 0.0005
dropout_rate = 0.1
epochs = 750
batch_size = 32
patience = 40

# Training function
def train_autoencoder():
    autoencoder = Autoencoder(input_dim, encoding_dim, dropout_rate).to(device)
    optimizer = optim.Adam(autoencoder.parameters(), lr=learning_rate)
    criterion = nn.MSELoss()
    
    best_val_loss = float('inf')
    patience_counter = 0
    
    for epoch in range(epochs):
        epoch_loss = 0
        dataloader = DataLoader(TensorDataset(torch.tensor(X_train, dtype=torch.float32).to(device)), batch_size=batch_size, shuffle=True)

        for batch_X in dataloader:
            batch_X = batch_X[0]
            optimizer.zero_grad()
            outputs = autoencoder(batch_X)
            loss = criterion(outputs, batch_X)
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item()
        
        avg_loss = epoch_loss / len(dataloader)
        
        # Validation
        autoencoder.eval()
        with torch.no_grad():
            val_outputs = autoencoder(torch.tensor(X_val, dtype=torch.float32).to(device))
            mse_loss = criterion(val_outputs, torch.tensor(X_val, dtype=torch.float32).to(device)).item()
            ree = np.mean(np.linalg.norm(X_val - val_outputs.cpu().numpy(), axis=1) / np.linalg.norm(X_val, axis=1))
            combined_metric = 0.8 * mse_loss + 0.2 * ree
        
        print(f"Epoch [{epoch+1}/{epochs}], Combined Loss: {combined_metric:.4f}")
        
        # Early stopping
        if combined_metric < best_val_loss:
            best_val_loss = combined_metric
            patience_counter = 0
            best_model = autoencoder.state_dict()
        else:
            patience_counter += 1
            if patience_counter >= patience:
                print("Early stopping triggered.")
                break
    
    return best_model

# Run 10 trials
num_trials = 10
metrics = []
error_percentages = []

t_sne_results = []
pca_results = []

for trial in range(num_trials):
    print(f"Starting trial {trial+1}...")
    best_model = train_autoencoder()
    autoencoder = Autoencoder(input_dim, encoding_dim, dropout_rate).to(device)
    autoencoder.load_state_dict(best_model)
    autoencoder.eval()
    
    with torch.no_grad():
        reconstructed_test = autoencoder(torch.tensor(X_test, dtype=torch.float32).to(device)).cpu().numpy()
    
    mse = np.mean((X_test - reconstructed_test) ** 2)
    mae = np.mean(np.abs(X_test - reconstructed_test))
    ree = np.mean(np.linalg.norm(X_test - reconstructed_test, axis=1) / np.linalg.norm(X_test, axis=1))
    euclidean_dist = np.mean([norm(X_test[i] - reconstructed_test[i]) for i in range(len(X_test))])
    
    print(f'Trial {trial+1} - MSE: {mse:.4f}, MAE: {mae:.4f}, REE: {ree:.4f}, Euclidean Distance: {euclidean_dist:.4f}')
    metrics.append([mse, mae, ree, euclidean_dist])
    
    # Reconstruction Error Percentage
    reconstruction_error_percentage = (
        np.mean(np.abs(X_test - reconstructed_test) / (np.abs(X_test) + 1e-8), axis=1) * 100
    )
    error_percentages.append(reconstruction_error_percentage)
    
    # t-SNE
    X_combined = np.vstack([X_test, reconstructed_test])
    labels = ["Original"] * len(X_test) + ["Reconstructed"] * len(reconstructed_test)
    tsne = TSNE(n_components=2, perplexity=30, random_state=42)
    t_sne_results.append(tsne.fit_transform(X_combined))
    
    # PCA
    pca = PCA(n_components=2)
    pca_results.append(pca.fit_transform(X_combined))
# Out:
# Using device: cuda
# Starting trial 1...
# Epoch [1/750], Combined Loss: 0.0990
# Epoch [2/750], Combined Loss: 0.0594
# Epoch [3/750], Combined Loss: 0.0635
# Epoch [4/750], Combined Loss: 0.0588
# Epoch [5/750], Combined Loss: 0.0541
# Epoch [6/750], Combined Loss: 0.0557
# Epoch [7/750], Combined Loss: 0.0564
# Epoch [8/750], Combined Loss: 0.0517
# Epoch [9/750], Combined Loss: 0.0596
# Epoch [10/750], Combined Loss: 0.0533
# Epoch [11/750], Combined Loss: 0.0543
# Epoch [12/750], Combined Loss: 0.0555
# Epoch [13/750], Combined Loss: 0.0507
# Epoch [14/750], Combined Loss: 0.0470
# Epoch [15/750], Combined Loss: 0.0434
# Epoch [16/750], Combined Loss: 0.0369
# Epoch [17/750], Combined Loss: 0.0270
# Epoch [18/750], Combined Loss: 0.0214
# Epoch [19/750], Combined Loss: 0.0174
# Epoch [20/750], Combined Loss: 0.0141
# Epoch [21/750], Combined Loss: 0.0144
# Epoch [22/750], Combined Loss: 0.0149
# Epoch [23/750], Combined Loss: 0.0152
# Epoch [24/750], Combined Loss: 0.0145
# Epoch [25/750], Combined Loss: 0.0152
# Epoch [26/750], Combined Loss: 0.0152
# Epoch [27/750], Combined Loss: 0.0140
# Epoch [28/750], Combined Loss: 0.0135
# Epoch [29/750], Combined Loss: 0.0141
# Epoch [30/750], Combined Loss: 0.0122
# Epoch [31/750], Combined Loss: 0.0104
# Epoch [32/750], Combined Loss: 0.0111
# Epoch [33/750], Combined Loss: 0.0106
# Epoch [34/750], Combined Loss: 0.0106
# Epoch [35/750], Combined Loss: 0.0103
# Epoch [36/750], Combined Loss: 0.0091
# Epoch [37/750], Combined Loss: 0.0092
# Epoch [38/750], Combined Loss: 0.0092
# Epoch [39/750], Combined Loss: 0.0086
# Epoch [40/750], Combined Loss: 0.0089
# Epoch [41/750], Combined Loss: 0.0082
# Epoch [42/750], Combined Loss: 0.0089
# Epoch [43/750], Combined Loss: 0.0078
# Epoch [44/750], Combined Loss: 0.0082
# Epoch [45/750], Combined Loss: 0.0085
# Epoch [46/750], Combined Loss: 0.0083
# Epoch [47/750], Combined Loss: 0.0085
# Epoch [48/750], Combined Loss: 0.0082
# Epoch [49/750], Combined Loss: 0.0078
# Epoch [50/750], Combined Loss: 0.0084
# Epoch [51/750], Combined Loss: 0.0080
# Epoch [52/750], Combined Loss: 0.0082
# Epoch [53/750], Combined Loss: 0.0084
# Epoch [54/750], Combined Loss: 0.0083
# Epoch [55/750], Combined Loss: 0.0080
# Epoch [56/750], Combined Loss: 0.0080
# Epoch [57/750], Combined Loss: 0.0080
# Epoch [58/750], Combined Loss: 0.0084
# Epoch [59/750], Combined Loss: 0.0079
# Epoch [60/750], Combined Loss: 0.0077
# Epoch [61/750], Combined Loss: 0.0076
# Epoch [62/750], Combined Loss: 0.0076
# Epoch [63/750], Combined Loss: 0.0082
# Epoch [64/750], Combined Loss: 0.0084
# Epoch [65/750], Combined Loss: 0.0085
# Epoch [66/750], Combined Loss: 0.0080
# Epoch [67/750], Combined Loss: 0.0079
# Epoch [68/750], Combined Loss: 0.0079
# Epoch [69/750], Combined Loss: 0.0084
# Epoch [70/750], Combined Loss: 0.0081
# Epoch [71/750], Combined Loss: 0.0081
# Epoch [72/750], Combined Loss: 0.0081
# Epoch [73/750], Combined Loss: 0.0084
# Epoch [74/750], Combined Loss: 0.0083
# Epoch [75/750], Combined Loss: 0.0079
# Epoch [76/750], Combined Loss: 0.0080
# Epoch [77/750], Combined Loss: 0.0077
# Epoch [78/750], Combined Loss: 0.0092
# Epoch [79/750], Combined Loss: 0.0083
# Epoch [80/750], Combined Loss: 0.0087
# Epoch [81/750], Combined Loss: 0.0080
# Epoch [82/750], Combined Loss: 0.0081
# Epoch [83/750], Combined Loss: 0.0086
# Epoch [84/750], Combined Loss: 0.0084
# Epoch [85/750], Combined Loss: 0.0079
# Epoch [86/750], Combined Loss: 0.0083
# Epoch [87/750], Combined Loss: 0.0088
# Epoch [88/750], Combined Loss: 0.0087
# Epoch [89/750], Combined Loss: 0.0089
# Epoch [90/750], Combined Loss: 0.0082
# Epoch [91/750], Combined Loss: 0.0087
# Epoch [92/750], Combined Loss: 0.0082
# Epoch [93/750], Combined Loss: 0.0082
# Epoch [94/750], Combined Loss: 0.0082
# Epoch [95/750], Combined Loss: 0.0078
# Epoch [96/750], Combined Loss: 0.0084
# Epoch [97/750], Combined Loss: 0.0082
# Epoch [98/750], Combined Loss: 0.0086
# Epoch [99/750], Combined Loss: 0.0085
# Epoch [100/750], Combined Loss: 0.0075
# Epoch [101/750], Combined Loss: 0.0079
# Epoch [102/750], Combined Loss: 0.0085
# Epoch [103/750], Combined Loss: 0.0078
# Epoch [104/750], Combined Loss: 0.0084
# Epoch [105/750], Combined Loss: 0.0083
# Epoch [106/750], Combined Loss: 0.0080
# Epoch [107/750], Combined Loss: 0.0082
# Epoch [108/750], Combined Loss: 0.0077
# Epoch [109/750], Combined Loss: 0.0083
# Epoch [110/750], Combined Loss: 0.0075
# Epoch [111/750], Combined Loss: 0.0083
# Epoch [112/750], Combined Loss: 0.0074
# Epoch [113/750], Combined Loss: 0.0080
# Epoch [114/750], Combined Loss: 0.0084
# Epoch [115/750], Combined Loss: 0.0083
# Epoch [116/750], Combined Loss: 0.0081
# Epoch [117/750], Combined Loss: 0.0079
# Epoch [118/750], Combined Loss: 0.0075
# Epoch [119/750], Combined Loss: 0.0081
# Epoch [120/750], Combined Loss: 0.0076
# Epoch [121/750], Combined Loss: 0.0074
# Epoch [122/750], Combined Loss: 0.0072
# Epoch [123/750], Combined Loss: 0.0076
# Epoch [124/750], Combined Loss: 0.0075
# Epoch [125/750], Combined Loss: 0.0072
# Epoch [126/750], Combined Loss: 0.0074
# Epoch [127/750], Combined Loss: 0.0071
# Epoch [128/750], Combined Loss: 0.0073
# Epoch [129/750], Combined Loss: 0.0072
# Epoch [130/750], Combined Loss: 0.0067
# Epoch [131/750], Combined Loss: 0.0071
# Epoch [132/750], Combined Loss: 0.0068
# Epoch [133/750], Combined Loss: 0.0072
# Epoch [134/750], Combined Loss: 0.0073
# Epoch [135/750], Combined Loss: 0.0072
# Epoch [136/750], Combined Loss: 0.0075
# Epoch [137/750], Combined Loss: 0.0069
# Epoch [138/750], Combined Loss: 0.0068
# Epoch [139/750], Combined Loss: 0.0074
# Epoch [140/750], Combined Loss: 0.0072
# Epoch [141/750], Combined Loss: 0.0072
# Epoch [142/750], Combined Loss: 0.0068
# Epoch [143/750], Combined Loss: 0.0070
# Epoch [144/750], Combined Loss: 0.0069
# Epoch [145/750], Combined Loss: 0.0073
# Epoch [146/750], Combined Loss: 0.0069
# Epoch [147/750], Combined Loss: 0.0068
# Epoch [148/750], Combined Loss: 0.0066
# Epoch [149/750], Combined Loss: 0.0075
# Epoch [150/750], Combined Loss: 0.0067
# Epoch [151/750], Combined Loss: 0.0071
# Epoch [152/750], Combined Loss: 0.0065
# Epoch [153/750], Combined Loss: 0.0070
# Epoch [154/750], Combined Loss: 0.0066
# Epoch [155/750], Combined Loss: 0.0069
# Epoch [156/750], Combined Loss: 0.0068
# Epoch [157/750], Combined Loss: 0.0070
# Epoch [158/750], Combined Loss: 0.0066
# Epoch [159/750], Combined Loss: 0.0066
# Epoch [160/750], Combined Loss: 0.0068
# Epoch [161/750], Combined Loss: 0.0071
# Epoch [162/750], Combined Loss: 0.0070
# Epoch [163/750], Combined Loss: 0.0070
# Epoch [164/750], Combined Loss: 0.0067
# Epoch [165/750], Combined Loss: 0.0067
# Epoch [166/750], Combined Loss: 0.0069
# Epoch [167/750], Combined Loss: 0.0067
# Epoch [168/750], Combined Loss: 0.0070
# Epoch [169/750], Combined Loss: 0.0071
# Epoch [170/750], Combined Loss: 0.0066
# Epoch [171/750], Combined Loss: 0.0066
# Epoch [172/750], Combined Loss: 0.0070
# Epoch [173/750], Combined Loss: 0.0064
# Epoch [174/750], Combined Loss: 0.0068
# Epoch [175/750], Combined Loss: 0.0067
# Epoch [176/750], Combined Loss: 0.0066
# Epoch [177/750], Combined Loss: 0.0067
# Epoch [178/750], Combined Loss: 0.0066
# Epoch [179/750], Combined Loss: 0.0068
# Epoch [180/750], Combined Loss: 0.0066
# Epoch [181/750], Combined Loss: 0.0066
# Epoch [182/750], Combined Loss: 0.0069
# Epoch [183/750], Combined Loss: 0.0070
# Epoch [184/750], Combined Loss: 0.0066
# Epoch [185/750], Combined Loss: 0.0067
# Epoch [186/750], Combined Loss: 0.0069
# Epoch [187/750], Combined Loss: 0.0065
# Epoch [188/750], Combined Loss: 0.0067
# Epoch [189/750], Combined Loss: 0.0068
# Epoch [190/750], Combined Loss: 0.0070
# Epoch [191/750], Combined Loss: 0.0069
# Epoch [192/750], Combined Loss: 0.0068
# Epoch [193/750], Combined Loss: 0.0068
# Epoch [194/750], Combined Loss: 0.0066
# Epoch [195/750], Combined Loss: 0.0064
# Epoch [196/750], Combined Loss: 0.0065
# Epoch [197/750], Combined Loss: 0.0068
# Epoch [198/750], Combined Loss: 0.0067
# Epoch [199/750], Combined Loss: 0.0069
# Epoch [200/750], Combined Loss: 0.0068
# Epoch [201/750], Combined Loss: 0.0069
# Epoch [202/750], Combined Loss: 0.0071
# Epoch [203/750], Combined Loss: 0.0066
# Epoch [204/750], Combined Loss: 0.0068
# Epoch [205/750], Combined Loss: 0.0068
# Epoch [206/750], Combined Loss: 0.0067
# Epoch [207/750], Combined Loss: 0.0067
# Epoch [208/750], Combined Loss: 0.0065
# Epoch [209/750], Combined Loss: 0.0066
# Epoch [210/750], Combined Loss: 0.0067
# Epoch [211/750], Combined Loss: 0.0073
# Epoch [212/750], Combined Loss: 0.0066
# Epoch [213/750], Combined Loss: 0.0070
# Epoch [214/750], Combined Loss: 0.0066
# Epoch [215/750], Combined Loss: 0.0069
# Epoch [216/750], Combined Loss: 0.0065
# Epoch [217/750], Combined Loss: 0.0070
# Epoch [218/750], Combined Loss: 0.0067
# Epoch [219/750], Combined Loss: 0.0067
# Epoch [220/750], Combined Loss: 0.0065
# Epoch [221/750], Combined Loss: 0.0070
# Epoch [222/750], Combined Loss: 0.0068
# Epoch [223/750], Combined Loss: 0.0064
# Epoch [224/750], Combined Loss: 0.0068
# Epoch [225/750], Combined Loss: 0.0066
# Epoch [226/750], Combined Loss: 0.0068
# Epoch [227/750], Combined Loss: 0.0073
# Epoch [228/750], Combined Loss: 0.0069
# Epoch [229/750], Combined Loss: 0.0069
# Epoch [230/750], Combined Loss: 0.0067
# Epoch [231/750], Combined Loss: 0.0066
# Epoch [232/750], Combined Loss: 0.0068
# Epoch [233/750], Combined Loss: 0.0065
# Epoch [234/750], Combined Loss: 0.0070
# Epoch [235/750], Combined Loss: 0.0067
# Early stopping triggered.
# Trial 1 - MSE: 0.0449, MAE: 0.1064, REE: 0.3208, Euclidean Distance: 0.5791
# Starting trial 2...
# Epoch [1/750], Combined Loss: 0.0849
# Epoch [2/750], Combined Loss: 0.0739
# Epoch [3/750], Combined Loss: 0.0633
# Epoch [4/750], Combined Loss: 0.0628
# Epoch [5/750], Combined Loss: 0.0593
# Epoch [6/750], Combined Loss: 0.0584
# Epoch [7/750], Combined Loss: 0.0518
# Epoch [8/750], Combined Loss: 0.0588
# Epoch [9/750], Combined Loss: 0.0567
# Epoch [10/750], Combined Loss: 0.0551
# Epoch [11/750], Combined Loss: 0.0593
# Epoch [12/750], Combined Loss: 0.0544
# Epoch [13/750], Combined Loss: 0.0536
# Epoch [14/750], Combined Loss: 0.0543
# Epoch [15/750], Combined Loss: 0.0516
# Epoch [16/750], Combined Loss: 0.0531
# Epoch [17/750], Combined Loss: 0.0515
# Epoch [18/750], Combined Loss: 0.0496
# Epoch [19/750], Combined Loss: 0.0383
# Epoch [20/750], Combined Loss: 0.0299
# Epoch [21/750], Combined Loss: 0.0189
# Epoch [22/750], Combined Loss: 0.0145
# Epoch [23/750], Combined Loss: 0.0122
# Epoch [24/750], Combined Loss: 0.0123
# Epoch [25/750], Combined Loss: 0.0112
# Epoch [26/750], Combined Loss: 0.0108
# Epoch [27/750], Combined Loss: 0.0099
# Epoch [28/750], Combined Loss: 0.0088
# Epoch [29/750], Combined Loss: 0.0087
# Epoch [30/750], Combined Loss: 0.0087
# Epoch [31/750], Combined Loss: 0.0083
# Epoch [32/750], Combined Loss: 0.0085
# Epoch [33/750], Combined Loss: 0.0086
# Epoch [34/750], Combined Loss: 0.0083
# Epoch [35/750], Combined Loss: 0.0082
# Epoch [36/750], Combined Loss: 0.0074
# Epoch [37/750], Combined Loss: 0.0075
# Epoch [38/750], Combined Loss: 0.0068
# Epoch [39/750], Combined Loss: 0.0075
# Epoch [40/750], Combined Loss: 0.0080
# Epoch [41/750], Combined Loss: 0.0073
# Epoch [42/750], Combined Loss: 0.0068
# Epoch [43/750], Combined Loss: 0.0071
# Epoch [44/750], Combined Loss: 0.0067
# Epoch [45/750], Combined Loss: 0.0071
# Epoch [46/750], Combined Loss: 0.0064
# Epoch [47/750], Combined Loss: 0.0067
# Epoch [48/750], Combined Loss: 0.0070
# Epoch [49/750], Combined Loss: 0.0067
# Epoch [50/750], Combined Loss: 0.0066
# Epoch [51/750], Combined Loss: 0.0069
# Epoch [52/750], Combined Loss: 0.0061
# Epoch [53/750], Combined Loss: 0.0063
# Epoch [54/750], Combined Loss: 0.0067
# Epoch [55/750], Combined Loss: 0.0070
# Epoch [56/750], Combined Loss: 0.0065
# Epoch [57/750], Combined Loss: 0.0065
# Epoch [58/750], Combined Loss: 0.0065
# Epoch [59/750], Combined Loss: 0.0066
# Epoch [60/750], Combined Loss: 0.0065
# Epoch [61/750], Combined Loss: 0.0065
# Epoch [62/750], Combined Loss: 0.0065
# Epoch [63/750], Combined Loss: 0.0069
# Epoch [64/750], Combined Loss: 0.0069
# Epoch [65/750], Combined Loss: 0.0061
# Epoch [66/750], Combined Loss: 0.0064
# Epoch [67/750], Combined Loss: 0.0066
# Epoch [68/750], Combined Loss: 0.0062
# Epoch [69/750], Combined Loss: 0.0060
# Epoch [70/750], Combined Loss: 0.0067
# Epoch [71/750], Combined Loss: 0.0073
# Epoch [72/750], Combined Loss: 0.0063
# Epoch [73/750], Combined Loss: 0.0072
# Epoch [74/750], Combined Loss: 0.0065
# Epoch [75/750], Combined Loss: 0.0068
# Epoch [76/750], Combined Loss: 0.0066
# Epoch [77/750], Combined Loss: 0.0065
# Epoch [78/750], Combined Loss: 0.0065
# Epoch [79/750], Combined Loss: 0.0065
# Epoch [80/750], Combined Loss: 0.0069
# Epoch [81/750], Combined Loss: 0.0068
# Epoch [82/750], Combined Loss: 0.0073
# Epoch [83/750], Combined Loss: 0.0060
# Epoch [84/750], Combined Loss: 0.0069
# Epoch [85/750], Combined Loss: 0.0059
# Epoch [86/750], Combined Loss: 0.0065
# Epoch [87/750], Combined Loss: 0.0061
# Epoch [88/750], Combined Loss: 0.0057
# Epoch [89/750], Combined Loss: 0.0067
# Epoch [90/750], Combined Loss: 0.0063
# Epoch [91/750], Combined Loss: 0.0063
# Epoch [92/750], Combined Loss: 0.0063
# Epoch [93/750], Combined Loss: 0.0060
# Epoch [94/750], Combined Loss: 0.0076
# Epoch [95/750], Combined Loss: 0.0075
# Epoch [96/750], Combined Loss: 0.0066
# Epoch [97/750], Combined Loss: 0.0068
# Epoch [98/750], Combined Loss: 0.0068
# Epoch [99/750], Combined Loss: 0.0063
# Epoch [100/750], Combined Loss: 0.0069
# Epoch [101/750], Combined Loss: 0.0070
# Epoch [102/750], Combined Loss: 0.0078
# Epoch [103/750], Combined Loss: 0.0065
# Epoch [104/750], Combined Loss: 0.0067
# Epoch [105/750], Combined Loss: 0.0065
# Epoch [106/750], Combined Loss: 0.0070
# Epoch [107/750], Combined Loss: 0.0068
# Epoch [108/750], Combined Loss: 0.0074
# Epoch [109/750], Combined Loss: 0.0070
# Epoch [110/750], Combined Loss: 0.0069
# Epoch [111/750], Combined Loss: 0.0071
# Epoch [112/750], Combined Loss: 0.0067
# Epoch [113/750], Combined Loss: 0.0062
# Epoch [114/750], Combined Loss: 0.0063
# Epoch [115/750], Combined Loss: 0.0068
# Epoch [116/750], Combined Loss: 0.0063
# Epoch [117/750], Combined Loss: 0.0063
# Epoch [118/750], Combined Loss: 0.0062
# Epoch [119/750], Combined Loss: 0.0063
# Epoch [120/750], Combined Loss: 0.0060
# Epoch [121/750], Combined Loss: 0.0062
# Epoch [122/750], Combined Loss: 0.0062
# Epoch [123/750], Combined Loss: 0.0059
# Epoch [124/750], Combined Loss: 0.0067
# Epoch [125/750], Combined Loss: 0.0057
# Epoch [126/750], Combined Loss: 0.0055
# Epoch [127/750], Combined Loss: 0.0056
# Epoch [128/750], Combined Loss: 0.0059
# Epoch [129/750], Combined Loss: 0.0054
# Epoch [130/750], Combined Loss: 0.0056
# Epoch [131/750], Combined Loss: 0.0058
# Epoch [132/750], Combined Loss: 0.0059
# Epoch [133/750], Combined Loss: 0.0054
# Epoch [134/750], Combined Loss: 0.0053
# Epoch [135/750], Combined Loss: 0.0048
# Epoch [136/750], Combined Loss: 0.0053
# Epoch [137/750], Combined Loss: 0.0046
# Epoch [138/750], Combined Loss: 0.0042
# Epoch [139/750], Combined Loss: 0.0052
# Epoch [140/750], Combined Loss: 0.0047
# Epoch [141/750], Combined Loss: 0.0040
# Epoch [142/750], Combined Loss: 0.0048
# Epoch [143/750], Combined Loss: 0.0049
# Epoch [144/750], Combined Loss: 0.0045
# Epoch [145/750], Combined Loss: 0.0045
# Epoch [146/750], Combined Loss: 0.0045
# Epoch [147/750], Combined Loss: 0.0045
# Epoch [148/750], Combined Loss: 0.0046
# Epoch [149/750], Combined Loss: 0.0044
# Epoch [150/750], Combined Loss: 0.0042
# Epoch [151/750], Combined Loss: 0.0047
# Epoch [152/750], Combined Loss: 0.0046
# Epoch [153/750], Combined Loss: 0.0042
# Epoch [154/750], Combined Loss: 0.0047
# Epoch [155/750], Combined Loss: 0.0043
# Epoch [156/750], Combined Loss: 0.0039
# Epoch [157/750], Combined Loss: 0.0043
# Epoch [158/750], Combined Loss: 0.0041
# Epoch [159/750], Combined Loss: 0.0043
# Epoch [160/750], Combined Loss: 0.0044
# Epoch [161/750], Combined Loss: 0.0046
# Epoch [162/750], Combined Loss: 0.0044
# Epoch [163/750], Combined Loss: 0.0045
# Epoch [164/750], Combined Loss: 0.0041
# Epoch [165/750], Combined Loss: 0.0041
# Epoch [166/750], Combined Loss: 0.0044
# Epoch [167/750], Combined Loss: 0.0043
# Epoch [168/750], Combined Loss: 0.0043
# Epoch [169/750], Combined Loss: 0.0042
# Epoch [170/750], Combined Loss: 0.0042
# Epoch [171/750], Combined Loss: 0.0040
# Epoch [172/750], Combined Loss: 0.0044
# Epoch [173/750], Combined Loss: 0.0044
# Epoch [174/750], Combined Loss: 0.0047
# Epoch [175/750], Combined Loss: 0.0039
# Epoch [176/750], Combined Loss: 0.0045
# Epoch [177/750], Combined Loss: 0.0045
# Epoch [178/750], Combined Loss: 0.0046
# Epoch [179/750], Combined Loss: 0.0043
# Epoch [180/750], Combined Loss: 0.0038
# Epoch [181/750], Combined Loss: 0.0046
# Epoch [182/750], Combined Loss: 0.0044
# Epoch [183/750], Combined Loss: 0.0047
# Epoch [184/750], Combined Loss: 0.0042
# Epoch [185/750], Combined Loss: 0.0043
# Epoch [186/750], Combined Loss: 0.0044
# Epoch [187/750], Combined Loss: 0.0043
# Epoch [188/750], Combined Loss: 0.0045
# Epoch [189/750], Combined Loss: 0.0043
# Epoch [190/750], Combined Loss: 0.0045
# Epoch [191/750], Combined Loss: 0.0044
# Epoch [192/750], Combined Loss: 0.0050
# Epoch [193/750], Combined Loss: 0.0047
# Epoch [194/750], Combined Loss: 0.0049
# Epoch [195/750], Combined Loss: 0.0045
# Epoch [196/750], Combined Loss: 0.0042
# Epoch [197/750], Combined Loss: 0.0050
# Epoch [198/750], Combined Loss: 0.0044
# Epoch [199/750], Combined Loss: 0.0044
# Epoch [200/750], Combined Loss: 0.0046
# Epoch [201/750], Combined Loss: 0.0045
# Epoch [202/750], Combined Loss: 0.0046
# Epoch [203/750], Combined Loss: 0.0042
# Epoch [204/750], Combined Loss: 0.0045
# Epoch [205/750], Combined Loss: 0.0047
# Epoch [206/750], Combined Loss: 0.0042
# Epoch [207/750], Combined Loss: 0.0045
# Epoch [208/750], Combined Loss: 0.0047
# Epoch [209/750], Combined Loss: 0.0047
# Epoch [210/750], Combined Loss: 0.0044
# Epoch [211/750], Combined Loss: 0.0044
# Epoch [212/750], Combined Loss: 0.0043
# Epoch [213/750], Combined Loss: 0.0046
# Epoch [214/750], Combined Loss: 0.0042
# Epoch [215/750], Combined Loss: 0.0043
# Epoch [216/750], Combined Loss: 0.0046
# Epoch [217/750], Combined Loss: 0.0043
# Epoch [218/750], Combined Loss: 0.0046
# Epoch [219/750], Combined Loss: 0.0041
# Epoch [220/750], Combined Loss: 0.0042
# Early stopping triggered.
# Trial 2 - MSE: 0.0275, MAE: 0.1058, REE: 0.2480, Euclidean Distance: 0.4468
# Starting trial 3...
# Epoch [1/750], Combined Loss: 0.1135
# Epoch [2/750], Combined Loss: 0.0620
# Epoch [3/750], Combined Loss: 0.0568
# Epoch [4/750], Combined Loss: 0.0553
# Epoch [5/750], Combined Loss: 0.0531
# Epoch [6/750], Combined Loss: 0.0562
# Epoch [7/750], Combined Loss: 0.0589
# Epoch [8/750], Combined Loss: 0.0545
# Epoch [9/750], Combined Loss: 0.0537
# Epoch [10/750], Combined Loss: 0.0555
# Epoch [11/750], Combined Loss: 0.0571
# Epoch [12/750], Combined Loss: 0.0529
# Epoch [13/750], Combined Loss: 0.0530
# Epoch [14/750], Combined Loss: 0.0592
# Epoch [15/750], Combined Loss: 0.0531
# Epoch [16/750], Combined Loss: 0.0526
# Epoch [17/750], Combined Loss: 0.0510
# Epoch [18/750], Combined Loss: 0.0509
# Epoch [19/750], Combined Loss: 0.0510
# Epoch [20/750], Combined Loss: 0.0508
# Epoch [21/750], Combined Loss: 0.0424
# Epoch [22/750], Combined Loss: 0.0339
# Epoch [23/750], Combined Loss: 0.0258
# Epoch [24/750], Combined Loss: 0.0179
# Epoch [25/750], Combined Loss: 0.0153
# Epoch [26/750], Combined Loss: 0.0164
# Epoch [27/750], Combined Loss: 0.0166
# Epoch [28/750], Combined Loss: 0.0157
# Epoch [29/750], Combined Loss: 0.0161
# Epoch [30/750], Combined Loss: 0.0168
# Epoch [31/750], Combined Loss: 0.0192
# Epoch [32/750], Combined Loss: 0.0163
# Epoch [33/750], Combined Loss: 0.0159
# Epoch [34/750], Combined Loss: 0.0161
# Epoch [35/750], Combined Loss: 0.0143
# Epoch [36/750], Combined Loss: 0.0148
# Epoch [37/750], Combined Loss: 0.0150
# Epoch [38/750], Combined Loss: 0.0127
# Epoch [39/750], Combined Loss: 0.0132
# Epoch [40/750], Combined Loss: 0.0126
# Epoch [41/750], Combined Loss: 0.0127
# Epoch [42/750], Combined Loss: 0.0119
# Epoch [43/750], Combined Loss: 0.0110
# Epoch [44/750], Combined Loss: 0.0104
# Epoch [45/750], Combined Loss: 0.0102
# Epoch [46/750], Combined Loss: 0.0104
# Epoch [47/750], Combined Loss: 0.0099
# Epoch [48/750], Combined Loss: 0.0095
# Epoch [49/750], Combined Loss: 0.0099
# Epoch [50/750], Combined Loss: 0.0090
# Epoch [51/750], Combined Loss: 0.0089
# Epoch [52/750], Combined Loss: 0.0096
# Epoch [53/750], Combined Loss: 0.0094
# Epoch [54/750], Combined Loss: 0.0087
# Epoch [55/750], Combined Loss: 0.0098
# Epoch [56/750], Combined Loss: 0.0089
# Epoch [57/750], Combined Loss: 0.0092
# Epoch [58/750], Combined Loss: 0.0093
# Epoch [59/750], Combined Loss: 0.0088
# Epoch [60/750], Combined Loss: 0.0087
# Epoch [61/750], Combined Loss: 0.0090
# Epoch [62/750], Combined Loss: 0.0088
# Epoch [63/750], Combined Loss: 0.0084
# Epoch [64/750], Combined Loss: 0.0082
# Epoch [65/750], Combined Loss: 0.0086
# Epoch [66/750], Combined Loss: 0.0087
# Epoch [67/750], Combined Loss: 0.0088
# Epoch [68/750], Combined Loss: 0.0091
# Epoch [69/750], Combined Loss: 0.0088
# Epoch [70/750], Combined Loss: 0.0087
# Epoch [71/750], Combined Loss: 0.0086
# Epoch [72/750], Combined Loss: 0.0094
# Epoch [73/750], Combined Loss: 0.0089
# Epoch [74/750], Combined Loss: 0.0082
# Epoch [75/750], Combined Loss: 0.0082
# Epoch [76/750], Combined Loss: 0.0087
# Epoch [77/750], Combined Loss: 0.0085
# Epoch [78/750], Combined Loss: 0.0085
# Epoch [79/750], Combined Loss: 0.0087
# Epoch [80/750], Combined Loss: 0.0091
# Epoch [81/750], Combined Loss: 0.0079
# Epoch [82/750], Combined Loss: 0.0089
# Epoch [83/750], Combined Loss: 0.0084
# Epoch [84/750], Combined Loss: 0.0088
# Epoch [85/750], Combined Loss: 0.0101
# Epoch [86/750], Combined Loss: 0.0078
# Epoch [87/750], Combined Loss: 0.0082
# Epoch [88/750], Combined Loss: 0.0073
# Epoch [89/750], Combined Loss: 0.0072
# Epoch [90/750], Combined Loss: 0.0072
# Epoch [91/750], Combined Loss: 0.0080
# Epoch [92/750], Combined Loss: 0.0075
# Epoch [93/750], Combined Loss: 0.0070
# Epoch [94/750], Combined Loss: 0.0070
# Epoch [95/750], Combined Loss: 0.0067
# Epoch [96/750], Combined Loss: 0.0066
# Epoch [97/750], Combined Loss: 0.0065
# Epoch [98/750], Combined Loss: 0.0065
# Epoch [99/750], Combined Loss: 0.0066
# Epoch [100/750], Combined Loss: 0.0067
# Epoch [101/750], Combined Loss: 0.0063
# Epoch [102/750], Combined Loss: 0.0061
# Epoch [103/750], Combined Loss: 0.0063
# Epoch [104/750], Combined Loss: 0.0058
# Epoch [105/750], Combined Loss: 0.0058
# Epoch [106/750], Combined Loss: 0.0060
# Epoch [107/750], Combined Loss: 0.0059
# Epoch [108/750], Combined Loss: 0.0061
# Epoch [109/750], Combined Loss: 0.0060
# Epoch [110/750], Combined Loss: 0.0058
# Epoch [111/750], Combined Loss: 0.0056
# Epoch [112/750], Combined Loss: 0.0058
# Epoch [113/750], Combined Loss: 0.0062
# Epoch [114/750], Combined Loss: 0.0058
# Epoch [115/750], Combined Loss: 0.0056
# Epoch [116/750], Combined Loss: 0.0054
# Epoch [117/750], Combined Loss: 0.0055
# Epoch [118/750], Combined Loss: 0.0056
# Epoch [119/750], Combined Loss: 0.0058
# Epoch [120/750], Combined Loss: 0.0057
# Epoch [121/750], Combined Loss: 0.0055
# Epoch [122/750], Combined Loss: 0.0054
# Epoch [123/750], Combined Loss: 0.0059
# Epoch [124/750], Combined Loss: 0.0051
# Epoch [125/750], Combined Loss: 0.0055
# Epoch [126/750], Combined Loss: 0.0056
# Epoch [127/750], Combined Loss: 0.0055
# Epoch [128/750], Combined Loss: 0.0053
# Epoch [129/750], Combined Loss: 0.0055
# Epoch [130/750], Combined Loss: 0.0056
# Epoch [131/750], Combined Loss: 0.0061
# Epoch [132/750], Combined Loss: 0.0056
# Epoch [133/750], Combined Loss: 0.0055
# Epoch [134/750], Combined Loss: 0.0054
# Epoch [135/750], Combined Loss: 0.0057
# Epoch [136/750], Combined Loss: 0.0052
# Epoch [137/750], Combined Loss: 0.0053
# Epoch [138/750], Combined Loss: 0.0054
# Epoch [139/750], Combined Loss: 0.0055
# Epoch [140/750], Combined Loss: 0.0055
# Epoch [141/750], Combined Loss: 0.0061
# Epoch [142/750], Combined Loss: 0.0059
# Epoch [143/750], Combined Loss: 0.0056
# Epoch [144/750], Combined Loss: 0.0053
# Epoch [145/750], Combined Loss: 0.0054
# Epoch [146/750], Combined Loss: 0.0056
# Epoch [147/750], Combined Loss: 0.0053
# Epoch [148/750], Combined Loss: 0.0052
# Epoch [149/750], Combined Loss: 0.0054
# Epoch [150/750], Combined Loss: 0.0056
# Epoch [151/750], Combined Loss: 0.0057
# Epoch [152/750], Combined Loss: 0.0056
# Epoch [153/750], Combined Loss: 0.0055
# Epoch [154/750], Combined Loss: 0.0055
# Epoch [155/750], Combined Loss: 0.0054
# Epoch [156/750], Combined Loss: 0.0053
# Epoch [157/750], Combined Loss: 0.0055
# Epoch [158/750], Combined Loss: 0.0053
# Epoch [159/750], Combined Loss: 0.0060
# Epoch [160/750], Combined Loss: 0.0054
# Epoch [161/750], Combined Loss: 0.0053
# Epoch [162/750], Combined Loss: 0.0053
# Epoch [163/750], Combined Loss: 0.0053
# Epoch [164/750], Combined Loss: 0.0055
# Early stopping triggered.
# Trial 3 - MSE: 0.0271, MAE: 0.1066, REE: 0.2518, Euclidean Distance: 0.4571
# Starting trial 4...
# Epoch [1/750], Combined Loss: 0.1706
# Epoch [2/750], Combined Loss: 0.0739
# Epoch [3/750], Combined Loss: 0.0595
# Epoch [4/750], Combined Loss: 0.0598
# Epoch [5/750], Combined Loss: 0.0588
# Epoch [6/750], Combined Loss: 0.0552
# Epoch [7/750], Combined Loss: 0.0565
# Epoch [8/750], Combined Loss: 0.0533
# Epoch [9/750], Combined Loss: 0.0582
# Epoch [10/750], Combined Loss: 0.0530
# Epoch [11/750], Combined Loss: 0.0520
# Epoch [12/750], Combined Loss: 0.0501
# Epoch [13/750], Combined Loss: 0.0545
# Epoch [14/750], Combined Loss: 0.0477
# Epoch [15/750], Combined Loss: 0.0461
# Epoch [16/750], Combined Loss: 0.0268
# Epoch [17/750], Combined Loss: 0.0213
# Epoch [18/750], Combined Loss: 0.0183
# Epoch [19/750], Combined Loss: 0.0159
# Epoch [20/750], Combined Loss: 0.0166
# Epoch [21/750], Combined Loss: 0.0158
# Epoch [22/750], Combined Loss: 0.0163
# Epoch [23/750], Combined Loss: 0.0161
# Epoch [24/750], Combined Loss: 0.0162
# Epoch [25/750], Combined Loss: 0.0165
# Epoch [26/750], Combined Loss: 0.0161
# Epoch [27/750], Combined Loss: 0.0166
# Epoch [28/750], Combined Loss: 0.0154
# Epoch [29/750], Combined Loss: 0.0163
# Epoch [30/750], Combined Loss: 0.0150
# Epoch [31/750], Combined Loss: 0.0153
# Epoch [32/750], Combined Loss: 0.0164
# Epoch [33/750], Combined Loss: 0.0153
# Epoch [34/750], Combined Loss: 0.0145
# Epoch [35/750], Combined Loss: 0.0149
# Epoch [36/750], Combined Loss: 0.0136
# Epoch [37/750], Combined Loss: 0.0128
# Epoch [38/750], Combined Loss: 0.0124
# Epoch [39/750], Combined Loss: 0.0122
# Epoch [40/750], Combined Loss: 0.0121
# Epoch [41/750], Combined Loss: 0.0119
# Epoch [42/750], Combined Loss: 0.0115
# Epoch [43/750], Combined Loss: 0.0114
# Epoch [44/750], Combined Loss: 0.0109
# Epoch [45/750], Combined Loss: 0.0113
# Epoch [46/750], Combined Loss: 0.0103
# Epoch [47/750], Combined Loss: 0.0106
# Epoch [48/750], Combined Loss: 0.0107
# Epoch [49/750], Combined Loss: 0.0103
# Epoch [50/750], Combined Loss: 0.0106
# Epoch [51/750], Combined Loss: 0.0099
# Epoch [52/750], Combined Loss: 0.0106
# Epoch [53/750], Combined Loss: 0.0101
# Epoch [54/750], Combined Loss: 0.0101
# Epoch [55/750], Combined Loss: 0.0098
# Epoch [56/750], Combined Loss: 0.0095
# Epoch [57/750], Combined Loss: 0.0103
# Epoch [58/750], Combined Loss: 0.0094
# Epoch [59/750], Combined Loss: 0.0094
# Epoch [60/750], Combined Loss: 0.0094
# Epoch [61/750], Combined Loss: 0.0095
# Epoch [62/750], Combined Loss: 0.0096
# Epoch [63/750], Combined Loss: 0.0106
# Epoch [64/750], Combined Loss: 0.0093
# Epoch [65/750], Combined Loss: 0.0098
# Epoch [66/750], Combined Loss: 0.0093
# Epoch [67/750], Combined Loss: 0.0094
# Epoch [68/750], Combined Loss: 0.0094
# Epoch [69/750], Combined Loss: 0.0097
# Epoch [70/750], Combined Loss: 0.0101
# Epoch [71/750], Combined Loss: 0.0094
# Epoch [72/750], Combined Loss: 0.0091
# Epoch [73/750], Combined Loss: 0.0093
# Epoch [74/750], Combined Loss: 0.0095
# Epoch [75/750], Combined Loss: 0.0102
# Epoch [76/750], Combined Loss: 0.0098
# Epoch [77/750], Combined Loss: 0.0104
# Epoch [78/750], Combined Loss: 0.0099
# Epoch [79/750], Combined Loss: 0.0107
# Epoch [80/750], Combined Loss: 0.0095
# Epoch [81/750], Combined Loss: 0.0089
# Epoch [82/750], Combined Loss: 0.0102
# Epoch [83/750], Combined Loss: 0.0094
# Epoch [84/750], Combined Loss: 0.0097
# Epoch [85/750], Combined Loss: 0.0094
# Epoch [86/750], Combined Loss: 0.0085
# Epoch [87/750], Combined Loss: 0.0092
# Epoch [88/750], Combined Loss: 0.0094
# Epoch [89/750], Combined Loss: 0.0092
# Epoch [90/750], Combined Loss: 0.0092
# Epoch [91/750], Combined Loss: 0.0089
# Epoch [92/750], Combined Loss: 0.0094
# Epoch [93/750], Combined Loss: 0.0079
# Epoch [94/750], Combined Loss: 0.0084
# Epoch [95/750], Combined Loss: 0.0088
# Epoch [96/750], Combined Loss: 0.0081
# Epoch [97/750], Combined Loss: 0.0081
# Epoch [98/750], Combined Loss: 0.0080
# Epoch [99/750], Combined Loss: 0.0088
# Epoch [100/750], Combined Loss: 0.0086
# Epoch [101/750], Combined Loss: 0.0080
# Epoch [102/750], Combined Loss: 0.0073
# Epoch [103/750], Combined Loss: 0.0078
# Epoch [104/750], Combined Loss: 0.0079
# Epoch [105/750], Combined Loss: 0.0070
# Epoch [106/750], Combined Loss: 0.0073
# Epoch [107/750], Combined Loss: 0.0068
# Epoch [108/750], Combined Loss: 0.0069
# Epoch [109/750], Combined Loss: 0.0068
# Epoch [110/750], Combined Loss: 0.0069
# Epoch [111/750], Combined Loss: 0.0062
# Epoch [112/750], Combined Loss: 0.0068
# Epoch [113/750], Combined Loss: 0.0062
# Epoch [114/750], Combined Loss: 0.0064
# Epoch [115/750], Combined Loss: 0.0062
# Epoch [116/750], Combined Loss: 0.0063
# Epoch [117/750], Combined Loss: 0.0063
# Epoch [118/750], Combined Loss: 0.0064
# Epoch [119/750], Combined Loss: 0.0062
# Epoch [120/750], Combined Loss: 0.0059
# Epoch [121/750], Combined Loss: 0.0061
# Epoch [122/750], Combined Loss: 0.0060
# Epoch [123/750], Combined Loss: 0.0062
# Epoch [124/750], Combined Loss: 0.0061
# Epoch [125/750], Combined Loss: 0.0061
# Epoch [126/750], Combined Loss: 0.0059
# Epoch [127/750], Combined Loss: 0.0061
# Epoch [128/750], Combined Loss: 0.0065
# Epoch [129/750], Combined Loss: 0.0061
# Epoch [130/750], Combined Loss: 0.0062
# Epoch [131/750], Combined Loss: 0.0061
# Epoch [132/750], Combined Loss: 0.0065
# Epoch [133/750], Combined Loss: 0.0065
# Epoch [134/750], Combined Loss: 0.0059
# Epoch [135/750], Combined Loss: 0.0067
# Epoch [136/750], Combined Loss: 0.0071
# Epoch [137/750], Combined Loss: 0.0060
# Epoch [138/750], Combined Loss: 0.0063
# Epoch [139/750], Combined Loss: 0.0062
# Epoch [140/750], Combined Loss: 0.0066
# Epoch [141/750], Combined Loss: 0.0059
# Epoch [142/750], Combined Loss: 0.0060
# Epoch [143/750], Combined Loss: 0.0060
# Epoch [144/750], Combined Loss: 0.0062
# Epoch [145/750], Combined Loss: 0.0058
# Epoch [146/750], Combined Loss: 0.0065
# Epoch [147/750], Combined Loss: 0.0060
# Epoch [148/750], Combined Loss: 0.0058
# Epoch [149/750], Combined Loss: 0.0060
# Epoch [150/750], Combined Loss: 0.0059
# Epoch [151/750], Combined Loss: 0.0059
# Epoch [152/750], Combined Loss: 0.0062
# Epoch [153/750], Combined Loss: 0.0064
# Epoch [154/750], Combined Loss: 0.0065
# Epoch [155/750], Combined Loss: 0.0061
# Epoch [156/750], Combined Loss: 0.0059
# Epoch [157/750], Combined Loss: 0.0063
# Epoch [158/750], Combined Loss: 0.0060
# Epoch [159/750], Combined Loss: 0.0064
# Epoch [160/750], Combined Loss: 0.0057
# Epoch [161/750], Combined Loss: 0.0062
# Epoch [162/750], Combined Loss: 0.0063
# Epoch [163/750], Combined Loss: 0.0059
# Epoch [164/750], Combined Loss: 0.0064
# Epoch [165/750], Combined Loss: 0.0061
# Epoch [166/750], Combined Loss: 0.0065
# Epoch [167/750], Combined Loss: 0.0064
# Epoch [168/750], Combined Loss: 0.0061
# Epoch [169/750], Combined Loss: 0.0061
# Epoch [170/750], Combined Loss: 0.0063
# Epoch [171/750], Combined Loss: 0.0063
# Epoch [172/750], Combined Loss: 0.0059
# Epoch [173/750], Combined Loss: 0.0063
# Epoch [174/750], Combined Loss: 0.0068
# Epoch [175/750], Combined Loss: 0.0064
# Epoch [176/750], Combined Loss: 0.0063
# Epoch [177/750], Combined Loss: 0.0061
# Epoch [178/750], Combined Loss: 0.0064
# Epoch [179/750], Combined Loss: 0.0062
# Epoch [180/750], Combined Loss: 0.0064
# Epoch [181/750], Combined Loss: 0.0064
# Epoch [182/750], Combined Loss: 0.0063
# Epoch [183/750], Combined Loss: 0.0066
# Epoch [184/750], Combined Loss: 0.0062
# Epoch [185/750], Combined Loss: 0.0077
# Epoch [186/750], Combined Loss: 0.0067
# Epoch [187/750], Combined Loss: 0.0062
# Epoch [188/750], Combined Loss: 0.0062
# Epoch [189/750], Combined Loss: 0.0064
# Epoch [190/750], Combined Loss: 0.0064
# Epoch [191/750], Combined Loss: 0.0065
# Epoch [192/750], Combined Loss: 0.0064
# Epoch [193/750], Combined Loss: 0.0067
# Epoch [194/750], Combined Loss: 0.0063
# Epoch [195/750], Combined Loss: 0.0062
# Epoch [196/750], Combined Loss: 0.0067
# Epoch [197/750], Combined Loss: 0.0069
# Epoch [198/750], Combined Loss: 0.0067
# Epoch [199/750], Combined Loss: 0.0067
# Epoch [200/750], Combined Loss: 0.0067
# Early stopping triggered.
# Trial 4 - MSE: 0.0384, MAE: 0.1082, REE: 0.2941, Euclidean Distance: 0.5376
# Starting trial 5...
# Epoch [1/750], Combined Loss: 0.1375
# Epoch [2/750], Combined Loss: 0.0611
# Epoch [3/750], Combined Loss: 0.0605
# Epoch [4/750], Combined Loss: 0.0593
# Epoch [5/750], Combined Loss: 0.0582
# Epoch [6/750], Combined Loss: 0.0603
# Epoch [7/750], Combined Loss: 0.0558
# Epoch [8/750], Combined Loss: 0.0526
# Epoch [9/750], Combined Loss: 0.0535
# Epoch [10/750], Combined Loss: 0.0562
# Epoch [11/750], Combined Loss: 0.0545
# Epoch [12/750], Combined Loss: 0.0564
# Epoch [13/750], Combined Loss: 0.0577
# Epoch [14/750], Combined Loss: 0.0503
# Epoch [15/750], Combined Loss: 0.0539
# Epoch [16/750], Combined Loss: 0.0531
# Epoch [17/750], Combined Loss: 0.0550
# Epoch [18/750], Combined Loss: 0.0526
# Epoch [19/750], Combined Loss: 0.0513
# Epoch [20/750], Combined Loss: 0.0569
# Epoch [21/750], Combined Loss: 0.0464
# Epoch [22/750], Combined Loss: 0.0479
# Epoch [23/750], Combined Loss: 0.0500
# Epoch [24/750], Combined Loss: 0.0386
# Epoch [25/750], Combined Loss: 0.0313
# Epoch [26/750], Combined Loss: 0.0256
# Epoch [27/750], Combined Loss: 0.0224
# Epoch [28/750], Combined Loss: 0.0205
# Epoch [29/750], Combined Loss: 0.0190
# Epoch [30/750], Combined Loss: 0.0180
# Epoch [31/750], Combined Loss: 0.0172
# Epoch [32/750], Combined Loss: 0.0175
# Epoch [33/750], Combined Loss: 0.0164
# Epoch [34/750], Combined Loss: 0.0167
# Epoch [35/750], Combined Loss: 0.0188
# Epoch [36/750], Combined Loss: 0.0149
# Epoch [37/750], Combined Loss: 0.0166
# Epoch [38/750], Combined Loss: 0.0177
# Epoch [39/750], Combined Loss: 0.0161
# Epoch [40/750], Combined Loss: 0.0180
# Epoch [41/750], Combined Loss: 0.0168
# Epoch [42/750], Combined Loss: 0.0158
# Epoch [43/750], Combined Loss: 0.0158
# Epoch [44/750], Combined Loss: 0.0149
# Epoch [45/750], Combined Loss: 0.0156
# Epoch [46/750], Combined Loss: 0.0163
# Epoch [47/750], Combined Loss: 0.0150
# Epoch [48/750], Combined Loss: 0.0155
# Epoch [49/750], Combined Loss: 0.0153
# Epoch [50/750], Combined Loss: 0.0139
# Epoch [51/750], Combined Loss: 0.0130
# Epoch [52/750], Combined Loss: 0.0128
# Epoch [53/750], Combined Loss: 0.0139
# Epoch [54/750], Combined Loss: 0.0129
# Epoch [55/750], Combined Loss: 0.0133
# Epoch [56/750], Combined Loss: 0.0112
# Epoch [57/750], Combined Loss: 0.0107
# Epoch [58/750], Combined Loss: 0.0107
# Epoch [59/750], Combined Loss: 0.0091
# Epoch [60/750], Combined Loss: 0.0089
# Epoch [61/750], Combined Loss: 0.0084
# Epoch [62/750], Combined Loss: 0.0080
# Epoch [63/750], Combined Loss: 0.0078
# Epoch [64/750], Combined Loss: 0.0085
# Epoch [65/750], Combined Loss: 0.0075
# Epoch [66/750], Combined Loss: 0.0073
# Epoch [67/750], Combined Loss: 0.0068
# Epoch [68/750], Combined Loss: 0.0066
# Epoch [69/750], Combined Loss: 0.0068
# Epoch [70/750], Combined Loss: 0.0070
# Epoch [71/750], Combined Loss: 0.0073
# Epoch [72/750], Combined Loss: 0.0063
# Epoch [73/750], Combined Loss: 0.0064
# Epoch [74/750], Combined Loss: 0.0059
# Epoch [75/750], Combined Loss: 0.0063
# Epoch [76/750], Combined Loss: 0.0061
# Epoch [77/750], Combined Loss: 0.0059
# Epoch [78/750], Combined Loss: 0.0058
# Epoch [79/750], Combined Loss: 0.0065
# Epoch [80/750], Combined Loss: 0.0057
# Epoch [81/750], Combined Loss: 0.0062
# Epoch [82/750], Combined Loss: 0.0059
# Epoch [83/750], Combined Loss: 0.0057
# Epoch [84/750], Combined Loss: 0.0062
# Epoch [85/750], Combined Loss: 0.0061
# Epoch [86/750], Combined Loss: 0.0058
# Epoch [87/750], Combined Loss: 0.0060
# Epoch [88/750], Combined Loss: 0.0054
# Epoch [89/750], Combined Loss: 0.0054
# Epoch [90/750], Combined Loss: 0.0049
# Epoch [91/750], Combined Loss: 0.0054
# Epoch [92/750], Combined Loss: 0.0049
# Epoch [93/750], Combined Loss: 0.0057
# Epoch [94/750], Combined Loss: 0.0057
# Epoch [95/750], Combined Loss: 0.0050
# Epoch [96/750], Combined Loss: 0.0050
# Epoch [97/750], Combined Loss: 0.0047
# Epoch [98/750], Combined Loss: 0.0051
# Epoch [99/750], Combined Loss: 0.0043
# Epoch [100/750], Combined Loss: 0.0050
# Epoch [101/750], Combined Loss: 0.0046
# Epoch [102/750], Combined Loss: 0.0052
# Epoch [103/750], Combined Loss: 0.0050
# Epoch [104/750], Combined Loss: 0.0046
# Epoch [105/750], Combined Loss: 0.0050
# Epoch [106/750], Combined Loss: 0.0045
# Epoch [107/750], Combined Loss: 0.0046
# Epoch [108/750], Combined Loss: 0.0047
# Epoch [109/750], Combined Loss: 0.0044
# Epoch [110/750], Combined Loss: 0.0043
# Epoch [111/750], Combined Loss: 0.0043
# Epoch [112/750], Combined Loss: 0.0044
# Epoch [113/750], Combined Loss: 0.0047
# Epoch [114/750], Combined Loss: 0.0043
# Epoch [115/750], Combined Loss: 0.0041
# Epoch [116/750], Combined Loss: 0.0045
# Epoch [117/750], Combined Loss: 0.0044
# Epoch [118/750], Combined Loss: 0.0046
# Epoch [119/750], Combined Loss: 0.0040
# Epoch [120/750], Combined Loss: 0.0043
# Epoch [121/750], Combined Loss: 0.0043
# Epoch [122/750], Combined Loss: 0.0045
# Epoch [123/750], Combined Loss: 0.0044
# Epoch [124/750], Combined Loss: 0.0041
# Epoch [125/750], Combined Loss: 0.0045
# Epoch [126/750], Combined Loss: 0.0042
# Epoch [127/750], Combined Loss: 0.0046
# Epoch [128/750], Combined Loss: 0.0042
# Epoch [129/750], Combined Loss: 0.0041
# Epoch [130/750], Combined Loss: 0.0041
# Epoch [131/750], Combined Loss: 0.0043
# Epoch [132/750], Combined Loss: 0.0043
# Epoch [133/750], Combined Loss: 0.0043
# Epoch [134/750], Combined Loss: 0.0040
# Epoch [135/750], Combined Loss: 0.0041
# Epoch [136/750], Combined Loss: 0.0040
# Epoch [137/750], Combined Loss: 0.0042
# Epoch [138/750], Combined Loss: 0.0043
# Epoch [139/750], Combined Loss: 0.0044
# Epoch [140/750], Combined Loss: 0.0040
# Epoch [141/750], Combined Loss: 0.0043
# Epoch [142/750], Combined Loss: 0.0043
# Epoch [143/750], Combined Loss: 0.0045
# Epoch [144/750], Combined Loss: 0.0040
# Epoch [145/750], Combined Loss: 0.0044
# Epoch [146/750], Combined Loss: 0.0041
# Epoch [147/750], Combined Loss: 0.0044
# Epoch [148/750], Combined Loss: 0.0044
# Epoch [149/750], Combined Loss: 0.0041
# Epoch [150/750], Combined Loss: 0.0041
# Epoch [151/750], Combined Loss: 0.0044
# Epoch [152/750], Combined Loss: 0.0044
# Epoch [153/750], Combined Loss: 0.0048
# Epoch [154/750], Combined Loss: 0.0043
# Epoch [155/750], Combined Loss: 0.0041
# Epoch [156/750], Combined Loss: 0.0040
# Epoch [157/750], Combined Loss: 0.0041
# Epoch [158/750], Combined Loss: 0.0040
# Epoch [159/750], Combined Loss: 0.0045
# Early stopping triggered.
# Trial 5 - MSE: 0.0203, MAE: 0.0975, REE: 0.2055, Euclidean Distance: 0.3742
# Starting trial 6...
# Epoch [1/750], Combined Loss: 0.1136
# Epoch [2/750], Combined Loss: 0.0849
# Epoch [3/750], Combined Loss: 0.0670
# Epoch [4/750], Combined Loss: 0.0650
# Epoch [5/750], Combined Loss: 0.0609
# Epoch [6/750], Combined Loss: 0.0563
# Epoch [7/750], Combined Loss: 0.0555
# Epoch [8/750], Combined Loss: 0.0583
# Epoch [9/750], Combined Loss: 0.0524
# Epoch [10/750], Combined Loss: 0.0509
# Epoch [11/750], Combined Loss: 0.0504
# Epoch [12/750], Combined Loss: 0.0504
# Epoch [13/750], Combined Loss: 0.0484
# Epoch [14/750], Combined Loss: 0.0493
# Epoch [15/750], Combined Loss: 0.0422
# Epoch [16/750], Combined Loss: 0.0420
# Epoch [17/750], Combined Loss: 0.0313
# Epoch [18/750], Combined Loss: 0.0280
# Epoch [19/750], Combined Loss: 0.0218
# Epoch [20/750], Combined Loss: 0.0203
# Epoch [21/750], Combined Loss: 0.0192
# Epoch [22/750], Combined Loss: 0.0190
# Epoch [23/750], Combined Loss: 0.0185
# Epoch [24/750], Combined Loss: 0.0180
# Epoch [25/750], Combined Loss: 0.0176
# Epoch [26/750], Combined Loss: 0.0181
# Epoch [27/750], Combined Loss: 0.0167
# Epoch [28/750], Combined Loss: 0.0176
# Epoch [29/750], Combined Loss: 0.0182
# Epoch [30/750], Combined Loss: 0.0165
# Epoch [31/750], Combined Loss: 0.0154
# Epoch [32/750], Combined Loss: 0.0134
# Epoch [33/750], Combined Loss: 0.0133
# Epoch [34/750], Combined Loss: 0.0123
# Epoch [35/750], Combined Loss: 0.0117
# Epoch [36/750], Combined Loss: 0.0118
# Epoch [37/750], Combined Loss: 0.0113
# Epoch [38/750], Combined Loss: 0.0110
# Epoch [39/750], Combined Loss: 0.0103
# Epoch [40/750], Combined Loss: 0.0112
# Epoch [41/750], Combined Loss: 0.0097
# Epoch [42/750], Combined Loss: 0.0099
# Epoch [43/750], Combined Loss: 0.0098
# Epoch [44/750], Combined Loss: 0.0095
# Epoch [45/750], Combined Loss: 0.0095
# Epoch [46/750], Combined Loss: 0.0094
# Epoch [47/750], Combined Loss: 0.0088
# Epoch [48/750], Combined Loss: 0.0093
# Epoch [49/750], Combined Loss: 0.0093
# Epoch [50/750], Combined Loss: 0.0097
# Epoch [51/750], Combined Loss: 0.0088
# Epoch [52/750], Combined Loss: 0.0087
# Epoch [53/750], Combined Loss: 0.0088
# Epoch [54/750], Combined Loss: 0.0087
# Epoch [55/750], Combined Loss: 0.0086
# Epoch [56/750], Combined Loss: 0.0092
# Epoch [57/750], Combined Loss: 0.0088
# Epoch [58/750], Combined Loss: 0.0090
# Epoch [59/750], Combined Loss: 0.0084
# Epoch [60/750], Combined Loss: 0.0085
# Epoch [61/750], Combined Loss: 0.0095
# Epoch [62/750], Combined Loss: 0.0087
# Epoch [63/750], Combined Loss: 0.0083
# Epoch [64/750], Combined Loss: 0.0082
# Epoch [65/750], Combined Loss: 0.0087
# Epoch [66/750], Combined Loss: 0.0087
# Epoch [67/750], Combined Loss: 0.0085
# Epoch [68/750], Combined Loss: 0.0089
# Epoch [69/750], Combined Loss: 0.0086
# Epoch [70/750], Combined Loss: 0.0088
# Epoch [71/750], Combined Loss: 0.0086
# Epoch [72/750], Combined Loss: 0.0081
# Epoch [73/750], Combined Loss: 0.0079
# Epoch [74/750], Combined Loss: 0.0083
# Epoch [75/750], Combined Loss: 0.0086
# Epoch [76/750], Combined Loss: 0.0082
# Epoch [77/750], Combined Loss: 0.0080
# Epoch [78/750], Combined Loss: 0.0082
# Epoch [79/750], Combined Loss: 0.0080
# Epoch [80/750], Combined Loss: 0.0081
# Epoch [81/750], Combined Loss: 0.0077
# Epoch [82/750], Combined Loss: 0.0081
# Epoch [83/750], Combined Loss: 0.0086
# Epoch [84/750], Combined Loss: 0.0082
# Epoch [85/750], Combined Loss: 0.0081
# Epoch [86/750], Combined Loss: 0.0081
# Epoch [87/750], Combined Loss: 0.0077
# Epoch [88/750], Combined Loss: 0.0083
# Epoch [89/750], Combined Loss: 0.0085
# Epoch [90/750], Combined Loss: 0.0080
# Epoch [91/750], Combined Loss: 0.0082
# Epoch [92/750], Combined Loss: 0.0088
# Epoch [93/750], Combined Loss: 0.0078
# Epoch [94/750], Combined Loss: 0.0088
# Epoch [95/750], Combined Loss: 0.0082
# Epoch [96/750], Combined Loss: 0.0084
# Epoch [97/750], Combined Loss: 0.0088
# Epoch [98/750], Combined Loss: 0.0077
# Epoch [99/750], Combined Loss: 0.0079
# Epoch [100/750], Combined Loss: 0.0079
# Epoch [101/750], Combined Loss: 0.0084
# Epoch [102/750], Combined Loss: 0.0082
# Epoch [103/750], Combined Loss: 0.0078
# Epoch [104/750], Combined Loss: 0.0075
# Epoch [105/750], Combined Loss: 0.0076
# Epoch [106/750], Combined Loss: 0.0078
# Epoch [107/750], Combined Loss: 0.0072
# Epoch [108/750], Combined Loss: 0.0079
# Epoch [109/750], Combined Loss: 0.0082
# Epoch [110/750], Combined Loss: 0.0080
# Epoch [111/750], Combined Loss: 0.0082
# Epoch [112/750], Combined Loss: 0.0075
# Epoch [113/750], Combined Loss: 0.0084
# Epoch [114/750], Combined Loss: 0.0074
# Epoch [115/750], Combined Loss: 0.0076
# Epoch [116/750], Combined Loss: 0.0078
# Epoch [117/750], Combined Loss: 0.0077
# Epoch [118/750], Combined Loss: 0.0076
# Epoch [119/750], Combined Loss: 0.0076
# Epoch [120/750], Combined Loss: 0.0079
# Epoch [121/750], Combined Loss: 0.0078
# Epoch [122/750], Combined Loss: 0.0076
# Epoch [123/750], Combined Loss: 0.0081
# Epoch [124/750], Combined Loss: 0.0071
# Epoch [125/750], Combined Loss: 0.0076
# Epoch [126/750], Combined Loss: 0.0080
# Epoch [127/750], Combined Loss: 0.0077
# Epoch [128/750], Combined Loss: 0.0077
# Epoch [129/750], Combined Loss: 0.0075
# Epoch [130/750], Combined Loss: 0.0075
# Epoch [131/750], Combined Loss: 0.0072
# Epoch [132/750], Combined Loss: 0.0071
# Epoch [133/750], Combined Loss: 0.0077
# Epoch [134/750], Combined Loss: 0.0071
# Epoch [135/750], Combined Loss: 0.0069
# Epoch [136/750], Combined Loss: 0.0076
# Epoch [137/750], Combined Loss: 0.0073
# Epoch [138/750], Combined Loss: 0.0070
# Epoch [139/750], Combined Loss: 0.0072
# Epoch [140/750], Combined Loss: 0.0067
# Epoch [141/750], Combined Loss: 0.0074
# Epoch [142/750], Combined Loss: 0.0067
# Epoch [143/750], Combined Loss: 0.0068
# Epoch [144/750], Combined Loss: 0.0065
# Epoch [145/750], Combined Loss: 0.0072
# Epoch [146/750], Combined Loss: 0.0067
# Epoch [147/750], Combined Loss: 0.0069
# Epoch [148/750], Combined Loss: 0.0064
# Epoch [149/750], Combined Loss: 0.0062
# Epoch [150/750], Combined Loss: 0.0067
# Epoch [151/750], Combined Loss: 0.0068
# Epoch [152/750], Combined Loss: 0.0069
# Epoch [153/750], Combined Loss: 0.0064
# Epoch [154/750], Combined Loss: 0.0064
# Epoch [155/750], Combined Loss: 0.0066
# Epoch [156/750], Combined Loss: 0.0074
# Epoch [157/750], Combined Loss: 0.0066
# Epoch [158/750], Combined Loss: 0.0064
# Epoch [159/750], Combined Loss: 0.0063
# Epoch [160/750], Combined Loss: 0.0069
# Epoch [161/750], Combined Loss: 0.0067
# Epoch [162/750], Combined Loss: 0.0067
# Epoch [163/750], Combined Loss: 0.0067
# Epoch [164/750], Combined Loss: 0.0068
# Epoch [165/750], Combined Loss: 0.0068
# Epoch [166/750], Combined Loss: 0.0068
# Epoch [167/750], Combined Loss: 0.0071
# Epoch [168/750], Combined Loss: 0.0066
# Epoch [169/750], Combined Loss: 0.0063
# Epoch [170/750], Combined Loss: 0.0066
# Epoch [171/750], Combined Loss: 0.0068
# Epoch [172/750], Combined Loss: 0.0065
# Epoch [173/750], Combined Loss: 0.0067
# Epoch [174/750], Combined Loss: 0.0063
# Epoch [175/750], Combined Loss: 0.0063
# Epoch [176/750], Combined Loss: 0.0065
# Epoch [177/750], Combined Loss: 0.0064
# Epoch [178/750], Combined Loss: 0.0064
# Epoch [179/750], Combined Loss: 0.0065
# Epoch [180/750], Combined Loss: 0.0064
# Epoch [181/750], Combined Loss: 0.0066
# Epoch [182/750], Combined Loss: 0.0065
# Epoch [183/750], Combined Loss: 0.0066
# Epoch [184/750], Combined Loss: 0.0066
# Epoch [185/750], Combined Loss: 0.0067
# Epoch [186/750], Combined Loss: 0.0062
# Epoch [187/750], Combined Loss: 0.0069
# Epoch [188/750], Combined Loss: 0.0065
# Epoch [189/750], Combined Loss: 0.0065
# Early stopping triggered.
# Trial 6 - MSE: 0.0351, MAE: 0.0817, REE: 0.2723, Euclidean Distance: 0.5029
# Starting trial 7...
# Epoch [1/750], Combined Loss: 0.1367
# Epoch [2/750], Combined Loss: 0.0736
# Epoch [3/750], Combined Loss: 0.0626
# Epoch [4/750], Combined Loss: 0.0618
# Epoch [5/750], Combined Loss: 0.0605
# Epoch [6/750], Combined Loss: 0.0537
# Epoch [7/750], Combined Loss: 0.0564
# Epoch [8/750], Combined Loss: 0.0551
# Epoch [9/750], Combined Loss: 0.0521
# Epoch [10/750], Combined Loss: 0.0506
# Epoch [11/750], Combined Loss: 0.0548
# Epoch [12/750], Combined Loss: 0.0542
# Epoch [13/750], Combined Loss: 0.0497
# Epoch [14/750], Combined Loss: 0.0517
# Epoch [15/750], Combined Loss: 0.0484
# Epoch [16/750], Combined Loss: 0.0411
# Epoch [17/750], Combined Loss: 0.0342
# Epoch [18/750], Combined Loss: 0.0286
# Epoch [19/750], Combined Loss: 0.0222
# Epoch [20/750], Combined Loss: 0.0199
# Epoch [21/750], Combined Loss: 0.0182
# Epoch [22/750], Combined Loss: 0.0208
# Epoch [23/750], Combined Loss: 0.0192
# Epoch [24/750], Combined Loss: 0.0192
# Epoch [25/750], Combined Loss: 0.0178
# Epoch [26/750], Combined Loss: 0.0186
# Epoch [27/750], Combined Loss: 0.0188
# Epoch [28/750], Combined Loss: 0.0188
# Epoch [29/750], Combined Loss: 0.0179
# Epoch [30/750], Combined Loss: 0.0164
# Epoch [31/750], Combined Loss: 0.0186
# Epoch [32/750], Combined Loss: 0.0147
# Epoch [33/750], Combined Loss: 0.0167
# Epoch [34/750], Combined Loss: 0.0160
# Epoch [35/750], Combined Loss: 0.0167
# Epoch [36/750], Combined Loss: 0.0154
# Epoch [37/750], Combined Loss: 0.0147
# Epoch [38/750], Combined Loss: 0.0136
# Epoch [39/750], Combined Loss: 0.0139
# Epoch [40/750], Combined Loss: 0.0135
# Epoch [41/750], Combined Loss: 0.0130
# Epoch [42/750], Combined Loss: 0.0120
# Epoch [43/750], Combined Loss: 0.0119
# Epoch [44/750], Combined Loss: 0.0116
# Epoch [45/750], Combined Loss: 0.0115
# Epoch [46/750], Combined Loss: 0.0121
# Epoch [47/750], Combined Loss: 0.0109
# Epoch [48/750], Combined Loss: 0.0117
# Epoch [49/750], Combined Loss: 0.0115
# Epoch [50/750], Combined Loss: 0.0110
# Epoch [51/750], Combined Loss: 0.0112
# Epoch [52/750], Combined Loss: 0.0115
# Epoch [53/750], Combined Loss: 0.0115
# Epoch [54/750], Combined Loss: 0.0109
# Epoch [55/750], Combined Loss: 0.0106
# Epoch [56/750], Combined Loss: 0.0100
# Epoch [57/750], Combined Loss: 0.0106
# Epoch [58/750], Combined Loss: 0.0107
# Epoch [59/750], Combined Loss: 0.0113
# Epoch [60/750], Combined Loss: 0.0106
# Epoch [61/750], Combined Loss: 0.0102
# Epoch [62/750], Combined Loss: 0.0102
# ...
# Epoch [17/750], Combined Loss: 0.0478
# Epoch [18/750], Combined Loss: 0.0425
# Epoch [19/750], Combined Loss: 0.0330
# Epoch [20/750], Combined Loss: 0.0194
# Epoch [21/750], Combined Loss: 0.0166
# Epoch [22/750], Combined Loss: 0.0162
# Epoch [23/750], Combined Loss: 0.0157
# Epoch [24/750], Combined Loss: 0.0179
# Epoch [25/750], Combined Loss: 0.0178
# Epoch [26/750], Combined Loss: 0.0175
# Epoch [27/750], Combined Loss: 0.0190
# Epoch [28/750], Combined Loss: 0.0168
# Epoch [29/750], Combined Loss: 0.0184
# Epoch [30/750], Combined Loss: 0.0168
# Epoch [31/750], Combined Loss: 0.0172
# Epoch [32/750], Combined Loss: 0.0206
# Epoch [33/750], Combined Loss: 0.0182
# Epoch [34/750], Combined Loss: 0.0175
# Epoch [35/750], Combined Loss: 0.0190
# Epoch [36/750], Combined Loss: 0.0175
# Epoch [37/750], Combined Loss: 0.0170
# Epoch [38/750], Combined Loss: 0.0181
# Epoch [39/750], Combined Loss: 0.0187
# Epoch [40/750], Combined Loss: 0.0190
# Epoch [41/750], Combined Loss: 0.0171
# Epoch [42/750], Combined Loss: 0.0181
# Epoch [43/750], Combined Loss: 0.0180
# Epoch [44/750], Combined Loss: 0.0197
# Epoch [45/750], Combined Loss: 0.0185
# Epoch [46/750], Combined Loss: 0.0163
# Epoch [47/750], Combined Loss: 0.0201
# Epoch [48/750], Combined Loss: 0.0172
# Epoch [49/750], Combined Loss: 0.0189
# Epoch [50/750], Combined Loss: 0.0161
# Epoch [51/750], Combined Loss: 0.0185
# Epoch [52/750], Combined Loss: 0.0186
# Epoch [53/750], Combined Loss: 0.0166
# Epoch [54/750], Combined Loss: 0.0195
# Epoch [55/750], Combined Loss: 0.0179
# Epoch [56/750], Combined Loss: 0.0199
# Epoch [57/750], Combined Loss: 0.0167
# Epoch [58/750], Combined Loss: 0.0152
# Epoch [59/750], Combined Loss: 0.0163
# Epoch [60/750], Combined Loss: 0.0155
# Epoch [61/750], Combined Loss: 0.0147
# Epoch [62/750], Combined Loss: 0.0149
# Epoch [63/750], Combined Loss: 0.0141
# Epoch [64/750], Combined Loss: 0.0140
# Epoch [65/750], Combined Loss: 0.0140
# Epoch [66/750], Combined Loss: 0.0128
# Epoch [67/750], Combined Loss: 0.0132
# Epoch [68/750], Combined Loss: 0.0126
# Epoch [69/750], Combined Loss: 0.0115
# Epoch [70/750], Combined Loss: 0.0106
# Epoch [71/750], Combined Loss: 0.0095
# Epoch [72/750], Combined Loss: 0.0103
# Epoch [73/750], Combined Loss: 0.0101
# Epoch [74/750], Combined Loss: 0.0110
# Epoch [75/750], Combined Loss: 0.0100
# Epoch [76/750], Combined Loss: 0.0099
# Epoch [77/750], Combined Loss: 0.0106
# Epoch [78/750], Combined Loss: 0.0101
# Epoch [79/750], Combined Loss: 0.0092
# Epoch [80/750], Combined Loss: 0.0100
# Epoch [81/750], Combined Loss: 0.0100
# Epoch [82/750], Combined Loss: 0.0095
# Epoch [83/750], Combined Loss: 0.0087
# Epoch [84/750], Combined Loss: 0.0100
# Epoch [85/750], Combined Loss: 0.0089
# Epoch [86/750], Combined Loss: 0.0097
# Epoch [87/750], Combined Loss: 0.0092
# Epoch [88/750], Combined Loss: 0.0089
# Epoch [89/750], Combined Loss: 0.0092
# Epoch [90/750], Combined Loss: 0.0098
# Epoch [91/750], Combined Loss: 0.0088
# Epoch [92/750], Combined Loss: 0.0090
# Epoch [93/750], Combined Loss: 0.0086
# Epoch [94/750], Combined Loss: 0.0097
# Epoch [95/750], Combined Loss: 0.0093
# Epoch [96/750], Combined Loss: 0.0085
# Epoch [97/750], Combined Loss: 0.0092
# Epoch [98/750], Combined Loss: 0.0083
# Epoch [99/750], Combined Loss: 0.0088
# Epoch [100/750], Combined Loss: 0.0097
# Epoch [101/750], Combined Loss: 0.0096
# Epoch [102/750], Combined Loss: 0.0092
# Epoch [103/750], Combined Loss: 0.0104
# Epoch [104/750], Combined Loss: 0.0097
# Epoch [105/750], Combined Loss: 0.0095
# Epoch [106/750], Combined Loss: 0.0095
# Epoch [107/750], Combined Loss: 0.0100
# Epoch [108/750], Combined Loss: 0.0092
# Epoch [109/750], Combined Loss: 0.0095
# Epoch [110/750], Combined Loss: 0.0087
# Epoch [111/750], Combined Loss: 0.0092
# Epoch [112/750], Combined Loss: 0.0101
# Epoch [113/750], Combined Loss: 0.0093
# Epoch [114/750], Combined Loss: 0.0101
# Epoch [115/750], Combined Loss: 0.0099
# Epoch [116/750], Combined Loss: 0.0107
# Epoch [117/750], Combined Loss: 0.0093
# Epoch [118/750], Combined Loss: 0.0107
# Epoch [119/750], Combined Loss: 0.0098
# Epoch [120/750], Combined Loss: 0.0091
# Epoch [121/750], Combined Loss: 0.0091
# Epoch [122/750], Combined Loss: 0.0092
# Epoch [123/750], Combined Loss: 0.0100
# Epoch [124/750], Combined Loss: 0.0112
# Epoch [125/750], Combined Loss: 0.0091
# Epoch [126/750], Combined Loss: 0.0089
# Epoch [127/750], Combined Loss: 0.0101
# Epoch [128/750], Combined Loss: 0.0096
# Epoch [129/750], Combined Loss: 0.0100
# Epoch [130/750], Combined Loss: 0.0099
# Epoch [131/750], Combined Loss: 0.0099
# Epoch [132/750], Combined Loss: 0.0111
# Epoch [133/750], Combined Loss: 0.0107
# Epoch [134/750], Combined Loss: 0.0108
# Epoch [135/750], Combined Loss: 0.0096
# Epoch [136/750], Combined Loss: 0.0107
# Epoch [137/750], Combined Loss: 0.0104
# Epoch [138/750], Combined Loss: 0.0112
# Early stopping triggered.
# Trial 9 - MSE: 0.0173, MAE: 0.0883, REE: 0.2139, Euclidean Distance: 0.3888
# Starting trial 10...
# Epoch [1/750], Combined Loss: 0.1043
# Epoch [2/750], Combined Loss: 0.0652
# Epoch [3/750], Combined Loss: 0.0579
# Epoch [4/750], Combined Loss: 0.0624
# Epoch [5/750], Combined Loss: 0.0620
# Epoch [6/750], Combined Loss: 0.0606
# Epoch [7/750], Combined Loss: 0.0562
# Epoch [8/750], Combined Loss: 0.0589
# Epoch [9/750], Combined Loss: 0.0559
# Epoch [10/750], Combined Loss: 0.0526
# Epoch [11/750], Combined Loss: 0.0545
# Epoch [12/750], Combined Loss: 0.0558
# Epoch [13/750], Combined Loss: 0.0566
# Epoch [14/750], Combined Loss: 0.0529
# Epoch [15/750], Combined Loss: 0.0547
# Epoch [16/750], Combined Loss: 0.0489
# Epoch [17/750], Combined Loss: 0.0425
# Epoch [18/750], Combined Loss: 0.0320
# Epoch [19/750], Combined Loss: 0.0215
# Epoch [20/750], Combined Loss: 0.0174
# Epoch [21/750], Combined Loss: 0.0168
# Epoch [22/750], Combined Loss: 0.0163
# Epoch [23/750], Combined Loss: 0.0157
# Epoch [24/750], Combined Loss: 0.0152
# Epoch [25/750], Combined Loss: 0.0145
# Epoch [26/750], Combined Loss: 0.0152
# Epoch [27/750], Combined Loss: 0.0139
# Epoch [28/750], Combined Loss: 0.0163
# Epoch [29/750], Combined Loss: 0.0164
# Epoch [30/750], Combined Loss: 0.0139
# Epoch [31/750], Combined Loss: 0.0160
# Epoch [32/750], Combined Loss: 0.0142
# Epoch [33/750], Combined Loss: 0.0149
# Epoch [34/750], Combined Loss: 0.0159
# Epoch [35/750], Combined Loss: 0.0160
# Epoch [36/750], Combined Loss: 0.0136
# Epoch [37/750], Combined Loss: 0.0159
# Epoch [38/750], Combined Loss: 0.0165
# Epoch [39/750], Combined Loss: 0.0162
# Epoch [40/750], Combined Loss: 0.0161
# Epoch [41/750], Combined Loss: 0.0141
# Epoch [42/750], Combined Loss: 0.0153
# Epoch [43/750], Combined Loss: 0.0152
# Epoch [44/750], Combined Loss: 0.0145
# Epoch [45/750], Combined Loss: 0.0148
# Epoch [46/750], Combined Loss: 0.0140
# Epoch [47/750], Combined Loss: 0.0148
# Epoch [48/750], Combined Loss: 0.0128
# Epoch [49/750], Combined Loss: 0.0149
# Epoch [50/750], Combined Loss: 0.0135
# Epoch [51/750], Combined Loss: 0.0120
# Epoch [52/750], Combined Loss: 0.0125
# Epoch [53/750], Combined Loss: 0.0111
# Epoch [54/750], Combined Loss: 0.0113
# Epoch [55/750], Combined Loss: 0.0098
# Epoch [56/750], Combined Loss: 0.0096
# Epoch [57/750], Combined Loss: 0.0101
# Epoch [58/750], Combined Loss: 0.0092
# Epoch [59/750], Combined Loss: 0.0093
# Epoch [60/750], Combined Loss: 0.0086
# Epoch [61/750], Combined Loss: 0.0086
# Epoch [62/750], Combined Loss: 0.0088
# Epoch [63/750], Combined Loss: 0.0085
# Epoch [64/750], Combined Loss: 0.0084
# Epoch [65/750], Combined Loss: 0.0084
# Epoch [66/750], Combined Loss: 0.0087
# Epoch [67/750], Combined Loss: 0.0085
# Epoch [68/750], Combined Loss: 0.0076
# Epoch [69/750], Combined Loss: 0.0077
# Epoch [70/750], Combined Loss: 0.0073
# Epoch [71/750], Combined Loss: 0.0081
# Epoch [72/750], Combined Loss: 0.0082
# Epoch [73/750], Combined Loss: 0.0075
# Epoch [74/750], Combined Loss: 0.0074
# Epoch [75/750], Combined Loss: 0.0078
# Epoch [76/750], Combined Loss: 0.0079
# Epoch [77/750], Combined Loss: 0.0079
# Epoch [78/750], Combined Loss: 0.0073
# Epoch [79/750], Combined Loss: 0.0079
# Epoch [80/750], Combined Loss: 0.0072
# Epoch [81/750], Combined Loss: 0.0077
# Epoch [82/750], Combined Loss: 0.0082
# Epoch [83/750], Combined Loss: 0.0077
# Epoch [84/750], Combined Loss: 0.0070
# Epoch [85/750], Combined Loss: 0.0074
# Epoch [86/750], Combined Loss: 0.0074
# Epoch [87/750], Combined Loss: 0.0073
# Epoch [88/750], Combined Loss: 0.0069
# Epoch [89/750], Combined Loss: 0.0070
# Epoch [90/750], Combined Loss: 0.0075
# Epoch [91/750], Combined Loss: 0.0073
# Epoch [92/750], Combined Loss: 0.0072
# Epoch [93/750], Combined Loss: 0.0070
# Epoch [94/750], Combined Loss: 0.0074
# Epoch [95/750], Combined Loss: 0.0074
# Epoch [96/750], Combined Loss: 0.0073
# Epoch [97/750], Combined Loss: 0.0069
# Epoch [98/750], Combined Loss: 0.0067
# Epoch [99/750], Combined Loss: 0.0069
# Epoch [100/750], Combined Loss: 0.0061
# Epoch [101/750], Combined Loss: 0.0064
# Epoch [102/750], Combined Loss: 0.0063
# Epoch [103/750], Combined Loss: 0.0060
# Epoch [104/750], Combined Loss: 0.0061
# Epoch [105/750], Combined Loss: 0.0059
# Epoch [106/750], Combined Loss: 0.0055
# Epoch [107/750], Combined Loss: 0.0057
# Epoch [108/750], Combined Loss: 0.0058
# Epoch [109/750], Combined Loss: 0.0060
# Epoch [110/750], Combined Loss: 0.0058
# Epoch [111/750], Combined Loss: 0.0063
# Epoch [112/750], Combined Loss: 0.0054
# Epoch [113/750], Combined Loss: 0.0056
# Epoch [114/750], Combined Loss: 0.0054
# Epoch [115/750], Combined Loss: 0.0053
# Epoch [116/750], Combined Loss: 0.0057
# Epoch [117/750], Combined Loss: 0.0057
# Epoch [118/750], Combined Loss: 0.0056
# Epoch [119/750], Combined Loss: 0.0056
# Epoch [120/750], Combined Loss: 0.0054
# Epoch [121/750], Combined Loss: 0.0057
# Epoch [122/750], Combined Loss: 0.0054
# Epoch [123/750], Combined Loss: 0.0056
# Epoch [124/750], Combined Loss: 0.0061
# Epoch [125/750], Combined Loss: 0.0058
# Epoch [126/750], Combined Loss: 0.0054
# Epoch [127/750], Combined Loss: 0.0057
# Epoch [128/750], Combined Loss: 0.0057
# Epoch [129/750], Combined Loss: 0.0059
# Epoch [130/750], Combined Loss: 0.0059
# Epoch [131/750], Combined Loss: 0.0057
# Epoch [132/750], Combined Loss: 0.0055
# Epoch [133/750], Combined Loss: 0.0058
# Epoch [134/750], Combined Loss: 0.0055
# Epoch [135/750], Combined Loss: 0.0052
# Epoch [136/750], Combined Loss: 0.0058
# Epoch [137/750], Combined Loss: 0.0051
# Epoch [138/750], Combined Loss: 0.0058
# Epoch [139/750], Combined Loss: 0.0059
# Epoch [140/750], Combined Loss: 0.0056
# Epoch [141/750], Combined Loss: 0.0059
# Epoch [142/750], Combined Loss: 0.0054
# Epoch [143/750], Combined Loss: 0.0058
# Epoch [144/750], Combined Loss: 0.0055
# Epoch [145/750], Combined Loss: 0.0057
# Epoch [146/750], Combined Loss: 0.0059
# Epoch [147/750], Combined Loss: 0.0058
# Epoch [148/750], Combined Loss: 0.0058
# Epoch [149/750], Combined Loss: 0.0058
# Epoch [150/750], Combined Loss: 0.0058
# Epoch [151/750], Combined Loss: 0.0056
# Epoch [152/750], Combined Loss: 0.0055
# Epoch [153/750], Combined Loss: 0.0055
# Epoch [154/750], Combined Loss: 0.0054
# Epoch [155/750], Combined Loss: 0.0056
# Epoch [156/750], Combined Loss: 0.0051
# Epoch [157/750], Combined Loss: 0.0050
# Epoch [158/750], Combined Loss: 0.0051
# Epoch [159/750], Combined Loss: 0.0055
# Epoch [160/750], Combined Loss: 0.0050
# Epoch [161/750], Combined Loss: 0.0049
# Epoch [162/750], Combined Loss: 0.0054
# Epoch [163/750], Combined Loss: 0.0054
# Epoch [164/750], Combined Loss: 0.0055
# Epoch [165/750], Combined Loss: 0.0054
# Epoch [166/750], Combined Loss: 0.0057
# Epoch [167/750], Combined Loss: 0.0062
# Epoch [168/750], Combined Loss: 0.0061
# Epoch [169/750], Combined Loss: 0.0054
# Epoch [170/750], Combined Loss: 0.0051
# Epoch [171/750], Combined Loss: 0.0051
# Epoch [172/750], Combined Loss: 0.0053
# Epoch [173/750], Combined Loss: 0.0054
# Epoch [174/750], Combined Loss: 0.0056
# Epoch [175/750], Combined Loss: 0.0051
# Epoch [176/750], Combined Loss: 0.0050
# Epoch [177/750], Combined Loss: 0.0058
# Epoch [178/750], Combined Loss: 0.0049
# Epoch [179/750], Combined Loss: 0.0051
# Epoch [180/750], Combined Loss: 0.0054
# Epoch [181/750], Combined Loss: 0.0054
# Epoch [182/750], Combined Loss: 0.0053
# Epoch [183/750], Combined Loss: 0.0053
# Epoch [184/750], Combined Loss: 0.0053
# Epoch [185/750], Combined Loss: 0.0048
# Epoch [186/750], Combined Loss: 0.0051
# Epoch [187/750], Combined Loss: 0.0050
# Epoch [188/750], Combined Loss: 0.0055
# Epoch [189/750], Combined Loss: 0.0050
# Epoch [190/750], Combined Loss: 0.0052
# Epoch [191/750], Combined Loss: 0.0061
# Epoch [192/750], Combined Loss: 0.0050
# Epoch [193/750], Combined Loss: 0.0048
# Epoch [194/750], Combined Loss: 0.0051
# Epoch [195/750], Combined Loss: 0.0049
# Epoch [196/750], Combined Loss: 0.0054
# Epoch [197/750], Combined Loss: 0.0049
# Epoch [198/750], Combined Loss: 0.0054
# Epoch [199/750], Combined Loss: 0.0052
# Epoch [200/750], Combined Loss: 0.0048
# Epoch [201/750], Combined Loss: 0.0059
# Epoch [202/750], Combined Loss: 0.0056
# Epoch [203/750], Combined Loss: 0.0050
# Epoch [204/750], Combined Loss: 0.0050
# Epoch [205/750], Combined Loss: 0.0048
# Epoch [206/750], Combined Loss: 0.0050
# Epoch [207/750], Combined Loss: 0.0052
# Epoch [208/750], Combined Loss: 0.0048
# Epoch [209/750], Combined Loss: 0.0049
# Epoch [210/750], Combined Loss: 0.0050
# Epoch [211/750], Combined Loss: 0.0049
# Epoch [212/750], Combined Loss: 0.0047
# Epoch [213/750], Combined Loss: 0.0050
# Epoch [214/750], Combined Loss: 0.0048
# Epoch [215/750], Combined Loss: 0.0046
# Epoch [216/750], Combined Loss: 0.0046
# Epoch [217/750], Combined Loss: 0.0046
# Epoch [218/750], Combined Loss: 0.0054
# Epoch [219/750], Combined Loss: 0.0051
# Epoch [220/750], Combined Loss: 0.0051
# Epoch [221/750], Combined Loss: 0.0048
# Epoch [222/750], Combined Loss: 0.0046
# Epoch [223/750], Combined Loss: 0.0049
# Epoch [224/750], Combined Loss: 0.0045
# Epoch [225/750], Combined Loss: 0.0047
# Epoch [226/750], Combined Loss: 0.0044
# Epoch [227/750], Combined Loss: 0.0046
# Epoch [228/750], Combined Loss: 0.0046
# Epoch [229/750], Combined Loss: 0.0046
# Epoch [230/750], Combined Loss: 0.0048
# Epoch [231/750], Combined Loss: 0.0047
# Epoch [232/750], Combined Loss: 0.0046
# Epoch [233/750], Combined Loss: 0.0046
# Epoch [234/750], Combined Loss: 0.0045
# Epoch [235/750], Combined Loss: 0.0045
# Epoch [236/750], Combined Loss: 0.0045
# Epoch [237/750], Combined Loss: 0.0048
# Epoch [238/750], Combined Loss: 0.0044
# Epoch [239/750], Combined Loss: 0.0045
# Epoch [240/750], Combined Loss: 0.0046
# Epoch [241/750], Combined Loss: 0.0046
# Epoch [242/750], Combined Loss: 0.0044
# Epoch [243/750], Combined Loss: 0.0046
# Epoch [244/750], Combined Loss: 0.0052
# Epoch [245/750], Combined Loss: 0.0048
# Epoch [246/750], Combined Loss: 0.0050
# Epoch [247/750], Combined Loss: 0.0043
# Epoch [248/750], Combined Loss: 0.0048
# Epoch [249/750], Combined Loss: 0.0048
# Epoch [250/750], Combined Loss: 0.0045
# Epoch [251/750], Combined Loss: 0.0047
# Epoch [252/750], Combined Loss: 0.0048
# Epoch [253/750], Combined Loss: 0.0044
# Epoch [254/750], Combined Loss: 0.0046
# Epoch [255/750], Combined Loss: 0.0046
# Epoch [256/750], Combined Loss: 0.0046
# Epoch [257/750], Combined Loss: 0.0044
# Epoch [258/750], Combined Loss: 0.0049
# Epoch [259/750], Combined Loss: 0.0044
# Epoch [260/750], Combined Loss: 0.0045
# Epoch [261/750], Combined Loss: 0.0046
# Epoch [262/750], Combined Loss: 0.0049
# Epoch [263/750], Combined Loss: 0.0045
# Epoch [264/750], Combined Loss: 0.0048
# Epoch [265/750], Combined Loss: 0.0055
# Epoch [266/750], Combined Loss: 0.0047
# Epoch [267/750], Combined Loss: 0.0047
# Epoch [268/750], Combined Loss: 0.0047
# Epoch [269/750], Combined Loss: 0.0047
# Epoch [270/750], Combined Loss: 0.0047
# Epoch [271/750], Combined Loss: 0.0047
# Epoch [272/750], Combined Loss: 0.0048
# Epoch [273/750], Combined Loss: 0.0047
# Epoch [274/750], Combined Loss: 0.0046
# Epoch [275/750], Combined Loss: 0.0047
# Epoch [276/750], Combined Loss: 0.0046
# Epoch [277/750], Combined Loss: 0.0045
# Epoch [278/750], Combined Loss: 0.0046
# Epoch [279/750], Combined Loss: 0.0043
# Epoch [280/750], Combined Loss: 0.0049
# Epoch [281/750], Combined Loss: 0.0046
# Epoch [282/750], Combined Loss: 0.0045
# Epoch [283/750], Combined Loss: 0.0045
# Epoch [284/750], Combined Loss: 0.0047
# Epoch [285/750], Combined Loss: 0.0043
# Epoch [286/750], Combined Loss: 0.0047
# Epoch [287/750], Combined Loss: 0.0048
# Early stopping triggered.
# Trial 10 - MSE: 0.0149, MAE: 0.0844, REE: 0.1844, Euclidean Distance: 0.3368

# %%
num_trials = 10

# Create a 2x5 grid of subplots
fig, axes = plt.subplots(2, 5, figsize=(25, 10))
axes = axes.flatten()  # Flatten the 2D array of axes to 1D for easy indexing

# Plot Reconstruction Error Percentage
for trial in range(num_trials):
    ax = axes[trial]
    ax.scatter(range(len(error_percentages[trial])), error_percentages[trial], color='blue')
    ax.set_ylim(0, 200)
    ax.set_title(f'Reconstruction Error Percentage - Trial {trial+1}')
    ax.set_xlabel('Data Point')
    ax.set_ylabel('Error Percentage')

# Adjust layout
plt.tight_layout()
plt.show()

# %%
num_trials = 10

# Create a 2x5 grid of subplots
fig, axes = plt.subplots(2, 5, figsize=(25, 10))
axes = axes.flatten()  # Flatten the 2D array of axes to 1D for easy indexing

# Plot t-SNE Visualization
for trial in range(num_trials):
    ax = axes[trial]
    ax.scatter(t_sne_results[trial][:len(X_test), 0], t_sne_results[trial][:len(X_test), 1], label="Original", alpha=0.5)
    ax.scatter(t_sne_results[trial][len(X_test):, 0], t_sne_results[trial][len(X_test):, 1], label="Reconstructed", alpha=0.5)
    ax.legend()
    ax.set_title(f't-SNE Visualization - Trial {trial+1}')

# Adjust layout
plt.tight_layout()
plt.show()

# %%
num_trials = 10

# Create a 2x5 grid of subplots
fig, axes = plt.subplots(2, 5, figsize=(25, 10))
axes = axes.flatten()  # Flatten the 2D array of axes to 1D for easy indexing

# Plot PCA Projection
for trial in range(num_trials):
    ax = axes[trial]
    ax.scatter(pca_results[trial][:len(X_test), 0], pca_results[trial][:len(X_test), 1], label="Original", alpha=0.5)
    ax.scatter(pca_results[trial][len(X_test):, 0], pca_results[trial][len(X_test):, 1], label="Reconstructed", alpha=0.5)
    ax.legend()
    ax.set_title(f'PCA Projection - Trial {trial+1}')

# Adjust layout
plt.tight_layout()
plt.show()

# %%
count = 1

for result in metrics:
    print(f"Trial {count}")
    count += 1
    print("MSE:", result[0])
    print("MAE:", result[1])
    print("REE:", result[2])
    print("Euclidean Distance:", result[3])
    print()
# Out:
# Trial 1
# MSE: 0.044861972543843345
# MAE: 0.10644499730697367
# REE: 0.32077577143895397
# Euclidean Distance: 0.5791302669658681
#
# Trial 2
# MSE: 0.02747723071402912
# MAE: 0.10582935033947759
# REE: 0.24798219521273382
# Euclidean Distance: 0.44682756064401796
#
# Trial 3
# MSE: 0.02713607411829143
# MAE: 0.10657590694084919
# REE: 0.251799825938592
# Euclidean Distance: 0.45705981798634304
#
# Trial 4
# MSE: 0.03844215978672251
# MAE: 0.10821415254861326
# REE: 0.2940879375963724
# Euclidean Distance: 0.5376492341009488
#
# Trial 5
# MSE: 0.02030696417596402
# MAE: 0.09752664029222749
# REE: 0.2055149019688452
# Euclidean Distance: 0.3741959653255769
#
# Trial 6
# MSE: 0.03510984533553569
# MAE: 0.08166384405230363
# REE: 0.27227624189327065
# Euclidean Distance: 0.5029495920079502
#
# Trial 7
# MSE: 0.04248071715511131
# MAE: 0.13407085975767544
# REE: 0.32509532881999403
# Euclidean Distance: 0.5881263728781947
#
# Trial 8
# MSE: 0.03693391205833276
# MAE: 0.11300956369463842
# REE: 0.32814530955306914
# Euclidean Distance: 0.5678172765980557
#
# Trial 9
# MSE: 0.017277437605637696
# MAE: 0.08832832658709247
# REE: 0.21389376337860883
# Euclidean Distance: 0.3888258068121309
#
# Trial 10
# MSE: 0.014889580488710311
# MAE: 0.0844091032305813
# REE: 0.18441370507048482
# Euclidean Distance: 0.3368372494092287

# %%
# Calculate statistics for MSE, MAE, REE, and Euclidean error
metrics = np.array(metrics)
mse_mean = np.mean(metrics[:, 0])
mse_std = np.std(metrics[:, 0])
mae_mean = np.mean(metrics[:, 1])
mae_std = np.std(metrics[:, 1])
ree_mean = np.mean(metrics[:, 2])
ree_std = np.std(metrics[:, 2])
euclidean_mean = np.mean(metrics[:, 3])
euclidean_std = np.std(metrics[:, 3])
error_percentages_mean = np.mean([np.mean(error_percentage) for error_percentage in error_percentages])
error_percentages_std = np.std([np.mean(error_percentage) for error_percentage in error_percentages])


# Print statistics for MSE, MAE, REE, and Euclidean error
print("\n===== Additional Metrics Across 10 Trials =====")
print(f"Error Percentage Mean: {error_percentages_mean:.4f}% ± {error_percentages_std:.4f}%")
print(f"MSE Mean: {mse_mean:.4f} ± {mse_std:.4f}")
print(f"MAE Mean: {mae_mean:.4f} ± {mae_std:.4f}")
print(f"REE Mean: {ree_mean:.4f} ± {ree_std:.4f}")
print(f"Euclidean Mean: {euclidean_mean:.4f} ± {euclidean_std:.4f}")
# Out:
# ===== Additional Metrics Across 10 Trials =====
# Error Percentage Mean: 70.6873% ± 19.4701%
# MSE Mean: 0.0305 ± 0.0101
# MAE Mean: 0.1026 ± 0.0147
# REE Mean: 0.2644 ± 0.0497
# Euclidean Mean: 0.4779 ± 0.0864
