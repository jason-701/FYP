# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import os
import torch

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
file_path = "SPY.csv"
df = pd.read_csv(file_path)




# start to nov 2001 (dot com crash)
# not bad
df = df.iloc[:2228]

# nov 01 to june 2009
# not bad
# df = df.iloc[2228:4135]

# june 2009 to april 2020
# ass
# df = df.iloc[4135:6862]

# april 2020 to most recent
# ass
# df = df.iloc[6862:]


# Convert the "Date" column to datetime
# df["Date"] = pd.to_datetime(df["Date"], format='%Y/%m/%d')

# # Sort the data by date in ascending order
# df = df.sort_values(by="Date")

# # Get the earliest and latest dates
# earliest_date = df["Date"].min()
# latest_date = df["Date"].max()

# print("Earliest Date:", earliest_date)
# print("Latest Date:", latest_date)

# %%
print(df.tail())
# Out:
#             Date       Open       High        Low      Close    Volume  Day  \
# 2223  2001-11-23  74.380302  75.495615  74.354212  75.449959   6717100   23
# 2224  2001-11-26  75.495635  75.880449  75.052119  75.613037  13726000   26
# 2225  2001-11-27  75.410798  76.245651  74.412882  75.286873  19261400   27
# 2226  2001-11-28  74.836875  75.117334  73.865054  73.923752  20195500   28
# 2227  2001-11-29  74.132433  74.954239  73.701959  74.921631  16354700   29
#
#       Weekday  Week  Month  Year
# 2223        4    47     11  2001
# 2224        0    48     11  2001
# 2225        1    48     11  2001
# 2226        2    48     11  2001
# 2227        3    48     11  2001

# %%
# if 'Day' and 'Weekday' and 'Week' and 'Month' and 'Year' in df.columns:
    # df.drop(columns=['Day', 'Weekday', 'Week', 'Month', 'Year'], inplace=True)

# %%
if "Target" not in df.columns:
    # df["Target"] = (df["Close"].shift(-1) > df["Close"]).astype(int)
    df["Target"] = df["Close"].shift(-1)

# %%
df = df.dropna()

# %%
# Adding SMA as part of the feature test
short_term_period = 20
medium_term_period = 50
long_term_period = 200

# Compute the SMAs
df['SMA_20'] = df['Close'].rolling(window=short_term_period).mean()
df['SMA_50'] = df['Close'].rolling(window=medium_term_period).mean()
df['SMA_200'] = df['Close'].rolling(window=long_term_period).mean()

df['EMA_10'] = df['Close'].ewm(span=10, adjust=False).mean()  # Short-term EMA
df['EMA_50'] = df['Close'].ewm(span=50, adjust=False).mean()  # Medium-term EMA
df['EMA_200'] = df['Close'].ewm(span=200, adjust=False).mean()  # Long-term EMA

# %%
df = df.dropna()

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

# Assuming you have a DataFrame `df` with a 'Close' column

# Create an index for the time series (usually the row number)
df['Time'] = np.arange(len(df))

# Fit a polynomial regression to the 'Close' price
X = df[['Time']]  # Independent variable (time)
y = df['Close']   # Dependent variable (closing price)

# Initialize a polynomial features transformer (degree = 2 for quadratic, or higher for more non-linearity)
degree = 3  # You can change the degree for more complexity
poly = PolynomialFeatures(degree)

# Transform the Time feature into polynomial features
X_poly = poly.fit_transform(X)

# Initialize and fit the linear regression model to the polynomial features
model = LinearRegression()
model.fit(X_poly, y)

# Generate predictions for the polynomial regression (non-linear trend)
df['Non_Linear_Trend'] = model.predict(X_poly)

# Optionally, visualize the non-linear trend
plt.figure(figsize=(12, 6))
plt.plot(df['Time'], df['Close'], label='Close Price')
plt.plot(df['Time'], df['Non_Linear_Trend'], label=f'Non-Linear Trend (Degree {degree})', linestyle='--')
plt.xlabel('Time')
plt.ylabel('Price')
plt.title('Stock Prices with Non-Linear Trend')
plt.legend()
plt.show()
# Out:
# <ipython-input-195-857a5e003f9e>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Time'] = np.arange(len(df))
# <ipython-input-195-857a5e003f9e>:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Non_Linear_Trend'] = model.predict(X_poly)

# %% [markdown]
# ## CREATING THE NEURAL NETWORK MODEL

# %%
dates = df["Date"]
X = df.drop(columns=["Date", "Target"])
y = df["Target"]

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix

# %%
# Define the LSTM-based model
class LSTMModel(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, dropout_rate):
        super(LSTMModel, self).__init__()
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True, dropout=dropout_rate)
        self.fc = nn.Linear(hidden_size, 1)  # Output layer for binary classification
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        # LSTM expects input of shape (batch_size, sequence_length, input_size)
        out, _ = self.lstm(x)
        # Use the output of the last time step
        out = out[:, -1, :]  # Shape: (batch_size, hidden_size)
        out = self.fc(out)  # Shape: (batch_size, 1)
        out = self.sigmoid(out)
        return out

# Define a more complex LSTM-based model
# class ComplexLSTMModel(nn.Module):
#     def __init__(self, input_size, hidden_size, num_layers, dropout_rate):
#         super(ComplexLSTMModel, self).__init__()
#         # LSTM Layer: Bidirectional for richer context
#         self.lstm = nn.LSTM(input_size, hidden_size, num_layers,
#                             batch_first=True, dropout=dropout_rate,
#                             bidirectional=True)
#         # Fully connected layers for added complexity
#         self.fc1 = nn.Linear(hidden_size * 2, hidden_size)  # Bidirectional LSTM doubles hidden size
#         self.dropout1 = nn.Dropout(dropout_rate)
#         self.fc2 = nn.Linear(hidden_size, hidden_size // 2)
#         self.dropout2 = nn.Dropout(dropout_rate)
#         self.fc3 = nn.Linear(hidden_size // 2, 1)
#         self.sigmoid = nn.Sigmoid()

#     def forward(self, x):
#         # LSTM expects input of shape (batch_size, sequence_length, input_size)
#         out, _ = self.lstm(x)
#         # Use the output of the last time step
#         out = out[:, -1, :]  # Shape: (batch_size, hidden_size * 2)
#         out = self.fc1(out)  # First fully connected layer
#         out = self.dropout1(out)
#         out = torch.relu(out)  # Nonlinear activation
#         out = self.fc2(out)  # Second fully connected layer
#         out = self.dropout2(out)
#         out = torch.relu(out)  # Nonlinear activation
#         out = self.fc3(out)  # Output layer
#         out = self.sigmoid(out)  # Apply sigmoid for binary classification
#         return out

# class ComplexLSTMModel(nn.Module):
#     def __init__(self, input_size, hidden_size, num_layers, dropout_rate):
#         super(ComplexLSTMModel, self).__init__()
#         # LSTM Layer: Bidirectional for richer context
#         self.lstm = nn.LSTM(input_size, hidden_size, num_layers,
#                             batch_first=True, dropout=dropout_rate,
#                             bidirectional=True)
#         # Fully connected layers for added complexity
#         self.fc1 = nn.Linear(hidden_size * 2, hidden_size)  # Bidirectional LSTM doubles hidden size
#         self.dropout1 = nn.Dropout(dropout_rate)
#         self.fc2 = nn.Linear(hidden_size, hidden_size // 2)
#         self.dropout2 = nn.Dropout(dropout_rate)
#         self.fc3 = nn.Linear(hidden_size // 2, 1)

#     def forward(self, x):
#         # LSTM expects input of shape (batch_size, sequence_length, input_size)
#         out, _ = self.lstm(x)
#         # Use the output of the last time step
#         out = out[:, -1, :]  # Shape: (batch_size, hidden_size * 2)
#         out = self.fc1(out)  # First fully connected layer
#         out = self.dropout1(out)
#         out = torch.relu(out)  # Nonlinear activation
#         out = self.fc2(out)  # Second fully connected layer
#         out = self.dropout2(out)
#         out = torch.relu(out)  # Nonlinear activation
#         out = self.fc3(out)  # Output layer
#         return out

class ComplexLSTMModel(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, dropout_rate):
        super(ComplexLSTMModel, self).__init__()
        # Unidirectional LSTM for sequential stock price prediction
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers,
                            batch_first=True, dropout=dropout_rate)  # Removed bidirectional=True

        # Fully connected layers for added complexity
        self.fc1 = nn.Linear(hidden_size, hidden_size // 2)
        self.dropout1 = nn.Dropout(dropout_rate)
        self.fc2 = nn.Linear(hidden_size // 2, hidden_size // 4)
        self.dropout2 = nn.Dropout(dropout_rate)
        self.fc3 = nn.Linear(hidden_size // 4, 1)

    def forward(self, x):
        # LSTM expects input of shape (batch_size, sequence_length, input_size)
        out, _ = self.lstm(x)
        # Use the output of the last time step
        out = out[:, -1, :]  # Shape: (batch_size, hidden_size)

        out = torch.relu(self.fc1(out))  # First fully connected layer
        out = self.dropout1(out)
        out = torch.relu(self.fc2(out))  # Second fully connected layer
        out = self.dropout2(out)
        out = self.fc3(out)  # Output layer (no activation for regression)
        return out

# %%
sequence_length = 10

# Reshape data into sequences
def create_sequences(data, target, seq_length):
    X_seq, y_seq = [], []
    for i in range(len(data) - seq_length):
        X_seq.append(data[i:i + seq_length])
        y_seq.append(target[i + seq_length])
    return np.array(X_seq), np.array(y_seq)

# %%
# scaler = StandardScaler()
# scaler = MinMaxScaler()
# feature_columns = ["Open", "High", "Low", "Close", "Volume", "Day", "Weekday", "Week", "Month", "Year"]
# feature_columns = ["Open", "High", "Low", "Close", "Volume", "SMA_20", "SMA_50", "SMA_200", "EMA_10", "EMA_50", "EMA_200", "Non_Linear_Trend"]
feature_columns = ["Open", "High", "Low", "Close", "Volume", "SMA_20", "SMA_50", "SMA_200", "EMA_10", "EMA_50", "EMA_200"]
# feature_columns = ["Open", "High", "Low", "Close", "Volume", "Non_Linear_Trend", "SMA_20", "SMA_50", "EMA_10", "EMA_50"]
# feature_columns = ["Open", "High", "Low", "Close", "Volume", "Non_Linear_Trend"]

# Split data
train_size = int(X.shape[0] * 0.7)
val_size = int(X.shape[0] * 0.15)

# Initialize scaler
# scaler = RobustScaler()
scaler = MinMaxScaler()

# Split data into train, validation, and test
temp_train = X[:train_size]
temp_val = X[train_size:train_size + val_size]
temp_test = X[train_size + val_size:]

temp_train = temp_train[feature_columns]
temp_val = temp_val[feature_columns]
temp_test = temp_test[feature_columns]

# Fit and transform for train, transform for validation and test
temp_train = scaler.fit_transform(temp_train)
temp_val = scaler.transform(temp_val)
temp_test = scaler.transform(temp_test)

# Convert NumPy arrays back to DataFrames
temp_train = pd.DataFrame(temp_train, columns=feature_columns)
temp_val = pd.DataFrame(temp_val, columns=feature_columns)
temp_test = pd.DataFrame(temp_test, columns=feature_columns)

# Concatenate the data
X_scaled = pd.concat([temp_train, temp_val, temp_test], axis=0)

# scaler = StandardScaler()

# scaler.fit(X_train)
# X_scaled = pd.DataFrame(scaler.fit_transform(X[feature_columns]), columns=feature_columns, index=X.index)

X_seq, y_seq = create_sequences(X_scaled, y.values, sequence_length)


# Split sequentially
X_train, y_train = X_seq[:train_size], y_seq[:train_size]
X_val, y_val = X_seq[train_size:train_size + val_size], y_seq[train_size:train_size + val_size]
X_test, y_test = X_seq[train_size + val_size:], y_seq[train_size + val_size:]

# Print sizes to confirm
print(f"Train: {len(X_train)}, Val: {len(X_val)}, Test: {len(X_test)}")
# Out:
# Train: 1419, Val: 304, Test: 295

# %%
# Convert to PyTorch tensors
X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train, dtype=torch.float32)
X_val_tensor = torch.tensor(X_val, dtype=torch.float32)
y_val_tensor = torch.tensor(y_val, dtype=torch.float32)
X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test, dtype=torch.float32)

# Create DataLoaders
train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
val_dataset = TensorDataset(X_val_tensor, y_val_tensor)
test_dataset = TensorDataset(X_test_tensor, y_test_tensor)

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=64, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

# %%
# THE OG
# Hyperparameters
# input_size = X_train.shape[2]  # Number of features
# hidden_size = 32
# num_layers = 2
# dropout_rate = 0.3
# learning_rate = 0.01
# num_epochs = 100
# patience = 17

# Hyperparameters
input_size = X_train.shape[2]  # Number of features
hidden_size = 128
num_layers = 4
dropout_rate = 0.3
learning_rate = 0.0001
num_epochs = 500
patience = 30


# Initialize the LSTM model
# model = LSTMModel(input_size=input_size, hidden_size=hidden_size, num_layers=num_layers, dropout_rate=dropout_rate)
model = ComplexLSTMModel(input_size=input_size, hidden_size=hidden_size, num_layers=num_layers, dropout_rate=dropout_rate)

model.to(device)

# Define loss and optimizer
# criterion = nn.BCELoss()
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# Training loop with early stopping
best_val_loss = float('inf')
early_stop_counter = 0

# if not os.path.exists("./models/best_lstm_model.pth"):
if not os.path.exists("./lstm_trials/lstm_after_gridsearch_new.pth"):
    for epoch in range(num_epochs):
        model.train()
        train_loss = 0
        for X_batch, y_batch in train_loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)
            y_batch = y_batch.unsqueeze(1)  # Match output shape
            optimizer.zero_grad()
            outputs = model(X_batch)
            loss = criterion(outputs, y_batch)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()
            train_loss += loss.item()

        train_loss /= len(train_loader)

        # Validation
        model.eval()
        val_loss = 0
        with torch.no_grad():
            for X_batch, y_batch in val_loader:
                X_batch, y_batch = X_batch.to(device), y_batch.to(device)
                y_batch = y_batch.unsqueeze(1)
                outputs = model(X_batch)
                loss = criterion(outputs, y_batch)
                val_loss += loss.item()

        val_loss /= len(val_loader)
        print(f"Epoch {epoch + 1}/{num_epochs}, Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}")


        # Early stopping
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            # torch.save(model.state_dict(), "./lstm_trials/lstm_after_gridsearch_new.pth")
            early_stop_counter = 0
        else:
            early_stop_counter += 1
            print(f"Early stopping counter: {early_stop_counter}/{patience}")
            if early_stop_counter >= patience:
                print("Early stopping triggered.")
                break

# Load the best model
# model.load_state_dict(torch.load("./lstm_trials/lstm_after_gridsearch_new.pth"))

# Evaluate on test data
model.eval()
test_loss = 0.0
with torch.no_grad():
    for X_batch, y_batch in test_loader:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)
        outputs = model(X_batch)
        loss = criterion(outputs, y_batch)
        test_loss += loss.item() * X_batch.size(0)

test_loss /= len(test_loader.dataset)
print(f'Test Loss: {test_loss:.4f}')

# Calculate Mean Absolute Error (MAE)
test_mae = 0.0
with torch.no_grad():
    for X_batch, y_batch in test_loader:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)
        outputs = model(X_batch)
        mae = torch.mean(torch.abs(outputs - y_batch))
        test_mae += mae.item() * X_batch.size(0)

test_mae /= len(test_loader.dataset)
print(f'Test MAE: {test_mae:.4f}')
# Out:
# Epoch 1/500, Train Loss: 2622.8511, Val Loss: 8247.7963
# Epoch 2/500, Train Loss: 2622.4996, Val Loss: 8231.3854
# Epoch 3/500, Train Loss: 2579.3826, Val Loss: 8153.6214
# Epoch 4/500, Train Loss: 2557.1051, Val Loss: 8017.2797
# Epoch 5/500, Train Loss: 2454.9012, Val Loss: 7876.9267
# Epoch 6/500, Train Loss: 2387.2235, Val Loss: 7721.8405
# Epoch 7/500, Train Loss: 2298.7448, Val Loss: 7551.7229
# Epoch 8/500, Train Loss: 2244.2783, Val Loss: 7363.1961
# Epoch 9/500, Train Loss: 2140.8593, Val Loss: 7164.9604
# Epoch 10/500, Train Loss: 2020.4860, Val Loss: 6955.0415
# Epoch 11/500, Train Loss: 1901.9914, Val Loss: 6732.2044
# Epoch 12/500, Train Loss: 1814.4052, Val Loss: 6494.6981
# Epoch 13/500, Train Loss: 1687.6088, Val Loss: 6242.6665
# Epoch 14/500, Train Loss: 1590.3159, Val Loss: 5979.3865
# Epoch 15/500, Train Loss: 1472.6998, Val Loss: 5698.8472
# Epoch 16/500, Train Loss: 1347.9345, Val Loss: 5402.3759
# Epoch 17/500, Train Loss: 1206.6432, Val Loss: 5092.8574
# Epoch 18/500, Train Loss: 1099.0325, Val Loss: 4773.9106
# Epoch 19/500, Train Loss: 996.9684, Val Loss: 4447.7922
# Epoch 20/500, Train Loss: 860.6539, Val Loss: 4116.0604
# Epoch 21/500, Train Loss: 765.8067, Val Loss: 3781.0997
# Epoch 22/500, Train Loss: 671.6654, Val Loss: 3445.8525
# Epoch 23/500, Train Loss: 598.9085, Val Loss: 3111.1392
# Epoch 24/500, Train Loss: 530.8389, Val Loss: 2780.7033
# Epoch 25/500, Train Loss: 488.7170, Val Loss: 2470.9350
# Epoch 26/500, Train Loss: 448.7363, Val Loss: 2242.4451
# Epoch 27/500, Train Loss: 458.9691, Val Loss: 2116.7179
# Epoch 28/500, Train Loss: 437.6636, Val Loss: 2074.2338
# Epoch 29/500, Train Loss: 446.9377, Val Loss: 2095.1417
# Early stopping counter: 1/30
# Epoch 30/500, Train Loss: 334.0601, Val Loss: 1843.6374
# Epoch 31/500, Train Loss: 243.7425, Val Loss: 1549.6687
# Epoch 32/500, Train Loss: 208.3895, Val Loss: 1267.8998
# Epoch 33/500, Train Loss: 174.7096, Val Loss: 1010.0332
# Epoch 34/500, Train Loss: 138.5890, Val Loss: 815.1007
# Epoch 35/500, Train Loss: 140.4327, Val Loss: 653.1524
# Epoch 36/500, Train Loss: 121.1789, Val Loss: 528.3252
# Epoch 37/500, Train Loss: 122.1971, Val Loss: 456.8802
# Epoch 38/500, Train Loss: 122.2331, Val Loss: 382.8354
# Epoch 39/500, Train Loss: 112.5662, Val Loss: 329.9709
# Epoch 40/500, Train Loss: 114.6676, Val Loss: 290.1926
# Epoch 41/500, Train Loss: 123.3150, Val Loss: 260.4148
# Epoch 42/500, Train Loss: 99.2371, Val Loss: 222.3020
# Epoch 43/500, Train Loss: 113.1306, Val Loss: 198.5413
# Epoch 44/500, Train Loss: 105.0837, Val Loss: 172.4876
# Epoch 45/500, Train Loss: 120.1986, Val Loss: 148.5300
# Epoch 46/500, Train Loss: 103.0052, Val Loss: 143.2991
# Epoch 47/500, Train Loss: 118.8052, Val Loss: 131.9112
# Epoch 48/500, Train Loss: 111.8344, Val Loss: 125.4192
# Epoch 49/500, Train Loss: 110.6656, Val Loss: 122.2415
# Epoch 50/500, Train Loss: 113.7556, Val Loss: 115.8016
# Epoch 51/500, Train Loss: 109.3436, Val Loss: 110.9646
# Epoch 52/500, Train Loss: 109.7881, Val Loss: 117.5956
# Early stopping counter: 1/30
# Epoch 53/500, Train Loss: 105.7731, Val Loss: 108.8059
# Epoch 54/500, Train Loss: 106.7826, Val Loss: 110.6625
# Early stopping counter: 1/30
# Epoch 55/500, Train Loss: 103.6754, Val Loss: 102.5652
# Epoch 56/500, Train Loss: 104.7970, Val Loss: 102.1183
# Epoch 57/500, Train Loss: 101.2690, Val Loss: 101.1693
# Epoch 58/500, Train Loss: 102.3682, Val Loss: 83.7740
# Epoch 59/500, Train Loss: 103.2078, Val Loss: 74.3040
# Epoch 60/500, Train Loss: 100.4850, Val Loss: 73.6380
# Epoch 61/500, Train Loss: 99.1430, Val Loss: 64.7410
# Epoch 62/500, Train Loss: 98.0223, Val Loss: 69.3437
# Early stopping counter: 1/30
# Epoch 63/500, Train Loss: 95.3090, Val Loss: 61.2856
# Epoch 64/500, Train Loss: 98.2999, Val Loss: 57.6260
# Epoch 65/500, Train Loss: 105.5367, Val Loss: 59.1401
# Early stopping counter: 1/30
# Epoch 66/500, Train Loss: 109.5734, Val Loss: 54.7586
# Epoch 67/500, Train Loss: 105.5990, Val Loss: 45.8286
# Epoch 68/500, Train Loss: 99.3884, Val Loss: 47.6260
# Early stopping counter: 1/30
# Epoch 69/500, Train Loss: 100.2440, Val Loss: 55.6406
# Early stopping counter: 2/30
# Epoch 70/500, Train Loss: 103.3077, Val Loss: 46.2957
# Early stopping counter: 3/30
# Epoch 71/500, Train Loss: 89.4068, Val Loss: 50.3779
# Early stopping counter: 4/30
# Epoch 72/500, Train Loss: 95.9340, Val Loss: 44.2803
# Epoch 73/500, Train Loss: 99.8522, Val Loss: 45.3961
# Early stopping counter: 1/30
# Epoch 74/500, Train Loss: 102.1664, Val Loss: 55.1521
# Early stopping counter: 2/30
# Epoch 75/500, Train Loss: 97.1385, Val Loss: 48.6527
# Early stopping counter: 3/30
# Epoch 76/500, Train Loss: 99.3550, Val Loss: 55.7117
# Early stopping counter: 4/30
# Epoch 77/500, Train Loss: 99.4324, Val Loss: 48.9228
# Early stopping counter: 5/30
# Epoch 78/500, Train Loss: 96.4230, Val Loss: 40.2351
# Epoch 79/500, Train Loss: 101.8059, Val Loss: 36.5530
# Epoch 80/500, Train Loss: 108.9221, Val Loss: 64.6517
# Early stopping counter: 1/30
# Epoch 81/500, Train Loss: 95.5681, Val Loss: 43.5628
# Early stopping counter: 2/30
# Epoch 82/500, Train Loss: 101.1256, Val Loss: 47.2375
# Early stopping counter: 3/30
# Epoch 83/500, Train Loss: 98.7740, Val Loss: 38.3142
# Early stopping counter: 4/30
# Epoch 84/500, Train Loss: 103.4451, Val Loss: 55.4123
# Early stopping counter: 5/30
# Epoch 85/500, Train Loss: 97.2766, Val Loss: 40.3162
# Early stopping counter: 6/30
# Epoch 86/500, Train Loss: 94.5518, Val Loss: 73.5545
# Early stopping counter: 7/30
# Epoch 87/500, Train Loss: 96.5331, Val Loss: 48.8472
# Early stopping counter: 8/30
# Epoch 88/500, Train Loss: 102.8160, Val Loss: 41.8965
# Early stopping counter: 9/30
# Epoch 89/500, Train Loss: 92.1339, Val Loss: 43.5562
# Early stopping counter: 10/30
# Epoch 90/500, Train Loss: 93.6714, Val Loss: 42.4734
# Early stopping counter: 11/30
# Epoch 91/500, Train Loss: 95.9805, Val Loss: 36.9142
# Early stopping counter: 12/30
# Epoch 92/500, Train Loss: 93.5549, Val Loss: 33.9936
# Epoch 93/500, Train Loss: 100.6829, Val Loss: 25.1944
# Epoch 94/500, Train Loss: 99.3365, Val Loss: 37.3330
# Early stopping counter: 1/30
# Epoch 95/500, Train Loss: 93.2719, Val Loss: 37.2003
# Early stopping counter: 2/30
# Epoch 96/500, Train Loss: 95.6805, Val Loss: 38.2775
# Early stopping counter: 3/30
# Epoch 97/500, Train Loss: 98.7921, Val Loss: 35.2529
# Early stopping counter: 4/30
# Epoch 98/500, Train Loss: 91.1298, Val Loss: 67.2549
# Early stopping counter: 5/30
# Epoch 99/500, Train Loss: 89.3278, Val Loss: 63.1436
# Early stopping counter: 6/30
# Epoch 100/500, Train Loss: 103.4871, Val Loss: 57.5011
# Early stopping counter: 7/30
# Epoch 101/500, Train Loss: 88.1930, Val Loss: 45.0112
# Early stopping counter: 8/30
# Epoch 102/500, Train Loss: 95.8704, Val Loss: 63.9296
# Early stopping counter: 9/30
# Epoch 103/500, Train Loss: 99.3578, Val Loss: 48.6984
# Early stopping counter: 10/30
# Epoch 104/500, Train Loss: 97.2152, Val Loss: 83.6511
# Early stopping counter: 11/30
# Epoch 105/500, Train Loss: 97.0585, Val Loss: 63.9058
# Early stopping counter: 12/30
# Epoch 106/500, Train Loss: 91.2127, Val Loss: 78.3544
# Early stopping counter: 13/30
# Epoch 107/500, Train Loss: 87.6969, Val Loss: 55.8053
# Early stopping counter: 14/30
# Epoch 108/500, Train Loss: 91.2916, Val Loss: 70.4091
# Early stopping counter: 15/30
# Epoch 109/500, Train Loss: 96.7476, Val Loss: 84.6867
# Early stopping counter: 16/30
# Epoch 110/500, Train Loss: 98.8483, Val Loss: 57.4955
# Early stopping counter: 17/30
# Epoch 111/500, Train Loss: 99.7618, Val Loss: 77.9716
# Early stopping counter: 18/30
# Epoch 112/500, Train Loss: 95.1534, Val Loss: 90.8122
# Early stopping counter: 19/30
# Epoch 113/500, Train Loss: 92.1769, Val Loss: 88.9416
# Early stopping counter: 20/30
# Epoch 114/500, Train Loss: 94.1770, Val Loss: 78.2686
# Early stopping counter: 21/30
# Epoch 115/500, Train Loss: 84.3833, Val Loss: 56.6253
# Early stopping counter: 22/30
# Epoch 116/500, Train Loss: 92.5365, Val Loss: 62.4565
# Early stopping counter: 23/30
# Epoch 117/500, Train Loss: 95.0693, Val Loss: 60.1944
# Early stopping counter: 24/30
# Epoch 118/500, Train Loss: 101.6357, Val Loss: 68.4729
# Early stopping counter: 25/30
# Epoch 119/500, Train Loss: 102.1180, Val Loss: 77.7969
# Early stopping counter: 26/30
# Epoch 120/500, Train Loss: 96.6071, Val Loss: 53.9852
# Early stopping counter: 27/30
# Epoch 121/500, Train Loss: 97.8477, Val Loss: 58.7753
# Early stopping counter: 28/30
# Epoch 122/500, Train Loss: 90.6622, Val Loss: 50.6702
# Early stopping counter: 29/30
# Epoch 123/500, Train Loss: 98.1175, Val Loss: 39.0421
# Early stopping counter: 30/30
# Early stopping triggered.
# Test Loss: 28.8366
# Test MAE: 4.0400
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/loss.py:608: UserWarning: Using a target size (torch.Size([64])) that is different to the input size (torch.Size([64, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/loss.py:608: UserWarning: Using a target size (torch.Size([39])) that is different to the input size (torch.Size([39, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)

# %%
# Evaluate the model
# print("Confusion Matrix:")
# print(confusion_matrix(y_test, y_pred_binary))

# # Generate precision, recall, and F1-score
# print("\nClassification Report:")
# print(classification_report(y_test, y_pred_binary, target_names=["Class 0", "Class 1"]))

# %%
X_seq_tensor = torch.tensor(X_seq, dtype=torch.float32).to(device)
y_seq_tensor = torch.tensor(y_seq, dtype=torch.float32).to(device)

outputs = model(X_seq_tensor)

# %%
error = 0
largest_error = 0
less_than_actual = 0
more_than_actual = 0

for true, pred in zip(y_seq, outputs):
    percent = abs(true - pred) / true
    if percent > largest_error:
        largest_error = percent
    error += percent
    if pred < true:
        less_than_actual += 1
    else:
        more_than_actual += 1

error = error / len(y_seq)
error = error.item()
largest_error = largest_error.item()
print(f"Average error percentage: {error*100}")
print(f"Largest error percentage: {largest_error*100}")
print(f"Less than actual: {less_than_actual}")
print(f"More than actual: {more_than_actual}")
# Out:
# Average error percentage: 4.6265240758657455
# Largest error percentage: 16.81637614965439
# Less than actual: 1639
# More than actual: 379

# %%
train_cutoff = int(len(y_seq) * 0.7)
val_cutoff = int(len(y_seq) * 0.85)

plt.figure(figsize=(12, 6))
plt.plot(y_seq, label='True Values')
plt.plot(outputs.cpu().detach().numpy(), label='Predicted Values')
plt.axvline(x=train_cutoff, color='g', linestyle='--', label='Train/Val Split (80%)')
plt.axvline(x=val_cutoff, color='b', linestyle='--', label='Val/Test Split (90%)')
plt.xlabel('Time')
plt.ylabel('Value')
plt.title('True vs Predicted Values')
plt.legend()
plt.show()

# %%
outputs
# Out:
# tensor([[24.6344],
#         [24.6286],
#         [24.6179],
#         ...,
#         [74.3964],
#         [74.9060],
#         [75.6451]], device='cuda:0', grad_fn=<AddmmBackward0>)

# %%
df['Target_Higher_Lower'] = np.where(df['Target'] > df['Open'], 'higher', 'lower')

# %%
# Ensure outputs is detached from the computation graph and converted to numpy
predicted_values = outputs.cpu().detach().numpy()

# Add the predicted values as a new column in the dataframe
df['Predicted'] = np.nan
df.loc[df.index[-len(predicted_values):], 'Predicted'] = predicted_values

print(df[['Date', 'Target', 'Predicted']].tail())
# Out:
#             Date     Target  Predicted
# 2222  2001-11-21  75.449959  73.306953
# 2223  2001-11-23  75.613037  73.787910
# 2224  2001-11-26  75.286873  74.396431
# 2225  2001-11-27  73.923752  74.906013
# 2226  2001-11-28  74.921631  75.645126

# %%
new_df = df.dropna()

# %%
new_df['Predicted_Higher_Lower'] = np.where(new_df['Predicted'] > new_df['Open'], 'higher', 'lower')
new_df['Correct'] = np.where(new_df['Predicted_Higher_Lower'] == new_df['Target_Higher_Lower'], 1, 0)

print('number of correct predictions:', new_df['Correct'].sum())
# Out:
# number of correct predictions: 959
# <ipython-input-211-54f40e89f447>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['Predicted_Higher_Lower'] = np.where(new_df['Predicted'] > new_df['Open'], 'higher', 'lower')
# <ipython-input-211-54f40e89f447>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['Correct'] = np.where(new_df['Predicted_Higher_Lower'] == new_df['Target_Higher_Lower'], 1, 0)

# %%
# # train model 10 times and get results with prediction error, max error etc
# error_array = []
# largest_error_array = []
# for i in range (10):
#     model = ComplexLSTMModel(input_size=input_size, hidden_size=hidden_size, num_layers=num_layers, dropout_rate=dropout_rate)

#     # Define loss and optimizer
#     # criterion = nn.BCELoss()
#     criterion = nn.MSELoss()
#     optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

#     # Training loop with early stopping
#     best_val_loss = float('inf')
#     early_stop_counter = 0

#     # if not os.path.exists("./models/best_lstm_model.pth"):
#     if not os.path.exists("./lstm_trials/lstm.pth"):
#         for epoch in range(num_epochs):
#             model.train()
#             train_loss = 0
#             for X_batch, y_batch in train_loader:
#                 y_batch = y_batch.unsqueeze(1)  # Match output shape
#                 optimizer.zero_grad()
#                 outputs = model(X_batch)
#                 loss = criterion(outputs, y_batch)
#                 loss.backward()
#                 torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
#                 optimizer.step()
#                 train_loss += loss.item()

#             train_loss /= len(train_loader)

#             # Validation
#             model.eval()
#             val_loss = 0
#             with torch.no_grad():
#                 for X_batch, y_batch in val_loader:
#                     y_batch = y_batch.unsqueeze(1)
#                     outputs = model(X_batch)
#                     loss = criterion(outputs, y_batch)
#                     val_loss += loss.item()

#             val_loss /= len(val_loader)
#             print(f"Epoch {epoch + 1}/{num_epochs}, Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}")


#             # Early stopping
#             if val_loss < best_val_loss:
#                 best_val_loss = val_loss
#                 # torch.save(model.state_dict(), "./lstm_trials/lstm_5.pth")
#                 early_stop_counter = 0
#             else:
#                 early_stop_counter += 1
#                 print(f"Early stopping counter: {early_stop_counter}/{patience}")
#                 if early_stop_counter >= patience:
#                     print("Early stopping triggered.")
#                     break
#     model.eval()
#     test_loss = 0.0
#     with torch.no_grad():
#         for X_batch, y_batch in test_loader:
#             outputs = model(X_batch)
#             loss = criterion(outputs, y_batch)
#             test_loss += loss.item() * X_batch.size(0)

#     test_loss /= len(test_loader.dataset)
#     print(f'Test Loss: {test_loss:.4f}')

#     # Calculate Mean Absolute Error (MAE)
#     test_mae = 0.0
#     with torch.no_grad():
#         for X_batch, y_batch in test_loader:
#             outputs = model(X_batch)
#             mae = torch.mean(torch.abs(outputs - y_batch))
#             test_mae += mae.item() * X_batch.size(0)

#     test_mae /= len(test_loader.dataset)
#     print(f'Test MAE: {test_mae:.4f}')

#     outputs = model(X_seq_tensor)
#     error = 0
#     largest_error = 0
#     less_than_actual = 0
#     more_than_actual = 0

#     for true, pred in zip(y_seq, outputs):
#         percent = abs(true - pred) / true
#         if percent > largest_error:
#             largest_error = percent
#         error += percent
#         if pred < true:
#             less_than_actual += 1
#         else:
#             more_than_actual += 1

#     error = error / len(y_seq)
#     error = error.item()
#     largest_error = largest_error.item()
#     # print(f"Average error percentage: {error*100}")
#     # print(f"Largest error percentage: {largest_error*100}")
#     # print(f"Less than actual: {less_than_actual}")
#     # print(f"More than actual: {more_than_actual}")
#     error_array.append(error*100)
#     largest_error_array.append(largest_error*100)

# print('Average error percentage:', np.mean(error_array))
# print('Average largest error percentage:', np.mean(largest_error_array))
# print("Standard deviation of average error percentage:", np.std(error_array))
# print("Standard deviation of average largest error percentage:", np.std(largest_error_array))

# %%
X_seq_tensor = torch.tensor(X_test, dtype=torch.float32).to(device)
y_seq_tensor = torch.tensor(y_test, dtype=torch.float32).to(device)

outputs = model(X_seq_tensor)

# %%
error = 0
largest_error = 0
less_than_actual = 0
more_than_actual = 0

for true, pred in zip(y_test, outputs):
    percent = abs(true - pred) / true
    if percent > largest_error:
        largest_error = percent
    error += percent
    if pred < true:
        less_than_actual += 1
    else:
        more_than_actual += 1

error = error / len(y_test)
error = error.item()
largest_error = largest_error.item()
print(f"Average error percentage: {error*100}")
print(f"Largest error percentage: {largest_error*100}")
print(f"Less than actual: {less_than_actual}")
print(f"More than actual: {more_than_actual}")
# Out:
# Average error percentage: 4.11812886595726
# Largest error percentage: 16.816364228725433
# Less than actual: 136
# More than actual: 159

# %%
import itertools
import torch

# Define possible hyperparameter ranges
hidden_sizes = [64, 128]
num_layers_list = [2, 3, 4]
dropout_rates = [0.1, 0.3, 0.5]
learning_rates = [0.001, 0.0005, 0.0001]
patience_values = [30]
num_repeats = 5  # Number of times each combination is trained


# Generate all combinations of hyperparameters
hyperparameter_combinations = list(itertools.product(hidden_sizes, num_layers_list, dropout_rates, learning_rates, patience_values))

# Initialize best loss
best_avg_loss = float('inf')
best_model = None
best_params = None

# Counter
total_count = len(hyperparameter_combinations)
current_count = 0

# Loop over all combinations
for hidden_size, num_layers, dropout_rate, learning_rate, patience in hyperparameter_combinations:
    print(f"Training with hidden_size={hidden_size}, num_layers={num_layers}, dropout_rate={dropout_rate}, learning_rate={learning_rate}, patience={patience}")
    print(f"Progress: {current_count}/{total_count}")
    current_count += 1

    total_val_loss = 0  # Accumulator for validation losses

    for repeat in range(num_repeats):
        print(f"  Repeat {repeat + 1}/{num_repeats}")

        # Reinitialize the model
        model = ComplexLSTMModel(input_size=input_size, hidden_size=hidden_size, num_layers=num_layers, dropout_rate=dropout_rate)
        optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

        best_loss = float('inf')
        epoch_no_improve = 0  # Counter for early stopping

        # Training loop
        for epoch in range(num_epochs):
            model.train()
            train_loss = 0
            for X_batch, y_batch in train_loader:
                y_batch = y_batch.unsqueeze(1)
                optimizer.zero_grad()
                outputs = model(X_batch)
                loss = criterion(outputs, y_batch)
                loss.backward()
                optimizer.step()
                train_loss += loss.item()

            train_loss /= len(train_loader)

            # Validation
            model.eval()
            val_loss = 0
            with torch.no_grad():
                for X_batch, y_batch in val_loader:
                    y_batch = y_batch.unsqueeze(1)
                    outputs = model(X_batch)
                    loss = criterion(outputs, y_batch)
                    val_loss += loss.item()

            val_loss /= len(val_loader)
            print(f"    Epoch {epoch + 1}/{num_epochs}, Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}")

            # Early stopping
            if val_loss < best_loss:
                best_loss = val_loss
                epoch_no_improve = 0  # Reset counter
            else:
                epoch_no_improve += 1
                print(f"    Early stopping counter: {epoch_no_improve}/{patience}")
                if epoch_no_improve >= patience:
                    print("    Early stopping triggered.")
                    break

        total_val_loss += best_loss  # Add the best validation loss from this repeat

    # Compute the average validation loss across `num_repeats` runs
    avg_val_loss = total_val_loss / num_repeats
    print(f"Average Validation Loss for this combination: {avg_val_loss:.4f}")

    # Check if this is the best combination so far
    if avg_val_loss < best_avg_loss:
        best_avg_loss = avg_val_loss
        best_model = model.state_dict()
        best_params = (hidden_size, num_layers, dropout_rate, learning_rate, patience)

# Load the best model
model.load_state_dict(best_model)
print(f"Best model parameters: {best_params}")
# Out:
# Streaming output truncated to the last 5000 lines.
#     Early stopping counter: 10/30
#     Epoch 195/500, Train Loss: 29.0500, Val Loss: 48.3564
#     Early stopping counter: 11/30
#     Epoch 196/500, Train Loss: 30.0362, Val Loss: 44.6863
#     Early stopping counter: 12/30
#     Epoch 197/500, Train Loss: 29.5933, Val Loss: 46.9878
#     Early stopping counter: 13/30
#     Epoch 198/500, Train Loss: 28.7721, Val Loss: 50.5012
#     Early stopping counter: 14/30
#     Epoch 199/500, Train Loss: 29.3904, Val Loss: 50.7869
#     Early stopping counter: 15/30
#     Epoch 200/500, Train Loss: 28.4130, Val Loss: 49.3603
#     Early stopping counter: 16/30
#     Epoch 201/500, Train Loss: 26.9743, Val Loss: 48.5779
#     Early stopping counter: 17/30
#     Epoch 202/500, Train Loss: 29.4524, Val Loss: 51.1651
#     Early stopping counter: 18/30
#     Epoch 203/500, Train Loss: 29.7759, Val Loss: 51.2701
#     Early stopping counter: 19/30
#     Epoch 204/500, Train Loss: 28.9475, Val Loss: 49.3434
#     Early stopping counter: 20/30
#     Epoch 205/500, Train Loss: 29.2563, Val Loss: 46.6267
#     Early stopping counter: 21/30
#     Epoch 206/500, Train Loss: 31.1326, Val Loss: 47.9292
#     Early stopping counter: 22/30
#     Epoch 207/500, Train Loss: 30.1399, Val Loss: 45.4952
#     Early stopping counter: 23/30
#     Epoch 208/500, Train Loss: 27.3366, Val Loss: 48.9141
#     Early stopping counter: 24/30
#     Epoch 209/500, Train Loss: 29.2467, Val Loss: 50.4524
#     Early stopping counter: 25/30
#     Epoch 210/500, Train Loss: 27.0296, Val Loss: 50.9598
#     Early stopping counter: 26/30
#     Epoch 211/500, Train Loss: 31.9079, Val Loss: 47.8420
#     Early stopping counter: 27/30
#     Epoch 212/500, Train Loss: 27.0885, Val Loss: 47.8295
#     Early stopping counter: 28/30
#     Epoch 213/500, Train Loss: 28.8955, Val Loss: 51.8078
#     Early stopping counter: 29/30
#     Epoch 214/500, Train Loss: 30.2560, Val Loss: 48.3990
#     Early stopping counter: 30/30
#     Early stopping triggered.
#   Repeat 5/5
#     Epoch 1/500, Train Loss: 2618.1526, Val Loss: 8218.9071
#     Epoch 2/500, Train Loss: 2574.4488, Val Loss: 8212.8016
#     Epoch 3/500, Train Loss: 2636.7484, Val Loss: 8183.1893
#     Epoch 4/500, Train Loss: 2539.8906, Val Loss: 8095.4799
#     Epoch 5/500, Train Loss: 2508.4664, Val Loss: 7986.9218
#     Epoch 6/500, Train Loss: 2435.8001, Val Loss: 7843.6237
#     Epoch 7/500, Train Loss: 2372.0899, Val Loss: 7673.9985
#     Epoch 8/500, Train Loss: 2267.6797, Val Loss: 7474.9877
#     Epoch 9/500, Train Loss: 2175.4914, Val Loss: 7215.6434
#     Epoch 10/500, Train Loss: 2041.1797, Val Loss: 6913.9584
#     Epoch 11/500, Train Loss: 1885.6773, Val Loss: 6573.7183
#     Epoch 12/500, Train Loss: 1703.6360, Val Loss: 6167.4520
#     Epoch 13/500, Train Loss: 1467.3106, Val Loss: 5722.5779
#     Epoch 14/500, Train Loss: 1318.8951, Val Loss: 5273.9964
#     Epoch 15/500, Train Loss: 1141.1701, Val Loss: 4818.7634
#     Epoch 16/500, Train Loss: 966.5054, Val Loss: 4366.9437
#     Epoch 17/500, Train Loss: 810.6552, Val Loss: 3943.7938
#     Epoch 18/500, Train Loss: 675.9990, Val Loss: 3547.7367
#     Epoch 19/500, Train Loss: 575.5052, Val Loss: 3197.7352
#     Epoch 20/500, Train Loss: 507.4334, Val Loss: 2903.7576
#     Epoch 21/500, Train Loss: 468.7326, Val Loss: 2646.2521
#     Epoch 22/500, Train Loss: 414.8256, Val Loss: 2442.9608
#     Epoch 23/500, Train Loss: 389.7672, Val Loss: 2289.8433
#     Epoch 24/500, Train Loss: 389.6421, Val Loss: 2171.9696
#     Epoch 25/500, Train Loss: 379.0958, Val Loss: 2084.8024
#     Epoch 26/500, Train Loss: 380.6127, Val Loss: 2025.6017
#     Epoch 27/500, Train Loss: 374.0464, Val Loss: 1988.2135
#     Epoch 28/500, Train Loss: 393.2285, Val Loss: 1966.7566
#     Epoch 29/500, Train Loss: 378.9034, Val Loss: 1943.6720
#     Epoch 30/500, Train Loss: 372.7813, Val Loss: 1933.1357
#     Epoch 31/500, Train Loss: 358.5450, Val Loss: 1941.9401
#     Early stopping counter: 1/30
#     Epoch 32/500, Train Loss: 309.9130, Val Loss: 1853.7576
#     Epoch 33/500, Train Loss: 207.2866, Val Loss: 1620.3154
#     Epoch 34/500, Train Loss: 164.9341, Val Loss: 1390.3249
#     Epoch 35/500, Train Loss: 130.3526, Val Loss: 1199.2806
#     Epoch 36/500, Train Loss: 113.4138, Val Loss: 1041.8888
#     Epoch 37/500, Train Loss: 100.0408, Val Loss: 907.5738
#     Epoch 38/500, Train Loss: 84.6827, Val Loss: 798.4221
#     Epoch 39/500, Train Loss: 72.2855, Val Loss: 709.5330
#     Epoch 40/500, Train Loss: 71.1563, Val Loss: 632.8530
#     Epoch 41/500, Train Loss: 57.7831, Val Loss: 572.3942
#     Epoch 42/500, Train Loss: 56.3305, Val Loss: 519.8952
#     Epoch 43/500, Train Loss: 55.6871, Val Loss: 474.1859
#     Epoch 44/500, Train Loss: 50.7721, Val Loss: 437.8205
#     Epoch 45/500, Train Loss: 51.9816, Val Loss: 402.6558
#     Epoch 46/500, Train Loss: 50.8077, Val Loss: 371.0615
#     Epoch 47/500, Train Loss: 50.4466, Val Loss: 339.1609
#     Epoch 48/500, Train Loss: 45.5514, Val Loss: 309.9725
#     Epoch 49/500, Train Loss: 42.5734, Val Loss: 282.4513
#     Epoch 50/500, Train Loss: 48.7106, Val Loss: 260.9377
#     Epoch 51/500, Train Loss: 39.4031, Val Loss: 237.6418
#     Epoch 52/500, Train Loss: 42.0374, Val Loss: 215.9422
#     Epoch 53/500, Train Loss: 40.0071, Val Loss: 199.3789
#     Epoch 54/500, Train Loss: 41.0034, Val Loss: 181.5403
#     Epoch 55/500, Train Loss: 40.4974, Val Loss: 167.3206
#     Epoch 56/500, Train Loss: 41.6793, Val Loss: 156.6305
#     Epoch 57/500, Train Loss: 37.8470, Val Loss: 146.2707
#     Epoch 58/500, Train Loss: 36.3878, Val Loss: 138.4669
#     Epoch 59/500, Train Loss: 38.1938, Val Loss: 131.5616
#     Epoch 60/500, Train Loss: 38.4446, Val Loss: 130.5904
#     Epoch 61/500, Train Loss: 39.1031, Val Loss: 126.2663
#     Epoch 62/500, Train Loss: 35.5894, Val Loss: 125.7055
#     Epoch 63/500, Train Loss: 36.8485, Val Loss: 121.7438
#     Epoch 64/500, Train Loss: 42.2771, Val Loss: 116.0752
#     Epoch 65/500, Train Loss: 38.4217, Val Loss: 110.4882
#     Epoch 66/500, Train Loss: 39.4006, Val Loss: 109.5507
#     Epoch 67/500, Train Loss: 36.2615, Val Loss: 103.6730
#     Epoch 68/500, Train Loss: 35.1608, Val Loss: 97.1984
#     Epoch 69/500, Train Loss: 34.7503, Val Loss: 95.0796
#     Epoch 70/500, Train Loss: 36.8248, Val Loss: 92.9268
#     Epoch 71/500, Train Loss: 33.7146, Val Loss: 90.9744
#     Epoch 72/500, Train Loss: 37.8741, Val Loss: 89.7803
#     Epoch 73/500, Train Loss: 43.0562, Val Loss: 87.5334
#     Epoch 74/500, Train Loss: 35.4832, Val Loss: 84.1059
#     Epoch 75/500, Train Loss: 38.7959, Val Loss: 82.2482
#     Epoch 76/500, Train Loss: 40.6068, Val Loss: 78.4503
#     Epoch 77/500, Train Loss: 35.1840, Val Loss: 76.9064
#     Epoch 78/500, Train Loss: 36.6668, Val Loss: 74.8079
#     Epoch 79/500, Train Loss: 38.7103, Val Loss: 73.1089
#     Epoch 80/500, Train Loss: 37.3039, Val Loss: 69.0260
#     Epoch 81/500, Train Loss: 34.2132, Val Loss: 67.9117
#     Epoch 82/500, Train Loss: 37.5529, Val Loss: 68.1657
#     Early stopping counter: 1/30
#     Epoch 83/500, Train Loss: 32.7704, Val Loss: 67.3218
#     Epoch 84/500, Train Loss: 37.8794, Val Loss: 67.5326
#     Early stopping counter: 1/30
#     Epoch 85/500, Train Loss: 34.5055, Val Loss: 65.4054
#     Epoch 86/500, Train Loss: 37.3203, Val Loss: 66.1547
#     Early stopping counter: 1/30
#     Epoch 87/500, Train Loss: 36.4807, Val Loss: 63.6594
#     Epoch 88/500, Train Loss: 36.5851, Val Loss: 64.5378
#     Early stopping counter: 1/30
#     Epoch 89/500, Train Loss: 39.8153, Val Loss: 63.1839
#     Epoch 90/500, Train Loss: 37.1371, Val Loss: 64.9418
#     Early stopping counter: 1/30
#     Epoch 91/500, Train Loss: 33.7424, Val Loss: 64.4063
#     Early stopping counter: 2/30
#     Epoch 92/500, Train Loss: 33.8852, Val Loss: 63.2697
#     Early stopping counter: 3/30
#     Epoch 93/500, Train Loss: 35.1136, Val Loss: 60.0093
#     Epoch 94/500, Train Loss: 33.6688, Val Loss: 61.3287
#     Early stopping counter: 1/30
#     Epoch 95/500, Train Loss: 36.0274, Val Loss: 59.7603
#     Epoch 96/500, Train Loss: 33.8148, Val Loss: 57.5726
#     Epoch 97/500, Train Loss: 33.8311, Val Loss: 58.9493
#     Early stopping counter: 1/30
#     Epoch 98/500, Train Loss: 38.6932, Val Loss: 54.7464
#     Epoch 99/500, Train Loss: 35.3931, Val Loss: 55.4309
#     Early stopping counter: 1/30
#     Epoch 100/500, Train Loss: 34.5916, Val Loss: 56.5058
#     Early stopping counter: 2/30
#     Epoch 101/500, Train Loss: 35.8528, Val Loss: 56.2088
#     Early stopping counter: 3/30
#     Epoch 102/500, Train Loss: 35.0162, Val Loss: 56.0591
#     Early stopping counter: 4/30
#     Epoch 103/500, Train Loss: 32.9904, Val Loss: 56.3170
#     Early stopping counter: 5/30
#     Epoch 104/500, Train Loss: 35.0589, Val Loss: 58.4707
#     Early stopping counter: 6/30
#     Epoch 105/500, Train Loss: 35.3454, Val Loss: 55.9228
#     Early stopping counter: 7/30
#     Epoch 106/500, Train Loss: 32.5783, Val Loss: 55.6143
#     Early stopping counter: 8/30
#     Epoch 107/500, Train Loss: 36.1632, Val Loss: 57.2765
#     Early stopping counter: 9/30
#     Epoch 108/500, Train Loss: 36.4728, Val Loss: 56.9284
#     Early stopping counter: 10/30
#     Epoch 109/500, Train Loss: 32.0400, Val Loss: 55.8043
#     Early stopping counter: 11/30
#     Epoch 110/500, Train Loss: 33.4434, Val Loss: 54.1767
#     Epoch 111/500, Train Loss: 36.6809, Val Loss: 56.0225
#     Early stopping counter: 1/30
#     Epoch 112/500, Train Loss: 37.7469, Val Loss: 56.1238
#     Early stopping counter: 2/30
#     Epoch 113/500, Train Loss: 35.7624, Val Loss: 58.9102
#     Early stopping counter: 3/30
#     Epoch 114/500, Train Loss: 35.3049, Val Loss: 61.5785
#     Early stopping counter: 4/30
#     Epoch 115/500, Train Loss: 33.7845, Val Loss: 59.5003
#     Early stopping counter: 5/30
#     Epoch 116/500, Train Loss: 31.5688, Val Loss: 62.6344
#     Early stopping counter: 6/30
#     Epoch 117/500, Train Loss: 35.8308, Val Loss: 67.6596
#     Early stopping counter: 7/30
#     Epoch 118/500, Train Loss: 34.1588, Val Loss: 67.2899
#     Early stopping counter: 8/30
#     Epoch 119/500, Train Loss: 34.7510, Val Loss: 64.2105
#     Early stopping counter: 9/30
#     Epoch 120/500, Train Loss: 34.3496, Val Loss: 64.9601
#     Early stopping counter: 10/30
#     Epoch 121/500, Train Loss: 31.3448, Val Loss: 64.8717
#     Early stopping counter: 11/30
#     Epoch 122/500, Train Loss: 34.2396, Val Loss: 67.5542
#     Early stopping counter: 12/30
#     Epoch 123/500, Train Loss: 35.1855, Val Loss: 69.0515
#     Early stopping counter: 13/30
#     Epoch 124/500, Train Loss: 34.5529, Val Loss: 63.9954
#     Early stopping counter: 14/30
#     Epoch 125/500, Train Loss: 37.3063, Val Loss: 62.3057
#     Early stopping counter: 15/30
#     Epoch 126/500, Train Loss: 33.2033, Val Loss: 60.6479
#     Early stopping counter: 16/30
#     Epoch 127/500, Train Loss: 38.6276, Val Loss: 56.1171
#     Early stopping counter: 17/30
#     Epoch 128/500, Train Loss: 36.7462, Val Loss: 51.4309
#     Epoch 129/500, Train Loss: 36.6317, Val Loss: 47.6838
#     Epoch 130/500, Train Loss: 35.2061, Val Loss: 48.9880
#     Early stopping counter: 1/30
#     Epoch 131/500, Train Loss: 35.2025, Val Loss: 46.7893
#     Epoch 132/500, Train Loss: 35.3845, Val Loss: 47.3154
#     Early stopping counter: 1/30
#     Epoch 133/500, Train Loss: 36.4180, Val Loss: 46.4840
#     Epoch 134/500, Train Loss: 33.4441, Val Loss: 50.9098
#     Early stopping counter: 1/30
#     Epoch 135/500, Train Loss: 33.3384, Val Loss: 55.2029
#     Early stopping counter: 2/30
#     Epoch 136/500, Train Loss: 36.8099, Val Loss: 53.4694
#     Early stopping counter: 3/30
#     Epoch 137/500, Train Loss: 38.9516, Val Loss: 53.7105
#     Early stopping counter: 4/30
#     Epoch 138/500, Train Loss: 34.9435, Val Loss: 53.3922
#     Early stopping counter: 5/30
#     Epoch 139/500, Train Loss: 35.4274, Val Loss: 47.8425
#     Early stopping counter: 6/30
#     Epoch 140/500, Train Loss: 36.2731, Val Loss: 42.9740
#     Epoch 141/500, Train Loss: 34.8391, Val Loss: 41.5839
#     Epoch 142/500, Train Loss: 35.1931, Val Loss: 46.8932
#     Early stopping counter: 1/30
#     Epoch 143/500, Train Loss: 33.6423, Val Loss: 43.1647
#     Early stopping counter: 2/30
#     Epoch 144/500, Train Loss: 35.3117, Val Loss: 41.9715
#     Early stopping counter: 3/30
#     Epoch 145/500, Train Loss: 33.5754, Val Loss: 46.9242
#     Early stopping counter: 4/30
#     Epoch 146/500, Train Loss: 34.9975, Val Loss: 41.8135
#     Early stopping counter: 5/30
#     Epoch 147/500, Train Loss: 33.4690, Val Loss: 41.4520
#     Epoch 148/500, Train Loss: 37.5256, Val Loss: 47.0414
#     Early stopping counter: 1/30
#     Epoch 149/500, Train Loss: 33.1151, Val Loss: 45.1033
#     Early stopping counter: 2/30
#     Epoch 150/500, Train Loss: 38.6941, Val Loss: 45.9428
#     Early stopping counter: 3/30
#     Epoch 151/500, Train Loss: 33.8971, Val Loss: 48.3009
#     Early stopping counter: 4/30
#     Epoch 152/500, Train Loss: 33.0710, Val Loss: 44.8939
#     Early stopping counter: 5/30
#     Epoch 153/500, Train Loss: 32.9144, Val Loss: 46.1847
#     Early stopping counter: 6/30
#     Epoch 154/500, Train Loss: 31.8767, Val Loss: 53.1896
#     Early stopping counter: 7/30
#     Epoch 155/500, Train Loss: 35.7949, Val Loss: 49.4192
#     Early stopping counter: 8/30
#     Epoch 156/500, Train Loss: 36.4456, Val Loss: 47.4549
#     Early stopping counter: 9/30
#     Epoch 157/500, Train Loss: 37.9088, Val Loss: 44.1657
#     Early stopping counter: 10/30
#     Epoch 158/500, Train Loss: 33.6240, Val Loss: 46.0265
#     Early stopping counter: 11/30
#     Epoch 159/500, Train Loss: 34.4366, Val Loss: 48.0485
#     Early stopping counter: 12/30
#     Epoch 160/500, Train Loss: 33.6695, Val Loss: 50.0301
#     Early stopping counter: 13/30
#     Epoch 161/500, Train Loss: 33.9168, Val Loss: 45.9397
#     Early stopping counter: 14/30
#     Epoch 162/500, Train Loss: 34.3133, Val Loss: 46.0663
#     Early stopping counter: 15/30
#     Epoch 163/500, Train Loss: 37.7631, Val Loss: 51.2879
#     Early stopping counter: 16/30
#     Epoch 164/500, Train Loss: 33.5917, Val Loss: 47.6978
#     Early stopping counter: 17/30
#     Epoch 165/500, Train Loss: 38.4245, Val Loss: 46.4641
#     Early stopping counter: 18/30
#     Epoch 166/500, Train Loss: 33.5444, Val Loss: 47.8195
#     Early stopping counter: 19/30
#     Epoch 167/500, Train Loss: 36.6454, Val Loss: 43.4975
#     Early stopping counter: 20/30
#     Epoch 168/500, Train Loss: 34.9647, Val Loss: 38.5771
#     Epoch 169/500, Train Loss: 34.4861, Val Loss: 49.0729
#     Early stopping counter: 1/30
#     Epoch 170/500, Train Loss: 38.5325, Val Loss: 45.4716
#     Early stopping counter: 2/30
#     Epoch 171/500, Train Loss: 32.9530, Val Loss: 48.5643
#     Early stopping counter: 3/30
#     Epoch 172/500, Train Loss: 35.7549, Val Loss: 48.1031
#     Early stopping counter: 4/30
#     Epoch 173/500, Train Loss: 33.0906, Val Loss: 59.8097
#     Early stopping counter: 5/30
#     Epoch 174/500, Train Loss: 34.7410, Val Loss: 56.3580
#     Early stopping counter: 6/30
#     Epoch 175/500, Train Loss: 38.1076, Val Loss: 54.0604
#     Early stopping counter: 7/30
#     Epoch 176/500, Train Loss: 35.9420, Val Loss: 56.4487
#     Early stopping counter: 8/30
#     Epoch 177/500, Train Loss: 37.5327, Val Loss: 58.9176
#     Early stopping counter: 9/30
#     Epoch 178/500, Train Loss: 34.7188, Val Loss: 53.6015
#     Early stopping counter: 10/30
#     Epoch 179/500, Train Loss: 36.1784, Val Loss: 53.0129
#     Early stopping counter: 11/30
#     Epoch 180/500, Train Loss: 31.1743, Val Loss: 53.3380
#     Early stopping counter: 12/30
#     Epoch 181/500, Train Loss: 36.6978, Val Loss: 49.9363
#     Early stopping counter: 13/30
#     Epoch 182/500, Train Loss: 33.4134, Val Loss: 54.8364
#     Early stopping counter: 14/30
#     Epoch 183/500, Train Loss: 32.5938, Val Loss: 48.7257
#     Early stopping counter: 15/30
#     Epoch 184/500, Train Loss: 33.8650, Val Loss: 53.4747
#     Early stopping counter: 16/30
#     Epoch 185/500, Train Loss: 32.0725, Val Loss: 51.1948
#     Early stopping counter: 17/30
#     Epoch 186/500, Train Loss: 31.3465, Val Loss: 41.2801
#     Early stopping counter: 18/30
#     Epoch 187/500, Train Loss: 33.0415, Val Loss: 47.7465
#     Early stopping counter: 19/30
#     Epoch 188/500, Train Loss: 32.6051, Val Loss: 53.2175
#     Early stopping counter: 20/30
#     Epoch 189/500, Train Loss: 30.5993, Val Loss: 47.4380
#     Early stopping counter: 21/30
#     Epoch 190/500, Train Loss: 35.8190, Val Loss: 53.1361
#     Early stopping counter: 22/30
#     Epoch 191/500, Train Loss: 34.7489, Val Loss: 55.1240
#     Early stopping counter: 23/30
#     Epoch 192/500, Train Loss: 37.3013, Val Loss: 54.4777
#     Early stopping counter: 24/30
#     Epoch 193/500, Train Loss: 34.8571, Val Loss: 52.8459
#     Early stopping counter: 25/30
#     Epoch 194/500, Train Loss: 35.7783, Val Loss: 49.3453
#     Early stopping counter: 26/30
#     Epoch 195/500, Train Loss: 34.9564, Val Loss: 46.3691
#     Early stopping counter: 27/30
#     Epoch 196/500, Train Loss: 34.0060, Val Loss: 53.0831
#     Early stopping counter: 28/30
#     Epoch 197/500, Train Loss: 34.2916, Val Loss: 50.4957
#     Early stopping counter: 29/30
#     Epoch 198/500, Train Loss: 31.2005, Val Loss: 53.4224
#     Early stopping counter: 30/30
#     Early stopping triggered.
# Average Validation Loss for this combination: 37.4627
# Training with hidden_size=128, num_layers=4, dropout_rate=0.3, learning_rate=0.001, patience=30
# Progress: 48/54
#   Repeat 1/5
#     Epoch 1/500, Train Loss: 2510.0842, Val Loss: 7449.6727
#     Epoch 2/500, Train Loss: 1598.3230, Val Loss: 4156.4796
#     Epoch 3/500, Train Loss: 532.4843, Val Loss: 1535.2542
#     Epoch 4/500, Train Loss: 462.4211, Val Loss: 2269.1349
#     Early stopping counter: 1/30
#     Epoch 5/500, Train Loss: 454.3400, Val Loss: 2033.4844
#     Early stopping counter: 2/30
#     Epoch 6/500, Train Loss: 450.4286, Val Loss: 2006.0867
#     Early stopping counter: 3/30
#     Epoch 7/500, Train Loss: 426.3157, Val Loss: 1969.1800
#     Early stopping counter: 4/30
#     Epoch 8/500, Train Loss: 445.9178, Val Loss: 2051.5769
#     Early stopping counter: 5/30
#     Epoch 9/500, Train Loss: 426.5553, Val Loss: 1856.4970
#     Early stopping counter: 6/30
#     Epoch 10/500, Train Loss: 426.1315, Val Loss: 2133.1406
#     Early stopping counter: 7/30
#     Epoch 11/500, Train Loss: 444.3680, Val Loss: 1877.7153
#     Early stopping counter: 8/30
#     Epoch 12/500, Train Loss: 454.6670, Val Loss: 2049.9344
#     Early stopping counter: 9/30
#     Epoch 13/500, Train Loss: 415.7631, Val Loss: 1940.6555
#     Early stopping counter: 10/30
#     Epoch 14/500, Train Loss: 429.6282, Val Loss: 2103.6675
#     Early stopping counter: 11/30
#     Epoch 15/500, Train Loss: 419.5788, Val Loss: 2041.5719
#     Early stopping counter: 12/30
#     Epoch 16/500, Train Loss: 431.6058, Val Loss: 1991.5249
#     Early stopping counter: 13/30
#     Epoch 17/500, Train Loss: 427.4369, Val Loss: 2060.1721
#     Early stopping counter: 14/30
#     Epoch 18/500, Train Loss: 427.1327, Val Loss: 2042.0886
#     Early stopping counter: 15/30
#     Epoch 19/500, Train Loss: 470.1031, Val Loss: 2238.5630
#     Early stopping counter: 16/30
#     Epoch 20/500, Train Loss: 434.8128, Val Loss: 1968.8924
#     Early stopping counter: 17/30
#     Epoch 21/500, Train Loss: 434.4562, Val Loss: 2019.7825
#     Early stopping counter: 18/30
#     Epoch 22/500, Train Loss: 418.6323, Val Loss: 2203.6357
#     Early stopping counter: 19/30
#     Epoch 23/500, Train Loss: 421.7835, Val Loss: 1969.6115
#     Early stopping counter: 20/30
#     Epoch 24/500, Train Loss: 433.0773, Val Loss: 1987.2295
#     Early stopping counter: 21/30
#     Epoch 25/500, Train Loss: 424.9629, Val Loss: 1904.3144
#     Early stopping counter: 22/30
#     Epoch 26/500, Train Loss: 415.6199, Val Loss: 2015.0714
#     Early stopping counter: 23/30
#     Epoch 27/500, Train Loss: 425.8354, Val Loss: 1952.5160
#     Early stopping counter: 24/30
#     Epoch 28/500, Train Loss: 425.3500, Val Loss: 2201.9102
#     Early stopping counter: 25/30
#     Epoch 29/500, Train Loss: 413.0219, Val Loss: 2027.2883
#     Early stopping counter: 26/30
#     Epoch 30/500, Train Loss: 424.5364, Val Loss: 1990.7236
#     Early stopping counter: 27/30
#     Epoch 31/500, Train Loss: 415.2341, Val Loss: 1985.8180
#     Early stopping counter: 28/30
#     Epoch 32/500, Train Loss: 409.7158, Val Loss: 1946.6110
#     Early stopping counter: 29/30
#     Epoch 33/500, Train Loss: 425.6550, Val Loss: 2061.3751
#     Early stopping counter: 30/30
#     Early stopping triggered.
#   Repeat 2/5
#     Epoch 1/500, Train Loss: 2451.3056, Val Loss: 7163.5519
#     Epoch 2/500, Train Loss: 1369.2128, Val Loss: 3358.0875
#     Epoch 3/500, Train Loss: 485.6804, Val Loss: 1701.5932
#     Epoch 4/500, Train Loss: 421.4088, Val Loss: 2097.3640
#     Early stopping counter: 1/30
#     Epoch 5/500, Train Loss: 436.2283, Val Loss: 2046.4594
#     Early stopping counter: 2/30
#     Epoch 6/500, Train Loss: 434.2493, Val Loss: 1966.4131
#     Early stopping counter: 3/30
#     Epoch 7/500, Train Loss: 439.1175, Val Loss: 2030.3091
#     Early stopping counter: 4/30
#     Epoch 8/500, Train Loss: 429.6319, Val Loss: 2039.0610
#     Early stopping counter: 5/30
#     Epoch 9/500, Train Loss: 412.2992, Val Loss: 1974.9188
#     Early stopping counter: 6/30
#     Epoch 10/500, Train Loss: 435.8054, Val Loss: 2021.2356
#     Early stopping counter: 7/30
#     Epoch 11/500, Train Loss: 415.4868, Val Loss: 2014.6597
#     Early stopping counter: 8/30
#     Epoch 12/500, Train Loss: 400.1593, Val Loss: 1980.9065
#     Early stopping counter: 9/30
#     Epoch 13/500, Train Loss: 408.1194, Val Loss: 1986.7749
#     Early stopping counter: 10/30
#     Epoch 14/500, Train Loss: 418.4310, Val Loss: 2022.7405
#     Early stopping counter: 11/30
#     Epoch 15/500, Train Loss: 435.0248, Val Loss: 2029.0283
#     Early stopping counter: 12/30
#     Epoch 16/500, Train Loss: 404.7018, Val Loss: 1820.4514
#     Early stopping counter: 13/30
#     Epoch 17/500, Train Loss: 422.2211, Val Loss: 1919.1546
#     Early stopping counter: 14/30
#     Epoch 18/500, Train Loss: 439.2750, Val Loss: 2172.8848
#     Early stopping counter: 15/30
#     Epoch 19/500, Train Loss: 423.4243, Val Loss: 2020.4433
#     Early stopping counter: 16/30
#     Epoch 20/500, Train Loss: 415.1093, Val Loss: 1953.5964
#     Early stopping counter: 17/30
#     Epoch 21/500, Train Loss: 401.2333, Val Loss: 2060.1593
#     Early stopping counter: 18/30
#     Epoch 22/500, Train Loss: 410.4301, Val Loss: 1894.8809
#     Early stopping counter: 19/30
#     Epoch 23/500, Train Loss: 428.3014, Val Loss: 1997.2137
#     Early stopping counter: 20/30
#     Epoch 24/500, Train Loss: 430.0364, Val Loss: 2055.5138
#     Early stopping counter: 21/30
#     Epoch 25/500, Train Loss: 408.3557, Val Loss: 2008.4390
#     Early stopping counter: 22/30
#     Epoch 26/500, Train Loss: 429.5217, Val Loss: 2007.2395
#     Early stopping counter: 23/30
#     Epoch 27/500, Train Loss: 413.8228, Val Loss: 1983.0695
#     Early stopping counter: 24/30
#     Epoch 28/500, Train Loss: 419.0802, Val Loss: 2096.5235
#     Early stopping counter: 25/30
#     Epoch 29/500, Train Loss: 415.5192, Val Loss: 1958.1201
#     Early stopping counter: 26/30
#     Epoch 30/500, Train Loss: 416.2889, Val Loss: 2013.0929
#     Early stopping counter: 27/30
#     Epoch 31/500, Train Loss: 426.7544, Val Loss: 2030.0121
#     Early stopping counter: 28/30
#     Epoch 32/500, Train Loss: 416.0545, Val Loss: 2182.1008
#     Early stopping counter: 29/30
#     Epoch 33/500, Train Loss: 401.9761, Val Loss: 1947.3725
#     Early stopping counter: 30/30
#     Early stopping triggered.
#   Repeat 3/5
#     Epoch 1/500, Train Loss: 2530.6387, Val Loss: 7453.1463
#     Epoch 2/500, Train Loss: 1619.9889, Val Loss: 4307.1709
#     Epoch 3/500, Train Loss: 535.9654, Val Loss: 1567.5175
#     Epoch 4/500, Train Loss: 460.4157, Val Loss: 2171.5980
#     Early stopping counter: 1/30
#     Epoch 5/500, Train Loss: 443.9176, Val Loss: 2043.9290
#     Early stopping counter: 2/30
#     Epoch 6/500, Train Loss: 441.6520, Val Loss: 2023.8270
#     Early stopping counter: 3/30
#     Epoch 7/500, Train Loss: 437.3492, Val Loss: 2044.6714
#     Early stopping counter: 4/30
#     Epoch 8/500, Train Loss: 462.1121, Val Loss: 1997.0675
#     Early stopping counter: 5/30
#     Epoch 9/500, Train Loss: 453.1849, Val Loss: 2105.5557
#     Early stopping counter: 6/30
#     Epoch 10/500, Train Loss: 449.7548, Val Loss: 2097.9031
#     Early stopping counter: 7/30
#     Epoch 11/500, Train Loss: 423.5249, Val Loss: 1836.8570
#     Early stopping counter: 8/30
#     Epoch 12/500, Train Loss: 423.3876, Val Loss: 2119.0964
#     Early stopping counter: 9/30
#     Epoch 13/500, Train Loss: 440.1216, Val Loss: 1954.6427
#     Early stopping counter: 10/30
#     Epoch 14/500, Train Loss: 447.3610, Val Loss: 2116.4358
#     Early stopping counter: 11/30
#     Epoch 15/500, Train Loss: 429.7876, Val Loss: 2068.2066
#     Early stopping counter: 12/30
#     Epoch 16/500, Train Loss: 458.0199, Val Loss: 2103.2759
#     Early stopping counter: 13/30
#     Epoch 17/500, Train Loss: 455.2783, Val Loss: 2126.0515
#     Early stopping counter: 14/30
#     Epoch 18/500, Train Loss: 441.2972, Val Loss: 1970.5473
#     Early stopping counter: 15/30
#     Epoch 19/500, Train Loss: 432.1529, Val Loss: 2104.4258
#     Early stopping counter: 16/30
#     Epoch 20/500, Train Loss: 434.3451, Val Loss: 1921.8390
#     Early stopping counter: 17/30
#     Epoch 21/500, Train Loss: 434.5717, Val Loss: 2035.6795
#     Early stopping counter: 18/30
#     Epoch 22/500, Train Loss: 436.6003, Val Loss: 2140.2987
#     Early stopping counter: 19/30
#     Epoch 23/500, Train Loss: 424.4512, Val Loss: 2018.1064
#     Early stopping counter: 20/30
#     Epoch 24/500, Train Loss: 435.5519, Val Loss: 1988.7535
#     Early stopping counter: 21/30
#     Epoch 25/500, Train Loss: 424.3307, Val Loss: 2087.6490
#     Early stopping counter: 22/30
#     Epoch 26/500, Train Loss: 414.1709, Val Loss: 1968.6392
#     Early stopping counter: 23/30
#     Epoch 27/500, Train Loss: 416.7545, Val Loss: 2181.5219
#     Early stopping counter: 24/30
#     Epoch 28/500, Train Loss: 434.7746, Val Loss: 1918.6379
#     Early stopping counter: 25/30
#     Epoch 29/500, Train Loss: 446.1703, Val Loss: 2026.5594
#     Early stopping counter: 26/30
#     Epoch 30/500, Train Loss: 425.6363, Val Loss: 2121.4028
#     Early stopping counter: 27/30
#     Epoch 31/500, Train Loss: 418.4149, Val Loss: 2057.5831
#     Early stopping counter: 28/30
#     Epoch 32/500, Train Loss: 428.2467, Val Loss: 2037.4018
#     Early stopping counter: 29/30
#     Epoch 33/500, Train Loss: 431.5042, Val Loss: 2071.8077
#     Early stopping counter: 30/30
#     Early stopping triggered.
#   Repeat 4/5
#     Epoch 1/500, Train Loss: 2536.2798, Val Loss: 7628.4106
#     Epoch 2/500, Train Loss: 1762.1282, Val Loss: 4833.4583
#     Epoch 3/500, Train Loss: 594.2987, Val Loss: 1575.3010
#     Epoch 4/500, Train Loss: 441.1278, Val Loss: 2165.5143
#     Early stopping counter: 1/30
#     Epoch 5/500, Train Loss: 426.7263, Val Loss: 1969.2600
#     Early stopping counter: 2/30
#     Epoch 6/500, Train Loss: 440.2208, Val Loss: 2105.5812
#     Early stopping counter: 3/30
#     Epoch 7/500, Train Loss: 429.6652, Val Loss: 1925.9702
#     Early stopping counter: 4/30
#     Epoch 8/500, Train Loss: 423.0935, Val Loss: 2018.8131
#     Early stopping counter: 5/30
#     Epoch 9/500, Train Loss: 459.6321, Val Loss: 2023.8647
#     Early stopping counter: 6/30
#     Epoch 10/500, Train Loss: 457.8834, Val Loss: 2094.0469
#     Early stopping counter: 7/30
#     Epoch 11/500, Train Loss: 424.2945, Val Loss: 2007.9428
#     Early stopping counter: 8/30
#     Epoch 12/500, Train Loss: 436.1537, Val Loss: 2059.5669
#     Early stopping counter: 9/30
#     Epoch 13/500, Train Loss: 439.8666, Val Loss: 2058.8591
#     Early stopping counter: 10/30
#     Epoch 14/500, Train Loss: 435.1453, Val Loss: 2051.1451
#     Early stopping counter: 11/30
#     Epoch 15/500, Train Loss: 457.7013, Val Loss: 1962.9275
#     Early stopping counter: 12/30
#     Epoch 16/500, Train Loss: 450.6841, Val Loss: 2185.5954
#     Early stopping counter: 13/30
#     Epoch 17/500, Train Loss: 442.3608, Val Loss: 1896.0098
#     Early stopping counter: 14/30
#     Epoch 18/500, Train Loss: 443.8595, Val Loss: 2150.7061
#     Early stopping counter: 15/30
#     Epoch 19/500, Train Loss: 422.2071, Val Loss: 2041.0955
#     Early stopping counter: 16/30
#     Epoch 20/500, Train Loss: 423.3869, Val Loss: 1905.4664
#     Early stopping counter: 17/30
#     Epoch 21/500, Train Loss: 408.0115, Val Loss: 1978.7250
#     Early stopping counter: 18/30
#     Epoch 22/500, Train Loss: 428.8968, Val Loss: 2019.2779
#     Early stopping counter: 19/30
#     Epoch 23/500, Train Loss: 434.3364, Val Loss: 2114.4865
#     Early stopping counter: 20/30
#     Epoch 24/500, Train Loss: 428.2719, Val Loss: 2047.4444
#     Early stopping counter: 21/30
#     Epoch 25/500, Train Loss: 446.0111, Val Loss: 2111.7291
#     Early stopping counter: 22/30
#     Epoch 26/500, Train Loss: 426.6261, Val Loss: 2060.7409
#     Early stopping counter: 23/30
#     Epoch 27/500, Train Loss: 438.1531, Val Loss: 2018.1102
#     Early stopping counter: 24/30
#     Epoch 28/500, Train Loss: 440.4625, Val Loss: 2020.0403
#     Early stopping counter: 25/30
#     Epoch 29/500, Train Loss: 416.3132, Val Loss: 2055.5901
#     Early stopping counter: 26/30
#     Epoch 30/500, Train Loss: 455.2368, Val Loss: 2218.7457
#     Early stopping counter: 27/30
#     Epoch 31/500, Train Loss: 443.5097, Val Loss: 1939.2033
#     Early stopping counter: 28/30
#     Epoch 32/500, Train Loss: 425.0201, Val Loss: 2030.1140
#     Early stopping counter: 29/30
#     Epoch 33/500, Train Loss: 431.6912, Val Loss: 2029.6137
#     Early stopping counter: 30/30
#     Early stopping triggered.
#   Repeat 5/5
#     Epoch 1/500, Train Loss: 2501.4042, Val Loss: 7437.1437
#     Epoch 2/500, Train Loss: 1602.9864, Val Loss: 4199.5337
#     Epoch 3/500, Train Loss: 540.5184, Val Loss: 1532.6573
#     Epoch 4/500, Train Loss: 440.2250, Val Loss: 2204.4724
#     Early stopping counter: 1/30
#     Epoch 5/500, Train Loss: 464.0110, Val Loss: 2015.2755
#     Early stopping counter: 2/30
#     Epoch 6/500, Train Loss: 449.2554, Val Loss: 2094.5243
#     Early stopping counter: 3/30
#     Epoch 7/500, Train Loss: 420.4656, Val Loss: 2064.2802
#     Early stopping counter: 4/30
#     Epoch 8/500, Train Loss: 473.0877, Val Loss: 2015.3229
#     Early stopping counter: 5/30
#     Epoch 9/500, Train Loss: 430.3770, Val Loss: 1955.8682
#     Early stopping counter: 6/30
#     Epoch 10/500, Train Loss: 452.9443, Val Loss: 1996.8302
#     Early stopping counter: 7/30
#     Epoch 11/500, Train Loss: 442.9153, Val Loss: 2108.5097
#     Early stopping counter: 8/30
#     Epoch 12/500, Train Loss: 447.6787, Val Loss: 1934.8264
#     Early stopping counter: 9/30
#     Epoch 13/500, Train Loss: 447.0508, Val Loss: 2021.1489
#     Early stopping counter: 10/30
#     Epoch 14/500, Train Loss: 433.0743, Val Loss: 2061.1476
#     Early stopping counter: 11/30
#     Epoch 15/500, Train Loss: 431.9041, Val Loss: 2019.0620
#     Early stopping counter: 12/30
#     Epoch 16/500, Train Loss: 427.5170, Val Loss: 2174.8908
#     Early stopping counter: 13/30
#     Epoch 17/500, Train Loss: 444.1795, Val Loss: 2066.0336
#     Early stopping counter: 14/30
#     Epoch 18/500, Train Loss: 430.0246, Val Loss: 2014.8383
#     Early stopping counter: 15/30
#     Epoch 19/500, Train Loss: 436.2121, Val Loss: 2003.3083
#     Early stopping counter: 16/30
#     Epoch 20/500, Train Loss: 437.1727, Val Loss: 2131.4900
#     Early stopping counter: 17/30
#     Epoch 21/500, Train Loss: 424.6409, Val Loss: 1797.5194
#     Early stopping counter: 18/30
#     Epoch 22/500, Train Loss: 442.7885, Val Loss: 2072.7944
#     Early stopping counter: 19/30
#     Epoch 23/500, Train Loss: 434.2154, Val Loss: 2115.8565
#     Early stopping counter: 20/30
#     Epoch 24/500, Train Loss: 424.6286, Val Loss: 2007.5427
#     Early stopping counter: 21/30
#     Epoch 25/500, Train Loss: 449.3055, Val Loss: 2103.6335
#     Early stopping counter: 22/30
#     Epoch 26/500, Train Loss: 430.8259, Val Loss: 2010.6321
#     Early stopping counter: 23/30
#     Epoch 27/500, Train Loss: 428.4699, Val Loss: 1904.7925
#     Early stopping counter: 24/30
#     Epoch 28/500, Train Loss: 434.1407, Val Loss: 2035.5070
#     Early stopping counter: 25/30
#     Epoch 29/500, Train Loss: 440.1782, Val Loss: 2060.5859
#     Early stopping counter: 26/30
#     Epoch 30/500, Train Loss: 416.8881, Val Loss: 2107.0812
#     Early stopping counter: 27/30
#     Epoch 31/500, Train Loss: 439.5506, Val Loss: 2046.4917
#     Early stopping counter: 28/30
#     Epoch 32/500, Train Loss: 424.2382, Val Loss: 2200.4047
#     Early stopping counter: 29/30
#     Epoch 33/500, Train Loss: 404.6717, Val Loss: 1883.5724
#     Early stopping counter: 30/30
#     Early stopping triggered.
# Average Validation Loss for this combination: 1582.4646
# Training with hidden_size=128, num_layers=4, dropout_rate=0.3, learning_rate=0.0005, patience=30
# Progress: 49/54
#   Repeat 1/5
#     Epoch 1/500, Train Loss: 2615.6969, Val Loss: 8042.0519
#     Epoch 2/500, Train Loss: 2293.1517, Val Loss: 7198.3868
#     Epoch 3/500, Train Loss: 1742.0495, Val Loss: 5533.9638
#     Epoch 4/500, Train Loss: 955.2680, Val Loss: 3330.4503
#     Epoch 5/500, Train Loss: 486.1331, Val Loss: 1977.2519
#     Epoch 6/500, Train Loss: 460.3178, Val Loss: 1950.5364
#     Epoch 7/500, Train Loss: 437.6906, Val Loss: 2037.9076
#     Early stopping counter: 1/30
#     Epoch 8/500, Train Loss: 448.9226, Val Loss: 1993.8086
#     Early stopping counter: 2/30
#     Epoch 9/500, Train Loss: 462.3020, Val Loss: 2099.2130
#     Early stopping counter: 3/30
#     Epoch 10/500, Train Loss: 474.1961, Val Loss: 2120.9113
#     Early stopping counter: 4/30
#     Epoch 11/500, Train Loss: 486.2215, Val Loss: 2136.8618
#     Early stopping counter: 5/30
#     Epoch 12/500, Train Loss: 465.5535, Val Loss: 2049.0228
#     Early stopping counter: 6/30
#     Epoch 13/500, Train Loss: 451.9688, Val Loss: 2029.8389
#     Early stopping counter: 7/30
#     Epoch 14/500, Train Loss: 447.4560, Val Loss: 2045.4651
#     Early stopping counter: 8/30
#     Epoch 15/500, Train Loss: 456.9280, Val Loss: 2011.1269
#     Early stopping counter: 9/30
#     Epoch 16/500, Train Loss: 433.8297, Val Loss: 2051.1025
#     Early stopping counter: 10/30
#     Epoch 17/500, Train Loss: 452.5655, Val Loss: 2093.9813
#     Early stopping counter: 11/30
#     Epoch 18/500, Train Loss: 463.4948, Val Loss: 2020.4177
#     Early stopping counter: 12/30
#     Epoch 19/500, Train Loss: 445.6918, Val Loss: 2118.3752
#     Early stopping counter: 13/30
#     Epoch 20/500, Train Loss: 457.3341, Val Loss: 2116.2552
#     Early stopping counter: 14/30
#     Epoch 21/500, Train Loss: 455.4091, Val Loss: 2007.6242
#     Early stopping counter: 15/30
#     Epoch 22/500, Train Loss: 456.2825, Val Loss: 1985.3543
#     Early stopping counter: 16/30
#     Epoch 23/500, Train Loss: 425.3817, Val Loss: 2011.3440
#     Early stopping counter: 17/30
#     Epoch 24/500, Train Loss: 448.0654, Val Loss: 1993.9376
#     Early stopping counter: 18/30
#     Epoch 25/500, Train Loss: 429.8182, Val Loss: 2006.1938
#     Early stopping counter: 19/30
#     Epoch 26/500, Train Loss: 266.3817, Val Loss: 1031.9919
#     Epoch 27/500, Train Loss: 156.0228, Val Loss: 420.3905
#     Epoch 28/500, Train Loss: 135.1277, Val Loss: 354.4854
#     Epoch 29/500, Train Loss: 135.7991, Val Loss: 233.2158
#     Epoch 30/500, Train Loss: 122.0146, Val Loss: 265.4727
#     Early stopping counter: 1/30
#     Epoch 31/500, Train Loss: 133.1265, Val Loss: 196.3530
#     Epoch 32/500, Train Loss: 113.3523, Val Loss: 193.3827
#     Epoch 33/500, Train Loss: 122.6791, Val Loss: 210.2585
#     Early stopping counter: 1/30
#     Epoch 34/500, Train Loss: 110.8949, Val Loss: 154.8761
#     Epoch 35/500, Train Loss: 115.4147, Val Loss: 149.6867
#     Epoch 36/500, Train Loss: 119.1419, Val Loss: 169.6741
#     Early stopping counter: 1/30
#     Epoch 37/500, Train Loss: 121.5101, Val Loss: 133.6048
#     Epoch 38/500, Train Loss: 116.3810, Val Loss: 151.7560
#     Early stopping counter: 1/30
#     Epoch 39/500, Train Loss: 108.7882, Val Loss: 139.0782
#     Early stopping counter: 2/30
#     Epoch 40/500, Train Loss: 115.8983, Val Loss: 130.1552
#     Epoch 41/500, Train Loss: 111.2095, Val Loss: 118.5664
#     Epoch 42/500, Train Loss: 112.6600, Val Loss: 113.9474
#     Epoch 43/500, Train Loss: 111.0224, Val Loss: 125.9399
#     Early stopping counter: 1/30
#     Epoch 44/500, Train Loss: 118.8968, Val Loss: 138.1362
#     Early stopping counter: 2/30
#     Epoch 45/500, Train Loss: 128.9130, Val Loss: 260.9713
#     Early stopping counter: 3/30
#     Epoch 46/500, Train Loss: 116.8635, Val Loss: 163.6702
#     Early stopping counter: 4/30
#     Epoch 47/500, Train Loss: 128.9621, Val Loss: 72.0822
#     Epoch 48/500, Train Loss: 119.3681, Val Loss: 75.2316
#     Early stopping counter: 1/30
#     Epoch 49/500, Train Loss: 114.6167, Val Loss: 79.0527
#     Early stopping counter: 2/30
#     Epoch 50/500, Train Loss: 114.8448, Val Loss: 74.5168
#     Early stopping counter: 3/30
#     Epoch 51/500, Train Loss: 108.5913, Val Loss: 68.0265
#     Epoch 52/500, Train Loss: 121.5593, Val Loss: 75.1655
#     Early stopping counter: 1/30
#     Epoch 53/500, Train Loss: 110.5184, Val Loss: 79.8885
#     Early stopping counter: 2/30
#     Epoch 54/500, Train Loss: 113.6781, Val Loss: 109.1619
#     Early stopping counter: 3/30
#     Epoch 55/500, Train Loss: 127.3405, Val Loss: 151.8463
#     Early stopping counter: 4/30
#     Epoch 56/500, Train Loss: 117.5664, Val Loss: 149.0361
#     Early stopping counter: 5/30
#     Epoch 57/500, Train Loss: 124.8924, Val Loss: 122.1020
#     Early stopping counter: 6/30
#     Epoch 58/500, Train Loss: 119.7258, Val Loss: 89.0289
#     Early stopping counter: 7/30
#     Epoch 59/500, Train Loss: 117.5747, Val Loss: 134.1971
#     Early stopping counter: 8/30
#     Epoch 60/500, Train Loss: 115.6201, Val Loss: 106.3824
#     Early stopping counter: 9/30
#     Epoch 61/500, Train Loss: 120.2675, Val Loss: 81.4346
#     Early stopping counter: 10/30
#     Epoch 62/500, Train Loss: 113.4394, Val Loss: 67.8357
#     Epoch 63/500, Train Loss: 121.9188, Val Loss: 98.0781
#     Early stopping counter: 1/30
#     Epoch 64/500, Train Loss: 107.3276, Val Loss: 87.7365
#     Early stopping counter: 2/30
#     Epoch 65/500, Train Loss: 119.1210, Val Loss: 84.1644
#     Early stopping counter: 3/30
#     Epoch 66/500, Train Loss: 120.1771, Val Loss: 134.6013
#     Early stopping counter: 4/30
#     Epoch 67/500, Train Loss: 116.8182, Val Loss: 72.5240
#     Early stopping counter: 5/30
#     Epoch 68/500, Train Loss: 118.4948, Val Loss: 56.0643
#     Epoch 69/500, Train Loss: 116.5349, Val Loss: 59.6582
#     Early stopping counter: 1/30
#     Epoch 70/500, Train Loss: 109.5413, Val Loss: 102.1474
#     Early stopping counter: 2/30
#     Epoch 71/500, Train Loss: 110.2065, Val Loss: 97.0769
#     Early stopping counter: 3/30
#     Epoch 72/500, Train Loss: 115.3757, Val Loss: 111.6536
#     Early stopping counter: 4/30
#     Epoch 73/500, Train Loss: 110.1797, Val Loss: 105.3713
#     Early stopping counter: 5/30
#     Epoch 74/500, Train Loss: 120.8878, Val Loss: 75.3482
#     Early stopping counter: 6/30
#     Epoch 75/500, Train Loss: 112.2017, Val Loss: 90.4259
#     Early stopping counter: 7/30
#     Epoch 76/500, Train Loss: 111.4347, Val Loss: 90.9442
#     Early stopping counter: 8/30
#     Epoch 77/500, Train Loss: 115.0578, Val Loss: 87.6532
#     Early stopping counter: 9/30
#     Epoch 78/500, Train Loss: 114.3114, Val Loss: 97.7468
#     Early stopping counter: 10/30
#     Epoch 79/500, Train Loss: 127.8798, Val Loss: 97.7044
#     Early stopping counter: 11/30
#     Epoch 80/500, Train Loss: 119.5771, Val Loss: 85.0442
#     Early stopping counter: 12/30
#     Epoch 81/500, Train Loss: 123.0027, Val Loss: 90.9105
#     Early stopping counter: 13/30
#     Epoch 82/500, Train Loss: 113.4553, Val Loss: 75.6159
#     Early stopping counter: 14/30
#     Epoch 83/500, Train Loss: 106.3136, Val Loss: 130.4907
#     Early stopping counter: 15/30
#     Epoch 84/500, Train Loss: 113.8799, Val Loss: 145.5980
#     Early stopping counter: 16/30
#     Epoch 85/500, Train Loss: 108.8087, Val Loss: 96.8408
#     Early stopping counter: 17/30
#     Epoch 86/500, Train Loss: 112.3628, Val Loss: 92.9793
#     Early stopping counter: 18/30
#     Epoch 87/500, Train Loss: 122.9143, Val Loss: 118.6588
#     Early stopping counter: 19/30
#     Epoch 88/500, Train Loss: 116.2630, Val Loss: 177.2185
#     Early stopping counter: 20/30
#     Epoch 89/500, Train Loss: 105.7908, Val Loss: 96.9112
#     Early stopping counter: 21/30
#     Epoch 90/500, Train Loss: 116.6914, Val Loss: 71.5089
#     Early stopping counter: 22/30
#     Epoch 91/500, Train Loss: 117.0063, Val Loss: 71.8265
#     Early stopping counter: 23/30
#     Epoch 92/500, Train Loss: 121.1464, Val Loss: 80.5443
#     Early stopping counter: 24/30
#     Epoch 93/500, Train Loss: 110.6587, Val Loss: 104.9947
#     Early stopping counter: 25/30
#     Epoch 94/500, Train Loss: 105.3018, Val Loss: 131.2291
#     Early stopping counter: 26/30
#     Epoch 95/500, Train Loss: 117.6941, Val Loss: 99.5198
#     Early stopping counter: 27/30
#     Epoch 96/500, Train Loss: 112.1443, Val Loss: 143.5522
#     Early stopping counter: 28/30
#     Epoch 97/500, Train Loss: 123.7738, Val Loss: 81.2840
#     Early stopping counter: 29/30
#     Epoch 98/500, Train Loss: 117.7447, Val Loss: 76.1640
#     Early stopping counter: 30/30
#     Early stopping triggered.
#   Repeat 2/5
#     Epoch 1/500, Train Loss: 2553.1306, Val Loss: 7864.8746
#     Epoch 2/500, Train Loss: 2137.1221, Val Loss: 6620.5142
#     Epoch 3/500, Train Loss: 1413.0443, Val Loss: 4538.1919
#     Epoch 4/500, Train Loss: 670.0092, Val Loss: 2445.4541
#     Epoch 5/500, Train Loss: 456.5200, Val Loss: 1853.5773
#     Epoch 6/500, Train Loss: 443.2993, Val Loss: 2068.2261
#     Early stopping counter: 1/30
#     Epoch 7/500, Train Loss: 442.8112, Val Loss: 2018.1234
#     Early stopping counter: 2/30
#     Epoch 8/500, Train Loss: 433.7044, Val Loss: 1984.6721
#     Early stopping counter: 3/30
#     Epoch 9/500, Train Loss: 452.9590, Val Loss: 2067.3643
#     Early stopping counter: 4/30
#     Epoch 10/500, Train Loss: 444.7696, Val Loss: 2087.8347
#     Early stopping counter: 5/30
#     Epoch 11/500, Train Loss: 444.6910, Val Loss: 1975.6055
#     Early stopping counter: 6/30
#     Epoch 12/500, Train Loss: 425.4461, Val Loss: 2082.6670
#     Early stopping counter: 7/30
#     Epoch 13/500, Train Loss: 457.0082, Val Loss: 2080.6980
#     Early stopping counter: 8/30
#     Epoch 14/500, Train Loss: 434.5825, Val Loss: 1970.8906
#     Early stopping counter: 9/30
#     Epoch 15/500, Train Loss: 418.9667, Val Loss: 2081.3161
#     Early stopping counter: 10/30
#     Epoch 16/500, Train Loss: 468.1544, Val Loss: 2074.2512
#     Early stopping counter: 11/30
#     Epoch 17/500, Train Loss: 428.4564, Val Loss: 1954.7590
#     Early stopping counter: 12/30
#     Epoch 18/500, Train Loss: 436.3200, Val Loss: 2016.4704
#     Early stopping counter: 13/30
#     Epoch 19/500, Train Loss: 416.4393, Val Loss: 2016.6964
#     Early stopping counter: 14/30
#     Epoch 20/500, Train Loss: 454.5290, Val Loss: 2056.4469
#     Early stopping counter: 15/30
#     Epoch 21/500, Train Loss: 433.8559, Val Loss: 1959.9964
#     Early stopping counter: 16/30
#     Epoch 22/500, Train Loss: 419.8060, Val Loss: 1996.5437
#     Early stopping counter: 17/30
#     Epoch 23/500, Train Loss: 427.2186, Val Loss: 2033.6886
#     Early stopping counter: 18/30
#     Epoch 24/500, Train Loss: 435.9834, Val Loss: 2117.5859
#     Early stopping counter: 19/30
#     Epoch 25/500, Train Loss: 444.3016, Val Loss: 2082.4890
#     Early stopping counter: 20/30
#     Epoch 26/500, Train Loss: 430.9697, Val Loss: 1995.7779
#     Early stopping counter: 21/30
#     Epoch 27/500, Train Loss: 418.4523, Val Loss: 2079.8461
#     Early stopping counter: 22/30
#     Epoch 28/500, Train Loss: 406.5532, Val Loss: 2006.1816
#     Early stopping counter: 23/30
#     Epoch 29/500, Train Loss: 345.1194, Val Loss: 1412.2839
#     Epoch 30/500, Train Loss: 167.0421, Val Loss: 608.6984
#     Epoch 31/500, Train Loss: 119.6330, Val Loss: 301.6186
#     Epoch 32/500, Train Loss: 108.6331, Val Loss: 159.5181
#     Epoch 33/500, Train Loss: 115.3063, Val Loss: 173.8031
#     Early stopping counter: 1/30
#     Epoch 34/500, Train Loss: 97.3312, Val Loss: 152.4552
#     Epoch 35/500, Train Loss: 102.4169, Val Loss: 120.8294
#     Epoch 36/500, Train Loss: 97.9343, Val Loss: 135.5247
#     Early stopping counter: 1/30
#     Epoch 37/500, Train Loss: 106.0631, Val Loss: 165.9485
#     Early stopping counter: 2/30
#     Epoch 38/500, Train Loss: 107.0545, Val Loss: 145.0483
#     Early stopping counter: 3/30
#     Epoch 39/500, Train Loss: 112.9027, Val Loss: 245.7681
#     Early stopping counter: 4/30
#     Epoch 40/500, Train Loss: 101.5651, Val Loss: 130.4370
#     Early stopping counter: 5/30
#     Epoch 41/500, Train Loss: 98.7628, Val Loss: 121.3544
#     Early stopping counter: 6/30
#     Epoch 42/500, Train Loss: 104.4295, Val Loss: 114.6975
#     Epoch 43/500, Train Loss: 99.5345, Val Loss: 119.9330
#     Early stopping counter: 1/30
#     Epoch 44/500, Train Loss: 103.9980, Val Loss: 123.6156
#     Early stopping counter: 2/30
#     Epoch 45/500, Train Loss: 92.9029, Val Loss: 117.2753
#     Early stopping counter: 3/30
#     Epoch 46/500, Train Loss: 97.0765, Val Loss: 117.9763
#     Early stopping counter: 4/30
#     Epoch 47/500, Train Loss: 101.6489, Val Loss: 114.8320
#     Early stopping counter: 5/30
#     Epoch 48/500, Train Loss: 98.5013, Val Loss: 84.9499
#     Epoch 49/500, Train Loss: 101.4733, Val Loss: 77.3575
#     Epoch 50/500, Train Loss: 89.9284, Val Loss: 95.7731
#     Early stopping counter: 1/30
#     Epoch 51/500, Train Loss: 96.9481, Val Loss: 75.4061
#     Epoch 52/500, Train Loss: 95.5539, Val Loss: 87.1868
#     Early stopping counter: 1/30
#     Epoch 53/500, Train Loss: 88.1896, Val Loss: 82.2823
#     Early stopping counter: 2/30
#     Epoch 54/500, Train Loss: 88.2022, Val Loss: 109.0321
#     Early stopping counter: 3/30
#     Epoch 55/500, Train Loss: 92.2516, Val Loss: 130.8257
#     Early stopping counter: 4/30
#     Epoch 56/500, Train Loss: 107.9481, Val Loss: 87.8689
#     Early stopping counter: 5/30
#     Epoch 57/500, Train Loss: 104.2769, Val Loss: 61.7207
#     Epoch 58/500, Train Loss: 100.1888, Val Loss: 95.2751
#     Early stopping counter: 1/30
#     Epoch 59/500, Train Loss: 94.9990, Val Loss: 82.3443
#     Early stopping counter: 2/30
#     Epoch 60/500, Train Loss: 97.6459, Val Loss: 52.1492
#     Epoch 61/500, Train Loss: 91.3777, Val Loss: 71.1219
#     Early stopping counter: 1/30
#     Epoch 62/500, Train Loss: 93.2670, Val Loss: 79.4742
#     Early stopping counter: 2/30
#     Epoch 63/500, Train Loss: 98.8385, Val Loss: 93.5458
#     Early stopping counter: 3/30
#     Epoch 64/500, Train Loss: 100.4459, Val Loss: 91.4505
#     Early stopping counter: 4/30
#     Epoch 65/500, Train Loss: 108.7340, Val Loss: 73.3466
#     Early stopping counter: 5/30
#     Epoch 66/500, Train Loss: 93.8812, Val Loss: 53.4110
#     Early stopping counter: 6/30
#     Epoch 67/500, Train Loss: 93.8705, Val Loss: 64.8208
#     Early stopping counter: 7/30
#     Epoch 68/500, Train Loss: 99.2486, Val Loss: 82.2522
#     Early stopping counter: 8/30
#     Epoch 69/500, Train Loss: 99.7229, Val Loss: 100.0082
#     Early stopping counter: 9/30
#     Epoch 70/500, Train Loss: 97.7333, Val Loss: 97.1918
#     Early stopping counter: 10/30
#     Epoch 71/500, Train Loss: 114.0120, Val Loss: 114.1026
#     Early stopping counter: 11/30
#     Epoch 72/500, Train Loss: 88.4425, Val Loss: 80.5121
#     Early stopping counter: 12/30
#     Epoch 73/500, Train Loss: 94.9208, Val Loss: 43.7148
#     Epoch 74/500, Train Loss: 100.2337, Val Loss: 58.2513
#     Early stopping counter: 1/30
#     Epoch 75/500, Train Loss: 98.8509, Val Loss: 80.1185
#     Early stopping counter: 2/30
#     Epoch 76/500, Train Loss: 93.6310, Val Loss: 76.9011
#     Early stopping counter: 3/30
#     Epoch 77/500, Train Loss: 101.5230, Val Loss: 63.2770
#     Early stopping counter: 4/30
#     Epoch 78/500, Train Loss: 106.6420, Val Loss: 92.4984
#     Early stopping counter: 5/30
#     Epoch 79/500, Train Loss: 102.4916, Val Loss: 104.4944
#     Early stopping counter: 6/30
#     Epoch 80/500, Train Loss: 107.9904, Val Loss: 125.1288
#     Early stopping counter: 7/30
#     Epoch 81/500, Train Loss: 97.1364, Val Loss: 82.7878
#     Early stopping counter: 8/30
#     Epoch 82/500, Train Loss: 101.1866, Val Loss: 136.8626
#     Early stopping counter: 9/30
#     Epoch 83/500, Train Loss: 101.0902, Val Loss: 108.6382
#     Early stopping counter: 10/30
#     Epoch 84/500, Train Loss: 102.4315, Val Loss: 96.8153
#     Early stopping counter: 11/30
#     Epoch 85/500, Train Loss: 100.8867, Val Loss: 64.0317
#     Early stopping counter: 12/30
# ...
#     Early stopping counter: 2/30
#     Epoch 81/500, Train Loss: 215.3812, Val Loss: 145.7352
#     Early stopping counter: 3/30
#     Epoch 82/500, Train Loss: 227.4127, Val Loss: 147.1785
#     Early stopping counter: 4/30
#     Epoch 83/500, Train Loss: 189.3067, Val Loss: 133.7202
#     Epoch 84/500, Train Loss: 211.7996, Val Loss: 141.3859
#     Early stopping counter: 1/30
#     Epoch 85/500, Train Loss: 214.5872, Val Loss: 136.2385
#     Early stopping counter: 2/30
#     Epoch 86/500, Train Loss: 203.4923, Val Loss: 137.9649
#     Early stopping counter: 3/30
#     Epoch 87/500, Train Loss: 202.1663, Val Loss: 130.1794
#     Epoch 88/500, Train Loss: 209.9373, Val Loss: 134.7006
#     Early stopping counter: 1/30
#     Epoch 89/500, Train Loss: 212.3501, Val Loss: 125.9555
#     Epoch 90/500, Train Loss: 209.2289, Val Loss: 139.2017
#     Early stopping counter: 1/30
#     Epoch 91/500, Train Loss: 208.1946, Val Loss: 129.4348
#     Early stopping counter: 2/30
#     Epoch 92/500, Train Loss: 196.1098, Val Loss: 130.3335
#     Early stopping counter: 3/30
#     Epoch 93/500, Train Loss: 189.1275, Val Loss: 129.2142
#     Early stopping counter: 4/30
#     Epoch 94/500, Train Loss: 202.0079, Val Loss: 135.9394
#     Early stopping counter: 5/30
#     Epoch 95/500, Train Loss: 208.3192, Val Loss: 129.9214
#     Early stopping counter: 6/30
#     Epoch 96/500, Train Loss: 212.4272, Val Loss: 123.0530
#     Epoch 97/500, Train Loss: 205.0250, Val Loss: 126.5709
#     Early stopping counter: 1/30
#     Epoch 98/500, Train Loss: 203.0389, Val Loss: 129.1517
#     Early stopping counter: 2/30
#     Epoch 99/500, Train Loss: 218.8046, Val Loss: 118.2560
#     Epoch 100/500, Train Loss: 204.9647, Val Loss: 127.0929
#     Early stopping counter: 1/30
#     Epoch 101/500, Train Loss: 212.0827, Val Loss: 152.0191
#     Early stopping counter: 2/30
#     Epoch 102/500, Train Loss: 201.2449, Val Loss: 153.0069
#     Early stopping counter: 3/30
#     Epoch 103/500, Train Loss: 198.2325, Val Loss: 201.2301
#     Early stopping counter: 4/30
#     Epoch 104/500, Train Loss: 208.5407, Val Loss: 169.0218
#     Early stopping counter: 5/30
#     Epoch 105/500, Train Loss: 206.2673, Val Loss: 142.7208
#     Early stopping counter: 6/30
#     Epoch 106/500, Train Loss: 191.4788, Val Loss: 148.1055
#     Early stopping counter: 7/30
#     Epoch 107/500, Train Loss: 209.7021, Val Loss: 142.5322
#     Early stopping counter: 8/30
#     Epoch 108/500, Train Loss: 215.8347, Val Loss: 171.5468
#     Early stopping counter: 9/30
#     Epoch 109/500, Train Loss: 198.9179, Val Loss: 161.3144
#     Early stopping counter: 10/30
#     Epoch 110/500, Train Loss: 197.5692, Val Loss: 140.7708
#     Early stopping counter: 11/30
#     Epoch 111/500, Train Loss: 209.0579, Val Loss: 119.4392
#     Early stopping counter: 12/30
#     Epoch 112/500, Train Loss: 212.1360, Val Loss: 114.4912
#     Epoch 113/500, Train Loss: 207.3731, Val Loss: 136.1643
#     Early stopping counter: 1/30
#     Epoch 114/500, Train Loss: 198.8775, Val Loss: 121.4921
#     Early stopping counter: 2/30
#     Epoch 115/500, Train Loss: 190.6382, Val Loss: 116.9467
#     Early stopping counter: 3/30
#     Epoch 116/500, Train Loss: 198.1756, Val Loss: 111.1028
#     Epoch 117/500, Train Loss: 196.3098, Val Loss: 118.0250
#     Early stopping counter: 1/30
#     Epoch 118/500, Train Loss: 185.3876, Val Loss: 121.4076
#     Early stopping counter: 2/30
#     Epoch 119/500, Train Loss: 211.9710, Val Loss: 108.2134
#     Epoch 120/500, Train Loss: 198.4701, Val Loss: 110.1624
#     Early stopping counter: 1/30
#     Epoch 121/500, Train Loss: 209.2047, Val Loss: 108.1447
#     Epoch 122/500, Train Loss: 195.2582, Val Loss: 106.4921
#     Epoch 123/500, Train Loss: 210.1999, Val Loss: 122.5056
#     Early stopping counter: 1/30
#     Epoch 124/500, Train Loss: 209.8835, Val Loss: 136.7908
#     Early stopping counter: 2/30
#     Epoch 125/500, Train Loss: 211.3347, Val Loss: 147.0541
#     Early stopping counter: 3/30
#     Epoch 126/500, Train Loss: 195.6554, Val Loss: 140.1740
#     Early stopping counter: 4/30
#     Epoch 127/500, Train Loss: 203.3814, Val Loss: 150.6532
#     Early stopping counter: 5/30
#     Epoch 128/500, Train Loss: 213.8623, Val Loss: 137.5419
#     Early stopping counter: 6/30
#     Epoch 129/500, Train Loss: 211.5796, Val Loss: 130.2010
#     Early stopping counter: 7/30
#     Epoch 130/500, Train Loss: 211.9916, Val Loss: 132.8919
#     Early stopping counter: 8/30
#     Epoch 131/500, Train Loss: 201.4429, Val Loss: 142.4455
#     Early stopping counter: 9/30
#     Epoch 132/500, Train Loss: 207.3806, Val Loss: 151.2313
#     Early stopping counter: 10/30
#     Epoch 133/500, Train Loss: 199.7666, Val Loss: 142.4202
#     Early stopping counter: 11/30
#     Epoch 134/500, Train Loss: 198.0231, Val Loss: 138.9713
#     Early stopping counter: 12/30
#     Epoch 135/500, Train Loss: 192.0222, Val Loss: 134.6753
#     Early stopping counter: 13/30
#     Epoch 136/500, Train Loss: 220.0895, Val Loss: 150.9084
#     Early stopping counter: 14/30
#     Epoch 137/500, Train Loss: 206.0312, Val Loss: 156.5410
#     Early stopping counter: 15/30
#     Epoch 138/500, Train Loss: 187.6660, Val Loss: 170.3657
#     Early stopping counter: 16/30
#     Epoch 139/500, Train Loss: 198.0435, Val Loss: 139.0643
#     Early stopping counter: 17/30
#     Epoch 140/500, Train Loss: 198.3069, Val Loss: 141.7024
#     Early stopping counter: 18/30
#     Epoch 141/500, Train Loss: 197.2808, Val Loss: 128.3678
#     Early stopping counter: 19/30
#     Epoch 142/500, Train Loss: 204.3656, Val Loss: 116.1923
#     Early stopping counter: 20/30
#     Epoch 143/500, Train Loss: 188.7105, Val Loss: 136.3424
#     Early stopping counter: 21/30
#     Epoch 144/500, Train Loss: 205.5315, Val Loss: 118.5494
#     Early stopping counter: 22/30
#     Epoch 145/500, Train Loss: 197.8471, Val Loss: 143.2475
#     Early stopping counter: 23/30
#     Epoch 146/500, Train Loss: 189.1263, Val Loss: 127.2348
#     Early stopping counter: 24/30
#     Epoch 147/500, Train Loss: 204.4799, Val Loss: 130.5092
#     Early stopping counter: 25/30
#     Epoch 148/500, Train Loss: 203.9621, Val Loss: 127.4781
#     Early stopping counter: 26/30
#     Epoch 149/500, Train Loss: 207.9598, Val Loss: 138.8074
#     Early stopping counter: 27/30
#     Epoch 150/500, Train Loss: 199.6129, Val Loss: 117.9937
#     Early stopping counter: 28/30
#     Epoch 151/500, Train Loss: 197.7007, Val Loss: 128.0102
#     Early stopping counter: 29/30
#     Epoch 152/500, Train Loss: 203.4840, Val Loss: 123.9188
#     Early stopping counter: 30/30
#     Early stopping triggered.
#   Repeat 5/5
#     Epoch 1/500, Train Loss: 2642.3305, Val Loss: 8229.7891
#     Epoch 2/500, Train Loss: 2618.1962, Val Loss: 8216.9137
#     Epoch 3/500, Train Loss: 2587.3054, Val Loss: 8148.0235
#     Epoch 4/500, Train Loss: 2556.0500, Val Loss: 8017.5933
#     Epoch 5/500, Train Loss: 2478.0710, Val Loss: 7855.0427
#     Epoch 6/500, Train Loss: 2385.7752, Val Loss: 7671.0537
#     Epoch 7/500, Train Loss: 2273.7620, Val Loss: 7458.0094
#     Epoch 8/500, Train Loss: 2153.1681, Val Loss: 7211.5782
#     Epoch 9/500, Train Loss: 2007.1752, Val Loss: 6929.9154
#     Epoch 10/500, Train Loss: 1891.9817, Val Loss: 6617.7607
#     Epoch 11/500, Train Loss: 1756.8716, Val Loss: 6277.4793
#     Epoch 12/500, Train Loss: 1572.7451, Val Loss: 5907.4795
#     Epoch 13/500, Train Loss: 1436.3675, Val Loss: 5515.6225
#     Epoch 14/500, Train Loss: 1255.9769, Val Loss: 5118.7608
#     Epoch 15/500, Train Loss: 1107.8410, Val Loss: 4723.1316
#     Epoch 16/500, Train Loss: 1029.3943, Val Loss: 4341.0314
#     Epoch 17/500, Train Loss: 852.9870, Val Loss: 3978.9915
#     Epoch 18/500, Train Loss: 814.1258, Val Loss: 3646.4129
#     Epoch 19/500, Train Loss: 722.4285, Val Loss: 3361.5418
#     Epoch 20/500, Train Loss: 665.9868, Val Loss: 3110.6078
#     Epoch 21/500, Train Loss: 680.8415, Val Loss: 2898.2127
#     Epoch 22/500, Train Loss: 651.0399, Val Loss: 2734.2177
#     Epoch 23/500, Train Loss: 594.2252, Val Loss: 2605.3112
#     Epoch 24/500, Train Loss: 646.3055, Val Loss: 2510.4297
#     Epoch 25/500, Train Loss: 583.0356, Val Loss: 2453.5943
#     Epoch 26/500, Train Loss: 609.1820, Val Loss: 2412.9907
#     Epoch 27/500, Train Loss: 617.2028, Val Loss: 2373.3736
#     Epoch 28/500, Train Loss: 601.2049, Val Loss: 2345.8089
#     Epoch 29/500, Train Loss: 594.9573, Val Loss: 2317.5481
#     Epoch 30/500, Train Loss: 572.0629, Val Loss: 2308.2118
#     Epoch 31/500, Train Loss: 574.7635, Val Loss: 2311.4436
#     Early stopping counter: 1/30
#     Epoch 32/500, Train Loss: 586.9377, Val Loss: 2331.1205
#     Early stopping counter: 2/30
#     Epoch 33/500, Train Loss: 577.8305, Val Loss: 2298.5860
#     Epoch 34/500, Train Loss: 464.0602, Val Loss: 2081.7096
#     Epoch 35/500, Train Loss: 397.7912, Val Loss: 1836.4663
#     Epoch 36/500, Train Loss: 382.3431, Val Loss: 1603.6594
#     Epoch 37/500, Train Loss: 340.6950, Val Loss: 1415.1059
#     Epoch 38/500, Train Loss: 311.8544, Val Loss: 1246.9749
#     Epoch 39/500, Train Loss: 304.8888, Val Loss: 1091.4209
#     Epoch 40/500, Train Loss: 303.8270, Val Loss: 971.0292
#     Epoch 41/500, Train Loss: 282.6895, Val Loss: 871.7950
#     Epoch 42/500, Train Loss: 251.8831, Val Loss: 783.2016
#     Epoch 43/500, Train Loss: 277.2236, Val Loss: 726.3395
#     Epoch 44/500, Train Loss: 270.7107, Val Loss: 675.1597
#     Epoch 45/500, Train Loss: 259.4241, Val Loss: 638.5171
#     Epoch 46/500, Train Loss: 249.0489, Val Loss: 587.5185
#     Epoch 47/500, Train Loss: 265.2068, Val Loss: 529.9562
#     Epoch 48/500, Train Loss: 273.4353, Val Loss: 491.3198
#     Epoch 49/500, Train Loss: 257.1127, Val Loss: 453.2723
#     Epoch 50/500, Train Loss: 232.8781, Val Loss: 421.9322
#     Epoch 51/500, Train Loss: 257.0790, Val Loss: 402.0976
#     Epoch 52/500, Train Loss: 238.9138, Val Loss: 375.5739
#     Epoch 53/500, Train Loss: 243.0259, Val Loss: 358.0020
#     Epoch 54/500, Train Loss: 266.7194, Val Loss: 331.7208
#     Epoch 55/500, Train Loss: 267.1001, Val Loss: 297.0207
#     Epoch 56/500, Train Loss: 235.8112, Val Loss: 278.2409
#     Epoch 57/500, Train Loss: 244.5537, Val Loss: 271.5039
#     Epoch 58/500, Train Loss: 246.8409, Val Loss: 260.5578
#     Epoch 59/500, Train Loss: 234.8562, Val Loss: 246.9989
#     Epoch 60/500, Train Loss: 246.9808, Val Loss: 229.4554
#     Epoch 61/500, Train Loss: 234.5303, Val Loss: 220.4990
#     Epoch 62/500, Train Loss: 269.2987, Val Loss: 214.9124
#     Epoch 63/500, Train Loss: 253.9436, Val Loss: 223.0402
#     Early stopping counter: 1/30
#     Epoch 64/500, Train Loss: 227.0928, Val Loss: 210.1102
#     Epoch 65/500, Train Loss: 239.2943, Val Loss: 197.3649
#     Epoch 66/500, Train Loss: 209.4831, Val Loss: 189.7304
#     Epoch 67/500, Train Loss: 220.0908, Val Loss: 180.1155
#     Epoch 68/500, Train Loss: 229.7537, Val Loss: 175.1594
#     Epoch 69/500, Train Loss: 223.1524, Val Loss: 164.0698
#     Epoch 70/500, Train Loss: 229.2426, Val Loss: 160.1813
#     Epoch 71/500, Train Loss: 243.6227, Val Loss: 157.1159
#     Epoch 72/500, Train Loss: 233.5686, Val Loss: 151.8645
#     Epoch 73/500, Train Loss: 231.7745, Val Loss: 173.1172
#     Early stopping counter: 1/30
#     Epoch 74/500, Train Loss: 222.5782, Val Loss: 131.1796
#     Epoch 75/500, Train Loss: 224.3324, Val Loss: 132.1576
#     Early stopping counter: 1/30
#     Epoch 76/500, Train Loss: 208.9385, Val Loss: 128.7544
#     Epoch 77/500, Train Loss: 213.5436, Val Loss: 125.3883
#     Epoch 78/500, Train Loss: 213.9963, Val Loss: 122.9678
#     Epoch 79/500, Train Loss: 226.0255, Val Loss: 117.1800
#     Epoch 80/500, Train Loss: 219.0861, Val Loss: 150.5277
#     Early stopping counter: 1/30
#     Epoch 81/500, Train Loss: 224.8082, Val Loss: 115.1732
#     Epoch 82/500, Train Loss: 227.7667, Val Loss: 103.4816
#     Epoch 83/500, Train Loss: 220.5190, Val Loss: 104.3539
#     Early stopping counter: 1/30
#     Epoch 84/500, Train Loss: 214.5155, Val Loss: 107.6647
#     Early stopping counter: 2/30
#     Epoch 85/500, Train Loss: 231.3736, Val Loss: 135.5091
#     Early stopping counter: 3/30
#     Epoch 86/500, Train Loss: 226.2479, Val Loss: 115.6798
#     Early stopping counter: 4/30
#     Epoch 87/500, Train Loss: 234.5919, Val Loss: 107.0119
#     Early stopping counter: 5/30
#     Epoch 88/500, Train Loss: 227.2354, Val Loss: 110.7540
#     Early stopping counter: 6/30
#     Epoch 89/500, Train Loss: 224.1433, Val Loss: 102.2351
#     Epoch 90/500, Train Loss: 211.8506, Val Loss: 120.1073
#     Early stopping counter: 1/30
#     Epoch 91/500, Train Loss: 214.1088, Val Loss: 122.0649
#     Early stopping counter: 2/30
#     Epoch 92/500, Train Loss: 226.7447, Val Loss: 129.9644
#     Early stopping counter: 3/30
#     Epoch 93/500, Train Loss: 218.2976, Val Loss: 130.8100
#     Early stopping counter: 4/30
#     Epoch 94/500, Train Loss: 215.4014, Val Loss: 125.2524
#     Early stopping counter: 5/30
#     Epoch 95/500, Train Loss: 211.0180, Val Loss: 110.5510
#     Early stopping counter: 6/30
#     Epoch 96/500, Train Loss: 216.5697, Val Loss: 113.8626
#     Early stopping counter: 7/30
#     Epoch 97/500, Train Loss: 213.6941, Val Loss: 115.2647
#     Early stopping counter: 8/30
#     Epoch 98/500, Train Loss: 203.2539, Val Loss: 120.1620
#     Early stopping counter: 9/30
#     Epoch 99/500, Train Loss: 219.7975, Val Loss: 126.8974
#     Early stopping counter: 10/30
#     Epoch 100/500, Train Loss: 223.6043, Val Loss: 135.3165
#     Early stopping counter: 11/30
#     Epoch 101/500, Train Loss: 206.7559, Val Loss: 124.6328
#     Early stopping counter: 12/30
#     Epoch 102/500, Train Loss: 199.1932, Val Loss: 133.4607
#     Early stopping counter: 13/30
#     Epoch 103/500, Train Loss: 203.6296, Val Loss: 138.2571
#     Early stopping counter: 14/30
#     Epoch 104/500, Train Loss: 213.4495, Val Loss: 120.8232
#     Early stopping counter: 15/30
#     Epoch 105/500, Train Loss: 205.2274, Val Loss: 126.1299
#     Early stopping counter: 16/30
#     Epoch 106/500, Train Loss: 205.6946, Val Loss: 126.4334
#     Early stopping counter: 17/30
#     Epoch 107/500, Train Loss: 202.8484, Val Loss: 118.4980
#     Early stopping counter: 18/30
#     Epoch 108/500, Train Loss: 198.8407, Val Loss: 131.1147
#     Early stopping counter: 19/30
#     Epoch 109/500, Train Loss: 235.0311, Val Loss: 145.2050
#     Early stopping counter: 20/30
#     Epoch 110/500, Train Loss: 210.9346, Val Loss: 168.9523
#     Early stopping counter: 21/30
#     Epoch 111/500, Train Loss: 217.9000, Val Loss: 139.3594
#     Early stopping counter: 22/30
#     Epoch 112/500, Train Loss: 213.0527, Val Loss: 136.1297
#     Early stopping counter: 23/30
#     Epoch 113/500, Train Loss: 192.7403, Val Loss: 142.9448
#     Early stopping counter: 24/30
#     Epoch 114/500, Train Loss: 191.1247, Val Loss: 118.9752
#     Early stopping counter: 25/30
#     Epoch 115/500, Train Loss: 217.0088, Val Loss: 109.5782
#     Early stopping counter: 26/30
#     Epoch 116/500, Train Loss: 195.7017, Val Loss: 117.7643
#     Early stopping counter: 27/30
#     Epoch 117/500, Train Loss: 194.4787, Val Loss: 122.5341
#     Early stopping counter: 28/30
#     Epoch 118/500, Train Loss: 217.5980, Val Loss: 140.9169
#     Early stopping counter: 29/30
#     Epoch 119/500, Train Loss: 207.2534, Val Loss: 151.8082
#     Early stopping counter: 30/30
#     Early stopping triggered.
# Average Validation Loss for this combination: 95.2065
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-215-c25fc1c0475f> in <cell line: 0>()
#      93
#      94 # Load the best model
# ---> 95 model.load_state_dict(best_model)
#      96 print(f"Best model parameters: {best_params}")
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in load_state_dict(self, state_dict, strict, assign)
#    2582
#    2583         if len(error_msgs) > 0:
# -> 2584             raise RuntimeError(
#    2585                 "Error(s) in loading state_dict for {}:\n\t{}".format(
#    2586                     self.__class__.__name__, "\n\t".join(error_msgs)
#
# RuntimeError: Error(s) in loading state_dict for ComplexLSTMModel:
# 	Missing key(s) in state_dict: "lstm.weight_ih_l2", "lstm.weight_hh_l2", "lstm.bias_ih_l2", "lstm.bias_hh_l2", "lstm.weight_ih_l3", "lstm.weight_hh_l3", "lstm.bias_ih_l3", "lstm.bias_hh_l3".

# %%
best_params
# Out:
# (128, 2, 0.1, 0.0005, 30)

# %%
print("Best params is hidden size 128, 2 layers, dropout 0.1, learning rate 0.0005, patience 30")
# Out:
# Best params is hidden size 128, 2 layers, dropout 0.1, learning rate 0.0005, patience 30
