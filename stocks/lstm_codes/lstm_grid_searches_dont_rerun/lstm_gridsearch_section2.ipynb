# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import os
import torch

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
file_path = "SPY.csv"
df = pd.read_csv(file_path)




# start to nov 2001 (dot com crash)
# not bad
# df = df.iloc[:2228]

# nov 01 to june 2009
# not bad
df = df.iloc[2228:4135]

# june 2009 to april 2020
# ass
# df = df.iloc[4135:6862]

# april 2020 to most recent
# ass
# df = df.iloc[6862:]


# Convert the "Date" column to datetime
# df["Date"] = pd.to_datetime(df["Date"], format='%Y/%m/%d')

# # Sort the data by date in ascending order
# df = df.sort_values(by="Date")

# # Get the earliest and latest dates
# earliest_date = df["Date"].min()
# latest_date = df["Date"].max()

# print("Earliest Date:", earliest_date)
# print("Latest Date:", latest_date)

# %%
print(df.tail())
# Out:
#             Date       Open       High        Low      Close     Volume  Day  \
# 4130  2009-06-23  67.457192  67.766315  66.989732  67.366714  188309800   23
# 4131  2009-06-24  67.977433  68.671078  67.555209  67.947273  211577700   24
# 4132  2009-06-25  67.607977  69.492888  67.532582  69.425034  279411000   25
# 4133  2009-06-26  69.191295  69.545659  68.814313  69.244072  167579000   26
# 4134  2009-06-29  69.447666  69.982980  69.063142  69.892502  168481300   29
#
#       Weekday  Week  Month  Year
# 4130        1    26      6  2009
# 4131        2    26      6  2009
# 4132        3    26      6  2009
# 4133        4    26      6  2009
# 4134        0    27      6  2009

# %%
# if 'Day' and 'Weekday' and 'Week' and 'Month' and 'Year' in df.columns:
    # df.drop(columns=['Day', 'Weekday', 'Week', 'Month', 'Year'], inplace=True)

# %%
if "Target" not in df.columns:
    # df["Target"] = (df["Close"].shift(-1) > df["Close"]).astype(int)
    df["Target"] = df["Close"].shift(-1)

# %%
df = df.dropna()

# %%
# Adding SMA as part of the feature test
short_term_period = 20
medium_term_period = 50
long_term_period = 200

# Compute the SMAs
df['SMA_20'] = df['Close'].rolling(window=short_term_period).mean()
df['SMA_50'] = df['Close'].rolling(window=medium_term_period).mean()
df['SMA_200'] = df['Close'].rolling(window=long_term_period).mean()

df['EMA_10'] = df['Close'].ewm(span=10, adjust=False).mean()  # Short-term EMA
df['EMA_50'] = df['Close'].ewm(span=50, adjust=False).mean()  # Medium-term EMA
df['EMA_200'] = df['Close'].ewm(span=200, adjust=False).mean()  # Long-term EMA

# %%
df = df.dropna()

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

# Assuming you have a DataFrame `df` with a 'Close' column

# Create an index for the time series (usually the row number)
df['Time'] = np.arange(len(df))

# Fit a polynomial regression to the 'Close' price
X = df[['Time']]  # Independent variable (time)
y = df['Close']   # Dependent variable (closing price)

# Initialize a polynomial features transformer (degree = 2 for quadratic, or higher for more non-linearity)
degree = 3  # You can change the degree for more complexity
poly = PolynomialFeatures(degree)

# Transform the Time feature into polynomial features
X_poly = poly.fit_transform(X)

# Initialize and fit the linear regression model to the polynomial features
model = LinearRegression()
model.fit(X_poly, y)

# Generate predictions for the polynomial regression (non-linear trend)
df['Non_Linear_Trend'] = model.predict(X_poly)

# Optionally, visualize the non-linear trend
plt.figure(figsize=(12, 6))
plt.plot(df['Time'], df['Close'], label='Close Price')
plt.plot(df['Time'], df['Non_Linear_Trend'], label=f'Non-Linear Trend (Degree {degree})', linestyle='--')
plt.xlabel('Time')
plt.ylabel('Price')
plt.title('Stock Prices with Non-Linear Trend')
plt.legend()
plt.show()

# %% [markdown]
# ## CREATING THE NEURAL NETWORK MODEL

# %%
dates = df["Date"]
X = df.drop(columns=["Date", "Target"])
y = df["Target"]

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix

# %%
# Define the LSTM-based model
class LSTMModel(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, dropout_rate):
        super(LSTMModel, self).__init__()
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True, dropout=dropout_rate)
        self.fc = nn.Linear(hidden_size, 1)  # Output layer for binary classification
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        # LSTM expects input of shape (batch_size, sequence_length, input_size)
        out, _ = self.lstm(x)
        # Use the output of the last time step
        out = out[:, -1, :]  # Shape: (batch_size, hidden_size)
        out = self.fc(out)  # Shape: (batch_size, 1)
        out = self.sigmoid(out)
        return out

# Define a more complex LSTM-based model
# class ComplexLSTMModel(nn.Module):
#     def __init__(self, input_size, hidden_size, num_layers, dropout_rate):
#         super(ComplexLSTMModel, self).__init__()
#         # LSTM Layer: Bidirectional for richer context
#         self.lstm = nn.LSTM(input_size, hidden_size, num_layers,
#                             batch_first=True, dropout=dropout_rate,
#                             bidirectional=True)
#         # Fully connected layers for added complexity
#         self.fc1 = nn.Linear(hidden_size * 2, hidden_size)  # Bidirectional LSTM doubles hidden size
#         self.dropout1 = nn.Dropout(dropout_rate)
#         self.fc2 = nn.Linear(hidden_size, hidden_size // 2)
#         self.dropout2 = nn.Dropout(dropout_rate)
#         self.fc3 = nn.Linear(hidden_size // 2, 1)
#         self.sigmoid = nn.Sigmoid()

#     def forward(self, x):
#         # LSTM expects input of shape (batch_size, sequence_length, input_size)
#         out, _ = self.lstm(x)
#         # Use the output of the last time step
#         out = out[:, -1, :]  # Shape: (batch_size, hidden_size * 2)
#         out = self.fc1(out)  # First fully connected layer
#         out = self.dropout1(out)
#         out = torch.relu(out)  # Nonlinear activation
#         out = self.fc2(out)  # Second fully connected layer
#         out = self.dropout2(out)
#         out = torch.relu(out)  # Nonlinear activation
#         out = self.fc3(out)  # Output layer
#         out = self.sigmoid(out)  # Apply sigmoid for binary classification
#         return out

# class ComplexLSTMModel(nn.Module):
#     def __init__(self, input_size, hidden_size, num_layers, dropout_rate):
#         super(ComplexLSTMModel, self).__init__()
#         # LSTM Layer: Bidirectional for richer context
#         self.lstm = nn.LSTM(input_size, hidden_size, num_layers,
#                             batch_first=True, dropout=dropout_rate,
#                             bidirectional=True)
#         # Fully connected layers for added complexity
#         self.fc1 = nn.Linear(hidden_size * 2, hidden_size)  # Bidirectional LSTM doubles hidden size
#         self.dropout1 = nn.Dropout(dropout_rate)
#         self.fc2 = nn.Linear(hidden_size, hidden_size // 2)
#         self.dropout2 = nn.Dropout(dropout_rate)
#         self.fc3 = nn.Linear(hidden_size // 2, 1)

#     def forward(self, x):
#         # LSTM expects input of shape (batch_size, sequence_length, input_size)
#         out, _ = self.lstm(x)
#         # Use the output of the last time step
#         out = out[:, -1, :]  # Shape: (batch_size, hidden_size * 2)
#         out = self.fc1(out)  # First fully connected layer
#         out = self.dropout1(out)
#         out = torch.relu(out)  # Nonlinear activation
#         out = self.fc2(out)  # Second fully connected layer
#         out = self.dropout2(out)
#         out = torch.relu(out)  # Nonlinear activation
#         out = self.fc3(out)  # Output layer
#         return out

class ComplexLSTMModel(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, dropout_rate):
        super(ComplexLSTMModel, self).__init__()
        # Unidirectional LSTM for sequential stock price prediction
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers,
                            batch_first=True, dropout=dropout_rate)  # Removed bidirectional=True

        # Fully connected layers for added complexity
        self.fc1 = nn.Linear(hidden_size, hidden_size // 2)
        self.dropout1 = nn.Dropout(dropout_rate)
        self.fc2 = nn.Linear(hidden_size // 2, hidden_size // 4)
        self.dropout2 = nn.Dropout(dropout_rate)
        self.fc3 = nn.Linear(hidden_size // 4, 1)

    def forward(self, x):
        # LSTM expects input of shape (batch_size, sequence_length, input_size)
        out, _ = self.lstm(x)
        # Use the output of the last time step
        out = out[:, -1, :]  # Shape: (batch_size, hidden_size)

        out = torch.relu(self.fc1(out))  # First fully connected layer
        out = self.dropout1(out)
        out = torch.relu(self.fc2(out))  # Second fully connected layer
        out = self.dropout2(out)
        out = self.fc3(out)  # Output layer (no activation for regression)
        return out

# %%
sequence_length = 10

# Reshape data into sequences
def create_sequences(data, target, seq_length):
    X_seq, y_seq = [], []
    for i in range(len(data) - seq_length):
        X_seq.append(data[i:i + seq_length])
        y_seq.append(target[i + seq_length])
    return np.array(X_seq), np.array(y_seq)

# %%
# scaler = StandardScaler()
# scaler = MinMaxScaler()
# feature_columns = ["Open", "High", "Low", "Close", "Volume", "Day", "Weekday", "Week", "Month", "Year"]
# feature_columns = ["Open", "High", "Low", "Close", "Volume", "SMA_20", "SMA_50", "SMA_200", "EMA_10", "EMA_50", "EMA_200", "Non_Linear_Trend"]
feature_columns = ["Open", "High", "Low", "Close", "Volume", "SMA_20", "SMA_50", "SMA_200", "EMA_10", "EMA_50", "EMA_200"]
# feature_columns = ["Open", "High", "Low", "Close", "Volume", "Non_Linear_Trend", "SMA_20", "SMA_50", "EMA_10", "EMA_50"]
# feature_columns = ["Open", "High", "Low", "Close", "Volume", "Non_Linear_Trend"]

# Split data
train_size = int(X.shape[0] * 0.7)
val_size = int(X.shape[0] * 0.15)

# Initialize scaler
# scaler = RobustScaler()
scaler = MinMaxScaler()

# Split data into train, validation, and test
temp_train = X[:train_size]
temp_val = X[train_size:train_size + val_size]
temp_test = X[train_size + val_size:]

temp_train = temp_train[feature_columns]
temp_val = temp_val[feature_columns]
temp_test = temp_test[feature_columns]

# Fit and transform for train, transform for validation and test
temp_train = scaler.fit_transform(temp_train)
temp_val = scaler.transform(temp_val)
temp_test = scaler.transform(temp_test)

# Convert NumPy arrays back to DataFrames
temp_train = pd.DataFrame(temp_train, columns=feature_columns)
temp_val = pd.DataFrame(temp_val, columns=feature_columns)
temp_test = pd.DataFrame(temp_test, columns=feature_columns)

# Concatenate the data
X_scaled = pd.concat([temp_train, temp_val, temp_test], axis=0)

# scaler = StandardScaler()

# scaler.fit(X_train)
# X_scaled = pd.DataFrame(scaler.fit_transform(X[feature_columns]), columns=feature_columns, index=X.index)

X_seq, y_seq = create_sequences(X_scaled, y.values, sequence_length)


# Split sequentially
X_train, y_train = X_seq[:train_size], y_seq[:train_size]
X_val, y_val = X_seq[train_size:train_size + val_size], y_seq[train_size:train_size + val_size]
X_test, y_test = X_seq[train_size + val_size:], y_seq[train_size + val_size:]

# Print sizes to confirm
print(f"Train: {len(X_train)}, Val: {len(X_val)}, Test: {len(X_test)}")
# Out:
# Train: 1194, Val: 256, Test: 247

# %%
# Convert to PyTorch tensors
X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train, dtype=torch.float32)
X_val_tensor = torch.tensor(X_val, dtype=torch.float32)
y_val_tensor = torch.tensor(y_val, dtype=torch.float32)
X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test, dtype=torch.float32)

# Create DataLoaders
train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
val_dataset = TensorDataset(X_val_tensor, y_val_tensor)
test_dataset = TensorDataset(X_test_tensor, y_test_tensor)

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=64, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

# %%
# THE OG
# Hyperparameters
# input_size = X_train.shape[2]  # Number of features
# hidden_size = 32
# num_layers = 2
# dropout_rate = 0.3
# learning_rate = 0.01
# num_epochs = 100
# patience = 17

# Hyperparameters
input_size = X_train.shape[2]  # Number of features
hidden_size = 128
num_layers = 4
dropout_rate = 0.3
learning_rate = 0.0001
num_epochs = 500
patience = 30


# Initialize the LSTM model
# model = LSTMModel(input_size=input_size, hidden_size=hidden_size, num_layers=num_layers, dropout_rate=dropout_rate)
model = ComplexLSTMModel(input_size=input_size, hidden_size=hidden_size, num_layers=num_layers, dropout_rate=dropout_rate)

model.to(device)

# Define loss and optimizer
# criterion = nn.BCELoss()
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# Training loop with early stopping
best_val_loss = float('inf')
early_stop_counter = 0

# if not os.path.exists("./models/best_lstm_model.pth"):
if not os.path.exists("./lstm_trials/lstm_after_gridsearch_new.pth"):
    for epoch in range(num_epochs):
        model.train()
        train_loss = 0
        for X_batch, y_batch in train_loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)
            y_batch = y_batch.unsqueeze(1)  # Match output shape
            optimizer.zero_grad()
            outputs = model(X_batch)
            loss = criterion(outputs, y_batch)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()
            train_loss += loss.item()

        train_loss /= len(train_loader)

        # Validation
        model.eval()
        val_loss = 0
        with torch.no_grad():
            for X_batch, y_batch in val_loader:
                X_batch, y_batch = X_batch.to(device), y_batch.to(device)
                y_batch = y_batch.unsqueeze(1)
                outputs = model(X_batch)
                loss = criterion(outputs, y_batch)
                val_loss += loss.item()

        val_loss /= len(val_loader)
        print(f"Epoch {epoch + 1}/{num_epochs}, Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}")


        # Early stopping
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            # torch.save(model.state_dict(), "./lstm_trials/lstm_after_gridsearch_new.pth")
            early_stop_counter = 0
        else:
            early_stop_counter += 1
            print(f"Early stopping counter: {early_stop_counter}/{patience}")
            if early_stop_counter >= patience:
                print("Early stopping triggered.")
                break

# Load the best model
# model.load_state_dict(torch.load("./lstm_trials/lstm_after_gridsearch_new.pth"))

# Evaluate on test data
model.eval()
test_loss = 0.0
with torch.no_grad():
    for X_batch, y_batch in test_loader:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)
        outputs = model(X_batch)
        loss = criterion(outputs, y_batch)
        test_loss += loss.item() * X_batch.size(0)

test_loss /= len(test_loader.dataset)
print(f'Test Loss: {test_loss:.4f}')

# Calculate Mean Absolute Error (MAE)
test_mae = 0.0
with torch.no_grad():
    for X_batch, y_batch in test_loader:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)
        outputs = model(X_batch)
        mae = torch.mean(torch.abs(outputs - y_batch))
        test_mae += mae.item() * X_batch.size(0)

test_mae /= len(test_loader.dataset)
print(f'Test MAE: {test_mae:.4f}')
# Out:
# Epoch 1/500, Train Loss: 6791.0503, Val Loss: 10744.4556
# Epoch 2/500, Train Loss: 6777.1522, Val Loss: 10737.6277
# Epoch 3/500, Train Loss: 6770.3829, Val Loss: 10711.9165
# Epoch 4/500, Train Loss: 6721.2892, Val Loss: 10586.5823
# Epoch 5/500, Train Loss: 6615.6898, Val Loss: 10444.4844
# Epoch 6/500, Train Loss: 6499.4664, Val Loss: 10284.9951
# Epoch 7/500, Train Loss: 6358.4871, Val Loss: 10110.5774
# Epoch 8/500, Train Loss: 6226.6554, Val Loss: 9927.5762
# Epoch 9/500, Train Loss: 6081.3865, Val Loss: 9737.0962
# Epoch 10/500, Train Loss: 5946.9169, Val Loss: 9536.6599
# Epoch 11/500, Train Loss: 5793.9486, Val Loss: 9324.2625
# Epoch 12/500, Train Loss: 5604.1961, Val Loss: 9098.9055
# Epoch 13/500, Train Loss: 5429.5732, Val Loss: 8860.7916
# Epoch 14/500, Train Loss: 5234.3891, Val Loss: 8610.5824
# Epoch 15/500, Train Loss: 5054.0650, Val Loss: 8348.4705
# Epoch 16/500, Train Loss: 4861.8504, Val Loss: 8074.5667
# Epoch 17/500, Train Loss: 4650.4711, Val Loss: 7789.9784
# Epoch 18/500, Train Loss: 4436.6482, Val Loss: 7495.3746
# Epoch 19/500, Train Loss: 4196.8210, Val Loss: 7191.5358
# Epoch 20/500, Train Loss: 4001.9683, Val Loss: 6878.0824
# Epoch 21/500, Train Loss: 3746.5675, Val Loss: 6556.8184
# Epoch 22/500, Train Loss: 3523.2887, Val Loss: 6229.3081
# Epoch 23/500, Train Loss: 3302.2806, Val Loss: 5894.1219
# Epoch 24/500, Train Loss: 3083.7549, Val Loss: 5553.4481
# Epoch 25/500, Train Loss: 2791.7755, Val Loss: 5209.2498
# Epoch 26/500, Train Loss: 2588.7877, Val Loss: 4860.5873
# Epoch 27/500, Train Loss: 2373.2521, Val Loss: 4509.9965
# Epoch 28/500, Train Loss: 2157.1869, Val Loss: 4156.8958
# Epoch 29/500, Train Loss: 1939.3750, Val Loss: 3800.1005
# Epoch 30/500, Train Loss: 1724.2012, Val Loss: 3443.6885
# Epoch 31/500, Train Loss: 1449.2836, Val Loss: 3090.0404
# Epoch 32/500, Train Loss: 1264.6675, Val Loss: 2742.8470
# Epoch 33/500, Train Loss: 1098.1426, Val Loss: 2404.3917
# Epoch 34/500, Train Loss: 913.5043, Val Loss: 2077.5286
# Epoch 35/500, Train Loss: 775.2766, Val Loss: 1763.9841
# Epoch 36/500, Train Loss: 677.6112, Val Loss: 1465.0997
# Epoch 37/500, Train Loss: 583.1338, Val Loss: 1188.9947
# Epoch 38/500, Train Loss: 509.8875, Val Loss: 942.7508
# Epoch 39/500, Train Loss: 513.7729, Val Loss: 757.8243
# Epoch 40/500, Train Loss: 494.4357, Val Loss: 688.0061
# Epoch 41/500, Train Loss: 442.6568, Val Loss: 699.7606
# Early stopping counter: 1/30
# Epoch 42/500, Train Loss: 434.1881, Val Loss: 680.1542
# Epoch 43/500, Train Loss: 474.5763, Val Loss: 658.9177
# Epoch 44/500, Train Loss: 470.2354, Val Loss: 649.0704
# Epoch 45/500, Train Loss: 477.0483, Val Loss: 666.9487
# Early stopping counter: 1/30
# Epoch 46/500, Train Loss: 470.0325, Val Loss: 686.0359
# Early stopping counter: 2/30
# Epoch 47/500, Train Loss: 471.1820, Val Loss: 700.3779
# Early stopping counter: 3/30
# Epoch 48/500, Train Loss: 456.8007, Val Loss: 673.2895
# Early stopping counter: 4/30
# Epoch 49/500, Train Loss: 379.1248, Val Loss: 501.8433
# Epoch 50/500, Train Loss: 333.2669, Val Loss: 377.4334
# Epoch 51/500, Train Loss: 316.2405, Val Loss: 284.6228
# Epoch 52/500, Train Loss: 310.5275, Val Loss: 213.6557
# Epoch 53/500, Train Loss: 284.0526, Val Loss: 164.7003
# Epoch 54/500, Train Loss: 306.5691, Val Loss: 130.6837
# Epoch 55/500, Train Loss: 283.1139, Val Loss: 102.7391
# Epoch 56/500, Train Loss: 288.1591, Val Loss: 91.4381
# Epoch 57/500, Train Loss: 281.6789, Val Loss: 83.5691
# Epoch 58/500, Train Loss: 282.6975, Val Loss: 72.8948
# Epoch 59/500, Train Loss: 292.8916, Val Loss: 57.3807
# Epoch 60/500, Train Loss: 278.7312, Val Loss: 55.4150
# Epoch 61/500, Train Loss: 270.2790, Val Loss: 46.8285
# Epoch 62/500, Train Loss: 294.0305, Val Loss: 44.5550
# Epoch 63/500, Train Loss: 267.2072, Val Loss: 37.4070
# Epoch 64/500, Train Loss: 274.7527, Val Loss: 42.8858
# Early stopping counter: 1/30
# Epoch 65/500, Train Loss: 285.7846, Val Loss: 30.2448
# Epoch 66/500, Train Loss: 300.9033, Val Loss: 28.5815
# Epoch 67/500, Train Loss: 284.2866, Val Loss: 27.4187
# Epoch 68/500, Train Loss: 276.8369, Val Loss: 26.5793
# Epoch 69/500, Train Loss: 276.9300, Val Loss: 25.4202
# Epoch 70/500, Train Loss: 268.9559, Val Loss: 24.0451
# Epoch 71/500, Train Loss: 266.5852, Val Loss: 21.0374
# Epoch 72/500, Train Loss: 268.7444, Val Loss: 24.4444
# Early stopping counter: 1/30
# Epoch 73/500, Train Loss: 291.8173, Val Loss: 21.5557
# Early stopping counter: 2/30
# Epoch 74/500, Train Loss: 265.5020, Val Loss: 20.4842
# Epoch 75/500, Train Loss: 267.5765, Val Loss: 23.9998
# Early stopping counter: 1/30
# Epoch 76/500, Train Loss: 281.2225, Val Loss: 23.7117
# Early stopping counter: 2/30
# Epoch 77/500, Train Loss: 296.6962, Val Loss: 20.0359
# Epoch 78/500, Train Loss: 281.5589, Val Loss: 21.3703
# Early stopping counter: 1/30
# Epoch 79/500, Train Loss: 274.5257, Val Loss: 22.5582
# Early stopping counter: 2/30
# Epoch 80/500, Train Loss: 280.4530, Val Loss: 21.2127
# Early stopping counter: 3/30
# Epoch 81/500, Train Loss: 282.0590, Val Loss: 20.8922
# Early stopping counter: 4/30
# Epoch 82/500, Train Loss: 280.5953, Val Loss: 20.4880
# Early stopping counter: 5/30
# Epoch 83/500, Train Loss: 261.5851, Val Loss: 17.7966
# Epoch 84/500, Train Loss: 279.8218, Val Loss: 23.1580
# Early stopping counter: 1/30
# Epoch 85/500, Train Loss: 280.0212, Val Loss: 16.0946
# Epoch 86/500, Train Loss: 278.4626, Val Loss: 17.6052
# Early stopping counter: 1/30
# Epoch 87/500, Train Loss: 270.3021, Val Loss: 18.6329
# Early stopping counter: 2/30
# Epoch 88/500, Train Loss: 274.5828, Val Loss: 24.4275
# Early stopping counter: 3/30
# Epoch 89/500, Train Loss: 261.4002, Val Loss: 16.5269
# Early stopping counter: 4/30
# Epoch 90/500, Train Loss: 293.9686, Val Loss: 15.9997
# Epoch 91/500, Train Loss: 282.3791, Val Loss: 15.6443
# Epoch 92/500, Train Loss: 296.2267, Val Loss: 18.1632
# Early stopping counter: 1/30
# Epoch 93/500, Train Loss: 277.6472, Val Loss: 18.5280
# Early stopping counter: 2/30
# Epoch 94/500, Train Loss: 265.1819, Val Loss: 18.3283
# Early stopping counter: 3/30
# Epoch 95/500, Train Loss: 273.0686, Val Loss: 16.8630
# Early stopping counter: 4/30
# Epoch 96/500, Train Loss: 276.7738, Val Loss: 16.4955
# Early stopping counter: 5/30
# Epoch 97/500, Train Loss: 276.7555, Val Loss: 23.0843
# Early stopping counter: 6/30
# Epoch 98/500, Train Loss: 248.3662, Val Loss: 21.3645
# Early stopping counter: 7/30
# Epoch 99/500, Train Loss: 263.3956, Val Loss: 17.5745
# Early stopping counter: 8/30
# Epoch 100/500, Train Loss: 275.2707, Val Loss: 15.0300
# Epoch 101/500, Train Loss: 270.8308, Val Loss: 19.2510
# Early stopping counter: 1/30
# Epoch 102/500, Train Loss: 266.3065, Val Loss: 12.9714
# Epoch 103/500, Train Loss: 262.4015, Val Loss: 16.3383
# Early stopping counter: 1/30
# Epoch 104/500, Train Loss: 271.8740, Val Loss: 16.0641
# Early stopping counter: 2/30
# Epoch 105/500, Train Loss: 274.0968, Val Loss: 19.6614
# Early stopping counter: 3/30
# Epoch 106/500, Train Loss: 266.6657, Val Loss: 15.7759
# Early stopping counter: 4/30
# Epoch 107/500, Train Loss: 286.7357, Val Loss: 17.6687
# Early stopping counter: 5/30
# Epoch 108/500, Train Loss: 262.4942, Val Loss: 16.0833
# Early stopping counter: 6/30
# Epoch 109/500, Train Loss: 251.6177, Val Loss: 17.3386
# Early stopping counter: 7/30
# Epoch 110/500, Train Loss: 260.8926, Val Loss: 15.9012
# Early stopping counter: 8/30
# Epoch 111/500, Train Loss: 275.2549, Val Loss: 19.7162
# Early stopping counter: 9/30
# Epoch 112/500, Train Loss: 282.9181, Val Loss: 17.8319
# Early stopping counter: 10/30
# Epoch 113/500, Train Loss: 291.0020, Val Loss: 17.1241
# Early stopping counter: 11/30
# Epoch 114/500, Train Loss: 280.1356, Val Loss: 19.6068
# Early stopping counter: 12/30
# Epoch 115/500, Train Loss: 288.6094, Val Loss: 26.3968
# Early stopping counter: 13/30
# Epoch 116/500, Train Loss: 276.0553, Val Loss: 18.4839
# Early stopping counter: 14/30
# Epoch 117/500, Train Loss: 275.4104, Val Loss: 21.0003
# Early stopping counter: 15/30
# Epoch 118/500, Train Loss: 262.6101, Val Loss: 16.7038
# Early stopping counter: 16/30
# Epoch 119/500, Train Loss: 274.0951, Val Loss: 16.3100
# Early stopping counter: 17/30
# Epoch 120/500, Train Loss: 280.9729, Val Loss: 16.8369
# Early stopping counter: 18/30
# Epoch 121/500, Train Loss: 275.3581, Val Loss: 13.9553
# Early stopping counter: 19/30
# Epoch 122/500, Train Loss: 281.5062, Val Loss: 14.8947
# Early stopping counter: 20/30
# Epoch 123/500, Train Loss: 275.1897, Val Loss: 13.6605
# Early stopping counter: 21/30
# Epoch 124/500, Train Loss: 269.8752, Val Loss: 26.8303
# Early stopping counter: 22/30
# Epoch 125/500, Train Loss: 254.3374, Val Loss: 14.1560
# Early stopping counter: 23/30
# Epoch 126/500, Train Loss: 266.0969, Val Loss: 14.0050
# Early stopping counter: 24/30
# Epoch 127/500, Train Loss: 281.6187, Val Loss: 28.6994
# Early stopping counter: 25/30
# Epoch 128/500, Train Loss: 269.7945, Val Loss: 13.1359
# Early stopping counter: 26/30
# Epoch 129/500, Train Loss: 266.0562, Val Loss: 14.6774
# Early stopping counter: 27/30
# Epoch 130/500, Train Loss: 261.9721, Val Loss: 14.2743
# Early stopping counter: 28/30
# Epoch 131/500, Train Loss: 264.0633, Val Loss: 13.6037
# Early stopping counter: 29/30
# Epoch 132/500, Train Loss: 274.7550, Val Loss: 46.5171
# Early stopping counter: 30/30
# Early stopping triggered.
# Test Loss: 41.5544
# Test MAE: 5.3397
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/loss.py:608: UserWarning: Using a target size (torch.Size([64])) that is different to the input size (torch.Size([64, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/loss.py:608: UserWarning: Using a target size (torch.Size([55])) that is different to the input size (torch.Size([55, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)

# %%
# Evaluate the model
# print("Confusion Matrix:")
# print(confusion_matrix(y_test, y_pred_binary))

# # Generate precision, recall, and F1-score
# print("\nClassification Report:")
# print(classification_report(y_test, y_pred_binary, target_names=["Class 0", "Class 1"]))

# %%
X_seq_tensor = torch.tensor(X_seq, dtype=torch.float32).to(device)
y_seq_tensor = torch.tensor(y_seq, dtype=torch.float32).to(device)

outputs = model(X_seq_tensor)

# %%
error = 0
largest_error = 0
less_than_actual = 0
more_than_actual = 0

for true, pred in zip(y_seq, outputs):
    percent = abs(true - pred) / true
    if percent > largest_error:
        largest_error = percent
    error += percent
    if pred < true:
        less_than_actual += 1
    else:
        more_than_actual += 1

error = error / len(y_seq)
error = error.item()
largest_error = largest_error.item()
print(f"Average error percentage: {error*100}")
print(f"Largest error percentage: {largest_error*100}")
print(f"Less than actual: {less_than_actual}")
print(f"More than actual: {more_than_actual}")
# Out:
# Average error percentage: 6.3945189118385315
# Largest error percentage: 24.82360452413559
# Less than actual: 1605
# More than actual: 92

# %%
train_cutoff = int(len(y_seq) * 0.7)
val_cutoff = int(len(y_seq) * 0.85)

plt.figure(figsize=(12, 6))
plt.plot(y_seq, label='True Values')
plt.plot(outputs.cpu().detach().numpy(), label='Predicted Values')
plt.axvline(x=train_cutoff, color='g', linestyle='--', label='Train/Val Split (80%)')
plt.axvline(x=val_cutoff, color='b', linestyle='--', label='Val/Test Split (90%)')
plt.xlabel('Time')
plt.ylabel('Value')
plt.title('True vs Predicted Values')
plt.legend()
plt.show()

# %%
outputs
# Out:
# tensor([[56.0423],
#         [55.6469],
#         [55.3592],
#         ...,
#         [65.1561],
#         [65.0971],
#         [64.9823]], device='cuda:0', grad_fn=<AddmmBackward0>)

# %%
df['Target_Higher_Lower'] = np.where(df['Target'] > df['Open'], 'higher', 'lower')

# %%
# Ensure outputs is detached from the computation graph and converted to numpy
predicted_values = outputs.cpu().detach().numpy()

# Add the predicted values as a new column in the dataframe
df['Predicted'] = np.nan
df.loc[df.index[-len(predicted_values):], 'Predicted'] = predicted_values

print(df[['Date', 'Target', 'Predicted']].tail())
# Out:
#             Date     Target  Predicted
# 4129  2009-06-22  67.366714  65.272789
# 4130  2009-06-23  67.947273  65.245079
# 4131  2009-06-24  69.425034  65.156136
# 4132  2009-06-25  69.244072  65.097130
# 4133  2009-06-26  69.892502  64.982277

# %%
new_df = df.dropna()

# %%
new_df['Predicted_Higher_Lower'] = np.where(new_df['Predicted'] > new_df['Open'], 'higher', 'lower')
new_df['Correct'] = np.where(new_df['Predicted_Higher_Lower'] == new_df['Target_Higher_Lower'], 1, 0)

print('number of correct predictions:', new_df['Correct'].sum())
# Out:
# number of correct predictions: 810
# <ipython-input-26-54f40e89f447>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['Predicted_Higher_Lower'] = np.where(new_df['Predicted'] > new_df['Open'], 'higher', 'lower')
# <ipython-input-26-54f40e89f447>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['Correct'] = np.where(new_df['Predicted_Higher_Lower'] == new_df['Target_Higher_Lower'], 1, 0)

# %%
# # train model 10 times and get results with prediction error, max error etc
# error_array = []
# largest_error_array = []
# for i in range (10):
#     model = ComplexLSTMModel(input_size=input_size, hidden_size=hidden_size, num_layers=num_layers, dropout_rate=dropout_rate)

#     # Define loss and optimizer
#     # criterion = nn.BCELoss()
#     criterion = nn.MSELoss()
#     optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

#     # Training loop with early stopping
#     best_val_loss = float('inf')
#     early_stop_counter = 0

#     # if not os.path.exists("./models/best_lstm_model.pth"):
#     if not os.path.exists("./lstm_trials/lstm.pth"):
#         for epoch in range(num_epochs):
#             model.train()
#             train_loss = 0
#             for X_batch, y_batch in train_loader:
#                 y_batch = y_batch.unsqueeze(1)  # Match output shape
#                 optimizer.zero_grad()
#                 outputs = model(X_batch)
#                 loss = criterion(outputs, y_batch)
#                 loss.backward()
#                 torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
#                 optimizer.step()
#                 train_loss += loss.item()

#             train_loss /= len(train_loader)

#             # Validation
#             model.eval()
#             val_loss = 0
#             with torch.no_grad():
#                 for X_batch, y_batch in val_loader:
#                     y_batch = y_batch.unsqueeze(1)
#                     outputs = model(X_batch)
#                     loss = criterion(outputs, y_batch)
#                     val_loss += loss.item()

#             val_loss /= len(val_loader)
#             print(f"Epoch {epoch + 1}/{num_epochs}, Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}")


#             # Early stopping
#             if val_loss < best_val_loss:
#                 best_val_loss = val_loss
#                 # torch.save(model.state_dict(), "./lstm_trials/lstm_5.pth")
#                 early_stop_counter = 0
#             else:
#                 early_stop_counter += 1
#                 print(f"Early stopping counter: {early_stop_counter}/{patience}")
#                 if early_stop_counter >= patience:
#                     print("Early stopping triggered.")
#                     break
#     model.eval()
#     test_loss = 0.0
#     with torch.no_grad():
#         for X_batch, y_batch in test_loader:
#             outputs = model(X_batch)
#             loss = criterion(outputs, y_batch)
#             test_loss += loss.item() * X_batch.size(0)

#     test_loss /= len(test_loader.dataset)
#     print(f'Test Loss: {test_loss:.4f}')

#     # Calculate Mean Absolute Error (MAE)
#     test_mae = 0.0
#     with torch.no_grad():
#         for X_batch, y_batch in test_loader:
#             outputs = model(X_batch)
#             mae = torch.mean(torch.abs(outputs - y_batch))
#             test_mae += mae.item() * X_batch.size(0)

#     test_mae /= len(test_loader.dataset)
#     print(f'Test MAE: {test_mae:.4f}')

#     outputs = model(X_seq_tensor)
#     error = 0
#     largest_error = 0
#     less_than_actual = 0
#     more_than_actual = 0

#     for true, pred in zip(y_seq, outputs):
#         percent = abs(true - pred) / true
#         if percent > largest_error:
#             largest_error = percent
#         error += percent
#         if pred < true:
#             less_than_actual += 1
#         else:
#             more_than_actual += 1

#     error = error / len(y_seq)
#     error = error.item()
#     largest_error = largest_error.item()
#     # print(f"Average error percentage: {error*100}")
#     # print(f"Largest error percentage: {largest_error*100}")
#     # print(f"Less than actual: {less_than_actual}")
#     # print(f"More than actual: {more_than_actual}")
#     error_array.append(error*100)
#     largest_error_array.append(largest_error*100)

# print('Average error percentage:', np.mean(error_array))
# print('Average largest error percentage:', np.mean(largest_error_array))
# print("Standard deviation of average error percentage:", np.std(error_array))
# print("Standard deviation of average largest error percentage:", np.std(largest_error_array))

# %%
X_seq_tensor = torch.tensor(X_test, dtype=torch.float32).to(device)
y_seq_tensor = torch.tensor(y_test, dtype=torch.float32).to(device)

outputs = model(X_seq_tensor)

# %%
error = 0
largest_error = 0
less_than_actual = 0
more_than_actual = 0

for true, pred in zip(y_test, outputs):
    percent = abs(true - pred) / true
    if percent > largest_error:
        largest_error = percent
    error += percent
    if pred < true:
        less_than_actual += 1
    else:
        more_than_actual += 1

error = error / len(y_test)
error = error.item()
largest_error = largest_error.item()
print(f"Average error percentage: {error*100}")
print(f"Largest error percentage: {largest_error*100}")
print(f"Less than actual: {less_than_actual}")
print(f"More than actual: {more_than_actual}")
# Out:
# Average error percentage: 6.52310848236084
# Largest error percentage: 24.82360452413559
# Less than actual: 187
# More than actual: 60

# %%
import itertools
import torch

# Define possible hyperparameter ranges
hidden_sizes = [64, 128]
num_layers_list = [2, 3, 4]
dropout_rates = [0.1, 0.3, 0.5]
learning_rates = [0.001, 0.0005, 0.0001]
patience_values = [30]
num_repeats = 5  # Number of times each combination is trained


# Generate all combinations of hyperparameters
hyperparameter_combinations = list(itertools.product(hidden_sizes, num_layers_list, dropout_rates, learning_rates, patience_values))

# Initialize best loss
best_avg_loss = float('inf')
best_model = None
best_params = None

# Counter
total_count = len(hyperparameter_combinations)
current_count = 0

# Loop over all combinations
for hidden_size, num_layers, dropout_rate, learning_rate, patience in hyperparameter_combinations:
    print(f"Training with hidden_size={hidden_size}, num_layers={num_layers}, dropout_rate={dropout_rate}, learning_rate={learning_rate}, patience={patience}")
    print(f"Progress: {current_count}/{total_count}")
    current_count += 1

    total_val_loss = 0  # Accumulator for validation losses

    for repeat in range(num_repeats):
        print(f"  Repeat {repeat + 1}/{num_repeats}")

        # Reinitialize the model
        model = ComplexLSTMModel(input_size=input_size, hidden_size=hidden_size, num_layers=num_layers, dropout_rate=dropout_rate)
        optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

        best_loss = float('inf')
        epoch_no_improve = 0  # Counter for early stopping

        # Training loop
        for epoch in range(num_epochs):
            model.train()
            train_loss = 0
            for X_batch, y_batch in train_loader:
                y_batch = y_batch.unsqueeze(1)
                optimizer.zero_grad()
                outputs = model(X_batch)
                loss = criterion(outputs, y_batch)
                loss.backward()
                optimizer.step()
                train_loss += loss.item()

            train_loss /= len(train_loader)

            # Validation
            model.eval()
            val_loss = 0
            with torch.no_grad():
                for X_batch, y_batch in val_loader:
                    y_batch = y_batch.unsqueeze(1)
                    outputs = model(X_batch)
                    loss = criterion(outputs, y_batch)
                    val_loss += loss.item()

            val_loss /= len(val_loader)
            print(f"    Epoch {epoch + 1}/{num_epochs}, Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}")

            # Early stopping
            if val_loss < best_loss:
                best_loss = val_loss
                epoch_no_improve = 0  # Reset counter
            else:
                epoch_no_improve += 1
                print(f"    Early stopping counter: {epoch_no_improve}/{patience}")
                if epoch_no_improve >= patience:
                    print("    Early stopping triggered.")
                    break

        total_val_loss += best_loss  # Add the best validation loss from this repeat

    # Compute the average validation loss across `num_repeats` runs
    avg_val_loss = total_val_loss / num_repeats
    print(f"Average Validation Loss for this combination: {avg_val_loss:.4f}")

    # Check if this is the best combination so far
    if avg_val_loss < best_avg_loss:
        best_avg_loss = avg_val_loss
        best_model = model.state_dict()
        best_params = (hidden_size, num_layers, dropout_rate, learning_rate, patience)

# Load the best model
model.load_state_dict(best_model)
print(f"Best model parameters: {best_params}")
# Out:
# Streaming output truncated to the last 5000 lines.
#     Early stopping counter: 29/30
#     Epoch 35/500, Train Loss: 445.9902, Val Loss: 655.2973
#     Early stopping counter: 30/30
#     Early stopping triggered.
#   Repeat 4/5
#     Epoch 1/500, Train Loss: 6666.4873, Val Loss: 10272.6758
#     Epoch 2/500, Train Loss: 5909.4297, Val Loss: 8573.7365
#     Epoch 3/500, Train Loss: 3986.6542, Val Loss: 5011.8905
#     Epoch 4/500, Train Loss: 1419.6719, Val Loss: 1219.7326
#     Epoch 5/500, Train Loss: 536.2612, Val Loss: 431.8450
#     Epoch 6/500, Train Loss: 539.4676, Val Loss: 750.7014
#     Early stopping counter: 1/30
#     Epoch 7/500, Train Loss: 497.6573, Val Loss: 701.5081
#     Early stopping counter: 2/30
#     Epoch 8/500, Train Loss: 493.1741, Val Loss: 676.6399
#     Early stopping counter: 3/30
#     Epoch 9/500, Train Loss: 513.0082, Val Loss: 689.3278
#     Early stopping counter: 4/30
#     Epoch 10/500, Train Loss: 519.8409, Val Loss: 713.1896
#     Early stopping counter: 5/30
#     Epoch 11/500, Train Loss: 494.5822, Val Loss: 672.2488
#     Early stopping counter: 6/30
#     Epoch 12/500, Train Loss: 502.3135, Val Loss: 659.2701
#     Early stopping counter: 7/30
#     Epoch 13/500, Train Loss: 463.6035, Val Loss: 706.6689
#     Early stopping counter: 8/30
#     Epoch 14/500, Train Loss: 496.8009, Val Loss: 690.3221
#     Early stopping counter: 9/30
#     Epoch 15/500, Train Loss: 497.5662, Val Loss: 692.6191
#     Early stopping counter: 10/30
#     Epoch 16/500, Train Loss: 475.2400, Val Loss: 730.9922
#     Early stopping counter: 11/30
#     Epoch 17/500, Train Loss: 473.3057, Val Loss: 632.6276
#     Early stopping counter: 12/30
#     Epoch 18/500, Train Loss: 485.6967, Val Loss: 770.8929
#     Early stopping counter: 13/30
#     Epoch 19/500, Train Loss: 452.5487, Val Loss: 676.7788
#     Early stopping counter: 14/30
#     Epoch 20/500, Train Loss: 432.1010, Val Loss: 702.2846
#     Early stopping counter: 15/30
#     Epoch 21/500, Train Loss: 456.1810, Val Loss: 704.0943
#     Early stopping counter: 16/30
#     Epoch 22/500, Train Loss: 443.4606, Val Loss: 695.4940
#     Early stopping counter: 17/30
#     Epoch 23/500, Train Loss: 455.4110, Val Loss: 675.9222
#     Early stopping counter: 18/30
#     Epoch 24/500, Train Loss: 449.5387, Val Loss: 759.5451
#     Early stopping counter: 19/30
#     Epoch 25/500, Train Loss: 445.7832, Val Loss: 564.0929
#     Early stopping counter: 20/30
#     Epoch 26/500, Train Loss: 452.3904, Val Loss: 754.3274
#     Early stopping counter: 21/30
#     Epoch 27/500, Train Loss: 443.9218, Val Loss: 652.5430
#     Early stopping counter: 22/30
#     Epoch 28/500, Train Loss: 469.5652, Val Loss: 560.5187
#     Early stopping counter: 23/30
#     Epoch 29/500, Train Loss: 486.8804, Val Loss: 706.6792
#     Early stopping counter: 24/30
#     Epoch 30/500, Train Loss: 462.6877, Val Loss: 709.9635
#     Early stopping counter: 25/30
#     Epoch 31/500, Train Loss: 450.5166, Val Loss: 687.9109
#     Early stopping counter: 26/30
#     Epoch 32/500, Train Loss: 449.9825, Val Loss: 755.2501
#     Early stopping counter: 27/30
#     Epoch 33/500, Train Loss: 421.1070, Val Loss: 661.1616
#     Early stopping counter: 28/30
#     Epoch 34/500, Train Loss: 450.1535, Val Loss: 726.9131
#     Early stopping counter: 29/30
#     Epoch 35/500, Train Loss: 420.5704, Val Loss: 660.5565
#     Early stopping counter: 30/30
#     Early stopping triggered.
#   Repeat 5/5
#     Epoch 1/500, Train Loss: 6625.2437, Val Loss: 10015.6211
#     Epoch 2/500, Train Loss: 5338.9815, Val Loss: 7130.7421
#     Epoch 3/500, Train Loss: 2471.5334, Val Loss: 2158.9575
#     Epoch 4/500, Train Loss: 571.9744, Val Loss: 301.8532
#     Epoch 5/500, Train Loss: 489.6631, Val Loss: 773.8323
#     Early stopping counter: 1/30
#     Epoch 6/500, Train Loss: 419.5086, Val Loss: 674.8720
#     Early stopping counter: 2/30
#     Epoch 7/500, Train Loss: 462.8596, Val Loss: 653.2351
#     Early stopping counter: 3/30
#     Epoch 8/500, Train Loss: 434.4478, Val Loss: 597.5558
#     Early stopping counter: 4/30
#     Epoch 9/500, Train Loss: 428.2093, Val Loss: 649.2817
#     Early stopping counter: 5/30
#     Epoch 10/500, Train Loss: 434.1618, Val Loss: 639.6790
#     Early stopping counter: 6/30
#     Epoch 11/500, Train Loss: 421.6723, Val Loss: 697.4159
#     Early stopping counter: 7/30
#     Epoch 12/500, Train Loss: 408.9376, Val Loss: 651.0282
#     Early stopping counter: 8/30
#     Epoch 13/500, Train Loss: 443.9351, Val Loss: 599.7057
#     Early stopping counter: 9/30
#     Epoch 14/500, Train Loss: 407.6213, Val Loss: 632.6036
#     Early stopping counter: 10/30
#     Epoch 15/500, Train Loss: 417.4076, Val Loss: 624.5800
#     Early stopping counter: 11/30
#     Epoch 16/500, Train Loss: 433.9414, Val Loss: 693.0353
#     Early stopping counter: 12/30
#     Epoch 17/500, Train Loss: 427.0655, Val Loss: 699.2598
#     Early stopping counter: 13/30
#     Epoch 18/500, Train Loss: 396.0579, Val Loss: 603.5008
#     Early stopping counter: 14/30
#     Epoch 19/500, Train Loss: 417.4952, Val Loss: 691.7990
#     Early stopping counter: 15/30
#     Epoch 20/500, Train Loss: 400.4633, Val Loss: 660.8508
#     Early stopping counter: 16/30
#     Epoch 21/500, Train Loss: 388.0729, Val Loss: 577.5334
#     Early stopping counter: 17/30
#     Epoch 22/500, Train Loss: 407.5433, Val Loss: 760.8755
#     Early stopping counter: 18/30
#     Epoch 23/500, Train Loss: 405.0731, Val Loss: 651.0178
#     Early stopping counter: 19/30
#     Epoch 24/500, Train Loss: 400.3140, Val Loss: 679.7082
#     Early stopping counter: 20/30
#     Epoch 25/500, Train Loss: 401.1290, Val Loss: 648.9452
#     Early stopping counter: 21/30
#     Epoch 26/500, Train Loss: 425.0321, Val Loss: 586.8863
#     Early stopping counter: 22/30
#     Epoch 27/500, Train Loss: 418.2788, Val Loss: 672.2178
#     Early stopping counter: 23/30
#     Epoch 28/500, Train Loss: 411.9511, Val Loss: 660.1237
#     Early stopping counter: 24/30
#     Epoch 29/500, Train Loss: 405.0037, Val Loss: 649.2935
#     Early stopping counter: 25/30
#     Epoch 30/500, Train Loss: 394.8727, Val Loss: 656.0414
#     Early stopping counter: 26/30
#     Epoch 31/500, Train Loss: 418.3584, Val Loss: 608.6255
#     Early stopping counter: 27/30
#     Epoch 32/500, Train Loss: 392.5874, Val Loss: 671.3235
#     Early stopping counter: 28/30
#     Epoch 33/500, Train Loss: 394.7866, Val Loss: 578.2762
#     Early stopping counter: 29/30
#     Epoch 34/500, Train Loss: 410.2133, Val Loss: 687.0043
#     Early stopping counter: 30/30
#     Early stopping triggered.
# Average Validation Loss for this combination: 439.8851
# Training with hidden_size=128, num_layers=4, dropout_rate=0.3, learning_rate=0.0005, patience=30
# Progress: 49/54
#   Repeat 1/5
#     Epoch 1/500, Train Loss: 6731.4795, Val Loss: 10647.2073
#     Epoch 2/500, Train Loss: 6621.0864, Val Loss: 10365.3545
#     Epoch 3/500, Train Loss: 6266.2375, Val Loss: 9698.9353
#     Epoch 4/500, Train Loss: 5546.7225, Val Loss: 8424.4601
#     Epoch 5/500, Train Loss: 4346.3465, Val Loss: 6507.9835
#     Epoch 6/500, Train Loss: 2841.8101, Val Loss: 4199.7277
#     Epoch 7/500, Train Loss: 1504.5082, Val Loss: 2127.4297
#     Epoch 8/500, Train Loss: 675.1163, Val Loss: 949.7727
#     Epoch 9/500, Train Loss: 569.6547, Val Loss: 646.6987
#     Epoch 10/500, Train Loss: 543.5401, Val Loss: 682.8662
#     Early stopping counter: 1/30
#     Epoch 11/500, Train Loss: 520.5662, Val Loss: 725.3136
#     Early stopping counter: 2/30
#     Epoch 12/500, Train Loss: 541.8857, Val Loss: 751.7465
#     Early stopping counter: 3/30
#     Epoch 13/500, Train Loss: 556.9746, Val Loss: 740.7811
#     Early stopping counter: 4/30
#     Epoch 14/500, Train Loss: 530.1897, Val Loss: 765.0088
#     Early stopping counter: 5/30
#     Epoch 15/500, Train Loss: 542.3392, Val Loss: 731.9153
#     Early stopping counter: 6/30
#     Epoch 16/500, Train Loss: 550.3316, Val Loss: 713.0210
#     Early stopping counter: 7/30
#     Epoch 17/500, Train Loss: 528.2680, Val Loss: 742.2060
#     Early stopping counter: 8/30
#     Epoch 18/500, Train Loss: 529.6829, Val Loss: 699.0209
#     Early stopping counter: 9/30
#     Epoch 19/500, Train Loss: 536.5874, Val Loss: 679.6381
#     Early stopping counter: 10/30
#     Epoch 20/500, Train Loss: 505.2497, Val Loss: 737.0160
#     Early stopping counter: 11/30
#     Epoch 21/500, Train Loss: 494.9952, Val Loss: 685.1859
#     Early stopping counter: 12/30
#     Epoch 22/500, Train Loss: 516.6682, Val Loss: 657.6021
#     Early stopping counter: 13/30
#     Epoch 23/500, Train Loss: 494.6092, Val Loss: 681.3185
#     Early stopping counter: 14/30
#     Epoch 24/500, Train Loss: 525.1418, Val Loss: 726.6569
#     Early stopping counter: 15/30
#     Epoch 25/500, Train Loss: 537.7065, Val Loss: 711.5324
#     Early stopping counter: 16/30
#     Epoch 26/500, Train Loss: 521.6246, Val Loss: 694.0098
#     Early stopping counter: 17/30
#     Epoch 27/500, Train Loss: 486.6040, Val Loss: 698.6812
#     Early stopping counter: 18/30
#     Epoch 28/500, Train Loss: 484.6029, Val Loss: 679.2346
#     Early stopping counter: 19/30
#     Epoch 29/500, Train Loss: 496.2984, Val Loss: 764.1353
#     Early stopping counter: 20/30
#     Epoch 30/500, Train Loss: 470.7745, Val Loss: 669.8398
#     Early stopping counter: 21/30
#     Epoch 31/500, Train Loss: 504.7268, Val Loss: 666.9057
#     Early stopping counter: 22/30
#     Epoch 32/500, Train Loss: 497.9727, Val Loss: 734.9432
#     Early stopping counter: 23/30
#     Epoch 33/500, Train Loss: 507.6731, Val Loss: 721.8310
#     Early stopping counter: 24/30
#     Epoch 34/500, Train Loss: 470.6041, Val Loss: 631.4619
#     Epoch 35/500, Train Loss: 407.4596, Val Loss: 411.1449
#     Epoch 36/500, Train Loss: 347.6033, Val Loss: 204.3854
#     Epoch 37/500, Train Loss: 341.6567, Val Loss: 129.4692
#     Epoch 38/500, Train Loss: 330.5631, Val Loss: 117.4452
#     Epoch 39/500, Train Loss: 331.8006, Val Loss: 194.2868
#     Early stopping counter: 1/30
#     Epoch 40/500, Train Loss: 325.3635, Val Loss: 100.3570
#     Epoch 41/500, Train Loss: 315.7165, Val Loss: 74.0613
#     Epoch 42/500, Train Loss: 342.2571, Val Loss: 170.1015
#     Early stopping counter: 1/30
#     Epoch 43/500, Train Loss: 309.6148, Val Loss: 30.1418
#     Epoch 44/500, Train Loss: 302.8405, Val Loss: 71.7210
#     Early stopping counter: 1/30
#     Epoch 45/500, Train Loss: 321.4712, Val Loss: 52.5266
#     Early stopping counter: 2/30
#     Epoch 46/500, Train Loss: 323.9376, Val Loss: 32.6717
#     Early stopping counter: 3/30
#     Epoch 47/500, Train Loss: 302.7710, Val Loss: 40.6019
#     Early stopping counter: 4/30
#     Epoch 48/500, Train Loss: 311.8519, Val Loss: 45.3577
#     Early stopping counter: 5/30
#     Epoch 49/500, Train Loss: 316.3669, Val Loss: 43.1331
#     Early stopping counter: 6/30
#     Epoch 50/500, Train Loss: 303.6497, Val Loss: 22.7257
#     Epoch 51/500, Train Loss: 313.3411, Val Loss: 88.3939
#     Early stopping counter: 1/30
#     Epoch 52/500, Train Loss: 316.3035, Val Loss: 66.4005
#     Early stopping counter: 2/30
#     Epoch 53/500, Train Loss: 294.7343, Val Loss: 49.4961
#     Early stopping counter: 3/30
#     Epoch 54/500, Train Loss: 314.7000, Val Loss: 49.1546
#     Early stopping counter: 4/30
#     Epoch 55/500, Train Loss: 290.4536, Val Loss: 48.3503
#     Early stopping counter: 5/30
#     Epoch 56/500, Train Loss: 322.5410, Val Loss: 65.7144
#     Early stopping counter: 6/30
#     Epoch 57/500, Train Loss: 302.3414, Val Loss: 82.2735
#     Early stopping counter: 7/30
#     Epoch 58/500, Train Loss: 308.8199, Val Loss: 60.9443
#     Early stopping counter: 8/30
#     Epoch 59/500, Train Loss: 291.3841, Val Loss: 56.0926
#     Early stopping counter: 9/30
#     Epoch 60/500, Train Loss: 303.5742, Val Loss: 88.9266
#     Early stopping counter: 10/30
#     Epoch 61/500, Train Loss: 310.7942, Val Loss: 62.1921
#     Early stopping counter: 11/30
#     Epoch 62/500, Train Loss: 326.5226, Val Loss: 67.0478
#     Early stopping counter: 12/30
#     Epoch 63/500, Train Loss: 315.2874, Val Loss: 63.9233
#     Early stopping counter: 13/30
#     Epoch 64/500, Train Loss: 298.6038, Val Loss: 59.9977
#     Early stopping counter: 14/30
#     Epoch 65/500, Train Loss: 304.6115, Val Loss: 109.2731
#     Early stopping counter: 15/30
#     Epoch 66/500, Train Loss: 314.0291, Val Loss: 57.5568
#     Early stopping counter: 16/30
#     Epoch 67/500, Train Loss: 295.8458, Val Loss: 20.3512
#     Epoch 68/500, Train Loss: 291.6411, Val Loss: 23.3560
#     Early stopping counter: 1/30
#     Epoch 69/500, Train Loss: 316.5762, Val Loss: 29.0934
#     Early stopping counter: 2/30
#     Epoch 70/500, Train Loss: 315.0495, Val Loss: 33.5660
#     Early stopping counter: 3/30
#     Epoch 71/500, Train Loss: 312.6969, Val Loss: 50.3958
#     Early stopping counter: 4/30
#     Epoch 72/500, Train Loss: 282.6882, Val Loss: 56.7684
#     Early stopping counter: 5/30
#     Epoch 73/500, Train Loss: 308.2035, Val Loss: 37.6366
#     Early stopping counter: 6/30
#     Epoch 74/500, Train Loss: 310.0643, Val Loss: 40.6237
#     Early stopping counter: 7/30
#     Epoch 75/500, Train Loss: 304.2776, Val Loss: 56.7253
#     Early stopping counter: 8/30
#     Epoch 76/500, Train Loss: 315.6099, Val Loss: 68.7647
#     Early stopping counter: 9/30
#     Epoch 77/500, Train Loss: 283.9595, Val Loss: 33.7524
#     Early stopping counter: 10/30
#     Epoch 78/500, Train Loss: 301.6828, Val Loss: 50.2655
#     Early stopping counter: 11/30
#     Epoch 79/500, Train Loss: 309.4755, Val Loss: 45.6642
#     Early stopping counter: 12/30
#     Epoch 80/500, Train Loss: 297.5441, Val Loss: 59.2402
#     Early stopping counter: 13/30
#     Epoch 81/500, Train Loss: 316.7983, Val Loss: 34.8358
#     Early stopping counter: 14/30
#     Epoch 82/500, Train Loss: 286.1204, Val Loss: 43.2897
#     Early stopping counter: 15/30
#     Epoch 83/500, Train Loss: 295.7625, Val Loss: 24.1061
#     Early stopping counter: 16/30
#     Epoch 84/500, Train Loss: 303.8604, Val Loss: 17.7333
#     Epoch 85/500, Train Loss: 308.7238, Val Loss: 19.3949
#     Early stopping counter: 1/30
#     Epoch 86/500, Train Loss: 310.8462, Val Loss: 30.7622
#     Early stopping counter: 2/30
#     Epoch 87/500, Train Loss: 330.5217, Val Loss: 29.5459
#     Early stopping counter: 3/30
#     Epoch 88/500, Train Loss: 290.5583, Val Loss: 20.8937
#     Early stopping counter: 4/30
#     Epoch 89/500, Train Loss: 296.6779, Val Loss: 34.0171
#     Early stopping counter: 5/30
#     Epoch 90/500, Train Loss: 301.2107, Val Loss: 59.0924
#     Early stopping counter: 6/30
#     Epoch 91/500, Train Loss: 304.0292, Val Loss: 25.1639
#     Early stopping counter: 7/30
#     Epoch 92/500, Train Loss: 342.3938, Val Loss: 21.1485
#     Early stopping counter: 8/30
#     Epoch 93/500, Train Loss: 330.7310, Val Loss: 22.8578
#     Early stopping counter: 9/30
#     Epoch 94/500, Train Loss: 286.1357, Val Loss: 30.3818
#     Early stopping counter: 10/30
#     Epoch 95/500, Train Loss: 310.5946, Val Loss: 25.2794
#     Early stopping counter: 11/30
#     Epoch 96/500, Train Loss: 297.1231, Val Loss: 40.6679
#     Early stopping counter: 12/30
#     Epoch 97/500, Train Loss: 308.9656, Val Loss: 67.4063
#     Early stopping counter: 13/30
#     Epoch 98/500, Train Loss: 294.5500, Val Loss: 55.8267
#     Early stopping counter: 14/30
#     Epoch 99/500, Train Loss: 320.7403, Val Loss: 57.9796
#     Early stopping counter: 15/30
#     Epoch 100/500, Train Loss: 288.8897, Val Loss: 34.6676
#     Early stopping counter: 16/30
#     Epoch 101/500, Train Loss: 304.6106, Val Loss: 39.0209
#     Early stopping counter: 17/30
#     Epoch 102/500, Train Loss: 328.2320, Val Loss: 40.5423
#     Early stopping counter: 18/30
#     Epoch 103/500, Train Loss: 293.4370, Val Loss: 38.1436
#     Early stopping counter: 19/30
#     Epoch 104/500, Train Loss: 302.8685, Val Loss: 32.0022
#     Early stopping counter: 20/30
#     Epoch 105/500, Train Loss: 317.0122, Val Loss: 33.3242
#     Early stopping counter: 21/30
#     Epoch 106/500, Train Loss: 283.6112, Val Loss: 21.2755
#     Early stopping counter: 22/30
#     Epoch 107/500, Train Loss: 301.8919, Val Loss: 23.9527
#     Early stopping counter: 23/30
#     Epoch 108/500, Train Loss: 306.9190, Val Loss: 37.5712
#     Early stopping counter: 24/30
#     Epoch 109/500, Train Loss: 292.5512, Val Loss: 30.3242
#     Early stopping counter: 25/30
#     Epoch 110/500, Train Loss: 293.1201, Val Loss: 33.8161
#     Early stopping counter: 26/30
#     Epoch 111/500, Train Loss: 286.3939, Val Loss: 66.6008
#     Early stopping counter: 27/30
#     Epoch 112/500, Train Loss: 290.7038, Val Loss: 50.4320
#     Early stopping counter: 28/30
#     Epoch 113/500, Train Loss: 322.6706, Val Loss: 33.8428
#     Early stopping counter: 29/30
#     Epoch 114/500, Train Loss: 300.1762, Val Loss: 23.4501
#     Early stopping counter: 30/30
#     Early stopping triggered.
#   Repeat 2/5
#     Epoch 1/500, Train Loss: 6739.8178, Val Loss: 10617.4282
#     Epoch 2/500, Train Loss: 6507.3385, Val Loss: 9979.9954
#     Epoch 3/500, Train Loss: 5777.5991, Val Loss: 8734.3538
#     Epoch 4/500, Train Loss: 4528.3159, Val Loss: 6673.6055
#     Epoch 5/500, Train Loss: 2902.4595, Val Loss: 3999.8191
#     Epoch 6/500, Train Loss: 1273.1209, Val Loss: 1686.0887
#     Epoch 7/500, Train Loss: 567.4369, Val Loss: 673.9673
#     Epoch 8/500, Train Loss: 420.4710, Val Loss: 589.6560
#     Epoch 9/500, Train Loss: 445.2051, Val Loss: 676.2482
#     Early stopping counter: 1/30
#     Epoch 10/500, Train Loss: 444.7606, Val Loss: 674.6060
#     Early stopping counter: 2/30
#     Epoch 11/500, Train Loss: 465.1585, Val Loss: 661.1094
#     Early stopping counter: 3/30
#     Epoch 12/500, Train Loss: 424.5510, Val Loss: 700.6774
#     Early stopping counter: 4/30
#     Epoch 13/500, Train Loss: 475.5979, Val Loss: 618.1850
#     Early stopping counter: 5/30
#     Epoch 14/500, Train Loss: 462.7568, Val Loss: 653.3286
#     Early stopping counter: 6/30
#     Epoch 15/500, Train Loss: 462.2414, Val Loss: 643.3294
#     Early stopping counter: 7/30
#     Epoch 16/500, Train Loss: 439.1552, Val Loss: 689.2931
#     Early stopping counter: 8/30
#     Epoch 17/500, Train Loss: 459.4029, Val Loss: 692.1844
#     Early stopping counter: 9/30
#     Epoch 18/500, Train Loss: 463.0279, Val Loss: 636.4635
#     Early stopping counter: 10/30
#     Epoch 19/500, Train Loss: 423.8638, Val Loss: 656.3484
#     Early stopping counter: 11/30
#     Epoch 20/500, Train Loss: 435.4270, Val Loss: 653.4727
#     Early stopping counter: 12/30
#     Epoch 21/500, Train Loss: 427.4511, Val Loss: 648.1033
#     Early stopping counter: 13/30
#     Epoch 22/500, Train Loss: 441.5768, Val Loss: 668.6024
#     Early stopping counter: 14/30
#     Epoch 23/500, Train Loss: 460.7328, Val Loss: 657.4183
#     Early stopping counter: 15/30
#     Epoch 24/500, Train Loss: 438.3238, Val Loss: 680.7553
#     Early stopping counter: 16/30
#     Epoch 25/500, Train Loss: 462.7243, Val Loss: 712.1500
#     Early stopping counter: 17/30
#     Epoch 26/500, Train Loss: 408.9485, Val Loss: 651.0138
#     Early stopping counter: 18/30
#     Epoch 27/500, Train Loss: 437.2717, Val Loss: 637.9203
#     Early stopping counter: 19/30
#     Epoch 28/500, Train Loss: 424.8477, Val Loss: 690.3573
#     Early stopping counter: 20/30
#     Epoch 29/500, Train Loss: 434.8047, Val Loss: 633.4833
#     Early stopping counter: 21/30
#     Epoch 30/500, Train Loss: 411.4530, Val Loss: 737.4594
#     Early stopping counter: 22/30
#     Epoch 31/500, Train Loss: 432.0141, Val Loss: 657.0675
#     Early stopping counter: 23/30
#     Epoch 32/500, Train Loss: 404.3492, Val Loss: 648.8167
#     Early stopping counter: 24/30
#     Epoch 33/500, Train Loss: 445.9551, Val Loss: 638.1968
#     Early stopping counter: 25/30
#     Epoch 34/500, Train Loss: 364.4618, Val Loss: 441.9441
#     Epoch 35/500, Train Loss: 301.4447, Val Loss: 285.5659
#     Epoch 36/500, Train Loss: 285.3268, Val Loss: 208.7995
#     Epoch 37/500, Train Loss: 279.4278, Val Loss: 96.2589
#     Epoch 38/500, Train Loss: 281.0066, Val Loss: 155.5105
#     Early stopping counter: 1/30
#     Epoch 39/500, Train Loss: 251.3359, Val Loss: 29.1920
#     Epoch 40/500, Train Loss: 280.0499, Val Loss: 69.7523
#     Early stopping counter: 1/30
#     Epoch 41/500, Train Loss: 247.4154, Val Loss: 35.4059
#     Early stopping counter: 2/30
#     Epoch 42/500, Train Loss: 272.2883, Val Loss: 27.0319
#     Epoch 43/500, Train Loss: 243.4599, Val Loss: 29.3940
#     Early stopping counter: 1/30
#     Epoch 44/500, Train Loss: 256.7459, Val Loss: 32.2480
#     Early stopping counter: 2/30
#     Epoch 45/500, Train Loss: 252.8240, Val Loss: 40.6897
#     Early stopping counter: 3/30
#     Epoch 46/500, Train Loss: 255.6045, Val Loss: 67.7105
#     Early stopping counter: 4/30
#     Epoch 47/500, Train Loss: 255.6217, Val Loss: 23.5683
#     Epoch 48/500, Train Loss: 242.0379, Val Loss: 24.1354
#     Early stopping counter: 1/30
#     Epoch 49/500, Train Loss: 242.2931, Val Loss: 20.2445
#     Epoch 50/500, Train Loss: 236.6737, Val Loss: 20.1362
#     Epoch 51/500, Train Loss: 253.5404, Val Loss: 22.3881
#     Early stopping counter: 1/30
#     Epoch 52/500, Train Loss: 252.7160, Val Loss: 24.9647
#     Early stopping counter: 2/30
#     Epoch 53/500, Train Loss: 243.8659, Val Loss: 22.4402
#     Early stopping counter: 3/30
#     Epoch 54/500, Train Loss: 265.4375, Val Loss: 22.4129
#     Early stopping counter: 4/30
#     Epoch 55/500, Train Loss: 252.7586, Val Loss: 30.8454
#     Early stopping counter: 5/30
#     Epoch 56/500, Train Loss: 247.5033, Val Loss: 33.2436
#     Early stopping counter: 6/30
#     Epoch 57/500, Train Loss: 248.3081, Val Loss: 33.9548
#     Early stopping counter: 7/30
#     Epoch 58/500, Train Loss: 243.1319, Val Loss: 29.2003
#     Early stopping counter: 8/30
#     Epoch 59/500, Train Loss: 242.4355, Val Loss: 28.7278
#     Early stopping counter: 9/30
#     Epoch 60/500, Train Loss: 245.2028, Val Loss: 27.7453
#     Early stopping counter: 10/30
#     Epoch 61/500, Train Loss: 242.9598, Val Loss: 30.6300
#     Early stopping counter: 11/30
#     Epoch 62/500, Train Loss: 234.6219, Val Loss: 27.8912
#     Early stopping counter: 12/30
#     Epoch 63/500, Train Loss: 250.6436, Val Loss: 22.0363
#     Early stopping counter: 13/30
#     Epoch 64/500, Train Loss: 243.8965, Val Loss: 22.6189
#     Early stopping counter: 14/30
#     Epoch 65/500, Train Loss: 248.7465, Val Loss: 43.8451
#     Early stopping counter: 15/30
#     Epoch 66/500, Train Loss: 242.1734, Val Loss: 22.4964
#     Early stopping counter: 16/30
#     Epoch 67/500, Train Loss: 236.7789, Val Loss: 16.0871
#     Epoch 68/500, Train Loss: 248.2393, Val Loss: 18.8694
#     Early stopping counter: 1/30
#     Epoch 69/500, Train Loss: 240.4855, Val Loss: 23.8865
#     Early stopping counter: 2/30
#     Epoch 70/500, Train Loss: 259.5394, Val Loss: 17.5302
#     Early stopping counter: 3/30
#     Epoch 71/500, Train Loss: 236.5955, Val Loss: 45.4720
#     Early stopping counter: 4/30
#     Epoch 72/500, Train Loss: 244.6450, Val Loss: 17.5472
#     Early stopping counter: 5/30
#     Epoch 73/500, Train Loss: 248.6529, Val Loss: 14.8800
#     Epoch 74/500, Train Loss: 246.2370, Val Loss: 13.0680
#     Epoch 75/500, Train Loss: 261.1970, Val Loss: 37.4986
#     Early stopping counter: 1/30
#     Epoch 76/500, Train Loss: 233.1784, Val Loss: 11.4561
#     Epoch 77/500, Train Loss: 236.4678, Val Loss: 19.0529
#     Early stopping counter: 1/30
#     Epoch 78/500, Train Loss: 246.6364, Val Loss: 32.7918
#     Early stopping counter: 2/30
#     Epoch 79/500, Train Loss: 226.8018, Val Loss: 20.2592
#     Early stopping counter: 3/30
#     Epoch 80/500, Train Loss: 235.5924, Val Loss: 28.9258
#     Early stopping counter: 4/30
#     Epoch 81/500, Train Loss: 240.7367, Val Loss: 27.6933
#     Early stopping counter: 5/30
#     Epoch 82/500, Train Loss: 226.5163, Val Loss: 19.4569
#     Early stopping counter: 6/30
#     Epoch 83/500, Train Loss: 229.3936, Val Loss: 18.8735
#     Early stopping counter: 7/30
#     Epoch 84/500, Train Loss: 234.4723, Val Loss: 16.1272
#     Early stopping counter: 8/30
#     Epoch 85/500, Train Loss: 241.8732, Val Loss: 19.2644
#     Early stopping counter: 9/30
#     Epoch 86/500, Train Loss: 256.1627, Val Loss: 53.3328
#     Early stopping counter: 10/30
#     Epoch 87/500, Train Loss: 221.7883, Val Loss: 29.9220
#     Early stopping counter: 11/30
#     Epoch 88/500, Train Loss: 235.5394, Val Loss: 25.2337
#     Early stopping counter: 12/30
#     Epoch 89/500, Train Loss: 245.9333, Val Loss: 55.3807
#     Early stopping counter: 13/30
#     Epoch 90/500, Train Loss: 233.8980, Val Loss: 56.6049
#     Early stopping counter: 14/30
#     Epoch 91/500, Train Loss: 218.4819, Val Loss: 31.3974
#     Early stopping counter: 15/30
#     Epoch 92/500, Train Loss: 243.3965, Val Loss: 14.9001
#     Early stopping counter: 16/30
#     Epoch 93/500, Train Loss: 245.4086, Val Loss: 21.1352
#     Early stopping counter: 17/30
#     Epoch 94/500, Train Loss: 232.5648, Val Loss: 23.0210
#     Early stopping counter: 18/30
#     Epoch 95/500, Train Loss: 247.3717, Val Loss: 18.0962
#     Early stopping counter: 19/30
#     Epoch 96/500, Train Loss: 229.9895, Val Loss: 27.6374
#     Early stopping counter: 20/30
#     Epoch 97/500, Train Loss: 228.6906, Val Loss: 20.3738
#     Early stopping counter: 21/30
#     Epoch 98/500, Train Loss: 244.1151, Val Loss: 38.9814
#     Early stopping counter: 22/30
#     Epoch 99/500, Train Loss: 232.3854, Val Loss: 20.2177
#     Early stopping counter: 23/30
#     Epoch 100/500, Train Loss: 234.9288, Val Loss: 39.5724
#     Early stopping counter: 24/30
#     Epoch 101/500, Train Loss: 240.3526, Val Loss: 18.2779
#     Early stopping counter: 25/30
#     Epoch 102/500, Train Loss: 243.5916, Val Loss: 23.8600
#     Early stopping counter: 26/30
#     Epoch 103/500, Train Loss: 234.5643, Val Loss: 24.0895
#     Early stopping counter: 27/30
#     Epoch 104/500, Train Loss: 252.3138, Val Loss: 23.9940
#     Early stopping counter: 28/30
#     Epoch 105/500, Train Loss: 217.1803, Val Loss: 33.2388
#     Early stopping counter: 29/30
#     Epoch 106/500, Train Loss: 225.5363, Val Loss: 18.7831
#     Early stopping counter: 30/30
#     Early stopping triggered.
#   Repeat 3/5
#     Epoch 1/500, Train Loss: 6719.2836, Val Loss: 10533.8118
#     Epoch 2/500, Train Loss: 6367.4766, Val Loss: 9710.1213
#     Epoch 3/500, Train Loss: 5463.6877, Val Loss: 8079.3696
#     Epoch 4/500, Train Loss: 3908.9186, Val Loss: 5552.3895
#     Epoch 5/500, Train Loss: 2028.1531, Val Loss: 2665.1551
#     Epoch 6/500, Train Loss: 724.7957, Val Loss: 845.9319
#     Epoch 7/500, Train Loss: 448.9036, Val Loss: 504.5115
#     Epoch 8/500, Train Loss: 464.7943, Val Loss: 618.3793
#     Early stopping counter: 1/30
#     Epoch 9/500, Train Loss: 439.5982, Val Loss: 727.6493
#     Early stopping counter: 2/30
#     Epoch 10/500, Train Loss: 437.0917, Val Loss: 685.8750
#     Early stopping counter: 3/30
#     Epoch 11/500, Train Loss: 445.1911, Val Loss: 612.1387
#     Early stopping counter: 4/30
#     Epoch 12/500, Train Loss: 437.8990, Val Loss: 643.7895
#     Early stopping counter: 5/30
#     Epoch 13/500, Train Loss: 429.2100, Val Loss: 702.5990
#     Early stopping counter: 6/30
#     Epoch 14/500, Train Loss: 410.0225, Val Loss: 684.9492
#     Early stopping counter: 7/30
#     Epoch 15/500, Train Loss: 427.1005, Val Loss: 703.9025
#     Early stopping counter: 8/30
#     Epoch 16/500, Train Loss: 418.1993, Val Loss: 639.3889
#     Early stopping counter: 9/30
#     Epoch 17/500, Train Loss: 414.0423, Val Loss: 654.9356
#     Early stopping counter: 10/30
#     Epoch 18/500, Train Loss: 400.9942, Val Loss: 612.0213
#     Early stopping counter: 11/30
#     Epoch 19/500, Train Loss: 416.6206, Val Loss: 634.0520
#     Early stopping counter: 12/30
#     Epoch 20/500, Train Loss: 400.6748, Val Loss: 662.0014
#     Early stopping counter: 13/30
#     Epoch 21/500, Train Loss: 405.1328, Val Loss: 658.7362
#     Early stopping counter: 14/30
#     Epoch 22/500, Train Loss: 392.5591, Val Loss: 696.0864
#     Early stopping counter: 15/30
#     Epoch 23/500, Train Loss: 440.4158, Val Loss: 646.8832
#     Early stopping counter: 16/30
#     Epoch 24/500, Train Loss: 414.3179, Val Loss: 649.2526
#     Early stopping counter: 17/30
#     Epoch 25/500, Train Loss: 419.8401, Val Loss: 654.9809
#     Early stopping counter: 18/30
#     Epoch 26/500, Train Loss: 417.8866, Val Loss: 652.3503
#     Early stopping counter: 19/30
#     Epoch 27/500, Train Loss: 399.1695, Val Loss: 637.0652
#     Early stopping counter: 20/30
#     Epoch 28/500, Train Loss: 400.4530, Val Loss: 670.2716
#     Early stopping counter: 21/30
#     Epoch 29/500, Train Loss: 403.0258, Val Loss: 665.6813
#     Early stopping counter: 22/30
#     Epoch 30/500, Train Loss: 402.9497, Val Loss: 570.4081
#     Early stopping counter: 23/30
#     Epoch 31/500, Train Loss: 401.7480, Val Loss: 647.7081
#     Early stopping counter: 24/30
#     Epoch 32/500, Train Loss: 405.8103, Val Loss: 647.8819
#     Early stopping counter: 25/30
#     Epoch 33/500, Train Loss: 421.9011, Val Loss: 638.3769
#     Early stopping counter: 26/30
#     Epoch 34/500, Train Loss: 370.7712, Val Loss: 655.2983
#     Early stopping counter: 27/30
#     Epoch 35/500, Train Loss: 405.0476, Val Loss: 666.6138
#     Early stopping counter: 28/30
#     Epoch 36/500, Train Loss: 391.0995, Val Loss: 621.4267
#     Early stopping counter: 29/30
#     Epoch 37/500, Train Loss: 388.2773, Val Loss: 681.7323
#     Early stopping counter: 30/30
#     Early stopping triggered.
#   Repeat 4/5
#     Epoch 1/500, Train Loss: 6739.9861, Val Loss: 10615.0264
#     Epoch 2/500, Train Loss: 6548.5877, Val Loss: 10180.8896
#     Epoch 3/500, Train Loss: 6042.7901, Val Loss: 9203.8645
#     Epoch 4/500, Train Loss: 5040.8493, Val Loss: 7483.7159
#     Epoch 5/500, Train Loss: 3492.3772, Val Loss: 5004.7031
#     Epoch 6/500, Train Loss: 1788.3878, Val Loss: 2485.1268
#     Epoch 7/500, Train Loss: 748.0141, Val Loss: 984.7258
#     Epoch 8/500, Train Loss: 500.8318, Val Loss: 614.7503
#     Epoch 9/500, Train Loss: 484.7611, Val Loss: 687.3382
#     Early stopping counter: 1/30
#     Epoch 10/500, Train Loss: 484.2588, Val Loss: 724.5466
#     Early stopping counter: 2/30
#     Epoch 11/500, Train Loss: 497.0201, Val Loss: 728.9091
#     Early stopping counter: 3/30
#     Epoch 12/500, Train Loss: 511.4712, Val Loss: 689.5200
#     Early stopping counter: 4/30
#     Epoch 13/500, Train Loss: 454.3742, Val Loss: 706.6500
#     Early stopping counter: 5/30
#     Epoch 14/500, Train Loss: 486.1829, Val Loss: 704.7977
#     Early stopping counter: 6/30
#     Epoch 15/500, Train Loss: 517.2870, Val Loss: 702.2692
#     Early stopping counter: 7/30
#     Epoch 16/500, Train Loss: 485.8809, Val Loss: 699.4632
#     Early stopping counter: 8/30
#     Epoch 17/500, Train Loss: 476.4891, Val Loss: 678.2859
#     Early stopping counter: 9/30
#     Epoch 18/500, Train Loss: 464.4425, Val Loss: 644.7260
#     Early stopping counter: 10/30
#     Epoch 19/500, Train Loss: 496.3846, Val Loss: 687.4965
#     Early stopping counter: 11/30
#     Epoch 20/500, Train Loss: 488.0929, Val Loss: 648.8255
#     Early stopping counter: 12/30
#     Epoch 21/500, Train Loss: 457.0819, Val Loss: 669.6098
#     Early stopping counter: 13/30
#     Epoch 22/500, Train Loss: 483.4329, Val Loss: 681.6562
#     Early stopping counter: 14/30
#     Epoch 23/500, Train Loss: 457.1805, Val Loss: 716.9364
#     Early stopping counter: 15/30
#     Epoch 24/500, Train Loss: 485.1849, Val Loss: 674.6688
#     Early stopping counter: 16/30
#     Epoch 25/500, Train Loss: 444.6208, Val Loss: 664.6197
#     Early stopping counter: 17/30
#     Epoch 26/500, Train Loss: 473.7883, Val Loss: 630.6518
#     Early stopping counter: 18/30
#     Epoch 27/500, Train Loss: 462.0239, Val Loss: 708.6923
#     Early stopping counter: 19/30
#     Epoch 28/500, Train Loss: 481.2242, Val Loss: 695.8012
#     Early stopping counter: 20/30
#     Epoch 29/500, Train Loss: 477.0213, Val Loss: 711.8503
#     Early stopping counter: 21/30
#     Epoch 30/500, Train Loss: 438.3573, Val Loss: 653.1008
#     Early stopping counter: 22/30
#     Epoch 31/500, Train Loss: 450.9326, Val Loss: 662.8293
#     Early stopping counter: 23/30
#     Epoch 32/500, Train Loss: 451.4473, Val Loss: 715.7093
#     Early stopping counter: 24/30
#     Epoch 33/500, Train Loss: 449.4388, Val Loss: 668.8247
#     Early stopping counter: 25/30
#     Epoch 34/500, Train Loss: 473.7017, Val Loss: 610.8294
#     Epoch 35/500, Train Loss: 455.1194, Val Loss: 697.1900
#     Early stopping counter: 1/30
#     Epoch 36/500, Train Loss: 436.9439, Val Loss: 692.0025
#     Early stopping counter: 2/30
#     Epoch 37/500, Train Loss: 459.1467, Val Loss: 643.6283
#     Early stopping counter: 3/30
#     Epoch 38/500, Train Loss: 437.0301, Val Loss: 643.8020
#     Early stopping counter: 4/30
#     Epoch 39/500, Train Loss: 451.1996, Val Loss: 649.4128
#     Early stopping counter: 5/30
#     Epoch 40/500, Train Loss: 434.8848, Val Loss: 632.3621
#     Early stopping counter: 6/30
#     Epoch 41/500, Train Loss: 473.7225, Val Loss: 689.5266
#     Early stopping counter: 7/30
#     Epoch 42/500, Train Loss: 465.7481, Val Loss: 644.7967
#     Early stopping counter: 8/30
#     Epoch 43/500, Train Loss: 441.6306, Val Loss: 689.6469
#     Early stopping counter: 9/30
#     Epoch 44/500, Train Loss: 456.3503, Val Loss: 671.4229
#     Early stopping counter: 10/30
#     Epoch 45/500, Train Loss: 452.4207, Val Loss: 664.1997
#     Early stopping counter: 11/30
#     Epoch 46/500, Train Loss: 428.3217, Val Loss: 638.3156
#     Early stopping counter: 12/30
#     Epoch 47/500, Train Loss: 431.2505, Val Loss: 592.1691
#     Epoch 48/500, Train Loss: 379.5567, Val Loss: 402.8652
#     Epoch 49/500, Train Loss: 334.5117, Val Loss: 246.5103
#     Epoch 50/500, Train Loss: 288.0334, Val Loss: 130.1497
#     Epoch 51/500, Train Loss: 283.2694, Val Loss: 52.0837
#     Epoch 52/500, Train Loss: 280.8856, Val Loss: 46.9363
#     Epoch 53/500, Train Loss: 270.0167, Val Loss: 74.9526
#     Early stopping counter: 1/30
#     Epoch 54/500, Train Loss: 252.0780, Val Loss: 37.5105
#     Epoch 55/500, Train Loss: 278.2750, Val Loss: 59.3442
#     Early stopping counter: 1/30
#     Epoch 56/500, Train Loss: 277.2728, Val Loss: 54.7861
#     Early stopping counter: 2/30
#     Epoch 57/500, Train Loss: 267.7729, Val Loss: 61.7926
#     Early stopping counter: 3/30
#     Epoch 58/500, Train Loss: 275.9352, Val Loss: 84.7967
#     Early stopping counter: 4/30
#     Epoch 59/500, Train Loss: 248.6511, Val Loss: 30.9654
#     Epoch 60/500, Train Loss: 257.4989, Val Loss: 17.8099
#     Epoch 61/500, Train Loss: 263.7141, Val Loss: 39.1432
#     Early stopping counter: 1/30
#     Epoch 62/500, Train Loss: 241.5264, Val Loss: 31.5976
#     Early stopping counter: 2/30
#     Epoch 63/500, Train Loss: 278.6628, Val Loss: 32.0003
#     Early stopping counter: 3/30
#     Epoch 64/500, Train Loss: 287.5677, Val Loss: 44.1366
#     Early stopping counter: 4/30
#     Epoch 65/500, Train Loss: 265.7335, Val Loss: 41.1550
#     Early stopping counter: 5/30
#     Epoch 66/500, Train Loss: 240.7154, Val Loss: 20.5493
#     Early stopping counter: 6/30
#     Epoch 67/500, Train Loss: 242.0323, Val Loss: 18.7145
#     Early stopping counter: 7/30
#     Epoch 68/500, Train Loss: 276.7643, Val Loss: 23.6354
#     Early stopping counter: 8/30
#     Epoch 69/500, Train Loss: 266.0935, Val Loss: 30.9611
#     Early stopping counter: 9/30
#     Epoch 70/500, Train Loss: 265.0840, Val Loss: 26.7392
#     Early stopping counter: 10/30
#     Epoch 71/500, Train Loss: 275.2590, Val Loss: 27.9041
#     Early stopping counter: 11/30
#     Epoch 72/500, Train Loss: 273.0931, Val Loss: 39.1122
#     Early stopping counter: 12/30
#     Epoch 73/500, Train Loss: 266.9351, Val Loss: 41.0319
#     Early stopping counter: 13/30
#     Epoch 74/500, Train Loss: 262.6717, Val Loss: 27.0403
#     Early stopping counter: 14/30
#     Epoch 75/500, Train Loss: 260.6108, Val Loss: 43.5660
#     Early stopping counter: 15/30
#     Epoch 76/500, Train Loss: 282.1217, Val Loss: 40.9085
#     Early stopping counter: 16/30
#     Epoch 77/500, Train Loss: 268.9713, Val Loss: 40.6954
#     Early stopping counter: 17/30
#     Epoch 78/500, Train Loss: 244.1928, Val Loss: 32.1273
#     Early stopping counter: 18/30
#     Epoch 79/500, Train Loss: 259.5761, Val Loss: 40.6998
#     Early stopping counter: 19/30
#     Epoch 80/500, Train Loss: 262.1064, Val Loss: 16.0630
#     Epoch 81/500, Train Loss: 250.3123, Val Loss: 15.1403
#     Epoch 82/500, Train Loss: 235.1282, Val Loss: 20.8179
#     Early stopping counter: 1/30
#     Epoch 83/500, Train Loss: 260.6923, Val Loss: 12.0096
#     Epoch 84/500, Train Loss: 271.4771, Val Loss: 17.5029
#     Early stopping counter: 1/30
#     Epoch 85/500, Train Loss: 266.1689, Val Loss: 11.0806
#     Epoch 86/500, Train Loss: 261.4437, Val Loss: 15.6152
#     Early stopping counter: 1/30
#     Epoch 87/500, Train Loss: 278.6010, Val Loss: 34.5014
#     Early stopping counter: 2/30
#     Epoch 88/500, Train Loss: 257.2548, Val Loss: 35.1620
#     Early stopping counter: 3/30
#     Epoch 89/500, Train Loss: 267.2257, Val Loss: 32.6067
#     Early stopping counter: 4/30
#     Epoch 90/500, Train Loss: 273.9284, Val Loss: 17.4159
#     Early stopping counter: 5/30
#     Epoch 91/500, Train Loss: 254.5410, Val Loss: 17.9644
#     Early stopping counter: 6/30
#     Epoch 92/500, Train Loss: 255.6261, Val Loss: 87.6622
#     Early stopping counter: 7/30
#     Epoch 93/500, Train Loss: 253.3632, Val Loss: 26.8200
#     Early stopping counter: 8/30
#     Epoch 94/500, Train Loss: 268.6921, Val Loss: 29.9501
#     Early stopping counter: 9/30
#     Epoch 95/500, Train Loss: 263.8777, Val Loss: 47.0490
#     Early stopping counter: 10/30
#     Epoch 96/500, Train Loss: 248.9046, Val Loss: 26.6576
#     Early stopping counter: 11/30
#     Epoch 97/500, Train Loss: 246.8855, Val Loss: 20.7354
#     Early stopping counter: 12/30
#     Epoch 98/500, Train Loss: 269.8295, Val Loss: 30.6916
#     Early stopping counter: 13/30
#     Epoch 99/500, Train Loss: 261.8606, Val Loss: 22.1930
#     Early stopping counter: 14/30
#     Epoch 100/500, Train Loss: 254.6778, Val Loss: 19.2565
#     Early stopping counter: 15/30
#     Epoch 101/500, Train Loss: 247.8860, Val Loss: 37.4236
#     Early stopping counter: 16/30
#     Epoch 102/500, Train Loss: 258.5358, Val Loss: 22.7900
#     Early stopping counter: 17/30
#     Epoch 103/500, Train Loss: 267.8193, Val Loss: 20.7412
#     Early stopping counter: 18/30
#     Epoch 104/500, Train Loss: 273.0158, Val Loss: 21.0706
#     Early stopping counter: 19/30
#     Epoch 105/500, Train Loss: 243.6300, Val Loss: 21.2929
#     Early stopping counter: 20/30
#     Epoch 106/500, Train Loss: 242.1137, Val Loss: 32.0213
#     Early stopping counter: 21/30
#     Epoch 107/500, Train Loss: 252.2024, Val Loss: 24.7352
#     Early stopping counter: 22/30
#     Epoch 108/500, Train Loss: 277.4762, Val Loss: 31.9901
#     Early stopping counter: 23/30
#     Epoch 109/500, Train Loss: 241.5253, Val Loss: 35.6010
#     Early stopping counter: 24/30
#     Epoch 110/500, Train Loss: 248.8853, Val Loss: 20.1340
#     Early stopping counter: 25/30
#     Epoch 111/500, Train Loss: 268.0031, Val Loss: 20.7645
#     Early stopping counter: 26/30
#     Epoch 112/500, Train Loss: 259.9925, Val Loss: 25.5766
#     Early stopping counter: 27/30
#     Epoch 113/500, Train Loss: 270.4846, Val Loss: 34.7608
#     Early stopping counter: 28/30
#     Epoch 114/500, Train Loss: 258.9470, Val Loss: 30.9779
#     Early stopping counter: 29/30
#     Epoch 115/500, Train Loss: 239.9693, Val Loss: 25.2220
#     Early stopping counter: 30/30
#     Early stopping triggered.
#   Repeat 5/5
#     Epoch 1/500, Train Loss: 6703.0675, Val Loss: 10476.4182
#     Epoch 2/500, Train Loss: 6281.0622, Val Loss: 9574.8342
#     Epoch 3/500, Train Loss: 5330.6722, Val Loss: 7914.8992
#     Epoch 4/500, Train Loss: 3825.8236, Val Loss: 5423.7332
#     Epoch 5/500, Train Loss: 1979.7824, Val Loss: 2753.5805
#     Epoch 6/500, Train Loss: 746.8498, Val Loss: 1025.9807
#     Epoch 7/500, Train Loss: 464.3120, Val Loss: 570.8318
#     Epoch 8/500, Train Loss: 452.4821, Val Loss: 599.5614
#     Early stopping counter: 1/30
#     Epoch 9/500, Train Loss: 440.5101, Val Loss: 694.8365
#     Early stopping counter: 2/30
#     Epoch 10/500, Train Loss: 452.7125, Val Loss: 712.6057
#     Early stopping counter: 3/30
#     Epoch 11/500, Train Loss: 465.1490, Val Loss: 676.7960
#     Early stopping counter: 4/30
#     Epoch 12/500, Train Loss: 433.6383, Val Loss: 692.9405
#     Early stopping counter: 5/30
#     Epoch 13/500, Train Loss: 462.9841, Val Loss: 693.7479
#     Early stopping counter: 6/30
#     Epoch 14/500, Train Loss: 466.2771, Val Loss: 671.2431
#     Early stopping counter: 7/30
#     Epoch 15/500, Train Loss: 445.3077, Val Loss: 643.3530
#     Early stopping counter: 8/30
#     Epoch 16/500, Train Loss: 444.6430, Val Loss: 687.7002
#     Early stopping counter: 9/30
#     Epoch 17/500, Train Loss: 454.4866, Val Loss: 698.9432
#     Early stopping counter: 10/30
#     Epoch 18/500, Train Loss: 417.7610, Val Loss: 683.3780
#     Early stopping counter: 11/30
#     Epoch 19/500, Train Loss: 430.6061, Val Loss: 618.5144
#     Early stopping counter: 12/30
#     Epoch 20/500, Train Loss: 486.2311, Val Loss: 706.4001
#     Early stopping counter: 13/30
#     Epoch 21/500, Train Loss: 417.6100, Val Loss: 645.4975
#     Early stopping counter: 14/30
#     Epoch 22/500, Train Loss: 435.5499, Val Loss: 660.9902
#     Early stopping counter: 15/30
#     Epoch 23/500, Train Loss: 445.3535, Val Loss: 686.7740
#     Early stopping counter: 16/30
#     Epoch 24/500, Train Loss: 429.2004, Val Loss: 654.1754
#     Early stopping counter: 17/30
#     Epoch 25/500, Train Loss: 421.5020, Val Loss: 651.2609
#     Early stopping counter: 18/30
#     Epoch 26/500, Train Loss: 448.3122, Val Loss: 669.1319
#     Early stopping counter: 19/30
#     Epoch 27/500, Train Loss: 425.0720, Val Loss: 675.3350
#     Early stopping counter: 20/30
#     Epoch 28/500, Train Loss: 432.6990, Val Loss: 642.0850
#     Early stopping counter: 21/30
#     Epoch 29/500, Train Loss: 461.2275, Val Loss: 664.0461
#     Early stopping counter: 22/30
#     Epoch 30/500, Train Loss: 430.5971, Val Loss: 630.1708
#     Early stopping counter: 23/30
#     Epoch 31/500, Train Loss: 391.2339, Val Loss: 650.1649
#     Early stopping counter: 24/30
#     Epoch 32/500, Train Loss: 395.5607, Val Loss: 540.1890
#     Epoch 33/500, Train Loss: 331.4975, Val Loss: 292.6789
#     Epoch 34/500, Train Loss: 295.6239, Val Loss: 204.3730
#     Epoch 35/500, Train Loss: 268.7585, Val Loss: 110.6834
#     Epoch 36/500, Train Loss: 261.9749, Val Loss: 91.2080
#     Epoch 37/500, Train Loss: 257.6909, Val Loss: 70.0273
#     Epoch 38/500, Train Loss: 268.4160, Val Loss: 45.6290
#     Epoch 39/500, Train Loss: 282.9870, Val Loss: 54.5807
#     Early stopping counter: 1/30
#     Epoch 40/500, Train Loss: 255.1718, Val Loss: 68.4943
#     Early stopping counter: 2/30
#     Epoch 41/500, Train Loss: 271.3574, Val Loss: 62.6645
#     Early stopping counter: 3/30
#     Epoch 42/500, Train Loss: 275.8344, Val Loss: 39.2557
#     Epoch 43/500, Train Loss: 241.8942, Val Loss: 31.7596
#     Epoch 44/500, Train Loss: 245.2669, Val Loss: 31.6896
#     Epoch 45/500, Train Loss: 252.7762, Val Loss: 42.5453
#     Early stopping counter: 1/30
#     Epoch 46/500, Train Loss: 251.0377, Val Loss: 53.4369
#     Early stopping counter: 2/30
#     Epoch 47/500, Train Loss: 244.0371, Val Loss: 41.0821
#     Early stopping counter: 3/30
#     Epoch 48/500, Train Loss: 233.5134, Val Loss: 33.1778
#     Early stopping counter: 4/30
#     Epoch 49/500, Train Loss: 251.5966, Val Loss: 35.1317
#     Early stopping counter: 5/30
#     Epoch 50/500, Train Loss: 235.2946, Val Loss: 31.6255
#     Epoch 51/500, Train Loss: 243.1428, Val Loss: 26.3580
#     Epoch 52/500, Train Loss: 254.1810, Val Loss: 23.8362
#     Epoch 53/500, Train Loss: 243.9241, Val Loss: 24.3107
#     Early stopping counter: 1/30
#     Epoch 54/500, Train Loss: 255.5575, Val Loss: 37.4579
#     Early stopping counter: 2/30
#     Epoch 55/500, Train Loss: 227.3717, Val Loss: 30.0763
#     Early stopping counter: 3/30
#     Epoch 56/500, Train Loss: 250.6935, Val Loss: 30.9438
#     Early stopping counter: 4/30
#     Epoch 57/500, Train Loss: 229.9215, Val Loss: 36.0684
#     Early stopping counter: 5/30
#     Epoch 58/500, Train Loss: 236.3307, Val Loss: 41.4166
#     Early stopping counter: 6/30
#     Epoch 59/500, Train Loss: 235.5818, Val Loss: 37.7762
#     Early stopping counter: 7/30
#     Epoch 60/500, Train Loss: 243.1612, Val Loss: 52.1882
#     Early stopping counter: 8/30
#     Epoch 61/500, Train Loss: 251.3967, Val Loss: 26.2219
#     Early stopping counter: 9/30
#     Epoch 62/500, Train Loss: 246.2008, Val Loss: 60.3203
#     Early stopping counter: 10/30
#     Epoch 63/500, Train Loss: 251.6606, Val Loss: 47.0739
#     Early stopping counter: 11/30
#     Epoch 64/500, Train Loss: 242.6599, Val Loss: 32.3526
#     Early stopping counter: 12/30
#     Epoch 65/500, Train Loss: 237.6408, Val Loss: 35.6782
#     Early stopping counter: 13/30
#     Epoch 66/500, Train Loss: 262.1772, Val Loss: 43.4353
#     Early stopping counter: 14/30
#     Epoch 67/500, Train Loss: 251.3409, Val Loss: 36.2981
#     Early stopping counter: 15/30
#     Epoch 68/500, Train Loss: 236.8543, Val Loss: 32.2059
#     Early stopping counter: 16/30
#     Epoch 69/500, Train Loss: 248.7540, Val Loss: 38.5103
#     Early stopping counter: 17/30
#     Epoch 70/500, Train Loss: 231.6908, Val Loss: 29.0474
#     Early stopping counter: 18/30
#     Epoch 71/500, Train Loss: 243.7112, Val Loss: 34.1896
#     Early stopping counter: 19/30
#     Epoch 72/500, Train Loss: 231.3843, Val Loss: 39.8998
#     Early stopping counter: 20/30
#     Epoch 73/500, Train Loss: 242.8964, Val Loss: 20.9393
#     Epoch 74/500, Train Loss: 237.1744, Val Loss: 20.3545
#     Epoch 75/500, Train Loss: 245.3125, Val Loss: 22.2006
#     Early stopping counter: 1/30
#     Epoch 76/500, Train Loss: 253.5783, Val Loss: 23.1611
#     Early stopping counter: 2/30
#     Epoch 77/500, Train Loss: 253.5317, Val Loss: 27.7606
#     Early stopping counter: 3/30
#     Epoch 78/500, Train Loss: 232.4223, Val Loss: 48.5304
#     Early stopping counter: 4/30
#     Epoch 79/500, Train Loss: 224.1832, Val Loss: 51.8822
#     Early stopping counter: 5/30
#     Epoch 80/500, Train Loss: 258.8940, Val Loss: 41.3005
#     Early stopping counter: 6/30
#     Epoch 81/500, Train Loss: 252.9013, Val Loss: 48.8846
#     Early stopping counter: 7/30
#     Epoch 82/500, Train Loss: 264.5066, Val Loss: 38.6406
#     Early stopping counter: 8/30
#     Epoch 83/500, Train Loss: 237.6049, Val Loss: 41.8689
#     Early stopping counter: 9/30
#     Epoch 84/500, Train Loss: 239.1698, Val Loss: 43.5574
#     Early stopping counter: 10/30
#     Epoch 85/500, Train Loss: 242.0334, Val Loss: 44.3650
#     Early stopping counter: 11/30
#     Epoch 86/500, Train Loss: 244.9992, Val Loss: 32.2110
#     Early stopping counter: 12/30
#     Epoch 87/500, Train Loss: 246.5965, Val Loss: 51.2863
#     Early stopping counter: 13/30
#     Epoch 88/500, Train Loss: 243.6936, Val Loss: 16.2714
#     Epoch 89/500, Train Loss: 236.7736, Val Loss: 49.4446
#     Early stopping counter: 1/30
#     Epoch 90/500, Train Loss: 239.2111, Val Loss: 14.0919
#     Epoch 91/500, Train Loss: 240.3823, Val Loss: 17.3335
#     Early stopping counter: 1/30
#     Epoch 92/500, Train Loss: 243.8571, Val Loss: 19.3360
#     Early stopping counter: 2/30
#     Epoch 93/500, Train Loss: 219.8011, Val Loss: 19.7056
#     Early stopping counter: 3/30
#     Epoch 94/500, Train Loss: 239.4053, Val Loss: 23.6012
#     Early stopping counter: 4/30
#     Epoch 95/500, Train Loss: 254.9685, Val Loss: 25.5732
#     Early stopping counter: 5/30
#     Epoch 96/500, Train Loss: 231.9546, Val Loss: 43.8184
#     Early stopping counter: 6/30
#     Epoch 97/500, Train Loss: 225.3087, Val Loss: 26.2490
#     Early stopping counter: 7/30
#     Epoch 98/500, Train Loss: 245.8451, Val Loss: 16.8334
#     Early stopping counter: 8/30
#     Epoch 99/500, Train Loss: 237.0277, Val Loss: 12.5499
#     Epoch 100/500, Train Loss: 233.2873, Val Loss: 24.5680
#     Early stopping counter: 1/30
#     Epoch 101/500, Train Loss: 253.1624, Val Loss: 17.7017
#     Early stopping counter: 2/30
#     Epoch 102/500, Train Loss: 229.3582, Val Loss: 28.3189
#     Early stopping counter: 3/30
#     Epoch 103/500, Train Loss: 238.9148, Val Loss: 20.8232
#     Early stopping counter: 4/30
#     Epoch 104/500, Train Loss: 223.7497, Val Loss: 22.0885
#     Early stopping counter: 5/30
#     Epoch 105/500, Train Loss: 222.3375, Val Loss: 24.9052
#     Early stopping counter: 6/30
#     Epoch 106/500, Train Loss: 248.5337, Val Loss: 16.7272
#     Early stopping counter: 7/30
#     Epoch 107/500, Train Loss: 234.5866, Val Loss: 14.3344
#     Early stopping counter: 8/30
#     Epoch 108/500, Train Loss: 212.6276, Val Loss: 12.8805
#     Early stopping counter: 9/30
#     Epoch 109/500, Train Loss: 249.0733, Val Loss: 17.5032
#     Early stopping counter: 10/30
#     Epoch 110/500, Train Loss: 222.7488, Val Loss: 19.6411
#     Early stopping counter: 11/30
#     Epoch 111/500, Train Loss: 246.4741, Val Loss: 12.4979
# ...
#     Epoch 76/500, Train Loss: 543.8371, Val Loss: 251.7582
#     Epoch 77/500, Train Loss: 635.9965, Val Loss: 249.5873
#     Epoch 78/500, Train Loss: 571.9671, Val Loss: 224.6015
#     Epoch 79/500, Train Loss: 544.2111, Val Loss: 209.3297
#     Epoch 80/500, Train Loss: 573.6137, Val Loss: 187.6070
#     Epoch 81/500, Train Loss: 543.1213, Val Loss: 171.6238
#     Epoch 82/500, Train Loss: 583.1411, Val Loss: 159.8670
#     Epoch 83/500, Train Loss: 574.3537, Val Loss: 155.4143
#     Epoch 84/500, Train Loss: 555.1708, Val Loss: 139.7641
#     Epoch 85/500, Train Loss: 553.1400, Val Loss: 136.1199
#     Epoch 86/500, Train Loss: 551.2379, Val Loss: 138.5592
#     Early stopping counter: 1/30
#     Epoch 87/500, Train Loss: 589.5767, Val Loss: 132.7303
#     Epoch 88/500, Train Loss: 558.3649, Val Loss: 139.3891
#     Early stopping counter: 1/30
#     Epoch 89/500, Train Loss: 558.8833, Val Loss: 123.1295
#     Epoch 90/500, Train Loss: 569.4364, Val Loss: 125.4179
#     Early stopping counter: 1/30
#     Epoch 91/500, Train Loss: 553.4783, Val Loss: 123.1804
#     Early stopping counter: 2/30
#     Epoch 92/500, Train Loss: 582.1186, Val Loss: 114.3102
#     Epoch 93/500, Train Loss: 564.4077, Val Loss: 119.2414
#     Early stopping counter: 1/30
#     Epoch 94/500, Train Loss: 595.3274, Val Loss: 120.6376
#     Early stopping counter: 2/30
#     Epoch 95/500, Train Loss: 562.2697, Val Loss: 106.6374
#     Epoch 96/500, Train Loss: 574.5996, Val Loss: 106.6555
#     Early stopping counter: 1/30
#     Epoch 97/500, Train Loss: 528.4554, Val Loss: 96.7090
#     Epoch 98/500, Train Loss: 572.5858, Val Loss: 97.9613
#     Early stopping counter: 1/30
#     Epoch 99/500, Train Loss: 577.4056, Val Loss: 96.0432
#     Epoch 100/500, Train Loss: 580.0713, Val Loss: 86.2501
#     Epoch 101/500, Train Loss: 575.0511, Val Loss: 120.9661
#     Early stopping counter: 1/30
#     Epoch 102/500, Train Loss: 557.3657, Val Loss: 86.0365
#     Epoch 103/500, Train Loss: 562.1752, Val Loss: 84.2380
#     Epoch 104/500, Train Loss: 552.0413, Val Loss: 83.7353
#     Epoch 105/500, Train Loss: 545.3461, Val Loss: 86.0453
#     Early stopping counter: 1/30
#     Epoch 106/500, Train Loss: 565.1819, Val Loss: 89.3496
#     Early stopping counter: 2/30
#     Epoch 107/500, Train Loss: 570.9427, Val Loss: 86.1637
#     Early stopping counter: 3/30
#     Epoch 108/500, Train Loss: 508.2478, Val Loss: 79.2958
#     Epoch 109/500, Train Loss: 532.9552, Val Loss: 120.6303
#     Early stopping counter: 1/30
#     Epoch 110/500, Train Loss: 517.5562, Val Loss: 79.3868
#     Early stopping counter: 2/30
#     Epoch 111/500, Train Loss: 559.6838, Val Loss: 83.3826
#     Early stopping counter: 3/30
#     Epoch 112/500, Train Loss: 540.6367, Val Loss: 88.2982
#     Early stopping counter: 4/30
#     Epoch 113/500, Train Loss: 559.1619, Val Loss: 78.9165
#     Epoch 114/500, Train Loss: 565.0937, Val Loss: 70.5162
#     Epoch 115/500, Train Loss: 589.8688, Val Loss: 86.2680
#     Early stopping counter: 1/30
#     Epoch 116/500, Train Loss: 567.9213, Val Loss: 70.5537
#     Early stopping counter: 2/30
#     Epoch 117/500, Train Loss: 571.8155, Val Loss: 70.0491
#     Epoch 118/500, Train Loss: 560.0959, Val Loss: 79.0690
#     Early stopping counter: 1/30
#     Epoch 119/500, Train Loss: 545.6461, Val Loss: 68.1718
#     Epoch 120/500, Train Loss: 558.1161, Val Loss: 79.3435
#     Early stopping counter: 1/30
#     Epoch 121/500, Train Loss: 562.1699, Val Loss: 77.6991
#     Early stopping counter: 2/30
#     Epoch 122/500, Train Loss: 564.1665, Val Loss: 76.9597
#     Early stopping counter: 3/30
#     Epoch 123/500, Train Loss: 577.3493, Val Loss: 70.6288
#     Early stopping counter: 4/30
#     Epoch 124/500, Train Loss: 553.6769, Val Loss: 70.2334
#     Early stopping counter: 5/30
#     Epoch 125/500, Train Loss: 567.1077, Val Loss: 69.2209
#     Early stopping counter: 6/30
#     Epoch 126/500, Train Loss: 512.7778, Val Loss: 71.7637
#     Early stopping counter: 7/30
#     Epoch 127/500, Train Loss: 581.5742, Val Loss: 63.9390
#     Epoch 128/500, Train Loss: 530.3344, Val Loss: 59.0046
#     Epoch 129/500, Train Loss: 531.8801, Val Loss: 73.2687
#     Early stopping counter: 1/30
#     Epoch 130/500, Train Loss: 548.6271, Val Loss: 63.5574
#     Early stopping counter: 2/30
#     Epoch 131/500, Train Loss: 505.0775, Val Loss: 54.7411
#     Epoch 132/500, Train Loss: 563.2836, Val Loss: 57.9181
#     Early stopping counter: 1/30
#     Epoch 133/500, Train Loss: 532.9296, Val Loss: 56.5374
#     Early stopping counter: 2/30
#     Epoch 134/500, Train Loss: 513.6966, Val Loss: 57.5647
#     Early stopping counter: 3/30
#     Epoch 135/500, Train Loss: 545.6651, Val Loss: 55.0923
#     Early stopping counter: 4/30
#     Epoch 136/500, Train Loss: 519.7920, Val Loss: 49.8840
#     Epoch 137/500, Train Loss: 517.6701, Val Loss: 50.7341
#     Early stopping counter: 1/30
#     Epoch 138/500, Train Loss: 576.7473, Val Loss: 59.4443
#     Early stopping counter: 2/30
#     Epoch 139/500, Train Loss: 509.9792, Val Loss: 55.8262
#     Early stopping counter: 3/30
#     Epoch 140/500, Train Loss: 555.3036, Val Loss: 66.4039
#     Early stopping counter: 4/30
#     Epoch 141/500, Train Loss: 559.5771, Val Loss: 72.7450
#     Early stopping counter: 5/30
#     Epoch 142/500, Train Loss: 519.3063, Val Loss: 65.7058
#     Early stopping counter: 6/30
#     Epoch 143/500, Train Loss: 567.3362, Val Loss: 60.3293
#     Early stopping counter: 7/30
#     Epoch 144/500, Train Loss: 514.9430, Val Loss: 50.6969
#     Early stopping counter: 8/30
#     Epoch 145/500, Train Loss: 560.4268, Val Loss: 78.5405
#     Early stopping counter: 9/30
#     Epoch 146/500, Train Loss: 572.0876, Val Loss: 72.7183
#     Early stopping counter: 10/30
#     Epoch 147/500, Train Loss: 572.4165, Val Loss: 73.4109
#     Early stopping counter: 11/30
#     Epoch 148/500, Train Loss: 545.6103, Val Loss: 76.6876
#     Early stopping counter: 12/30
#     Epoch 149/500, Train Loss: 554.1017, Val Loss: 68.6166
#     Early stopping counter: 13/30
#     Epoch 150/500, Train Loss: 540.7332, Val Loss: 67.0663
#     Early stopping counter: 14/30
#     Epoch 151/500, Train Loss: 546.5516, Val Loss: 68.9712
#     Early stopping counter: 15/30
#     Epoch 152/500, Train Loss: 565.5367, Val Loss: 60.1290
#     Early stopping counter: 16/30
#     Epoch 153/500, Train Loss: 487.7601, Val Loss: 55.6848
#     Early stopping counter: 17/30
#     Epoch 154/500, Train Loss: 568.9334, Val Loss: 52.3341
#     Early stopping counter: 18/30
#     Epoch 155/500, Train Loss: 535.8657, Val Loss: 45.4246
#     Epoch 156/500, Train Loss: 580.2568, Val Loss: 46.3335
#     Early stopping counter: 1/30
#     Epoch 157/500, Train Loss: 598.0715, Val Loss: 66.6267
#     Early stopping counter: 2/30
#     Epoch 158/500, Train Loss: 531.7557, Val Loss: 38.2743
#     Epoch 159/500, Train Loss: 564.8550, Val Loss: 76.5943
#     Early stopping counter: 1/30
#     Epoch 160/500, Train Loss: 552.7378, Val Loss: 38.0884
#     Epoch 161/500, Train Loss: 536.9760, Val Loss: 34.7796
#     Epoch 162/500, Train Loss: 545.9043, Val Loss: 102.7149
#     Early stopping counter: 1/30
#     Epoch 163/500, Train Loss: 510.4171, Val Loss: 37.5688
#     Early stopping counter: 2/30
#     Epoch 164/500, Train Loss: 554.6890, Val Loss: 39.0550
#     Early stopping counter: 3/30
#     Epoch 165/500, Train Loss: 566.4197, Val Loss: 68.5822
#     Early stopping counter: 4/30
#     Epoch 166/500, Train Loss: 539.1088, Val Loss: 39.3700
#     Early stopping counter: 5/30
#     Epoch 167/500, Train Loss: 542.6358, Val Loss: 35.8760
#     Early stopping counter: 6/30
#     Epoch 168/500, Train Loss: 547.9590, Val Loss: 34.9862
#     Early stopping counter: 7/30
#     Epoch 169/500, Train Loss: 532.9065, Val Loss: 43.1843
#     Early stopping counter: 8/30
#     Epoch 170/500, Train Loss: 511.9269, Val Loss: 36.7016
#     Early stopping counter: 9/30
#     Epoch 171/500, Train Loss: 515.4119, Val Loss: 35.8859
#     Early stopping counter: 10/30
#     Epoch 172/500, Train Loss: 488.8291, Val Loss: 35.2028
#     Early stopping counter: 11/30
#     Epoch 173/500, Train Loss: 565.4392, Val Loss: 52.5643
#     Early stopping counter: 12/30
#     Epoch 174/500, Train Loss: 552.2077, Val Loss: 64.7402
#     Early stopping counter: 13/30
#     Epoch 175/500, Train Loss: 545.1254, Val Loss: 38.7190
#     Early stopping counter: 14/30
#     Epoch 176/500, Train Loss: 535.0312, Val Loss: 43.0969
#     Early stopping counter: 15/30
#     Epoch 177/500, Train Loss: 569.9777, Val Loss: 57.3528
#     Early stopping counter: 16/30
#     Epoch 178/500, Train Loss: 534.8950, Val Loss: 83.0897
#     Early stopping counter: 17/30
#     Epoch 179/500, Train Loss: 519.9492, Val Loss: 67.4341
#     Early stopping counter: 18/30
#     Epoch 180/500, Train Loss: 611.4924, Val Loss: 69.3338
#     Early stopping counter: 19/30
#     Epoch 181/500, Train Loss: 556.2662, Val Loss: 71.2333
#     Early stopping counter: 20/30
#     Epoch 182/500, Train Loss: 499.0600, Val Loss: 49.9720
#     Early stopping counter: 21/30
#     Epoch 183/500, Train Loss: 549.8952, Val Loss: 59.5504
#     Early stopping counter: 22/30
#     Epoch 184/500, Train Loss: 517.0445, Val Loss: 49.0725
#     Early stopping counter: 23/30
#     Epoch 185/500, Train Loss: 514.5846, Val Loss: 66.4439
#     Early stopping counter: 24/30
#     Epoch 186/500, Train Loss: 572.7277, Val Loss: 63.8025
#     Early stopping counter: 25/30
#     Epoch 187/500, Train Loss: 557.9537, Val Loss: 73.3252
#     Early stopping counter: 26/30
#     Epoch 188/500, Train Loss: 533.1537, Val Loss: 63.5570
#     Early stopping counter: 27/30
#     Epoch 189/500, Train Loss: 569.1985, Val Loss: 62.5197
#     Early stopping counter: 28/30
#     Epoch 190/500, Train Loss: 508.5814, Val Loss: 46.2980
#     Early stopping counter: 29/30
#     Epoch 191/500, Train Loss: 539.7680, Val Loss: 34.9671
#     Early stopping counter: 30/30
#     Early stopping triggered.
#   Repeat 5/5
#     Epoch 1/500, Train Loss: 6780.5699, Val Loss: 10735.9919
#     Epoch 2/500, Train Loss: 6781.9854, Val Loss: 10725.8857
#     Epoch 3/500, Train Loss: 6765.0809, Val Loss: 10695.8997
#     Epoch 4/500, Train Loss: 6712.5840, Val Loss: 10552.8096
#     Epoch 5/500, Train Loss: 6582.2608, Val Loss: 10380.7354
#     Epoch 6/500, Train Loss: 6447.0100, Val Loss: 10171.2795
#     Epoch 7/500, Train Loss: 6256.7161, Val Loss: 9929.8616
#     Epoch 8/500, Train Loss: 6056.7752, Val Loss: 9651.7095
#     Epoch 9/500, Train Loss: 5846.0425, Val Loss: 9340.8831
#     Epoch 10/500, Train Loss: 5549.9396, Val Loss: 8991.7258
#     Epoch 11/500, Train Loss: 5293.9073, Val Loss: 8609.8279
#     Epoch 12/500, Train Loss: 5006.6523, Val Loss: 8199.7841
#     Epoch 13/500, Train Loss: 4700.8593, Val Loss: 7761.6191
#     Epoch 14/500, Train Loss: 4343.0817, Val Loss: 7300.1543
#     Epoch 15/500, Train Loss: 4031.8516, Val Loss: 6813.7372
#     Epoch 16/500, Train Loss: 3697.9871, Val Loss: 6320.5857
#     Epoch 17/500, Train Loss: 3383.8005, Val Loss: 5823.5533
#     Epoch 18/500, Train Loss: 3055.6614, Val Loss: 5317.1365
#     Epoch 19/500, Train Loss: 2711.3353, Val Loss: 4797.4459
#     Epoch 20/500, Train Loss: 2392.8709, Val Loss: 4288.8812
#     Epoch 21/500, Train Loss: 2070.8735, Val Loss: 3804.2264
#     Epoch 22/500, Train Loss: 1808.5688, Val Loss: 3350.5543
#     Epoch 23/500, Train Loss: 1603.1281, Val Loss: 2931.1715
#     Epoch 24/500, Train Loss: 1422.0257, Val Loss: 2565.7465
#     Epoch 25/500, Train Loss: 1237.9251, Val Loss: 2242.9097
#     Epoch 26/500, Train Loss: 1131.2634, Val Loss: 1971.7257
#     Epoch 27/500, Train Loss: 991.4826, Val Loss: 1748.9417
#     Epoch 28/500, Train Loss: 930.9436, Val Loss: 1565.7449
#     Epoch 29/500, Train Loss: 899.9812, Val Loss: 1409.7976
#     Epoch 30/500, Train Loss: 859.8395, Val Loss: 1284.8824
#     Epoch 31/500, Train Loss: 880.0530, Val Loss: 1188.5889
#     Epoch 32/500, Train Loss: 830.6647, Val Loss: 1123.8074
#     Epoch 33/500, Train Loss: 810.8281, Val Loss: 1071.0428
#     Epoch 34/500, Train Loss: 813.9581, Val Loss: 1030.8495
#     Epoch 35/500, Train Loss: 835.2593, Val Loss: 993.4052
#     Epoch 36/500, Train Loss: 846.0411, Val Loss: 947.9603
#     Epoch 37/500, Train Loss: 788.4184, Val Loss: 916.1489
#     Epoch 38/500, Train Loss: 817.5598, Val Loss: 896.8717
#     Epoch 39/500, Train Loss: 796.7343, Val Loss: 897.4999
#     Early stopping counter: 1/30
#     Epoch 40/500, Train Loss: 790.2466, Val Loss: 882.1628
#     Epoch 41/500, Train Loss: 811.1807, Val Loss: 876.6904
#     Epoch 42/500, Train Loss: 800.3116, Val Loss: 885.9214
#     Early stopping counter: 1/30
#     Epoch 43/500, Train Loss: 838.2108, Val Loss: 891.1937
#     Early stopping counter: 2/30
#     Epoch 44/500, Train Loss: 792.0307, Val Loss: 895.8419
#     Early stopping counter: 3/30
#     Epoch 45/500, Train Loss: 820.5354, Val Loss: 889.1470
#     Early stopping counter: 4/30
#     Epoch 46/500, Train Loss: 792.0841, Val Loss: 893.2592
#     Early stopping counter: 5/30
#     Epoch 47/500, Train Loss: 823.1917, Val Loss: 889.7301
#     Early stopping counter: 6/30
#     Epoch 48/500, Train Loss: 805.9050, Val Loss: 892.4056
#     Early stopping counter: 7/30
#     Epoch 49/500, Train Loss: 830.1048, Val Loss: 917.3607
#     Early stopping counter: 8/30
#     Epoch 50/500, Train Loss: 775.5446, Val Loss: 924.9760
#     Early stopping counter: 9/30
#     Epoch 51/500, Train Loss: 807.4725, Val Loss: 910.4733
#     Early stopping counter: 10/30
#     Epoch 52/500, Train Loss: 771.0774, Val Loss: 915.5872
#     Early stopping counter: 11/30
#     Epoch 53/500, Train Loss: 789.2419, Val Loss: 898.0287
#     Early stopping counter: 12/30
#     Epoch 54/500, Train Loss: 782.3885, Val Loss: 903.6082
#     Early stopping counter: 13/30
#     Epoch 55/500, Train Loss: 809.8438, Val Loss: 908.2713
#     Early stopping counter: 14/30
#     Epoch 56/500, Train Loss: 813.4368, Val Loss: 913.3735
#     Early stopping counter: 15/30
#     Epoch 57/500, Train Loss: 815.7616, Val Loss: 934.0093
#     Early stopping counter: 16/30
#     Epoch 58/500, Train Loss: 802.4624, Val Loss: 938.8662
#     Early stopping counter: 17/30
#     Epoch 59/500, Train Loss: 790.9035, Val Loss: 927.3087
#     Early stopping counter: 18/30
#     Epoch 60/500, Train Loss: 788.9925, Val Loss: 913.0939
#     Early stopping counter: 19/30
#     Epoch 61/500, Train Loss: 736.8220, Val Loss: 902.4923
#     Early stopping counter: 20/30
#     Epoch 62/500, Train Loss: 773.4533, Val Loss: 877.1687
#     Early stopping counter: 21/30
#     Epoch 63/500, Train Loss: 747.3465, Val Loss: 882.1587
#     Early stopping counter: 22/30
#     Epoch 64/500, Train Loss: 737.5403, Val Loss: 882.7537
#     Early stopping counter: 23/30
#     Epoch 65/500, Train Loss: 756.8579, Val Loss: 890.8159
#     Early stopping counter: 24/30
#     Epoch 66/500, Train Loss: 775.8827, Val Loss: 886.4136
#     Early stopping counter: 25/30
#     Epoch 67/500, Train Loss: 750.3085, Val Loss: 903.5199
#     Early stopping counter: 26/30
#     Epoch 68/500, Train Loss: 777.8159, Val Loss: 903.7405
#     Early stopping counter: 27/30
#     Epoch 69/500, Train Loss: 775.7193, Val Loss: 916.4600
#     Early stopping counter: 28/30
#     Epoch 70/500, Train Loss: 816.8010, Val Loss: 918.1626
#     Early stopping counter: 29/30
#     Epoch 71/500, Train Loss: 791.7659, Val Loss: 966.5845
#     Early stopping counter: 30/30
#     Early stopping triggered.
# Average Validation Loss for this combination: 201.0275
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-30-c25fc1c0475f> in <cell line: 0>()
#      93
#      94 # Load the best model
# ---> 95 model.load_state_dict(best_model)
#      96 print(f"Best model parameters: {best_params}")
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in load_state_dict(self, state_dict, strict, assign)
#    2582
#    2583         if len(error_msgs) > 0:
# -> 2584             raise RuntimeError(
#    2585                 "Error(s) in loading state_dict for {}:\n\t{}".format(
#    2586                     self.__class__.__name__, "\n\t".join(error_msgs)
#
# RuntimeError: Error(s) in loading state_dict for ComplexLSTMModel:
# 	Missing key(s) in state_dict: "lstm.weight_ih_l2", "lstm.weight_hh_l2", "lstm.bias_ih_l2", "lstm.bias_hh_l2", "lstm.weight_ih_l3", "lstm.weight_hh_l3", "lstm.bias_ih_l3", "lstm.bias_hh_l3".

# %%
best_params
# Out:
# (128, 2, 0.1, 0.0001, 30)

# %%
print("Best params at hidden size 128, 2 layers, dropout rate 0.1, learning rate 0.0001, patience 30")
# Out:
# Best params at hidden size 128, 2 layers, dropout rate 0.1, learning rate 0.0001, patience 30
