# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
from numpy.linalg import norm

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# Load the data
file_path = "../SPY_section_3.csv"
df = pd.read_csv(file_path)

# %%
# Define Autoencoder
class Autoencoder(nn.Module):
    def __init__(self, input_dim, encoding_dim, dropout_rate):
        super(Autoencoder, self).__init__()
        self.encoder = nn.Sequential(
            nn.Linear(input_dim, 128),
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.Linear(64, encoding_dim)
        )
        self.decoder = nn.Sequential(
            nn.Linear(encoding_dim, 64),
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.Linear(64, 128),
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.Linear(128, input_dim)
        )
    
    def forward(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return decoded

# %%
# Define LSTM model
class ComplexLSTMModel(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, dropout_rate):
        super(ComplexLSTMModel, self).__init__()
        # Unidirectional LSTM for sequential stock price prediction
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers,
                            batch_first=True, dropout=dropout_rate)  # Removed bidirectional=True

        # Fully connected layers for added complexity
        self.fc1 = nn.Linear(hidden_size, hidden_size // 2)
        self.dropout1 = nn.Dropout(dropout_rate)
        self.fc2 = nn.Linear(hidden_size // 2, hidden_size // 4)
        self.dropout2 = nn.Dropout(dropout_rate)
        self.fc3 = nn.Linear(hidden_size // 4, 1)

    def forward(self, x):
        # LSTM expects input of shape (batch_size, sequence_length, input_size)
        out, _ = self.lstm(x)
        # Use the output of the last time step
        out = out[:, -1, :]  # Shape: (batch_size, hidden_size)

        out = torch.relu(self.fc1(out))  # First fully connected layer
        out = self.dropout1(out)
        out = torch.relu(self.fc2(out))  # Second fully connected layer
        out = self.dropout2(out)
        out = self.fc3(out)  # Output layer (no activation for regression)
        return out
    
    
sequence_length = 10

# Reshape data into sequences
def create_sequences(data, target, seq_length):
    X_seq, y_seq = [], []
    for i in range(len(data) - seq_length):
        X_seq.append(data[i:i + seq_length])
        y_seq.append(target[i + seq_length])
    return np.array(X_seq), np.array(y_seq)

# %%
# Define the target variable
if "Target" not in df.columns:
    # df["Target"] = (df["Close"].shift(-1) > df["Close"]).astype(int)
    df["Target"] = df["Close"].shift(-1)
df = df.dropna()

# %%
# Adding SMA and EMA to the feature
short_term_period = 20
medium_term_period = 50
long_term_period = 200

# Compute the SMAs
df['SMA_20'] = df['Close'].rolling(window=short_term_period).mean() # Short-term SMA
df['SMA_50'] = df['Close'].rolling(window=medium_term_period).mean() # Medium-term SMA
df['SMA_200'] = df['Close'].rolling(window=long_term_period).mean() # Long-term SMA

df['EMA_10'] = df['Close'].ewm(span=10, adjust=False).mean()  # Short-term EMA
df['EMA_50'] = df['Close'].ewm(span=50, adjust=False).mean()  # Medium-term EMA
df['EMA_200'] = df['Close'].ewm(span=200, adjust=False).mean()  # Long-term EMA

df = df.dropna()

# %%
X = df.drop(columns=["Date", "Target"])
y = df["Target"]

feature_columns = ["Open", "High", "Low", "Close", "Volume", "SMA_20", "SMA_50", "SMA_200", "EMA_10", "EMA_50", "EMA_200"]

train_size = int(X.shape[0] * 0.7)
val_size = int(X.shape[0] * 0.15)

scaler = MinMaxScaler()

# Split data into train, validation, and test
temp_train = X[:train_size]
temp_val = X[train_size:train_size + val_size]
temp_test = X[train_size + val_size:]

temp_train = temp_train[feature_columns]
temp_val = temp_val[feature_columns]
temp_test = temp_test[feature_columns]

# Fit and transform for train, transform for validation and test
temp_train = scaler.fit_transform(temp_train)
temp_val = scaler.transform(temp_val)
temp_test = scaler.transform(temp_test)

# Convert NumPy arrays back to DataFrames
temp_train = pd.DataFrame(temp_train, columns=feature_columns)
temp_val = pd.DataFrame(temp_val, columns=feature_columns)
temp_test = pd.DataFrame(temp_test, columns=feature_columns)

# Concatenate the data
X_scaled = pd.concat([temp_train, temp_val, temp_test], axis=0)

X_seq, y_seq = create_sequences(X_scaled, y.values, sequence_length)

# Split sequentially
X_train, y_train = X_seq[:train_size], y_seq[:train_size]
X_val, y_val = X_seq[train_size:train_size + val_size], y_seq[train_size:train_size + val_size]
X_test, y_test = X_seq[train_size + val_size:], y_seq[train_size + val_size:]

# Print sizes to confirm
print(f"Train: {len(X_train)}, Val: {len(X_val)}, Test: {len(X_test)}")
print(X_scaled.shape)
# Out:
# Train: 1768, Val: 379, Test: 370
# (2527, 11)

# %%
# Convert to PyTorch tensors
X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train, dtype=torch.float32)
X_val_tensor = torch.tensor(X_val, dtype=torch.float32)
y_val_tensor = torch.tensor(y_val, dtype=torch.float32)
X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test, dtype=torch.float32)

# Create DataLoaders
train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
val_dataset = TensorDataset(X_val_tensor, y_val_tensor)
test_dataset = TensorDataset(X_test_tensor, y_test_tensor)

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=64, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

# %% [markdown]
# <span style="color: yellow; font-size: 40px;">Evaluating original LSTM</span>

# %%
# Hyperparameters
input_size = X_train.shape[2]  # Number of features
hidden_size = 128
num_layers = 2
dropout_rate = 0.1
learning_rate = 0.0005
num_epochs = 500
patience = 30

# %%
# Define paths
LSTM_model_path = "../lstm_codes/lstm_models/lstm_section_3.pth"  # Change this to your specific model file

# Load the trained model
LSTM_model = ComplexLSTMModel(input_size=input_size, hidden_size=hidden_size, num_layers=num_layers, dropout_rate=dropout_rate).to(device)
LSTM_model.load_state_dict(torch.load(LSTM_model_path))
LSTM_model.eval()

# Define loss function
criterion = torch.nn.MSELoss()

# Evaluate on test data
test_loss = 0.0
test_mae = 0.0
all_true = []
all_preds = []

with torch.no_grad():
    for X_batch, y_batch in test_loader:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)
        outputs = LSTM_model(X_batch)
        loss = criterion(outputs, y_batch)
        mae = torch.mean(torch.abs(outputs - y_batch))
        
        test_loss += loss.item() * X_batch.size(0)
        test_mae += mae.item() * X_batch.size(0)
        
        all_true.extend(y_batch.cpu().numpy())
        all_preds.extend(outputs.cpu().numpy())

# Compute final metrics
test_loss /= len(test_loader.dataset)
test_mae /= len(test_loader.dataset)

# Compute error percentages
all_true = np.array(all_true).flatten()
all_preds = np.array(all_preds).flatten()
error = np.abs(all_true - all_preds) / (np.abs(all_true) + 1e-8)
avg_error = np.mean(error) * 100
largest_error = np.max(error) * 100

# Print results
print("\n===== Evaluation Results =====")
print(f"Test Loss: {test_loss:.4f}")
print(f"Test MAE: {test_mae:.4f}")
print(f"Average Error Percentage: {avg_error:.2f}%")
print(f"Largest Error Percentage: {largest_error:.2f}%")

# Plot actual vs predicted values
plt.figure(figsize=(10, 5))
plt.plot(all_true, label='True Values', color='blue')
plt.plot(all_preds, label='Predicted Values', color='red')
plt.xlabel('Time')
plt.ylabel('Value')
plt.title('Actual vs. Predicted Values')
plt.legend()
plt.show()
# Out:
# You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# Using a target size (torch.Size([64])) that is different to the input size (torch.Size([64, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
# Using a target size (torch.Size([50])) that is different to the input size (torch.Size([50, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
# ===== Evaluation Results =====
# Test Loss: 1275.9282
# Test MAE: 30.6079
# Average Error Percentage: 10.94%
# Largest Error Percentage: 23.87%

# %% [markdown]
# <span style="color: yellow; font-size: 40px;">Evaluating original autoencoder</span>

# %%
X_train = X_scaled[:train_size]
X_val = X_scaled[train_size:train_size + val_size]
X_test = X_scaled[train_size + val_size:]

# %%
X_train = X_train.values
X_val = X_val.values
X_test = X_test.values

# %%
# Convert data to PyTorch tensors
X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
X_val_tensor = torch.tensor(X_val, dtype=torch.float32)
X_test_tensor = torch.tensor(X_test, dtype=torch.float32)

# Create DataLoader
train_dataset = TensorDataset(X_train_tensor, X_train_tensor)
val_dataset = TensorDataset(X_val_tensor, X_val_tensor)
test_dataset = TensorDataset(X_test_tensor, X_test_tensor)
train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=16, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=16, shuffle=False)

# %%
input_dim = X_train.shape[1]

# Hyperparameters
encoding_dim = 5
learning_rate = 0.0005
dropout_rate = 0.3
epochs = 750
batch_size = 16
patience = 40

# %%
autoencoder_model_path = "../autoencoder_codes/autoencoder_models/autoencoder_section_3.pth"
autoencoder_model = Autoencoder(input_dim=input_dim, encoding_dim=encoding_dim, dropout_rate=dropout_rate).to(device)
autoencoder_model.load_state_dict(torch.load(autoencoder_model_path))
# Out:
# You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# <All keys matched successfully>

# %%
autoencoder_model.eval()
with torch.no_grad():
    reconstructed_test = autoencoder_model(torch.tensor(X_test, dtype=torch.float32).to(device)).cpu().numpy()
mse = np.mean((X_test - reconstructed_test) ** 2)
mae = np.mean(np.abs(X_test - reconstructed_test))
ree = np.mean(np.linalg.norm(X_test - reconstructed_test, axis=1) / np.linalg.norm(X_test, axis=1))
euclidean_dist = np.mean([norm(X_test[i] - reconstructed_test[i]) for i in range(len(X_test))])
reconstruction_error_percentage = (
    np.mean(np.abs(X_test - reconstructed_test) / (np.abs(X_test) + 1e-8), axis=1) * 100
)
average_error = np.mean(reconstruction_error_percentage)
print(f'MSE: {mse:.4f}, MAE: {mae:.4f}, REE: {ree:.4f}, Euclidean Distance: {euclidean_dist:.4f}, Average Error: {average_error:.4f}%')
# Out:
# MSE: 0.0052, MAE: 0.0563, REE: 0.0482, Euclidean Distance: 0.2232, Average Error: 38.4449%

# %%
# Scatter plot of reconstruction error percentage
plt.figure(figsize=(10, 5))
plt.scatter(range(len(reconstruction_error_percentage)), reconstruction_error_percentage, alpha=0.5)
plt.ylim(0, 50)
plt.xlabel('Sample')
plt.ylabel('Reconstruction Error Percentage')
plt.title('Reconstruction Error Percentage')
plt.show()

# %% [markdown]
# <span style="color: yellow; font-size: 40px;">Bias correction model - single input</span>

# %%
# import torch
# import torch.nn as nn
# import torch.nn.functional as F

# class BiasPredictor(nn.Module):
#     def __init__(self, input_size, hidden_size1, dropout_rate):
#         super(BiasPredictor, self).__init__()
        
#         hidden_size2 = hidden_size1 // 2
#         hidden_size3 = hidden_size2 // 2
#         hidden_size4 = hidden_size3 // 2  # New additional layer

#         self.fc1 = nn.Linear(input_size, hidden_size1)
#         self.dropout1 = nn.Dropout(dropout_rate)
        
#         self.fc2 = nn.Linear(hidden_size1, hidden_size2)
#         self.dropout2 = nn.Dropout(dropout_rate)
        
#         self.fc3 = nn.Linear(hidden_size2, hidden_size3)
#         self.dropout3 = nn.Dropout(dropout_rate)

#         self.fc4 = nn.Linear(hidden_size3, hidden_size4)  # New additional layer
#         self.dropout4 = nn.Dropout(dropout_rate)

#         self.fc5 = nn.Linear(hidden_size4, 1)  # Final output layer

#     def forward(self, x):
#         x = F.relu(self.fc1(x))
#         x = self.dropout1(x)
        
#         x = F.relu(self.fc2(x))
#         x = self.dropout2(x)
        
#         x = F.relu(self.fc3(x))
#         x = self.dropout3(x)

#         x = F.relu(self.fc4(x))  # New layer
#         x = self.dropout4(x)

#         return self.fc5(x)



import torch
import torch.nn as nn
import torch.nn.functional as F

class BiasPredictor(nn.Module):
    def __init__(self, input_size, hidden_size, dropout_rate):
        super(BiasPredictor, self).__init__()

        hidden_size2 = hidden_size // 2

        # Define layers
        self.fc1 = nn.Linear(input_size, hidden_size)
        self.dropout1 = nn.Dropout(dropout_rate)

        self.fc2 = nn.Linear(hidden_size, hidden_size2)
        self.dropout2 = nn.Dropout(dropout_rate)

        self.fc3 = nn.Linear(hidden_size2, 1) 

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = self.dropout1(x)

        x = F.relu(self.fc2(x))
        x = self.dropout2(x)

        return self.fc3(x)

# %%
# Get LSTM predictions of entire dataset
with torch.no_grad():
    X_tensor = torch.tensor(X_seq, dtype=torch.float32).to(device)
    LSTM_preds = LSTM_model(X_tensor).cpu().numpy()
    
# Put LSTM predictions into a new DataFrame
new_df = pd.DataFrame(LSTM_preds, columns=["LSTM_Pred"])

# %%
# Drop the first sequence_length rows
temp_y = y
temp_y = temp_y[sequence_length:]

# add the target variable to the new DataFrame
new_df["Target"] = temp_y.values

# %%
# Get reconstruction error percentage for the entire dataset
autoencoder_model.eval()
with torch.no_grad():
    reconstructed = autoencoder_model(torch.tensor(X_scaled.values, dtype=torch.float32).to(device)).cpu().numpy()
    
# Compute the MAE
reconstruction_error = np.mean(np.abs(X_scaled.values - reconstructed), axis=1)

# Compute the reconstruction error percentage
# reconstruction_error = np.mean(np.abs(X_scaled.values - reconstructed) / (np.abs(X_scaled.values) + 1e-8), axis=1) * 100
# reconstruction_error = np.mean((X_scaled.values - reconstructed) / ((X_scaled.values) + 1e-8), axis=1) * 100

# Drop the first sequence_length rows
reconstruction_error_new = reconstruction_error[sequence_length:]

# Add the reconstruction error to the new DataFrame
new_df["Reconstruction_error_single"] = reconstruction_error_new

# Get reconstruction error arr of past 10 days
reconstruction_error_arr = []
for i in range(sequence_length, len(reconstruction_error)):
    reconstruction_error_arr.append(reconstruction_error[i - sequence_length:i])
    

# Add the reconstruction error array to the new DataFrame
new_df["Reconstruction_error_arr"] = reconstruction_error_arr

# %%
# plot reconstruction error scatter plot
plt.figure(figsize=(10, 5))
plt.scatter(range(len(reconstruction_error)), reconstruction_error, alpha=0.5)
plt.ylim(0, 0.5)
plt.xlabel('Sample')
# plt.ylabel('Reconstruction Error Percentage')
# plt.title('Reconstruction Error Percentage')
plt.ylabel('Reconstruction Error MAE')
plt.title('Reconstruction Error MAE')
plt.show()

# %%
reconstruction_error_arr[0]
# Out:
# array([0.01112294, 0.01061798, 0.01121775, 0.01175785, 0.01235987,
#        0.01201896, 0.01181609, 0.00948298, 0.00851218, 0.0115408 ])

# %%
# Calculate the difference between the target and LSTM prediction
new_df["Bias"] = new_df["Target"] - new_df["LSTM_Pred"]

# %%
y = new_df["Bias"]
X = new_df["Reconstruction_error_single"]
# X = new_df["Reconstruction_error_arr"]

# %%
# Sequential split
train_size = int(0.7 * len(X))
val_size = int(0.15 * len(X))

X_train_raw = X[:train_size]
y_train_raw = y[:train_size]
X_val_raw = X[train_size:train_size + val_size]
y_val_raw = y[train_size:train_size + val_size]
X_test_raw = X[train_size + val_size:]
y_test_raw = y[train_size + val_size:]

# Scale using StandardScaler (fit only on train data)
# X_scaler = StandardScaler()
X_scaler = RobustScaler()
X_train_scaled = X_scaler.fit_transform(X_train_raw.values.reshape(-1, 1))
X_val_scaled = X_scaler.transform(X_val_raw.values.reshape(-1, 1))
X_test_scaled = X_scaler.transform(X_test_raw.values.reshape(-1, 1))

# y_scaler = StandardScaler()
y_scaler = RobustScaler()
y_train_scaled = y_scaler.fit_transform(y_train_raw.values.reshape(-1, 1))
y_val_scaled = y_scaler.transform(y_val_raw.values.reshape(-1, 1))
y_test_scaled = y_scaler.transform(y_test_raw.values.reshape(-1, 1))

# Convert data to PyTorch tensors
X_train = torch.tensor(X_train_scaled, dtype=torch.float32).unsqueeze(1)
y_train = torch.tensor(y_train_scaled, dtype=torch.float32).unsqueeze(1)
X_val = torch.tensor(X_val_scaled, dtype=torch.float32).unsqueeze(1)
y_val = torch.tensor(y_val_scaled, dtype=torch.float32).unsqueeze(1)
X_test = torch.tensor(X_test_scaled, dtype=torch.float32).unsqueeze(1)
y_test = torch.tensor(y_test_scaled, dtype=torch.float32).unsqueeze(1)

# Print sizes
print(f"Train: {len(X_train)}, Val: {len(X_val)}, Test: {len(X_test)}")
# Out:
# Train: 1761, Val: 377, Test: 379

# %%
# Create DataLoader
train_dataset = TensorDataset(X_train, y_train)
val_dataset = TensorDataset(X_val, y_val)
test_dataset = TensorDataset(X_test, y_test)
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import os
from torch.utils.data import DataLoader, TensorDataset

# Directory to save the models
save_dir = "uni_input_trials"
os.makedirs(save_dir, exist_ok=True)

# Number of trials
num_trials = 10

# Training parameters
input_size = 1
hidden_size = 16
dropout_rate = 0.2
learning_rate = 0.0001
num_epochs = 500
patience = 20

bias_model = BiasPredictor(input_size=input_size, hidden_size=hidden_size, dropout_rate=dropout_rate).to(device)

#load model
bias_model.load_state_dict(torch.load("./models/bias_model_uni_input_section_3.pth"))

bias_model.eval()

with torch.no_grad():
    combined_X = torch.cat((X_train, X_val, X_test), dim=0).to(device)
    y_pred = bias_model(combined_X).cpu().numpy()
    
outputs_unscaled = y_scaler.inverse_transform(y_pred.reshape(y_pred.shape[0], -1))


# # To store predictions for each trial
# all_predictions = {}

# for trial in range(num_trials):
#     print(f"Starting trial {trial + 1}/{num_trials}")

#     # Initialize model, loss function, and optimizer
#     bias_model = BiasPredictor(input_size=input_size, hidden_size=hidden_size, dropout_rate=dropout_rate).to(device)
#     criterion = nn.MSELoss()
#     optimizer = optim.Adam(bias_model.parameters(), lr=learning_rate)

#     best_val_loss = np.inf
#     best_epoch = 0
#     best_model_state = None  # Store best model state

#     # Training loop
#     for epoch in range(num_epochs):
#         bias_model.train()
#         train_loss = 0.0
#         for X_batch, y_batch in train_loader:
#             X_batch, y_batch = X_batch.to(device), y_batch.to(device)
#             optimizer.zero_grad()
#             outputs = bias_model(X_batch)
#             loss = criterion(outputs, y_batch)
#             loss.backward()
#             optimizer.step()
#             train_loss += loss.item() * X_batch.size(0)

#         train_loss /= len(train_loader.dataset)

#         # Validation loop
#         bias_model.eval()
#         val_loss = 0.0
#         with torch.no_grad():
#             for X_batch, y_batch in val_loader:
#                 X_batch, y_batch = X_batch.to(device), y_batch.to(device)
#                 outputs = bias_model(X_batch)
#                 loss = criterion(outputs, y_batch)
#                 val_loss += loss.item() * X_batch.size(0)

#         val_loss /= len(val_loader.dataset)

#         if val_loss < best_val_loss:
#             best_val_loss = val_loss
#             best_epoch = epoch
#             best_model_state = bias_model.state_dict()  # Save the best model state

#         elif epoch - best_epoch >= patience:
#             print(f"Trial {trial + 1}: Stopping early at epoch {epoch}")
#             break

#         print(f"Trial {trial + 1}, Epoch {epoch}, Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}")

#     # Save the best model from this trial
#     if best_model_state is not None:
#         model_filename = os.path.join(save_dir, f"bias_model_trial_{trial + 1}.pth")
#         torch.save(best_model_state, model_filename)
#         print(f"Saved model for Trial {trial + 1} to {model_filename}")

#         # Load best model and generate predictions
#         bias_model.load_state_dict(best_model_state)
#         bias_model.eval()
        
#         with torch.no_grad():
#             combined_X = torch.cat((X_train, X_val, X_test), dim=0).to(device)
#             y_pred = bias_model(combined_X).cpu().numpy()

#         outputs_unscaled = y_scaler.inverse_transform(y_pred.reshape(y_pred.shape[0], -1))
        
#         # Store predictions for this trial
#         all_predictions[f"trial_{trial + 1}"] = outputs_unscaled

# print("Completed all trials and saved models & predictions!")
# Out:
# You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.

# %%
# concat y values of train test and val 
combined_y = torch.cat((y_train, y_val, y_test), dim=0)
combined_y = combined_y.cpu().numpy()

# %%
# Create empty DataFrame
temp_df = pd.DataFrame()

temp_df["bias_model_uni_prediction"] = outputs_unscaled.flatten()

# %%
temp_df["LSTM_prediction_original"] = new_df["LSTM_Pred"]
temp_df["Target"] = new_df["Target"]
temp_df["New_predictions_uni"] = new_df["LSTM_Pred"] + temp_df["bias_model_uni_prediction"]

# %%
# plot graph of lstm prediction vs new predictions
plt.figure(figsize=(20, 10))
plt.plot(temp_df["New_predictions_uni"].iloc[train_size+val_size:], label='New predicted values', color='blue')
plt.plot(temp_df["LSTM_prediction_original"].iloc[train_size+val_size:], label='Original predicted values', color='red')
plt.plot(temp_df["Target"].iloc[train_size+val_size:], label='True Values', color='green')
plt.xlabel('Time')
plt.ylabel('Value')
plt.title('Actual vs. Predicted Values')
plt.legend()
plt.show()

# %%
original_LSTM_error_percent = np.mean(np.abs(temp_df["Target"].iloc[train_size+val_size:].values - temp_df["LSTM_prediction_original"].iloc[train_size+val_size:].values) / (np.abs(temp_df["Target"].iloc[train_size+val_size:].values) + 1e-8)) * 100
new_LSTM_error_percent = np.mean(np.abs(temp_df["Target"].iloc[train_size+val_size:].values - temp_df["New_predictions_uni"].iloc[train_size+val_size:].values) / (np.abs(temp_df["Target"].iloc[train_size+val_size:].values) + 1e-8)) * 100

print(f"Original LSTM Error Percentage: {original_LSTM_error_percent:.4f}%")
print(f"New LSTM Error Percentage: {new_LSTM_error_percent:.4f}%")
# Out:
# Original LSTM Error Percentage: 10.7707%
# New LSTM Error Percentage: 10.4422%

# %% [markdown]
# <span style="color: yellow; font-size: 40px;">Bias correction model - multi input</span>

# %%
temp_df
# Out:
#       bias_model_uni_prediction  LSTM_prediction_original      Target  \
# 0                      2.592185                 87.154686   92.040123
# 1                      2.373617                 87.266373   89.875847
# 2                      2.701494                 87.720535   89.340523
# 3                      2.434641                 86.771088   86.373199
# 4                      2.107985                 85.992126   85.088394
# ...                         ...                       ...         ...
# 2512                   0.115546                238.381989  264.779175
# 2513                   0.276087                238.427292  268.596954
# 2514                   0.290529                238.467728  267.361877
# 2515                   0.053551                238.517731  274.360992
# 2516                  -0.224087                238.558563  271.806519
#
#       New_predictions_uni
# 0               89.746872
# 1               89.639992
# 2               90.422028
# 3               89.205727
# 4               88.100113
# ...                   ...
# 2512           238.497528
# 2513           238.703384
# 2514           238.758255
# 2515           238.571289
# 2516           238.334473
#
# [2517 rows x 4 columns]

# %%
X_train_scaled_df = pd.DataFrame(X_train_scaled, columns=["Reconstruction_error"])
X_val_scaled_df = pd.DataFrame(X_val_scaled, columns=["Reconstruction_error"])
X_test_scaled_df = pd.DataFrame(X_test_scaled, columns=["Reconstruction_error"])

combined_X_df = pd.concat([X_train_scaled_df, X_val_scaled_df, X_test_scaled_df], axis=0)
combined_X_df
# Out:
#      Reconstruction_error
# 0               -0.448675
# 1               -0.049611
# 2               -0.595218
# 3               -0.164389
# 4                1.139522
# ..                    ...
# 374             13.805304
# 375             12.783022
# 376             12.691058
# 377             14.200071
# 378             15.967995
#
# [2517 rows x 1 columns]

# %%
combined_X_df['Reconstruction_error_array'] = np.nan

# Fill the new column with arrays of the past 10 reconstruction errors
# for i in range(len(combined_X_df)):
#     if i >= 9:
#         combined_X_df.at[i, 'reconstruction_error_array'] = combined_X_df['Reconstruction_error'][i-9:i+1].tolist()

reconstruction_error_arrays = []
for i in range(len(combined_X_df)):
    if i >= 9:
        reconstruction_error_arrays.append(combined_X_df['Reconstruction_error'][i-9:i+1].tolist())
    else:
        reconstruction_error_arrays.append(np.nan)  # Keep NaN for the first 9 rows

combined_X_df['Reconstruction_error_array'] = reconstruction_error_arrays

# %%
combined_X_df = combined_X_df.dropna()
combined_X_df = combined_X_df.reset_index(drop=True)
combined_X_df.head()
# Out:
#    Reconstruction_error                         Reconstruction_error_array
# 0             -0.282488  [-0.44867539239698373, -0.04961145690822866, -...
# 1              0.168115  [-0.04961145690822866, -0.5952178754991634, -0...
# 2              0.361519  [-0.5952178754991634, -0.1643889804819083, 1.1...
# 3              0.400293  [-0.1643889804819083, 1.1395224371920063, 0.80...
# 4              0.697508  [1.1395224371920063, 0.8058563074645291, -0.25...

# %%
if temp_df.shape[0] != combined_X_df.shape[0]:
    temp_df = temp_df.iloc[sequence_length-1:]
    temp_df = temp_df.reset_index(drop=True)
    print("Shape mismatch, adjusted DataFrame")
    print("temp_df shape:", temp_df.shape)
    print("combined_X_df shape:", combined_X_df.shape)
# Out:
# Shape mismatch, adjusted DataFrame
# temp_df shape: (2508, 4)
# combined_X_df shape: (2508, 2)

# %%
y_train_scaled_df = pd.DataFrame(y_train_scaled, columns=["Bias"])
y_val_scaled_df = pd.DataFrame(y_val_scaled, columns=["Bias"])
y_test_scaled_df = pd.DataFrame(y_test_scaled, columns=["Bias"])

combined_y_df = pd.concat([y_train_scaled_df, y_val_scaled_df, y_test_scaled_df], axis=0)

# drop first 9 rows of y
if combined_y_df.shape[0] != combined_X_df.shape[0]:
    combined_y_df = combined_y_df.iloc[sequence_length-1:]
    combined_y_df = combined_y_df.reset_index(drop=True)
    print("Shape mismatch, adjusted DataFrame")
    print("combined_y_df shape:", combined_y_df.shape)
    print("combined_X_df shape:", combined_X_df.shape)
# Out:
# Shape mismatch, adjusted DataFrame
# combined_y_df shape: (2508, 1)
# combined_X_df shape: (2508, 2)

# %%
X = combined_X_df["Reconstruction_error_array"]
y = combined_y_df['Bias']

# Sequential split
train_size = int(0.7 * len(X))
val_size = int(0.15 * len(X))

X_train_raw = X[:train_size]
y_train_raw = y[:train_size]
X_val_raw = X[train_size:train_size + val_size]
y_val_raw = y[train_size:train_size + val_size]
X_test_raw = X[train_size + val_size:]
y_test_raw = y[train_size + val_size:]

# Convert data to PyTorch tensors
# X_train = torch.tensor(X_train_raw, dtype=torch.float32).unsqueeze(1)
# y_train = torch.tensor(y_train_raw, dtype=torch.float32).unsqueeze(1)
# X_val = torch.tensor(X_val_raw, dtype=torch.float32).unsqueeze(1)
# y_val = torch.tensor(y_val_raw, dtype=torch.float32).unsqueeze(1)
# X_test = torch.tensor(X_test_raw, dtype=torch.float32).unsqueeze(1)
# y_test = torch.tensor(y_test_raw, dtype=torch.float32).unsqueeze(1)
X_train = torch.tensor(np.stack(X_train_raw.values), dtype=torch.float32)
y_train = torch.tensor(y_train_raw.values, dtype=torch.float32).unsqueeze(1)
X_val = torch.tensor(np.stack(X_val_raw.values), dtype=torch.float32)
y_val = torch.tensor(y_val_raw.values, dtype=torch.float32).unsqueeze(1)
X_test = torch.tensor(np.stack(X_test_raw.values), dtype=torch.float32)
y_test = torch.tensor(y_test_raw.values, dtype=torch.float32).unsqueeze(1)

# Print sizes
print(f"Train: {len(X_train)}, Val: {len(X_val)}, Test: {len(X_test)}")
# Out:
# Train: 1755, Val: 376, Test: 377

# %%
# Define bias predictor model
class BiasPredictor(nn.Module):
    def __init__(self, input_size, hidden_size, dropout_rate, use_bn):
        super(BiasPredictor, self).__init__()

        hidden_size2 = hidden_size // 2
        hidden_size3 = hidden_size2 // 2

        self.use_bn = use_bn

        self.fc1 = nn.Linear(input_size, hidden_size)
        self.bn1 = nn.BatchNorm1d(hidden_size) if use_bn else nn.Identity()
        self.dropout1 = nn.Dropout(dropout_rate)

        self.fc2 = nn.Linear(hidden_size, hidden_size2)
        self.bn2 = nn.BatchNorm1d(hidden_size2) if use_bn else nn.Identity()
        self.dropout2 = nn.Dropout(dropout_rate)

        self.fc3 = nn.Linear(hidden_size2, hidden_size3)
        self.bn3 = nn.BatchNorm1d(hidden_size3) if use_bn else nn.Identity()
        self.dropout3 = nn.Dropout(dropout_rate)

        self.fc4 = nn.Linear(hidden_size3, 1)

    def forward(self, x):
        x = F.leaky_relu(self.bn1(self.fc1(x)))
        x = self.dropout1(x)

        x = F.leaky_relu(self.bn2(self.fc2(x)))
        x = self.dropout2(x)

        x = F.leaky_relu(self.bn3(self.fc3(x)))
        x = self.dropout3(x)

        return self.fc4(x)

# %%
# Training function
def train_bias_predictor(model, train_loader, val_loader, num_epochs, patience, learning_rate):
    model.to(device)
    criterion = nn.MSELoss()
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)

    best_val_loss = np.inf
    best_epoch = 0
    history = {"train_loss": [], "val_loss": []}

    for epoch in range(num_epochs):
        ###### Training Phase ######
        model.train()
        train_loss = 0.0

        for X_batch, y_batch in train_loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)

            optimizer.zero_grad()
            outputs = model(X_batch)
            loss = criterion(outputs, y_batch)
            loss.backward()
            optimizer.step()

            train_loss += loss.item() * X_batch.size(0)

        train_loss /= len(train_loader.dataset)
        history["train_loss"].append(train_loss)

        ###### Validation Phase ######
        model.eval()
        val_loss = 0.0

        with torch.no_grad():
            for X_batch, y_batch in val_loader:
                X_batch, y_batch = X_batch.to(device), y_batch.to(device)
                outputs = model(X_batch)
                loss = criterion(outputs, y_batch)
                val_loss += loss.item() * X_batch.size(0)

        val_loss /= len(val_loader.dataset)
        history["val_loss"].append(val_loss)

        # Print Progress
        print(f"📉 Epoch {epoch+1}/{num_epochs} - Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}")

        # Early Stopping Check
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            best_epoch = epoch
            best_model = model  # Store best model
        elif epoch - best_epoch >= patience:
            print(f"⏹️ Early stopping triggered at epoch {epoch+1}. Best epoch: {best_epoch+1}, Best Val Loss: {best_val_loss:.4f}")
            break

    return best_model, history

# %%
# # Create dataloader
# train_dataset = TensorDataset(X_train, y_train)
# val_dataset = TensorDataset(X_val, y_val)
# test_dataset = TensorDataset(X_test, y_test)
# train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
# val_loader = DataLoader(val_dataset, batch_size=16, shuffle=False)
# test_loader = DataLoader(test_dataset, batch_size=16, shuffle=False)

# Hyperparameters
input_size = 10
hidden_size = 16
dropout_rate = 0.3
use_bn = False
learning_rate = 0.0001
num_epochs = 500
patience = 20

arr_model = BiasPredictor(input_size=input_size, hidden_size=hidden_size, dropout_rate=dropout_rate, use_bn=use_bn).to(device)

arr_model.load_state_dict(torch.load("./models/bias_model_arr_input_section_3.pth"))
# Out:
# You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# <All keys matched successfully>

# %%
arr_model.eval()

with torch.no_grad():
    X_tensor = torch.tensor(X, dtype=torch.float32).to(device)
    y_pred_arr = arr_model(X_tensor).cpu().numpy()

outputs_arr_unscaled = y_scaler.inverse_transform(y_pred_arr.reshape(y_pred_arr.shape[0], -1))

# Add predictions into df
temp_df["bias_model_arr_prediction"] = outputs_arr_unscaled.flatten()
temp_df['New_predictions_arr'] = temp_df["LSTM_prediction_original"] + temp_df["bias_model_arr_prediction"]

# %%
temp_df
# Out:
#       bias_model_uni_prediction  LSTM_prediction_original      Target  \
# 0                      2.480385                 83.360207   87.099731
# 1                      2.285826                 83.942398   87.145599
# 2                      2.233702                 83.372101   85.960190
# 3                      2.224969                 82.514267   85.470764
# 4                      2.162492                 81.897781   82.243431
# ...                         ...                       ...         ...
# 2503                   0.115546                238.381989  264.779175
# 2504                   0.276087                238.427292  268.596954
# 2505                   0.290529                238.467728  267.361877
# 2506                   0.053551                238.517731  274.360992
# 2507                  -0.224087                238.558563  271.806519
#
#       New_predictions_uni  bias_model_arr_prediction  New_predictions_arr
# 0               85.840591                   2.507497            85.867706
# 1               86.228226                   2.227980            86.170380
# 2               85.605804                   2.093096            85.465195
# 3               84.739235                   2.018606            84.532875
# 4               84.060272                   2.009294            83.907074
# ...                   ...                        ...                  ...
# 2503           238.497528                   4.996389           243.378372
# 2504           238.703384                   5.072405           243.499695
# 2505           238.758255                   4.543294           243.011017
# 2506           238.571289                   4.406693           242.924423
# 2507           238.334473                   4.172369           242.730927
#
# [2508 rows x 6 columns]

# %%
# plot line graph of bias_model_arr_prediction vs original
plt.figure(figsize=(20, 10))
plt.plot(temp_df["New_predictions_arr"].iloc[train_size+val_size:], label='Array predictions', color='blue')
plt.plot(temp_df["New_predictions_uni"].iloc[train_size+val_size:], label='Single input predictions', color='red')
plt.plot(temp_df["Target"].iloc[train_size+val_size:], label='True Values', color='green')
plt.xlabel('Time')
plt.ylabel('Value')
plt.title('Actual vs. Predicted Values')
plt.legend()
plt.show()

# %%
# get prediction error percentages
original_error_percent = np.mean(np.abs(temp_df["Target"].iloc[train_size+val_size:].values - temp_df["LSTM_prediction_original"].iloc[train_size+val_size:].values) / (np.abs(temp_df["Target"].iloc[train_size+val_size:].values) + 1e-8)) * 100
uni_input_error_percent = np.mean(np.abs(temp_df["Target"].iloc[train_size+val_size:].values - temp_df["New_predictions_uni"].iloc[train_size+val_size:].values) / (np.abs(temp_df["Target"].iloc[train_size+val_size:].values) + 1e-8)) * 100
arr_input_error_percent = np.mean(np.abs(temp_df["Target"].iloc[train_size+val_size:].values - temp_df["New_predictions_arr"].iloc[train_size+val_size:].values) / (np.abs(temp_df["Target"].iloc[train_size+val_size:].values) + 1e-8)) * 100

print("Percentages over test set\n")
print(f"Original LSTM Error Percentage: {original_error_percent:.4f}%")
print(f"New LSTM Error Percentage (Single Input): {uni_input_error_percent:.4f}%")
print(f"New LSTM Error Percentage (Array Input): {arr_input_error_percent:.4f}%")
# Out:
# Percentages over test set
#
# Original LSTM Error Percentage: 10.8221%
# New LSTM Error Percentage (Single Input): 10.4940%
# New LSTM Error Percentage (Array Input): 9.7021%

# %%
# plot graph over entire dataset
plt.figure(figsize=(20, 10))
plt.plot(temp_df["New_predictions_arr"], label='Array predictions', color='blue')
plt.plot(temp_df["New_predictions_uni"], label='Single input predictions', color='red')
plt.plot(temp_df["Target"], label='True Values', color='green')
plt.xlabel('Time')
plt.ylabel('Value')
plt.title('Actual vs. Predicted Values')
plt.legend()
plt.show()

# %%
# get prediction error percentages
original_error_percent = np.mean(np.abs(temp_df["Target"].values - temp_df["LSTM_prediction_original"].values) / (np.abs(temp_df["Target"].values) + 1e-8)) * 100
uni_input_error_percent = np.mean(np.abs(temp_df["Target"].values - temp_df["New_predictions_uni"].values) / (np.abs(temp_df["Target"].values) + 1e-8)) * 100
arr_input_error_percent = np.mean(np.abs(temp_df["Target"].values - temp_df["New_predictions_arr"].values) / (np.abs(temp_df["Target"].values) + 1e-8)) * 100

print("Percentages over entire set\n")
print(f"Original LSTM Error Percentage: {original_error_percent:.4f}%")
print(f"New LSTM Error Percentage (Single Input): {uni_input_error_percent:.4f}%")
print(f"New LSTM Error Percentage (Array Input): {arr_input_error_percent:.4f}%")
# Out:
# Percentages over entire set
#
# Original LSTM Error Percentage: 3.6834%
# New LSTM Error Percentage (Single Input): 2.9803%
# New LSTM Error Percentage (Array Input): 2.8037%

# %% [markdown]
# <span style="color: yellow; font-size: 40px;">Bias correction model - multi input with SHAP</span>

# %%
import shap

# Define a custom wrapper for the PyTorch model
class ModelWrapper:
    def __init__(self, model):
        self.model = model

    def __call__(self, data):
        self.model.eval()
        with torch.no_grad():
            data = torch.tensor(data, dtype=torch.float32).to(device)
            return self.model(data).cpu().numpy()

arr_model.eval()

# Create SHAP explainer
wrapped_model = ModelWrapper(arr_model)
explainer = shap.Explainer(wrapped_model, X_test.cpu().numpy())



print("Running SHAP explainer...")
shap_values = explainer(X_test.cpu().numpy())
# Convert to numpy
shap_values_array = shap_values.values

# Average SHAP values across all test samples
feature_importance = np.mean(np.abs(shap_values_array), axis=0)

# Create labels for the features
num_features = len(feature_importance)
feature_labels = [f"Day {i+1}" for i in range(num_features)]
# Out:
# Running SHAP explainer...

# %%
# Plot feature importance
plt.figure(figsize=(10, 5))
plt.barh(feature_labels, feature_importance)
plt.xlabel('Average SHAP Value')
plt.title('Feature Importance')
plt.show()

# Display results
day = 1
for i in feature_importance:
    print(f"Day {day}: {i:.4f}")
    day += 1
# Out:
# Day 1: 0.0711
# Day 2: 0.0116
# Day 3: 0.0127
# Day 4: 0.0060
# Day 5: 0.0550
# Day 6: 0.0712
# Day 7: 0.1733
# Day 8: 0.0742
# Day 9: 0.0616
# Day 10: 0.1219

# %%
# Normalize feature importance such that sum = 1
normalized_importance = feature_importance / np.sum(feature_importance)

# Plot graph
plt.figure(figsize=(10, 5))
plt.barh(feature_labels, normalized_importance)
plt.xlabel('Normalized Importance')
plt.title('Feature Importance (Normalized)')
plt.show()

day = 1
for i in normalized_importance:
    print(f"Day {day}: {i:.4f}")
    day += 1
# Out:
# Day 1: 0.1079
# Day 2: 0.0177
# Day 3: 0.0193
# Day 4: 0.0090
# Day 5: 0.0835
# Day 6: 0.1082
# Day 7: 0.2631
# Day 8: 0.1126
# Day 9: 0.0936
# Day 10: 0.1851

# %%
sum = 0
for i in normalized_importance:
    sum += i
    
print(f"Total: {sum:.4f}")
# Out:
# Total: 1.0000

# %%
weighted = 0

if weighted == 0:
    # Multiply X by weights
    X_weighted = X.apply(lambda arr: arr * normalized_importance)
    weighted = 1
    # Print the first few elements to verify
    X_weighted.head()

# %%
X = X_weighted
y = combined_y_df['Bias']

# Sequential split
train_size = int(0.7 * len(X))
val_size = int(0.15 * len(X))

X_train_raw = X[:train_size]
y_train_raw = y[:train_size]
X_val_raw = X[train_size:train_size + val_size]
y_val_raw = y[train_size:train_size + val_size]
X_test_raw = X[train_size + val_size:]
y_test_raw = y[train_size + val_size:]

# Convert data to PyTorch tensors
# X_train = torch.tensor(X_train_raw, dtype=torch.float32).unsqueeze(1)
# y_train = torch.tensor(y_train_raw, dtype=torch.float32).unsqueeze(1)
# X_val = torch.tensor(X_val_raw, dtype=torch.float32).unsqueeze(1)
# y_val = torch.tensor(y_val_raw, dtype=torch.float32).unsqueeze(1)
# X_test = torch.tensor(X_test_raw, dtype=torch.float32).unsqueeze(1)
# y_test = torch.tensor(y_test_raw, dtype=torch.float32).unsqueeze(1)
X_train = torch.tensor(np.stack(X_train_raw.values), dtype=torch.float32)
y_train = torch.tensor(y_train_raw.values, dtype=torch.float32).unsqueeze(1)
X_val = torch.tensor(np.stack(X_val_raw.values), dtype=torch.float32)
y_val = torch.tensor(y_val_raw.values, dtype=torch.float32).unsqueeze(1)
X_test = torch.tensor(np.stack(X_test_raw.values), dtype=torch.float32)
y_test = torch.tensor(y_test_raw.values, dtype=torch.float32).unsqueeze(1)

# Print sizes
print(f"Train: {len(X_train)}, Val: {len(X_val)}, Test: {len(X_test)}")
# Out:
# Train: 1755, Val: 376, Test: 377

# %%
import itertools

# Create dataloader
train_dataset = TensorDataset(X_train, y_train)
val_dataset = TensorDataset(X_val, y_val)
test_dataset = TensorDataset(X_test, y_test)
train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=16, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=16, shuffle=False)

# # Hyperparameters
# input_size = 10
# hidden_size = 64
# dropout_rate = 0.2
# use_bn = True
# learning_rate = 0.0005
# num_epochs = 500
# patience = 20

# model = BiasPredictor(input_size=input_size, hidden_size=hidden_size, dropout_rate=dropout_rate, use_bn=use_bn).to(device)

# best_model, history = train_bias_predictor(model, train_loader, val_loader, num_epochs, patience, learning_rate)

# Define hyperparameter search space
# param_grid = {
#     "hidden_size": [32, 64, 128],
#     "dropout_rate": [0.0, 0.1, 0.2, 0.3],
#     "use_bn": [True, False],
#     "learning_rate": [0.001, 0.0005, 0.0001],
#     "batch_size" : [8,16,32]
# }

# # Number of runs per combination
# num_repeats = 5

# # Store results
# results = []

# # Define device
# device = "cuda" if torch.cuda.is_available() else "cpu"

# total_combinations = np.prod([len(v) for v in param_grid.values()])
# count = 0
# # Grid search loop
# for params in itertools.product(*param_grid.values()):
#     hidden_size, dropout_rate, use_bn, learning_rate, batch_size = params
#     param_key = f"HS={hidden_size}, DR={dropout_rate}, BN={use_bn}, LR={learning_rate}, BS={batch_size}"

#     print(f"\n🔍 Testing: {param_key}")
#     print(f"{count} / {total_combinations} combinations\n")
#     count += 1

#     # Store metrics across runs
#     avg_train_loss, avg_val_loss, avg_mae, avg_mse, avg_percent_error = 0, 0, 0, 0, 0

#     for run in range(num_repeats):
#         print(f"⚡ Run {run+1}/{num_repeats}")

#         train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
#         val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

#         # Initialize model
#         model = BiasPredictor(input_size=10, hidden_size=hidden_size, dropout_rate=dropout_rate, use_bn=use_bn).to(device)

#         # Train model
#         best_model, history = train_bias_predictor(model, train_loader, val_loader, num_epochs=500, patience=20, learning_rate=learning_rate)

#         # Evaluate performance
#         with torch.no_grad():
#             X_tensor = torch.tensor(X, dtype=torch.float32).to(device)
#             y_pred_arr = best_model(X_tensor).cpu().numpy()

#         # Unscale predictions
#         outputs_arr_unscaled = y_scaler.inverse_transform(y_pred_arr.reshape(y_pred_arr.shape[0], -1))

#         # Store predictions
#         temp_df["bias_model_arr_prediction"] = outputs_arr_unscaled.flatten()
#         temp_df["New_predictions_arr"] = temp_df["LSTM_prediction_original"] + temp_df["bias_model_arr_prediction"]

#         # Compute error metrics
#         target_vals = temp_df["Target"].iloc[train_size+val_size:].values
#         pred_vals = temp_df["New_predictions_arr"].iloc[train_size+val_size:].values

#         mae = np.mean(np.abs(target_vals - pred_vals))
#         mse = np.mean((target_vals - pred_vals) ** 2)
#         percent_error = np.mean(np.abs(target_vals - pred_vals) / (np.abs(target_vals) + 1e-8)) * 100

#         # Accumulate metrics
#         avg_train_loss += history["train_loss"][-1] / num_repeats
#         avg_val_loss += history["val_loss"][-1] / num_repeats
#         avg_mae += mae / num_repeats
#         avg_mse += mse / num_repeats
#         avg_percent_error += percent_error / num_repeats

#     # Store results
#     results.append({
#         "hidden_size": hidden_size,
#         "dropout_rate": dropout_rate,
#         "use_bn": use_bn,
#         "learning_rate": learning_rate,
#         "batch_size": batch_size,
#         "train_loss": avg_train_loss,
#         "val_loss": avg_val_loss,
#         "MAE": avg_mae,
#         "MSE": avg_mse,
#         "Percent Error": avg_percent_error
#     })

# # Convert results to DataFrame and sort by best validation loss
# results_df = pd.DataFrame(results)
# results_df = results_df.sort_values(by="Percent Error", ascending=True)

# # Print best hyperparameters
# best_params = results_df.iloc[0]
# print("\n🏆 Best Hyperparameters Found:")
# print(best_params)

# # Save results to CSV
# results_df.to_csv("grid_search_results.csv", index=False)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
import os

# Directory to save models
save_dir = "saved_models"
os.makedirs(save_dir, exist_ok=True)

# Number of runs
num_runs = 10

# Store results
all_predictions = []
error_percentages = []

# Run training 10 times
for run in range(num_runs):
    print(f"⚡ Run {run+1}/{num_runs}")

    train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)
    test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

    # Initialize model
    model = BiasPredictor(input_size=10, hidden_size=64, dropout_rate=0.0, use_bn=False).to(device)

    # Train model
    best_model, history = train_bias_predictor(model, train_loader, val_loader, num_epochs=500, patience=20, learning_rate=0.0005)

    # Save trained model
    model_path = os.path.join(save_dir, f"bias_predictor_run_{run+1}.pth")
    torch.save(best_model.state_dict(), model_path)
    print(f"✅ Model saved at: {model_path}")

    # Evaluate model
    best_model.eval()
    with torch.no_grad():
        X_tensor = torch.tensor(X, dtype=torch.float32).to(device)
        y_pred_arr = best_model(X_tensor).cpu().numpy()

    # Unscale predictions
    outputs_arr_unscaled = y_scaler.inverse_transform(y_pred_arr.reshape(y_pred_arr.shape[0], -1))

    # Store predictions
    temp_df[f"bias_model_arr_prediction_SHAP_run_{run+1}"] = outputs_arr_unscaled.flatten()
    temp_df[f"New_predictions_arr_SHAP_run_{run+1}"] = temp_df["LSTM_prediction_original"] + temp_df[f"bias_model_arr_prediction_SHAP_run_{run+1}"]

    # Compute error percentage for this run
    target_vals = temp_df["Target"].iloc[train_size+val_size:].values
    pred_vals = temp_df[f"New_predictions_arr_SHAP_run_{run+1}"].iloc[train_size+val_size:].values

    error_percent = np.mean(np.abs(target_vals - pred_vals) / (np.abs(target_vals) + 1e-8)) * 100
    error_percentages.append(error_percent)

    # Store predictions
    all_predictions.append(pred_vals)
# Out:
# ⚡ Run 1/10
# 📉 Epoch 1/500 - Train Loss: 0.6676, Val Loss: 9.8661
# 📉 Epoch 2/500 - Train Loss: 0.6309, Val Loss: 10.4011
# 📉 Epoch 3/500 - Train Loss: 0.6195, Val Loss: 10.7067
# 📉 Epoch 4/500 - Train Loss: 0.6150, Val Loss: 10.9252
# 📉 Epoch 5/500 - Train Loss: 0.6095, Val Loss: 10.9581
# 📉 Epoch 6/500 - Train Loss: 0.6027, Val Loss: 11.1966
# 📉 Epoch 7/500 - Train Loss: 0.5977, Val Loss: 10.9594
# 📉 Epoch 8/500 - Train Loss: 0.5913, Val Loss: 10.9908
# 📉 Epoch 9/500 - Train Loss: 0.5860, Val Loss: 10.2308
# 📉 Epoch 10/500 - Train Loss: 0.5789, Val Loss: 9.5155
# 📉 Epoch 11/500 - Train Loss: 0.5765, Val Loss: 9.9824
# 📉 Epoch 12/500 - Train Loss: 0.5735, Val Loss: 9.8021
# 📉 Epoch 13/500 - Train Loss: 0.5723, Val Loss: 9.7796
# 📉 Epoch 14/500 - Train Loss: 0.5705, Val Loss: 9.6089
# 📉 Epoch 15/500 - Train Loss: 0.5697, Val Loss: 9.5400
# 📉 Epoch 16/500 - Train Loss: 0.5689, Val Loss: 9.2415
# 📉 Epoch 17/500 - Train Loss: 0.5674, Val Loss: 9.3197
# 📉 Epoch 18/500 - Train Loss: 0.5693, Val Loss: 9.8841
# 📉 Epoch 19/500 - Train Loss: 0.5697, Val Loss: 9.3456
# 📉 Epoch 20/500 - Train Loss: 0.5649, Val Loss: 8.7047
# 📉 Epoch 21/500 - Train Loss: 0.5662, Val Loss: 8.9542
# 📉 Epoch 22/500 - Train Loss: 0.5634, Val Loss: 9.1084
# 📉 Epoch 23/500 - Train Loss: 0.5641, Val Loss: 9.1943
# 📉 Epoch 24/500 - Train Loss: 0.5633, Val Loss: 9.1054
# 📉 Epoch 25/500 - Train Loss: 0.5632, Val Loss: 9.4800
# 📉 Epoch 26/500 - Train Loss: 0.5612, Val Loss: 9.1023
# 📉 Epoch 27/500 - Train Loss: 0.5609, Val Loss: 8.9598
# 📉 Epoch 28/500 - Train Loss: 0.5579, Val Loss: 8.9098
# 📉 Epoch 29/500 - Train Loss: 0.5579, Val Loss: 8.7291
# 📉 Epoch 30/500 - Train Loss: 0.5582, Val Loss: 9.1446
# 📉 Epoch 31/500 - Train Loss: 0.5589, Val Loss: 8.4524
# 📉 Epoch 32/500 - Train Loss: 0.5581, Val Loss: 9.0362
# 📉 Epoch 33/500 - Train Loss: 0.5543, Val Loss: 9.5803
# 📉 Epoch 34/500 - Train Loss: 0.5604, Val Loss: 9.2597
# 📉 Epoch 35/500 - Train Loss: 0.5559, Val Loss: 9.0113
# 📉 Epoch 36/500 - Train Loss: 0.5566, Val Loss: 8.8300
# 📉 Epoch 37/500 - Train Loss: 0.5535, Val Loss: 9.1249
# 📉 Epoch 38/500 - Train Loss: 0.5526, Val Loss: 8.9567
# 📉 Epoch 39/500 - Train Loss: 0.5525, Val Loss: 8.8642
# 📉 Epoch 40/500 - Train Loss: 0.5502, Val Loss: 9.1242
# 📉 Epoch 41/500 - Train Loss: 0.5514, Val Loss: 8.7173
# 📉 Epoch 42/500 - Train Loss: 0.5527, Val Loss: 8.5189
# 📉 Epoch 43/500 - Train Loss: 0.5496, Val Loss: 8.6474
# 📉 Epoch 44/500 - Train Loss: 0.5523, Val Loss: 8.3564
# 📉 Epoch 45/500 - Train Loss: 0.5542, Val Loss: 8.7716
# 📉 Epoch 46/500 - Train Loss: 0.5495, Val Loss: 8.5035
# 📉 Epoch 47/500 - Train Loss: 0.5496, Val Loss: 8.2917
# 📉 Epoch 48/500 - Train Loss: 0.5483, Val Loss: 8.4822
# 📉 Epoch 49/500 - Train Loss: 0.5480, Val Loss: 8.9090
# 📉 Epoch 50/500 - Train Loss: 0.5476, Val Loss: 8.4808
# 📉 Epoch 51/500 - Train Loss: 0.5472, Val Loss: 8.2552
# 📉 Epoch 52/500 - Train Loss: 0.5469, Val Loss: 8.3989
# 📉 Epoch 53/500 - Train Loss: 0.5484, Val Loss: 8.6120
# 📉 Epoch 54/500 - Train Loss: 0.5481, Val Loss: 8.1937
# 📉 Epoch 55/500 - Train Loss: 0.5465, Val Loss: 8.1644
# 📉 Epoch 56/500 - Train Loss: 0.5442, Val Loss: 8.1908
# 📉 Epoch 57/500 - Train Loss: 0.5467, Val Loss: 8.6080
# 📉 Epoch 58/500 - Train Loss: 0.5461, Val Loss: 8.4868
# 📉 Epoch 59/500 - Train Loss: 0.5440, Val Loss: 8.1744
# 📉 Epoch 60/500 - Train Loss: 0.5442, Val Loss: 8.2511
# 📉 Epoch 61/500 - Train Loss: 0.5435, Val Loss: 8.5138
# 📉 Epoch 62/500 - Train Loss: 0.5432, Val Loss: 8.6426
# 📉 Epoch 63/500 - Train Loss: 0.5464, Val Loss: 8.4143
# 📉 Epoch 64/500 - Train Loss: 0.5452, Val Loss: 8.3831
# 📉 Epoch 65/500 - Train Loss: 0.5454, Val Loss: 8.2890
# 📉 Epoch 66/500 - Train Loss: 0.5409, Val Loss: 7.9478
# 📉 Epoch 67/500 - Train Loss: 0.5444, Val Loss: 8.4277
# 📉 Epoch 68/500 - Train Loss: 0.5405, Val Loss: 7.9321
# 📉 Epoch 69/500 - Train Loss: 0.5400, Val Loss: 7.7805
# 📉 Epoch 70/500 - Train Loss: 0.5392, Val Loss: 8.3049
# 📉 Epoch 71/500 - Train Loss: 0.5438, Val Loss: 7.8985
# 📉 Epoch 72/500 - Train Loss: 0.5385, Val Loss: 7.7776
# 📉 Epoch 153/500 - Train Loss: 0.5148, Val Loss: 6.1843
# 📉 Epoch 154/500 - Train Loss: 0.5182, Val Loss: 6.1596
# 📉 Epoch 155/500 - Train Loss: 0.5178, Val Loss: 6.2485
# 📉 Epoch 156/500 - Train Loss: 0.5183, Val Loss: 6.3049
# 📉 Epoch 157/500 - Train Loss: 0.5185, Val Loss: 6.4801
# 📉 Epoch 158/500 - Train Loss: 0.5169, Val Loss: 5.8814
# 📉 Epoch 159/500 - Train Loss: 0.5149, Val Loss: 6.3178
# 📉 Epoch 160/500 - Train Loss: 0.5176, Val Loss: 6.2768
# 📉 Epoch 161/500 - Train Loss: 0.5211, Val Loss: 5.9579
# 📉 Epoch 162/500 - Train Loss: 0.5148, Val Loss: 5.9329
# 📉 Epoch 163/500 - Train Loss: 0.5225, Val Loss: 5.9486
# 📉 Epoch 164/500 - Train Loss: 0.5181, Val Loss: 6.1248
# 📉 Epoch 165/500 - Train Loss: 0.5139, Val Loss: 6.0038
# ⏹️ Early stopping triggered at epoch 165. Best epoch: 145, Best Val Loss: 5.8795
# ✅ Model saved at: saved_models\bias_predictor_run_1.pth
# ⚡ Run 2/10
# Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\torch\csrc\utils\tensor_new.cpp:281.)
# 📉 Epoch 1/500 - Train Loss: 0.6219, Val Loss: 10.2135
# 📉 Epoch 2/500 - Train Loss: 0.6182, Val Loss: 10.3651
# 📉 Epoch 3/500 - Train Loss: 0.6125, Val Loss: 10.4025
# 📉 Epoch 4/500 - Train Loss: 0.6069, Val Loss: 10.4671
# 📉 Epoch 5/500 - Train Loss: 0.6024, Val Loss: 10.4850
# 📉 Epoch 6/500 - Train Loss: 0.5981, Val Loss: 10.5008
# 📉 Epoch 7/500 - Train Loss: 0.5925, Val Loss: 10.1425
# 📉 Epoch 8/500 - Train Loss: 0.5870, Val Loss: 10.3419
# 📉 Epoch 9/500 - Train Loss: 0.5832, Val Loss: 10.4452
# 📉 Epoch 10/500 - Train Loss: 0.5799, Val Loss: 10.1201
# 📉 Epoch 11/500 - Train Loss: 0.5797, Val Loss: 10.2655
# 📉 Epoch 12/500 - Train Loss: 0.5770, Val Loss: 10.2715
# 📉 Epoch 13/500 - Train Loss: 0.5756, Val Loss: 10.8844
# 📉 Epoch 14/500 - Train Loss: 0.5741, Val Loss: 10.6382
# 📉 Epoch 15/500 - Train Loss: 0.5736, Val Loss: 10.3822
# 📉 Epoch 16/500 - Train Loss: 0.5722, Val Loss: 10.4945
# 📉 Epoch 17/500 - Train Loss: 0.5709, Val Loss: 10.4619
# 📉 Epoch 18/500 - Train Loss: 0.5705, Val Loss: 10.0259
# 📉 Epoch 19/500 - Train Loss: 0.5709, Val Loss: 10.3240
# 📉 Epoch 20/500 - Train Loss: 0.5682, Val Loss: 10.0207
# 📉 Epoch 21/500 - Train Loss: 0.5688, Val Loss: 10.2367
# 📉 Epoch 22/500 - Train Loss: 0.5684, Val Loss: 10.2557
# 📉 Epoch 23/500 - Train Loss: 0.5668, Val Loss: 10.4475
# 📉 Epoch 24/500 - Train Loss: 0.5668, Val Loss: 10.1307
# 📉 Epoch 25/500 - Train Loss: 0.5649, Val Loss: 10.2455
# 📉 Epoch 23/500 - Train Loss: 0.5637, Val Loss: 7.9980
# 📉 Epoch 24/500 - Train Loss: 0.5667, Val Loss: 7.9966
# 📉 Epoch 25/500 - Train Loss: 0.5643, Val Loss: 7.9095
# 📉 Epoch 26/500 - Train Loss: 0.5628, Val Loss: 7.7450
# 📉 Epoch 27/500 - Train Loss: 0.5616, Val Loss: 7.3259
# 📉 Epoch 28/500 - Train Loss: 0.5642, Val Loss: 7.9252
# 📉 Epoch 29/500 - Train Loss: 0.5608, Val Loss: 7.8431
# 📉 Epoch 30/500 - Train Loss: 0.5604, Val Loss: 7.5847
# 📉 Epoch 31/500 - Train Loss: 0.5612, Val Loss: 7.5597
# 📉 Epoch 32/500 - Train Loss: 0.5603, Val Loss: 7.5716
# 📉 Epoch 33/500 - Train Loss: 0.5598, Val Loss: 7.9438
# 📉 Epoch 34/500 - Train Loss: 0.5603, Val Loss: 7.2550
# 📉 Epoch 35/500 - Train Loss: 0.5586, Val Loss: 8.1533
# 📉 Epoch 36/500 - Train Loss: 0.5582, Val Loss: 7.4298
# 📉 Epoch 37/500 - Train Loss: 0.5585, Val Loss: 7.6879
# 📉 Epoch 38/500 - Train Loss: 0.5575, Val Loss: 7.8623
# 📉 Epoch 39/500 - Train Loss: 0.5577, Val Loss: 7.6912
# 📉 Epoch 40/500 - Train Loss: 0.5593, Val Loss: 8.1718
# 📉 Epoch 41/500 - Train Loss: 0.5594, Val Loss: 8.0962
# 📉 Epoch 42/500 - Train Loss: 0.5567, Val Loss: 8.0890
# 📉 Epoch 43/500 - Train Loss: 0.5558, Val Loss: 8.0488
# 📉 Epoch 44/500 - Train Loss: 0.5554, Val Loss: 7.8910
# 📉 Epoch 45/500 - Train Loss: 0.5548, Val Loss: 7.8781
# 📉 Epoch 46/500 - Train Loss: 0.5522, Val Loss: 7.3029
# 📉 Epoch 47/500 - Train Loss: 0.5567, Val Loss: 7.9956
# 📉 Epoch 48/500 - Train Loss: 0.5544, Val Loss: 7.5840
# 📉 Epoch 49/500 - Train Loss: 0.5513, Val Loss: 7.4841
# 📉 Epoch 50/500 - Train Loss: 0.5536, Val Loss: 7.7056
# 📉 Epoch 51/500 - Train Loss: 0.5504, Val Loss: 8.1650
# 📉 Epoch 52/500 - Train Loss: 0.5529, Val Loss: 7.8228
# 📉 Epoch 53/500 - Train Loss: 0.5502, Val Loss: 7.9384
# 📉 Epoch 54/500 - Train Loss: 0.5513, Val Loss: 7.8873
# ⏹️ Early stopping triggered at epoch 54. Best epoch: 34, Best Val Loss: 7.2550
# ✅ Model saved at: saved_models\bias_predictor_run_3.pth
# ⚡ Run 4/10
# 📉 Epoch 1/500 - Train Loss: 0.6295, Val Loss: 10.2697
# 📉 Epoch 2/500 - Train Loss: 0.6190, Val Loss: 10.5478
# 📉 Epoch 3/500 - Train Loss: 0.6137, Val Loss: 10.7349
# 📉 Epoch 4/500 - Train Loss: 0.6084, Val Loss: 10.8838
# 📉 Epoch 5/500 - Train Loss: 0.6035, Val Loss: 10.6069
# 📉 Epoch 6/500 - Train Loss: 0.5985, Val Loss: 10.2527
# 📉 Epoch 7/500 - Train Loss: 0.5926, Val Loss: 10.0336
# 📉 Epoch 8/500 - Train Loss: 0.5881, Val Loss: 10.0671
# 📉 Epoch 9/500 - Train Loss: 0.5840, Val Loss: 10.1381
# 📉 Epoch 10/500 - Train Loss: 0.5802, Val Loss: 9.3505
# 📉 Epoch 11/500 - Train Loss: 0.5766, Val Loss: 9.7298
# 📉 Epoch 12/500 - Train Loss: 0.5745, Val Loss: 9.0938
# 📉 Epoch 13/500 - Train Loss: 0.5725, Val Loss: 8.8478
# 📉 Epoch 14/500 - Train Loss: 0.5737, Val Loss: 8.8175
# 📉 Epoch 15/500 - Train Loss: 0.5705, Val Loss: 8.5145
# 📉 Epoch 16/500 - Train Loss: 0.5686, Val Loss: 9.3427
# 📉 Epoch 17/500 - Train Loss: 0.5703, Val Loss: 8.6130
# 📉 Epoch 18/500 - Train Loss: 0.5704, Val Loss: 8.6831
# 📉 Epoch 19/500 - Train Loss: 0.5679, Val Loss: 8.2109
# 📉 Epoch 20/500 - Train Loss: 0.5663, Val Loss: 8.2410
# 📉 Epoch 21/500 - Train Loss: 0.5664, Val Loss: 8.1534
# 📉 Epoch 22/500 - Train Loss: 0.5653, Val Loss: 8.0002
# 📉 Epoch 23/500 - Train Loss: 0.5636, Val Loss: 8.4605
# 📉 Epoch 24/500 - Train Loss: 0.5638, Val Loss: 8.2007
# 📉 Epoch 25/500 - Train Loss: 0.5632, Val Loss: 8.0885
# 📉 Epoch 26/500 - Train Loss: 0.5624, Val Loss: 8.0635
# 📉 Epoch 27/500 - Train Loss: 0.5632, Val Loss: 8.0338
# 📉 Epoch 28/500 - Train Loss: 0.5631, Val Loss: 8.3913
# 📉 Epoch 29/500 - Train Loss: 0.5604, Val Loss: 8.2573
# 📉 Epoch 30/500 - Train Loss: 0.5611, Val Loss: 8.7478
# 📉 Epoch 31/500 - Train Loss: 0.5591, Val Loss: 8.1130
# 📉 Epoch 32/500 - Train Loss: 0.5601, Val Loss: 8.5881
# 📉 Epoch 33/500 - Train Loss: 0.5574, Val Loss: 8.0248
# 📉 Epoch 34/500 - Train Loss: 0.5588, Val Loss: 8.7852
# 📉 Epoch 35/500 - Train Loss: 0.5579, Val Loss: 8.4628
# 📉 Epoch 36/500 - Train Loss: 0.5558, Val Loss: 8.3224
# 📉 Epoch 37/500 - Train Loss: 0.5572, Val Loss: 8.0273
# 📉 Epoch 38/500 - Train Loss: 0.5588, Val Loss: 8.8519
# 📉 Epoch 39/500 - Train Loss: 0.5557, Val Loss: 8.2172
# 📉 Epoch 40/500 - Train Loss: 0.5544, Val Loss: 8.2047
# 📉 Epoch 41/500 - Train Loss: 0.5529, Val Loss: 7.7318
# 📉 Epoch 42/500 - Train Loss: 0.5537, Val Loss: 8.3580
# 📉 Epoch 43/500 - Train Loss: 0.5524, Val Loss: 8.7034
# 📉 Epoch 44/500 - Train Loss: 0.5516, Val Loss: 8.5844
# 📉 Epoch 45/500 - Train Loss: 0.5513, Val Loss: 8.4123
# 📉 Epoch 46/500 - Train Loss: 0.5507, Val Loss: 8.9852
# 📉 Epoch 47/500 - Train Loss: 0.5482, Val Loss: 8.0816
# 📉 Epoch 48/500 - Train Loss: 0.5507, Val Loss: 8.9671
# 📉 Epoch 49/500 - Train Loss: 0.5467, Val Loss: 8.0579
# 📉 Epoch 50/500 - Train Loss: 0.5493, Val Loss: 8.5036
# 📉 Epoch 51/500 - Train Loss: 0.5480, Val Loss: 8.8200
# 📉 Epoch 52/500 - Train Loss: 0.5446, Val Loss: 7.8791
# 📉 Epoch 53/500 - Train Loss: 0.5443, Val Loss: 8.0716
# 📉 Epoch 54/500 - Train Loss: 0.5458, Val Loss: 8.7796
# 📉 Epoch 55/500 - Train Loss: 0.5444, Val Loss: 8.2676
# 📉 Epoch 56/500 - Train Loss: 0.5470, Val Loss: 8.3252
# 📉 Epoch 57/500 - Train Loss: 0.5433, Val Loss: 8.9022
# 📉 Epoch 58/500 - Train Loss: 0.5439, Val Loss: 8.6482
# 📉 Epoch 59/500 - Train Loss: 0.5434, Val Loss: 9.7404
# 📉 Epoch 60/500 - Train Loss: 0.5407, Val Loss: 8.5164
# 📉 Epoch 61/500 - Train Loss: 0.5382, Val Loss: 9.3645
# ⏹️ Early stopping triggered at epoch 61. Best epoch: 41, Best Val Loss: 7.7318
# ✅ Model saved at: saved_models\bias_predictor_run_4.pth
# ⚡ Run 5/10
# 📉 Epoch 1/500 - Train Loss: 0.6225, Val Loss: 10.3584
# 📉 Epoch 2/500 - Train Loss: 0.6182, Val Loss: 10.4263
# 📉 Epoch 3/500 - Train Loss: 0.6138, Val Loss: 10.5431
# 📉 Epoch 4/500 - Train Loss: 0.6077, Val Loss: 10.7184
# 📉 Epoch 5/500 - Train Loss: 0.6018, Val Loss: 10.8687
# 📉 Epoch 6/500 - Train Loss: 0.5951, Val Loss: 10.7947
# 📉 Epoch 7/500 - Train Loss: 0.5883, Val Loss: 10.5672
# 📉 Epoch 8/500 - Train Loss: 0.5846, Val Loss: 10.2531
# 📉 Epoch 9/500 - Train Loss: 0.5802, Val Loss: 10.4723
# 📉 Epoch 10/500 - Train Loss: 0.5779, Val Loss: 10.0676
# 📉 Epoch 11/500 - Train Loss: 0.5771, Val Loss: 9.5499
# 📉 Epoch 12/500 - Train Loss: 0.5741, Val Loss: 10.1265
# 📉 Epoch 13/500 - Train Loss: 0.5719, Val Loss: 9.4537
# 📉 Epoch 14/500 - Train Loss: 0.5739, Val Loss: 9.1940
# 📉 Epoch 15/500 - Train Loss: 0.5709, Val Loss: 9.6341
# 📉 Epoch 16/500 - Train Loss: 0.5697, Val Loss: 9.1277
# 📉 Epoch 17/500 - Train Loss: 0.5687, Val Loss: 9.0296
# 📉 Epoch 18/500 - Train Loss: 0.5689, Val Loss: 9.0283
# 📉 Epoch 19/500 - Train Loss: 0.5689, Val Loss: 8.4598
# 📉 Epoch 20/500 - Train Loss: 0.5692, Val Loss: 8.8601
# 📉 Epoch 21/500 - Train Loss: 0.5672, Val Loss: 9.5034
# 📉 Epoch 22/500 - Train Loss: 0.5645, Val Loss: 8.9733
# 📉 Epoch 104/500 - Train Loss: 0.5336, Val Loss: 6.7462
# 📉 Epoch 105/500 - Train Loss: 0.5341, Val Loss: 7.3776
# 📉 Epoch 106/500 - Train Loss: 0.5365, Val Loss: 6.8236
# 📉 Epoch 107/500 - Train Loss: 0.5331, Val Loss: 7.1146
# 📉 Epoch 108/500 - Train Loss: 0.5315, Val Loss: 6.3940
# 📉 Epoch 109/500 - Train Loss: 0.5306, Val Loss: 6.8397
# 📉 Epoch 110/500 - Train Loss: 0.5307, Val Loss: 6.7891
# 📉 Epoch 111/500 - Train Loss: 0.5320, Val Loss: 6.8339
# 📉 Epoch 112/500 - Train Loss: 0.5328, Val Loss: 6.9129
# 📉 Epoch 113/500 - Train Loss: 0.5311, Val Loss: 7.7348
# 📉 Epoch 114/500 - Train Loss: 0.5333, Val Loss: 6.4271
# 📉 Epoch 115/500 - Train Loss: 0.5292, Val Loss: 6.9189
# 📉 Epoch 116/500 - Train Loss: 0.5339, Val Loss: 6.7215
# 📉 Epoch 117/500 - Train Loss: 0.5313, Val Loss: 6.8873
# 📉 Epoch 118/500 - Train Loss: 0.5284, Val Loss: 6.5891
# 📉 Epoch 119/500 - Train Loss: 0.5300, Val Loss: 7.0814
# 📉 Epoch 120/500 - Train Loss: 0.5302, Val Loss: 6.9335
# 📉 Epoch 121/500 - Train Loss: 0.5280, Val Loss: 7.1981
# 📉 Epoch 122/500 - Train Loss: 0.5302, Val Loss: 6.7446
# 📉 Epoch 123/500 - Train Loss: 0.5267, Val Loss: 6.7502
# 📉 Epoch 124/500 - Train Loss: 0.5301, Val Loss: 6.4660
# 📉 Epoch 125/500 - Train Loss: 0.5284, Val Loss: 7.0475
# 📉 Epoch 126/500 - Train Loss: 0.5269, Val Loss: 6.8679
# 📉 Epoch 127/500 - Train Loss: 0.5256, Val Loss: 6.7286
# 📉 Epoch 128/500 - Train Loss: 0.5268, Val Loss: 6.8544
# ⏹️ Early stopping triggered at epoch 128. Best epoch: 108, Best Val Loss: 6.3940
# ✅ Model saved at: saved_models\bias_predictor_run_5.pth
# ⚡ Run 6/10
# 📉 Epoch 1/500 - Train Loss: 0.6296, Val Loss: 10.0793
# 📉 Epoch 2/500 - Train Loss: 0.6222, Val Loss: 10.2558
# 📉 Epoch 3/500 - Train Loss: 0.6182, Val Loss: 10.4641
# 📉 Epoch 4/500 - Train Loss: 0.6139, Val Loss: 10.5547
# 📉 Epoch 5/500 - Train Loss: 0.6079, Val Loss: 10.7317
# 📉 Epoch 6/500 - Train Loss: 0.6015, Val Loss: 10.5885
# 📉 Epoch 7/500 - Train Loss: 0.5939, Val Loss: 10.2210
# 📉 Epoch 8/500 - Train Loss: 0.5865, Val Loss: 9.5584
# 📉 Epoch 9/500 - Train Loss: 0.5860, Val Loss: 9.8645
# 📉 Epoch 10/500 - Train Loss: 0.5787, Val Loss: 10.1023
# 📉 Epoch 11/500 - Train Loss: 0.5746, Val Loss: 9.6643
# 📉 Epoch 12/500 - Train Loss: 0.5735, Val Loss: 9.8090
# 📉 Epoch 13/500 - Train Loss: 0.5738, Val Loss: 9.8150
# 📉 Epoch 14/500 - Train Loss: 0.5695, Val Loss: 9.5592
# 📉 Epoch 15/500 - Train Loss: 0.5720, Val Loss: 9.8266
# 📉 Epoch 16/500 - Train Loss: 0.5687, Val Loss: 9.2435
# 📉 Epoch 17/500 - Train Loss: 0.5657, Val Loss: 9.2693
# 📉 Epoch 18/500 - Train Loss: 0.5665, Val Loss: 9.1999
# 📉 Epoch 19/500 - Train Loss: 0.5647, Val Loss: 8.9875
# 📉 Epoch 20/500 - Train Loss: 0.5643, Val Loss: 9.3481
# 📉 Epoch 21/500 - Train Loss: 0.5636, Val Loss: 8.6927
# 📉 Epoch 22/500 - Train Loss: 0.5619, Val Loss: 8.9431
# 📉 Epoch 23/500 - Train Loss: 0.5616, Val Loss: 8.9460
# 📉 Epoch 24/500 - Train Loss: 0.5604, Val Loss: 9.3989
# 📉 Epoch 25/500 - Train Loss: 0.5607, Val Loss: 9.8705
# 📉 Epoch 26/500 - Train Loss: 0.5594, Val Loss: 8.9788
# 📉 Epoch 27/500 - Train Loss: 0.5584, Val Loss: 8.9117
# 📉 Epoch 28/500 - Train Loss: 0.5585, Val Loss: 9.7095
# 📉 Epoch 29/500 - Train Loss: 0.5559, Val Loss: 8.9247
# 📉 Epoch 30/500 - Train Loss: 0.5561, Val Loss: 9.3508
# 📉 Epoch 31/500 - Train Loss: 0.5566, Val Loss: 9.2504
# 📉 Epoch 32/500 - Train Loss: 0.5550, Val Loss: 9.0416
# 📉 Epoch 33/500 - Train Loss: 0.5545, Val Loss: 8.9489
# 📉 Epoch 34/500 - Train Loss: 0.5520, Val Loss: 9.4373
# 📉 Epoch 35/500 - Train Loss: 0.5517, Val Loss: 9.0483
# 📉 Epoch 36/500 - Train Loss: 0.5513, Val Loss: 9.1817
# 📉 Epoch 37/500 - Train Loss: 0.5504, Val Loss: 9.5559
# 📉 Epoch 38/500 - Train Loss: 0.5502, Val Loss: 9.4143
# 📉 Epoch 39/500 - Train Loss: 0.5474, Val Loss: 9.0907
# 📉 Epoch 40/500 - Train Loss: 0.5499, Val Loss: 9.1409
# 📉 Epoch 41/500 - Train Loss: 0.5493, Val Loss: 9.2467
# ⏹️ Early stopping triggered at epoch 41. Best epoch: 21, Best Val Loss: 8.6927
# ✅ Model saved at: saved_models\bias_predictor_run_6.pth
# ⚡ Run 7/10
# 📉 Epoch 1/500 - Train Loss: 0.6492, Val Loss: 10.5764
# 📉 Epoch 2/500 - Train Loss: 0.6243, Val Loss: 10.4729
# 📉 Epoch 3/500 - Train Loss: 0.6154, Val Loss: 10.5153
# 📉 Epoch 4/500 - Train Loss: 0.6080, Val Loss: 10.4804
# 📉 Epoch 5/500 - Train Loss: 0.6026, Val Loss: 10.3561
# 📉 Epoch 6/500 - Train Loss: 0.5979, Val Loss: 10.1734
# 📉 Epoch 7/500 - Train Loss: 0.5924, Val Loss: 10.2151
# 📉 Epoch 8/500 - Train Loss: 0.5887, Val Loss: 9.8536
# 📉 Epoch 9/500 - Train Loss: 0.5835, Val Loss: 9.7420
# 📉 Epoch 50/500 - Train Loss: 0.5503, Val Loss: 9.1875
# 📉 Epoch 51/500 - Train Loss: 0.5503, Val Loss: 8.5270
# 📉 Epoch 52/500 - Train Loss: 0.5509, Val Loss: 8.4522
# 📉 Epoch 53/500 - Train Loss: 0.5481, Val Loss: 9.1417
# 📉 Epoch 54/500 - Train Loss: 0.5480, Val Loss: 9.3635
# ⏹️ Early stopping triggered at epoch 54. Best epoch: 34, Best Val Loss: 7.9160
# ✅ Model saved at: saved_models\bias_predictor_run_7.pth
# ⚡ Run 8/10
# 📉 Epoch 1/500 - Train Loss: 0.6887, Val Loss: 10.2863
# 📉 Epoch 2/500 - Train Loss: 0.6290, Val Loss: 11.0477
# 📉 Epoch 3/500 - Train Loss: 0.6156, Val Loss: 11.6111
# 📉 Epoch 4/500 - Train Loss: 0.6105, Val Loss: 11.5753
# 📉 Epoch 5/500 - Train Loss: 0.6059, Val Loss: 11.7528
# 📉 Epoch 6/500 - Train Loss: 0.6015, Val Loss: 11.3260
# 📉 Epoch 7/500 - Train Loss: 0.5966, Val Loss: 10.9625
# 📉 Epoch 8/500 - Train Loss: 0.5914, Val Loss: 10.8089
# 📉 Epoch 9/500 - Train Loss: 0.5868, Val Loss: 10.5403
# 📉 Epoch 10/500 - Train Loss: 0.5831, Val Loss: 10.0077
# 📉 Epoch 11/500 - Train Loss: 0.5798, Val Loss: 10.5885
# 📉 Epoch 12/500 - Train Loss: 0.5792, Val Loss: 10.5675
# 📉 Epoch 13/500 - Train Loss: 0.5749, Val Loss: 10.2470
# 📉 Epoch 14/500 - Train Loss: 0.5717, Val Loss: 9.9703
# 📉 Epoch 15/500 - Train Loss: 0.5724, Val Loss: 10.6738
# 📉 Epoch 16/500 - Train Loss: 0.5695, Val Loss: 10.3056
# 📉 Epoch 17/500 - Train Loss: 0.5696, Val Loss: 9.8057
# 📉 Epoch 18/500 - Train Loss: 0.5683, Val Loss: 10.8560
# 📉 Epoch 19/500 - Train Loss: 0.5682, Val Loss: 10.8352
# 📉 Epoch 20/500 - Train Loss: 0.5661, Val Loss: 10.0917
# 📉 Epoch 21/500 - Train Loss: 0.5665, Val Loss: 10.5257
# 📉 Epoch 22/500 - Train Loss: 0.5650, Val Loss: 9.7974
# 📉 Epoch 23/500 - Train Loss: 0.5633, Val Loss: 10.7426
# 📉 Epoch 24/500 - Train Loss: 0.5641, Val Loss: 10.1681
# 📉 Epoch 25/500 - Train Loss: 0.5627, Val Loss: 9.1145
# 📉 Epoch 26/500 - Train Loss: 0.5632, Val Loss: 10.1633
# 📉 Epoch 27/500 - Train Loss: 0.5605, Val Loss: 9.6900
# 📉 Epoch 28/500 - Train Loss: 0.5600, Val Loss: 9.6493
# 📉 Epoch 29/500 - Train Loss: 0.5601, Val Loss: 10.1669
# 📉 Epoch 30/500 - Train Loss: 0.5597, Val Loss: 10.2634
# 📉 Epoch 31/500 - Train Loss: 0.5573, Val Loss: 9.4544
# 📉 Epoch 32/500 - Train Loss: 0.5577, Val Loss: 9.3924
# 📉 Epoch 33/500 - Train Loss: 0.5565, Val Loss: 9.6947
# 📉 Epoch 34/500 - Train Loss: 0.5571, Val Loss: 9.5311
# 📉 Epoch 35/500 - Train Loss: 0.5558, Val Loss: 9.5431
# 📉 Epoch 36/500 - Train Loss: 0.5547, Val Loss: 9.9688
# 📉 Epoch 37/500 - Train Loss: 0.5550, Val Loss: 9.4557
# 📉 Epoch 38/500 - Train Loss: 0.5546, Val Loss: 9.6813
# 📉 Epoch 39/500 - Train Loss: 0.5549, Val Loss: 9.4470
# 📉 Epoch 40/500 - Train Loss: 0.5524, Val Loss: 9.7702
# 📉 Epoch 41/500 - Train Loss: 0.5525, Val Loss: 8.9885
# 📉 Epoch 42/500 - Train Loss: 0.5512, Val Loss: 9.0838
# 📉 Epoch 43/500 - Train Loss: 0.5517, Val Loss: 9.5155
# 📉 Epoch 44/500 - Train Loss: 0.5524, Val Loss: 9.7193
# 📉 Epoch 45/500 - Train Loss: 0.5505, Val Loss: 10.2961
# 📉 Epoch 46/500 - Train Loss: 0.5500, Val Loss: 9.3886
# 📉 Epoch 47/500 - Train Loss: 0.5485, Val Loss: 9.8142
# 📉 Epoch 48/500 - Train Loss: 0.5502, Val Loss: 9.0358
# 📉 Epoch 49/500 - Train Loss: 0.5506, Val Loss: 9.0619
# 📉 Epoch 50/500 - Train Loss: 0.5508, Val Loss: 8.7242
# 📉 Epoch 51/500 - Train Loss: 0.5503, Val Loss: 9.3055
# 📉 Epoch 52/500 - Train Loss: 0.5493, Val Loss: 8.9368
# 📉 Epoch 53/500 - Train Loss: 0.5464, Val Loss: 9.6120
# 📉 Epoch 54/500 - Train Loss: 0.5571, Val Loss: 9.9999
# 📉 Epoch 55/500 - Train Loss: 0.5489, Val Loss: 9.0507
# 📉 Epoch 56/500 - Train Loss: 0.5463, Val Loss: 9.4176
# 📉 Epoch 57/500 - Train Loss: 0.5458, Val Loss: 9.1478
# 📉 Epoch 58/500 - Train Loss: 0.5462, Val Loss: 8.9278
# 📉 Epoch 59/500 - Train Loss: 0.5438, Val Loss: 9.0549
# 📉 Epoch 60/500 - Train Loss: 0.5452, Val Loss: 9.0698
# 📉 Epoch 61/500 - Train Loss: 0.5419, Val Loss: 9.5734
# 📉 Epoch 62/500 - Train Loss: 0.5429, Val Loss: 9.2856
# 📉 Epoch 63/500 - Train Loss: 0.5427, Val Loss: 8.8982
# 📉 Epoch 64/500 - Train Loss: 0.5409, Val Loss: 8.1067
# 📉 Epoch 65/500 - Train Loss: 0.5416, Val Loss: 8.1207
# 📉 Epoch 66/500 - Train Loss: 0.5428, Val Loss: 9.0045
# 📉 Epoch 67/500 - Train Loss: 0.5410, Val Loss: 8.4875
# 📉 Epoch 68/500 - Train Loss: 0.5408, Val Loss: 8.7688
# 📉 Epoch 69/500 - Train Loss: 0.5380, Val Loss: 8.8125
# 📉 Epoch 70/500 - Train Loss: 0.5385, Val Loss: 8.6166
# 📉 Epoch 71/500 - Train Loss: 0.5391, Val Loss: 8.3994
# 📉 Epoch 72/500 - Train Loss: 0.5374, Val Loss: 8.3818
# 📉 Epoch 73/500 - Train Loss: 0.5371, Val Loss: 8.4746
# 📉 Epoch 74/500 - Train Loss: 0.5386, Val Loss: 9.0637
# 📉 Epoch 75/500 - Train Loss: 0.5375, Val Loss: 8.4801
# 📉 Epoch 76/500 - Train Loss: 0.5367, Val Loss: 8.5995
# 📉 Epoch 77/500 - Train Loss: 0.5364, Val Loss: 8.4055
# 📉 Epoch 78/500 - Train Loss: 0.5343, Val Loss: 7.7196
# 📉 Epoch 79/500 - Train Loss: 0.5357, Val Loss: 8.6113
# 📉 Epoch 80/500 - Train Loss: 0.5336, Val Loss: 8.5950
# 📉 Epoch 81/500 - Train Loss: 0.5362, Val Loss: 9.2697
# 📉 Epoch 82/500 - Train Loss: 0.5342, Val Loss: 8.1361
# 📉 Epoch 83/500 - Train Loss: 0.5332, Val Loss: 8.6052
# 📉 Epoch 84/500 - Train Loss: 0.5331, Val Loss: 9.0235
# 📉 Epoch 85/500 - Train Loss: 0.5325, Val Loss: 8.4511
# 📉 Epoch 86/500 - Train Loss: 0.5330, Val Loss: 8.6492
# 📉 Epoch 87/500 - Train Loss: 0.5370, Val Loss: 8.1488
# 📉 Epoch 88/500 - Train Loss: 0.5305, Val Loss: 8.4568
# 📉 Epoch 89/500 - Train Loss: 0.5306, Val Loss: 8.5272
# 📉 Epoch 90/500 - Train Loss: 0.5336, Val Loss: 8.3896
# 📉 Epoch 91/500 - Train Loss: 0.5291, Val Loss: 7.8554
# 📉 Epoch 92/500 - Train Loss: 0.5293, Val Loss: 8.0376
# 📉 Epoch 93/500 - Train Loss: 0.5307, Val Loss: 7.8058
# 📉 Epoch 94/500 - Train Loss: 0.5333, Val Loss: 8.4858
# 📉 Epoch 95/500 - Train Loss: 0.5290, Val Loss: 7.7276
# 📉 Epoch 96/500 - Train Loss: 0.5298, Val Loss: 8.1523
# 📉 Epoch 97/500 - Train Loss: 0.5291, Val Loss: 8.7462
# 📉 Epoch 98/500 - Train Loss: 0.5284, Val Loss: 8.2592
# ⏹️ Early stopping triggered at epoch 98. Best epoch: 78, Best Val Loss: 7.7196
# ✅ Model saved at: saved_models\bias_predictor_run_8.pth
# ⚡ Run 9/10
# 📉 Epoch 1/500 - Train Loss: 0.6967, Val Loss: 9.6352
# 📉 Epoch 2/500 - Train Loss: 0.6513, Val Loss: 9.8793
# 📉 Epoch 3/500 - Train Loss: 0.6294, Val Loss: 10.2037
# 📉 Epoch 4/500 - Train Loss: 0.6181, Val Loss: 10.6335
# 📉 Epoch 5/500 - Train Loss: 0.6132, Val Loss: 10.7405
# 📉 Epoch 6/500 - Train Loss: 0.6073, Val Loss: 10.9163
# 📉 Epoch 7/500 - Train Loss: 0.6015, Val Loss: 10.6535
# 📉 Epoch 8/500 - Train Loss: 0.5970, Val Loss: 10.5338
# 📉 Epoch 9/500 - Train Loss: 0.5934, Val Loss: 10.1437
# 📉 Epoch 10/500 - Train Loss: 0.5899, Val Loss: 9.7183
# 📉 Epoch 11/500 - Train Loss: 0.5836, Val Loss: 9.8720
# 📉 Epoch 12/500 - Train Loss: 0.5804, Val Loss: 9.1636
# 📉 Epoch 13/500 - Train Loss: 0.5806, Val Loss: 9.3193
# 📉 Epoch 14/500 - Train Loss: 0.5764, Val Loss: 9.0767
# 📉 Epoch 15/500 - Train Loss: 0.5743, Val Loss: 8.9059
# 📉 Epoch 16/500 - Train Loss: 0.5725, Val Loss: 8.2132
# 📉 Epoch 17/500 - Train Loss: 0.5698, Val Loss: 8.2428
# 📉 Epoch 18/500 - Train Loss: 0.5734, Val Loss: 8.1462
# 📉 Epoch 19/500 - Train Loss: 0.5686, Val Loss: 8.3150
# 📉 Epoch 20/500 - Train Loss: 0.5684, Val Loss: 7.8075
# 📉 Epoch 21/500 - Train Loss: 0.5660, Val Loss: 7.2327
# 📉 Epoch 22/500 - Train Loss: 0.5660, Val Loss: 7.6542
# 📉 Epoch 23/500 - Train Loss: 0.5659, Val Loss: 7.4682
# 📉 Epoch 24/500 - Train Loss: 0.5658, Val Loss: 7.8496
# 📉 Epoch 25/500 - Train Loss: 0.5635, Val Loss: 7.6763
# 📉 Epoch 26/500 - Train Loss: 0.5617, Val Loss: 7.5476
# 📉 Epoch 27/500 - Train Loss: 0.5630, Val Loss: 7.3008
# 📉 Epoch 28/500 - Train Loss: 0.5612, Val Loss: 7.2724
# 📉 Epoch 29/500 - Train Loss: 0.5605, Val Loss: 7.0373
# 📉 Epoch 30/500 - Train Loss: 0.5655, Val Loss: 7.8337
# 📉 Epoch 31/500 - Train Loss: 0.5607, Val Loss: 7.7053
# 📉 Epoch 32/500 - Train Loss: 0.5588, Val Loss: 7.5968
# 📉 Epoch 33/500 - Train Loss: 0.5582, Val Loss: 7.3344
# 📉 Epoch 34/500 - Train Loss: 0.5585, Val Loss: 7.5877
# 📉 Epoch 35/500 - Train Loss: 0.5577, Val Loss: 7.5196
# 📉 Epoch 36/500 - Train Loss: 0.5567, Val Loss: 7.6084
# 📉 Epoch 37/500 - Train Loss: 0.5569, Val Loss: 7.5131
# 📉 Epoch 38/500 - Train Loss: 0.5555, Val Loss: 7.4895
# 📉 Epoch 39/500 - Train Loss: 0.5548, Val Loss: 7.5085
# 📉 Epoch 40/500 - Train Loss: 0.5548, Val Loss: 7.6008
# 📉 Epoch 41/500 - Train Loss: 0.5556, Val Loss: 7.2949
# 📉 Epoch 42/500 - Train Loss: 0.5528, Val Loss: 7.5228
# 📉 Epoch 43/500 - Train Loss: 0.5537, Val Loss: 7.6645
# 📉 Epoch 44/500 - Train Loss: 0.5535, Val Loss: 7.7989
# 📉 Epoch 45/500 - Train Loss: 0.5516, Val Loss: 7.4379
# 📉 Epoch 46/500 - Train Loss: 0.5524, Val Loss: 7.2238
# 📉 Epoch 47/500 - Train Loss: 0.5512, Val Loss: 7.7451
# 📉 Epoch 48/500 - Train Loss: 0.5509, Val Loss: 7.5657
# 📉 Epoch 49/500 - Train Loss: 0.5501, Val Loss: 7.1912
# ⏹️ Early stopping triggered at epoch 49. Best epoch: 29, Best Val Loss: 7.0373
# ✅ Model saved at: saved_models\bias_predictor_run_9.pth
# ⚡ Run 10/10
# 📉 Epoch 1/500 - Train Loss: 0.6713, Val Loss: 9.8121
# 📉 Epoch 2/500 - Train Loss: 0.6308, Val Loss: 10.3251
# 📉 Epoch 3/500 - Train Loss: 0.6183, Val Loss: 10.6267
# 📉 Epoch 4/500 - Train Loss: 0.6113, Val Loss: 10.5910
# 📉 Epoch 5/500 - Train Loss: 0.6054, Val Loss: 10.6607
# 📉 Epoch 6/500 - Train Loss: 0.5985, Val Loss: 10.7426
# 📉 Epoch 7/500 - Train Loss: 0.5930, Val Loss: 10.6532
# 📉 Epoch 8/500 - Train Loss: 0.5868, Val Loss: 10.6157
# 📉 Epoch 9/500 - Train Loss: 0.5820, Val Loss: 10.5995
# 📉 Epoch 10/500 - Train Loss: 0.5808, Val Loss: 9.7081
# 📉 Epoch 11/500 - Train Loss: 0.5744, Val Loss: 9.5528
# 📉 Epoch 12/500 - Train Loss: 0.5741, Val Loss: 9.3108
# 📉 Epoch 13/500 - Train Loss: 0.5718, Val Loss: 8.9083
# 📉 Epoch 14/500 - Train Loss: 0.5690, Val Loss: 8.6631
# 📉 Epoch 15/500 - Train Loss: 0.5689, Val Loss: 8.4678
# 📉 Epoch 16/500 - Train Loss: 0.5749, Val Loss: 8.9733
# 📉 Epoch 17/500 - Train Loss: 0.5660, Val Loss: 8.3777
# 📉 Epoch 18/500 - Train Loss: 0.5651, Val Loss: 8.9102
# 📉 Epoch 19/500 - Train Loss: 0.5677, Val Loss: 8.2393
# 📉 Epoch 20/500 - Train Loss: 0.5641, Val Loss: 8.4238
# 📉 Epoch 21/500 - Train Loss: 0.5639, Val Loss: 8.3117
# 📉 Epoch 22/500 - Train Loss: 0.5635, Val Loss: 7.8536
# 📉 Epoch 23/500 - Train Loss: 0.5641, Val Loss: 8.2009
# 📉 Epoch 24/500 - Train Loss: 0.5644, Val Loss: 8.0890
# 📉 Epoch 25/500 - Train Loss: 0.5616, Val Loss: 7.9197
# 📉 Epoch 26/500 - Train Loss: 0.5623, Val Loss: 7.8756
# 📉 Epoch 27/500 - Train Loss: 0.5621, Val Loss: 8.2999
# 📉 Epoch 28/500 - Train Loss: 0.5622, Val Loss: 8.3853
# 📉 Epoch 29/500 - Train Loss: 0.5599, Val Loss: 8.2778
# 📉 Epoch 30/500 - Train Loss: 0.5598, Val Loss: 8.0257
# 📉 Epoch 31/500 - Train Loss: 0.5593, Val Loss: 7.8780
# 📉 Epoch 32/500 - Train Loss: 0.5602, Val Loss: 7.6386
# 📉 Epoch 33/500 - Train Loss: 0.5580, Val Loss: 7.9364
# 📉 Epoch 34/500 - Train Loss: 0.5589, Val Loss: 8.3620
# 📉 Epoch 35/500 - Train Loss: 0.5592, Val Loss: 8.4584
# 📉 Epoch 36/500 - Train Loss: 0.5588, Val Loss: 7.3654
# 📉 Epoch 37/500 - Train Loss: 0.5555, Val Loss: 8.0845
# 📉 Epoch 38/500 - Train Loss: 0.5559, Val Loss: 7.6947
# 📉 Epoch 39/500 - Train Loss: 0.5541, Val Loss: 7.6987
# 📉 Epoch 40/500 - Train Loss: 0.5572, Val Loss: 8.1699
# 📉 Epoch 41/500 - Train Loss: 0.5548, Val Loss: 7.6292
# 📉 Epoch 42/500 - Train Loss: 0.5543, Val Loss: 7.8422
# 📉 Epoch 43/500 - Train Loss: 0.5560, Val Loss: 8.1375
# 📉 Epoch 44/500 - Train Loss: 0.5529, Val Loss: 7.9271
# 📉 Epoch 45/500 - Train Loss: 0.5513, Val Loss: 7.9917
# 📉 Epoch 46/500 - Train Loss: 0.5482, Val Loss: 7.4471
# 📉 Epoch 47/500 - Train Loss: 0.5532, Val Loss: 8.2614
# 📉 Epoch 48/500 - Train Loss: 0.5514, Val Loss: 7.3878
# 📉 Epoch 49/500 - Train Loss: 0.5520, Val Loss: 7.6545
# 📉 Epoch 50/500 - Train Loss: 0.5502, Val Loss: 7.6991
# 📉 Epoch 51/500 - Train Loss: 0.5519, Val Loss: 8.3077
# 📉 Epoch 52/500 - Train Loss: 0.5528, Val Loss: 8.0540
# 📉 Epoch 53/500 - Train Loss: 0.5510, Val Loss: 8.0179
# 📉 Epoch 54/500 - Train Loss: 0.5491, Val Loss: 7.5755
# 📉 Epoch 55/500 - Train Loss: 0.5488, Val Loss: 7.8464
# 📉 Epoch 56/500 - Train Loss: 0.5481, Val Loss: 7.7318
# ⏹️ Early stopping triggered at epoch 56. Best epoch: 36, Best Val Loss: 7.3654
# ✅ Model saved at: saved_models\bias_predictor_run_10.pth

# %%
# Plot all 10 runs in subplots (2 rows, 5 columns)
fig, axes = plt.subplots(2, 5, figsize=(25, 10))
fig.suptitle("Actual vs Predicted Values (10 Runs)")

for i, ax in enumerate(axes.flatten()):
    ax.plot(temp_df[f"New_predictions_arr_SHAP_run_{i+1}"].iloc[train_size+val_size:], label='Array input predictions (SHAP)', color='blue')
    ax.plot(temp_df["New_predictions_arr"].iloc[train_size+val_size:], label='Array input predictions', color='purple')
    ax.plot(temp_df["New_predictions_uni"].iloc[train_size+val_size:], label='Single input predictions', color='red')
    ax.plot(temp_df["Target"].iloc[train_size+val_size:], label='True Values', color='green')
    ax.set_title(f"Run {i+1}")
    ax.set_xlabel('Time')
    ax.set_ylabel('Value')
    ax.legend()

plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# Compute statistics for error percentages
error_stats = {
    "Mean Error %": np.mean(error_percentages),
    "Std Dev Error %": np.std(error_percentages),
    "Min Error %": np.min(error_percentages),
    "Max Error %": np.max(error_percentages),
}

# Print statistics
print("📊 Error Percentage Statistics For Each Run:\n")
count = 1
for error in error_percentages:
    print(f"Run {count} Error Percentage: {error:.4f}%")
    count += 1
print("\n📊 Error Percentage Statistics Across 10 Runs:\n")
for key, value in error_stats.items():
    print(f"{key}: {value:.4f}%")
  
print("------------------------------------------------------------------------------------------")  
original_LSTM_error_percent = np.mean(np.abs(temp_df["Target"].iloc[train_size+val_size:].values - temp_df["LSTM_prediction_original"].iloc[train_size+val_size:].values) / (np.abs(temp_df["Target"].iloc[train_size+val_size:].values) + 1e-8)) * 100
uni_input_error_percent = np.mean(np.abs(temp_df["Target"].iloc[train_size+val_size:].values - temp_df["New_predictions_uni"].iloc[train_size+val_size:].values) / (np.abs(temp_df["Target"].iloc[train_size+val_size:].values) + 1e-8)) * 100
arr_input_error_percent = np.mean(np.abs(temp_df["Target"].iloc[train_size+val_size:].values - temp_df["New_predictions_arr"].iloc[train_size+val_size:].values) / (np.abs(temp_df["Target"].iloc[train_size+val_size:].values) + 1e-8)) * 100
print(f"Original LSTM Error Percentage: {original_LSTM_error_percent:.4f}%")
print(f"Uni input bias prediction Error Percentage: {uni_input_error_percent:.4f}%")
print(f"Arr input bias prediction Error Percentage: {arr_input_error_percent:.4f}%")
# Out:
# 📊 Error Percentage Statistics For Each Run:
#
# Run 1 Error Percentage: 7.9366%
# Run 2 Error Percentage: 7.4970%
# Run 3 Error Percentage: 8.4958%
# Run 4 Error Percentage: 9.0683%
# Run 5 Error Percentage: 8.0763%
# Run 6 Error Percentage: 9.1066%
# Run 7 Error Percentage: 9.2072%
# Run 8 Error Percentage: 8.8472%
# Run 9 Error Percentage: 8.3545%
# Run 10 Error Percentage: 8.7580%
#
# 📊 Error Percentage Statistics Across 10 Runs:
#
# Mean Error %: 8.5348%
# Std Dev Error %: 0.5376%
# Min Error %: 7.4970%
# Max Error %: 9.2072%
# ------------------------------------------------------------------------------------------
# Original LSTM Error Percentage: 10.8221%
# Uni input bias prediction Error Percentage: 10.4940%
# Arr input bias prediction Error Percentage: 9.7021%
