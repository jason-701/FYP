# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
from numpy.linalg import norm

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# Load the data
file_path = "../SPY_section_3.csv"
df = pd.read_csv(file_path)

# %%
# Define Autoencoder
class Autoencoder(nn.Module):
    def __init__(self, input_dim, encoding_dim, dropout_rate):
        super(Autoencoder, self).__init__()
        self.encoder = nn.Sequential(
            nn.Linear(input_dim, 128),
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.Linear(64, encoding_dim)
        )
        self.decoder = nn.Sequential(
            nn.Linear(encoding_dim, 64),
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.Linear(64, 128),
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.Linear(128, input_dim)
        )
    
    def forward(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return decoded

# %%
# Define LSTM model
class ComplexLSTMModel(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, dropout_rate):
        super(ComplexLSTMModel, self).__init__()
        # Unidirectional LSTM for sequential stock price prediction
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers,
                            batch_first=True, dropout=dropout_rate)  # Removed bidirectional=True

        # Fully connected layers for added complexity
        self.fc1 = nn.Linear(hidden_size, hidden_size // 2)
        self.dropout1 = nn.Dropout(dropout_rate)
        self.fc2 = nn.Linear(hidden_size // 2, hidden_size // 4)
        self.dropout2 = nn.Dropout(dropout_rate)
        self.fc3 = nn.Linear(hidden_size // 4, 1)

    def forward(self, x):
        # LSTM expects input of shape (batch_size, sequence_length, input_size)
        out, _ = self.lstm(x)
        # Use the output of the last time step
        out = out[:, -1, :]  # Shape: (batch_size, hidden_size)

        out = torch.relu(self.fc1(out))  # First fully connected layer
        out = self.dropout1(out)
        out = torch.relu(self.fc2(out))  # Second fully connected layer
        out = self.dropout2(out)
        out = self.fc3(out)  # Output layer (no activation for regression)
        return out
    
    
sequence_length = 10

# Reshape data into sequences
def create_sequences(data, target, seq_length):
    X_seq, y_seq = [], []
    for i in range(len(data) - seq_length):
        X_seq.append(data[i:i + seq_length])
        y_seq.append(target[i + seq_length])
    return np.array(X_seq), np.array(y_seq)

# %%
# Define the target variable
if "Target" not in df.columns:
    # df["Target"] = (df["Close"].shift(-1) > df["Close"]).astype(int)
    df["Target"] = df["Close"].shift(-1)
df = df.dropna()

# %%
# Adding SMA and EMA to the feature
short_term_period = 20
medium_term_period = 50
long_term_period = 200

# Compute the SMAs
df['SMA_20'] = df['Close'].rolling(window=short_term_period).mean() # Short-term SMA
df['SMA_50'] = df['Close'].rolling(window=medium_term_period).mean() # Medium-term SMA
df['SMA_200'] = df['Close'].rolling(window=long_term_period).mean() # Long-term SMA

df['EMA_10'] = df['Close'].ewm(span=10, adjust=False).mean()  # Short-term EMA
df['EMA_50'] = df['Close'].ewm(span=50, adjust=False).mean()  # Medium-term EMA
df['EMA_200'] = df['Close'].ewm(span=200, adjust=False).mean()  # Long-term EMA

df = df.dropna()

# %%
X = df.drop(columns=["Date", "Target"])
y = df["Target"]

feature_columns = ["Open", "High", "Low", "Close", "Volume", "SMA_20", "SMA_50", "SMA_200", "EMA_10", "EMA_50", "EMA_200"]

train_size = int(X.shape[0] * 0.7)
val_size = int(X.shape[0] * 0.15)

scaler = MinMaxScaler()

# Split data into train, validation, and test
temp_train = X[:train_size]
temp_val = X[train_size:train_size + val_size]
temp_test = X[train_size + val_size:]

temp_train = temp_train[feature_columns]
temp_val = temp_val[feature_columns]
temp_test = temp_test[feature_columns]

# Fit and transform for train, transform for validation and test
temp_train = scaler.fit_transform(temp_train)
temp_val = scaler.transform(temp_val)
temp_test = scaler.transform(temp_test)

# Convert NumPy arrays back to DataFrames
temp_train = pd.DataFrame(temp_train, columns=feature_columns)
temp_val = pd.DataFrame(temp_val, columns=feature_columns)
temp_test = pd.DataFrame(temp_test, columns=feature_columns)

# Concatenate the data
X_scaled = pd.concat([temp_train, temp_val, temp_test], axis=0)

X_seq, y_seq = create_sequences(X_scaled, y.values, sequence_length)

# Split sequentially
X_train, y_train = X_seq[:train_size], y_seq[:train_size]
X_val, y_val = X_seq[train_size:train_size + val_size], y_seq[train_size:train_size + val_size]
X_test, y_test = X_seq[train_size + val_size:], y_seq[train_size + val_size:]

# Print sizes to confirm
print(f"Train: {len(X_train)}, Val: {len(X_val)}, Test: {len(X_test)}")
print(X_scaled.shape)
# Out:
# Train: 1768, Val: 379, Test: 370
# (2527, 11)

# %%
# Convert to PyTorch tensors
X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train, dtype=torch.float32)
X_val_tensor = torch.tensor(X_val, dtype=torch.float32)
y_val_tensor = torch.tensor(y_val, dtype=torch.float32)
X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test, dtype=torch.float32)

# Create DataLoaders
train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
val_dataset = TensorDataset(X_val_tensor, y_val_tensor)
test_dataset = TensorDataset(X_test_tensor, y_test_tensor)

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=64, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

# %% [markdown]
# <span style="color: yellow; font-size: 40px;">Evaluating original LSTM</span>

# %%
# Hyperparameters
input_size = X_train.shape[2]  # Number of features
hidden_size = 128
num_layers = 2
dropout_rate = 0.1
learning_rate = 0.0005
num_epochs = 500
patience = 30

# %%
# Define paths
LSTM_model_path = "../lstm_codes/lstm_models/lstm_section_3.pth"
# Load the trained model
LSTM_model = ComplexLSTMModel(input_size=input_size, hidden_size=hidden_size, num_layers=num_layers, dropout_rate=dropout_rate).to(device)
LSTM_model.load_state_dict(torch.load(LSTM_model_path))
LSTM_model.eval()

# Define loss function
criterion = torch.nn.MSELoss()

# Evaluate on test data
test_loss = 0.0
test_mae = 0.0
all_true = []
all_preds = []

with torch.no_grad():
    for X_batch, y_batch in test_loader:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)
        outputs = LSTM_model(X_batch)
        loss = criterion(outputs, y_batch)
        mae = torch.mean(torch.abs(outputs - y_batch))
        
        test_loss += loss.item() * X_batch.size(0)
        test_mae += mae.item() * X_batch.size(0)
        
        all_true.extend(y_batch.cpu().numpy())
        all_preds.extend(outputs.cpu().numpy())

# Compute final metrics
test_loss /= len(test_loader.dataset)
test_mae /= len(test_loader.dataset)

# Compute error percentages
all_true = np.array(all_true).flatten()
all_preds = np.array(all_preds).flatten()
error = np.abs(all_true - all_preds) / (np.abs(all_true) + 1e-8)
avg_error = np.mean(error) * 100
largest_error = np.max(error) * 100

# Print results
print("\n===== Evaluation Results =====")
print(f"Test Loss: {test_loss:.4f}")
print(f"Test MAE: {test_mae:.4f}")
print(f"Average Error Percentage: {avg_error:.2f}%")
print(f"Largest Error Percentage: {largest_error:.2f}%")

# Plot actual vs predicted values
plt.figure(figsize=(10, 5))
plt.plot(all_true, label='True Values', color='blue')
plt.plot(all_preds, label='Predicted Values', color='red')
plt.xlabel('Time')
plt.ylabel('Value')
plt.title('Actual vs. Predicted Values')
plt.legend()
plt.show()
# Out:
# C:\Users\ROG\AppData\Local\Temp/ipykernel_25856/4192910867.py:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   LSTM_model.load_state_dict(torch.load(LSTM_model_path))
# d:\Anaconda\lib\site-packages\torch\nn\modules\loss.py:538: UserWarning: Using a target size (torch.Size([64])) that is different to the input size (torch.Size([64, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# d:\Anaconda\lib\site-packages\torch\nn\modules\loss.py:538: UserWarning: Using a target size (torch.Size([50])) that is different to the input size (torch.Size([50, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# ===== Evaluation Results =====
# Test Loss: 1275.9282
# Test MAE: 30.6079
# Average Error Percentage: 10.94%
# Largest Error Percentage: 23.87%

# %% [markdown]
# <span style="color: yellow; font-size: 40px;">Evaluating original autoencoder</span>

# %%
X_train = X_scaled[:train_size]
X_val = X_scaled[train_size:train_size + val_size]
X_test = X_scaled[train_size + val_size:]

# %%
X_train = X_train.values
X_val = X_val.values
X_test = X_test.values

# %%
# Convert data to PyTorch tensors
X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
X_val_tensor = torch.tensor(X_val, dtype=torch.float32)
X_test_tensor = torch.tensor(X_test, dtype=torch.float32)

# Create DataLoader
train_dataset = TensorDataset(X_train_tensor, X_train_tensor)
val_dataset = TensorDataset(X_val_tensor, X_val_tensor)
test_dataset = TensorDataset(X_test_tensor, X_test_tensor)
train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=16, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=16, shuffle=False)

# %%
input_dim = X_train.shape[1]

# Hyperparameters
encoding_dim = 5
learning_rate = 0.0005
dropout_rate = 0.3
epochs = 750
batch_size = 16
patience = 40

# %%
autoencoder_model_path = "../autoencoder_codes/autoencoder_models/autoencoder_section_3.pth"
autoencoder_model = Autoencoder(input_dim=input_dim, encoding_dim=encoding_dim, dropout_rate=dropout_rate).to(device)
autoencoder_model.load_state_dict(torch.load(autoencoder_model_path))
# Out:
# C:\Users\ROG\AppData\Local\Temp/ipykernel_25856/633403455.py:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   autoencoder_model.load_state_dict(torch.load(autoencoder_model_path))
# <All keys matched successfully>

# %%
autoencoder_model.eval()
with torch.no_grad():
    reconstructed_test = autoencoder_model(torch.tensor(X_test, dtype=torch.float32).to(device)).cpu().numpy()
mse = np.mean((X_test - reconstructed_test) ** 2)
mae = np.mean(np.abs(X_test - reconstructed_test))
ree = np.mean(np.linalg.norm(X_test - reconstructed_test, axis=1) / np.linalg.norm(X_test, axis=1))
euclidean_dist = np.mean([norm(X_test[i] - reconstructed_test[i]) for i in range(len(X_test))])
reconstruction_error_percentage = (
    np.mean(np.abs(X_test - reconstructed_test) / (np.abs(X_test) + 1e-8), axis=1) * 100
)
average_error = np.mean(reconstruction_error_percentage)
print(f'MSE: {mse:.4f}, MAE: {mae:.4f}, REE: {ree:.4f}, Euclidean Distance: {euclidean_dist:.4f}, Average Error: {average_error:.4f}%')
# Out:
# MSE: 0.0052, MAE: 0.0563, REE: 0.0482, Euclidean Distance: 0.2232, Average Error: 38.4449%

# %%
# Scatter plot of reconstruction error percentage
plt.figure(figsize=(10, 5))
plt.scatter(range(len(reconstruction_error_percentage)), reconstruction_error_percentage, alpha=0.5)
plt.ylim(0, 50)
plt.xlabel('Sample')
plt.ylabel('Reconstruction Error Percentage')
plt.title('Reconstruction Error Percentage')
plt.show()

# %% [markdown]
# <span style="color: yellow; font-size: 40px;">Bias correction model - single input</span>

# %%
# import torch
# import torch.nn as nn
# import torch.nn.functional as F

# class BiasPredictor(nn.Module):
#     def __init__(self, input_size, hidden_size1, dropout_rate):
#         super(BiasPredictor, self).__init__()
        
#         hidden_size2 = hidden_size1 // 2
#         hidden_size3 = hidden_size2 // 2
#         hidden_size4 = hidden_size3 // 2  # New additional layer

#         self.fc1 = nn.Linear(input_size, hidden_size1)
#         self.dropout1 = nn.Dropout(dropout_rate)
        
#         self.fc2 = nn.Linear(hidden_size1, hidden_size2)
#         self.dropout2 = nn.Dropout(dropout_rate)
        
#         self.fc3 = nn.Linear(hidden_size2, hidden_size3)
#         self.dropout3 = nn.Dropout(dropout_rate)

#         self.fc4 = nn.Linear(hidden_size3, hidden_size4)  # New additional layer
#         self.dropout4 = nn.Dropout(dropout_rate)

#         self.fc5 = nn.Linear(hidden_size4, 1)  # Final output layer

#     def forward(self, x):
#         x = F.relu(self.fc1(x))
#         x = self.dropout1(x)
        
#         x = F.relu(self.fc2(x))
#         x = self.dropout2(x)
        
#         x = F.relu(self.fc3(x))
#         x = self.dropout3(x)

#         x = F.relu(self.fc4(x))  # New layer
#         x = self.dropout4(x)

#         return self.fc5(x)



import torch
import torch.nn as nn
import torch.nn.functional as F

class BiasPredictor(nn.Module):
    def __init__(self, input_size, hidden_size, dropout_rate):
        super(BiasPredictor, self).__init__()

        hidden_size2 = hidden_size // 2

        # Define layers
        self.fc1 = nn.Linear(input_size, hidden_size)
        self.dropout1 = nn.Dropout(dropout_rate)

        self.fc2 = nn.Linear(hidden_size, hidden_size2)
        self.dropout2 = nn.Dropout(dropout_rate)

        self.fc3 = nn.Linear(hidden_size2, 1) 

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = self.dropout1(x)

        x = F.relu(self.fc2(x))
        x = self.dropout2(x)

        return self.fc3(x)

# %%
# Get LSTM predictions of entire dataset
with torch.no_grad():
    X_tensor = torch.tensor(X_seq, dtype=torch.float32).to(device)
    LSTM_preds = LSTM_model(X_tensor).cpu().numpy()
    
# Put LSTM predictions into a new DataFrame
new_df = pd.DataFrame(LSTM_preds, columns=["LSTM_Pred"])

# %%
# Drop the first sequence_length rows
temp_y = y
temp_y = temp_y[sequence_length:]

# add the target variable to the new DataFrame
new_df["Target"] = temp_y.values

# %%
# Get reconstruction error percentage for the entire dataset
autoencoder_model.eval()
with torch.no_grad():
    reconstructed = autoencoder_model(torch.tensor(X_scaled.values, dtype=torch.float32).to(device)).cpu().numpy()
    
# Compute the MAE
reconstruction_error = np.mean(np.abs(X_scaled.values - reconstructed), axis=1)

# Compute the reconstruction error percentage
# reconstruction_error = np.mean(np.abs(X_scaled.values - reconstructed) / (np.abs(X_scaled.values) + 1e-8), axis=1) * 100
# reconstruction_error = np.mean((X_scaled.values - reconstructed) / ((X_scaled.values) + 1e-8), axis=1) * 100

# Drop the first sequence_length rows
reconstruction_error_new = reconstruction_error[sequence_length:]

# Add the reconstruction error to the new DataFrame
new_df["Reconstruction_error_single"] = reconstruction_error_new

# Get reconstruction error arr of past 10 days
reconstruction_error_arr = []
for i in range(sequence_length, len(reconstruction_error)):
    reconstruction_error_arr.append(reconstruction_error[i - sequence_length:i])
    

# Add the reconstruction error array to the new DataFrame
new_df["Reconstruction_error_arr"] = reconstruction_error_arr

# %%
# plot reconstruction error scatter plot
plt.figure(figsize=(10, 5))
plt.scatter(range(len(reconstruction_error)), reconstruction_error, alpha=0.5)
plt.ylim(0, 0.5)
plt.xlabel('Sample')
# plt.ylabel('Reconstruction Error Percentage')
# plt.title('Reconstruction Error Percentage')
plt.ylabel('Reconstruction Error MAE')
plt.title('Reconstruction Error MAE')
plt.show()

# %%
reconstruction_error_arr[0]
# Out:
# array([0.01112294, 0.01061798, 0.01121775, 0.01175785, 0.01235987,
#        0.01201896, 0.01181609, 0.00948298, 0.00851218, 0.0115408 ])

# %%
# Calculate the difference between the target and LSTM prediction
new_df["Bias"] = new_df["Target"] - new_df["LSTM_Pred"]

# %%
y = new_df["Bias"]
X = new_df["Reconstruction_error_single"]
# X = new_df["Reconstruction_error_arr"]

# %%
# Sequential split
train_size = int(0.7 * len(X))
val_size = int(0.15 * len(X))

X_train_raw = X[:train_size]
y_train_raw = y[:train_size]
X_val_raw = X[train_size:train_size + val_size]
y_val_raw = y[train_size:train_size + val_size]
X_test_raw = X[train_size + val_size:]
y_test_raw = y[train_size + val_size:]

# Scale using StandardScaler (fit only on train data)
# X_scaler = StandardScaler()
X_scaler = RobustScaler()
X_train_scaled = X_scaler.fit_transform(X_train_raw.values.reshape(-1, 1))
X_val_scaled = X_scaler.transform(X_val_raw.values.reshape(-1, 1))
X_test_scaled = X_scaler.transform(X_test_raw.values.reshape(-1, 1))

# y_scaler = StandardScaler()
y_scaler = RobustScaler()
y_train_scaled = y_scaler.fit_transform(y_train_raw.values.reshape(-1, 1))
y_val_scaled = y_scaler.transform(y_val_raw.values.reshape(-1, 1))
y_test_scaled = y_scaler.transform(y_test_raw.values.reshape(-1, 1))

# Convert data to PyTorch tensors
X_train = torch.tensor(X_train_scaled, dtype=torch.float32).unsqueeze(1)
y_train = torch.tensor(y_train_scaled, dtype=torch.float32).unsqueeze(1)
X_val = torch.tensor(X_val_scaled, dtype=torch.float32).unsqueeze(1)
y_val = torch.tensor(y_val_scaled, dtype=torch.float32).unsqueeze(1)
X_test = torch.tensor(X_test_scaled, dtype=torch.float32).unsqueeze(1)
y_test = torch.tensor(y_test_scaled, dtype=torch.float32).unsqueeze(1)

# Print sizes
print(f"Train: {len(X_train)}, Val: {len(X_val)}, Test: {len(X_test)}")
# Out:
# Train: 1761, Val: 377, Test: 379

# %%
# Create DataLoader
train_dataset = TensorDataset(X_train, y_train)
val_dataset = TensorDataset(X_val, y_val)
test_dataset = TensorDataset(X_test, y_test)
train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=16, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=16, shuffle=False)

import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import os
from torch.utils.data import DataLoader, TensorDataset

# Directory to save the models
save_dir = "uni_input_trials"
os.makedirs(save_dir, exist_ok=True)

# Number of trials
num_trials = 10

# Training parameters
input_size = 1
hidden_size = 16
dropout_rate = 0.2
learning_rate = 0.0001
num_epochs = 500
patience = 20

# To store predictions for each trial
all_predictions = {}

for trial in range(num_trials):
    print(f"Starting trial {trial + 1}/{num_trials}")

    # Initialize model, loss function, and optimizer
    bias_model = BiasPredictor(input_size=input_size, hidden_size=hidden_size, dropout_rate=dropout_rate).to(device)
    criterion = nn.MSELoss()
    optimizer = optim.Adam(bias_model.parameters(), lr=learning_rate)

    best_val_loss = np.inf
    best_epoch = 0
    best_model_state = None  # Store best model state

    # Training loop
    for epoch in range(num_epochs):
        bias_model.train()
        train_loss = 0.0
        for X_batch, y_batch in train_loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)
            optimizer.zero_grad()
            outputs = bias_model(X_batch)
            loss = criterion(outputs, y_batch)
            loss.backward()
            optimizer.step()
            train_loss += loss.item() * X_batch.size(0)

        train_loss /= len(train_loader.dataset)

        # Validation loop
        bias_model.eval()
        val_loss = 0.0
        with torch.no_grad():
            for X_batch, y_batch in val_loader:
                X_batch, y_batch = X_batch.to(device), y_batch.to(device)
                outputs = bias_model(X_batch)
                loss = criterion(outputs, y_batch)
                val_loss += loss.item() * X_batch.size(0)

        val_loss /= len(val_loader.dataset)

        if val_loss < best_val_loss:
            best_val_loss = val_loss
            best_epoch = epoch
            best_model_state = bias_model.state_dict()  # Save the best model state

        elif epoch - best_epoch >= patience:
            print(f"Trial {trial + 1}: Stopping early at epoch {epoch}")
            break

        print(f"Trial {trial + 1}, Epoch {epoch}, Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}")

    # Save the best model from this trial
    if best_model_state is not None:
        model_filename = os.path.join(save_dir, f"bias_model_trial_{trial + 1}.pth")
        torch.save(best_model_state, model_filename)
        print(f"Saved model for Trial {trial + 1} to {model_filename}")

        # Load best model and generate predictions
        bias_model.load_state_dict(best_model_state)
        bias_model.eval()
        
        with torch.no_grad():
            combined_X = torch.cat((X_train, X_val, X_test), dim=0).to(device)
            y_pred = bias_model(combined_X).cpu().numpy()

        outputs_unscaled = y_scaler.inverse_transform(y_pred.reshape(y_pred.shape[0], -1))
        
        # Store predictions for this trial
        all_predictions[f"trial_{trial + 1}"] = outputs_unscaled

print("Completed all trials and saved models & predictions!")
# Out:
# Starting trial 1/10
# Trial 1, Epoch 0, Train Loss: 0.7340, Val Loss: 13.4140
# Trial 1, Epoch 1, Train Loss: 0.7088, Val Loss: 13.2359
# Trial 1, Epoch 2, Train Loss: 0.6821, Val Loss: 13.1029
# Trial 1, Epoch 3, Train Loss: 0.6627, Val Loss: 12.9901
# Trial 1, Epoch 4, Train Loss: 0.6469, Val Loss: 12.9237
# Trial 1, Epoch 5, Train Loss: 0.6347, Val Loss: 12.8436
# Trial 1, Epoch 6, Train Loss: 0.6322, Val Loss: 12.7593
# Trial 1, Epoch 7, Train Loss: 0.6263, Val Loss: 12.6995
# Trial 1, Epoch 8, Train Loss: 0.6256, Val Loss: 12.6457
# Trial 1, Epoch 9, Train Loss: 0.6121, Val Loss: 12.6299
# Trial 1, Epoch 10, Train Loss: 0.6140, Val Loss: 12.6074
# Trial 1, Epoch 11, Train Loss: 0.6152, Val Loss: 12.5720
# Trial 1, Epoch 12, Train Loss: 0.6120, Val Loss: 12.5379
# Trial 1, Epoch 13, Train Loss: 0.6129, Val Loss: 12.5043
# Trial 1, Epoch 14, Train Loss: 0.6081, Val Loss: 12.4879
# Trial 1, Epoch 15, Train Loss: 0.6155, Val Loss: 12.4406
# Trial 1, Epoch 16, Train Loss: 0.6126, Val Loss: 12.4146
# Trial 1, Epoch 17, Train Loss: 0.6102, Val Loss: 12.3945
# Trial 1, Epoch 18, Train Loss: 0.6077, Val Loss: 12.3733
# Trial 1, Epoch 19, Train Loss: 0.6089, Val Loss: 12.3582
# Trial 1, Epoch 20, Train Loss: 0.6093, Val Loss: 12.3366
# Trial 1, Epoch 21, Train Loss: 0.6092, Val Loss: 12.3301
# Trial 1, Epoch 22, Train Loss: 0.6162, Val Loss: 12.2945
# Trial 1, Epoch 23, Train Loss: 0.6094, Val Loss: 12.2885
# Trial 1, Epoch 24, Train Loss: 0.6105, Val Loss: 12.2660
# Trial 1, Epoch 25, Train Loss: 0.6143, Val Loss: 12.2456
# Trial 1, Epoch 26, Train Loss: 0.6119, Val Loss: 12.2376
# Trial 1, Epoch 27, Train Loss: 0.6109, Val Loss: 12.2302
# Trial 1, Epoch 28, Train Loss: 0.6083, Val Loss: 12.2234
# Trial 1, Epoch 29, Train Loss: 0.6057, Val Loss: 12.2072
# Trial 1, Epoch 30, Train Loss: 0.6069, Val Loss: 12.2200
# Trial 1, Epoch 31, Train Loss: 0.6049, Val Loss: 12.2400
# Trial 1, Epoch 32, Train Loss: 0.6096, Val Loss: 12.2401
# Trial 1, Epoch 33, Train Loss: 0.6006, Val Loss: 12.2518
# Trial 1, Epoch 34, Train Loss: 0.6123, Val Loss: 12.2214
# Trial 1, Epoch 35, Train Loss: 0.6109, Val Loss: 12.1922
# Trial 1, Epoch 36, Train Loss: 0.6113, Val Loss: 12.1811
# Trial 1, Epoch 37, Train Loss: 0.6043, Val Loss: 12.1933
# Trial 1, Epoch 38, Train Loss: 0.6080, Val Loss: 12.1754
# Trial 1, Epoch 39, Train Loss: 0.6087, Val Loss: 12.1687
# Trial 1, Epoch 40, Train Loss: 0.6076, Val Loss: 12.1811
# Trial 1, Epoch 41, Train Loss: 0.6084, Val Loss: 12.1722
# Trial 1, Epoch 42, Train Loss: 0.6052, Val Loss: 12.1825
# Trial 1, Epoch 43, Train Loss: 0.6068, Val Loss: 12.1769
# Trial 1, Epoch 44, Train Loss: 0.6083, Val Loss: 12.1643
# Trial 1, Epoch 45, Train Loss: 0.6059, Val Loss: 12.1694
# Trial 1, Epoch 46, Train Loss: 0.6128, Val Loss: 12.1835
# Trial 1, Epoch 47, Train Loss: 0.6041, Val Loss: 12.2034
# Trial 1, Epoch 48, Train Loss: 0.6093, Val Loss: 12.1928
# Trial 1, Epoch 49, Train Loss: 0.6023, Val Loss: 12.2055
# Trial 1, Epoch 50, Train Loss: 0.6073, Val Loss: 12.1931
# Trial 1, Epoch 51, Train Loss: 0.6074, Val Loss: 12.1965
# Trial 1, Epoch 52, Train Loss: 0.6065, Val Loss: 12.1940
# Trial 1, Epoch 53, Train Loss: 0.6100, Val Loss: 12.1909
# Trial 1, Epoch 54, Train Loss: 0.6077, Val Loss: 12.1914
# Trial 1, Epoch 55, Train Loss: 0.6053, Val Loss: 12.2039
# Trial 1, Epoch 56, Train Loss: 0.6079, Val Loss: 12.1713
# Trial 1, Epoch 57, Train Loss: 0.6062, Val Loss: 12.1846
# Trial 1, Epoch 58, Train Loss: 0.6093, Val Loss: 12.1536
# Trial 1, Epoch 59, Train Loss: 0.6037, Val Loss: 12.1581
# Trial 1, Epoch 60, Train Loss: 0.6104, Val Loss: 12.1588
# Trial 1, Epoch 61, Train Loss: 0.6081, Val Loss: 12.1517
# Trial 1, Epoch 62, Train Loss: 0.6037, Val Loss: 12.1671
# Trial 1, Epoch 63, Train Loss: 0.6095, Val Loss: 12.1870
# Trial 1, Epoch 64, Train Loss: 0.6089, Val Loss: 12.1796
# Trial 1, Epoch 65, Train Loss: 0.6031, Val Loss: 12.2055
# Trial 1, Epoch 66, Train Loss: 0.6082, Val Loss: 12.2131
# Trial 1, Epoch 67, Train Loss: 0.6063, Val Loss: 12.2104
# Trial 1, Epoch 68, Train Loss: 0.6062, Val Loss: 12.2068
# Trial 1, Epoch 69, Train Loss: 0.6108, Val Loss: 12.2025
# Trial 1, Epoch 70, Train Loss: 0.6045, Val Loss: 12.2265
# Trial 1, Epoch 71, Train Loss: 0.6098, Val Loss: 12.2141
# Trial 1, Epoch 72, Train Loss: 0.6087, Val Loss: 12.2105
# Trial 1, Epoch 73, Train Loss: 0.6032, Val Loss: 12.2246
# Trial 1, Epoch 74, Train Loss: 0.6079, Val Loss: 12.2192
# Trial 1, Epoch 75, Train Loss: 0.6006, Val Loss: 12.2341
# Trial 1, Epoch 76, Train Loss: 0.6040, Val Loss: 12.2489
# Trial 1, Epoch 77, Train Loss: 0.6096, Val Loss: 12.2263
# Trial 1, Epoch 78, Train Loss: 0.6087, Val Loss: 12.2175
# Trial 1, Epoch 79, Train Loss: 0.6071, Val Loss: 12.2205
# Trial 1, Epoch 80, Train Loss: 0.6058, Val Loss: 12.2201
# Trial 1: Stopping early at epoch 81
# Saved model for Trial 1 to uni_input_trials\bias_model_trial_1.pth
# Starting trial 2/10
# Trial 2, Epoch 0, Train Loss: 0.6968, Val Loss: 7.4344
# Trial 2, Epoch 1, Train Loss: 0.6734, Val Loss: 7.6406
# Trial 2, Epoch 2, Train Loss: 0.6625, Val Loss: 7.8192
# Trial 2, Epoch 3, Train Loss: 0.6550, Val Loss: 7.9610
# Trial 2, Epoch 4, Train Loss: 0.6559, Val Loss: 8.1021
# Trial 2, Epoch 5, Train Loss: 0.6533, Val Loss: 8.2487
# Trial 2, Epoch 6, Train Loss: 0.6386, Val Loss: 8.3429
# Trial 2, Epoch 7, Train Loss: 0.6498, Val Loss: 8.4297
# Trial 2, Epoch 8, Train Loss: 0.6433, Val Loss: 8.5098
# Trial 2, Epoch 9, Train Loss: 0.6390, Val Loss: 8.5831
# Trial 2, Epoch 10, Train Loss: 0.6378, Val Loss: 8.6706
# Trial 2, Epoch 11, Train Loss: 0.6270, Val Loss: 8.7406
# Trial 2, Epoch 12, Train Loss: 0.6380, Val Loss: 8.8259
# Trial 2, Epoch 13, Train Loss: 0.6380, Val Loss: 8.8893
# Trial 2, Epoch 14, Train Loss: 0.6300, Val Loss: 8.9423
# Trial 2, Epoch 15, Train Loss: 0.6378, Val Loss: 8.9935
# Trial 2, Epoch 16, Train Loss: 0.6337, Val Loss: 9.0575
# Trial 2, Epoch 17, Train Loss: 0.6287, Val Loss: 9.1162
# Trial 2, Epoch 18, Train Loss: 0.6253, Val Loss: 9.1607
# Trial 2, Epoch 19, Train Loss: 0.6286, Val Loss: 9.2247
# Trial 2: Stopping early at epoch 20
# Saved model for Trial 2 to uni_input_trials\bias_model_trial_2.pth
# Starting trial 3/10
# Trial 3, Epoch 0, Train Loss: 0.6509, Val Loss: 8.9956
# Trial 3, Epoch 1, Train Loss: 0.6413, Val Loss: 9.1391
# Trial 3, Epoch 2, Train Loss: 0.6361, Val Loss: 9.2803
# Trial 3, Epoch 3, Train Loss: 0.6413, Val Loss: 9.4328
# Trial 3, Epoch 4, Train Loss: 0.6297, Val Loss: 9.5393
# Trial 3, Epoch 5, Train Loss: 0.6386, Val Loss: 9.6472
# Trial 3, Epoch 6, Train Loss: 0.6278, Val Loss: 9.7376
# Trial 3, Epoch 7, Train Loss: 0.6173, Val Loss: 9.8399
# Trial 3, Epoch 8, Train Loss: 0.6227, Val Loss: 9.9287
# Trial 3, Epoch 9, Train Loss: 0.6236, Val Loss: 10.0397
# Trial 3, Epoch 10, Train Loss: 0.6225, Val Loss: 10.1405
# Trial 3, Epoch 11, Train Loss: 0.6280, Val Loss: 10.2211
# Trial 3, Epoch 12, Train Loss: 0.6137, Val Loss: 10.3022
# Trial 3, Epoch 13, Train Loss: 0.6210, Val Loss: 10.3648
# Trial 3, Epoch 14, Train Loss: 0.6119, Val Loss: 10.4468
# Trial 3, Epoch 15, Train Loss: 0.6201, Val Loss: 10.5105
# Trial 3, Epoch 16, Train Loss: 0.6160, Val Loss: 10.5711
# Trial 3, Epoch 17, Train Loss: 0.6177, Val Loss: 10.6271
# Trial 3, Epoch 18, Train Loss: 0.6191, Val Loss: 10.6628
# Trial 3, Epoch 19, Train Loss: 0.6115, Val Loss: 10.7438
# Trial 3: Stopping early at epoch 20
# Saved model for Trial 3 to uni_input_trials\bias_model_trial_3.pth
# Starting trial 4/10
# Trial 4, Epoch 0, Train Loss: 0.7136, Val Loss: 9.4459
# Trial 4, Epoch 1, Train Loss: 0.6753, Val Loss: 9.6982
# Trial 4, Epoch 2, Train Loss: 0.6600, Val Loss: 9.9215
# Trial 4, Epoch 3, Train Loss: 0.6418, Val Loss: 10.1380
# Trial 4, Epoch 4, Train Loss: 0.6319, Val Loss: 10.2694
# Trial 4, Epoch 5, Train Loss: 0.6285, Val Loss: 10.3871
# Trial 4, Epoch 6, Train Loss: 0.6286, Val Loss: 10.4978
# Trial 4, Epoch 7, Train Loss: 0.6241, Val Loss: 10.5848
# Trial 4, Epoch 8, Train Loss: 0.6221, Val Loss: 10.6732
# Trial 4, Epoch 9, Train Loss: 0.6178, Val Loss: 10.7680
# Trial 4, Epoch 10, Train Loss: 0.6181, Val Loss: 10.8378
# Trial 4, Epoch 11, Train Loss: 0.6165, Val Loss: 10.9144
# Trial 4, Epoch 12, Train Loss: 0.6159, Val Loss: 10.9657
# Trial 4, Epoch 13, Train Loss: 0.6146, Val Loss: 11.0278
# Trial 4, Epoch 14, Train Loss: 0.6146, Val Loss: 11.0984
# Trial 4, Epoch 15, Train Loss: 0.6079, Val Loss: 11.1684
# Trial 4, Epoch 16, Train Loss: 0.6101, Val Loss: 11.2326
# Trial 4, Epoch 17, Train Loss: 0.6157, Val Loss: 11.2574
# Trial 4, Epoch 18, Train Loss: 0.6140, Val Loss: 11.2952
# Trial 4, Epoch 19, Train Loss: 0.6148, Val Loss: 11.3271
# Trial 4: Stopping early at epoch 20
# Saved model for Trial 4 to uni_input_trials\bias_model_trial_4.pth
# Starting trial 5/10
# Trial 5, Epoch 0, Train Loss: 0.7058, Val Loss: 8.9451
# Trial 5, Epoch 1, Train Loss: 0.6876, Val Loss: 9.4954
# Trial 5, Epoch 2, Train Loss: 0.6586, Val Loss: 10.0603
# Trial 5, Epoch 3, Train Loss: 0.6528, Val Loss: 10.3930
# Trial 5, Epoch 4, Train Loss: 0.6423, Val Loss: 10.7801
# Trial 5, Epoch 5, Train Loss: 0.6350, Val Loss: 11.0530
# Trial 5, Epoch 6, Train Loss: 0.6290, Val Loss: 11.2814
# Trial 5, Epoch 7, Train Loss: 0.6221, Val Loss: 11.5321
# Trial 5, Epoch 8, Train Loss: 0.6158, Val Loss: 11.7275
# Trial 5, Epoch 9, Train Loss: 0.6268, Val Loss: 11.8151
# Trial 5, Epoch 10, Train Loss: 0.6227, Val Loss: 11.8483
# Trial 5, Epoch 11, Train Loss: 0.6225, Val Loss: 11.8501
# Trial 5, Epoch 12, Train Loss: 0.6192, Val Loss: 11.9729
# Trial 5, Epoch 13, Train Loss: 0.6191, Val Loss: 12.0842
# Trial 5, Epoch 14, Train Loss: 0.6173, Val Loss: 12.0969
# Trial 5, Epoch 15, Train Loss: 0.6187, Val Loss: 12.1420
# Trial 5, Epoch 16, Train Loss: 0.6235, Val Loss: 12.1718
# Trial 5, Epoch 17, Train Loss: 0.6196, Val Loss: 12.1178
# Trial 5, Epoch 18, Train Loss: 0.6190, Val Loss: 12.1184
# Trial 5, Epoch 19, Train Loss: 0.6109, Val Loss: 12.2097
# Trial 5: Stopping early at epoch 20
# Saved model for Trial 5 to uni_input_trials\bias_model_trial_5.pth
# Starting trial 6/10
# Trial 6, Epoch 0, Train Loss: 0.6450, Val Loss: 9.2756
# Trial 6, Epoch 1, Train Loss: 0.6376, Val Loss: 9.3614
# Trial 6, Epoch 2, Train Loss: 0.6367, Val Loss: 9.4417
# Trial 6, Epoch 3, Train Loss: 0.6350, Val Loss: 9.5181
# Trial 6, Epoch 4, Train Loss: 0.6276, Val Loss: 9.5858
# Trial 6, Epoch 5, Train Loss: 0.6301, Val Loss: 9.6639
# Trial 6, Epoch 6, Train Loss: 0.6286, Val Loss: 9.7413
# Trial 6, Epoch 7, Train Loss: 0.6243, Val Loss: 9.8198
# Trial 6, Epoch 8, Train Loss: 0.6237, Val Loss: 9.8949
# Trial 6, Epoch 9, Train Loss: 0.6222, Val Loss: 9.9968
# Trial 6, Epoch 10, Train Loss: 0.6182, Val Loss: 10.1007
# Trial 6, Epoch 11, Train Loss: 0.6152, Val Loss: 10.2140
# Trial 6, Epoch 12, Train Loss: 0.6195, Val Loss: 10.3043
# Trial 6, Epoch 13, Train Loss: 0.6137, Val Loss: 10.4036
# Trial 6, Epoch 14, Train Loss: 0.6159, Val Loss: 10.4615
# Trial 6, Epoch 15, Train Loss: 0.6147, Val Loss: 10.5209
# Trial 6, Epoch 16, Train Loss: 0.6129, Val Loss: 10.5929
# Trial 6, Epoch 17, Train Loss: 0.6171, Val Loss: 10.6699
# Trial 6, Epoch 18, Train Loss: 0.6132, Val Loss: 10.7405
# Trial 6, Epoch 19, Train Loss: 0.6137, Val Loss: 10.7725
# Trial 6: Stopping early at epoch 20
# Saved model for Trial 6 to uni_input_trials\bias_model_trial_6.pth
# Starting trial 7/10
# Trial 7, Epoch 0, Train Loss: 0.6575, Val Loss: 10.2432
# Trial 7, Epoch 1, Train Loss: 0.6485, Val Loss: 10.2753
# Trial 7, Epoch 2, Train Loss: 0.6361, Val Loss: 10.4345
# Trial 7, Epoch 3, Train Loss: 0.6350, Val Loss: 10.6226
# Trial 7, Epoch 4, Train Loss: 0.6290, Val Loss: 10.6889
# Trial 7, Epoch 5, Train Loss: 0.6246, Val Loss: 10.8063
# Trial 7, Epoch 6, Train Loss: 0.6230, Val Loss: 10.8994
# Trial 7, Epoch 7, Train Loss: 0.6223, Val Loss: 11.0630
# Trial 7, Epoch 8, Train Loss: 0.6171, Val Loss: 11.1472
# Trial 7, Epoch 9, Train Loss: 0.6269, Val Loss: 11.2285
# Trial 7, Epoch 10, Train Loss: 0.6188, Val Loss: 11.3115
# Trial 7, Epoch 11, Train Loss: 0.6106, Val Loss: 11.4851
# Trial 7, Epoch 12, Train Loss: 0.6113, Val Loss: 11.5573
# Trial 7, Epoch 13, Train Loss: 0.6099, Val Loss: 11.6574
# Trial 7, Epoch 14, Train Loss: 0.6165, Val Loss: 11.7867
# Trial 7, Epoch 15, Train Loss: 0.6060, Val Loss: 11.9370
# Trial 7, Epoch 16, Train Loss: 0.6047, Val Loss: 11.9026
# Trial 7, Epoch 17, Train Loss: 0.6097, Val Loss: 11.9807
# Trial 7, Epoch 18, Train Loss: 0.6048, Val Loss: 12.0393
# Trial 7, Epoch 19, Train Loss: 0.6172, Val Loss: 11.9735
# Trial 7: Stopping early at epoch 20
# Saved model for Trial 7 to uni_input_trials\bias_model_trial_7.pth
# Starting trial 8/10
# Trial 8, Epoch 0, Train Loss: 0.6501, Val Loss: 11.7344
# Trial 8, Epoch 1, Train Loss: 0.6454, Val Loss: 11.8523
# Trial 8, Epoch 2, Train Loss: 0.6274, Val Loss: 12.0299
# Trial 8, Epoch 3, Train Loss: 0.6326, Val Loss: 12.1562
# Trial 8, Epoch 4, Train Loss: 0.6285, Val Loss: 12.2580
# Trial 8, Epoch 5, Train Loss: 0.6297, Val Loss: 12.3437
# Trial 8, Epoch 6, Train Loss: 0.6251, Val Loss: 12.4312
# Trial 8, Epoch 7, Train Loss: 0.6311, Val Loss: 12.5414
# Trial 8, Epoch 8, Train Loss: 0.6222, Val Loss: 12.6447
# Trial 8, Epoch 9, Train Loss: 0.6230, Val Loss: 12.7208
# Trial 8, Epoch 10, Train Loss: 0.6242, Val Loss: 12.7585
# Trial 8, Epoch 11, Train Loss: 0.6248, Val Loss: 12.7911
# Trial 8, Epoch 12, Train Loss: 0.6206, Val Loss: 12.8443
# Trial 8, Epoch 13, Train Loss: 0.6263, Val Loss: 12.8724
# Trial 8, Epoch 14, Train Loss: 0.6141, Val Loss: 12.9296
# Trial 8, Epoch 15, Train Loss: 0.6156, Val Loss: 12.9967
# Trial 8, Epoch 16, Train Loss: 0.6223, Val Loss: 13.0115
# Trial 8, Epoch 17, Train Loss: 0.6221, Val Loss: 13.0182
# Trial 8, Epoch 18, Train Loss: 0.6208, Val Loss: 13.0875
# Trial 8, Epoch 19, Train Loss: 0.6258, Val Loss: 13.1186
# Trial 8: Stopping early at epoch 20
# Saved model for Trial 8 to uni_input_trials\bias_model_trial_8.pth
# Starting trial 9/10
# Trial 9, Epoch 0, Train Loss: 0.6148, Val Loss: 10.3117
# Trial 9, Epoch 1, Train Loss: 0.6201, Val Loss: 10.5241
# Trial 9, Epoch 2, Train Loss: 0.6194, Val Loss: 10.6577
# Trial 9, Epoch 3, Train Loss: 0.6190, Val Loss: 10.8053
# Trial 9, Epoch 4, Train Loss: 0.6145, Val Loss: 10.9182
# Trial 9, Epoch 5, Train Loss: 0.6100, Val Loss: 11.0895
# Trial 9, Epoch 6, Train Loss: 0.6201, Val Loss: 11.0912
# Trial 9, Epoch 7, Train Loss: 0.6178, Val Loss: 11.2782
# Trial 9, Epoch 8, Train Loss: 0.6188, Val Loss: 11.3698
# Trial 9, Epoch 9, Train Loss: 0.6230, Val Loss: 11.4858
# Trial 9, Epoch 10, Train Loss: 0.6241, Val Loss: 11.4941
# Trial 9, Epoch 11, Train Loss: 0.6181, Val Loss: 11.5566
# Trial 9, Epoch 12, Train Loss: 0.6231, Val Loss: 11.5376
# Trial 9, Epoch 13, Train Loss: 0.6039, Val Loss: 11.6370
# Trial 9, Epoch 14, Train Loss: 0.6212, Val Loss: 11.7365
# Trial 9, Epoch 15, Train Loss: 0.6070, Val Loss: 11.8064
# Trial 9, Epoch 16, Train Loss: 0.6241, Val Loss: 11.8943
# Trial 9, Epoch 17, Train Loss: 0.6084, Val Loss: 11.9435
# Trial 9, Epoch 18, Train Loss: 0.6113, Val Loss: 11.9246
# Trial 9, Epoch 19, Train Loss: 0.6154, Val Loss: 11.9630
# Trial 9: Stopping early at epoch 20
# Saved model for Trial 9 to uni_input_trials\bias_model_trial_9.pth
# Starting trial 10/10
# Trial 10, Epoch 0, Train Loss: 0.7081, Val Loss: 12.5727
# Trial 10, Epoch 1, Train Loss: 0.6756, Val Loss: 12.3672
# Trial 10, Epoch 2, Train Loss: 0.6559, Val Loss: 12.1678
# Trial 10, Epoch 3, Train Loss: 0.6515, Val Loss: 11.9983
# Trial 10, Epoch 4, Train Loss: 0.6494, Val Loss: 11.8078
# Trial 10, Epoch 5, Train Loss: 0.6395, Val Loss: 11.6529
# Trial 10, Epoch 6, Train Loss: 0.6363, Val Loss: 11.5324
# Trial 10, Epoch 7, Train Loss: 0.6302, Val Loss: 11.4468
# Trial 10, Epoch 8, Train Loss: 0.6210, Val Loss: 11.4066
# Trial 10, Epoch 9, Train Loss: 0.6233, Val Loss: 11.3721
# Trial 10, Epoch 10, Train Loss: 0.6245, Val Loss: 11.3241
# Trial 10, Epoch 11, Train Loss: 0.6205, Val Loss: 11.3248
# Trial 10, Epoch 12, Train Loss: 0.6191, Val Loss: 11.2758
# Trial 10, Epoch 13, Train Loss: 0.6157, Val Loss: 11.3233
# Trial 10, Epoch 14, Train Loss: 0.6170, Val Loss: 11.3337
# Trial 10, Epoch 15, Train Loss: 0.6234, Val Loss: 11.3357
# Trial 10, Epoch 16, Train Loss: 0.6179, Val Loss: 11.3479
# Trial 10, Epoch 17, Train Loss: 0.6155, Val Loss: 11.4328
# Trial 10, Epoch 18, Train Loss: 0.6171, Val Loss: 11.4498
# Trial 10, Epoch 19, Train Loss: 0.6141, Val Loss: 11.4813
# Trial 10, Epoch 20, Train Loss: 0.6121, Val Loss: 11.5384
# Trial 10, Epoch 21, Train Loss: 0.6150, Val Loss: 11.5551
# Trial 10, Epoch 22, Train Loss: 0.6143, Val Loss: 11.5278
# Trial 10, Epoch 23, Train Loss: 0.6132, Val Loss: 11.5774
# Trial 10, Epoch 24, Train Loss: 0.6108, Val Loss: 11.6273
# Trial 10, Epoch 25, Train Loss: 0.6135, Val Loss: 11.7041
# Trial 10, Epoch 26, Train Loss: 0.6120, Val Loss: 11.7153
# Trial 10, Epoch 27, Train Loss: 0.6146, Val Loss: 11.7299
# Trial 10, Epoch 28, Train Loss: 0.6081, Val Loss: 11.8053
# Trial 10, Epoch 29, Train Loss: 0.6117, Val Loss: 11.8415
# Trial 10, Epoch 30, Train Loss: 0.6135, Val Loss: 11.8993
# Trial 10, Epoch 31, Train Loss: 0.6083, Val Loss: 11.9618
# Trial 10: Stopping early at epoch 32
# Saved model for Trial 10 to uni_input_trials\bias_model_trial_10.pth
# Completed all trials and saved models & predictions!

# %%
# # Get predictions on entire set
# combined_X = torch.cat((X_train, X_val, X_test), dim=0)
# combined_y = torch.cat((y_train, y_val, y_test), dim=0)
# # convert x_scaled to tensor
# X_scaled_tensor = torch.tensor(combined_X, dtype=torch.float32).unsqueeze(1)
# bias_model.eval()
# with torch.no_grad():
#     y_pred = bias_model(X_scaled_tensor.to(device)).cpu().numpy()

# %%
# # Unscale outputs
# outputs_unscaled = y_scaler.inverse_transform(y_pred.reshape(y_pred.shape[0], -1))

# %%
# new_df["Bias_Pred"] = outputs_unscaled
# new_df["Corrected_LSTM_Pred"] = new_df["LSTM_Pred"] + new_df["Bias_Pred"]

# %%
# original_error_percent = np.mean(np.abs(new_df["Bias"]) / (np.abs(new_df["Target"]) + 1e-8)) * 100
# corrected_error_percent = np.mean(np.abs(new_df["Target"] - new_df["Corrected_LSTM_Pred"]) / (np.abs(new_df["Target"]) + 1e-8)) * 100

# print(f"Original Error Percentage (entire dataset): {original_error_percent:.4f}%")
# print(f"Corrected Error Percentage (entire dataset): {corrected_error_percent:.4f}%")

# %%
# # plot graph of target vs original vs predicted
# plt.figure(figsize=(25, 15))
# plt.plot(new_df["Target"], label='Target', color='blue')
# plt.plot(new_df["LSTM_Pred"], label='Original Prediction', color='red')
# plt.plot(new_df["Corrected_LSTM_Pred"], label='Corrected Prediction', color='green')
# plt.xlabel('Time')
# plt.ylabel('Value')
# plt.title('Target vs. Original vs. Corrected Prediction')
# plt.legend()
# plt.show()

# %%
# # only plot test dataset
# plt.figure(figsize=(25, 15))
# plt.plot(new_df["Target"].iloc[train_size + val_size:], label='Target', color='blue')
# plt.plot(new_df["LSTM_Pred"].iloc[train_size + val_size:], label='Original Prediction', color='red')
# plt.plot(new_df["Corrected_LSTM_Pred"].iloc[train_size + val_size:], label='Corrected Prediction', color='green')
# plt.xlabel('Time')
# plt.ylabel('Value')
# plt.title('Target vs. Original vs. Corrected Prediction (Test Dataset)')
# plt.legend()
# plt.show()

# %%
# # original error percent of test set
# original_error_percent_test = np.mean(np.abs(new_df["Bias"].iloc[train_size + val_size:]) / (np.abs(new_df["Target"].iloc[train_size + val_size:]) + 1e-8)) * 100
# corrected_error_percent_test = np.mean(np.abs(new_df["Target"].iloc[train_size + val_size:] - new_df["Corrected_LSTM_Pred"].iloc[train_size + val_size:]) / (np.abs(new_df["Target"].iloc[train_size + val_size:]) + 1e-8)) * 100

# print(f"Original Error Percentage (Test Dataset): {original_error_percent_test:.4f}%")
# print(f"Corrected Error Percentage (Test Dataset): {corrected_error_percent_test:.4f}%")

# %%
# concat y values of train test and val 
combined_y = torch.cat((y_train, y_val, y_test), dim=0)
combined_y = combined_y.cpu().numpy()

# %%
# Create empty DataFrame
temp_df = pd.DataFrame()

# Convert all predictions to a DataFrame
for i, predictions in all_predictions.items():
    temp_df[i] = pd.Series(predictions.flatten())  # Convert array to Series

print(temp_df.head())
# Out:
#     trial_1   trial_2   trial_3   trial_4   trial_5   trial_6   trial_7  \
# 0  2.579580  2.585753  2.549533  2.592185  2.664249  2.521983  2.578240
# 1  2.429585  2.386386  2.365198  2.373617  2.514148  2.384296  2.481910
# 2  2.669517  2.662644  2.643829  2.701494  2.732117  2.595972  2.645097
# 3  2.466048  2.441708  2.418121  2.434641  2.553592  2.422491  2.521685
# 4  1.818941  2.333650  1.898431  2.107985  2.076369  2.281044  1.859410
#
#     trial_8   trial_9  trial_10
# 0  2.691653  2.664055  2.613064
# 1  2.566017  2.451157  2.547303
# 2  2.705266  2.710805  2.636448
# 3  2.599394  2.499513  2.584877
# 4  2.058387  1.936709  1.947924

# %%
temp_df["LSTM_prediction_original"] = new_df["LSTM_Pred"]
temp_df["Target"] = new_df["Target"]

# %%
import matplotlib.pyplot as plt

# Define number of trials
num_trials = 10

# Define the test set portion
test_set = temp_df.iloc[train_size + val_size:]

# Create a figure with subplots (2 rows, 5 columns)
fig, axes = plt.subplots(2, 5, figsize=(20, 10))

# Flatten axes array for easy indexing
axes = axes.flatten()

# Iterate over trials and plot each in a separate subplot
for i in range(num_trials):
    trial_col = f'trial_{i+1}'
    
    ax = axes[i]  # Get the current subplot

    # Compute LSTM original + trial prediction for test set only
    corrected_prediction = test_set['LSTM_prediction_original'] + test_set[trial_col]

    # Plot LSTM Original + Bias-Corrected prediction (current trial)
    ax.plot(test_set.index, corrected_prediction, label=f'Trial {i+1} + LSTM', color='orange')

    # Plot Target values for test set
    ax.plot(test_set.index, test_set['Target'], label='Target', color='green')

    # Title and legend
    ax.set_title(f'Trial {i+1} + LSTM vs Target')
    ax.legend()
    ax.set_xlabel('Time Steps')
    ax.set_ylabel('Prediction Value')

# Adjust layout
plt.tight_layout()
plt.show()

# %%
# print average error for each trial over the test set
for i in range(num_trials):
    trial_col = f'trial_{i+1}'
    error = np.mean(np.abs(test_set['Target'] - (test_set['LSTM_prediction_original'] + test_set[trial_col])) / (np.abs(test_set['Target']) + 1e-8)) * 100
    print(f"Trial {i+1} Average Error: {error:.4f}%")
# Out:
# Trial 1 Average Error: 10.6668%
# Trial 2 Average Error: 9.6124%
# Trial 3 Average Error: 10.1832%
# Trial 4 Average Error: 10.4422%
# Trial 5 Average Error: 10.7760%
# Trial 6 Average Error: 10.2415%
# Trial 7 Average Error: 10.6640%
# Trial 8 Average Error: 11.0428%
# Trial 9 Average Error: 10.5730%
# Trial 10 Average Error: 10.6283%

# %%
# print original error of lstm from new_df
original_error_percent = np.mean(np.abs(new_df["Bias"]) / (np.abs(new_df["Target"]) + 1e-8)) * 100
print(f"Original Error Percentage (entire dataset): {original_error_percent:.4f}%")

# print original error of lstm from new_df
original_error_percent_test = np.mean(np.abs(new_df["Bias"].iloc[train_size + val_size:]) / (np.abs(new_df["Target"].iloc[train_size + val_size:]) + 1e-8)) * 100
print(f"Original Error Percentage (Test Dataset): {original_error_percent_test:.4f}%")
# Out:
# Original Error Percentage (entire dataset): 3.6875%
# Original Error Percentage (Test Dataset): 10.7707%
