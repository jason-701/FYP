# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from sklearn.base import BaseEstimator, RegressorMixin

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
file_path = "SPY_section_2.csv"
df = pd.read_csv(file_path)

# start to nov 2001 (dot com crash)
# not bad
# df = df.iloc[:2228]

# nov 01 to june 2009
# not bad
# df = df.iloc[2228:4135]

# june 2009 to april 2020
# ass
# df = df.iloc[4135:6862]

# april 2020 to most recent
# ass
# df = df.iloc[6862:]


# Convert the "Date" column to datetime
# df["Date"] = pd.to_datetime(df["Date"], format='%Y/%m/%d')

# # Sort the data by date in ascending order
# df = df.sort_values(by="Date")

# # Get the earliest and latest dates
# earliest_date = df["Date"].min()
# latest_date = df["Date"].max()

# print("Earliest Date:", earliest_date)
# print("Latest Date:", latest_date)

# %%
# Adding SMA as part of the feature test
short_term_period = 20
medium_term_period = 50
long_term_period = 200

# Compute the SMAs
df['SMA_20'] = df['Close'].rolling(window=short_term_period).mean()
df['SMA_50'] = df['Close'].rolling(window=medium_term_period).mean()
df['SMA_200'] = df['Close'].rolling(window=long_term_period).mean()

df['EMA_10'] = df['Close'].ewm(span=10, adjust=False).mean()  # Short-term EMA
df['EMA_50'] = df['Close'].ewm(span=50, adjust=False).mean()  # Medium-term EMA
df['EMA_200'] = df['Close'].ewm(span=200, adjust=False).mean()  # Long-term EMA

df = df.dropna()

# %%
feature_columns = ["Open", "High", "Low", "Close", "Volume"]  
dates = df["Date"]
# if "Open" and "High" and "Low" and "Close" and "Volume" in df.columns:
#     df = df[feature_columns]

# %%
# scaler = StandardScaler()
# scaler = MinMaxScaler()
# feature_columns = ["Open", "High", "Low", "Close", "Volume", "Day", "Weekday", "Week", "Month", "Year"]
# feature_columns = ["Open", "High", "Low", "Close", "Volume", "SMA_20", "SMA_50", "SMA_200", "EMA_10", "EMA_50", "EMA_200", "Non_Linear_Trend"]
feature_columns = ["Open", "High", "Low", "Close", "Volume", "SMA_20", "SMA_50", "SMA_200", "EMA_10", "EMA_50", "EMA_200"]
# feature_columns = ["Open", "High", "Low", "Close", "Volume", "Non_Linear_Trend", "SMA_20", "SMA_50", "EMA_10", "EMA_50"]
# feature_columns = ["Open", "High", "Low", "Close", "Volume", "Non_Linear_Trend"]
# feature_columns = ["Open", "High", "Low", "Close", "Volume", "SMA_200", "EMA_10"]
X = df[feature_columns]

# Split data
train_size = int(X.shape[0] * 0.7)
val_size = int(X.shape[0] * 0.15)

# Initialize scaler
scaler = MinMaxScaler()
# scaler = RobustScaler()

# Split data into train, validation, and test
temp_train = X[:train_size]
temp_val = X[train_size:train_size + val_size]
temp_test = X[train_size + val_size:]

temp_train = temp_train[feature_columns]
temp_val = temp_val[feature_columns]
temp_test = temp_test[feature_columns]

# Fit and transform for train, transform for validation and test
temp_train = scaler.fit_transform(temp_train)
temp_val = scaler.transform(temp_val)
temp_test = scaler.transform(temp_test)

# Convert NumPy arrays back to DataFrames
temp_train = pd.DataFrame(temp_train, columns=feature_columns)
temp_val = pd.DataFrame(temp_val, columns=feature_columns)
temp_test = pd.DataFrame(temp_test, columns=feature_columns)

# Concatenate the data
X_scaled = pd.concat([temp_train, temp_val, temp_test], axis=0)

# Split sequentially
X_train = X_scaled[:train_size]
X_val = X_scaled[train_size:train_size + val_size]
X_test = X_scaled[train_size + val_size:]

# Print sizes to confirm
print(f"Train: {len(X_train)}, Val: {len(X_val)}, Test: {len(X_test)}")
# Out:
# Train: 1195, Val: 256, Test: 257

# %%
X_train = X_train.values
X_val = X_val.values
X_test = X_test.values

# %%
# Convert data to PyTorch tensors
X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
X_val_tensor = torch.tensor(X_val, dtype=torch.float32)
X_test_tensor = torch.tensor(X_test, dtype=torch.float32)

# Create DataLoader
train_dataset = TensorDataset(X_train_tensor, X_train_tensor)
val_dataset = TensorDataset(X_val_tensor, X_val_tensor)
test_dataset = TensorDataset(X_test_tensor, X_test_tensor)
train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=16, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=16, shuffle=False)

# %%
# # Check if CUDA is available and print the device being used
# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# print(f"Using device: {device}")

# class Encoder(nn.Module):
#     def __init__(self, input_dim, encoding_dim):
#         super(Encoder, self).__init__()
#         self.encoder = nn.Sequential(
#             nn.Linear(input_dim, 128),
#             nn.ReLU(),
#             nn.Dropout(0.2),
#             nn.Linear(128, 64),
#             nn.ReLU(),
#             nn.Dropout(0.2),
#             nn.Linear(64, encoding_dim)
#         )

#     def forward(self, x):
#         return self.encoder(x)

# class Decoder(nn.Module):
#     def __init__(self, encoding_dim, input_dim):
#         super(Decoder, self).__init__()
#         self.decoder = nn.Sequential(
#             nn.Linear(encoding_dim, 64),
#             nn.ReLU(),
#             nn.Dropout(0.2),
#             nn.Linear(64, 128),
#             nn.ReLU(),
#             nn.Dropout(0.2),
#             nn.Linear(128, input_dim)
#         )

#     def forward(self, x):
#         return self.decoder(x)

    
# # Define input dimensions
# input_dim = X_train.shape[1]

# # Model file paths
# encoder_model_file = './autoencoder_trials/encoder.pth'
# decoder_model_file = './autoencoder_trials/decoder.pth'

# # Hyperparameters
# encoding_dim = 8
# learning_rate = 0.001
# epochs = 50
# batch_size = 8
# patience = 5

# # Check if the model files exist
# if os.path.exists(encoder_model_file) and os.path.exists(decoder_model_file):
#     print("Model files exist. Loading the models...")
#     encoder = Encoder(input_dim, encoding_dim).to(device)
#     decoder = Decoder(encoding_dim, input_dim).to(device)
#     encoder.load_state_dict(torch.load(encoder_model_file))
#     decoder.load_state_dict(torch.load(decoder_model_file))
# else:
#     print("Model files do not exist. Training new models...")

#     # Initialize the encoder and decoder models
#     encoder = Encoder(input_dim, encoding_dim).to(device)
#     decoder = Decoder(encoding_dim, input_dim).to(device)
#     optimizer_encoder = optim.Adam(encoder.parameters(), lr=learning_rate)
#     optimizer_decoder = optim.Adam(decoder.parameters(), lr=learning_rate)
#     criterion = nn.MSELoss()

#     # Track training loss
#     encoder_losses = []
#     decoder_losses = []

#     # Train the Encoder separately
#     encoder.train()
#     best_val_loss = float('inf')
#     patience_counter = 0
#     for epoch in range(epochs):
#         epoch_loss = 0
#         dataloader = DataLoader(TensorDataset(torch.tensor(X_train, dtype=torch.float32).to(device), torch.tensor(X_train, dtype=torch.float32).to(device)), batch_size=batch_size, shuffle=True, num_workers=0)
#         for i, (batch_X, _) in enumerate(dataloader):
#             batch_X = batch_X.to(device)
#             optimizer_encoder.zero_grad()
#             encoded = encoder(batch_X)
#             # Pass the encoded output through the decoder
#             decoded = decoder(encoded)
#             # Calculate loss between decoder output and original input
#             loss = criterion(decoded, batch_X)
#             loss.backward()
            
#             optimizer_encoder.step()
#             optimizer_encoder.zero_grad()
            
#             epoch_loss += loss.item()
#         avg_loss = epoch_loss / len(dataloader)
#         encoder_losses.append(avg_loss)
#         print(f"Epoch [{epoch+1}/{epochs}], Encoder Loss: {avg_loss:.4f}")

#         # Validation loss
#         encoder.eval()
#         decoder.eval()
#         with torch.no_grad():
#             val_encoded = encoder(torch.tensor(X_val, dtype=torch.float32).to(device))
#             val_decoded = decoder(val_encoded)
#             val_loss = criterion(val_decoded, torch.tensor(X_val, dtype=torch.float32).to(device)).item()
#         print(f"Validation Loss: {val_loss:.4f}")

#         # Early stopping
#         if val_loss < best_val_loss:
#             best_val_loss = val_loss
#             patience_counter = 0
#         else:
#             patience_counter += 1
#             if patience_counter >= patience:
#                 print("Early stopping triggered.")
#                 break

#     # Train the Decoder separately
#     encoded_train = encoder(torch.tensor(X_train, dtype=torch.float32).to(device)).detach()
#     decoder.train()
#     best_val_loss = float('inf')
#     patience_counter = 0
#     for epoch in range(epochs):
#         epoch_loss = 0
#         dataloader = DataLoader(TensorDataset(encoded_train, torch.tensor(X_train, dtype=torch.float32).to(device)), batch_size=batch_size, shuffle=True, num_workers=0)
#         for i, (batch_X, batch_y) in enumerate(dataloader):
#             batch_X, batch_y = batch_X.to(device), batch_y.to(device)
#             optimizer_decoder.zero_grad()
#             outputs = decoder(batch_X)
#             # Calculate loss between decoder output and original input
#             loss = criterion(outputs, batch_y)
#             loss.backward()
            
#             optimizer_decoder.step()
#             optimizer_decoder.zero_grad()
            
#             epoch_loss += loss.item()
#         avg_loss = epoch_loss / len(dataloader)
#         decoder_losses.append(avg_loss)
#         print(f"Epoch [{epoch+1}/{epochs}], Decoder Loss: {avg_loss:.4f}")

#         # Validation loss
#         decoder.eval()
#         with torch.no_grad():
#             val_outputs = decoder(encoded_train)
#             val_loss = criterion(val_outputs, torch.tensor(X_train, dtype=torch.float32).to(device)).item()
#         print(f"Validation Loss: {val_loss:.4f}")

#         # Early stopping
#         if val_loss < best_val_loss:
#             best_val_loss = val_loss
#             patience_counter = 0
#         else:
#             patience_counter += 1
#             print("Early stopping counter:", patience_counter)
#             if patience_counter >= patience:
#                 print("Early stopping triggered.")
#                 break

#     # Save the trained models
#     os.makedirs('./autoencoder_trials', exist_ok=True)
#     # torch.save(encoder.state_dict(), encoder_model_file)
#     # torch.save(decoder.state_dict(), decoder_model_file)
#     print("Models trained and saved.")

# # Combine Encoder and Decoder to form the Autoencoder
# class Autoencoder(nn.Module):
#     def __init__(self, encoder, decoder):
#         super(Autoencoder, self).__init__()
#         self.encoder = encoder
#         self.decoder = decoder

#     def forward(self, x):
#         encoded = self.encoder(x)
#         decoded = self.decoder(encoded)
#         return decoded

# autoencoder = Autoencoder(encoder, decoder).to(device)
# autoencoder.eval()

# # Calculate reconstruction error on the test set
# with torch.no_grad():
#     reconstructed_test = autoencoder(torch.tensor(X_test, dtype=torch.float32).to(device)).cpu().numpy()

# # Calculate Mean Squared Error (MSE)
# mse = np.mean((X_test - reconstructed_test) ** 2)
# print(f'Mean Squared Error (MSE): {mse}')

# # Calculate Mean Absolute Error (MAE)
# mae = np.mean(np.abs(X_test - reconstructed_test))
# print(f'Mean Absolute Error (MAE): {mae}')

# # Calculate Reconstruction Error Percentage
# # reconstruction_error = np.mean(np.square(X_test - reconstructed_test), axis=1)
# # reconstruction_error_percentage = np.mean(reconstruction_error) * 100
# # print(f'Reconstruction Error Percentage: {reconstruction_error_percentage}')

# reconstruction_error_percentage = (
#     np.mean(np.abs(X_test - reconstructed_test) / (np.abs(X_test) + 1e-8), axis=1) * 100
# )
# reconstruction_error_percentage_mean = np.mean(reconstruction_error_percentage)
# print(f'Reconstruction Error Percentage: {reconstruction_error_percentage_mean}')

# def calculate_index_error_percentage(index, X, reconstructed_X):
#     print(np.mean(np.abs(X[index] - reconstructed_X[index]) / (np.abs(X[index]) + 1e-8)) * 100)

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
from torch.utils.data import DataLoader, TensorDataset

# Check if CUDA is available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Define Encoder
class Encoder(nn.Module):
    def __init__(self, input_dim, encoding_dim, dropout_rate):
        super(Encoder, self).__init__()
        self.encoder = nn.Sequential(
            nn.Linear(input_dim, 128),
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.Linear(64, encoding_dim)
        )

    def forward(self, x):
        return self.encoder(x)

# Define Decoder
class Decoder(nn.Module):
    def __init__(self, encoding_dim, input_dim, dropout_rate):
        super(Decoder, self).__init__()
        self.decoder = nn.Sequential(
            nn.Linear(encoding_dim, 64),
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.Linear(64, 128),
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.Linear(128, input_dim)
        )

    def forward(self, x):
        return self.decoder(x)

# Define input dimensions
input_dim = X_train.shape[1]

# Model file paths
encoder_model_file = './autoencoder_trials/encoder.pth'
decoder_model_file = './autoencoder_trials/decoder.pth'

# Hyperparameters
encoding_dim = 5
learning_rate = 0.0001
dropout_rate = 0.0
epochs = 750
batch_size = 16
patience = 30

# Initialize models
encoder = Encoder(input_dim, encoding_dim, dropout_rate).to(device)
decoder = Decoder(encoding_dim, input_dim, dropout_rate).to(device)

# Define optimizers and loss function
optimizer_encoder = optim.Adam(encoder.parameters(), lr=learning_rate)
optimizer_decoder = optim.Adam(decoder.parameters(), lr=learning_rate)
criterion = nn.MSELoss()
#use MAE
# criterion = nn.L1Loss()

# Add Gaussian noise to encoded representations to avoid overfitting
def add_noise(encoded, noise_factor=0.01):
    return encoded + noise_factor * torch.randn_like(encoded)

# Train Encoder
def train_encoder():
    print("Training Encoder...")
    encoder.train()
    best_val_loss = float('inf')
    patience_counter = 0
    # clip_value = 1

    for epoch in range(epochs):
        epoch_loss = 0
        dataloader = DataLoader(TensorDataset(torch.tensor(X_train, dtype=torch.float32).to(device), 
                                              torch.tensor(X_train, dtype=torch.float32).to(device)), 
                                batch_size=batch_size, shuffle=True, num_workers=0)

        for batch_X, _ in dataloader:
            batch_X = batch_X.to(device)
            optimizer_encoder.zero_grad()
            encoded = encoder(batch_X)
            decoded = decoder(encoded)
            loss = criterion(decoded, batch_X)
            loss.backward()
            
            # torch.nn.utils.clip_grad_norm_(encoder.parameters(), max_norm=clip_value)  # Option 1
            # torch.nn.utils.clip_grad_value_(encoder.parameters(), clip_value=clip_value)  # Option 2

            optimizer_encoder.step()
            epoch_loss += loss.item()

        avg_loss = epoch_loss / len(dataloader)
        print(f"Epoch [{epoch+1}/{epochs}], Encoder Loss: {avg_loss:.4f}")

        # Validation loss
        encoder.eval()
        decoder.eval()
        with torch.no_grad():
            val_encoded = encoder(torch.tensor(X_val, dtype=torch.float32).to(device))
            val_decoded = decoder(val_encoded)
            val_loss = criterion(val_decoded, torch.tensor(X_val, dtype=torch.float32).to(device)).item()
        print(f"Validation Loss: {val_loss:.4f}")

        # Early stopping
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            patience_counter = 0
            torch.save(encoder.state_dict(), encoder_model_file)  # Save best model
        else:
            patience_counter += 1
            print("Early stopping counter:", patience_counter)
            if patience_counter >= patience:
                print("Early stopping triggered for encoder.")
                break

# Train Decoder
def train_decoder():
    print("Training Decoder...")
    encoder.eval()
    encoded_train = encoder(torch.tensor(X_train, dtype=torch.float32).to(device)).detach()

    decoder.train()
    best_val_loss = float('inf')
    patience_counter = 0
    # clip_value = 1

    for epoch in range(epochs):
        epoch_loss = 0
        dataloader = DataLoader(TensorDataset(encoded_train, torch.tensor(X_train, dtype=torch.float32).to(device)), 
                                batch_size=batch_size, shuffle=True, num_workers=0)

        for batch_X, batch_y in dataloader:
            batch_X, batch_y = batch_X.to(device), batch_y.to(device)
            
            # Add Gaussian noise
            noisy_batch_X = add_noise(batch_X)

            optimizer_decoder.zero_grad()
            outputs = decoder(noisy_batch_X)
            loss = criterion(outputs, batch_y)
            loss.backward()
            
            # torch.nn.utils.clip_grad_norm_(decoder.parameters(), max_norm=clip_value)  # Option 1
            # torch.nn.utils.clip_grad_value_(decoder.parameters(), clip_value=clip_value)  # Option 2
            
            optimizer_decoder.step()
            
            epoch_loss += loss.item()

        avg_loss = epoch_loss / len(dataloader)
        print(f"Epoch [{epoch+1}/{epochs}], Decoder Loss: {avg_loss:.4f}")

        # Validation loss
        decoder.eval()
        with torch.no_grad():
            val_encoded = encoder(torch.tensor(X_val, dtype=torch.float32).to(device))
            val_decoded = decoder(val_encoded)
            val_loss = criterion(val_decoded, torch.tensor(X_val, dtype=torch.float32).to(device)).item()
        print(f"Validation Loss: {val_loss:.4f}")

        # Early stopping
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            patience_counter = 0
            torch.save(decoder.state_dict(), decoder_model_file)  # Save best model
        else:
            patience_counter += 1
            print("Early stopping counter:", patience_counter)
            if patience_counter >= patience:
                print("Early stopping triggered for decoder.")
                break

# Train models if files do not exist
if os.path.exists(encoder_model_file) and os.path.exists(decoder_model_file):
    print("Model files exist. Loading the models...")
    encoder.load_state_dict(torch.load(encoder_model_file))
    decoder.load_state_dict(torch.load(decoder_model_file))
else:
    os.makedirs('./autoencoder_trials', exist_ok=True)
    train_encoder()
    train_decoder()

# Combine Encoder and Decoder to form the Autoencoder
class Autoencoder(nn.Module):
    def __init__(self, encoder, decoder):
        super(Autoencoder, self).__init__()
        self.encoder = encoder
        self.decoder = decoder

    def forward(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return decoded

# Load trained models
encoder.load_state_dict(torch.load(encoder_model_file))
decoder.load_state_dict(torch.load(decoder_model_file))
autoencoder = Autoencoder(encoder, decoder).to(device)
autoencoder.eval()

# Calculate reconstruction error on the test set
with torch.no_grad():
    reconstructed_test = autoencoder(torch.tensor(X_test, dtype=torch.float32).to(device)).cpu().numpy()

# Calculate Mean Squared Error (MSE)
mse = np.mean((X_test - reconstructed_test) ** 2)
print(f'Mean Squared Error (MSE): {mse}')

# Calculate Mean Absolute Error (MAE)
mae = np.mean(np.abs(X_test - reconstructed_test))
print(f'Mean Absolute Error (MAE): {mae}')

# Calculate Reconstruction Error Percentage
reconstruction_error_percentage = (
    np.mean(np.abs(X_test - reconstructed_test) / (np.abs(X_test) + 1e-8), axis=1) * 100
)
reconstruction_error_percentage_mean = np.mean(reconstruction_error_percentage)
print(f'Reconstruction Error Percentage: {reconstruction_error_percentage_mean:.4f}%')

def calculate_index_error_percentage(index, X, reconstructed_X):
    print(np.mean(np.abs(X[index] - reconstructed_X[index]) / (np.abs(X[index]) + 1e-8)) * 100)
# Out:
# Using device: cuda
# Training Encoder...
# Epoch [1/750], Encoder Loss: 0.2618
# Validation Loss: 0.8673
# Epoch [2/750], Encoder Loss: 0.2509
# Validation Loss: 0.8217
# Epoch [3/750], Encoder Loss: 0.2287
# Validation Loss: 0.7424
# Epoch [4/750], Encoder Loss: 0.2019
# Validation Loss: 0.6797
# Epoch [5/750], Encoder Loss: 0.1876
# Validation Loss: 0.6539
# Epoch [6/750], Encoder Loss: 0.1822
# Validation Loss: 0.6353
# Epoch [7/750], Encoder Loss: 0.1800
# Validation Loss: 0.6302
# Epoch [8/750], Encoder Loss: 0.1789
# Validation Loss: 0.6279
# Epoch [9/750], Encoder Loss: 0.1786
# Validation Loss: 0.6277
# Epoch [10/750], Encoder Loss: 0.1787
# Validation Loss: 0.6276
# Epoch [11/750], Encoder Loss: 0.1782
# Validation Loss: 0.6274
# Epoch [12/750], Encoder Loss: 0.1785
# Validation Loss: 0.6271
# Epoch [13/750], Encoder Loss: 0.1781
# Validation Loss: 0.6266
# Epoch [14/750], Encoder Loss: 0.1780
# Validation Loss: 0.6262
# Epoch [15/750], Encoder Loss: 0.1781
# Validation Loss: 0.6260
# Epoch [16/750], Encoder Loss: 0.1781
# Validation Loss: 0.6259
# Epoch [17/750], Encoder Loss: 0.1780
# Validation Loss: 0.6257
# Epoch [18/750], Encoder Loss: 0.1776
# Validation Loss: 0.6256
# Epoch [19/750], Encoder Loss: 0.1777
# Validation Loss: 0.6256
# Epoch [20/750], Encoder Loss: 0.1781
# Validation Loss: 0.6255
# Epoch [21/750], Encoder Loss: 0.1778
# Validation Loss: 0.6254
# Epoch [22/750], Encoder Loss: 0.1775
# Validation Loss: 0.6253
# Epoch [23/750], Encoder Loss: 0.1776
# Validation Loss: 0.6253
# Epoch [24/750], Encoder Loss: 0.1779
# Validation Loss: 0.6252
# Epoch [25/750], Encoder Loss: 0.1775
# Validation Loss: 0.6253
# Early stopping counter: 1
# Epoch [26/750], Encoder Loss: 0.1775
# Validation Loss: 0.6252
# Epoch [27/750], Encoder Loss: 0.1776
# Validation Loss: 0.6251
# Epoch [28/750], Encoder Loss: 0.1774
# Validation Loss: 0.6252
# Early stopping counter: 1
# Epoch [29/750], Encoder Loss: 0.1776
# Validation Loss: 0.6251
# Epoch [30/750], Encoder Loss: 0.1775
# Validation Loss: 0.6253
# Early stopping counter: 1
# Epoch [31/750], Encoder Loss: 0.1776
# Validation Loss: 0.6252
# Early stopping counter: 2
# Epoch [32/750], Encoder Loss: 0.1777
# Validation Loss: 0.6253
# Early stopping counter: 3
# Epoch [33/750], Encoder Loss: 0.1778
# Validation Loss: 0.6252
# Early stopping counter: 4
# Epoch [34/750], Encoder Loss: 0.1775
# Validation Loss: 0.6252
# Early stopping counter: 5
# Epoch [35/750], Encoder Loss: 0.1777
# Validation Loss: 0.6250
# Epoch [36/750], Encoder Loss: 0.1776
# Validation Loss: 0.6251
# Early stopping counter: 1
# Epoch [37/750], Encoder Loss: 0.1776
# Validation Loss: 0.6251
# Early stopping counter: 2
# Epoch [38/750], Encoder Loss: 0.1773
# Validation Loss: 0.6251
# Early stopping counter: 3
# Epoch [39/750], Encoder Loss: 0.1773
# Validation Loss: 0.6251
# Early stopping counter: 4
# Epoch [40/750], Encoder Loss: 0.1778
# Validation Loss: 0.6251
# Early stopping counter: 5
# Epoch [41/750], Encoder Loss: 0.1774
# Validation Loss: 0.6251
# Early stopping counter: 6
# Epoch [42/750], Encoder Loss: 0.1775
# Validation Loss: 0.6251
# Early stopping counter: 7
# Epoch [43/750], Encoder Loss: 0.1775
# Validation Loss: 0.6250
# Epoch [44/750], Encoder Loss: 0.1775
# Validation Loss: 0.6250
# Early stopping counter: 1
# Epoch [45/750], Encoder Loss: 0.1775
# Validation Loss: 0.6251
# Early stopping counter: 2
# Epoch [46/750], Encoder Loss: 0.1777
# Validation Loss: 0.6250
# Early stopping counter: 3
# Epoch [47/750], Encoder Loss: 0.1774
# Validation Loss: 0.6250
# Early stopping counter: 4
# Epoch [48/750], Encoder Loss: 0.1775
# Validation Loss: 0.6251
# Early stopping counter: 5
# Epoch [49/750], Encoder Loss: 0.1774
# Validation Loss: 0.6251
# Early stopping counter: 6
# Epoch [50/750], Encoder Loss: 0.1774
# Validation Loss: 0.6250
# Early stopping counter: 7
750], Encoder Loss: 0.1774
# Validation Loss: 0.6246
# Early stopping counter: 1
# Epoch [128/750], Encoder Loss: 0.1776
# Validation Loss: 0.6246
# Epoch [129/750], Encoder Loss: 0.1776
# Validation Loss: 0.6247
# Early stopping counter: 1
# Epoch [130/750], Encoder Loss: 0.1775
# Validation Loss: 0.6246
# Epoch [131/750], Encoder Loss: 0.1773
# Validation Loss: 0.6246
# Early stopping counter: 1
# Epoch [132/750], Encoder Loss: 0.1774
# Validation Loss: 0.6246
# Early stopping counter: 2
# Epoch [133/750], Encoder Loss: 0.1775
# Validation Loss: 0.6246
# Early stopping counter: 3
# Epoch [134/750], Encoder Loss: 0.1776
# Validation Loss: 0.6247
# Early stopping counter: 4
# Epoch [135/750], Encoder Loss: 0.1776
# Validation Loss: 0.6246
# Early stopping counter: 5
# Epoch [136/750], Encoder Loss: 0.1772
# Validation Loss: 0.6246
# Early stopping counter: 6
# Epoch [137/750], Encoder Loss: 0.1776
# Validation Loss: 0.6246
# Early stopping counter: 7
# Epoch [138/750], Encoder Loss: 0.1773
# Validation Loss: 0.6247
# Early stopping counter: 8
# Epoch [139/750], Encoder Loss: 0.1773
# Validation Loss: 0.6246
# Early stopping counter: 9
# Epoch [140/750], Encoder Loss: 0.1776
# Validation Loss: 0.6246
# Early stopping counter: 10
# Epoch [141/750], Encoder Loss: 0.1778
# Validation Loss: 0.6246
# Early stopping counter: 11
# Epoch [142/750], Encoder Loss: 0.1774
# Validation Loss: 0.6246
# Epoch [143/750], Encoder Loss: 0.1774
# Validation Loss: 0.6246
# Early stopping counter: 1
# Epoch [144/750], Encoder Loss: 0.1777
# Validation Loss: 0.6246
# Early stopping counter: 2
# Epoch [145/750], Encoder Loss: 0.1777
# Validation Loss: 0.6247
# Early stopping counter: 3
# Epoch [146/750], Encoder Loss: 0.1774
# Validation Loss: 0.6246
# Early stopping counter: 4
# Epoch [147/750], Encoder Loss: 0.1775
# Validation Loss: 0.6246
# Early stopping counter: 5
# Epoch [148/750], Encoder Loss: 0.1773
# Validation Loss: 0.6246
# Epoch [149/750], Encoder Loss: 0.1775
# Validation Loss: 0.6247
# Early stopping counter: 1
# Epoch [150/750], Encoder Loss: 0.1774
# Validation Loss: 0.6246
# Early stopping counter: 2
# Epoch [151/750], Encoder Loss: 0.1775
# Validation Loss: 0.6246
# Early stopping counter: 3
# Epoch [152/750], Encoder Loss: 0.1774
# Validation Loss: 0.6246
# Early stopping counter: 4
# Epoch [153/750], Encoder Loss: 0.1774
# Validation Loss: 0.6246
# Early stopping counter: 5
# Epoch [154/750], Encoder Loss: 0.1771
# Validation Loss: 0.6246
# Early stopping counter: 6
# Epoch [155/750], Encoder Loss: 0.1775
# Validation Loss: 0.6246
# Early stopping counter: 7
# Epoch [156/750], Encoder Loss: 0.1777
# Validation Loss: 0.6246
# Epoch [157/750], Encoder Loss: 0.1774
# Validation Loss: 0.6246
# Early stopping counter: 1
# Epoch [158/750], Encoder Loss: 0.1773
# Validation Loss: 0.6246
# Early stopping counter: 2
# Epoch [159/750], Encoder Loss: 0.1775
# Validation Loss: 0.6246
# Early stopping counter: 3
# Epoch [160/750], Encoder Loss: 0.1777
# Validation Loss: 0.6246
# Early stopping counter: 4
# Epoch [161/750], Encoder Loss: 0.1772
# Validation Loss: 0.6246
# Early stopping counter: 5
# Epoch [162/750], Encoder Loss: 0.1773
# Validation Loss: 0.6246
# Early stopping counter: 6
# Epoch [163/750], Encoder Loss: 0.1772
# Validation Loss: 0.6246
# Early stopping counter: 7
# Epoch [164/750], Encoder Loss: 0.1773
# Validation Loss: 0.6246
# Early stopping counter: 8
# Epoch [165/750], Encoder Loss: 0.1774
# Validation Loss: 0.6246
# Early stopping counter: 9
# Epoch [166/750], Encoder Loss: 0.1775
# Validation Loss: 0.6246
# Early stopping counter: 10
# Epoch [167/750], Encoder Loss: 0.1775
# Validation Loss: 0.6246
# Early stopping counter: 11
# Epoch [168/750], Encoder Loss: 0.1772
# Validation Loss: 0.6246
# Early stopping counter: 12
# Epoch [169/750], Encoder Loss: 0.1773
# Validation Loss: 0.6246
# Early stopping counter: 13
# Epoch [170/750], Encoder Loss: 0.1774
# Validation Loss: 0.6246
# Early stopping counter: 14
# Epoch [171/750], Encoder Loss: 0.1772
# Validation Loss: 0.6246
# Early stopping counter: 15
# Epoch [172/750], Encoder Loss: 0.1777
# Validation Loss: 0.6245
# Epoch [173/750], Encoder Loss: 0.1775
# Validation Loss: 0.6246
# Early stopping counter: 1
# Epoch [174/750], Encoder Loss: 0.1774
# Validation Loss: 0.6246
# Early stopping counter: 2
# Epoch [175/750], Encoder Loss: 0.1773
# Validation Loss: 0.6246
# Early stopping counter: 3
# Epoch [176/750], Encoder Loss: 0.1775
# Validation Loss: 0.6245
# Early stopping counter: 4
# Epoch [177/750], Encoder Loss: 0.1774
# Validation Loss: 0.6246
# Early stopping counter: 5
# Epoch [178/750], Encoder Loss: 0.1773
# Validation Loss: 0.6245
# Epoch [179/750], Encoder Loss: 0.1772
# Validation Loss: 0.6246
# Early stopping counter: 1
# Epoch [180/750], Encoder Loss: 0.1773
# Validation Loss: 0.6246
# Early stopping counter: 2
# Epoch [181/750], Encoder Loss: 0.1779
# Validation Loss: 0.6246
# Early stopping counter: 3
# Epoch [182/750], Encoder Loss: 0.1774
# Validation Loss: 0.6246
# Early stopping counter: 4
# Epoch [183/750], Encoder Loss: 0.1775
# Validation Loss: 0.6246
# Early stopping counter: 5
# Epoch [184/750], Encoder Loss: 0.1772
# Validation Loss: 0.6245
# Early stopping counter: 6
# Epoch [185/750], Encoder Loss: 0.1774
# Validation Loss: 0.6246
# Early stopping counter: 7
# Epoch [186/750], Encoder Loss: 0.1773
# Validation Loss: 0.6245
# Early stopping counter: 8
# Epoch [187/750], Encoder Loss: 0.1775
# Validation Loss: 0.6246
# Early stopping counter: 9
# Epoch [188/750], Encoder Loss: 0.1770
# Validation Loss: 0.6246
# Early stopping counter: 10
# Epoch [189/750], Encoder Loss: 0.1774
# Validation Loss: 0.6246
# Early stopping counter: 11
# Epoch [190/750], Encoder Loss: 0.1771
# Validation Loss: 0.6246
# Early stopping counter: 12
# Epoch [191/750], Encoder Loss: 0.1775
# Validation Loss: 0.6246
# Early stopping counter: 13
# Epoch [192/750], Encoder Loss: 0.1772
# Validation Loss: 0.6246
# Early stopping counter:
# Epoch [24/750], Decoder Loss: 0.0011
# Validation Loss: 0.0375
# Early stopping counter: 5
# Epoch [25/750], Decoder Loss: 0.0011
# Validation Loss: 0.0325
# Early stopping counter: 6
# Epoch [26/750], Decoder Loss: 0.0011
# Validation Loss: 0.0313
# Early stopping counter: 7
# Epoch [27/750], Decoder Loss: 0.0011
# Validation Loss: 0.0293
# Epoch [28/750], Decoder Loss: 0.0011
# Validation Loss: 0.0325
# Early stopping counter: 1
# Epoch [29/750], Decoder Loss: 0.0010
# Validation Loss: 0.0318
# Early stopping counter: 2
# Epoch [30/750], Decoder Loss: 0.0011
# Validation Loss: 0.0308
# Early stopping counter: 3
# Epoch [31/750], Decoder Loss: 0.0010
# Validation Loss: 0.0328
# Early stopping counter: 4
# Epoch [32/750], Decoder Loss: 0.0010
# Validation Loss: 0.0297
# Early stopping counter: 5
# Epoch [33/750], Decoder Loss: 0.0010
# Validation Loss: 0.0311
# Early stopping counter: 6
# Epoch [34/750], Decoder Loss: 0.0010
# Validation Loss: 0.0290
# Epoch [35/750], Decoder Loss: 0.0010
# Validation Loss: 0.0313
# Early stopping counter: 1
# Epoch [36/750], Decoder Loss: 0.0010
# Validation Loss: 0.0297
# Early stopping counter: 2
# Epoch [37/750], Decoder Loss: 0.0010
# Validation Loss: 0.0293
# Early stopping counter: 3
# Epoch [38/750], Decoder Loss: 0.0010
# Validation Loss: 0.0328
# Early stopping counter: 4
# Epoch [39/750], Decoder Loss: 0.0010
# Validation Loss: 0.0288
# Epoch [40/750], Decoder Loss: 0.0010
# Validation Loss: 0.0289
# Early stopping counter: 1
# Epoch [41/750], Decoder Loss: 0.0010
# Validation Loss: 0.0281
# Epoch [42/750], Decoder Loss: 0.0009
# Validation Loss: 0.0310
# Early stopping counter: 1
# Epoch [43/750], Decoder Loss: 0.0009
# Validation Loss: 0.0291
# Early stopping counter: 2
# Epoch [44/750], Decoder Loss: 0.0009
# Validation Loss: 0.0302
# Early stopping counter: 3
# Epoch [45/750], Decoder Loss: 0.0009
# Validation Loss: 0.0274
# Epoch [46/750], Decoder Loss: 0.0009
# Validation Loss: 0.0286
# Early stopping counter: 1
# Epoch [47/750], Decoder Loss: 0.0009
# Validation Loss: 0.0304
# Early stopping counter: 2
# Epoch [48/750], Decoder Loss: 0.0009
# Validation Loss: 0.0310
# Early stopping counter: 3
# Epoch [49/750], Decoder Loss: 0.0009
# Validation Loss: 0.0275
# Early stopping counter: 4
# Epoch [50/750], Decoder Loss: 0.0009
# Validation Loss: 0.0294
# Early stopping counter: 5
# Epoch [51/750], Decoder Loss: 0.0009
# Validation Loss: 0.0295
# Early stopping counter: 6
# Epoch [52/750], Decoder Loss: 0.0009
# Validation Loss: 0.0260
# Epoch [53/750], Decoder Loss: 0.0009
# Validation Loss: 0.0260
# Early stopping counter: 1
# Epoch [54/750], Decoder Loss: 0.0009
# Validation Loss: 0.0276
# Early stopping counter: 2
# Epoch [55/750], Decoder Loss: 0.0009
# Validation Loss: 0.0256
# Epoch [56/750], Decoder Loss: 0.0009
# Validation Loss: 0.0266
# Early stopping counter: 1
# Epoch [57/750], Decoder Loss: 0.0009
# Validation Loss: 0.0270
# Early stopping counter: 2
# Epoch [58/750], Decoder Loss: 0.0009
# Validation Loss: 0.0244
# Epoch [59/750], Decoder Loss: 0.0008
# Validation Loss: 0.0266
# Early stopping counter: 1
# Epoch [60/750], Decoder Loss: 0.0008
# Validation Loss: 0.0264
# Early stopping counter: 2
# Epoch [61/750], Decoder Loss: 0.0008
# Validation Loss: 0.0277
# Early stopping counter: 3
# Epoch [62/750], Decoder Loss: 0.0008
# Validation Loss: 0.0260
# Early stopping counter: 4
# Epoch [63/750], Decoder Loss: 0.0008
# Validation Loss: 0.0254
# Early stopping counter: 5
# Epoch [64/750], Decoder Loss: 0.0008
# Validation Loss: 0.0265
# Early stopping counter: 6
# Epoch [65/750], Decoder Loss: 0.0008
# Validation Loss: 0.0228
# Epoch [66/750], Decoder Loss: 0.0008
# Validation Loss: 0.0242
# Early stopping counter: 1
# Epoch [67/750], Decoder Loss: 0.0008
# Validation Loss: 0.0227
# Epoch [68/750], Decoder Loss: 0.0008
# Validation Loss: 0.0261
# Early stopping counter: 1
# Epoch [69/750], Decoder Loss: 0.0008
# Validation Loss: 0.0278
# Early stopping counter: 2
# Epoch [70/750], Decoder Loss: 0.0008
# Validation Loss: 0.0244
# Early stopping counter: 3
# Epoch [71/750], Decoder Loss: 0.0008
# Validation Loss: 0.0240
# Early stopping counter: 4
# Epoch [72/750], Decoder Loss: 0.0008
# Validation Loss: 0.0230
# Early stopping counter: 5
# Epoch [73/750], Decoder Loss: 0.0008
# Validation Loss: 0.0233
# Early stopping counter: 6
# Epoch [74/750], Decoder Loss: 0.0008
# Validation Loss: 0.0219
# Epoch [75/750], Decoder Loss: 0.0008
# Validation Loss: 0.0218
# Epoch [76/750], Decoder Loss: 0.0008
# Validation Loss: 0.0237
# Early stopping counter: 1
# Epoch [77/750], Decoder Loss: 0.0008
# Validation Loss: 0.0225
# Early stopping counter: 2
# Epoch [78/750], Decoder Loss: 0.0008
# Validation Loss: 0.0231
# Early stopping counter: 3
# Epoch [79/750], Decoder Loss: 0.0008
# Validation Loss: 0.0233
# Early stopping counter: 4
# Epoch [80/750], Decoder Loss: 0.0008
# Validation Loss: 0.0212
# Epoch [81/750], Decoder Loss: 0.0007
# Validation Loss: 0.0236
# Early stopping counter: 1
# Epoch [82/750], Decoder Loss: 0.0007
# Validation Loss: 0.0222
# Early stopping counter: 2
# Epoch [83/750], Decoder Loss: 0.0007
# Validation Loss: 0.0233
# Early stopping counter: 3
# Epoch [84/750], Decoder Loss: 0.0007
# Validation Loss: 0.0239
# Early stopping counter: 4
# Epoch [85/750], Decoder Loss: 0.0007
# Validation Loss: 0.0218
# Early stopping counter: 5
# Epoch [86/750], Decoder Loss: 0.0007
# Validation Loss: 0.0218
# Early stopping counter: 6
# Epoch [87/750], Decoder Loss: 0.0007
# Validation Loss: 0.0211
# Epoch [88/750], Decoder Loss: 0.0007
# Validation Loss: 0.0218
# Early stopping counter: 1
# Epoch [89/750], Decoder Loss: 0.0007
# Validation Loss: 0.0196
# Epoch [90/750], Decoder Loss: 0.0007
# Validation Loss: 0.0218
# Early stopping counter: 1
# Epoch [91/750], Decoder Loss: 0.0007
# Validation Loss: 0.0220
# Early stopping counter: 2
# Epoch [92/750], Decoder Loss: 0.0007
# Validation Loss: 0.0210
# Early stopping counter: 3
# Epoch [93/750], Decoder Loss: 0.0007
# Validation Loss: 0.0218
# Early stopping counter: 4
# Epoch [94/750], Decoder Loss: 0.0007
# Validation Loss: 0.0212
# Early stopping counter: 5
# Epoch [95/750], Decoder Loss: 0.0007
# Validation Loss: 0.0201
# Early stopping counter: 6
# Epoch [96/750], Decoder Loss: 0.0007
# Validation Loss: 0.0202
# Early stopping counter: 7
# Epoch [97/750], Decoder Loss: 0.0007
# Validation Loss: 0.0204
# Early stopping counter: 8
# Epoch [98/750], Decoder Loss: 0.0007
# Validation Loss: 0.0203
# Early stopping counter: 9
# Epoch [99/750], Decoder Loss: 0.0007
# Validation Loss: 0.0199
# Early stopping counter: 10
# Epoch [100/750], Decoder Loss: 0.0007
# Validation Loss: 0.0222
# Early stopping counter: 11
# Epoch [101/750], Decoder Loss: 0.0007
# Validation Loss: 0.0198
# Early stopping counter: 12
# Epoch [102/750], Decoder Loss: 0.0007
# Validation Loss: 0.0179
# Epoch [103/750], Decoder Loss: 0.0007
# Validation Loss: 0.0199
# Early stopping counter: 1
# Epoch [104/750], Decoder Loss: 0.0007
# Validation Loss: 0.0211
# Early stopping counter: 2
# Epoch [105/750], Decoder Loss: 0.0007
# Validation Loss: 0.0214
# Early stopping counter: 3
# Epoch [106/750], Decoder Loss: 0.0007
# Validation Loss: 0.0182
# Early stopping counter: 4
# Epoch [107/750], Decoder Loss: 0.0007
# Validation Loss: 0.0192
# Early stopping counter: 5
# Epoch [108/750], Decoder Loss: 0.0007
# Validation Loss: 0.0183
# Early stopping counter: 6
# Epoch [109/750], Decoder Loss: 0.0007
# Validation Loss: 0.0192
# Early stopping counter: 7
# Epoch [110/750], Decoder Loss: 0.0006
# Validation Loss: 0.0197
# Early stopping counter: 8
# Epoch [111/750], Decoder Loss: 0.0006
# Validation Loss: 0.0192
# Early stopping counter: 9
# Epoch [112/750], Decoder Loss: 0.0006
# Validation Loss: 0.0187
# Early stopping counter: 10
# Epoch [113/750], Decoder Loss: 0.0006
# Validation Loss: 0.0172
# Epoch [114/750], Decoder Loss: 0.0006
# Validation Loss: 0.0188
# Early stopping counter: 1
# Epoch [115/750], Decoder Loss: 0.0006
# Validation Loss: 0.0170
# Epoch [116/750], Decoder Loss: 0.0006
# Validation Loss: 0.0158
# Epoch [117/750], Decoder Loss: 0.0006
# Validation Loss: 0.0152
# Epoch [118/750], Decoder Loss: 0.0006
# Validation Loss: 0.0165
# Early stopping counter: 1
# Epoch [119/750], Decoder Loss: 0.0006
# Validation Loss: 0.0177
# Early stopping counter: 2
# Epoch [120/750], Decoder Loss: 0.0006
# Validation Loss: 0.0173
# Early stopping counter: 3
# Epoch [217/750], Decoder Loss: 0.0004
# Validation Loss: 0.0096
# Early stopping counter: 3
# Epoch [218/750], Decoder Loss: 0.0004
# Validation Loss: 0.0094
# Early stopping counter: 4
# Epoch [219/750], Decoder Loss: 0.0004
# Validation Loss: 0.0094
# Early stopping counter: 5
# Epoch [220/750], Decoder Loss: 0.0004
# Validation Loss: 0.0096
# Early stopping counter: 6
# Epoch [221/750], Decoder Loss: 0.0004
# Validation Loss: 0.0091
# Early stopping counter: 7
# Epoch [222/750], Decoder Loss: 0.0004
# Validation Loss: 0.0097
# Early stopping counter: 8
# Epoch [223/750], Decoder Loss: 0.0004
# Validation Loss: 0.0095
# Early stopping counter: 9
# Epoch [224/750], Decoder Loss: 0.0004
# Validation Loss: 0.0090
# Early stopping counter: 10
# Epoch [225/750], Decoder Loss: 0.0004
# Validation Loss: 0.0091
# Early stopping counter: 11
# Epoch [226/750], Decoder Loss: 0.0004
# Validation Loss: 0.0085
# Epoch [227/750], Decoder Loss: 0.0004
# Validation Loss: 0.0093
# Early stopping counter: 1
# Epoch [228/750], Decoder Loss: 0.0004
# Validation Loss: 0.0088
# Early stopping counter: 2
# Epoch [229/750], Decoder Loss: 0.0004
# Validation Loss: 0.0090
# Early stopping counter: 3
# Epoch [230/750], Decoder Loss: 0.0004
# Validation Loss: 0.0095
# Early stopping counter: 4
# Epoch [231/750], Decoder Loss: 0.0004
# Validation Loss: 0.0088
# Early stopping counter: 5
# Epoch [232/750], Decoder Loss: 0.0004
# Validation Loss: 0.0094
# Early stopping counter: 6
# Epoch [233/750], Decoder Loss: 0.0004
# Validation Loss: 0.0090
# Early stopping counter: 7
# Epoch [234/750], Decoder Loss: 0.0004
# Validation Loss: 0.0088
# Early stopping counter: 8
# Epoch [235/750], Decoder Loss: 0.0004
# Validation Loss: 0.0096
# Early stopping counter: 9
# Epoch [236/750], Decoder Loss: 0.0004
# Validation Loss: 0.0081
# Epoch [237/750], Decoder Loss: 0.0004
# Validation Loss: 0.0096
# Early stopping counter: 1
# Epoch [238/750], Decoder Loss: 0.0004
# Validation Loss: 0.0089
# Early stopping counter: 2
# Epoch [239/750], Decoder Loss: 0.0004
# Validation Loss: 0.0082
# Early stopping counter: 3
# Epoch [240/750], Decoder Loss: 0.0004
# Validation Loss: 0.0084
# Early stopping counter: 4
# Epoch [241/750], Decoder Loss: 0.0004
# Validation Loss: 0.0086
# Early stopping counter: 5
# Epoch [242/750], Decoder Loss: 0.0004
# Validation Loss: 0.0088
# Early stopping counter: 6
# Epoch [243/750], Decoder Loss: 0.0004
# Validation Loss: 0.0098
# Early stopping counter: 7
# Epoch [244/750], Decoder Loss: 0.0004
# Validation Loss: 0.0072
# Epoch [245/750], Decoder Loss: 0.0004
# Validation Loss: 0.0092
# Early stopping counter: 1
# Epoch [246/750], Decoder Loss: 0.0004
# Validation Loss: 0.0087
# Early stopping counter: 2
# Epoch [247/750], Decoder Loss: 0.0004
# Validation Loss: 0.0081
# Early stopping counter: 3
# Epoch [248/750], Decoder Loss: 0.0004
# Validation Loss: 0.0078
# Early stopping counter: 4
# Epoch [249/750], Decoder Loss: 0.0004
# Validation Loss: 0.0068
# Epoch [250/750], Decoder Loss: 0.0004
# Validation Loss: 0.0076
# Early stopping counter: 1
# Epoch [251/750], Decoder Loss: 0.0004
# Validation Loss: 0.0087
# Early stopping counter: 2
# Epoch [252/750], Decoder Loss: 0.0004
# Validation Loss: 0.0086
# Early stopping counter: 3
# Epoch [253/750], Decoder Loss: 0.0004
# Validation Loss: 0.0094
# Early stopping counter: 4
# Epoch [254/750], Decoder Loss: 0.0004
# Validation Loss: 0.0077
# Early stopping counter: 5
# Epoch [255/750], Decoder Loss: 0.0004
# Validation Loss: 0.0078
# Early stopping counter: 6
# Epoch [256/750], Decoder Loss: 0.0004
# Validation Loss: 0.0078
# Early stopping counter: 7
# Epoch [257/750], Decoder Loss: 0.0004
# Validation Loss: 0.0069
# Early stopping counter: 8
# Epoch [258/750], Decoder Loss: 0.0004
# Validation Loss: 0.0082
# Early stopping counter: 9
# Epoch [259/750], Decoder Loss: 0.0004
# Validation Loss: 0.0091
# Early stopping counter: 10
# Epoch [260/750], Decoder Loss: 0.0004
# Validation Loss: 0.0075
# Early stopping counter: 11
# Epoch [261/750], Decoder Loss: 0.0004
# Validation Loss: 0.0081
# Early stopping counter: 12
# Epoch [262/750], Decoder Loss: 0.0004
# Validation Loss: 0.0073
# Early stopping counter: 13
# Epoch [263/750], Decoder Loss: 0.0004
# Validation Loss: 0.0073
# Early stopping counter: 14
# Epoch [264/750], Decoder Loss: 0.0004
# Validation Loss: 0.0077
# Early stopping counter: 15
# Epoch [265/750], Decoder Loss: 0.0004
# Validation Loss: 0.0071
# Early stopping counter: 16
# Epoch [266/750], Decoder Loss: 0.0004
# Validation Loss: 0.0077
# Early stopping counter: 17
# Epoch [267/750], Decoder Loss: 0.0004
# Validation Loss: 0.0077
# Early stopping counter: 18
# Epoch [268/750], Decoder Loss: 0.0004
# Validation Loss: 0.0069
# Early stopping counter: 19
# Epoch [269/750], Decoder Loss: 0.0004
# Validation Loss: 0.0074
# Early stopping counter: 20
# Epoch [270/750], Decoder Loss: 0.0004
# Validation Loss: 0.0084
# Early stopping counter: 21
# Epoch [271/750], Decoder Loss: 0.0004
# Validation Loss: 0.0072
# Early stopping counter: 22
# Epoch [272/750], Decoder Loss: 0.0004
# Validation Loss: 0.0068
# Early stopping counter: 23
# Epoch [273/750], Decoder Loss: 0.0004
# Validation Loss: 0.0076
# Early stopping counter: 24
# Epoch [274/750], Decoder Loss: 0.0004
# Validation Loss: 0.0084
# Early stopping counter: 25
# Epoch [275/750], Decoder Loss: 0.0004
# Validation Loss: 0.0070
# Early stopping counter: 26
# Epoch [276/750], Decoder Loss: 0.0004
# Validation Loss: 0.0064
# Epoch [277/750], Decoder Loss: 0.0004
# Validation Loss: 0.0069
# Early stopping counter: 1
# Epoch [278/750], Decoder Loss: 0.0004
# Validation Loss: 0.0077
# Early stopping counter: 2
# Epoch [279/750], Decoder Loss: 0.0004
# Validation Loss: 0.0079
# Early stopping counter: 3
# Epoch [280/750], Decoder Loss: 0.0004
# Validation Loss: 0.0068
# Early stopping counter: 4
# Epoch [281/750], Decoder Loss: 0.0004
# Validation Loss: 0.0074
# Early stopping counter: 5
# Epoch [282/750], Decoder Loss: 0.0004
# Validation Loss: 0.0074
# Early stopping counter: 6
# Epoch [283/750], Decoder Loss: 0.0004
# Validation Loss: 0.0072
# Early stopping counter: 7
# Epoch [284/750], Decoder Loss: 0.0003
# Validation Loss: 0.0060
# Epoch [285/750], Decoder Loss: 0.0004
# Validation Loss: 0.0065
# Early stopping counter: 1
# Epoch [286/750], Decoder Loss: 0.0004
# Validation Loss: 0.0072
# Early stopping counter: 2
# Epoch [287/750], Decoder Loss: 0.0004
# Validation Loss: 0.0070
# Early stopping counter: 3
# Epoch [288/750], Decoder Loss: 0.0004
# Validation Loss: 0.0063
# Early stopping counter: 4
# Epoch [289/750], Decoder Loss: 0.0004
# Validation Loss: 0.0060
# Epoch [290/750], Decoder Loss: 0.0004
# Validation Loss: 0.0070
# Early stopping counter: 1
# Epoch [291/750], Decoder Loss: 0.0004
# Validation Loss: 0.0070
# Early stopping counter: 2
# Epoch [292/750], Decoder Loss: 0.0004
# Validation Loss: 0.0061
# Early stopping counter: 3
# Epoch [293/750], Decoder Loss: 0.0004
# Validation Loss: 0.0079
# Early stopping counter: 4
# Epoch [294/750], Decoder Loss: 0.0003
# Validation Loss: 0.0071
# Early stopping counter: 5
# Epoch [295/750], Decoder Loss: 0.0004
# Validation Loss: 0.0081
# Early stopping counter: 6
# Epoch [296/750], Decoder Loss: 0.0004
# Validation Loss: 0.0079
# Early stopping counter: 7
# Epoch [297/750], Decoder Loss: 0.0004
# Validation Loss: 0.0061
# Early stopping counter: 8
# Epoch [298/750], Decoder Loss: 0.0003
# Validation Loss: 0.0073
# Early stopping counter: 9
# Epoch [299/750], Decoder Loss: 0.0003
# Validation Loss: 0.0063
# Early stopping counter: 10
# Epoch [300/750], Decoder Loss: 0.0004
# Validation Loss: 0.0055
# Epoch [301/750], Decoder Loss: 0.0004
# Validation Loss: 0.0072
# Early stopping counter: 1
# Epoch [302/750], Decoder Loss: 0.0004
# Validation Loss: 0.0060
# Early stopping counter: 2
# Epoch [303/750], Decoder Loss: 0.0003
# Validation Loss: 0.0070
# Early stopping counter: 3
# Epoch [304/750], Decoder Loss: 0.0004
# Validation Loss: 0.0057
# Early stopping counter: 4
# Epoch [305/750], Decoder Loss: 0.0004
# Validation Loss: 0.0054
# Epoch [306/750], Decoder Loss: 0.0003
# Validation Loss: 0.0065
# Early stopping counter: 1
# Epoch [307/750], Decoder Loss: 0.0003
# Validation Loss: 0.0066
# Early stopping counter: 2
# Epoch [308/750], Decoder Loss: 0.0003
# Validation Loss: 0.0073
# Early stopping counter: 3
# Epoch [309/750], Decoder Loss: 0.0003
# Validation Loss: 0.0053
# Epoch [310/750], Decoder Loss: 0.0003
# Validation Loss: 0.0051
# Epoch [311/750], Decoder Loss: 0.0004
# Validation Loss: 0.0060
# Early stopping counter: 1
# Epoch [312/750], Decoder Loss: 0.0003
# Validation Loss: 0.0064
# Early stopping counter: 2
# Epoch [313/750], Decoder Loss: 0.0003
# Validation Loss: 0.0066
# Early stopping counter: 3
# Epoch [314/750], Decoder Loss: 0.0004
# Validation Loss: 0.0061
# Early stopping counter: 4
# Epoch [315/750], Decoder Loss: 0.0003
# Validation Loss: 0.0065
# Early stopping counter: 5
# Epoch [316/750], Decoder Loss: 0.0004
# Validation Loss: 0.0048
# Epoch [317/750], Decoder Loss: 0.0004
# Validation Loss: 0.0062
# Early stopping counter: 1
# Epoch [318/750], Decoder Loss: 0.0003
# Validation Loss: 0.0060
# Early stopping counter: 2
# Epoch [319/750], Decoder Loss: 0.0003
# Validation Loss: 0.0051
# Early stopping counter: 3
# Epoch [320/750], Decoder Loss: 0.0003
# Validation Loss: 0.0057
# Early stopping counter: 4
# Epoch [321/750], Decoder Loss: 0.0003
# Validation Loss: 0.0062
# Early stopping counter: 5
# Epoch [322/750], Decoder Loss: 0.0003
# Validation Loss: 0.0058
# Early stopping counter: 6
# Epoch [323/750], Decoder Loss: 0.0003
# Validation Loss: 0.0061
# Early stopping counter: 7
# Epoch [324/750], Decoder Loss: 0.0003
# Validation Loss: 0.0061
# Early stopping counter: 8
# Epoch [325/750], Decoder Loss: 0.0003
# Validation Loss: 0.0065
# Early stopping counter: 9
# Epoch [326/750], Decoder Loss: 0.0003
# Validation Loss: 0.0061
# Early stopping counter: 10
# Epoch [327/750], Decoder Loss: 0.0004
# Validation Loss: 0.0059
# Early stopping counter: 11
# Epoch [328/750], Decoder Loss: 0.0003
# Validation Loss: 0.0062
# Early stopping counter: 12
# Epoch [329/750], Decoder Loss: 0.0003
# Validation Loss: 0.0060
# Early stopping counter: 13
# Epoch [330/750], Decoder Loss: 0.0004
# Validation Loss: 0.0072
# Early stopping counter: 14
# Epoch [331/750], Decoder Loss: 0.0003
# Validation Loss: 0.0053
# Early stopping counter: 15
# Epoch [332/750], Decoder Loss: 0.0003
# Validation Loss: 0.0067
# Early stopping counter: 16
# Epoch [333/750], Decoder Loss: 0.0003
# Validation Loss: 0.0058
# Early stopping counter: 17
# Epoch [334/750], Decoder Loss: 0.0003
# Validation Loss: 0.0057
# Early stopping counter: 18
# Epoch [335/750], Decoder Loss: 0.0003
# Validation Loss: 0.0057
# Early stopping counter: 19
# Epoch [336/750], Decoder Loss: 0.0003
# Validation Loss: 0.0052
# Early stopping counter: 20
# Epoch [337/750], Decoder Loss: 0.0004
# Validation Loss: 0.0063
# Early stopping counter: 21
# Epoch [338/750], Decoder Loss: 0.0003
# Validation Loss: 0.0064
# Early stopping counter: 22
# Epoch [339/750], Decoder Loss: 0.0003
# Validation Loss: 0.0064
# Early stopping counter: 23
# Epoch [340/750], Decoder Loss: 0.0004
# Validation Loss: 0.0061
# Early stopping counter: 24
# Epoch [341/750], Decoder Loss: 0.0003
# Validation Loss: 0.0052
# Early stopping counter: 25
# Epoch [342/750], Decoder Loss: 0.0003
# Validation Loss: 0.0052
# Early stopping counter: 26
# Epoch [343/750], Decoder Loss: 0.0003
# Validation Loss: 0.0058
# Early stopping counter: 27
# Epoch [344/750], Decoder Loss: 0.0003
# Validation Loss: 0.0049
# Early stopping counter: 28
# Epoch [345/750], Decoder Loss: 0.0003
# Validation Loss: 0.0063
# Early stopping counter: 29
# Epoch [346/750], Decoder Loss: 0.0003
# Validation Loss: 0.0053
# Early stopping counter: 30
# Early stopping triggered for decoder.
# Mean Squared Error (MSE): 0.030545312846985733
# Mean Absolute Error (MAE): 0.10880374989762888
# Reconstruction Error Percentage: 42.1956%
# C:\Users\ROG\AppData\Local\Temp/ipykernel_16200/312451534.py:208: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   encoder.load_state_dict(torch.load(encoder_model_file))
# C:\Users\ROG\AppData\Local\Temp/ipykernel_16200/312451534.py:209: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   decoder.load_state_dict(torch.load(decoder_model_file))

# %%
# number of points with error greater than average
np.sum(reconstruction_error_percentage > reconstruction_error_percentage_mean)
# Out:
# 66

# %%
# plot line graph of price for entire df, price column is df['Close']
last_15_percent_index = int(len(df) * 0.85)
last_30_percent_index = int(len(df) * 0.70)

plt.figure(figsize=(14, 7))
plt.plot(df['Close'], label='Train', color='blue')
plt.plot(df['Close'].iloc[last_30_percent_index:last_15_percent_index], label='Val', color='green')
plt.plot(df['Close'].iloc[last_15_percent_index:], label='Test', color='red')
plt.title('Close Price History')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
#   scatter graph to plot all errors, dont need to rearragne points
plt.figure(figsize=(14, 7))
plt.scatter(range(len(reconstruction_error_percentage)), reconstruction_error_percentage, color='blue')
plt.ylim(0, 200)
plt.title('Reconstruction Error Percentage')
plt.xlabel('Data Point')
plt.ylabel('Error Percentage')
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
# error count frequency per range
error_ranges = [0, 1, 2, 5, 10, 20, 50, 100, 200]
error_counts = np.zeros(len(error_ranges) - 1)
for i in range(len(error_ranges) - 1):
    error_counts[i] = np.sum((reconstruction_error_percentage > error_ranges[i]) & (reconstruction_error_percentage <= error_ranges[i + 1]))
print(error_counts)
# Out:
# [  0.   0.   0.  67.  22. 113.  36.  11.]

# %%
# print with descriptino
for i in range(len(error_ranges) - 1):
    print(f'Error percentage between {error_ranges[i]} and {error_ranges[i + 1]}: {error_counts[i]}')
# Out:
# Error percentage between 0 and 1: 0.0
# Error percentage between 1 and 2: 0.0
# Error percentage between 2 and 5: 0.0
# Error percentage between 5 and 10: 67.0
# Error percentage between 10 and 20: 22.0
# Error percentage between 20 and 50: 113.0
# Error percentage between 50 and 100: 36.0
# Error percentage between 100 and 200: 11.0

# %%
#sum error count
np.sum(error_counts)
# Out:
# 249.0

# %%
len(X_test)
# Out:
# 257

# %%
# remove top 10 highest errors and get new error average without them
top_10_indices = np.argsort(reconstruction_error_percentage)[-10:]
top_10_indices

# remove from reconstruction_error_percentages
reconstruction_error_percentage_no_top_10 = np.delete(reconstruction_error_percentage, top_10_indices)

print(f'Original Error Percentage Mean: {reconstruction_error_percentage_mean}')
print(f'Error Percentage Mean Without Top 10: {np.mean(reconstruction_error_percentage_no_top_10)}')
# Out:
# Original Error Percentage Mean: 42.195578554601866
# Error Percentage Mean Without Top 10: 32.347637915742496

# %%
# get cosine similarity
from sklearn.metrics.pairwise import cosine_similarity
cosine_similarities  = np.diag(cosine_similarity(X_test, reconstructed_test))

# get some statistics on the cosine similarities
cosine_similarities_mean = np.mean(cosine_similarities)
cosine_similarities_std = np.std(cosine_similarities)
cosine_similarities_min = np.min(cosine_similarities)
cosine_similarities_max = np.max(cosine_similarities)

print(f'Cosine Similarity Mean: {cosine_similarities_mean}')
print(f'Cosine Similarity Std: {cosine_similarities_std}')
print(f'Cosine Similarity Min: {cosine_similarities_min}')
print(f'Cosine Similarity Max: {cosine_similarities_max}')
# Out:
# Cosine Similarity Mean: 0.9626205848028971
# Cosine Similarity Std: 0.028748029849896734
# Cosine Similarity Min: 0.8398178637079368
# Cosine Similarity Max: 0.9960350502799343

# %%
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

# Combine original and reconstructed vectors
X_combined = np.vstack([X_test, reconstructed_test])
labels = ["Original"] * len(X_test) + ["Reconstructed"] * len(reconstructed_test)

# Apply t-SNE
tsne = TSNE(n_components=2, perplexity=30, random_state=42)
X_tsne = tsne.fit_transform(X_combined)

# Plot
plt.figure(figsize=(12, 6))
plt.scatter(X_tsne[:len(X_test), 0], X_tsne[:len(X_test), 1], label="Original", alpha=0.5)
plt.scatter(X_tsne[len(X_test):, 0], X_tsne[len(X_test):, 1], label="Reconstructed", alpha=0.5)
plt.legend()
plt.title("t-SNE Visualization of Original vs. Reconstructed Data")
plt.show()

# %%
from sklearn.decomposition import PCA

X_combined = np.vstack([X_test, reconstructed_test])

# Apply PCA
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_combined)

# Plot
plt.figure(figsize=(12, 6))
plt.scatter(X_pca[:len(X_test), 0], X_pca[:len(X_test), 1], label="Original", alpha=0.5)
plt.scatter(X_pca[len(X_test):, 0], X_pca[len(X_test):, 1], label="Reconstructed", alpha=0.5)
plt.legend()
plt.title("PCA Projection of Original vs. Reconstructed Data")
plt.show()

# %%
for i in range (50,100):
    print(f'Index: {i}')
    calculate_index_error_percentage(i, X_test, reconstructed_test)
# Out:
# Index: 50
# 6.523963515894395
# Index: 51
# 7.084301467519037
# Index: 52
# 7.901007485527043
# Index: 53
# 7.41380885939002
# Index: 54
# 6.752386715709225
# Index: 55
# 6.943204028715157
# Index: 56
# 6.732343904360398
# Index: 57
# 8.659956677882539
# Index: 58
# 9.863810112641556
# Index: 59
# 10.34499763032449
# Index: 60
# 13.186877427921917
# Index: 61
# 11.609381211422406
# Index: 62
# 7.919903824898257
# Index: 63
# 6.704937017617045
# Index: 64
# 7.481660558572142
# Index: 65
# 6.803145306017103
# Index: 66
# 7.691102730928696
# Index: 67
# 7.862830060612827
# Index: 68
# 8.673316164555521
# Index: 69
# 7.999050477096602
# Index: 70
# 8.070420950020623
# Index: 71
# 7.300901721510638
# Index: 72
# 8.133018731569862
# Index: 73
# 10.298261278969743
# Index: 74
# 9.327275415565063
# Index: 75
# 17.888450742455557
# Index: 76
# 21.607063708893175
# Index: 77
# 18.339263791209877
# Index: 78
# 11.833616293875012
# Index: 79
# 20.150067903186894
# Index: 80
# 15.638962741898618
# Index: 81
# 19.620349496662772
# Index: 82
# 22.323605835184797
# Index: 83
# 21.042553586534755
# Index: 84
# 19.679278273626487
# Index: 85
# 18.121582474914227
# Index: 86
# 28.055380719945866
# Index: 87
# 37.715253441543815
# Index: 88
# 21.87083826410428
# Index: 89
# 18.769532368920363
# Index: 90
# 21.901418830452943
# Index: 91
# 21.264593353501485
# Index: 92
# 30.583853451618314
# Index: 93
# 21.30647687690536
# Index: 94
# 21.251478133919218
# Index: 95
# 21.256997788537852
# Index: 96
# 24.785878203870013
# Index: 97
# 27.434628748866025
# Index: 98
# 25.18315274661213
# Index: 99
# 27.741193671565373

# %%
from numpy.linalg import norm

euclidean_dist = np.mean([norm(X_test[i] - reconstructed_test[i]) for i in range(len(X_test))])
print(f"Average Euclidean Distance: {euclidean_dist:.4f}")

relative_error = euclidean_dist / np.mean(np.linalg.norm(X_test, axis=1))
print(f"Relative Euclidean Error: {relative_error:.4f}")
# Out:
# Average Euclidean Distance: 0.5337
# Relative Euclidean Error: 0.2751
